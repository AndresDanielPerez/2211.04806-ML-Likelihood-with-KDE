# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import gridspec
from matplotlib import patches
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

import os
import math
import random

import keras
from keras.models import Sequential
from keras.layers import Input, Dense, Conv2D, Flatten, MaxPooling2D
from keras.layers import Dropout
from keras.callbacks import EarlyStopping

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn import preprocessing
from sklearn.metrics import roc_curve, roc_auc_score, auc

import scipy.stats as st
from scipy.stats import poisson
from scipy.interpolate import interp1d
from scipy.stats import norm

# %%
from sklearn.neighbors import KernelDensity # paquete necesario
from sklearn.model_selection import GridSearchCV

import scipy.integrate as integrate

# %%
# !pip install xgboost

import xgboost
from xgboost import XGBRegressor, XGBClassifier
# Out:
# Requirement already satisfied: xgboost in /home/andres/anaconda3/lib/python3.8/site-packages (1.5.1)
# Requirement already satisfied: scipy in /home/andres/.local/lib/python3.8/site-packages (from xgboost) (1.9.3)
# Requirement already satisfied: numpy in /home/andres/.local/lib/python3.8/site-packages (from xgboost) (1.22.4)
# WARNING: You are using pip version 21.3.1; however, version 23.2 is available.
# You should consider upgrading via the '/home/andres/anaconda3/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# ## DATA

# %%
# data

folder_data = "../../MLL-exclusion/data/"

# %%
folder_saved = "Zprime-SSM-mumu-mZ5000GeV-variables/"

# 1st DATASET
e1pt_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-pt-5000-1.txt', delimiter=',')
e1eta_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-eta-5000-1.txt', delimiter=',')
e1phi_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-phi-5000-1.txt', delimiter=',')

e2pt_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-pt-5000-1.txt', delimiter=',')
e2eta_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-eta-5000-1.txt', delimiter=',')
e2phi_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-phi-5000-1.txt', delimiter=',')




# INVARIANT MASS

invariant_mass_eeSM = []

for i in range(len(e1pt_eeSSMZprime)):
    invariant_mass_eeSM.append( ( 2 * e1pt_eeSSMZprime[i] * e2pt_eeSSMZprime[i] * ( np.cosh(e1eta_eeSSMZprime[i] - e2eta_eeSSMZprime[i]) - np.cos(e1phi_eeSSMZprime[i] - e2phi_eeSSMZprime[i]) ) )**0.5 )
    
print(len(invariant_mass_eeSM))

f= open(folder_data + folder_saved + "mmumu-1.txt","w")
for i in range(len(invariant_mass_eeSM)):
    f.write("%.3f\n" % invariant_mass_eeSM[i] )
f.close()




# 2nd DATASET
e1pt_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-pt-5000-2.txt', delimiter=',')
e1eta_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-eta-5000-2.txt', delimiter=',')
e1phi_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-phi-5000-2.txt', delimiter=',')

e2pt_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-pt-5000-2.txt', delimiter=',')
e2eta_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-eta-5000-2.txt', delimiter=',')
e2phi_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-phi-5000-2.txt', delimiter=',')




# INVARIANT MASS

invariant_mass_eeSM = []

for i in range(len(e1pt_eeSSMZprime)):
    invariant_mass_eeSM.append( ( 2 * e1pt_eeSSMZprime[i] * e2pt_eeSSMZprime[i] * ( np.cosh(e1eta_eeSSMZprime[i] - e2eta_eeSSMZprime[i]) - np.cos(e1phi_eeSSMZprime[i] - e2phi_eeSSMZprime[i]) ) )**0.5 )
    
print(len(invariant_mass_eeSM))

f= open(folder_data + folder_saved + "mmumu-2.txt","w")
for i in range(len(invariant_mass_eeSM)):
    f.write("%.3f\n" % invariant_mass_eeSM[i] )
f.close()
# Out:
# 721501
# 720147

# %%
# just to check that we need to ask again that the invariant mass has to be greater than 2000 GeV

bins_atlas = [70, 80.0, 90.0, 105.0, 120.0, 140.0, 160.0, 180.0, 210.0, 240.0, 275.0, 315.0, 360.0, 415.0, 475.0, 545.0, 625.0, 715.0, 825.0, 950.0, 1100.0, 1250.0, 1450.0, 1650.0, 1900.0, 2200.0, 2500.0, 2850.0, 3250.0, 3750.0, 4350.0, 5000.0, 5750.0, 6600.0, 7500.0, 8750.0, 10000.0, 11500.0, 13000.0, 20000]

folder_saved = "SM/mumu/"

invariant_mass_eeSM_1800 = np.loadtxt(folder_data + folder_saved +"mmumu-1800.txt", delimiter=',')
invariant_mass_eeSM_1800_2 = np.loadtxt(folder_data + folder_saved +"mmumu-1800-2.txt", delimiter=',')

plt.hist(invariant_mass_eeSM_1800, bins=bins_atlas, lw=2, edgecolor='lightblue', histtype='step', label="SM (dataset 1)")
plt.hist(invariant_mass_eeSM_1800_2, bins=bins_atlas, lw=2, edgecolor='green', histtype='step', label="SM (dataset 2)")


folder_saved = "Zprime-SSM-mumu-mZ5000GeV-variables/"

invariant_mass_eeSSMZprime_1 = np.loadtxt(folder_data + folder_saved +"mmumu-1.txt", delimiter=',')
invariant_mass_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved +"mmumu-2.txt", delimiter=',')

plt.hist(invariant_mass_eeSSMZprime_1, bins=bins_atlas, lw=2, edgecolor='pink', histtype='step', label="$Z'_{SSM}$ (dataset 1)")
plt.hist(invariant_mass_eeSSMZprime_2, bins=bins_atlas, lw=2, edgecolor='darkorange', histtype='step', label="$Z'_{SSM}$ (dataset 2)")


plt.grid()  # Add grid lines

plt.title(r"Z/Z'$\rightarrow$e+e-",fontsize=14)  # Titles etc
plt.xlabel("$m_{ll}$ (GeV)",fontsize=14)
plt.ylabel("Events",fontsize=14)

plt.xlim(70.,20000)
plt.ylim(1e0,1e7)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xscale('log')
plt.yscale('log')
plt.legend(loc='upper left',fontsize=12)

plt.show()

# %% [markdown]
# ### SM

# %%
######
# SM #
######


folder_saved = "SM/mumu/"


# 1st DATASET
invariant_mass_eeSM = np.loadtxt(folder_data + folder_saved +"mmumu-1800.txt", delimiter=',')

e1pt_eeSM = np.loadtxt(folder_data + folder_saved + 'mu1_pt_events_IM_1800.txt', delimiter=',')
e1eta_eeSM = np.loadtxt(folder_data + folder_saved + 'mu1_eta_events_IM_1800.txt', delimiter=',')
e1phi_eeSM = np.loadtxt(folder_data + folder_saved + 'mu1_phi_events_IM_1800.txt', delimiter=',')

e2pt_eeSM = np.loadtxt(folder_data + folder_saved + 'mu2_pt_events_IM_1800.txt', delimiter=',')
e2eta_eeSM = np.loadtxt(folder_data + folder_saved + 'mu2_eta_events_IM_1800.txt', delimiter=',')
e2phi_eeSM = np.loadtxt(folder_data + folder_saved + 'mu2_phi_events_IM_1800.txt', delimiter=',')


# only keep points where the invariant mass is greater than 2000 GeV
# and make sure that both electrons: |eta| < 2.65
for i in reversed(range(len(invariant_mass_eeSM))):
    if invariant_mass_eeSM[i]< 2000 or e1eta_eeSM[i] < -2.65 or e1eta_eeSM[i] > 2.65 or e2eta_eeSM[i] < -2.65 or e2eta_eeSM[i] > 2.65:
        e1pt_eeSM = np.delete(e1pt_eeSM, i)
        e1eta_eeSM = np.delete(e1eta_eeSM, i)
        e1phi_eeSM = np.delete(e1phi_eeSM, i)
        
        e2pt_eeSM = np.delete(e2pt_eeSM, i)
        e2eta_eeSM = np.delete(e2eta_eeSM, i)
        e2phi_eeSM = np.delete(e2phi_eeSM, i)
        
        invariant_mass_eeSM = np.delete(invariant_mass_eeSM, i)
        

        
        
# 2nd DATASET
invariant_mass_eeSM_1800 = np.loadtxt(folder_data + folder_saved +"mmumu-1800-2.txt", delimiter=',')

e1pt_eeSM_1800 = np.loadtxt(folder_data + folder_saved + 'mu1_pt_events_IM_1800_2.txt', delimiter=',')
e1eta_eeSM_1800 = np.loadtxt(folder_data + folder_saved + 'mu1_eta_events_IM_1800_2.txt', delimiter=',')
e1phi_eeSM_1800 = np.loadtxt(folder_data + folder_saved + 'mu1_phi_events_IM_1800_2.txt', delimiter=',')

e2pt_eeSM_1800 = np.loadtxt(folder_data + folder_saved + 'mu2_pt_events_IM_1800_2.txt', delimiter=',')
e2eta_eeSM_1800 = np.loadtxt(folder_data + folder_saved + 'mu2_eta_events_IM_1800_2.txt', delimiter=',')
e2phi_eeSM_1800 = np.loadtxt(folder_data + folder_saved + 'mu2_phi_events_IM_1800_2.txt', delimiter=',')


# only keep points where the invariant mass is greater than 2000 GeV
# and make sure that both electrons: |eta| < 2.65
for i in reversed(range(len(invariant_mass_eeSM_1800))):
    if invariant_mass_eeSM_1800[i]< 2000 or e1eta_eeSM_1800[i] < -2.65 or e1eta_eeSM_1800[i] > 2.65 or e2eta_eeSM_1800[i] < -2.65 or e2eta_eeSM_1800[i] > 2.65:
        e1pt_eeSM_1800 = np.delete(e1pt_eeSM_1800, i)
        e1eta_eeSM_1800 = np.delete(e1eta_eeSM_1800, i)
        e1phi_eeSM_1800 = np.delete(e1phi_eeSM_1800, i)
        
        e2pt_eeSM_1800 = np.delete(e2pt_eeSM_1800, i)
        e2eta_eeSM_1800 = np.delete(e2eta_eeSM_1800, i)
        e2phi_eeSM_1800 = np.delete(e2phi_eeSM_1800, i)
        
        invariant_mass_eeSM_1800 = np.delete(invariant_mass_eeSM_1800, i)
        


# concatenate results
e1pt_eeSM = np.concatenate([e1pt_eeSM,e1pt_eeSM_1800])
e1eta_eeSM = np.concatenate([e1eta_eeSM,e1eta_eeSM_1800])
e1phi_eeSM = np.concatenate([e1phi_eeSM,e1phi_eeSM_1800])

e2pt_eeSM = np.concatenate([e2pt_eeSM,e2pt_eeSM_1800])
e2eta_eeSM = np.concatenate([e2eta_eeSM,e2eta_eeSM_1800])
e2phi_eeSM = np.concatenate([e2phi_eeSM,e2phi_eeSM_1800])

invariant_mass_eeSM = np.concatenate([invariant_mass_eeSM,invariant_mass_eeSM_1800])



# remove the aux
del e1pt_eeSM_1800
del e1eta_eeSM_1800
del e1phi_eeSM_1800

del e2pt_eeSM_1800
del e2eta_eeSM_1800
del e2phi_eeSM_1800

del invariant_mass_eeSM_1800




# FINALLY

# compute \Delta \eta_{l+l-}
e1e2diffeta_eeSM = np.array([a-b for a,b in zip(e1eta_eeSM,e2eta_eeSM)])

# compute R = [ \Delta \eta_{l+l-}^2 + \Delta \eta_{l+l-}^2 ]^1/2
e1e2R_eeSM = np.array([( (a-b)**2. + (c-d)**2. )**0.5 for a,b,c,d in zip(e1eta_eeSM,e2eta_eeSM,e1phi_eeSM,e2phi_eeSM)])



print(e1pt_eeSM.shape)
print(e1eta_eeSM.shape)
print(e1phi_eeSM.shape)

print(e2pt_eeSM.shape)
print(e2eta_eeSM.shape)
print(e2phi_eeSM.shape)

print(invariant_mass_eeSM.shape)
print(e1e2diffeta_eeSM.shape)
print(e1e2R_eeSM.shape)
# Out:
# (804774,)
# (804774,)
# (804774,)
# (804774,)
# (804774,)
# (804774,)
# (804774,)
# (804774,)
# (804774,)

# %%
print(min(e1eta_eeSM))
print(max(e1eta_eeSM))

print(min(e2eta_eeSM))
print(max(e2eta_eeSM))
# Out:
# -2.646
# 2.648
# -2.649
# 2.649

# %% [markdown]
# ### SSM Z prime

# %%
##########
# Zprime #
##########


folder_saved = "Zprime-SSM-mumu-mZ5000GeV-variables/"


# 1st DATASET
invariant_mass_eeSSMZprime = np.loadtxt(folder_data + folder_saved +"mmumu-1.txt", delimiter=',')

e1pt_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-pt-5000-1.txt', delimiter=',')
e1eta_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-eta-5000-1.txt', delimiter=',')
e1phi_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-phi-5000-1.txt', delimiter=',')

e2pt_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-pt-5000-1.txt', delimiter=',')
e2eta_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-eta-5000-1.txt', delimiter=',')
e2phi_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-phi-5000-1.txt', delimiter=',')


# only keep points where the invariant mass is greater than 2000 GeV
# and make sure that both electrons: |eta| < 2.65
for i in reversed(range(len(invariant_mass_eeSSMZprime))):
    if invariant_mass_eeSSMZprime[i]< 2000 or e1eta_eeSSMZprime[i] < -2.65 or e1eta_eeSSMZprime[i] > 2.65 or e2eta_eeSSMZprime[i] < -2.65 or e2eta_eeSSMZprime[i] > 2.65:
        e1pt_eeSSMZprime = np.delete(e1pt_eeSSMZprime, i)
        e1eta_eeSSMZprime = np.delete(e1eta_eeSSMZprime, i)
        e1phi_eeSSMZprime = np.delete(e1phi_eeSSMZprime, i)
        
        e2pt_eeSSMZprime = np.delete(e2pt_eeSSMZprime, i)
        e2eta_eeSSMZprime = np.delete(e2eta_eeSSMZprime, i)
        e2phi_eeSSMZprime = np.delete(e2phi_eeSSMZprime, i)
        
        invariant_mass_eeSSMZprime = np.delete(invariant_mass_eeSSMZprime, i)

        
        
        
        
# 2nd DATASET
invariant_mass_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved +"mmumu-2.txt", delimiter=',')

e1pt_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved + 'mu1-pt-5000-2.txt', delimiter=',')
e1eta_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved + 'mu1-eta-5000-2.txt', delimiter=',')
e1phi_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved + 'mu1-phi-5000-2.txt', delimiter=',')

e2pt_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved + 'mu2-pt-5000-2.txt', delimiter=',')
e2eta_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved + 'mu2-eta-5000-2.txt', delimiter=',')
e2phi_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved + 'mu2-phi-5000-2.txt', delimiter=',')


# only keep points where the invariant mass is greater than 2000 GeV
# and make sure that both electrons: |eta| < 2.65
for i in reversed(range(len(invariant_mass_eeSSMZprime_2))):
    if invariant_mass_eeSSMZprime_2[i]< 2000 or e1eta_eeSSMZprime_2[i] < -2.65 or e1eta_eeSSMZprime_2[i] > 2.65 or e2eta_eeSSMZprime_2[i] < -2.65 or e2eta_eeSSMZprime_2[i] > 2.65:
        e1pt_eeSSMZprime_2 = np.delete(e1pt_eeSSMZprime_2, i)
        e1eta_eeSSMZprime_2 = np.delete(e1eta_eeSSMZprime_2, i)
        e1phi_eeSSMZprime_2 = np.delete(e1phi_eeSSMZprime_2, i)
        
        e2pt_eeSSMZprime_2 = np.delete(e2pt_eeSSMZprime_2, i)
        e2eta_eeSSMZprime_2 = np.delete(e2eta_eeSSMZprime_2, i)
        e2phi_eeSSMZprime_2 = np.delete(e2phi_eeSSMZprime_2, i)
        
        invariant_mass_eeSSMZprime_2 = np.delete(invariant_mass_eeSSMZprime_2, i)
        
eventos_parton = 1000000
aceptancia_eeSSMZprime_2 = 1.*len(invariant_mass_eeSSMZprime_2) / eventos_parton
print(aceptancia_eeSSMZprime_2)


# concatenate results
e1pt_eeSSMZprime = np.concatenate([e1pt_eeSSMZprime,e1pt_eeSSMZprime_2])
e1eta_eeSSMZprime = np.concatenate([e1eta_eeSSMZprime,e1eta_eeSSMZprime_2])
e1phi_eeSSMZprime = np.concatenate([e1phi_eeSSMZprime,e1phi_eeSSMZprime_2])

e2pt_eeSSMZprime = np.concatenate([e2pt_eeSSMZprime,e2pt_eeSSMZprime_2])
e2eta_eeSSMZprime = np.concatenate([e2eta_eeSSMZprime,e2eta_eeSSMZprime_2])
e2phi_eeSSMZprime = np.concatenate([e2phi_eeSSMZprime,e2phi_eeSSMZprime_2])

invariant_mass_eeSSMZprime = np.concatenate([invariant_mass_eeSSMZprime,invariant_mass_eeSSMZprime_2])



# remove the aux
del e1pt_eeSSMZprime_2
del e1eta_eeSSMZprime_2
del e1phi_eeSSMZprime_2

del e2pt_eeSSMZprime_2
del e2eta_eeSSMZprime_2
del e2phi_eeSSMZprime_2

del invariant_mass_eeSSMZprime_2








# FINALLY

# compute \Delta \eta_{l+l-}
e1e2diffeta_eeSSMZprime = np.array([a-b for a,b in zip(e1eta_eeSSMZprime,e2eta_eeSSMZprime)])

# compute R = [ \Delta \eta_{l+l-}^2 + \Delta \eta_{l+l-}^2 ]^1/2
e1e2R_eeSSMZprime = np.array([( (a-b)**2. + (c-d)**2. )**0.5 for a,b,c,d in zip(e1eta_eeSSMZprime,e2eta_eeSSMZprime,e1phi_eeSSMZprime,e2phi_eeSSMZprime)])




print(e1pt_eeSSMZprime.shape)
print(e1eta_eeSSMZprime.shape)
print(e1phi_eeSSMZprime.shape)

print(e2pt_eeSSMZprime.shape)
print(e2eta_eeSSMZprime.shape)
print(e2phi_eeSSMZprime.shape)

print(invariant_mass_eeSSMZprime.shape)
print(e1e2diffeta_eeSSMZprime.shape)
print(e1e2R_eeSSMZprime.shape)
# Out:
# 0.720128
# (1441606,)
# (1441606,)
# (1441606,)
# (1441606,)
# (1441606,)
# (1441606,)
# (1441606,)
# (1441606,)
# (1441606,)

# %%
print(min(e1eta_eeSSMZprime))
print(max(e1eta_eeSSMZprime))

print(min(e2eta_eeSSMZprime))
print(max(e2eta_eeSSMZprime))
# Out:
# -2.629
# 2.635
# -2.649
# 2.649

# %%
# NOW DATA IS CHECKED

bins_atlas = [70, 80.0, 90.0, 105.0, 120.0, 140.0, 160.0, 180.0, 210.0, 240.0, 275.0, 315.0, 360.0, 415.0, 475.0, 545.0, 625.0, 715.0, 825.0, 950.0, 1100.0, 1250.0, 1450.0, 1650.0, 1900.0, 2200.0, 2500.0, 2850.0, 3250.0, 3750.0, 4350.0, 5000.0, 5750.0, 6600.0, 7500.0, 8750.0, 10000.0, 11500.0, 13000.0, 20000]

plt.hist(invariant_mass_eeSM, bins=bins_atlas, lw=2, edgecolor='blue', histtype='step', label="SM")
plt.hist(invariant_mass_eeSSMZprime, bins=bins_atlas, lw=2, edgecolor='red', histtype='step', label="$Z'_{SSM}$")

plt.grid()  # Add grid lines

plt.title(r"Z/Z'$\rightarrow \mu+ \mu-$",fontsize=14)  # Titles etc
plt.xlabel("$m_{ll}$ (GeV)",fontsize=14)
plt.ylabel("Events",fontsize=14)

plt.xlim(70.,20000)
plt.ylim(1e0,1e7)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xscale('log')
plt.yscale('log')
plt.legend(loc='upper left',fontsize=12)

plt.show()




plt.hist(e1e2diffeta_eeSM, bins=100, range=[-5,5], lw=2, edgecolor='blue', histtype='step', label="SM")
plt.hist(e1e2diffeta_eeSSMZprime, bins=100, range=[-5,5], lw=2, edgecolor='red', histtype='step', label="$Z'_{SSM}$")

plt.grid()  # Add grid lines

plt.title(r"Z/Z'$\rightarrow \mu+ \mu-$",fontsize=14)  # Titles etc
plt.xlabel("$\Delta \eta_{ll}$",fontsize=14)
plt.ylabel("Events",fontsize=14)

plt.xlim(-5,5)
plt.ylim(1e0,1e7)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#plt.xscale('log')
plt.yscale('log')
plt.legend(loc='upper left',fontsize=12)

plt.show()




plt.hist(e1e2R_eeSM, bins=82, range=[0,8.2], lw=2, edgecolor='blue', histtype='step', label="SM")
plt.hist(e1e2R_eeSSMZprime, bins=82, range=[0,8.2], lw=2, edgecolor='red', histtype='step', label="$Z'_{SSM}$")

plt.grid()  # Add grid lines

plt.title(r"Z/Z'$\rightarrow \mu+ \mu-$",fontsize=14)  # Titles etc
plt.xlabel("$R$",fontsize=14)
plt.ylabel("Events",fontsize=14)

plt.xlim(0.,8.2)
plt.ylim(1e0,1e7)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#plt.xscale('log')
plt.yscale('log')
plt.legend(loc='upper left',fontsize=12)

plt.show()

# %% [markdown]
# ### Train-test-val datasets

# %%
# to normalize
scaler = preprocessing.MinMaxScaler()

# Number of data points (per-class) for the ML classifier
num_data = 750000



df = pd.DataFrame()

df['e1-pt']= np.concatenate([e1pt_eeSM[:num_data],e1pt_eeSSMZprime[:num_data]])
df['e1-eta']= np.concatenate([e1eta_eeSM[:num_data],e1eta_eeSSMZprime[:num_data]])
df['e1-phi']= np.concatenate([e1phi_eeSM[:num_data],e1phi_eeSSMZprime[:num_data]])

df['e2-pt']= np.concatenate([e2pt_eeSM[:num_data],e2pt_eeSSMZprime[:num_data]])
df['e2-eta']= np.concatenate([e2eta_eeSM[:num_data],e2eta_eeSSMZprime[:num_data]])
df['e2-phi']= np.concatenate([e2phi_eeSM[:num_data],e2phi_eeSSMZprime[:num_data]])

df['mll']= np.concatenate([invariant_mass_eeSM[:num_data],invariant_mass_eeSSMZprime[:num_data]])
df['delta-eta']= np.concatenate([e1e2diffeta_eeSM[:num_data],e1e2diffeta_eeSSMZprime[:num_data]])
df['R']= np.concatenate([e1e2R_eeSM[:num_data],e1e2R_eeSSMZprime[:num_data]])

df['Y'] = np.concatenate([np.zeros(num_data),np.ones(num_data)])


# remove the used data
del e1pt_eeSM
del e1eta_eeSM
del e1phi_eeSM

del e2pt_eeSM
del e2eta_eeSM
del e2phi_eeSM

del e1pt_eeSSMZprime
del e1eta_eeSSMZprime
del e1phi_eeSSMZprime

del e2pt_eeSSMZprime
del e2eta_eeSSMZprime
del e2phi_eeSSMZprime


# NORMALIZE
df = scaler.fit_transform(df)
df = pd.DataFrame(df,columns=['e1-pt','e1-eta','e1-phi','e2-pt','e2-eta','e2-phi','mll','delta-eta','R','Y'])


# print df to see the data
print(df)


# X and Y for the classifier
X_mon = df[['e1-pt','e1-eta','e1-phi','e2-pt','e2-eta','e2-phi']].values
y_mon = df[['Y']].values

del df

# divide into train-val and test data samples
test_ratio = 1./3
val_ratio = 0.25


X_mon_aux, X_mon_test, y_mon_aux, y_mon_test = train_test_split(X_mon,
                                                                y_mon,
                                                                test_size=test_ratio,
                                                                random_state=42,
                                                                #stratify = y_mon,
                                                                shuffle=True)


X_mon_train, X_mon_val, y_mon_train, y_mon_val = train_test_split(X_mon_aux,
                                                                  y_mon_aux,
                                                                  test_size=val_ratio,
                                                                  random_state=42,
                                                                  #stratify = y_mon_aux,
                                                                  shuffle=True)


print('')
print('X_mon_train : ', X_mon_train.shape)
print('y_mon_train : ', y_mon_train.shape)
print('X_mon_val : ', X_mon_val.shape)
print('y_mon_val : ', y_mon_val.shape)
print('X_mon_test : ', X_mon_test.shape)
print('y_mon_test : ', y_mon_test.shape)
print('')
# Out:
#             e1-pt    e1-eta    e1-phi     e2-pt    e2-eta    e2-phi       mll  \
# 0        0.237383  0.591235  0.081158  0.279270  0.609664  0.557288  0.039780
# 1        0.231715  0.636759  0.312540  0.265668  0.353341  0.827976  0.121861
# 2        0.313298  0.703627  0.972311  0.347861  0.502831  0.473265  0.181610
# 3        0.218136  0.581224  0.581158  0.233058  0.567573  0.101528  0.002850
# 4        0.193023  0.544012  0.273711  0.242338  0.285957  0.765595  0.061335
# ...           ...       ...       ...       ...       ...       ...       ...
# 1499995  0.517921  0.515489  0.892266  0.585320  0.581540  0.393221  0.383801
# 1499996  0.231188  0.123347  0.661044  0.259959  0.678935  0.169796  0.426186
# 1499997  0.207316  0.777295  0.283259  0.236309  0.204983  0.785805  0.391508
# 1499998  0.572974  0.435399  0.264004  0.624024  0.400906  0.764163  0.430443
# 1499999  0.166409  0.909331  0.181891  0.205421  0.255002  0.678071  0.421981
#
#          delta-eta         R    Y
# 0         0.490750  0.271333  0.0
# 1         0.644826  0.364958  0.0
# 2         0.602621  0.322957  0.0
# 3         0.507130  0.274793  0.0
# 4         0.631914  0.334095  0.0
# ...            ...       ...  ...
# 1499995   0.466468  0.297597  1.0
# 1499996   0.216708  0.477517  1.0
# 1499997   0.792253  0.496057  1.0
# 1499998   0.517826  0.296464  1.0
# 1499999   0.834072  0.542191  1.0
#
# [1500000 rows x 10 columns]
#
# X_mon_train :  (750000, 6)
# y_mon_train :  (750000, 1)
# X_mon_val :  (250000, 6)
# y_mon_val :  (250000, 1)
# X_mon_test :  (500000, 6)
# y_mon_test :  (500000, 1)

# %% [markdown]
# ### XGBoost (per-event)

# %% [markdown]
# ##### For 1 ML

# %%
# XGBoost with only the kinematic variables of the leptons

# CLASSIFIER
classifier = XGBClassifier(
    n_estimators=2500,
    learning_rate=0.1,
    reg_lambda=0.0,reg_alpha=0.0,
    gamma=0.0,objective='binary:logistic',
    max_depth=5)

# FIT
classifier.fit(X_mon_train,y_mon_train,eval_set=[(X_mon_train, y_mon_train), (X_mon_val, y_mon_val)],
        eval_metric='logloss',early_stopping_rounds=50,#early stopping
        verbose=True)

# PREDICTIONS
y_pred_xg_1ML = classifier.predict_proba(X_mon_test).T[1]


# ROC
fpr_mon_xg, tpr_mon_xg, _ = roc_curve(y_mon_test, y_pred_xg_1ML)
roc_auc_xg = auc(fpr_mon_xg, tpr_mon_xg)


# PLOT THE ROC WITH AUC
fig = plt.figure(figsize=(6, 6))
gs = gridspec.GridSpec(1, 1) 
ax0 = plt.subplot(gs[0])
ax0.yaxis.set_ticks_position('both')
ax0.xaxis.set_ticks_position('both')
ax0.tick_params(direction="in",which="both")
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
ax0.minorticks_on()


plt.plot(tpr_mon_xg,1-fpr_mon_xg,label="$f_{1}$, AUC = %0.2f" % roc_auc_xg,color="orange",ls=":",lw=4)
plt.plot([1,0],[0,1],ls=":",color="grey")
plt.xlabel("True Positive Rate",fontsize=16)
plt.ylabel("1 $-$ False Positive Rate",fontsize=16)
plt.legend()
plt.title(r"SSM Z' - XGBoost",fontsize=16)
plt.xlim([0,1])
plt.ylim([0,1])
plt.yticks([0.2,0.4,0.6,0.8,1.])
plt.legend(frameon=False,fontsize=16)
plt.show()




feature_names = np.array(['e1-pt','e1-eta','e1-phi','e2-pt','e2-eta','e2-phi'])
plt.barh(feature_names, classifier.feature_importances_)
plt.xlabel("Xgboost Feature Importance")
plt.show()
# Out:
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [0]	validation_0-logloss:0.63588	validation_1-logloss:0.63587
# [1]	validation_0-logloss:0.58856	validation_1-logloss:0.58870
# [2]	validation_0-logloss:0.54846	validation_1-logloss:0.54853
# [3]	validation_0-logloss:0.51424	validation_1-logloss:0.51433
# [4]	validation_0-logloss:0.48534	validation_1-logloss:0.48548
# [5]	validation_0-logloss:0.46059	validation_1-logloss:0.46076
# [6]	validation_0-logloss:0.43896	validation_1-logloss:0.43907
# [7]	validation_0-logloss:0.41977	validation_1-logloss:0.41994
# [8]	validation_0-logloss:0.40297	validation_1-logloss:0.40300
# [9]	validation_0-logloss:0.38819	validation_1-logloss:0.38819
# [10]	validation_0-logloss:0.37380	validation_1-logloss:0.37379
# [11]	validation_0-logloss:0.36240	validation_1-logloss:0.36235
# [12]	validation_0-logloss:0.35161	validation_1-logloss:0.35161
# [13]	validation_0-logloss:0.34232	validation_1-logloss:0.34244
# [14]	validation_0-logloss:0.33441	validation_1-logloss:0.33449
# [15]	validation_0-logloss:0.32706	validation_1-logloss:0.32721
# [16]	validation_0-logloss:0.31912	validation_1-logloss:0.31921
# [17]	validation_0-logloss:0.31306	validation_1-logloss:0.31318
# [18]	validation_0-logloss:0.30667	validation_1-logloss:0.30678
# [19]	validation_0-logloss:0.30179	validation_1-logloss:0.30194
# [20]	validation_0-logloss:0.29771	validation_1-logloss:0.29784
# [21]	validation_0-logloss:0.29302	validation_1-logloss:0.29318
# [22]	validation_0-logloss:0.28959	validation_1-logloss:0.28974
# [23]	validation_0-logloss:0.28663	validation_1-logloss:0.28676
# [24]	validation_0-logloss:0.28309	validation_1-logloss:0.28329
# [25]	validation_0-logloss:0.27983	validation_1-logloss:0.28004
# [26]	validation_0-logloss:0.27719	validation_1-logloss:0.27742
# [27]	validation_0-logloss:0.27493	validation_1-logloss:0.27518
# [28]	validation_0-logloss:0.27281	validation_1-logloss:0.27309
# [29]	validation_0-logloss:0.27048	validation_1-logloss:0.27076
# [30]	validation_0-logloss:0.26891	validation_1-logloss:0.26918
# [31]	validation_0-logloss:0.26682	validation_1-logloss:0.26712
# [32]	validation_0-logloss:0.26482	validation_1-logloss:0.26515
# [33]	validation_0-logloss:0.26323	validation_1-logloss:0.26359
# [34]	validation_0-logloss:0.26192	validation_1-logloss:0.26230
# [35]	validation_0-logloss:0.26031	validation_1-logloss:0.26078
# [36]	validation_0-logloss:0.25944	validation_1-logloss:0.25993
# [37]	validation_0-logloss:0.25834	validation_1-logloss:0.25882
# [38]	validation_0-logloss:0.25735	validation_1-logloss:0.25787
# [39]	validation_0-logloss:0.25621	validation_1-logloss:0.25675
# [40]	validation_0-logloss:0.25512	validation_1-logloss:0.25568
# [41]	validation_0-logloss:0.25433	validation_1-logloss:0.25490
# [42]	validation_0-logloss:0.25357	validation_1-logloss:0.25418
# [43]	validation_0-logloss:0.25273	validation_1-logloss:0.25338
# [44]	validation_0-logloss:0.25185	validation_1-logloss:0.25251
# [45]	validation_0-logloss:0.25120	validation_1-logloss:0.25188
# [46]	validation_0-logloss:0.25047	validation_1-logloss:0.25119
# [47]	validation_0-logloss:0.24984	validation_1-logloss:0.25059
# [48]	validation_0-logloss:0.24922	validation_1-logloss:0.25000
# [49]	validation_0-logloss:0.24847	validation_1-logloss:0.24925
# [50]	validation_0-logloss:0.24789	validation_1-logloss:0.24873
# [51]	validation_0-logloss:0.24735	validation_1-logloss:0.24821
# [52]	validation_0-logloss:0.24674	validation_1-logloss:0.24761
# [53]	validation_0-logloss:0.24607	validation_1-logloss:0.24697
# [54]	validation_0-logloss:0.24564	validation_1-logloss:0.24653
# [55]	validation_0-logloss:0.24529	validation_1-logloss:0.24618
# [56]	validation_0-logloss:0.24491	validation_1-logloss:0.24582
# [57]	validation_0-logloss:0.24461	validation_1-logloss:0.24555
# [58]	validation_0-logloss:0.24419	validation_1-logloss:0.24516
# [59]	validation_0-logloss:0.24381	validation_1-logloss:0.24479
# [60]	validation_0-logloss:0.24347	validation_1-logloss:0.24446
# [61]	validation_0-logloss:0.24317	validation_1-logloss:0.24419
# [62]	validation_0-logloss:0.24281	validation_1-logloss:0.24387
# [63]	validation_0-logloss:0.24244	validation_1-logloss:0.24354
# [64]	validation_0-logloss:0.24219	validation_1-logloss:0.24330
# [65]	validation_0-logloss:0.24200	validation_1-logloss:0.24313
# [66]	validation_0-logloss:0.24175	validation_1-logloss:0.24288
# [67]	validation_0-logloss:0.24143	validation_1-logloss:0.24259
# [68]	validation_0-logloss:0.24131	validation_1-logloss:0.24247
# [69]	validation_0-logloss:0.24117	validation_1-logloss:0.24235
# [70]	validation_0-logloss:0.24094	validation_1-logloss:0.24215
# [71]	validation_0-logloss:0.24082	validation_1-logloss:0.24203
# [72]	validation_0-logloss:0.24067	validation_1-logloss:0.24191
# [73]	validation_0-logloss:0.24048	validation_1-logloss:0.24173
# [74]	validation_0-logloss:0.24029	validation_1-logloss:0.24156
# [75]	validation_0-logloss:0.24013	validation_1-logloss:0.24142
# [76]	validation_0-logloss:0.24000	validation_1-logloss:0.24132
# [77]	validation_0-logloss:0.23982	validation_1-logloss:0.24115
# [78]	validation_0-logloss:0.23967	validation_1-logloss:0.24102
# [79]	validation_0-logloss:0.23958	validation_1-logloss:0.24095
# [80]	validation_0-logloss:0.23942	validation_1-logloss:0.24083
# [81]	validation_0-logloss:0.23931	validation_1-logloss:0.24072
# [82]	validation_0-logloss:0.23920	validation_1-logloss:0.24063
# [83]	validation_0-logloss:0.23910	validation_1-logloss:0.24054
# [84]	validation_0-logloss:0.23900	validation_1-logloss:0.24045
# [85]	validation_0-logloss:0.23893	validation_1-logloss:0.24040
# [86]	validation_0-logloss:0.23884	validation_1-logloss:0.24032
# [87]	validation_0-logloss:0.23876	validation_1-logloss:0.24026
# [88]	validation_0-logloss:0.23866	validation_1-logloss:0.24018
# [89]	validation_0-logloss:0.23857	validation_1-logloss:0.24011
# [90]	validation_0-logloss:0.23852	validation_1-logloss:0.24007
# [91]	validation_0-logloss:0.23842	validation_1-logloss:0.23999
# [92]	validation_0-logloss:0.23836	validation_1-logloss:0.23996
# [93]	validation_0-logloss:0.23829	validation_1-logloss:0.23991
# [94]	validation_0-logloss:0.23823	validation_1-logloss:0.23988
# [95]	validation_0-logloss:0.23817	validation_1-logloss:0.23983
# [96]	validation_0-logloss:0.23812	validation_1-logloss:0.23979
# [97]	validation_0-logloss:0.23803	validation_1-logloss:0.23973
# [98]	validation_0-logloss:0.23795	validation_1-logloss:0.23966
# [99]	validation_0-logloss:0.23791	validation_1-logloss:0.23964
# [100]	validation_0-logloss:0.23783	validation_1-logloss:0.23957
# [101]	validation_0-logloss:0.23778	validation_1-logloss:0.23953
# [102]	validation_0-logloss:0.23774	validation_1-logloss:0.23951
# [103]	validation_0-logloss:0.23769	validation_1-logloss:0.23948
# [104]	validation_0-logloss:0.23765	validation_1-logloss:0.23945
# [105]	validation_0-logloss:0.23759	validation_1-logloss:0.23941
# [106]	validation_0-logloss:0.23753	validation_1-logloss:0.23937
# [107]	validation_0-logloss:0.23750	validation_1-logloss:0.23935
# [108]	validation_0-logloss:0.23745	validation_1-logloss:0.23932
# [109]	validation_0-logloss:0.23741	validation_1-logloss:0.23929
# [110]	validation_0-logloss:0.23737	validation_1-logloss:0.23926
# [111]	validation_0-logloss:0.23733	validation_1-logloss:0.23924
# [112]	validation_0-logloss:0.23728	validation_1-logloss:0.23921
# [113]	validation_0-logloss:0.23726	validation_1-logloss:0.23920
# [114]	validation_0-logloss:0.23724	validation_1-logloss:0.23919
# [115]	validation_0-logloss:0.23720	validation_1-logloss:0.23917
# [116]	validation_0-logloss:0.23715	validation_1-logloss:0.23913
# [117]	validation_0-logloss:0.23712	validation_1-logloss:0.23911
# [118]	validation_0-logloss:0.23707	validation_1-logloss:0.23908
# [119]	validation_0-logloss:0.23705	validation_1-logloss:0.23907
# [120]	validation_0-logloss:0.23703	validation_1-logloss:0.23907
# [121]	validation_0-logloss:0.23700	validation_1-logloss:0.23906
# [122]	validation_0-logloss:0.23693	validation_1-logloss:0.23901
# [123]	validation_0-logloss:0.23691	validation_1-logloss:0.23901
# [124]	validation_0-logloss:0.23688	validation_1-logloss:0.23898
# [125]	validation_0-logloss:0.23685	validation_1-logloss:0.23897
# [126]	validation_0-logloss:0.23683	validation_1-logloss:0.23897
# [127]	validation_0-logloss:0.23678	validation_1-logloss:0.23894
# [128]	validation_0-logloss:0.23676	validation_1-logloss:0.23892
# [129]	validation_0-logloss:0.23673	validation_1-logloss:0.23892
# [130]	validation_0-logloss:0.23671	validation_1-logloss:0.23892
# [131]	validation_0-logloss:0.23670	validation_1-logloss:0.23892
# [132]	validation_0-logloss:0.23668	validation_1-logloss:0.23891
# [133]	validation_0-logloss:0.23665	validation_1-logloss:0.23889
# [134]	validation_0-logloss:0.23663	validation_1-logloss:0.23888
# [135]	validation_0-logloss:0.23661	validation_1-logloss:0.23888
# [136]	validation_0-logloss:0.23659	validation_1-logloss:0.23888
# [137]	validation_0-logloss:0.23656	validation_1-logloss:0.23887
# [138]	validation_0-logloss:0.23654	validation_1-logloss:0.23886
# [139]	validation_0-logloss:0.23652	validation_1-logloss:0.23885
# [140]	validation_0-logloss:0.23650	validation_1-logloss:0.23885
# [141]	validation_0-logloss:0.23647	validation_1-logloss:0.23884
# [142]	validation_0-logloss:0.23646	validation_1-logloss:0.23884
# [143]	validation_0-logloss:0.23645	validation_1-logloss:0.23883
# [144]	validation_0-logloss:0.23642	validation_1-logloss:0.23883
# [145]	validation_0-logloss:0.23639	validation_1-logloss:0.23882
# [146]	validation_0-logloss:0.23637	validation_1-logloss:0.23881
# [147]	validation_0-logloss:0.23635	validation_1-logloss:0.23880
# [148]	validation_0-logloss:0.23633	validation_1-logloss:0.23880
# [149]	validation_0-logloss:0.23631	validation_1-logloss:0.23879
# [150]	validation_0-logloss:0.23629	validation_1-logloss:0.23879
# [151]	validation_0-logloss:0.23628	validation_1-logloss:0.23879
# [152]	validation_0-logloss:0.23626	validation_1-logloss:0.23878
# [153]	validation_0-logloss:0.23620	validation_1-logloss:0.23875
# [154]	validation_0-logloss:0.23618	validation_1-logloss:0.23875
# [155]	validation_0-logloss:0.23617	validation_1-logloss:0.23875
# [156]	validation_0-logloss:0.23615	validation_1-logloss:0.23875
# [157]	validation_0-logloss:0.23609	validation_1-logloss:0.23870
# [158]	validation_0-logloss:0.23607	validation_1-logloss:0.23871
# [159]	validation_0-logloss:0.23606	validation_1-logloss:0.23871
# [160]	validation_0-logloss:0.23605	validation_1-logloss:0.23871
# [161]	validation_0-logloss:0.23603	validation_1-logloss:0.23871
# [162]	validation_0-logloss:0.23601	validation_1-logloss:0.23870
# [163]	validation_0-logloss:0.23599	validation_1-logloss:0.23869
# [164]	validation_0-logloss:0.23598	validation_1-logloss:0.23869
# [165]	validation_0-logloss:0.23597	validation_1-logloss:0.23869
# [166]	validation_0-logloss:0.23594	validation_1-logloss:0.23868
# [167]	validation_0-logloss:0.23592	validation_1-logloss:0.23867
# [168]	validation_0-logloss:0.23591	validation_1-logloss:0.23867
# [169]	validation_0-logloss:0.23590	validation_1-logloss:0.23867
# [170]	validation_0-logloss:0.23584	validation_1-logloss:0.23864
# [171]	validation_0-logloss:0.23582	validation_1-logloss:0.23865
# [172]	validation_0-logloss:0.23580	validation_1-logloss:0.23865
# [173]	validation_0-logloss:0.23579	validation_1-logloss:0.23866
# [174]	validation_0-logloss:0.23576	validation_1-logloss:0.23866
# [175]	validation_0-logloss:0.23573	validation_1-logloss:0.23865
# [176]	validation_0-logloss:0.23572	validation_1-logloss:0.23865
# [177]	validation_0-logloss:0.23569	validation_1-logloss:0.23865
# [178]	validation_0-logloss:0.23568	validation_1-logloss:0.23865
# [179]	validation_0-logloss:0.23566	validation_1-logloss:0.23865
# [180]	validation_0-logloss:0.23565	validation_1-logloss:0.23864
# [181]	validation_0-logloss:0.23563	validation_1-logloss:0.23865
# [182]	validation_0-logloss:0.23561	validation_1-logloss:0.23865
# [183]	validation_0-logloss:0.23558	validation_1-logloss:0.23864
# [184]	validation_0-logloss:0.23556	validation_1-logloss:0.23864
# [185]	validation_0-logloss:0.23556	validation_1-logloss:0.23864
# [186]	validation_0-logloss:0.23555	validation_1-logloss:0.23864
# [187]	validation_0-logloss:0.23554	validation_1-logloss:0.23864
# [188]	validation_0-logloss:0.23554	validation_1-logloss:0.23864
# [189]	validation_0-logloss:0.23553	validation_1-logloss:0.23865
# [190]	validation_0-logloss:0.23551	validation_1-logloss:0.23865
# [191]	validation_0-logloss:0.23549	validation_1-logloss:0.23864
# [192]	validation_0-logloss:0.23547	validation_1-logloss:0.23864
# [193]	validation_0-logloss:0.23546	validation_1-logloss:0.23864
# [194]	validation_0-logloss:0.23544	validation_1-logloss:0.23864
# [195]	validation_0-logloss:0.23542	validation_1-logloss:0.23865
# [196]	validation_0-logloss:0.23540	validation_1-logloss:0.23864
# [197]	validation_0-logloss:0.23539	validation_1-logloss:0.23864
# [198]	validation_0-logloss:0.23537	validation_1-logloss:0.23864
# [199]	validation_0-logloss:0.23535	validation_1-logloss:0.23864
# [200]	validation_0-logloss:0.23533	validation_1-logloss:0.23863
# [201]	validation_0-logloss:0.23531	validation_1-logloss:0.23864
# [202]	validation_0-logloss:0.23531	validation_1-logloss:0.23864
# [203]	validation_0-logloss:0.23530	validation_1-logloss:0.23864
# [204]	validation_0-logloss:0.23527	validation_1-logloss:0.23863
# [205]	validation_0-logloss:0.23525	validation_1-logloss:0.23862
# [206]	validation_0-logloss:0.23525	validation_1-logloss:0.23862
# [207]	validation_0-logloss:0.23523	validation_1-logloss:0.23861
# [208]	validation_0-logloss:0.23521	validation_1-logloss:0.23861
# [209]	validation_0-logloss:0.23521	validation_1-logloss:0.23861
# [210]	validation_0-logloss:0.23520	validation_1-logloss:0.23861
# [211]	validation_0-logloss:0.23516	validation_1-logloss:0.23860
# [212]	validation_0-logloss:0.23515	validation_1-logloss:0.23860
# [213]	validation_0-logloss:0.23513	validation_1-logloss:0.23860
# [214]	validation_0-logloss:0.23511	validation_1-logloss:0.23859
# [215]	validation_0-logloss:0.23510	validation_1-logloss:0.23859
# [216]	validation_0-logloss:0.23508	validation_1-logloss:0.23859
# [217]	validation_0-logloss:0.23506	validation_1-logloss:0.23858
# [218]	validation_0-logloss:0.23505	validation_1-logloss:0.23859
# [219]	validation_0-logloss:0.23504	validation_1-logloss:0.23859
# [220]	validation_0-logloss:0.23504	validation_1-logloss:0.23859
# [221]	validation_0-logloss:0.23502	validation_1-logloss:0.23858
# [222]	validation_0-logloss:0.23500	validation_1-logloss:0.23858
# [223]	validation_0-logloss:0.23499	validation_1-logloss:0.23858
# [224]	validation_0-logloss:0.23496	validation_1-logloss:0.23856
# [225]	validation_0-logloss:0.23496	validation_1-logloss:0.23856
# [226]	validation_0-logloss:0.23495	validation_1-logloss:0.23856
# [227]	validation_0-logloss:0.23493	validation_1-logloss:0.23857
# [228]	validation_0-logloss:0.23488	validation_1-logloss:0.23854
# [229]	validation_0-logloss:0.23486	validation_1-logloss:0.23855
# [230]	validation_0-logloss:0.23484	validation_1-logloss:0.23855
# [231]	validation_0-logloss:0.23484	validation_1-logloss:0.23855
# [232]	validation_0-logloss:0.23482	validation_1-logloss:0.23855
# [233]	validation_0-logloss:0.23481	validation_1-logloss:0.23855
# [234]	validation_0-logloss:0.23479	validation_1-logloss:0.23855
# [235]	validation_0-logloss:0.23477	validation_1-logloss:0.23854
# [236]	validation_0-logloss:0.23475	validation_1-logloss:0.23854
# [237]	validation_0-logloss:0.23475	validation_1-logloss:0.23855
# [238]	validation_0-logloss:0.23474	validation_1-logloss:0.23855
# [239]	validation_0-logloss:0.23473	validation_1-logloss:0.23855
# [240]	validation_0-logloss:0.23473	validation_1-logloss:0.23855
# [241]	validation_0-logloss:0.23472	validation_1-logloss:0.23855
# [242]	validation_0-logloss:0.23470	validation_1-logloss:0.23854
# [243]	validation_0-logloss:0.23469	validation_1-logloss:0.23854
# [244]	validation_0-logloss:0.23468	validation_1-logloss:0.23854
# [245]	validation_0-logloss:0.23468	validation_1-logloss:0.23854
# [246]	validation_0-logloss:0.23467	validation_1-logloss:0.23855
# [247]	validation_0-logloss:0.23466	validation_1-logloss:0.23854
# [248]	validation_0-logloss:0.23464	validation_1-logloss:0.23853
# [249]	validation_0-logloss:0.23463	validation_1-logloss:0.23853
# [250]	validation_0-logloss:0.23463	validation_1-logloss:0.23854
# [251]	validation_0-logloss:0.23461	validation_1-logloss:0.23854
# [252]	validation_0-logloss:0.23460	validation_1-logloss:0.23853
# [253]	validation_0-logloss:0.23460	validation_1-logloss:0.23854
# [254]	validation_0-logloss:0.23458	validation_1-logloss:0.23854
# [255]	validation_0-logloss:0.23456	validation_1-logloss:0.23853
# [256]	validation_0-logloss:0.23452	validation_1-logloss:0.23851
# [257]	validation_0-logloss:0.23451	validation_1-logloss:0.23851
# [258]	validation_0-logloss:0.23449	validation_1-logloss:0.23851
# [259]	validation_0-logloss:0.23448	validation_1-logloss:0.23851
# [260]	validation_0-logloss:0.23447	validation_1-logloss:0.23851
# [261]	validation_0-logloss:0.23446	validation_1-logloss:0.23851
# [262]	validation_0-logloss:0.23444	validation_1-logloss:0.23851
# [263]	validation_0-logloss:0.23442	validation_1-logloss:0.23851
# [264]	validation_0-logloss:0.23441	validation_1-logloss:0.23851
# [265]	validation_0-logloss:0.23441	validation_1-logloss:0.23851
# [266]	validation_0-logloss:0.23440	validation_1-logloss:0.23851
# [267]	validation_0-logloss:0.23436	validation_1-logloss:0.23850
# [268]	validation_0-logloss:0.23433	validation_1-logloss:0.23850
# [269]	validation_0-logloss:0.23431	validation_1-logloss:0.23849
# [270]	validation_0-logloss:0.23431	validation_1-logloss:0.23850
# [271]	validation_0-logloss:0.23429	validation_1-logloss:0.23849
# [272]	validation_0-logloss:0.23427	validation_1-logloss:0.23848
# [273]	validation_0-logloss:0.23425	validation_1-logloss:0.23847
# [274]	validation_0-logloss:0.23423	validation_1-logloss:0.23848
# [275]	validation_0-logloss:0.23423	validation_1-logloss:0.23848
# [276]	validation_0-logloss:0.23422	validation_1-logloss:0.23848
# [277]	validation_0-logloss:0.23422	validation_1-logloss:0.23848
# [278]	validation_0-logloss:0.23418	validation_1-logloss:0.23846
# [279]	validation_0-logloss:0.23417	validation_1-logloss:0.23845
# [280]	validation_0-logloss:0.23416	validation_1-logloss:0.23845
# [281]	validation_0-logloss:0.23414	validation_1-logloss:0.23845
# [282]	validation_0-logloss:0.23411	validation_1-logloss:0.23845
# [283]	validation_0-logloss:0.23411	validation_1-logloss:0.23845
# [284]	validation_0-logloss:0.23409	validation_1-logloss:0.23845
# [285]	validation_0-logloss:0.23408	validation_1-logloss:0.23845
# [286]	validation_0-logloss:0.23406	validation_1-logloss:0.23845
# [287]	validation_0-logloss:0.23405	validation_1-logloss:0.23845
# [288]	validation_0-logloss:0.23403	validation_1-logloss:0.23845
# [289]	validation_0-logloss:0.23400	validation_1-logloss:0.23843
# [290]	validation_0-logloss:0.23397	validation_1-logloss:0.23842
# [291]	validation_0-logloss:0.23395	validation_1-logloss:0.23842
# [292]	validation_0-logloss:0.23394	validation_1-logloss:0.23841
# [293]	validation_0-logloss:0.23392	validation_1-logloss:0.23841
# [294]	validation_0-logloss:0.23388	validation_1-logloss:0.23840
# [295]	validation_0-logloss:0.23387	validation_1-logloss:0.23840
# [296]	validation_0-logloss:0.23387	validation_1-logloss:0.23840
# [297]	validation_0-logloss:0.23385	validation_1-logloss:0.23840
# [298]	validation_0-logloss:0.23383	validation_1-logloss:0.23840
# [299]	validation_0-logloss:0.23381	validation_1-logloss:0.23839
# [300]	validation_0-logloss:0.23381	validation_1-logloss:0.23839
# [301]	validation_0-logloss:0.23381	validation_1-logloss:0.23839
# [302]	validation_0-logloss:0.23379	validation_1-logloss:0.23839
# [303]	validation_0-logloss:0.23378	validation_1-logloss:0.23839
# [304]	validation_0-logloss:0.23376	validation_1-logloss:0.23839
# [305]	validation_0-logloss:0.23375	validation_1-logloss:0.23838
# [306]	validation_0-logloss:0.23375	validation_1-logloss:0.23838
# [307]	validation_0-logloss:0.23373	validation_1-logloss:0.23839
# [308]	validation_0-logloss:0.23372	validation_1-logloss:0.23839
# [309]	validation_0-logloss:0.23370	validation_1-logloss:0.23839
# [310]	validation_0-logloss:0.23368	validation_1-logloss:0.23839
# [311]	validation_0-logloss:0.23367	validation_1-logloss:0.23839
# [312]	validation_0-logloss:0.23364	validation_1-logloss:0.23838
# [313]	validation_0-logloss:0.23363	validation_1-logloss:0.23838
# [314]	validation_0-logloss:0.23361	validation_1-logloss:0.23838
# [315]	validation_0-logloss:0.23360	validation_1-logloss:0.23838
# [316]	validation_0-logloss:0.23359	validation_1-logloss:0.23838
# [317]	validation_0-logloss:0.23357	validation_1-logloss:0.23839
# [318]	validation_0-logloss:0.23356	validation_1-logloss:0.23839
# [319]	validation_0-logloss:0.23353	validation_1-logloss:0.23838
# [320]	validation_0-logloss:0.23351	validation_1-logloss:0.23838
# [321]	validation_0-logloss:0.23349	validation_1-logloss:0.23838
# [322]	validation_0-logloss:0.23348	validation_1-logloss:0.23838
# [323]	validation_0-logloss:0.23346	validation_1-logloss:0.23839
# [324]	validation_0-logloss:0.23345	validation_1-logloss:0.23839
# [325]	validation_0-logloss:0.23343	validation_1-logloss:0.23839
# [326]	validation_0-logloss:0.23343	validation_1-logloss:0.23839
# [327]	validation_0-logloss:0.23342	validation_1-logloss:0.23838
# [328]	validation_0-logloss:0.23340	validation_1-logloss:0.23838
# [329]	validation_0-logloss:0.23337	validation_1-logloss:0.23838
# [330]	validation_0-logloss:0.23335	validation_1-logloss:0.23836
# [331]	validation_0-logloss:0.23333	validation_1-logloss:0.23836
# [332]	validation_0-logloss:0.23330	validation_1-logloss:0.23836
# [333]	validation_0-logloss:0.23329	validation_1-logloss:0.23836
# [334]	validation_0-logloss:0.23327	validation_1-logloss:0.23836
# [335]	validation_0-logloss:0.23325	validation_1-logloss:0.23836
# [336]	validation_0-logloss:0.23323	validation_1-logloss:0.23836
# [337]	validation_0-logloss:0.23323	validation_1-logloss:0.23836
# [338]	validation_0-logloss:0.23321	validation_1-logloss:0.23837
# [339]	validation_0-logloss:0.23320	validation_1-logloss:0.23837
# [340]	validation_0-logloss:0.23318	validation_1-logloss:0.23836
# [341]	validation_0-logloss:0.23317	validation_1-logloss:0.23836
# [342]	validation_0-logloss:0.23315	validation_1-logloss:0.23836
# [343]	validation_0-logloss:0.23313	validation_1-logloss:0.23836
# [344]	validation_0-logloss:0.23311	validation_1-logloss:0.23836
# [345]	validation_0-logloss:0.23309	validation_1-logloss:0.23836
# [346]	validation_0-logloss:0.23308	validation_1-logloss:0.23836
# [347]	validation_0-logloss:0.23305	validation_1-logloss:0.23835
# [348]	validation_0-logloss:0.23303	validation_1-logloss:0.23834
# [349]	validation_0-logloss:0.23303	validation_1-logloss:0.23835
# [350]	validation_0-logloss:0.23301	validation_1-logloss:0.23835
# [351]	validation_0-logloss:0.23300	validation_1-logloss:0.23836
# [352]	validation_0-logloss:0.23299	validation_1-logloss:0.23836
# [353]	validation_0-logloss:0.23298	validation_1-logloss:0.23836
# [354]	validation_0-logloss:0.23296	validation_1-logloss:0.23836
# [355]	validation_0-logloss:0.23295	validation_1-logloss:0.23836
# [356]	validation_0-logloss:0.23295	validation_1-logloss:0.23836
# [357]	validation_0-logloss:0.23293	validation_1-logloss:0.23836
# [358]	validation_0-logloss:0.23292	validation_1-logloss:0.23836
# [359]	validation_0-logloss:0.23291	validation_1-logloss:0.23836
# [360]	validation_0-logloss:0.23290	validation_1-logloss:0.23836
# [361]	validation_0-logloss:0.23290	validation_1-logloss:0.23836
# [362]	validation_0-logloss:0.23288	validation_1-logloss:0.23837
# [363]	validation_0-logloss:0.23285	validation_1-logloss:0.23837
# [364]	validation_0-logloss:0.23283	validation_1-logloss:0.23837
# [365]	validation_0-logloss:0.23281	validation_1-logloss:0.23837
# [366]	validation_0-logloss:0.23278	validation_1-logloss:0.23836
# [367]	validation_0-logloss:0.23277	validation_1-logloss:0.23836
# [368]	validation_0-logloss:0.23275	validation_1-logloss:0.23836
# [369]	validation_0-logloss:0.23273	validation_1-logloss:0.23836
# [370]	validation_0-logloss:0.23270	validation_1-logloss:0.23835
# [371]	validation_0-logloss:0.23270	validation_1-logloss:0.23835
# [372]	validation_0-logloss:0.23268	validation_1-logloss:0.23835
# [373]	validation_0-logloss:0.23268	validation_1-logloss:0.23835
# [374]	validation_0-logloss:0.23267	validation_1-logloss:0.23836
# [375]	validation_0-logloss:0.23266	validation_1-logloss:0.23836
# [376]	validation_0-logloss:0.23265	validation_1-logloss:0.23836
# [377]	validation_0-logloss:0.23264	validation_1-logloss:0.23836
# [378]	validation_0-logloss:0.23264	validation_1-logloss:0.23836
# [379]	validation_0-logloss:0.23263	validation_1-logloss:0.23836
# [380]	validation_0-logloss:0.23261	validation_1-logloss:0.23836
# [381]	validation_0-logloss:0.23259	validation_1-logloss:0.23836
# [382]	validation_0-logloss:0.23257	validation_1-logloss:0.23836
# [383]	validation_0-logloss:0.23256	validation_1-logloss:0.23837
# [384]	validation_0-logloss:0.23256	validation_1-logloss:0.23836
# [385]	validation_0-logloss:0.23253	validation_1-logloss:0.23837
# [386]	validation_0-logloss:0.23253	validation_1-logloss:0.23837
# [387]	validation_0-logloss:0.23253	validation_1-logloss:0.23837
# [388]	validation_0-logloss:0.23253	validation_1-logloss:0.23837
# [389]	validation_0-logloss:0.23250	validation_1-logloss:0.23836
# [390]	validation_0-logloss:0.23249	validation_1-logloss:0.23836
# [391]	validation_0-logloss:0.23248	validation_1-logloss:0.23836
# [392]	validation_0-logloss:0.23247	validation_1-logloss:0.23836
# [393]	validation_0-logloss:0.23246	validation_1-logloss:0.23837
# [394]	validation_0-logloss:0.23246	validation_1-logloss:0.23837
# [395]	validation_0-logloss:0.23244	validation_1-logloss:0.23837
# [396]	validation_0-logloss:0.23244	validation_1-logloss:0.23837
# [397]	validation_0-logloss:0.23242	validation_1-logloss:0.23837

# %% [markdown]
# ##### For 10 ML

# %%
# XGBoost with only the kinematic variables of the leptons

iterations_ML = 10

print('ML iteration 1')

# CLASSIFIER
classifier = XGBClassifier(
    n_estimators=2500,
    learning_rate=0.1,
    reg_lambda=0.0,reg_alpha=0.0,
    gamma=0.0,objective='binary:logistic',
    max_depth=5)

ran_ind = np.random.choice(np.arange(len(X_mon_train)), size = len(X_mon_train), replace = True)

# FIT
classifier.fit(X_mon_train[ran_ind],y_mon_train[ran_ind],eval_set=[(X_mon_train[ran_ind], y_mon_train[ran_ind]), (X_mon_val, y_mon_val)],
        eval_metric='logloss',early_stopping_rounds=50,#early stopping
        verbose=True)

# PREDICTIONS
y_pred_xg_aux = classifier.predict_proba(X_mon_test).T[1]
y_pred_xg_auxRE = np.reshape(y_pred_xg_aux, (1,len(y_pred_xg_aux)))


# ROC
fpr_mon_xg, tpr_mon_xg, _ = roc_curve(y_mon_test, y_pred_xg_aux)
roc_auc_xg = auc(fpr_mon_xg, tpr_mon_xg)


# PLOT THE ROC WITH AUC
fig = plt.figure(figsize=(6, 6))
gs = gridspec.GridSpec(1, 1) 
ax0 = plt.subplot(gs[0])
ax0.yaxis.set_ticks_position('both')
ax0.xaxis.set_ticks_position('both')
ax0.tick_params(direction="in",which="both")
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
ax0.minorticks_on()


plt.plot(tpr_mon_xg,1-fpr_mon_xg,label="$f_{1}$, AUC = %0.2f" % roc_auc_xg,color="orange",ls=":",lw=4)
plt.plot([1,0],[0,1],ls=":",color="grey")
plt.xlabel("True Positive Rate",fontsize=16)
plt.ylabel("1 $-$ False Positive Rate",fontsize=16)
plt.legend()
plt.title(r"SSM Z' - XGBoost",fontsize=16)
plt.xlim([0,1])
plt.ylim([0,1])
plt.yticks([0.2,0.4,0.6,0.8,1.])
plt.legend(frameon=False,fontsize=16)
plt.show()




print('\n ########################################\n')





for it in range(1,iterations_ML):

    print('ML iteration ', it)
    
    # CLASSIFIER
    classifier = XGBClassifier(
        n_estimators=2500,
        learning_rate=0.1,
        reg_lambda=0.0,reg_alpha=0.0,
        gamma=0.0,objective='binary:logistic',
        max_depth=5)

    ran_ind = np.random.choice(np.arange(len(X_mon_train)), size = len(X_mon_train), replace = True)

    # FIT
    classifier.fit(X_mon_train[ran_ind],y_mon_train[ran_ind],eval_set=[(X_mon_train[ran_ind], y_mon_train[ran_ind]), (X_mon_val, y_mon_val)],
            eval_metric='logloss',early_stopping_rounds=50,#early stopping
            verbose=True)

    # PREDICTIONS
    y_pred_xg_aux_it = classifier.predict_proba(X_mon_test).T[1]
    y_pred_xg_auxRE_it = np.reshape(y_pred_xg_aux_it, (1,len(y_pred_xg_aux_it)))
    
    y_pred_xg_auxRE = np.concatenate([y_pred_xg_auxRE,y_pred_xg_auxRE_it])


    # ROC
    fpr_mon_xg, tpr_mon_xg, _ = roc_curve(y_mon_test, y_pred_xg_aux)
    roc_auc_xg = auc(fpr_mon_xg, tpr_mon_xg)


    # PLOT THE ROC WITH AUC
    fig = plt.figure(figsize=(6, 6))
    gs = gridspec.GridSpec(1, 1) 
    ax0 = plt.subplot(gs[0])
    ax0.yaxis.set_ticks_position('both')
    ax0.xaxis.set_ticks_position('both')
    ax0.tick_params(direction="in",which="both")
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
    ax0.minorticks_on()


    plt.plot(tpr_mon_xg,1-fpr_mon_xg,label="$f_{1}$, AUC = %0.2f" % roc_auc_xg,color="orange",ls=":",lw=4)
    plt.plot([1,0],[0,1],ls=":",color="grey")
    plt.xlabel("True Positive Rate",fontsize=16)
    plt.ylabel("1 $-$ False Positive Rate",fontsize=16)
    plt.legend()
    plt.title(r"SSM Z' - XGBoost",fontsize=16)
    plt.xlim([0,1])
    plt.ylim([0,1])
    plt.yticks([0.2,0.4,0.6,0.8,1.])
    plt.legend(frameon=False,fontsize=16)
    plt.show()
    
    print('\n ########################################\n')
    
    
y_pred_xg = np.mean(y_pred_xg_auxRE, axis=0)
# Out:
# ML iteration 1
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [0]	validation_0-logloss:0.63571	validation_1-logloss:0.63573
# [1]	validation_0-logloss:0.58848	validation_1-logloss:0.58867
# [2]	validation_0-logloss:0.54838	validation_1-logloss:0.54873
# [3]	validation_0-logloss:0.51428	validation_1-logloss:0.51468
# [4]	validation_0-logloss:0.48599	validation_1-logloss:0.48628
# [5]	validation_0-logloss:0.46053	validation_1-logloss:0.46096
# [6]	validation_0-logloss:0.43878	validation_1-logloss:0.43924
# [7]	validation_0-logloss:0.41970	validation_1-logloss:0.42015
# [8]	validation_0-logloss:0.40336	validation_1-logloss:0.40384
# [9]	validation_0-logloss:0.38816	validation_1-logloss:0.38866
# [10]	validation_0-logloss:0.37544	validation_1-logloss:0.37594
# [11]	validation_0-logloss:0.36342	validation_1-logloss:0.36401
# [12]	validation_0-logloss:0.35293	validation_1-logloss:0.35353
# [13]	validation_0-logloss:0.34400	validation_1-logloss:0.34467
# [14]	validation_0-logloss:0.33568	validation_1-logloss:0.33636
# [15]	validation_0-logloss:0.32654	validation_1-logloss:0.32723
# [16]	validation_0-logloss:0.31971	validation_1-logloss:0.32040
# [17]	validation_0-logloss:0.31229	validation_1-logloss:0.31301
# [18]	validation_0-logloss:0.30707	validation_1-logloss:0.30777
# [19]	validation_0-logloss:0.30122	validation_1-logloss:0.30198
# [20]	validation_0-logloss:0.29602	validation_1-logloss:0.29692
# [21]	validation_0-logloss:0.29234	validation_1-logloss:0.29323
# [22]	validation_0-logloss:0.28817	validation_1-logloss:0.28906
# [23]	validation_0-logloss:0.28502	validation_1-logloss:0.28593
# [24]	validation_0-logloss:0.28213	validation_1-logloss:0.28310
# [25]	validation_0-logloss:0.27870	validation_1-logloss:0.27971
# [26]	validation_0-logloss:0.27579	validation_1-logloss:0.27680
# [27]	validation_0-logloss:0.27339	validation_1-logloss:0.27444
# [28]	validation_0-logloss:0.27159	validation_1-logloss:0.27269
# [29]	validation_0-logloss:0.26969	validation_1-logloss:0.27077
# [30]	validation_0-logloss:0.26759	validation_1-logloss:0.26873
# [31]	validation_0-logloss:0.26551	validation_1-logloss:0.26669
# [32]	validation_0-logloss:0.26375	validation_1-logloss:0.26498
# [33]	validation_0-logloss:0.26237	validation_1-logloss:0.26367
# [34]	validation_0-logloss:0.26116	validation_1-logloss:0.26244
# [35]	validation_0-logloss:0.25954	validation_1-logloss:0.26087
# [36]	validation_0-logloss:0.25813	validation_1-logloss:0.25945
# [37]	validation_0-logloss:0.25708	validation_1-logloss:0.25844
# [38]	validation_0-logloss:0.25585	validation_1-logloss:0.25727
# [39]	validation_0-logloss:0.25487	validation_1-logloss:0.25632
# [40]	validation_0-logloss:0.25385	validation_1-logloss:0.25533
# [41]	validation_0-logloss:0.25283	validation_1-logloss:0.25435
# [42]	validation_0-logloss:0.25208	validation_1-logloss:0.25368
# [43]	validation_0-logloss:0.25120	validation_1-logloss:0.25285
# [44]	validation_0-logloss:0.25045	validation_1-logloss:0.25213
# [45]	validation_0-logloss:0.24966	validation_1-logloss:0.25140
# [46]	validation_0-logloss:0.24890	validation_1-logloss:0.25069
# [47]	validation_0-logloss:0.24826	validation_1-logloss:0.25010
# [48]	validation_0-logloss:0.24756	validation_1-logloss:0.24946
# [49]	validation_0-logloss:0.24709	validation_1-logloss:0.24903
# [50]	validation_0-logloss:0.24645	validation_1-logloss:0.24840
# [51]	validation_0-logloss:0.24592	validation_1-logloss:0.24793
# [52]	validation_0-logloss:0.24541	validation_1-logloss:0.24749
# [53]	validation_0-logloss:0.24483	validation_1-logloss:0.24697
# [54]	validation_0-logloss:0.24425	validation_1-logloss:0.24644
# [55]	validation_0-logloss:0.24388	validation_1-logloss:0.24610
# [56]	validation_0-logloss:0.24349	validation_1-logloss:0.24576
# [57]	validation_0-logloss:0.24317	validation_1-logloss:0.24547
# [58]	validation_0-logloss:0.24278	validation_1-logloss:0.24513
# [59]	validation_0-logloss:0.24240	validation_1-logloss:0.24479
# [60]	validation_0-logloss:0.24204	validation_1-logloss:0.24448
# [61]	validation_0-logloss:0.24172	validation_1-logloss:0.24422
# [62]	validation_0-logloss:0.24147	validation_1-logloss:0.24401
# [63]	validation_0-logloss:0.24117	validation_1-logloss:0.24373
# [64]	validation_0-logloss:0.24090	validation_1-logloss:0.24351
# [65]	validation_0-logloss:0.24060	validation_1-logloss:0.24325
# [66]	validation_0-logloss:0.24025	validation_1-logloss:0.24295
# [67]	validation_0-logloss:0.24004	validation_1-logloss:0.24276
# [68]	validation_0-logloss:0.23981	validation_1-logloss:0.24256
# [69]	validation_0-logloss:0.23963	validation_1-logloss:0.24241
# [70]	validation_0-logloss:0.23942	validation_1-logloss:0.24226
# [71]	validation_0-logloss:0.23923	validation_1-logloss:0.24212
# [72]	validation_0-logloss:0.23912	validation_1-logloss:0.24204
# [73]	validation_0-logloss:0.23895	validation_1-logloss:0.24190
# [74]	validation_0-logloss:0.23877	validation_1-logloss:0.24178
# [75]	validation_0-logloss:0.23864	validation_1-logloss:0.24170
# [76]	validation_0-logloss:0.23840	validation_1-logloss:0.24151
# [77]	validation_0-logloss:0.23818	validation_1-logloss:0.24134
# [78]	validation_0-logloss:0.23803	validation_1-logloss:0.24124
# [79]	validation_0-logloss:0.23790	validation_1-logloss:0.24114
# [80]	validation_0-logloss:0.23782	validation_1-logloss:0.24110
# [81]	validation_0-logloss:0.23769	validation_1-logloss:0.24099
# [82]	validation_0-logloss:0.23756	validation_1-logloss:0.24089
# [83]	validation_0-logloss:0.23746	validation_1-logloss:0.24082
# [84]	validation_0-logloss:0.23732	validation_1-logloss:0.24073
# [85]	validation_0-logloss:0.23722	validation_1-logloss:0.24066
# [86]	validation_0-logloss:0.23706	validation_1-logloss:0.24055
# [87]	validation_0-logloss:0.23694	validation_1-logloss:0.24047
# [88]	validation_0-logloss:0.23687	validation_1-logloss:0.24044
# [89]	validation_0-logloss:0.23679	validation_1-logloss:0.24038
# [90]	validation_0-logloss:0.23665	validation_1-logloss:0.24030
# [91]	validation_0-logloss:0.23656	validation_1-logloss:0.24025
# [92]	validation_0-logloss:0.23646	validation_1-logloss:0.24018
# [93]	validation_0-logloss:0.23640	validation_1-logloss:0.24016
# [94]	validation_0-logloss:0.23627	validation_1-logloss:0.24007
# [95]	validation_0-logloss:0.23621	validation_1-logloss:0.24003
# [96]	validation_0-logloss:0.23616	validation_1-logloss:0.24000
# [97]	validation_0-logloss:0.23610	validation_1-logloss:0.23998
# [98]	validation_0-logloss:0.23602	validation_1-logloss:0.23994
# [99]	validation_0-logloss:0.23598	validation_1-logloss:0.23993
# [100]	validation_0-logloss:0.23592	validation_1-logloss:0.23990
# [101]	validation_0-logloss:0.23587	validation_1-logloss:0.23987
# [102]	validation_0-logloss:0.23579	validation_1-logloss:0.23984
# [103]	validation_0-logloss:0.23574	validation_1-logloss:0.23981
# [104]	validation_0-logloss:0.23566	validation_1-logloss:0.23976
# [105]	validation_0-logloss:0.23560	validation_1-logloss:0.23974
# [106]	validation_0-logloss:0.23549	validation_1-logloss:0.23966
# [107]	validation_0-logloss:0.23544	validation_1-logloss:0.23964
# [108]	validation_0-logloss:0.23538	validation_1-logloss:0.23961
# [109]	validation_0-logloss:0.23533	validation_1-logloss:0.23958
# [110]	validation_0-logloss:0.23528	validation_1-logloss:0.23958
# [111]	validation_0-logloss:0.23525	validation_1-logloss:0.23957
# [112]	validation_0-logloss:0.23519	validation_1-logloss:0.23953
# [113]	validation_0-logloss:0.23515	validation_1-logloss:0.23952
# [114]	validation_0-logloss:0.23509	validation_1-logloss:0.23951
# [115]	validation_0-logloss:0.23506	validation_1-logloss:0.23950
# [116]	validation_0-logloss:0.23501	validation_1-logloss:0.23949
# [117]	validation_0-logloss:0.23497	validation_1-logloss:0.23949
# [118]	validation_0-logloss:0.23493	validation_1-logloss:0.23949
# [119]	validation_0-logloss:0.23489	validation_1-logloss:0.23947
# [120]	validation_0-logloss:0.23483	validation_1-logloss:0.23944
# [121]	validation_0-logloss:0.23478	validation_1-logloss:0.23941
# [122]	validation_0-logloss:0.23472	validation_1-logloss:0.23940
# [123]	validation_0-logloss:0.23470	validation_1-logloss:0.23940
# [124]	validation_0-logloss:0.23467	validation_1-logloss:0.23940
# [125]	validation_0-logloss:0.23459	validation_1-logloss:0.23935
# [126]	validation_0-logloss:0.23456	validation_1-logloss:0.23935
# [127]	validation_0-logloss:0.23453	validation_1-logloss:0.23935
# [128]	validation_0-logloss:0.23449	validation_1-logloss:0.23933
# [129]	validation_0-logloss:0.23445	validation_1-logloss:0.23933
# [130]	validation_0-logloss:0.23442	validation_1-logloss:0.23932
# [131]	validation_0-logloss:0.23437	validation_1-logloss:0.23933
# [132]	validation_0-logloss:0.23431	validation_1-logloss:0.23931
# [133]	validation_0-logloss:0.23427	validation_1-logloss:0.23930
# [134]	validation_0-logloss:0.23424	validation_1-logloss:0.23930
# [135]	validation_0-logloss:0.23422	validation_1-logloss:0.23930
# [136]	validation_0-logloss:0.23415	validation_1-logloss:0.23928
# [137]	validation_0-logloss:0.23413	validation_1-logloss:0.23929
# [138]	validation_0-logloss:0.23403	validation_1-logloss:0.23925
# [139]	validation_0-logloss:0.23400	validation_1-logloss:0.23924
# [140]	validation_0-logloss:0.23396	validation_1-logloss:0.23924
# [141]	validation_0-logloss:0.23393	validation_1-logloss:0.23923
# [142]	validation_0-logloss:0.23390	validation_1-logloss:0.23923
# [143]	validation_0-logloss:0.23386	validation_1-logloss:0.23922
# [144]	validation_0-logloss:0.23384	validation_1-logloss:0.23922
# [145]	validation_0-logloss:0.23383	validation_1-logloss:0.23922
# [146]	validation_0-logloss:0.23379	validation_1-logloss:0.23921
# [147]	validation_0-logloss:0.23372	validation_1-logloss:0.23918
# [148]	validation_0-logloss:0.23366	validation_1-logloss:0.23915
# [149]	validation_0-logloss:0.23364	validation_1-logloss:0.23916
# [150]	validation_0-logloss:0.23361	validation_1-logloss:0.23916
# [151]	validation_0-logloss:0.23359	validation_1-logloss:0.23916
# [152]	validation_0-logloss:0.23355	validation_1-logloss:0.23916
# [153]	validation_0-logloss:0.23352	validation_1-logloss:0.23916
# [154]	validation_0-logloss:0.23351	validation_1-logloss:0.23915
# [155]	validation_0-logloss:0.23347	validation_1-logloss:0.23914
# [156]	validation_0-logloss:0.23344	validation_1-logloss:0.23914
# [157]	validation_0-logloss:0.23339	validation_1-logloss:0.23914
# [158]	validation_0-logloss:0.23338	validation_1-logloss:0.23914
# [159]	validation_0-logloss:0.23333	validation_1-logloss:0.23913
# [160]	validation_0-logloss:0.23331	validation_1-logloss:0.23913
# [161]	validation_0-logloss:0.23328	validation_1-logloss:0.23912
# [162]	validation_0-logloss:0.23326	validation_1-logloss:0.23912
# [163]	validation_0-logloss:0.23323	validation_1-logloss:0.23911
# [164]	validation_0-logloss:0.23316	validation_1-logloss:0.23910
# [165]	validation_0-logloss:0.23312	validation_1-logloss:0.23911
# [166]	validation_0-logloss:0.23310	validation_1-logloss:0.23912
# [167]	validation_0-logloss:0.23308	validation_1-logloss:0.23912
# [168]	validation_0-logloss:0.23307	validation_1-logloss:0.23912
# [169]	validation_0-logloss:0.23303	validation_1-logloss:0.23911
# [170]	validation_0-logloss:0.23301	validation_1-logloss:0.23911
# [171]	validation_0-logloss:0.23298	validation_1-logloss:0.23910
# [172]	validation_0-logloss:0.23294	validation_1-logloss:0.23909
# [173]	validation_0-logloss:0.23288	validation_1-logloss:0.23907
# [174]	validation_0-logloss:0.23284	validation_1-logloss:0.23906
# [175]	validation_0-logloss:0.23282	validation_1-logloss:0.23907
# [176]	validation_0-logloss:0.23278	validation_1-logloss:0.23906
# [177]	validation_0-logloss:0.23275	validation_1-logloss:0.23906
# [178]	validation_0-logloss:0.23273	validation_1-logloss:0.23906
# [179]	validation_0-logloss:0.23269	validation_1-logloss:0.23907
# [180]	validation_0-logloss:0.23267	validation_1-logloss:0.23907
# [181]	validation_0-logloss:0.23266	validation_1-logloss:0.23907
# [182]	validation_0-logloss:0.23262	validation_1-logloss:0.23907
# [183]	validation_0-logloss:0.23260	validation_1-logloss:0.23907
# [184]	validation_0-logloss:0.23257	validation_1-logloss:0.23908
# [185]	validation_0-logloss:0.23256	validation_1-logloss:0.23907
# [186]	validation_0-logloss:0.23255	validation_1-logloss:0.23907
# [187]	validation_0-logloss:0.23251	validation_1-logloss:0.23907
# [188]	validation_0-logloss:0.23248	validation_1-logloss:0.23907
# [189]	validation_0-logloss:0.23242	validation_1-logloss:0.23905
# [190]	validation_0-logloss:0.23239	validation_1-logloss:0.23905
# [191]	validation_0-logloss:0.23235	validation_1-logloss:0.23906
# [192]	validation_0-logloss:0.23233	validation_1-logloss:0.23905
# [193]	validation_0-logloss:0.23229	validation_1-logloss:0.23905
# [194]	validation_0-logloss:0.23226	validation_1-logloss:0.23905
# [195]	validation_0-logloss:0.23223	validation_1-logloss:0.23905
# [196]	validation_0-logloss:0.23219	validation_1-logloss:0.23904
# [197]	validation_0-logloss:0.23217	validation_1-logloss:0.23904
# [198]	validation_0-logloss:0.23212	validation_1-logloss:0.23902
# [199]	validation_0-logloss:0.23208	validation_1-logloss:0.23902
# [200]	validation_0-logloss:0.23204	validation_1-logloss:0.23901
# [201]	validation_0-logloss:0.23203	validation_1-logloss:0.23901
# [202]	validation_0-logloss:0.23200	validation_1-logloss:0.23901
# [203]	validation_0-logloss:0.23198	validation_1-logloss:0.23901
# [204]	validation_0-logloss:0.23195	validation_1-logloss:0.23902
# [205]	validation_0-logloss:0.23194	validation_1-logloss:0.23902
# [206]	validation_0-logloss:0.23192	validation_1-logloss:0.23902
# [207]	validation_0-logloss:0.23188	validation_1-logloss:0.23901
# [208]	validation_0-logloss:0.23187	validation_1-logloss:0.23901
# [209]	validation_0-logloss:0.23183	validation_1-logloss:0.23902
# [210]	validation_0-logloss:0.23179	validation_1-logloss:0.23902
# [211]	validation_0-logloss:0.23176	validation_1-logloss:0.23901
# [212]	validation_0-logloss:0.23175	validation_1-logloss:0.23901
# [213]	validation_0-logloss:0.23172	validation_1-logloss:0.23901
# [214]	validation_0-logloss:0.23166	validation_1-logloss:0.23900
# [215]	validation_0-logloss:0.23163	validation_1-logloss:0.23901
# [216]	validation_0-logloss:0.23160	validation_1-logloss:0.23900
# [217]	validation_0-logloss:0.23159	validation_1-logloss:0.23901
# [218]	validation_0-logloss:0.23157	validation_1-logloss:0.23901
# [219]	validation_0-logloss:0.23155	validation_1-logloss:0.23902
# [220]	validation_0-logloss:0.23152	validation_1-logloss:0.23902
# [221]	validation_0-logloss:0.23148	validation_1-logloss:0.23902
# [222]	validation_0-logloss:0.23145	validation_1-logloss:0.23902
# [223]	validation_0-logloss:0.23144	validation_1-logloss:0.23902
# [224]	validation_0-logloss:0.23143	validation_1-logloss:0.23902
# [225]	validation_0-logloss:0.23140	validation_1-logloss:0.23902
# [226]	validation_0-logloss:0.23138	validation_1-logloss:0.23902
# [227]	validation_0-logloss:0.23134	validation_1-logloss:0.23902
# [228]	validation_0-logloss:0.23130	validation_1-logloss:0.23902
# [229]	validation_0-logloss:0.23125	validation_1-logloss:0.23902
# [230]	validation_0-logloss:0.23121	validation_1-logloss:0.23902
# [231]	validation_0-logloss:0.23117	validation_1-logloss:0.23902
# [232]	validation_0-logloss:0.23114	validation_1-logloss:0.23902
# [233]	validation_0-logloss:0.23110	validation_1-logloss:0.23902
# [234]	validation_0-logloss:0.23108	validation_1-logloss:0.23903
# [235]	validation_0-logloss:0.23103	validation_1-logloss:0.23903
# [236]	validation_0-logloss:0.23100	validation_1-logloss:0.23903
# [237]	validation_0-logloss:0.23096	validation_1-logloss:0.23903
# [238]	validation_0-logloss:0.23095	validation_1-logloss:0.23903
# [239]	validation_0-logloss:0.23093	validation_1-logloss:0.23903
# [240]	validation_0-logloss:0.23090	validation_1-logloss:0.23904
# [241]	validation_0-logloss:0.23089	validation_1-logloss:0.23904
# [242]	validation_0-logloss:0.23088	validation_1-logloss:0.23904
# [243]	validation_0-logloss:0.23082	validation_1-logloss:0.23903
# [244]	validation_0-logloss:0.23080	validation_1-logloss:0.23903
# [245]	validation_0-logloss:0.23074	validation_1-logloss:0.23903
# [246]	validation_0-logloss:0.23070	validation_1-logloss:0.23903
# [247]	validation_0-logloss:0.23068	validation_1-logloss:0.23903
# [248]	validation_0-logloss:0.23064	validation_1-logloss:0.23904
# [249]	validation_0-logloss:0.23062	validation_1-logloss:0.23904
# [250]	validation_0-logloss:0.23062	validation_1-logloss:0.23904
# [251]	validation_0-logloss:0.23060	validation_1-logloss:0.23905
# [252]	validation_0-logloss:0.23054	validation_1-logloss:0.23903
# [253]	validation_0-logloss:0.23053	validation_1-logloss:0.23903
# [254]	validation_0-logloss:0.23051	validation_1-logloss:0.23903
# [255]	validation_0-logloss:0.23048	validation_1-logloss:0.23903
# [256]	validation_0-logloss:0.23046	validation_1-logloss:0.23903
# [257]	validation_0-logloss:0.23043	validation_1-logloss:0.23903
# [258]	validation_0-logloss:0.23040	validation_1-logloss:0.23903
# [259]	validation_0-logloss:0.23037	validation_1-logloss:0.23903
# [260]	validation_0-logloss:0.23037	validation_1-logloss:0.23903
# [261]	validation_0-logloss:0.23035	validation_1-logloss:0.23903
# [262]	validation_0-logloss:0.23033	validation_1-logloss:0.23903
# [263]	validation_0-logloss:0.23031	validation_1-logloss:0.23904
#  ########################################
#
# ML iteration  1
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [0]	validation_0-logloss:0.63590	validation_1-logloss:0.63587
# [1]	validation_0-logloss:0.58843	validation_1-logloss:0.58874
# [2]	validation_0-logloss:0.54878	validation_1-logloss:0.54903
# [3]	validation_0-logloss:0.51481	validation_1-logloss:0.51514
# [4]	validation_0-logloss:0.48559	validation_1-logloss:0.48596
# [5]	validation_0-logloss:0.45989	validation_1-logloss:0.46022
# [6]	validation_0-logloss:0.43859	validation_1-logloss:0.43894
# [7]	validation_0-logloss:0.41919	validation_1-logloss:0.41955
# [8]	validation_0-logloss:0.40269	validation_1-logloss:0.40302
# [9]	validation_0-logloss:0.38818	validation_1-logloss:0.38848
# [10]	validation_0-logloss:0.37518	validation_1-logloss:0.37547
# [11]	validation_0-logloss:0.36357	validation_1-logloss:0.36386
# [12]	validation_0-logloss:0.35317	validation_1-logloss:0.35344
# [13]	validation_0-logloss:0.34391	validation_1-logloss:0.34420
# [14]	validation_0-logloss:0.33427	validation_1-logloss:0.33470
# [15]	validation_0-logloss:0.32664	validation_1-logloss:0.32708
# [16]	validation_0-logloss:0.31879	validation_1-logloss:0.31926
# [17]	validation_0-logloss:0.31265	validation_1-logloss:0.31320
# [18]	validation_0-logloss:0.30650	validation_1-logloss:0.30708
# [19]	validation_0-logloss:0.30132	validation_1-logloss:0.30199
# [20]	validation_0-logloss:0.29724	validation_1-logloss:0.29786
# [21]	validation_0-logloss:0.29247	validation_1-logloss:0.29319
# [22]	validation_0-logloss:0.28908	validation_1-logloss:0.28980
# [23]	validation_0-logloss:0.28499	validation_1-logloss:0.28568
# [24]	validation_0-logloss:0.28185	validation_1-logloss:0.28258
# [25]	validation_0-logloss:0.27858	validation_1-logloss:0.27935
# [26]	validation_0-logloss:0.27622	validation_1-logloss:0.27703
# [27]	validation_0-logloss:0.27359	validation_1-logloss:0.27444
# [28]	validation_0-logloss:0.27086	validation_1-logloss:0.27178
# [29]	validation_0-logloss:0.26893	validation_1-logloss:0.26986
# [30]	validation_0-logloss:0.26742	validation_1-logloss:0.26842
# [31]	validation_0-logloss:0.26556	validation_1-logloss:0.26660
# [32]	validation_0-logloss:0.26403	validation_1-logloss:0.26509
# [33]	validation_0-logloss:0.26244	validation_1-logloss:0.26357
# [34]	validation_0-logloss:0.26085	validation_1-logloss:0.26200
# [35]	validation_0-logloss:0.25922	validation_1-logloss:0.26043
# [36]	validation_0-logloss:0.25799	validation_1-logloss:0.25918
# [37]	validation_0-logloss:0.25683	validation_1-logloss:0.25806
# [38]	validation_0-logloss:0.25583	validation_1-logloss:0.25711
# [39]	validation_0-logloss:0.25474	validation_1-logloss:0.25606
# [40]	validation_0-logloss:0.25394	validation_1-logloss:0.25530
# [41]	validation_0-logloss:0.25292	validation_1-logloss:0.25432
# [42]	validation_0-logloss:0.25203	validation_1-logloss:0.25350
# [43]	validation_0-logloss:0.25115	validation_1-logloss:0.25266
# [44]	validation_0-logloss:0.25035	validation_1-logloss:0.25187
# [45]	validation_0-logloss:0.24942	validation_1-logloss:0.25100
# [46]	validation_0-logloss:0.24885	validation_1-logloss:0.25044
# [47]	validation_0-logloss:0.24836	validation_1-logloss:0.24999
# [48]	validation_0-logloss:0.24768	validation_1-logloss:0.24934
# [49]	validation_0-logloss:0.24703	validation_1-logloss:0.24871
# [50]	validation_0-logloss:0.24636	validation_1-logloss:0.24808
# [51]	validation_0-logloss:0.24585	validation_1-logloss:0.24760
# [52]	validation_0-logloss:0.24528	validation_1-logloss:0.24709
# [53]	validation_0-logloss:0.24478	validation_1-logloss:0.24663
# [54]	validation_0-logloss:0.24439	validation_1-logloss:0.24626
# [55]	validation_0-logloss:0.24398	validation_1-logloss:0.24590
# [56]	validation_0-logloss:0.24350	validation_1-logloss:0.24547
# [57]	validation_0-logloss:0.24318	validation_1-logloss:0.24517
# [58]	validation_0-logloss:0.24278	validation_1-logloss:0.24481
# [59]	validation_0-logloss:0.24239	validation_1-logloss:0.24447
# [60]	validation_0-logloss:0.24205	validation_1-logloss:0.24417
# [61]	validation_0-logloss:0.24179	validation_1-logloss:0.24394
# [62]	validation_0-logloss:0.24144	validation_1-logloss:0.24363
# [63]	validation_0-logloss:0.24122	validation_1-logloss:0.24346
# [64]	validation_0-logloss:0.24096	validation_1-logloss:0.24322
# [65]	validation_0-logloss:0.24074	validation_1-logloss:0.24305
# [66]	validation_0-logloss:0.24039	validation_1-logloss:0.24274
# [67]	validation_0-logloss:0.24019	validation_1-logloss:0.24258
# [68]	validation_0-logloss:0.23999	validation_1-logloss:0.24241
# [69]	validation_0-logloss:0.23978	validation_1-logloss:0.24225
# [70]	validation_0-logloss:0.23958	validation_1-logloss:0.24208
# [71]	validation_0-logloss:0.23940	validation_1-logloss:0.24195
# [72]	validation_0-logloss:0.23918	validation_1-logloss:0.24178
# [73]	validation_0-logloss:0.23906	validation_1-logloss:0.24169
# [74]	validation_0-logloss:0.23884	validation_1-logloss:0.24152
# [75]	validation_0-logloss:0.23872	validation_1-logloss:0.24144
# [76]	validation_0-logloss:0.23857	validation_1-logloss:0.24132
# [77]	validation_0-logloss:0.23841	validation_1-logloss:0.24120
# [78]	validation_0-logloss:0.23827	validation_1-logloss:0.24110
# [79]	validation_0-logloss:0.23814	validation_1-logloss:0.24099
# [80]	validation_0-logloss:0.23798	validation_1-logloss:0.24086
# [81]	validation_0-logloss:0.23784	validation_1-logloss:0.24077
# [82]	validation_0-logloss:0.23773	validation_1-logloss:0.24070
# [83]	validation_0-logloss:0.23763	validation_1-logloss:0.24063
# [84]	validation_0-logloss:0.23755	validation_1-logloss:0.24058
# [85]	validation_0-logloss:0.23744	validation_1-logloss:0.24052
# [86]	validation_0-logloss:0.23733	validation_1-logloss:0.24047
# [87]	validation_0-logloss:0.23723	validation_1-logloss:0.24041
# [88]	validation_0-logloss:0.23712	validation_1-logloss:0.24033
# [89]	validation_0-logloss:0.23707	validation_1-logloss:0.24032
# [90]	validation_0-logloss:0.23697	validation_1-logloss:0.24025
# [91]	validation_0-logloss:0.23691	validation_1-logloss:0.24023
# [92]	validation_0-logloss:0.23679	validation_1-logloss:0.24014
# [93]	validation_0-logloss:0.23670	validation_1-logloss:0.24010
# [94]	validation_0-logloss:0.23663	validation_1-logloss:0.24006
# [95]	validation_0-logloss:0.23657	validation_1-logloss:0.24004
# [96]	validation_0-logloss:0.23650	validation_1-logloss:0.24000
# [97]	validation_0-logloss:0.23644	validation_1-logloss:0.23998
# [98]	validation_0-logloss:0.23632	validation_1-logloss:0.23991
# [99]	validation_0-logloss:0.23624	validation_1-logloss:0.23986
# [100]	validation_0-logloss:0.23616	validation_1-logloss:0.23982
# [101]	validation_0-logloss:0.23609	validation_1-logloss:0.23979
# [102]	validation_0-logloss:0.23605	validation_1-logloss:0.23977
# [103]	validation_0-logloss:0.23597	validation_1-logloss:0.23973
# [104]	validation_0-logloss:0.23588	validation_1-logloss:0.23968
# [105]	validation_0-logloss:0.23582	validation_1-logloss:0.23965
# [106]	validation_0-logloss:0.23577	validation_1-logloss:0.23963
# [107]	validation_0-logloss:0.23570	validation_1-logloss:0.23960
# [108]	validation_0-logloss:0.23566	validation_1-logloss:0.23959
# [109]	validation_0-logloss:0.23560	validation_1-logloss:0.23956
# [110]	validation_0-logloss:0.23558	validation_1-logloss:0.23956
# [111]	validation_0-logloss:0.23551	validation_1-logloss:0.23954
# [112]	validation_0-logloss:0.23546	validation_1-logloss:0.23951
# [113]	validation_0-logloss:0.23542	validation_1-logloss:0.23949
# [114]	validation_0-logloss:0.23537	validation_1-logloss:0.23948
# [115]	validation_0-logloss:0.23533	validation_1-logloss:0.23947
# [116]	validation_0-logloss:0.23528	validation_1-logloss:0.23946
# [117]	validation_0-logloss:0.23525	validation_1-logloss:0.23946
# [118]	validation_0-logloss:0.23519	validation_1-logloss:0.23943
# [119]	validation_0-logloss:0.23517	validation_1-logloss:0.23942
# [120]	validation_0-logloss:0.23511	validation_1-logloss:0.23941
# [121]	validation_0-logloss:0.23507	validation_1-logloss:0.23941
# [122]	validation_0-logloss:0.23504	validation_1-logloss:0.23941
# [123]	validation_0-logloss:0.23502	validation_1-logloss:0.23941
# [124]	validation_0-logloss:0.23495	validation_1-logloss:0.23938
# [125]	validation_0-logloss:0.23490	validation_1-logloss:0.23938
# [126]	validation_0-logloss:0.23486	validation_1-logloss:0.23937
# [127]	validation_0-logloss:0.23481	validation_1-logloss:0.23937
# [128]	validation_0-logloss:0.23477	validation_1-logloss:0.23936
# [129]	validation_0-logloss:0.23474	validation_1-logloss:0.23937
# [130]	validation_0-logloss:0.23471	validation_1-logloss:0.23937
# [131]	validation_0-logloss:0.23465	validation_1-logloss:0.23935
# [132]	validation_0-logloss:0.23461	validation_1-logloss:0.23931
# [133]	validation_0-logloss:0.23456	validation_1-logloss:0.23930
# [134]	validation_0-logloss:0.23451	validation_1-logloss:0.23930
# [135]	validation_0-logloss:0.23448	validation_1-logloss:0.23930
# [136]	validation_0-logloss:0.23446	validation_1-logloss:0.23930
# [137]	validation_0-logloss:0.23442	validation_1-logloss:0.23930
# [138]	validation_0-logloss:0.23438	validation_1-logloss:0.23929
# [139]	validation_0-logloss:0.23433	validation_1-logloss:0.23929
# [140]	validation_0-logloss:0.23423	validation_1-logloss:0.23925
# [141]	validation_0-logloss:0.23421	validation_1-logloss:0.23925
# [142]	validation_0-logloss:0.23419	validation_1-logloss:0.23925
# [143]	validation_0-logloss:0.23416	validation_1-logloss:0.23925
# [144]	validation_0-logloss:0.23408	validation_1-logloss:0.23923
# [145]	validation_0-logloss:0.23404	validation_1-logloss:0.23922
# [146]	validation_0-logloss:0.23396	validation_1-logloss:0.23918
# [147]	validation_0-logloss:0.23395	validation_1-logloss:0.23919
# [148]	validation_0-logloss:0.23391	validation_1-logloss:0.23919
# [149]	validation_0-logloss:0.23386	validation_1-logloss:0.23917
# [150]	validation_0-logloss:0.23383	validation_1-logloss:0.23918
# [151]	validation_0-logloss:0.23381	validation_1-logloss:0.23917
# [152]	validation_0-logloss:0.23377	validation_1-logloss:0.23917
# [153]	validation_0-logloss:0.23374	validation_1-logloss:0.23917
# [154]	validation_0-logloss:0.23371	validation_1-logloss:0.23917
# [155]	validation_0-logloss:0.23368	validation_1-logloss:0.23917
# [156]	validation_0-logloss:0.23362	validation_1-logloss:0.23916
# [157]	validation_0-logloss:0.23359	validation_1-logloss:0.23915
# [158]	validation_0-logloss:0.23352	validation_1-logloss:0.23914
# [159]	validation_0-logloss:0.23350	validation_1-logloss:0.23914
# [160]	validation_0-logloss:0.23348	validation_1-logloss:0.23914
# [161]	validation_0-logloss:0.23340	validation_1-logloss:0.23911
# [162]	validation_0-logloss:0.23338	validation_1-logloss:0.23912
# [163]	validation_0-logloss:0.23336	validation_1-logloss:0.23912
# [164]	validation_0-logloss:0.23333	validation_1-logloss:0.23912
# [165]	validation_0-logloss:0.23326	validation_1-logloss:0.23912
# [166]	validation_0-logloss:0.23321	validation_1-logloss:0.23912
# [167]	validation_0-logloss:0.23320	validation_1-logloss:0.23912
# [168]	validation_0-logloss:0.23317	validation_1-logloss:0.23913
# [169]	validation_0-logloss:0.23315	validation_1-logloss:0.23913
# [170]	validation_0-logloss:0.23311	validation_1-logloss:0.23913
# [171]	validation_0-logloss:0.23309	validation_1-logloss:0.23913
# [172]	validation_0-logloss:0.23303	validation_1-logloss:0.23914
# [173]	validation_0-logloss:0.23299	validation_1-logloss:0.23913
# [174]	validation_0-logloss:0.23295	validation_1-logloss:0.23913
# [175]	validation_0-logloss:0.23291	validation_1-logloss:0.23914
# [176]	validation_0-logloss:0.23287	validation_1-logloss:0.23914
# [177]	validation_0-logloss:0.23286	validation_1-logloss:0.23914
# [178]	validation_0-logloss:0.23283	validation_1-logloss:0.23915
# [179]	validation_0-logloss:0.23281	validation_1-logloss:0.23915
# [180]	validation_0-logloss:0.23278	validation_1-logloss:0.23915
# [181]	validation_0-logloss:0.23276	validation_1-logloss:0.23916
# [182]	validation_0-logloss:0.23271	validation_1-logloss:0.23913
# [183]	validation_0-logloss:0.23267	validation_1-logloss:0.23913
# [184]	validation_0-logloss:0.23264	validation_1-logloss:0.23913
# [185]	validation_0-logloss:0.23261	validation_1-logloss:0.23913
# [186]	validation_0-logloss:0.23259	validation_1-logloss:0.23913
# [187]	validation_0-logloss:0.23258	validation_1-logloss:0.23913
# [188]	validation_0-logloss:0.23255	validation_1-logloss:0.23914
# [189]	validation_0-logloss:0.23252	validation_1-logloss:0.23914
# [190]	validation_0-logloss:0.23249	validation_1-logloss:0.23914
# [191]	validation_0-logloss:0.23244	validation_1-logloss:0.23913
# [192]	validation_0-logloss:0.23241	validation_1-logloss:0.23914
# [193]	validation_0-logloss:0.23237	validation_1-logloss:0.23914
# [194]	validation_0-logloss:0.23234	validation_1-logloss:0.23914
# [195]	validation_0-logloss:0.23232	validation_1-logloss:0.23913
# [196]	validation_0-logloss:0.23228	validation_1-logloss:0.23914
# [197]	validation_0-logloss:0.23224	validation_1-logloss:0.23914
# [198]	validation_0-logloss:0.23222	validation_1-logloss:0.23915
# [199]	validation_0-logloss:0.23219	validation_1-logloss:0.23915
# [200]	validation_0-logloss:0.23219	validation_1-logloss:0.23915
# [201]	validation_0-logloss:0.23217	validation_1-logloss:0.23916
# [202]	validation_0-logloss:0.23213	validation_1-logloss:0.23915
# [203]	validation_0-logloss:0.23211	validation_1-logloss:0.23916
# [204]	validation_0-logloss:0.23211	validation_1-logloss:0.23916
# [205]	validation_0-logloss:0.23208	validation_1-logloss:0.23916
# [206]	validation_0-logloss:0.23206	validation_1-logloss:0.23916
# [207]	validation_0-logloss:0.23204	validation_1-logloss:0.23917
# [208]	validation_0-logloss:0.23196	validation_1-logloss:0.23914
# [209]	validation_0-logloss:0.23193	validation_1-logloss:0.23914
# [210]	validation_0-logloss:0.23191	validation_1-logloss:0.23914
# [211]	validation_0-logloss:0.23187	validation_1-logloss:0.23915
#  ########################################
#
# ML iteration  2
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [0]	validation_0-logloss:0.63585	validation_1-logloss:0.63591
# [1]	validation_0-logloss:0.58819	validation_1-logloss:0.58848
# [2]	validation_0-logloss:0.54770	validation_1-logloss:0.54815
# [3]	validation_0-logloss:0.51419	validation_1-logloss:0.51465
# [4]	validation_0-logloss:0.48515	validation_1-logloss:0.48581
# [5]	validation_0-logloss:0.46011	validation_1-logloss:0.46079
# [6]	validation_0-logloss:0.43808	validation_1-logloss:0.43888
# [7]	validation_0-logloss:0.41923	validation_1-logloss:0.41998
# [8]	validation_0-logloss:0.40284	validation_1-logloss:0.40361
# [9]	validation_0-logloss:0.38748	validation_1-logloss:0.38837
# [10]	validation_0-logloss:0.37493	validation_1-logloss:0.37587
# [11]	validation_0-logloss:0.36344	validation_1-logloss:0.36435
# [12]	validation_0-logloss:0.35158	validation_1-logloss:0.35257
# [13]	validation_0-logloss:0.34256	validation_1-logloss:0.34366
# [14]	validation_0-logloss:0.33392	validation_1-logloss:0.33494
# [15]	validation_0-logloss:0.32615	validation_1-logloss:0.32730
# [16]	validation_0-logloss:0.31954	validation_1-logloss:0.32068
# [17]	validation_0-logloss:0.31231	validation_1-logloss:0.31348
# [18]	validation_0-logloss:0.30619	validation_1-logloss:0.30738
# [19]	validation_0-logloss:0.30059	validation_1-logloss:0.30189
# [20]	validation_0-logloss:0.29632	validation_1-logloss:0.29768
# [21]	validation_0-logloss:0.29157	validation_1-logloss:0.29294
# [22]	validation_0-logloss:0.28749	validation_1-logloss:0.28885
# [23]	validation_0-logloss:0.28416	validation_1-logloss:0.28561
# [24]	validation_0-logloss:0.28047	validation_1-logloss:0.28193
# [25]	validation_0-logloss:0.27801	validation_1-logloss:0.27949
# [26]	validation_0-logloss:0.27485	validation_1-logloss:0.27640
# [27]	validation_0-logloss:0.27256	validation_1-logloss:0.27414
# [28]	validation_0-logloss:0.26994	validation_1-logloss:0.27160
# [29]	validation_0-logloss:0.26758	validation_1-logloss:0.26930
# [30]	validation_0-logloss:0.26606	validation_1-logloss:0.26783
# [31]	validation_0-logloss:0.26439	validation_1-logloss:0.26616
# [32]	validation_0-logloss:0.26302	validation_1-logloss:0.26484
# [33]	validation_0-logloss:0.26137	validation_1-logloss:0.26322
# [34]	validation_0-logloss:0.26022	validation_1-logloss:0.26210
# [35]	validation_0-logloss:0.25868	validation_1-logloss:0.26061
# [36]	validation_0-logloss:0.25751	validation_1-logloss:0.25950
# [37]	validation_0-logloss:0.25636	validation_1-logloss:0.25837
# [38]	validation_0-logloss:0.25521	validation_1-logloss:0.25728
# [39]	validation_0-logloss:0.25440	validation_1-logloss:0.25649
# [40]	validation_0-logloss:0.25351	validation_1-logloss:0.25562
# [41]	validation_0-logloss:0.25250	validation_1-logloss:0.25465
# [42]	validation_0-logloss:0.25154	validation_1-logloss:0.25372
# [43]	validation_0-logloss:0.25063	validation_1-logloss:0.25286
# [44]	validation_0-logloss:0.24974	validation_1-logloss:0.25201
# [45]	validation_0-logloss:0.24896	validation_1-logloss:0.25127
# [46]	validation_0-logloss:0.24836	validation_1-logloss:0.25070
# [47]	validation_0-logloss:0.24773	validation_1-logloss:0.25013
# [48]	validation_0-logloss:0.24711	validation_1-logloss:0.24956
# [49]	validation_0-logloss:0.24662	validation_1-logloss:0.24911
# [50]	validation_0-logloss:0.24596	validation_1-logloss:0.24850
# [51]	validation_0-logloss:0.24530	validation_1-logloss:0.24786
# [52]	validation_0-logloss:0.24486	validation_1-logloss:0.24744
# [53]	validation_0-logloss:0.24446	validation_1-logloss:0.24708
# [54]	validation_0-logloss:0.24399	validation_1-logloss:0.24664
# [55]	validation_0-logloss:0.24360	validation_1-logloss:0.24630
# [56]	validation_0-logloss:0.24301	validation_1-logloss:0.24577
# [57]	validation_0-logloss:0.24269	validation_1-logloss:0.24549
# [58]	validation_0-logloss:0.24221	validation_1-logloss:0.24505
# [59]	validation_0-logloss:0.24187	validation_1-logloss:0.24475
# [60]	validation_0-logloss:0.24151	validation_1-logloss:0.24444
# [61]	validation_0-logloss:0.24108	validation_1-logloss:0.24405
# [62]	validation_0-logloss:0.24069	validation_1-logloss:0.24371
# [63]	validation_0-logloss:0.24047	validation_1-logloss:0.24351
# [64]	validation_0-logloss:0.24029	validation_1-logloss:0.24337
# [65]	validation_0-logloss:0.24003	validation_1-logloss:0.24315
# [66]	validation_0-logloss:0.23978	validation_1-logloss:0.24294
# [67]	validation_0-logloss:0.23958	validation_1-logloss:0.24280
# [68]	validation_0-logloss:0.23937	validation_1-logloss:0.24264
# [69]	validation_0-logloss:0.23925	validation_1-logloss:0.24255
# [70]	validation_0-logloss:0.23895	validation_1-logloss:0.24230
# [71]	validation_0-logloss:0.23868	validation_1-logloss:0.24209
# [72]	validation_0-logloss:0.23850	validation_1-logloss:0.24195
# [73]	validation_0-logloss:0.23840	validation_1-logloss:0.24187
# [74]	validation_0-logloss:0.23822	validation_1-logloss:0.24172
# [75]	validation_0-logloss:0.23802	validation_1-logloss:0.24157
# [76]	validation_0-logloss:0.23790	validation_1-logloss:0.24147
# [77]	validation_0-logloss:0.23778	validation_1-logloss:0.24137
# [78]	validation_0-logloss:0.23768	validation_1-logloss:0.24129
# [79]	validation_0-logloss:0.23759	validation_1-logloss:0.24124
# [80]	validation_0-logloss:0.23741	validation_1-logloss:0.24110
# [81]	validation_0-logloss:0.23734	validation_1-logloss:0.24105
# [82]	validation_0-logloss:0.23719	validation_1-logloss:0.24094
# [83]	validation_0-logloss:0.23707	validation_1-logloss:0.24086
# [84]	validation_0-logloss:0.23697	validation_1-logloss:0.24078
# [85]	validation_0-logloss:0.23683	validation_1-logloss:0.24069
# [86]	validation_0-logloss:0.23674	validation_1-logloss:0.24065
# [87]	validation_0-logloss:0.23662	validation_1-logloss:0.24059
# [88]	validation_0-logloss:0.23655	validation_1-logloss:0.24055
# [89]	validation_0-logloss:0.23646	validation_1-logloss:0.24048
# [90]	validation_0-logloss:0.23636	validation_1-logloss:0.24042
# [91]	validation_0-logloss:0.23627	validation_1-logloss:0.24037
# [92]	validation_0-logloss:0.23623	validation_1-logloss:0.24035
# [93]	validation_0-logloss:0.23618	validation_1-logloss:0.24032
# [94]	validation_0-logloss:0.23606	validation_1-logloss:0.24024
# [95]	validation_0-logloss:0.23598	validation_1-logloss:0.24017
# [96]	validation_0-logloss:0.23592	validation_1-logloss:0.24015
# [97]	validation_0-logloss:0.23583	validation_1-logloss:0.24009
# [98]	validation_0-logloss:0.23577	validation_1-logloss:0.24005
# [99]	validation_0-logloss:0.23569	validation_1-logloss:0.24002
# [100]	validation_0-logloss:0.23563	validation_1-logloss:0.23999
# [101]	validation_0-logloss:0.23559	validation_1-logloss:0.23998
# [102]	validation_0-logloss:0.23555	validation_1-logloss:0.23997
# [103]	validation_0-logloss:0.23544	validation_1-logloss:0.23990
# [104]	validation_0-logloss:0.23539	validation_1-logloss:0.23988
# [105]	validation_0-logloss:0.23532	validation_1-logloss:0.23985
# [106]	validation_0-logloss:0.23527	validation_1-logloss:0.23983
# [107]	validation_0-logloss:0.23521	validation_1-logloss:0.23981
# [108]	validation_0-logloss:0.23518	validation_1-logloss:0.23980
# [109]	validation_0-logloss:0.23511	validation_1-logloss:0.23975
# [110]	validation_0-logloss:0.23506	validation_1-logloss:0.23973
# [111]	validation_0-logloss:0.23502	validation_1-logloss:0.23971
# [112]	validation_0-logloss:0.23496	validation_1-logloss:0.23969
# [113]	validation_0-logloss:0.23493	validation_1-logloss:0.23969
# [114]	validation_0-logloss:0.23487	validation_1-logloss:0.23967
# [115]	validation_0-logloss:0.23481	validation_1-logloss:0.23966
# [116]	validation_0-logloss:0.23478	validation_1-logloss:0.23966
# [117]	validation_0-logloss:0.23474	validation_1-logloss:0.23964
# [118]	validation_0-logloss:0.23469	validation_1-logloss:0.23963
# [119]	validation_0-logloss:0.23464	validation_1-logloss:0.23961
# [120]	validation_0-logloss:0.23456	validation_1-logloss:0.23957
# [121]	validation_0-logloss:0.23454	validation_1-logloss:0.23957
# [122]	validation_0-logloss:0.23449	validation_1-logloss:0.23955
# [123]	validation_0-logloss:0.23444	validation_1-logloss:0.23955
# [124]	validation_0-logloss:0.23440	validation_1-logloss:0.23953
# [125]	validation_0-logloss:0.23437	validation_1-logloss:0.23952
# [126]	validation_0-logloss:0.23428	validation_1-logloss:0.23948
# [127]	validation_0-logloss:0.23425	validation_1-logloss:0.23949
# [128]	validation_0-logloss:0.23422	validation_1-logloss:0.23948
# [129]	validation_0-logloss:0.23419	validation_1-logloss:0.23947
# [130]	validation_0-logloss:0.23415	validation_1-logloss:0.23947
# [131]	validation_0-logloss:0.23412	validation_1-logloss:0.23947
# [132]	validation_0-logloss:0.23409	validation_1-logloss:0.23947
# [133]	validation_0-logloss:0.23406	validation_1-logloss:0.23946
# [134]	validation_0-logloss:0.23396	validation_1-logloss:0.23941
# [135]	validation_0-logloss:0.23390	validation_1-logloss:0.23939
# [136]	validation_0-logloss:0.23386	validation_1-logloss:0.23939
# [137]	validation_0-logloss:0.23380	validation_1-logloss:0.23936
# [138]	validation_0-logloss:0.23377	validation_1-logloss:0.23936
# [139]	validation_0-logloss:0.23370	validation_1-logloss:0.23933
# [140]	validation_0-logloss:0.23367	validation_1-logloss:0.23933
# [141]	validation_0-logloss:0.23363	validation_1-logloss:0.23933
# [142]	validation_0-logloss:0.23360	validation_1-logloss:0.23932
# [143]	validation_0-logloss:0.23355	validation_1-logloss:0.23931
# [144]	validation_0-logloss:0.23353	validation_1-logloss:0.23931
# [145]	validation_0-logloss:0.23349	validation_1-logloss:0.23930
# [146]	validation_0-logloss:0.23345	validation_1-logloss:0.23931
# [147]	validation_0-logloss:0.23344	validation_1-logloss:0.23931
# [148]	validation_0-logloss:0.23339	validation_1-logloss:0.23929
# [149]	validation_0-logloss:0.23333	validation_1-logloss:0.23928
# [150]	validation_0-logloss:0.23330	validation_1-logloss:0.23928
# [151]	validation_0-logloss:0.23328	validation_1-logloss:0.23928
# [152]	validation_0-logloss:0.23326	validation_1-logloss:0.23929
# [153]	validation_0-logloss:0.23321	validation_1-logloss:0.23928
# [154]	validation_0-logloss:0.23320	validation_1-logloss:0.23928
# [155]	validation_0-logloss:0.23316	validation_1-logloss:0.23928
# [156]	validation_0-logloss:0.23308	validation_1-logloss:0.23925
# [157]	validation_0-logloss:0.23305	validation_1-logloss:0.23925
# [158]	validation_0-logloss:0.23303	validation_1-logloss:0.23924
# [159]	validation_0-logloss:0.23300	validation_1-logloss:0.23924
# [160]	validation_0-logloss:0.23296	validation_1-logloss:0.23924
# [161]	validation_0-logloss:0.23292	validation_1-logloss:0.23925
# [162]	validation_0-logloss:0.23287	validation_1-logloss:0.23924
# [163]	validation_0-logloss:0.23281	validation_1-logloss:0.23924
# [164]	validation_0-logloss:0.23278	validation_1-logloss:0.23925
# [165]	validation_0-logloss:0.23276	validation_1-logloss:0.23925
# [166]	validation_0-logloss:0.23272	validation_1-logloss:0.23925
# [167]	validation_0-logloss:0.23267	validation_1-logloss:0.23924
# [168]	validation_0-logloss:0.23262	validation_1-logloss:0.23923
# [169]	validation_0-logloss:0.23259	validation_1-logloss:0.23923
# [170]	validation_0-logloss:0.23255	validation_1-logloss:0.23922
# [171]	validation_0-logloss:0.23252	validation_1-logloss:0.23922
# [172]	validation_0-logloss:0.23246	validation_1-logloss:0.23921
# [173]	validation_0-logloss:0.23242	validation_1-logloss:0.23922
# [174]	validation_0-logloss:0.23239	validation_1-logloss:0.23922
# [175]	validation_0-logloss:0.23237	validation_1-logloss:0.23922
# [176]	validation_0-logloss:0.23230	validation_1-logloss:0.23919
# [177]	validation_0-logloss:0.23228	validation_1-logloss:0.23918
# [178]	validation_0-logloss:0.23226	validation_1-logloss:0.23918
# [179]	validation_0-logloss:0.23222	validation_1-logloss:0.23919
# [180]	validation_0-logloss:0.23220	validation_1-logloss:0.23919
# [181]	validation_0-logloss:0.23216	validation_1-logloss:0.23917
# [182]	validation_0-logloss:0.23212	validation_1-logloss:0.23917
# [183]	validation_0-logloss:0.23209	validation_1-logloss:0.23917
# [184]	validation_0-logloss:0.23208	validation_1-logloss:0.23917
# [185]	validation_0-logloss:0.23205	validation_1-logloss:0.23918
# [186]	validation_0-logloss:0.23199	validation_1-logloss:0.23917
# [187]	validation_0-logloss:0.23195	validation_1-logloss:0.23917
# [188]	validation_0-logloss:0.23194	validation_1-logloss:0.23917
# [189]	validation_0-logloss:0.23190	validation_1-logloss:0.23917
# [190]	validation_0-logloss:0.23186	validation_1-logloss:0.23917
# [191]	validation_0-logloss:0.23184	validation_1-logloss:0.23917
# [192]	validation_0-logloss:0.23182	validation_1-logloss:0.23917
# [193]	validation_0-logloss:0.23179	validation_1-logloss:0.23917
# [194]	validation_0-logloss:0.23178	validation_1-logloss:0.23917
# [195]	validation_0-logloss:0.23177	validation_1-logloss:0.23917
# [196]	validation_0-logloss:0.23172	validation_1-logloss:0.23917
# [197]	validation_0-logloss:0.23172	validation_1-logloss:0.23917
# [198]	validation_0-logloss:0.23170	validation_1-logloss:0.23916
# [199]	validation_0-logloss:0.23167	validation_1-logloss:0.23916
# [200]	validation_0-logloss:0.23161	validation_1-logloss:0.23916
# [201]	validation_0-logloss:0.23158	validation_1-logloss:0.23916
# [202]	validation_0-logloss:0.23155	validation_1-logloss:0.23916
# [203]	validation_0-logloss:0.23155	validation_1-logloss:0.23916
# [204]	validation_0-logloss:0.23151	validation_1-logloss:0.23916
# [205]	validation_0-logloss:0.23147	validation_1-logloss:0.23917
# [206]	validation_0-logloss:0.23144	validation_1-logloss:0.23917
# [207]	validation_0-logloss:0.23139	validation_1-logloss:0.23916
# [208]	validation_0-logloss:0.23137	validation_1-logloss:0.23916
# [209]	validation_0-logloss:0.23134	validation_1-logloss:0.23917
# [210]	validation_0-logloss:0.23128	validation_1-logloss:0.23917
# [211]	validation_0-logloss:0.23127	validation_1-logloss:0.23917
# [212]	validation_0-logloss:0.23123	validation_1-logloss:0.23917
# [213]	validation_0-logloss:0.23121	validation_1-logloss:0.23917
# [214]	validation_0-logloss:0.23117	validation_1-logloss:0.23918
# [215]	validation_0-logloss:0.23116	validation_1-logloss:0.23918
# [216]	validation_0-logloss:0.23116	validation_1-logloss:0.23918
# [217]	validation_0-logloss:0.23112	validation_1-logloss:0.23918
# [218]	validation_0-logloss:0.23110	validation_1-logloss:0.23919
# [219]	validation_0-logloss:0.23108	validation_1-logloss:0.23919
# [220]	validation_0-logloss:0.23106	validation_1-logloss:0.23918
# [221]	validation_0-logloss:0.23100	validation_1-logloss:0.23916
# [222]	validation_0-logloss:0.23096	validation_1-logloss:0.23916
# [223]	validation_0-logloss:0.23092	validation_1-logloss:0.23916
# [224]	validation_0-logloss:0.23091	validation_1-logloss:0.23916
# [225]	validation_0-logloss:0.23085	validation_1-logloss:0.23916
# [226]	validation_0-logloss:0.23083	validation_1-logloss:0.23916
# [227]	validation_0-logloss:0.23080	validation_1-logloss:0.23917
# [228]	validation_0-logloss:0.23076	validation_1-logloss:0.23916
# [229]	validation_0-logloss:0.23071	validation_1-logloss:0.23916
# [230]	validation_0-logloss:0.23069	validation_1-logloss:0.23916
# [231]	validation_0-logloss:0.23064	validation_1-logloss:0.23916
# [232]	validation_0-logloss:0.23063	validation_1-logloss:0.23916
# [233]	validation_0-logloss:0.23063	validation_1-logloss:0.23917
# [234]	validation_0-logloss:0.23061	validation_1-logloss:0.23917
# [235]	validation_0-logloss:0.23061	validation_1-logloss:0.23917
# [236]	validation_0-logloss:0.23059	validation_1-logloss:0.23916
# [237]	validation_0-logloss:0.23056	validation_1-logloss:0.23916
# [238]	validation_0-logloss:0.23053	validation_1-logloss:0.23917
# [239]	validation_0-logloss:0.23050	validation_1-logloss:0.23917
# [240]	validation_0-logloss:0.23046	validation_1-logloss:0.23917
# [241]	validation_0-logloss:0.23046	validation_1-logloss:0.23917
# ...
# [26]	validation_0-logloss:0.27609	validation_1-logloss:0.27714
# [27]	validation_0-logloss:0.27385	validation_1-logloss:0.27493
# [28]	validation_0-logloss:0.27133	validation_1-logloss:0.27249
# [29]	validation_0-logloss:0.26879	validation_1-logloss:0.27003
# [30]	validation_0-logloss:0.26681	validation_1-logloss:0.26805
# [31]	validation_0-logloss:0.26515	validation_1-logloss:0.26643
# [32]	validation_0-logloss:0.26379	validation_1-logloss:0.26513
# [33]	validation_0-logloss:0.26249	validation_1-logloss:0.26386
# [34]	validation_0-logloss:0.26068	validation_1-logloss:0.26212
# [35]	validation_0-logloss:0.25928	validation_1-logloss:0.26076
# [36]	validation_0-logloss:0.25801	validation_1-logloss:0.25952
# [37]	validation_0-logloss:0.25693	validation_1-logloss:0.25847
# [38]	validation_0-logloss:0.25568	validation_1-logloss:0.25728
# [39]	validation_0-logloss:0.25463	validation_1-logloss:0.25629
# [40]	validation_0-logloss:0.25348	validation_1-logloss:0.25518
# [41]	validation_0-logloss:0.25249	validation_1-logloss:0.25422
# [42]	validation_0-logloss:0.25168	validation_1-logloss:0.25344
# [43]	validation_0-logloss:0.25088	validation_1-logloss:0.25269
# [44]	validation_0-logloss:0.25007	validation_1-logloss:0.25193
# [45]	validation_0-logloss:0.24936	validation_1-logloss:0.25125
# [46]	validation_0-logloss:0.24860	validation_1-logloss:0.25054
# [47]	validation_0-logloss:0.24812	validation_1-logloss:0.25008
# [48]	validation_0-logloss:0.24746	validation_1-logloss:0.24947
# [49]	validation_0-logloss:0.24700	validation_1-logloss:0.24905
# [50]	validation_0-logloss:0.24637	validation_1-logloss:0.24847
# [51]	validation_0-logloss:0.24595	validation_1-logloss:0.24810
# [52]	validation_0-logloss:0.24520	validation_1-logloss:0.24739
# [53]	validation_0-logloss:0.24465	validation_1-logloss:0.24689
# [54]	validation_0-logloss:0.24415	validation_1-logloss:0.24642
# [55]	validation_0-logloss:0.24362	validation_1-logloss:0.24593
# [56]	validation_0-logloss:0.24320	validation_1-logloss:0.24555
# [57]	validation_0-logloss:0.24279	validation_1-logloss:0.24519
# [58]	validation_0-logloss:0.24235	validation_1-logloss:0.24478
# [59]	validation_0-logloss:0.24201	validation_1-logloss:0.24448
# [60]	validation_0-logloss:0.24163	validation_1-logloss:0.24416
# [61]	validation_0-logloss:0.24132	validation_1-logloss:0.24388
# [62]	validation_0-logloss:0.24114	validation_1-logloss:0.24374
# [63]	validation_0-logloss:0.24080	validation_1-logloss:0.24342
# [64]	validation_0-logloss:0.24059	validation_1-logloss:0.24323
# [65]	validation_0-logloss:0.24032	validation_1-logloss:0.24298
# [66]	validation_0-logloss:0.24008	validation_1-logloss:0.24277
# [67]	validation_0-logloss:0.23985	validation_1-logloss:0.24258
# [68]	validation_0-logloss:0.23959	validation_1-logloss:0.24235
# [69]	validation_0-logloss:0.23931	validation_1-logloss:0.24210
# [70]	validation_0-logloss:0.23911	validation_1-logloss:0.24195
# [71]	validation_0-logloss:0.23891	validation_1-logloss:0.24180
# [72]	validation_0-logloss:0.23875	validation_1-logloss:0.24168
# [73]	validation_0-logloss:0.23863	validation_1-logloss:0.24159
# [74]	validation_0-logloss:0.23841	validation_1-logloss:0.24141
# [75]	validation_0-logloss:0.23826	validation_1-logloss:0.24129
# [76]	validation_0-logloss:0.23812	validation_1-logloss:0.24118
# [77]	validation_0-logloss:0.23801	validation_1-logloss:0.24112
# [78]	validation_0-logloss:0.23788	validation_1-logloss:0.24101
# [79]	validation_0-logloss:0.23774	validation_1-logloss:0.24092
# [80]	validation_0-logloss:0.23754	validation_1-logloss:0.24077
# [81]	validation_0-logloss:0.23743	validation_1-logloss:0.24068
# [82]	validation_0-logloss:0.23734	validation_1-logloss:0.24062
# [83]	validation_0-logloss:0.23718	validation_1-logloss:0.24052
# [84]	validation_0-logloss:0.23709	validation_1-logloss:0.24048
# [85]	validation_0-logloss:0.23695	validation_1-logloss:0.24039
# [86]	validation_0-logloss:0.23688	validation_1-logloss:0.24034
# [87]	validation_0-logloss:0.23680	validation_1-logloss:0.24029
# [88]	validation_0-logloss:0.23667	validation_1-logloss:0.24022
# [89]	validation_0-logloss:0.23656	validation_1-logloss:0.24014
# [90]	validation_0-logloss:0.23645	validation_1-logloss:0.24007
# [91]	validation_0-logloss:0.23636	validation_1-logloss:0.24001
# [92]	validation_0-logloss:0.23621	validation_1-logloss:0.23991
# [93]	validation_0-logloss:0.23610	validation_1-logloss:0.23985
# [94]	validation_0-logloss:0.23598	validation_1-logloss:0.23977
# [95]	validation_0-logloss:0.23591	validation_1-logloss:0.23974
# [96]	validation_0-logloss:0.23583	validation_1-logloss:0.23969
# [97]	validation_0-logloss:0.23577	validation_1-logloss:0.23968
# [98]	validation_0-logloss:0.23570	validation_1-logloss:0.23964
# [99]	validation_0-logloss:0.23560	validation_1-logloss:0.23957
# [100]	validation_0-logloss:0.23554	validation_1-logloss:0.23955
# [101]	validation_0-logloss:0.23547	validation_1-logloss:0.23951
# [102]	validation_0-logloss:0.23543	validation_1-logloss:0.23950
# [103]	validation_0-logloss:0.23537	validation_1-logloss:0.23949
# [104]	validation_0-logloss:0.23531	validation_1-logloss:0.23947
# [105]	validation_0-logloss:0.23525	validation_1-logloss:0.23944
# [106]	validation_0-logloss:0.23519	validation_1-logloss:0.23941
# [107]	validation_0-logloss:0.23512	validation_1-logloss:0.23938
# [108]	validation_0-logloss:0.23505	validation_1-logloss:0.23936
# [109]	validation_0-logloss:0.23501	validation_1-logloss:0.23935
# [110]	validation_0-logloss:0.23496	validation_1-logloss:0.23934
# [111]	validation_0-logloss:0.23491	validation_1-logloss:0.23932
# [112]	validation_0-logloss:0.23486	validation_1-logloss:0.23930
# [113]	validation_0-logloss:0.23481	validation_1-logloss:0.23930
# [114]	validation_0-logloss:0.23478	validation_1-logloss:0.23928
# [115]	validation_0-logloss:0.23475	validation_1-logloss:0.23927
# [116]	validation_0-logloss:0.23468	validation_1-logloss:0.23925
# [117]	validation_0-logloss:0.23464	validation_1-logloss:0.23924
# [118]	validation_0-logloss:0.23461	validation_1-logloss:0.23924
# [119]	validation_0-logloss:0.23456	validation_1-logloss:0.23923
# [120]	validation_0-logloss:0.23453	validation_1-logloss:0.23922
# [121]	validation_0-logloss:0.23444	validation_1-logloss:0.23917
# [122]	validation_0-logloss:0.23440	validation_1-logloss:0.23916
# [123]	validation_0-logloss:0.23436	validation_1-logloss:0.23916
# [124]	validation_0-logloss:0.23433	validation_1-logloss:0.23915
# [125]	validation_0-logloss:0.23429	validation_1-logloss:0.23915
# [126]	validation_0-logloss:0.23426	validation_1-logloss:0.23914
# [127]	validation_0-logloss:0.23424	validation_1-logloss:0.23914
# [128]	validation_0-logloss:0.23419	validation_1-logloss:0.23913
# [129]	validation_0-logloss:0.23414	validation_1-logloss:0.23911
# [130]	validation_0-logloss:0.23409	validation_1-logloss:0.23910
# [131]	validation_0-logloss:0.23405	validation_1-logloss:0.23910
# [132]	validation_0-logloss:0.23402	validation_1-logloss:0.23909
# [133]	validation_0-logloss:0.23394	validation_1-logloss:0.23905
# [134]	validation_0-logloss:0.23389	validation_1-logloss:0.23905
# [135]	validation_0-logloss:0.23386	validation_1-logloss:0.23906
# [136]	validation_0-logloss:0.23383	validation_1-logloss:0.23905
# [137]	validation_0-logloss:0.23380	validation_1-logloss:0.23904
# [138]	validation_0-logloss:0.23377	validation_1-logloss:0.23904
# [139]	validation_0-logloss:0.23372	validation_1-logloss:0.23902
# [140]	validation_0-logloss:0.23369	validation_1-logloss:0.23902
# [141]	validation_0-logloss:0.23366	validation_1-logloss:0.23902
# [142]	validation_0-logloss:0.23360	validation_1-logloss:0.23900
# [143]	validation_0-logloss:0.23355	validation_1-logloss:0.23899
# [144]	validation_0-logloss:0.23353	validation_1-logloss:0.23900
# [145]	validation_0-logloss:0.23347	validation_1-logloss:0.23898
# [146]	validation_0-logloss:0.23344	validation_1-logloss:0.23898
# [147]	validation_0-logloss:0.23342	validation_1-logloss:0.23898
# [148]	validation_0-logloss:0.23338	validation_1-logloss:0.23899
# [149]	validation_0-logloss:0.23333	validation_1-logloss:0.23898
# [150]	validation_0-logloss:0.23332	validation_1-logloss:0.23898
# [151]	validation_0-logloss:0.23331	validation_1-logloss:0.23898
# [152]	validation_0-logloss:0.23327	validation_1-logloss:0.23898
# [153]	validation_0-logloss:0.23323	validation_1-logloss:0.23899
# [154]	validation_0-logloss:0.23322	validation_1-logloss:0.23899
# [155]	validation_0-logloss:0.23316	validation_1-logloss:0.23896
# [156]	validation_0-logloss:0.23313	validation_1-logloss:0.23896
# [157]	validation_0-logloss:0.23309	validation_1-logloss:0.23895
# [158]	validation_0-logloss:0.23305	validation_1-logloss:0.23894
# [159]	validation_0-logloss:0.23301	validation_1-logloss:0.23894
# [160]	validation_0-logloss:0.23296	validation_1-logloss:0.23894
# [161]	validation_0-logloss:0.23294	validation_1-logloss:0.23894
# [162]	validation_0-logloss:0.23292	validation_1-logloss:0.23894
# [163]	validation_0-logloss:0.23290	validation_1-logloss:0.23894
# [164]	validation_0-logloss:0.23286	validation_1-logloss:0.23893
# [165]	validation_0-logloss:0.23278	validation_1-logloss:0.23890
# [166]	validation_0-logloss:0.23276	validation_1-logloss:0.23890
# [167]	validation_0-logloss:0.23272	validation_1-logloss:0.23889
# [168]	validation_0-logloss:0.23269	validation_1-logloss:0.23888
# [169]	validation_0-logloss:0.23267	validation_1-logloss:0.23888
# [170]	validation_0-logloss:0.23262	validation_1-logloss:0.23888
# [171]	validation_0-logloss:0.23259	validation_1-logloss:0.23888
# [172]	validation_0-logloss:0.23257	validation_1-logloss:0.23888
# [173]	validation_0-logloss:0.23256	validation_1-logloss:0.23888
# [174]	validation_0-logloss:0.23253	validation_1-logloss:0.23888
# [175]	validation_0-logloss:0.23250	validation_1-logloss:0.23887
# [176]	validation_0-logloss:0.23247	validation_1-logloss:0.23887
# [177]	validation_0-logloss:0.23243	validation_1-logloss:0.23887
# [178]	validation_0-logloss:0.23235	validation_1-logloss:0.23885
# [179]	validation_0-logloss:0.23233	validation_1-logloss:0.23885
# [180]	validation_0-logloss:0.23231	validation_1-logloss:0.23886
# [181]	validation_0-logloss:0.23227	validation_1-logloss:0.23886
# [182]	validation_0-logloss:0.23224	validation_1-logloss:0.23885
# [183]	validation_0-logloss:0.23222	validation_1-logloss:0.23885
# [184]	validation_0-logloss:0.23219	validation_1-logloss:0.23884
# [185]	validation_0-logloss:0.23218	validation_1-logloss:0.23885
# [186]	validation_0-logloss:0.23213	validation_1-logloss:0.23884
# [187]	validation_0-logloss:0.23211	validation_1-logloss:0.23884
# [188]	validation_0-logloss:0.23208	validation_1-logloss:0.23885
# [189]	validation_0-logloss:0.23206	validation_1-logloss:0.23885
# [190]	validation_0-logloss:0.23202	validation_1-logloss:0.23884
# [191]	validation_0-logloss:0.23198	validation_1-logloss:0.23884
# [192]	validation_0-logloss:0.23196	validation_1-logloss:0.23884
# [193]	validation_0-logloss:0.23193	validation_1-logloss:0.23885
# [194]	validation_0-logloss:0.23190	validation_1-logloss:0.23885
# [195]	validation_0-logloss:0.23187	validation_1-logloss:0.23886
# [196]	validation_0-logloss:0.23184	validation_1-logloss:0.23886
# [197]	validation_0-logloss:0.23183	validation_1-logloss:0.23886
# [198]	validation_0-logloss:0.23179	validation_1-logloss:0.23886
# [199]	validation_0-logloss:0.23176	validation_1-logloss:0.23886
# [200]	validation_0-logloss:0.23172	validation_1-logloss:0.23886
# [201]	validation_0-logloss:0.23169	validation_1-logloss:0.23886
# [202]	validation_0-logloss:0.23166	validation_1-logloss:0.23886
# [203]	validation_0-logloss:0.23165	validation_1-logloss:0.23886
# [204]	validation_0-logloss:0.23162	validation_1-logloss:0.23886
# [205]	validation_0-logloss:0.23158	validation_1-logloss:0.23886
# [206]	validation_0-logloss:0.23155	validation_1-logloss:0.23886
# [207]	validation_0-logloss:0.23153	validation_1-logloss:0.23886
# [208]	validation_0-logloss:0.23150	validation_1-logloss:0.23886
# [209]	validation_0-logloss:0.23148	validation_1-logloss:0.23885
# [210]	validation_0-logloss:0.23146	validation_1-logloss:0.23885
# [211]	validation_0-logloss:0.23143	validation_1-logloss:0.23884
# [212]	validation_0-logloss:0.23141	validation_1-logloss:0.23884
# [213]	validation_0-logloss:0.23140	validation_1-logloss:0.23884
# [214]	validation_0-logloss:0.23138	validation_1-logloss:0.23885
# [215]	validation_0-logloss:0.23137	validation_1-logloss:0.23885
# [216]	validation_0-logloss:0.23133	validation_1-logloss:0.23884
# [217]	validation_0-logloss:0.23129	validation_1-logloss:0.23884
# [218]	validation_0-logloss:0.23126	validation_1-logloss:0.23883
# [219]	validation_0-logloss:0.23124	validation_1-logloss:0.23884
# [220]	validation_0-logloss:0.23121	validation_1-logloss:0.23883
# [221]	validation_0-logloss:0.23120	validation_1-logloss:0.23884
# [222]	validation_0-logloss:0.23117	validation_1-logloss:0.23884
# [223]	validation_0-logloss:0.23115	validation_1-logloss:0.23884
# [224]	validation_0-logloss:0.23109	validation_1-logloss:0.23884
# [225]	validation_0-logloss:0.23106	validation_1-logloss:0.23885
# [226]	validation_0-logloss:0.23100	validation_1-logloss:0.23882
# [227]	validation_0-logloss:0.23098	validation_1-logloss:0.23883
# [228]	validation_0-logloss:0.23095	validation_1-logloss:0.23883
# [229]	validation_0-logloss:0.23091	validation_1-logloss:0.23883
# [230]	validation_0-logloss:0.23089	validation_1-logloss:0.23884
# [231]	validation_0-logloss:0.23084	validation_1-logloss:0.23884
# [232]	validation_0-logloss:0.23081	validation_1-logloss:0.23884
# [233]	validation_0-logloss:0.23079	validation_1-logloss:0.23884
# [234]	validation_0-logloss:0.23078	validation_1-logloss:0.23884
# [235]	validation_0-logloss:0.23077	validation_1-logloss:0.23885
# [236]	validation_0-logloss:0.23076	validation_1-logloss:0.23885
# [237]	validation_0-logloss:0.23072	validation_1-logloss:0.23886
# [238]	validation_0-logloss:0.23067	validation_1-logloss:0.23885
# [239]	validation_0-logloss:0.23064	validation_1-logloss:0.23885
# [240]	validation_0-logloss:0.23061	validation_1-logloss:0.23885
# [241]	validation_0-logloss:0.23059	validation_1-logloss:0.23885
# [242]	validation_0-logloss:0.23058	validation_1-logloss:0.23885
# [243]	validation_0-logloss:0.23057	validation_1-logloss:0.23886
# [244]	validation_0-logloss:0.23056	validation_1-logloss:0.23886
# [245]	validation_0-logloss:0.23056	validation_1-logloss:0.23886
# [246]	validation_0-logloss:0.23055	validation_1-logloss:0.23886
# [247]	validation_0-logloss:0.23052	validation_1-logloss:0.23886
# [248]	validation_0-logloss:0.23049	validation_1-logloss:0.23886
# [249]	validation_0-logloss:0.23045	validation_1-logloss:0.23886
# [250]	validation_0-logloss:0.23042	validation_1-logloss:0.23886
# [251]	validation_0-logloss:0.23038	validation_1-logloss:0.23886
# [252]	validation_0-logloss:0.23033	validation_1-logloss:0.23885
# [253]	validation_0-logloss:0.23030	validation_1-logloss:0.23886
# [254]	validation_0-logloss:0.23027	validation_1-logloss:0.23886
# [255]	validation_0-logloss:0.23025	validation_1-logloss:0.23886
# [256]	validation_0-logloss:0.23021	validation_1-logloss:0.23886
# [257]	validation_0-logloss:0.23019	validation_1-logloss:0.23886
# [258]	validation_0-logloss:0.23015	validation_1-logloss:0.23887
# [259]	validation_0-logloss:0.23012	validation_1-logloss:0.23887
# [260]	validation_0-logloss:0.23010	validation_1-logloss:0.23887
# [261]	validation_0-logloss:0.23007	validation_1-logloss:0.23887
# [262]	validation_0-logloss:0.23006	validation_1-logloss:0.23886
# [263]	validation_0-logloss:0.23003	validation_1-logloss:0.23887
# [264]	validation_0-logloss:0.22998	validation_1-logloss:0.23887
# [265]	validation_0-logloss:0.22995	validation_1-logloss:0.23887
# [266]	validation_0-logloss:0.22992	validation_1-logloss:0.23887
# [267]	validation_0-logloss:0.22987	validation_1-logloss:0.23886
# [268]	validation_0-logloss:0.22986	validation_1-logloss:0.23887
# [269]	validation_0-logloss:0.22981	validation_1-logloss:0.23886
# [270]	validation_0-logloss:0.22979	validation_1-logloss:0.23886
# [271]	validation_0-logloss:0.22977	validation_1-logloss:0.23885
# [272]	validation_0-logloss:0.22975	validation_1-logloss:0.23885
# [273]	validation_0-logloss:0.22972	validation_1-logloss:0.23885
# [274]	validation_0-logloss:0.22971	validation_1-logloss:0.23885
# [275]	validation_0-logloss:0.22970	validation_1-logloss:0.23885
#  ########################################

# %%
# XGBoost with the kinematic variables of the leptons

########################
# CLASSIFICATION SCORE #
########################

# Outputs for validation data set

pred_XG_SM_1ML = []
pred_XG_NP_1ML = []

for i in range(len(y_mon_test)):
    if y_mon_test[i] == 0:
        pred_XG_SM_1ML.append(y_pred_xg_1ML[i])
    else:
        pred_XG_NP_1ML.append(y_pred_xg_1ML[i])
        
        
print('Classification score (1ML):')
        
weights = np.ones_like(pred_XG_SM_1ML)/float(len(pred_XG_SM_1ML))
nSM, binsSM, patchesSM = plt.hist(pred_XG_SM_1ML, 100, weights=weights, range=[0,1], histtype='step', color='firebrick', linewidth=2, label='Background')

weights = np.ones_like(pred_XG_NP_1ML)/float(len(pred_XG_NP_1ML))
nNP, binsNP, patchesNP = plt.hist(pred_XG_NP_1ML, 100, weights=weights, range=[0,1], histtype='step', color='forestgreen', linewidth=2, label='Signal')

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("Classication score (XGBoost)",fontsize=15)
plt.ylabel("Fraction of events",fontsize=14)
plt.grid()
plt.legend(fontsize=12)
plt.title('Multivariate monian distributions, $\mathcal{N}_{2}$', fontsize=14)
#plt.savefig('images/' + '2monian-output.pdf', format="pdf", bbox_inches="tight")
plt.show()




# Outputs for validation data set

pred_XG_SM = []
pred_XG_NP = []

for i in range(len(y_mon_test)):
    if y_mon_test[i] == 0:
        pred_XG_SM.append(y_pred_xg[i])
    else:
        pred_XG_NP.append(y_pred_xg[i])
        
        
print('Classification score (10ML):')
        
weights = np.ones_like(pred_XG_SM)/float(len(pred_XG_SM))
nSM, binsSM, patchesSM = plt.hist(pred_XG_SM, 100, weights=weights, range=[0,1], histtype='step', color='firebrick', linewidth=2, label='Background')

weights = np.ones_like(pred_XG_NP)/float(len(pred_XG_NP))
nNP, binsNP, patchesNP = plt.hist(pred_XG_NP, 100, weights=weights, range=[0,1], histtype='step', color='forestgreen', linewidth=2, label='Signal')

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("Classication score (XGBoost)",fontsize=15)
plt.ylabel("Fraction of events",fontsize=14)
plt.grid()
plt.legend(fontsize=12)
plt.title('Multivariate monian distributions, $\mathcal{N}_{2}$', fontsize=14)
#plt.savefig('images/' + '2monian-output.pdf', format="pdf", bbox_inches="tight")
plt.show()
# Out:
# Classification score (1ML):
# Classification score (10ML):

# %% [markdown]
# ## METHODS

# %% [markdown]
# ### 0. Ensembles characteristics

# %%
##############
# PARAMETERS #
##############

# requested number of ensembles
n_ensembles = 5000

# number of expected background events per ensemble
B_expected = 5000

# ratio S_expected/B_expected (signal ratio)
SB_ratio = [0.0006, 0.001, 0.0016, 0.0025, 0.005, 0.0075, 0.01, 0.025]





# SOME USEFUL DERIVATED PARAMETERS:

# S_expected:
S_expected = [ int(SB_ratio[iii]*B_expected) for iii in range(len(SB_ratio)) ]
print(S_expected)

# S/\sqrt{B}
SsqrtB = [ S_expected[iii]/(B_expected)**0.5 for iii in range(len(SB_ratio)) ]
# Out:
# [2, 5, 8, 12, 25, 37, 50, 125]

# %% [markdown]
# ### 1. BIN LOG LIKELIHOOD

# %%
# 1st variable: invariant mass
background_X_1 = invariant_mass_eeSM
signal_X_1 = invariant_mass_eeSSMZprime

N_B = len(background_X_1)
N_S = len(signal_X_1)

# bins
logbins = [2000.0, 2200.0, 2500.0, 2850.0, 3250.0, 3750.0, 4350.0, 5000.0, 5750.0, 6600.0, 7500.0, 8750.0, 10000.0, 11500.0, 13000.0, 20000.0]

# %%
#################################
# BINNED POISSON LOG-LIKELIHOOD #
#################################


store_Z_bins = []
store_Z_bins_logbins = []


for iii in range(len(SB_ratio)):

    print('B_expected: ', B_expected)
    print('S_expected: ', S_expected[iii])
    print(r'S/$\sqrt{B}$: ', SsqrtB[iii])

    # Les't use an integer number of possible ensembles
    N_ensembles_back = int(N_B / B_expected)
    N_events_back = N_ensembles_back * B_expected

    N_ensembles_sig = int(N_S / S_expected[iii])
    N_events_sig = N_ensembles_sig * S_expected[iii]


    #Let's find out the expected number of B and S events in each bin:

    # bin the parameter space of all background events
    hist_back, binedges_back = np.histogramdd([background_X_1[:N_events_back]], bins=(100), range = [[2000,20000]])
    # now divide by the number of possible ensembles
    back_prom = hist_back.T.ravel()/N_ensembles_back

    # same for signal
    hist_sig, binedges_sig = np.histogramdd([signal_X_1[:N_events_sig]], bins=(100), range = [[2000,20000]])
    sig_prom = hist_sig.T.ravel()/N_ensembles_sig

        

    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    back_prom_noceros = []
    for i in range(len(back_prom)):
        if back_prom[i]!=0:
            back_prom_noceros.append(back_prom[i])

    min_back = min(back_prom_noceros)

    # replace the zeros
    for i in range(len(back_prom)):
        if back_prom[i]==0:
            back_prom[i] = min_back

    # then the signif Z^binned-Asimov:
    Z_bins = ( 2* sum( ( back_prom * np.log( back_prom/(sig_prom + back_prom) ) ) + sig_prom ) )**0.5

    store_Z_bins.append(Z_bins)

    print('Z_bins : ', Z_bins)
    

    
    ############
    # LOG BINS #
    ############
    #Let's find out the expected number of B and S events in each bin:

    # bin the parameter space of all background events
    hist_back, binedges_back = np.histogramdd([background_X_1[:N_events_back]], bins=[logbins])
    # now divide by the number of possible ensembles
    back_prom = hist_back.T.ravel()/N_ensembles_back

    # same for signal
    hist_sig, binedges_sig = np.histogramdd([signal_X_1[:N_events_sig]], bins=[logbins])
    sig_prom = hist_sig.T.ravel()/N_ensembles_sig

        

    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    back_prom_noceros = []
    for i in range(len(back_prom)):
        if back_prom[i]!=0:
            back_prom_noceros.append(back_prom[i])

    min_back = min(back_prom_noceros)

    # replace the zeros
    for i in range(len(back_prom)):
        if back_prom[i]==0:
            back_prom[i] = min_back

    # then the signif Z^binned-Asimov:
    Z_bins_logbins = ( 2* sum( ( back_prom * np.log( back_prom/(sig_prom + back_prom) ) ) + sig_prom ) )**0.5

    store_Z_bins_logbins.append(Z_bins_logbins)

    print('Z_bins_logbins : ', Z_bins_logbins)
    
    
    
    print('\n ----------------------------------- \n')
# Out:
# B_expected:  5000
# S_expected:  2
# S/$\sqrt{B}$:  0.0282842712474619
# Z_bins :  0.433108008760961
# Z_bins_logbins :  0.35215464721392276
#
#  -----------------------------------
#
# B_expected:  5000
# S_expected:  5
# S/$\sqrt{B}$:  0.07071067811865475
# Z_bins :  1.013733285356924
# Z_bins_logbins :  0.842962647181671
#
#  -----------------------------------
#
# B_expected:  5000
# S_expected:  8
# S/$\sqrt{B}$:  0.1131370849898476
# Z_bins :  1.5336422703666046
# Z_bins_logbins :  1.2976920637645761
#
#  -----------------------------------
#
# B_expected:  5000
# S_expected:  12
# S/$\sqrt{B}$:  0.1697056274847714
# Z_bins :  2.1581640791752714
# Z_bins_logbins :  1.8595474559792702
#
#  -----------------------------------
#
# B_expected:  5000
# S_expected:  25
# S/$\sqrt{B}$:  0.35355339059327373
# Z_bins :  3.8453082119773043
# Z_bins_logbins :  3.4397170100126804
#
#  -----------------------------------
#
# B_expected:  5000
# S_expected:  37
# S/$\sqrt{B}$:  0.5232590180780452
# Z_bins :  5.122655367679353
# Z_bins_logbins :  4.676377869533103
#
#  -----------------------------------
#
# B_expected:  5000
# S_expected:  50
# S/$\sqrt{B}$:  0.7071067811865475
# Z_bins :  6.323962926379762
# Z_bins_logbins :  5.8587373311981015
#
#  -----------------------------------
#
# B_expected:  5000
# S_expected:  125
# S/$\sqrt{B}$:  1.7677669529663687
# Z_bins :  11.489252931451743
# Z_bins_logbins :  11.034494345484156
#
#  -----------------------------------

# %%
print(store_Z_bins)
print(store_Z_bins_logbins)
# Out:
# [0.433108008760961, 1.013733285356924, 1.5336422703666046, 2.1581640791752714, 3.8453082119773043, 5.122655367679353, 6.323962926379762, 11.489252931451743]
# [0.35215464721392276, 0.842962647181671, 1.2976920637645761, 1.8595474559792702, 3.4397170100126804, 4.676377869533103, 5.8587373311981015, 11.034494345484156]

# %%
store_Z_bins = [0.433108008760961, 1.013733285356924, 1.5336422703666046, 2.1581640791752714, 3.8453082119773043, 5.122655367679353, 6.323962926379762, 11.489252931451743]

store_Z_bins_logbins = [0.35215464721392276, 0.842962647181671, 1.2976920637645761, 1.8595474559792702, 3.4397170100126804, 4.676377869533103, 5.8587373311981015, 11.034494345484156]

# %%
#########
# PLOTS #
#########

posX = []

for i in range(len(SB_ratio)):
    posX.append( (B_expected*SB_ratio[i]) / ( B_expected )**0.5 )


    
plt.figure()
lw = 2

plt.plot(posX, store_Z_bins, '-ok', color='blue', lw=lw, label='100 Linear Binned Likelihood') 
plt.plot(posX, store_Z_bins_logbins, '-ok', color='lightblue', lw=lw, label='15 Log Binned Likelihood')

#plt.xlim([0.5, 10])
#plt.ylim([-0.5, 7.5])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=14)
plt.ylabel('$Z_{\mu}$ (exclusion)', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title('<B> per ensemble: %0.2d' % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()
# Out:
# <ipython-input-66-3340ebf10fa5>:15: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins, '-ok', color='blue', lw=lw, label='100 Linear Binned Likelihood')
# <ipython-input-66-3340ebf10fa5>:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_logbins, '-ok', color='lightblue', lw=lw, label='15 Log Binned Likelihood')

# %% [markdown]
# ### 2. Binned OUTPUT and MLL Asimov

# %%
#################################
# MLL Asimov-like #
#################################


store_Z_bins_XG = []

store_Z_bins_XG_15bins = []
store_Z_bins_XG_15bins_1ML = []

store_Z_bins_XG_15bins_eq = []
store_Z_bins_XG_15bins_eq_1ML = []


for iii in range(len(SB_ratio)):

    print('B_expected: ', B_expected)
    print('S_expected: ', S_expected[iii])
    print(r'S/$\sqrt{B}$: ', SsqrtB[iii])

    # Les't find the number of possible ensembles
    N_ensembles_back = len(pred_XG_SM) / B_expected
    N_ensembles_sig = len(pred_XG_NP) / S_expected[iii]



    #Let's find out the expected number of B and S events in each bin:
 
    # bin the parameter space of all background events
    hist_back, binedges_back = np.histogramdd([pred_XG_SM], bins=(100), range = [[0,1]])
    
    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    hist_back_noceros = []
    for i in range(len(hist_back)):
        if hist_back[i]!=0:
            hist_back_noceros.append(hist_back[i])

    min_back = min(hist_back_noceros)

    # replace the zeros
    for i in range(len(hist_back)):
        if hist_back[i]==0:
            hist_back[i] = min_back
    
    # now divide by the number of possible ensembles
    back_prom = hist_back/N_ensembles_back
    # normalized (sum=1)
    back_norm = hist_back/np.sum(hist_back)

    
    
    # same for signal
    hist_sig, binedges_sig = np.histogramdd([pred_XG_NP], bins=(100), range = [[0,1]])
    sig_prom = hist_sig/N_ensembles_sig
    sig_norm = hist_sig/np.sum(hist_sig)
        


    ##########################################
    # BINNED LIKELIHOOD of CLASSIFIER OUTPUT #
    ##########################################

    # then the signif Z^binned-Asimov:
    Z_bins_XG = ( 2* sum( ( back_prom * np.log( back_prom / (sig_prom+back_prom) ) ) + sig_prom ) )**0.5

    store_Z_bins_XG.append(Z_bins_XG)

    print('Z_bins_XG : ', Z_bins_XG)
    
    
    
    
    
    ######################
    # linear bins, 10 ML #
    ######################
    
    #Let's find out the expected number of B and S events in each bin:
 
    # bin the parameter space of all background events
    hist_back, binedges_back = np.histogramdd([pred_XG_SM], bins=(15), range = [[0,1]])
    
    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    hist_back_noceros = []
    for i in range(len(hist_back)):
        if hist_back[i]!=0:
            hist_back_noceros.append(hist_back[i])

    min_back = min(hist_back_noceros)

    # replace the zeros
    for i in range(len(hist_back)):
        if hist_back[i]==0:
            hist_back[i] = min_back
    
    # now divide by the number of possible ensembles
    back_prom = hist_back/N_ensembles_back
    # normalized (sum=1)
    back_norm = hist_back/np.sum(hist_back)

    
    
    # same for signal
    hist_sig, binedges_sig = np.histogramdd([pred_XG_NP], bins=(15), range = [[0,1]])
    sig_prom = hist_sig/N_ensembles_sig
    sig_norm = hist_sig/np.sum(hist_sig)
        


    ##########################################
    # BINNED LIKELIHOOD of CLASSIFIER OUTPUT #
    ##########################################

    # then the signif Z^binned-Asimov:
    Z_bins_XG_15bins = ( 2* sum( ( back_prom * np.log( back_prom / (sig_prom+back_prom) ) ) + sig_prom ) )**0.5

    store_Z_bins_XG_15bins.append(Z_bins_XG_15bins)

    print('Z_bins_XG_15bins : ', Z_bins_XG_15bins)
    
    
    
    
    
    ######################
    # linear bins, 1  ML #
    ######################
    
    #Let's find out the expected number of B and S events in each bin:
 
    # bin the parameter space of all background events
    hist_back, binedges_back = np.histogramdd([pred_XG_SM_1ML], bins=(15), range = [[0,1]])
    
    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    hist_back_noceros = []
    for i in range(len(hist_back)):
        if hist_back[i]!=0:
            hist_back_noceros.append(hist_back[i])

    min_back = min(hist_back_noceros)

    # replace the zeros
    for i in range(len(hist_back)):
        if hist_back[i]==0:
            hist_back[i] = min_back
    
    # now divide by the number of possible ensembles
    back_prom = hist_back/N_ensembles_back
    # normalized (sum=1)
    back_norm = hist_back/np.sum(hist_back)

    
    
    # same for signal
    hist_sig, binedges_sig = np.histogramdd([pred_XG_NP], bins=(15), range = [[0,1]])
    sig_prom = hist_sig/N_ensembles_sig
    sig_norm = hist_sig/np.sum(hist_sig)
        


    ##########################################
    # BINNED LIKELIHOOD of CLASSIFIER OUTPUT #
    ##########################################

    # then the signif Z^binned-Asimov:
    Z_bins_XG_15bins_1ML = ( 2* sum( ( back_prom * np.log( back_prom / (sig_prom+back_prom) ) ) + sig_prom ) )**0.5

    store_Z_bins_XG_15bins_1ML.append(Z_bins_XG_15bins_1ML)

    print('Z_bins_XG_15bins_1ML : ', Z_bins_XG_15bins_1ML)
    
    
    
    
    
    ##########################
    # non linear bins, 10 ML #
    ##########################
    
    #Let's find out the expected number of B and S events in each bin:
    # same number of B events per bin
    bin_edges_same = pd.qcut(pd.DataFrame(pred_XG_SM)[0], q = 15, precision=0, retbins = True)[1]
 
    # bin the parameter space of all background events
    hist_back, binedges_back = np.histogramdd([pred_XG_SM], bins=[bin_edges_same], range = [[0,1]])
    
    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    hist_back_noceros = []
    for i in range(len(hist_back)):
        if hist_back[i]!=0:
            hist_back_noceros.append(hist_back[i])

    min_back = min(hist_back_noceros)

    # replace the zeros
    for i in range(len(hist_back)):
        if hist_back[i]==0:
            hist_back[i] = min_back
    
    # now divide by the number of possible ensembles
    back_prom = hist_back/N_ensembles_back
    # normalized (sum=1)
    back_norm = hist_back/np.sum(hist_back)

    
    
    # same for signal
    hist_sig, binedges_sig = np.histogramdd([pred_XG_NP], bins=[bin_edges_same], range = [[0,1]])
    sig_prom = hist_sig/N_ensembles_sig
    sig_norm = hist_sig/np.sum(hist_sig)
        


    ##########################################
    # BINNED LIKELIHOOD of CLASSIFIER OUTPUT #
    ##########################################

    # then the signif Z^binned-Asimov:
    Z_bins_XG_15bins_eq = ( 2* sum( ( back_prom * np.log( back_prom / (sig_prom+back_prom) ) ) + sig_prom ) )**0.5

    store_Z_bins_XG_15bins_eq.append(Z_bins_XG_15bins_eq)

    print('Z_bins_XG_15bins_eq : ', Z_bins_XG_15bins_eq)
    
    
    
    
    
    ##########################
    # non linear bins, 1  ML #
    ##########################
    
    #Let's find out the expected number of B and S events in each bin:
    # same number of B events per bin
    bin_edges_same = pd.qcut(pd.DataFrame(pred_XG_SM_1ML)[0], q = 15, precision=0, retbins = True)[1]
 
    # bin the parameter space of all background events
    hist_back, binedges_back = np.histogramdd([pred_XG_SM_1ML], bins=[bin_edges_same], range = [[0,1]])
    
    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    hist_back_noceros = []
    for i in range(len(hist_back)):
        if hist_back[i]!=0:
            hist_back_noceros.append(hist_back[i])

    min_back = min(hist_back_noceros)

    # replace the zeros
    for i in range(len(hist_back)):
        if hist_back[i]==0:
            hist_back[i] = min_back
    
    # now divide by the number of possible ensembles
    back_prom = hist_back/N_ensembles_back
    # normalized (sum=1)
    back_norm = hist_back/np.sum(hist_back)

    
    
    # same for signal
    hist_sig, binedges_sig = np.histogramdd([pred_XG_NP_1ML], bins=[bin_edges_same], range = [[0,1]])
    sig_prom = hist_sig/N_ensembles_sig
    sig_norm = hist_sig/np.sum(hist_sig)
        


    ##########################################
    # BINNED LIKELIHOOD of CLASSIFIER OUTPUT #
    ##########################################

    # then the signif Z^binned-Asimov:
    Z_bins_XG_15bins_eq_1ML = ( 2* sum( ( back_prom * np.log( back_prom / (sig_prom+back_prom) ) ) + sig_prom ) )**0.5

    store_Z_bins_XG_15bins_eq_1ML.append(Z_bins_XG_15bins_eq_1ML)

    print('Z_bins_XG_15bins_eq_1ML : ', Z_bins_XG_15bins_eq_1ML)


        
    print('\n ----------------------------------------- \n')
# Out:
# B_expected:  5000
# S_expected:  2
# S/$\sqrt{B}$:  0.0282842712474619
# Z_bins_XG :  0.3657119570183754
# Z_bins_XG_15bins :  0.26791819886432433
# Z_bins_XG_15bins_1ML :  0.2678374039546337
# Z_bins_XG_15bins_eq :  0.09655460450434147
# Z_bins_XG_15bins_eq_1ML :  0.0965283119794364
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  5
# S/$\sqrt{B}$:  0.07071067811865475
# Z_bins_XG :  0.8735706663269368
# Z_bins_XG_15bins :  0.6552614946059496
# Z_bins_XG_15bins_1ML :  0.655071683100822
# Z_bins_XG_15bins_eq :  0.24075464340771388
# Z_bins_XG_15bins_eq_1ML :  0.24068925305989114
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  8
# S/$\sqrt{B}$:  0.1131370849898476
# Z_bins_XG :  1.3420377112802955
# Z_bins_XG_15bins :  1.0268318966143966
# Z_bins_XG_15bins_1ML :  1.0265454051953842
# Z_bins_XG_15bins_eq :  0.38420565480568014
# Z_bins_XG_15bins_eq_1ML :  0.38410156836651665
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  12
# S/$\sqrt{B}$:  0.1697056274847714
# Z_bins_XG :  1.918174877932676
# Z_bins_XG_15bins :  1.5004516233462772
# Z_bins_XG_15bins_1ML :  1.5000519468521418
# Z_bins_XG_15bins_eq :  0.5743260467534053
# Z_bins_XG_15bins_eq_1ML :  0.5741709763906572
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  25
# S/$\sqrt{B}$:  0.35355339059327373
# Z_bins_XG :  3.5248394853275316
# Z_bins_XG_15bins :  2.8997356857374355
# Z_bins_XG_15bins_1ML :  2.8990558225277043
# Z_bins_XG_15bins_eq :  1.1834249245791797
# Z_bins_XG_15bins_eq_1ML :  1.1831087679787025
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  37
# S/$\sqrt{B}$:  0.5232590180780452
# Z_bins_XG :  4.771795147936808
# Z_bins_XG_15bins :  4.04547061699648
# Z_bins_XG_15bins_1ML :  4.04460786824605
# Z_bins_XG_15bins_eq :  1.7342290771066313
# Z_bins_XG_15bins_eq_1ML :  1.7337701018338958
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  50
# S/$\sqrt{B}$:  0.7071067811865475
# Z_bins_XG :  5.958552615641308
# Z_bins_XG_15bins :  5.169767776918851
# Z_bins_XG_15bins_1ML :  5.168755117382373
# Z_bins_XG_15bins_eq :  2.319192357753986
# Z_bins_XG_15bins_eq_1ML :  2.3185845332913995
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  125
# S/$\sqrt{B}$:  1.7677669529663687
# Z_bins_XG :  11.129359216112464
# Z_bins_XG_15bins :  10.273328882621136
# Z_bins_XG_15bins_1ML :  10.271837258804268
# Z_bins_XG_15bins_eq :  5.484737957231937
# Z_bins_XG_15bins_eq_1ML :  5.483369714029085
#
#  -----------------------------------------

# %%
print(store_Z_bins_XG)

print(store_Z_bins_XG_15bins)
print(store_Z_bins_XG_15bins_1ML)

print(store_Z_bins_XG_15bins_eq)
print(store_Z_bins_XG_15bins_eq_1ML)
# Out:
# [0.3657119570183754, 0.8735706663269368, 1.3420377112802955, 1.918174877932676, 3.5248394853275316, 4.771795147936808, 5.958552615641308, 11.129359216112464]
# [0.26791819886432433, 0.6552614946059496, 1.0268318966143966, 1.5004516233462772, 2.8997356857374355, 4.04547061699648, 5.169767776918851, 10.273328882621136]
# [0.2678374039546337, 0.655071683100822, 1.0265454051953842, 1.5000519468521418, 2.8990558225277043, 4.04460786824605, 5.168755117382373, 10.271837258804268]
# [0.09655460450434147, 0.24075464340771388, 0.38420565480568014, 0.5743260467534053, 1.1834249245791797, 1.7342290771066313, 2.319192357753986, 5.484737957231937]
# [0.0965283119794364, 0.24068925305989114, 0.38410156836651665, 0.5741709763906572, 1.1831087679787025, 1.7337701018338958, 2.3185845332913995, 5.483369714029085]

# %%
store_Z_bins_XG = [0.3657119570183754, 0.8735706663269368, 1.3420377112802955, 1.918174877932676, 3.5248394853275316, 4.771795147936808, 5.958552615641308, 11.129359216112464]

store_Z_bins_XG_15bins = [0.26791819886432433, 0.6552614946059496, 1.0268318966143966, 1.5004516233462772, 2.8997356857374355, 4.04547061699648, 5.169767776918851, 10.273328882621136]
store_Z_bins_XG_15bins_1ML = [0.2678374039546337, 0.655071683100822, 1.0265454051953842, 1.5000519468521418, 2.8990558225277043, 4.04460786824605, 5.168755117382373, 10.271837258804268]

store_Z_bins_XG_15bins_eq = [0.09655460450434147, 0.24075464340771388, 0.38420565480568014, 0.5743260467534053, 1.1834249245791797, 1.7342290771066313, 2.319192357753986, 5.484737957231937]
store_Z_bins_XG_15bins_eq_1ML = [0.0965283119794364, 0.24068925305989114, 0.38410156836651665, 0.5741709763906572, 1.1831087679787025, 1.7337701018338958, 2.3185845332913995, 5.483369714029085]

# %%
#########
# PLOTS #
#########

posX = []

for i in range(len(SB_ratio)):
    posX.append( (B_expected*SB_ratio[i]) / ( B_expected )**0.5 )



    
    
plt.figure()
lw = 2

plt.plot(posX, store_Z_bins_XG, '-ok', color='blue', lw=lw, label='o(x) BL (100 l.bins)') 
plt.plot(posX, store_Z_bins_XG_15bins, '-ok', color='red', lw=lw, label='o(x) BL (15 l.bins) (10ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_1ML, '-ok', color='green', lw=lw, label='o(x) BL (15 l.bins) (1ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_eq, '-ok', color='magenta', lw=lw, label='o(x) BL (15 n.l.bins) (10ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_eq_1ML, '-ok', color='darkorange', lw=lw, label='o(x) BL (15 n.l.bins) (1ML)') 

#plt.xlim([0.5, 10])
#plt.ylim([-0.5, 7.5])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=14)
plt.ylabel('$Z_{\mu}$ (exclusion)', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title("SSM Z', <B> per ensemble: %0.2d" % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()
# Out:
# <ipython-input-68-13c05c382495>:17: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG, '-ok', color='blue', lw=lw, label='o(x) BL (100 l.bins)')
# <ipython-input-68-13c05c382495>:18: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins, '-ok', color='red', lw=lw, label='o(x) BL (15 l.bins) (10ML)')
# <ipython-input-68-13c05c382495>:19: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_1ML, '-ok', color='green', lw=lw, label='o(x) BL (15 l.bins) (1ML)')
# <ipython-input-68-13c05c382495>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_eq, '-ok', color='magenta', lw=lw, label='o(x) BL (15 n.l.bins) (10ML)')
# <ipython-input-68-13c05c382495>:21: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_eq_1ML, '-ok', color='darkorange', lw=lw, label='o(x) BL (15 n.l.bins) (1ML)')

# %% [markdown]
# ### 3. MACHINE-LEARNED LIKELIHOOD with KDE

# %% [markdown]
# ##### For 10 ML

# %%
store_Z_MLL_KDE = []
store_Z_MLL_KDE_mu0 = []

store_muhat_mean_MLL = []




# FIND THE BANDWIDTH

bandwidth = np.logspace(-3.0, 0.05, 20)
print(bandwidth)

kde = KernelDensity(kernel='epanechnikov')
grid = GridSearchCV(kde, {'bandwidth': bandwidth})
grid.fit(np.c_[pred_XG_SM[:50000]])
print(grid.best_estimator_)

SM_bandwidth = grid.best_estimator_.bandwidth



kde = KernelDensity(kernel='epanechnikov')
grid = GridSearchCV(kde, {'bandwidth': bandwidth})
grid.fit(np.c_[pred_XG_NP[:50000]])
print(grid.best_estimator_)

NP_bandwidth = grid.best_estimator_.bandwidth







# aca fitteo 
kde_bkg = KernelDensity(kernel="epanechnikov", bandwidth=SM_bandwidth).fit(np.c_[pred_XG_SM, np.zeros(len(pred_XG_SM)) ])
kde_sig = KernelDensity(kernel="epanechnikov", bandwidth=NP_bandwidth).fit(np.c_[pred_XG_NP, np.ones(len(pred_XG_NP)) ])


# elijo los valores para graficar y calcular la significancia de Asimov
min_val = np.min([np.min(pred_XG_SM),np.min(pred_XG_NP)])
max_val = np.max([np.max(pred_XG_SM),np.max(pred_XG_NP)])

s_vals = np.linspace(min_val,max_val,100)





# evaluo las densidades en cada valor de s. esto es mas o menos equivalente a tomar bines continuos
dens_bkg = np.exp(kde_bkg.score_samples(np.c_[s_vals, np.zeros(len(s_vals)) ]) )
dens_sig = np.exp(kde_sig.score_samples(np.c_[s_vals, np.ones(len(s_vals)) ]) )





# PERO NO ESTA NORMALIZADO A 1 el area
# Area
factor_aux_SM = sum(dens_bkg*(s_vals[1]-s_vals[0]))
factor_aux_NP = sum(dens_sig*(s_vals[1]-s_vals[0]))

# normalizo
dens_bkg = dens_bkg / factor_aux_SM
dens_sig = dens_sig / factor_aux_NP






# grafico y verifico si la densidad es una buena aproximacion

plt.figure()

plt.hist(pred_XG_SM,density=True,bins=50,color='red',alpha=0.25,label='Sampled $p_{b}$');
plt.plot(s_vals,dens_bkg,color='red',label='Learned $p_{b}$',linestyle='dashed');

plt.hist(pred_XG_NP,density=True,bins=50,color='blue',alpha=0.25,label='Sampled $p_{s}$');
plt.plot(s_vals,dens_sig,color='blue',label='Learned $p_{s}$',linestyle='dashed');

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("o(x)",fontsize=15)
plt.ylabel("PDF",fontsize=14)
plt.grid()
plt.legend(fontsize=12)
#plt.title(r"Signal: W'$\rightarrow$XY, Background: QCD", fontsize=14)
#plt.savefig('images/' + 'Wprime-output.pdf', format="pdf", bbox_inches="tight")
plt.show()



  
    
    

# all the dataset though the SM and NP KDEs
# with this we'll form the toy samples for MLL

KDE_SM_pred_SM = np.exp(kde_bkg.score_samples(np.c_[pred_XG_SM, np.zeros(len(pred_XG_SM)) ]) )
KDE_NP_pred_SM = np.exp(kde_sig.score_samples(np.c_[pred_XG_SM, np.ones(len(pred_XG_SM)) ]) )

# Normalize

KDE_SM_pred_SM = KDE_SM_pred_SM / factor_aux_SM
KDE_NP_pred_SM = KDE_NP_pred_SM / factor_aux_NP




indices = [i for i in range(len(KDE_NP_pred_SM))]


########################
# METHOD: MLL with KDE #
########################

print('\n-------------------------------------')
print(' MLL with KDE')
print('-------------------------------------')




for iii in range(len(SB_ratio)):
    
    print('B_expected: ', B_expected)
    print('S_expected: ', S_expected[iii])
    print(r'S/$\sqrt{B}$: ', SsqrtB[iii])
    print('n_ensembles (initial): ', n_ensembles, '\n')

    
    

    ###########
    # NOW MLL #
    ###########

    # to construct ensembles B and S events are taken from Poisson distributions
    mu = S_expected[iii] + B_expected


    # Letś find the number of events per ensemble such that we get at least one ensemble populated if events are taken from a Poisson distribution

    # around the mean its populated so let's try (proposed range to be checked)
    list_events_per_ensembles = [i for i in range(int(mu*0.9),int(mu*1.1))]
    to_check = len(list_events_per_ensembles)

    # I want at least one ensemble populated
    list_nums_ensembles = [ int( poisson.pmf(list_events_per_ensembles[i],mu)*n_ensembles ) for i in range(len(list_events_per_ensembles)) ]



    # Remove from the list the elements without at least 1 ensemble possible
    for i in range(len(list_events_per_ensembles)):
        if list_nums_ensembles[i] > 1:
            list_events_per_ensembles = list_events_per_ensembles[i:]
            list_nums_ensembles = list_nums_ensembles[i:]
            break


    for i in range(len(list_events_per_ensembles)):
        if list_nums_ensembles[i] < 1:
            list_events_per_ensembles = list_events_per_ensembles[:i]
            list_nums_ensembles = list_nums_ensembles[:i]
            break

    print('\n If ', to_check, ' = ', len(list_events_per_ensembles), '   then the proposed range has to be extended')

    print('n_ensembles (actual): ', sum(list_nums_ensembles))



    # lists of S and B events per ensemble, w.r.t the total of number of events per ensemble found above:

    p_berno = S_expected[iii]/(S_expected[iii]+B_expected)

    list_S_per_ensembles = []
    list_B_per_ensembles = []

    for jj in range(len(list_events_per_ensembles)):
        list_S_per_ensembles.append( int(p_berno * list_events_per_ensembles[jj]) )
        list_B_per_ensembles.append( list_events_per_ensembles[jj] - int(p_berno * list_events_per_ensembles[jj]) )

    ######
    # NOW I HAVE 4 LISTS:
    # list_events_per_ensembles     list with the number of events per ensemble (its a range)
    # list_nums_ensembles           list with the number of ensembles, w.r.t the 1st list
    # list_S_per_ensembles          list with the number of signal events in each ensembles, w.r.t the 1st list
    # list_B_per_ensembles          list with the number of background events in each ensembles, w.r.t the 1st list
    ######



    print('\n This may take long... \n')


    # NOW LETS APPLY THE METHOD

    muhat_selected_list = []
    q_muhat = []
    q_muhat_mu0 = []

    for bb in range(len(list_nums_ensembles)):

        for kk in range(list_nums_ensembles[bb]):

            # KDE
            ran_ind = np.random.choice(indices, list_B_per_ensembles[bb])

            KDE_SM_pred_SM_shuf = []
            KDE_NP_pred_SM_shuf = []

            for i in ran_ind:
                KDE_SM_pred_SM_shuf.append(KDE_SM_pred_SM[i])
                KDE_NP_pred_SM_shuf.append(KDE_NP_pred_SM[i])

            KDE_SM_pred_SM_shuf  = np.array(KDE_SM_pred_SM_shuf)
            KDE_NP_pred_SM_shuf  = np.array(KDE_NP_pred_SM_shuf)



            # p_b(o(x_ensemble)) =    concatenate: p_b(o(B_ensemble)) and p_b(o(S_ensemble))  NOTICE THE o(x)
            prob_x_given_B = np.ndarray.tolist( KDE_SM_pred_SM_shuf ) #+ np.ndarray.tolist( KDE_SM_pred_NP_shuf )

            # p_s(o(x_ensemble)) =    concatenate: p_s(o(B_ensemble)) and p_s(o(S_ensemble))  NOTICE THE o(x)
            prob_x_given_S = np.ndarray.tolist( KDE_NP_pred_SM_shuf ) #+ np.ndarray.tolist( KDE_NP_pred_NP_shuf )









            # NOW WE HAVE p_{s,b}(x_ensemble) for this particular ensemble
            # WE NEED TO ESTIMATE mu_hat for this particular ensemble
            # we are going to obtain a mu_hat with a grid of values for this particular ensemble



            mu_hat_condition_equal_1 = []

            # grid, mu_hat is around 1
            muhat_test = np.arange(0., 1.5, 0.1).tolist()

            B_prob_x_given_B = [x * B_expected for x in prob_x_given_B]

            for vv in range(len(muhat_test)):

                mu_hat_condition_equal_1.append( sum ( [(x*1.) / ( (x * muhat_test[vv] * S_expected[iii]) + y ) for x, y in zip(prob_x_given_S, B_prob_x_given_B)] ) )



            muhat_selected = 0

            # from the grid, select the mu_hat such that the condition is equal to 1
            if mu_hat_condition_equal_1[0] < mu_hat_condition_equal_1[-1]:
                for ll in range(len(mu_hat_condition_equal_1)):
                    if mu_hat_condition_equal_1[ll] -1 > 0:
                        muhat_selected = muhat_test[ll]
                        break


            if mu_hat_condition_equal_1[0] > mu_hat_condition_equal_1[-1]:
                for ll in range(len(mu_hat_condition_equal_1)):
                    if mu_hat_condition_equal_1[ll] -1 < 0:
                        muhat_selected = muhat_test[ll]
                        break


            muhat_selected_list.append(muhat_selected)



            # NOW THAT WE HAVE mu_hat FOR THIS ENSEMBLE, CALCULATE THE TEST STATISTIC FOR THIS ENSEMBLE
            # and append it (we need the median over lots of ensembles)
            #q_muhat.append( 2 * ( (-1.*muhat_selected * S_expected[iii]) + sum( [np.log( 1 + ( (muhat_selected*S_expected[iii]/B_expected) * (x / y) ) ) for x, y in zip(prob_x_given_S, prob_x_given_B)] ) ) )
            # EXCLUSION:
            q_muhat.append( 2 * ( ( (1.-muhat_selected) * S_expected[iii] ) - sum( [np.log( ( (B_expected*y) + (S_expected[iii]*x) ) / ( (B_expected*y) + (muhat_selected*S_expected[iii]*x) ) ) for x, y in zip(prob_x_given_S, prob_x_given_B)] )
    ) )
            q_muhat_mu0.append( 2 * ( ( (1.-0.) * S_expected[iii] ) - sum( [np.log( ( (B_expected*y) + (S_expected[iii]*x) ) / ( (B_expected*y) + (0.*S_expected[iii]*x) ) ) for x, y in zip(prob_x_given_S, prob_x_given_B)] )
    ) )


    # Histogram of q_muhats

    weights = np.ones_like(q_muhat)/float(len(q_muhat))
    nMIX, binsMIX, patchesMIX = plt.hist(q_muhat, 25, weights=weights, histtype='step', color='blue', linewidth=2)
    #plt.xlim(0,1)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.xlabel("$q_0(\hat{\mu})$",fontsize=16)
    plt.ylabel("Fraction of ensembles",fontsize=16)
    plt.title(r"$\bar{B}$=%0.2i, $\bar{S}=$%0.2i" % (B_expected,S_expected[iii]),fontsize=14)
    plt.grid()
    #plt.legend(fontsize=14)
    plt.show()


    # Finally calculate muhat_mean and Z_gaussian

    # Remove nan if any
    q_muhat_mu0 = [x for x in q_muhat_mu0 if x == x]
    for jk in range(len(q_muhat_mu0)):
        if q_muhat_mu0[jk] < 0:
            q_muhat_mu0[jk] = 0

    q_muhat_median_mu0 = np.median(q_muhat_mu0)

    Z_KDE_mu0 = abs(q_muhat_median_mu0)**0.5
    store_Z_MLL_KDE_mu0.append(Z_KDE_mu0)


    # Finally calculate muhat_mean and Z_gaussian
    muhat_mean = np.mean(muhat_selected_list)
    store_muhat_mean_MLL.append(muhat_mean)

    # Remove nan if any
    q_muhat = [x for x in q_muhat if x == x]
    for jk in range(len(q_muhat)):
        if q_muhat[jk] < 0:
            q_muhat[jk] = 0

    q_muhat_median = np.median(q_muhat)

    Z_KDE = abs(q_muhat_median)**0.5
    store_Z_MLL_KDE.append(Z_KDE)

    print('muhat mean: ', muhat_mean)
    print('median q_muhat: ', q_muhat_median)
    print('Z_KDE: ', Z_KDE)
    print('Z_KDE mu=0: ', Z_KDE_mu0)
    
    print('\n ----------------------------------------- \n')
# Out:
# [1.00000000e-03 1.44719254e-03 2.09436625e-03 3.03095122e-03
#  4.38637001e-03 6.34792196e-03 9.18666532e-03 1.32948735e-02
#  1.92402418e-02 2.78443345e-02 4.02961132e-02 5.83162345e-02
#  8.43948197e-02 1.22135554e-01 1.76753662e-01 2.55796582e-01
#  3.70186906e-01 5.35731729e-01 7.75306963e-01 1.12201845e+00]
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [          -inf 16139.84379138 16156.39660469 16165.29124561
#  16169.99752876 16164.10456858 16137.43080765 16055.07965609
#  15849.29420129 15431.38841953 14751.78719702 13796.21408453
#  12550.5258979  11007.75962382  9120.81309574  6904.19110268
#   4401.71722829  1636.18945929 -1298.78574469 -4412.24431798]
#   warnings.warn(
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:929: RuntimeWarning: invalid value encountered in subtract
#   array_stds = np.sqrt(np.average((array -
# KernelDensity(bandwidth=0.004386370005779536, kernel='epanechnikov')
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [          -inf           -inf           -inf           -inf
#            -inf           -inf 22992.44621164 22084.8139412
#  20824.73526404 19200.92643877 17243.24836814 15030.8673985
#  12632.06317418 10075.94371177  7417.50008251  4682.94738804
#   1887.11546906  -991.98855181 -3782.18966379 -5537.41477382]
#   warnings.warn(
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:929: RuntimeWarning: invalid value encountered in subtract
#   array_stds = np.sqrt(np.average((array -
# KernelDensity(bandwidth=0.0091866653175426, kernel='epanechnikov')
# -------------------------------------
#  MLL with KDE
# -------------------------------------
# B_expected:  5000
# S_expected:  2
# S/$\sqrt{B}$:  0.0282842712474619
# n_ensembles (initial):  5000
#
#
#  If  1001  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4759
#
#  This may take long...
# muhat mean:  0.09550325698676193
# median q_muhat:  0.5098447088375044
# Z_KDE:  0.7140341090154618
# Z_KDE mu=0:  0.7140341090154618
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  5
# S/$\sqrt{B}$:  0.07071067811865475
# n_ensembles (initial):  5000
#
#
#  If  1001  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4757
#
#  This may take long...
# muhat mean:  0.1252259827622451
# median q_muhat:  1.6626122009732551
# Z_KDE:  1.2894232047598861
# Z_KDE mu=0:  1.2894232047598861
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  8
# S/$\sqrt{B}$:  0.1131370849898476
# n_ensembles (initial):  5000
#
#
#  If  1001  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4757
#
#  This may take long...
# muhat mean:  0.11391633382383855
# median q_muhat:  3.0917752476882185
# Z_KDE:  1.7583444621826005
# Z_KDE mu=0:  1.7583444621826005
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  12
# S/$\sqrt{B}$:  0.1697056274847714
# n_ensembles (initial):  5000
#
#
#  If  1003  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4757
#
#  This may take long...
# muhat mean:  0.08295143998318269
# median q_muhat:  5.480405223627397
# Z_KDE:  2.3410265320212407
# Z_KDE mu=0:  2.3410265320212407
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  25
# S/$\sqrt{B}$:  0.35355339059327373
# n_ensembles (initial):  5000
#
#
#  If  1005  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4753
#
#  This may take long...
# muhat mean:  0.049358300021039345
# median q_muhat:  15.028388391041837
# Z_KDE:  3.8766465393483887
# Z_KDE mu=0:  3.8766465393483887
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  37
# S/$\sqrt{B}$:  0.5232590180780452
# n_ensembles (initial):  5000
#
#
#  If  1007  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4751
#
#  This may take long...
# muhat mean:  0.03976005051568091
# median q_muhat:  25.71617879940692
# Z_KDE:  5.071112185645958
# Z_KDE mu=0:  5.071112185645958
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  50
# S/$\sqrt{B}$:  0.7071067811865475
# n_ensembles (initial):  5000
#
#
#  If  1010  =  347    then the proposed range has to be extended
# n_ensembles (actual):  4754
#
#  This may take long...
# muhat mean:  0.03388725283971392
# median q_muhat:  39.019434334048896
# Z_KDE:  6.246553796618492
# Z_KDE mu=0:  6.246553796618492
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  125
# S/$\sqrt{B}$:  1.7677669529663687
# n_ensembles (initial):  5000
#
#
#  If  1025  =  349    then the proposed range has to be extended
# n_ensembles (actual):  4744
#
#  This may take long...
# muhat mean:  0.026939291736930857
# median q_muhat:  128.77538791729978
# Z_KDE:  11.347924388067616
# Z_KDE mu=0:  11.347924388067616
#
#  -----------------------------------------

# %%
print(store_Z_MLL_KDE)
print(store_Z_MLL_KDE_mu0)

print(store_muhat_mean_MLL)
# Out:
# [0.7140341090154618, 1.2894232047598861, 1.7583444621826005, 2.3410265320212407, 3.8766465393483887, 5.071112185645958, 6.246553796618492, 11.347924388067616]
# [0.7140341090154618, 1.2894232047598861, 1.7583444621826005, 2.3410265320212407, 3.8766465393483887, 5.071112185645958, 6.246553796618492, 11.347924388067616]
# [0.09550325698676193, 0.1252259827622451, 0.11391633382383855, 0.08295143998318269, 0.049358300021039345, 0.03976005051568091, 0.03388725283971392, 0.026939291736930857]

# %%
store_Z_MLL_KDE = [0.7140341090154618, 1.2894232047598861, 1.7583444621826005, 2.3410265320212407, 3.8766465393483887, 5.071112185645958, 6.246553796618492, 11.347924388067616]
store_Z_MLL_KDE_mu0 = [0.7140341090154618, 1.2894232047598861, 1.7583444621826005, 2.3410265320212407, 3.8766465393483887, 5.071112185645958, 6.246553796618492, 11.347924388067616]

store_muhat_mean_MLL = [0.09550325698676193, 0.1252259827622451, 0.11391633382383855, 0.08295143998318269, 0.049358300021039345, 0.03976005051568091, 0.03388725283971392, 0.026939291736930857]

# %% [markdown]
# ##### For 1 ML

# %%
store_Z_KDE_bins = []

store_Z_MLL_KDE_1ML = []
store_Z_MLL_KDE_mu0_1ML = []

store_muhat_mean_MLL_1ML = []




# FIND THE BANDWIDTH

# bandwidth = np.logspace(-3.0, 0.05, 20)
# print(bandwidth)

# kde = KernelDensity(kernel='epanechnikov')
# grid = GridSearchCV(kde, {'bandwidth': bandwidth})
# grid.fit(np.c_[pred_XG_SM_1ML[:50000]])
# print(grid.best_estimator_)

# SM_bandwidth_1ML = grid.best_estimator_.bandwidth
SM_bandwidth_1ML = 0.004386370005779536


# kde = KernelDensity(kernel='epanechnikov')
# grid = GridSearchCV(kde, {'bandwidth': bandwidth})
# grid.fit(np.c_[pred_XG_NP_1ML[:50000]])
# print(grid.best_estimator_)

# NP_bandwidth_1ML = grid.best_estimator_.bandwidth
NP_bandwidth_1ML = 0.0091866653175426






# aca fitteo 
kde_bkg_1ML = KernelDensity(kernel="epanechnikov", bandwidth=SM_bandwidth_1ML).fit(np.c_[pred_XG_SM_1ML, np.zeros(len(pred_XG_SM_1ML)) ])
kde_sig_1ML = KernelDensity(kernel="epanechnikov", bandwidth=NP_bandwidth_1ML).fit(np.c_[pred_XG_NP_1ML, np.ones(len(pred_XG_NP_1ML)) ])


# elijo los valores para graficar y calcular la significancia de Asimov
min_val_1ML = np.min([np.min(pred_XG_SM_1ML),np.min(pred_XG_NP_1ML)])
max_val_1ML = np.max([np.max(pred_XG_SM_1ML),np.max(pred_XG_NP_1ML)])

s_vals_1ML = np.linspace(min_val_1ML,max_val_1ML,100)





# evaluo las densidades en cada valor de s. esto es mas o menos equivalente a tomar bines continuos
dens_bkg_1ML = np.exp(kde_bkg_1ML.score_samples(np.c_[s_vals_1ML, np.zeros(len(s_vals_1ML)) ]) )
dens_sig_1ML = np.exp(kde_sig_1ML.score_samples(np.c_[s_vals_1ML, np.ones(len(s_vals_1ML)) ]) )





# PERO NO ESTA NORMALIZADO A 1 el area
# Area
factor_aux_SM_1ML = sum(dens_bkg_1ML*(s_vals_1ML[1]-s_vals_1ML[0]))
factor_aux_NP_1ML = sum(dens_sig_1ML*(s_vals_1ML[1]-s_vals_1ML[0]))

# normalizo
dens_bkg_1ML = dens_bkg_1ML / factor_aux_SM_1ML
dens_sig_1ML = dens_sig_1ML / factor_aux_NP_1ML






# grafico y verifico si la densidad es una buena aproximacion

plt.figure()

plt.hist(pred_XG_SM_1ML,density=True,bins=100,color='red',alpha=0.25,label='Sampled $p_{b}$');
plt.plot(s_vals_1ML,dens_bkg_1ML,color='red',label='Learned $p_{b}$',linestyle='dashed');

plt.hist(pred_XG_NP_1ML,density=True,bins=100,color='blue',alpha=0.25,label='Sampled $p_{s}$');
plt.plot(s_vals_1ML,dens_sig_1ML,color='blue',label='Learned $p_{s}$',linestyle='dashed');

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("o(x)",fontsize=15)
plt.ylabel("PDF",fontsize=14)
plt.grid()
plt.legend(fontsize=12)
#plt.title(r"Signal: W'$\rightarrow$XY, Background: QCD", fontsize=14)
#plt.savefig('images/' + 'Wprime-output.pdf', format="pdf", bbox_inches="tight")
plt.show()



  
    
    

# all the dataset though the SM and NP KDEs
# with this we'll form the toy samples for MLL

KDE_SM_pred_SM_1ML = np.exp(kde_bkg_1ML.score_samples(np.c_[pred_XG_SM_1ML, np.zeros(len(pred_XG_SM_1ML)) ]) )
KDE_NP_pred_SM_1ML = np.exp(kde_sig_1ML.score_samples(np.c_[pred_XG_SM_1ML, np.ones(len(pred_XG_SM_1ML)) ]) )

# Normalize

KDE_SM_pred_SM_1ML = KDE_SM_pred_SM_1ML / factor_aux_SM_1ML
KDE_NP_pred_SM_1ML = KDE_NP_pred_SM_1ML / factor_aux_NP_1ML





indices = [i for i in range(len(KDE_NP_pred_SM))]


########################
# METHOD: MLL with KDE #
########################

print('\n-------------------------------------')
print(' MLL with KDE')
print('-------------------------------------')




for iii in range(len(SB_ratio)):
    
    print('B_expected: ', B_expected)
    print('S_expected: ', S_expected[iii])
    print(r'S/$\sqrt{B}$: ', SsqrtB[iii])
    print('n_ensembles (initial): ', n_ensembles, '\n')
    
    
    ####################
    # 1st a binned KDE #
    ####################
    
    # Bd: binned KDE background
    Bd = B_expected*dens_bkg_1ML*(s_vals_1ML[1]-s_vals_1ML[0])




    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    Bd_noceros = []
    for i in range(len(Bd)):
        if Bd[i]!=0:
            Bd_noceros.append(Bd[i])

    min_back = min(Bd_noceros)

    # replace the zeros
    for i in range(len(Bd)):
        if Bd[i]==0:
            Bd[i] = min_back


    # Sd: binned KDE signal
    Sd = SsqrtB[iii]*np.sqrt(B_expected)*dens_sig_1ML*(s_vals_1ML[1]-s_vals_1ML[0])

    #Z_KDE_bins = np.sqrt(2.0*np.sum(((Sd+Bd)*np.log(1.0+Sd/Bd)-Sd))) # Discovery
    Z_KDE_bins = np.sqrt(2.0*np.sum(Bd*np.log(Bd/(Sd+Bd))+Sd)) # Exclusion

    store_Z_KDE_bins.append(Z_KDE_bins)

    print('Z_KDE_bins : ', Z_KDE_bins)
    
    

    ###########
    # NOW MLL #
    ###########

    # to construct ensembles B and S events are taken from Poisson distributions
    mu = S_expected[iii] + B_expected


    # Letś find the number of events per ensemble such that we get at least one ensemble populated if events are taken from a Poisson distribution

    # around the mean its populated so let's try (proposed range to be checked)
    list_events_per_ensembles = [i for i in range(int(mu*0.9),int(mu*1.1))]
    to_check = len(list_events_per_ensembles)

    # I want at least one ensemble populated
    list_nums_ensembles = [ int( poisson.pmf(list_events_per_ensembles[i],mu)*n_ensembles ) for i in range(len(list_events_per_ensembles)) ]



    # Remove from the list the elements without at least 1 ensemble possible
    for i in range(len(list_events_per_ensembles)):
        if list_nums_ensembles[i] > 1:
            list_events_per_ensembles = list_events_per_ensembles[i:]
            list_nums_ensembles = list_nums_ensembles[i:]
            break


    for i in range(len(list_events_per_ensembles)):
        if list_nums_ensembles[i] < 1:
            list_events_per_ensembles = list_events_per_ensembles[:i]
            list_nums_ensembles = list_nums_ensembles[:i]
            break

    print('\n If ', to_check, ' = ', len(list_events_per_ensembles), '   then the proposed range has to be extended')

    print('n_ensembles (actual): ', sum(list_nums_ensembles))



    # lists of S and B events per ensemble, w.r.t the total of number of events per ensemble found above:

    p_berno = S_expected[iii]/(S_expected[iii]+B_expected)

    list_S_per_ensembles = []
    list_B_per_ensembles = []

    for jj in range(len(list_events_per_ensembles)):
        list_S_per_ensembles.append( int(p_berno * list_events_per_ensembles[jj]) )
        list_B_per_ensembles.append( list_events_per_ensembles[jj] - int(p_berno * list_events_per_ensembles[jj]) )

    ######
    # NOW I HAVE 4 LISTS:
    # list_events_per_ensembles     list with the number of events per ensemble (its a range)
    # list_nums_ensembles           list with the number of ensembles, w.r.t the 1st list
    # list_S_per_ensembles          list with the number of signal events in each ensembles, w.r.t the 1st list
    # list_B_per_ensembles          list with the number of background events in each ensembles, w.r.t the 1st list
    ######



    print('\n This may take long... \n')


    # NOW LETS APPLY THE METHOD

    muhat_selected_list = []
    q_muhat = []
    q_muhat_mu0 = []

    for bb in range(len(list_nums_ensembles)):

        for kk in range(list_nums_ensembles[bb]):

            # KDE
            ran_ind = np.random.choice(indices, list_B_per_ensembles[bb])

            KDE_SM_pred_SM_shuf = []
            KDE_NP_pred_SM_shuf = []

            for i in ran_ind:
                KDE_SM_pred_SM_shuf.append(KDE_SM_pred_SM_1ML[i])
                KDE_NP_pred_SM_shuf.append(KDE_NP_pred_SM_1ML[i])

            KDE_SM_pred_SM_shuf  = np.array(KDE_SM_pred_SM_shuf)
            KDE_NP_pred_SM_shuf  = np.array(KDE_NP_pred_SM_shuf)



            # p_b(o(x_ensemble)) =    concatenate: p_b(o(B_ensemble)) and p_b(o(S_ensemble))  NOTICE THE o(x)
            prob_x_given_B = np.ndarray.tolist( KDE_SM_pred_SM_shuf ) #+ np.ndarray.tolist( KDE_SM_pred_NP_shuf )

            # p_s(o(x_ensemble)) =    concatenate: p_s(o(B_ensemble)) and p_s(o(S_ensemble))  NOTICE THE o(x)
            prob_x_given_S = np.ndarray.tolist( KDE_NP_pred_SM_shuf ) #+ np.ndarray.tolist( KDE_NP_pred_NP_shuf )









            # NOW WE HAVE p_{s,b}(x_ensemble) for this particular ensemble
            # WE NEED TO ESTIMATE mu_hat for this particular ensemble
            # we are going to obtain a mu_hat with a grid of values for this particular ensemble



            mu_hat_condition_equal_1 = []

            # grid, mu_hat is around 1
            muhat_test = np.arange(0., 1.5, 0.1).tolist()

            B_prob_x_given_B = [x * B_expected for x in prob_x_given_B]

            for vv in range(len(muhat_test)):

                mu_hat_condition_equal_1.append( sum ( [(x*1.) / ( (x * muhat_test[vv] * S_expected[iii]) + y ) for x, y in zip(prob_x_given_S, B_prob_x_given_B)] ) )



            muhat_selected = 0

            # from the grid, select the mu_hat such that the condition is equal to 1
            if mu_hat_condition_equal_1[0] < mu_hat_condition_equal_1[-1]:
                for ll in range(len(mu_hat_condition_equal_1)):
                    if mu_hat_condition_equal_1[ll] -1 > 0:
                        muhat_selected = muhat_test[ll]
                        break


            if mu_hat_condition_equal_1[0] > mu_hat_condition_equal_1[-1]:
                for ll in range(len(mu_hat_condition_equal_1)):
                    if mu_hat_condition_equal_1[ll] -1 < 0:
                        muhat_selected = muhat_test[ll]
                        break


            muhat_selected_list.append(muhat_selected)



            # NOW THAT WE HAVE mu_hat FOR THIS ENSEMBLE, CALCULATE THE TEST STATISTIC FOR THIS ENSEMBLE
            # and append it (we need the median over lots of ensembles)
            #q_muhat.append( 2 * ( (-1.*muhat_selected * S_expected[iii]) + sum( [np.log( 1 + ( (muhat_selected*S_expected[iii]/B_expected) * (x / y) ) ) for x, y in zip(prob_x_given_S, prob_x_given_B)] ) ) )
            # EXCLUSION:
            q_muhat.append( 2 * ( ( (1.-muhat_selected) * S_expected[iii] ) - sum( [np.log( ( (B_expected*y) + (S_expected[iii]*x) ) / ( (B_expected*y) + (muhat_selected*S_expected[iii]*x) ) ) for x, y in zip(prob_x_given_S, prob_x_given_B)] )
    ) )
            q_muhat_mu0.append( 2 * ( ( (1.-0.) * S_expected[iii] ) - sum( [np.log( ( (B_expected*y) + (S_expected[iii]*x) ) / ( (B_expected*y) + (0.*S_expected[iii]*x) ) ) for x, y in zip(prob_x_given_S, prob_x_given_B)] )
    ) )


    # Histogram of q_muhats

    weights = np.ones_like(q_muhat)/float(len(q_muhat))
    nMIX, binsMIX, patchesMIX = plt.hist(q_muhat, 25, weights=weights, histtype='step', color='blue', linewidth=2)
    #plt.xlim(0,1)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.xlabel("$q_0(\hat{\mu})$",fontsize=16)
    plt.ylabel("Fraction of ensembles",fontsize=16)
    plt.title(r"$\bar{B}$=%0.2i, $\bar{S}=$%0.2i" % (B_expected,S_expected[iii]),fontsize=14)
    plt.grid()
    #plt.legend(fontsize=14)
    plt.show()


    # Finally calculate muhat_mean and Z_gaussian

    # Remove nan if any
    q_muhat_mu0 = [x for x in q_muhat_mu0 if x == x]

    q_muhat_median_mu0 = np.median(q_muhat_mu0)

    Z_KDE_mu0 = abs(q_muhat_median_mu0)**0.5
    store_Z_MLL_KDE_mu0_1ML.append(Z_KDE_mu0)


    # Finally calculate muhat_mean and Z_gaussian
    muhat_mean = np.mean(muhat_selected_list)
    store_muhat_mean_MLL_1ML.append(muhat_mean)

    # Remove nan if any
    q_muhat = [x for x in q_muhat if x == x]

    q_muhat_median = np.median(q_muhat)

    Z_KDE = abs(q_muhat_median)**0.5
    store_Z_MLL_KDE_1ML.append(Z_KDE)

    print('muhat mean: ', muhat_mean)
    print('median q_muhat: ', q_muhat_median)
    print('Z_KDE: ', Z_KDE)
    print('Z_KDE mu=0: ', Z_KDE_mu0)
    
    print('\n ----------------------------------------- \n')
# Out:
# -------------------------------------
#  MLL with KDE
# -------------------------------------
# B_expected:  5000
# S_expected:  2
# S/$\sqrt{B}$:  0.0282842712474619
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  0.380887774399524
#
#  If  1001  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4759
#
#  This may take long...
# muhat mean:  0.08194998949359109
# median q_muhat:  0.5561679040119918
# Z_KDE:  0.7457666552025451
# Z_KDE mu=0:  0.7457666552025451
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  5
# S/$\sqrt{B}$:  0.07071067811865475
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  0.9075761659037421
#
#  If  1001  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4757
#
#  This may take long...
# muhat mean:  0.12701282320790416
# median q_muhat:  1.6722965197281106
# Z_KDE:  1.2931730432266637
# Z_KDE mu=0:  1.2931730432266637
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  8
# S/$\sqrt{B}$:  0.1131370849898476
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  1.3913311722164903
#
#  If  1001  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4757
#
#  This may take long...
# muhat mean:  0.10691612360731553
# median q_muhat:  3.2106638408737354
# Z_KDE:  1.791832537061914
# Z_KDE mu=0:  1.791832537061914
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  12
# S/$\sqrt{B}$:  0.1697056274847714
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  1.9838617643279686
#
#  If  1003  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4757
#
#  This may take long...
# muhat mean:  0.08290939667857894
# median q_muhat:  5.384826629817944
# Z_KDE:  2.320522921631662
# Z_KDE mu=0:  2.320522921631662
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  25
# S/$\sqrt{B}$:  0.35355339059327373
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  3.62504604441952
#
#  If  1005  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4753
#
#  This may take long...
# muhat mean:  0.05125184094256258
# median q_muhat:  15.032812459921011
# Z_KDE:  3.8772171025003246
# Z_KDE mu=0:  3.8772171025003246
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  37
# S/$\sqrt{B}$:  0.5232590180780452
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  4.890421135393516
#
#  If  1007  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4751
#
#  This may take long...
# muhat mean:  0.03668701326036624
# median q_muhat:  25.952702356486157
# Z_KDE:  5.0943794868939785
# Z_KDE mu=0:  5.0943794868939785
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  50
# S/$\sqrt{B}$:  0.7071067811865475
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  6.090033582565752
#
#  If  1010  =  347    then the proposed range has to be extended
# n_ensembles (actual):  4754
#
#  This may take long...
# muhat mean:  0.031994110222970135
# median q_muhat:  39.28317645101218
# Z_KDE:  6.267629252836529
# Z_KDE mu=0:  6.267629252836529
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  125
# S/$\sqrt{B}$:  1.7677669529663687
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  11.288360955856305
#
#  If  1025  =  349    then the proposed range has to be extended
# n_ensembles (actual):  4744
#
#  This may take long...
# muhat mean:  0.02521079258010118
# median q_muhat:  129.19270078983627
# Z_KDE:  11.366296705164627
# Z_KDE mu=0:  11.366296705164627
#
#  -----------------------------------------

# %%
print(store_Z_KDE_bins)

print(store_Z_MLL_KDE_1ML)
print(store_Z_MLL_KDE_mu0_1ML)

print(store_muhat_mean_MLL_1ML)
# Out:
# [0.380887774399524, 0.9075761659037421, 1.3913311722164903, 1.9838617643279686, 3.62504604441952, 4.890421135393516, 6.090033582565752, 11.288360955856305]
# [0.7457666552025451, 1.2931730432266637, 1.791832537061914, 2.320522921631662, 3.8772171025003246, 5.0943794868939785, 6.267629252836529, 11.366296705164627]
# [0.7457666552025451, 1.2931730432266637, 1.791832537061914, 2.320522921631662, 3.8772171025003246, 5.0943794868939785, 6.267629252836529, 11.366296705164627]
# [0.08194998949359109, 0.12701282320790416, 0.10691612360731553, 0.08290939667857894, 0.05125184094256258, 0.03668701326036624, 0.031994110222970135, 0.02521079258010118]

# %%
store_Z_KDE_bins = [0.380887774399524, 0.9075761659037421, 1.3913311722164903, 1.9838617643279686, 3.62504604441952, 4.890421135393516, 6.090033582565752, 11.288360955856305]

store_Z_MLL_KDE_1ML = [0.7457666552025451, 1.2931730432266637, 1.791832537061914, 2.320522921631662, 3.8772171025003246, 5.0943794868939785, 6.267629252836529, 11.366296705164627]
store_Z_MLL_KDE_mu0_1ML = [0.7457666552025451, 1.2931730432266637, 1.791832537061914, 2.320522921631662, 3.8772171025003246, 5.0943794868939785, 6.267629252836529, 11.366296705164627]

store_muhat_mean_MLL_1ML = [0.08194998949359109, 0.12701282320790416, 0.10691612360731553, 0.08290939667857894, 0.05125184094256258, 0.03668701326036624, 0.031994110222970135, 0.02521079258010118]

# %%
#########
# PLOTS #
#########

posX = []

for i in range(len(SB_ratio)):
    posX.append( (B_expected*SB_ratio[i]) / ( B_expected )**0.5 )




plt.figure()
lw = 2

plt.plot(posX, store_muhat_mean_MLL, '-ok', color='red', lw=lw, label='mu_hat XGBoost (10ML)')
plt.plot(posX, store_muhat_mean_MLL_1ML, '-ok', color='blue', lw=lw, label='mu_hat XGBoost (1ML)')

#plt.xlim([0.5, 100])
#plt.ylim([-0.5, 7.5])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=14)
plt.ylabel(r'$\hat{\mu}$', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title('<B> per ensemble: %0.2d' % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()






plt.figure()
lw = 2

plt.plot(posX, store_Z_bins, ':ok', color='blue', lw=lw, label='100 Linear Binned Likelihood') 
plt.plot(posX, store_Z_bins_logbins, ':ok', color='lightblue', lw=lw, label='15 Log Binned Likelihood') 
plt.plot(posX, store_Z_bins_XG, '--ok', color='green', lw=lw, label='o(x) BL (100 l.bins)') 
plt.plot(posX, store_Z_bins_XG_15bins, '-ok', color='navy', lw=lw, label='o(x) BL (15 l.bins) (10ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_1ML, '-ok', color='green', lw=lw, label='o(x) BL (15 l.bins) (1ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_eq, '-ok', color='magenta', lw=lw, label='o(x) BL (15 n.l.bins) (10ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_eq_1ML, '-ok', color='darkorange', lw=lw, label='o(x) BL (15 n.l.bins) (1ML)') 
plt.plot(posX, store_Z_MLL_KDE, '-ok', color='red', lw=3, label=r'MLL KDE (10ML)')
plt.plot(posX, store_Z_MLL_KDE_1ML, '--ok', color='lightcoral', lw=3, label=r'MLL KDE (1ML)')
#plt.plot(posX, store_Z_MLL_KDE_mu0, '-ok', color='pink', lw=3, label=r'MLL KDE (XGBoost) muhat=0')
#plt.plot(posX, store_Z_KDE_bins, '-ok', color='magenta', lw=3, label=r'100 Bins KDE')

#plt.xlim([0.5, 10])
#plt.ylim([-0.5, 7.5])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=14)
plt.ylabel('$Z_{\mu}$ (exclusion)', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title('<B> per ensemble: %0.2d' % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()
# Out:
# <ipython-input-57-8bc2cdbd1b25>:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_muhat_mean_MLL, '-ok', color='red', lw=lw, label='mu_hat XGBoost (10ML)')
# <ipython-input-57-8bc2cdbd1b25>:17: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_muhat_mean_MLL_1ML, '-ok', color='blue', lw=lw, label='mu_hat XGBoost (1ML)')
# <ipython-input-57-8bc2cdbd1b25>:39: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string ":ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins, ':ok', color='blue', lw=lw, label='100 Linear Binned Likelihood')
# <ipython-input-57-8bc2cdbd1b25>:40: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string ":ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_logbins, ':ok', color='lightblue', lw=lw, label='15 Log Binned Likelihood')
# <ipython-input-57-8bc2cdbd1b25>:41: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "--ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG, '--ok', color='green', lw=lw, label='o(x) BL (100 l.bins)')
# <ipython-input-57-8bc2cdbd1b25>:42: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins, '-ok', color='navy', lw=lw, label='o(x) BL (15 l.bins) (10ML)')
# <ipython-input-57-8bc2cdbd1b25>:43: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_1ML, '-ok', color='green', lw=lw, label='o(x) BL (15 l.bins) (1ML)')
# <ipython-input-57-8bc2cdbd1b25>:44: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_eq, '-ok', color='magenta', lw=lw, label='o(x) BL (15 n.l.bins) (10ML)')
# <ipython-input-57-8bc2cdbd1b25>:45: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_eq_1ML, '-ok', color='darkorange', lw=lw, label='o(x) BL (15 n.l.bins) (1ML)')
# <ipython-input-57-8bc2cdbd1b25>:46: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_MLL_KDE, '-ok', color='red', lw=3, label=r'MLL KDE (10ML)')
# <ipython-input-57-8bc2cdbd1b25>:47: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "--ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_MLL_KDE_1ML, '--ok', color='lightcoral', lw=3, label=r'MLL KDE (1ML)')

# %% [markdown]
# ### 4.Working points, counting over 1 bin

# %%
WP = [0.25, 0.5, 0.75]

S_expected = [int(SB_ratio[i]*B_expected) for i in range(len(SB_ratio))]

print(S_expected)
# Out:
# [2, 5, 8, 12, 25, 37, 50, 125]

# %%
# XGBoost #

SrootB_WP0_XG = []
SrootB_WP1_XG = []
SrootB_WP2_XG = []


# number of background ensembles
B_ensembles = int(len(pred_XG_SM)/B_expected)

# shorten the number of B events so I get an integer number of ensembles
pred_XG_SM_entero = pred_XG_SM[:int(len(pred_XG_SM)/B_expected) * B_expected]

XG_SM_passWP0 = 0
XG_SM_passWP1 = 0
XG_SM_passWP2 = 0

for i in range(len(pred_XG_SM_entero)):
    if pred_XG_SM_entero[i] > WP[0]:
        XG_SM_passWP0 += 1
    if pred_XG_SM_entero[i] > WP[1]:
        XG_SM_passWP1 += 1
    if pred_XG_SM_entero[i] > WP[2]:
        XG_SM_passWP2 += 1



# SIGNAL

for j in range(len(S_expected)):
    
    # number of signal ensembles
    S_ensembles = int(len(pred_XG_NP)/S_expected[j])

    # shorten the number of S events so I get an integer number of ensembles
    pred_XG_NP_entero = pred_XG_NP[:int(len(pred_XG_NP)/S_expected[j]) * S_expected[j]]

    XG_NP_passWP0 = 0
    XG_NP_passWP1 = 0
    XG_NP_passWP2 = 0

    for i in range(len(pred_XG_NP_entero)):
        if pred_XG_NP_entero[i] > WP[0]:
            XG_NP_passWP0 += 1
        if pred_XG_NP_entero[i] > WP[1]:
            XG_NP_passWP1 += 1
        if pred_XG_NP_entero[i] > WP[2]:
            XG_NP_passWP2 += 1

            
    # save the results Z_binned after WP
    SrootB_WP0_XG.append( ( XG_NP_passWP0 / S_ensembles ) / ( XG_SM_passWP0 / B_ensembles )**0.5 )
    SrootB_WP1_XG.append( ( XG_NP_passWP1 / S_ensembles ) / ( XG_SM_passWP1 / B_ensembles )**0.5 )
    SrootB_WP2_XG.append( ( XG_NP_passWP2 / S_ensembles ) / ( XG_SM_passWP2 / B_ensembles )**0.5 )
    
    print('S_expected = ', S_expected[j])
    print('WP: 0     S/B**0.5= ', S_expected[j]/(B_expected)**0.5)
    print('WP: ', WP[0], '    S/B**0.5= ', SrootB_WP0_XG[j] )
    print('WP: ', WP[1], '    S/B**0.5= ', SrootB_WP1_XG[j] )
    print('WP: ', WP[2], '    S/B**0.5= ', SrootB_WP2_XG[j] )
    print('------------------------')
    print('')
    
print('SrootB_WP0_XG: ', SrootB_WP0_XG)
print('SrootB_WP1_XG: ', SrootB_WP1_XG)
print('SrootB_WP2_XG: ', SrootB_WP2_XG)
# Out:
# S_expected =  2
# WP: 0     S/B**0.5=  0.0282842712474619
# WP:  0.25     S/B**0.5=  0.07773264243674997
# WP:  0.5     S/B**0.5=  0.12398731336333728
# WP:  0.75     S/B**0.5=  0.17688557986238523
# ------------------------
#
# S_expected =  5
# WP: 0     S/B**0.5=  0.07071067811865475
# WP:  0.25     S/B**0.5=  0.19433151957664183
# WP:  0.5     S/B**0.5=  0.3099680856466041
# WP:  0.75     S/B**0.5=  0.4422135921277735
# ------------------------
#
# S_expected =  8
# WP: 0     S/B**0.5=  0.1131370849898476
# WP:  0.25     S/B**0.5=  0.31093001604287196
# WP:  0.5     S/B**0.5=  0.49594798776304966
# WP:  0.75     S/B**0.5=  0.7075400312417034
# ------------------------
#
# S_expected =  12
# WP: 0     S/B**0.5=  0.1697056274847714
# WP:  0.25     S/B**0.5=  0.4663941934815711
# WP:  0.5     S/B**0.5=  0.743920083048447
# WP:  0.75     S/B**0.5=  1.0613117125629508
# ------------------------
#
# S_expected =  25
# WP: 0     S/B**0.5=  0.35355339059327373
# WP:  0.25     S/B**0.5=  0.971651108825952
# WP:  0.5     S/B**0.5=  1.5498255951544688
# WP:  0.75     S/B**0.5=  2.2110517657372233
# ------------------------
#
# S_expected =  37
# WP: 0     S/B**0.5=  0.5232590180780452
# WP:  0.25     S/B**0.5=  1.4380468424585504
# WP:  0.5     S/B**0.5=  2.2937491987730487
# WP:  0.75     S/B**0.5=  3.2723698428942387
# ------------------------
#
# S_expected =  50
# WP: 0     S/B**0.5=  0.7071067811865475
# WP:  0.25     S/B**0.5=  1.943302217651904
# WP:  0.5     S/B**0.5=  3.0996511903089377
# WP:  0.75     S/B**0.5=  4.422103531474447
# ------------------------
#
# S_expected =  125
# WP: 0     S/B**0.5=  1.7677669529663687
# WP:  0.25     S/B**0.5=  4.858233673842223
# WP:  0.5     S/B**0.5=  7.749096160724762
# WP:  0.75     S/B**0.5=  11.05518360861262
# ------------------------
#
# SrootB_WP0_XG:  [0.07773264243674997, 0.19433151957664183, 0.31093001604287196, 0.4663941934815711, 0.971651108825952, 1.4380468424585504, 1.943302217651904, 4.858233673842223]
# SrootB_WP1_XG:  [0.12398731336333728, 0.3099680856466041, 0.49594798776304966, 0.743920083048447, 1.5498255951544688, 2.2937491987730487, 3.0996511903089377, 7.749096160724762]
# SrootB_WP2_XG:  [0.17688557986238523, 0.4422135921277735, 0.7075400312417034, 1.0613117125629508, 2.2110517657372233, 3.2723698428942387, 4.422103531474447, 11.05518360861262]

# %%
# To use if you dont want to run everything again. Its the previous results
SrootB_WP0_XG = [0.07773264243674997, 0.19433151957664183, 0.31093001604287196, 0.4663941934815711, 0.971651108825952, 1.4380468424585504, 1.943302217651904, 4.858233673842223]
SrootB_WP1_XG = [0.12398731336333728, 0.3099680856466041, 0.49594798776304966, 0.743920083048447, 1.5498255951544688, 2.2937491987730487, 3.0996511903089377, 7.749096160724762]
SrootB_WP2_XG = [0.17688557986238523, 0.4422135921277735, 0.7075400312417034, 1.0613117125629508, 2.2110517657372233, 3.2723698428942387, 4.422103531474447, 11.05518360861262]

# %%
#########
# PLOTS #
#########

posX = []

for i in range(len(SB_ratio)):
    posX.append( (B_expected*SB_ratio[i]) / ( B_expected )**0.5 )



plt.figure()
lw = 2

plt.plot(posX, store_Z_bins, ':ok', color='blue', lw=lw, label='100 Linear Binned Likelihood') 
plt.plot(posX, store_Z_bins_logbins, ':ok', color='lightblue', lw=lw, label='15 Log Binned Likelihood') 
plt.plot(posX, store_Z_bins_XG, '--ok', color='green', lw=lw, label='o(x) BL (100 l.bins)') 
plt.plot(posX, store_Z_bins_XG_15bins, '-ok', color='navy', lw=lw, label='o(x) BL (15 l.bins) (10ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_1ML, '-ok', color='green', lw=lw, label='o(x) BL (15 l.bins) (1ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_eq, '-ok', color='magenta', lw=lw, label='o(x) BL (15 n.l.bins) (10ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_eq_1ML, '-ok', color='darkorange', lw=lw, label='o(x) BL (15 n.l.bins) (1ML)') 
plt.plot(posX, store_Z_MLL_KDE, '-ok', color='red', lw=3, label=r'MLL KDE (10ML)')
plt.plot(posX, store_Z_MLL_KDE_1ML, '--ok', color='lightcoral', lw=3, label=r'MLL KDE (1ML)')
#plt.plot(posX, store_Z_MLL_KDE_mu0, '-ok', color='pink', lw=3, label=r'MLL KDE (XGBoost) muhat=0')
#plt.plot(posX, store_Z_KDE_bins, '-ok', color='magenta', lw=3, label=r'100 Bins KDE')
plt.plot(posX, SrootB_WP2_XG, '--', color='darkorange', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[2] )
plt.plot(posX, SrootB_WP1_XG, '--', color='magenta', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[1] )
plt.plot(posX, SrootB_WP0_XG, '--', color='navy', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[0] )
plt.plot(posX, posX, ':', color='black', lw=lw, label=r'$S/\sqrt{B}$')

#plt.xlim([0.5, 10])
#plt.ylim([-0.5, 7.5])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=14)
plt.ylabel('$Z_{\mu}$ (exclusion)', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title('<B> per ensemble: %0.2d' % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()
# Out:
# <ipython-input-60-1231ce6ddeb8>:15: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string ":ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins, ':ok', color='blue', lw=lw, label='100 Linear Binned Likelihood')
# <ipython-input-60-1231ce6ddeb8>:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string ":ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_logbins, ':ok', color='lightblue', lw=lw, label='15 Log Binned Likelihood')
# <ipython-input-60-1231ce6ddeb8>:17: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "--ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG, '--ok', color='green', lw=lw, label='o(x) BL (100 l.bins)')
# <ipython-input-60-1231ce6ddeb8>:18: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins, '-ok', color='navy', lw=lw, label='o(x) BL (15 l.bins) (10ML)')
# <ipython-input-60-1231ce6ddeb8>:19: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_1ML, '-ok', color='green', lw=lw, label='o(x) BL (15 l.bins) (1ML)')
# <ipython-input-60-1231ce6ddeb8>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_eq, '-ok', color='magenta', lw=lw, label='o(x) BL (15 n.l.bins) (10ML)')
# <ipython-input-60-1231ce6ddeb8>:21: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_eq_1ML, '-ok', color='darkorange', lw=lw, label='o(x) BL (15 n.l.bins) (1ML)')
# <ipython-input-60-1231ce6ddeb8>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_MLL_KDE, '-ok', color='red', lw=3, label=r'MLL KDE (10ML)')
# <ipython-input-60-1231ce6ddeb8>:23: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "--ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_MLL_KDE_1ML, '--ok', color='lightcoral', lw=3, label=r'MLL KDE (1ML)')

# %%
posX = []

for i in range(len(SB_ratio)):
    posX.append( (B_expected*SB_ratio[i]) / ( B_expected )**0.5 )


plt.figure()
lw = 2

plt.plot(posX, store_Z_bins_logbins, '-', color='dodgerblue', lw=3, label='x BL (15 log l.bins)') 
plt.plot(posX, store_Z_bins_XG_15bins, '-', color='green', lw=3, label='o(x) BL (15 l.bins) (10ML)') 
plt.plot(posX, store_Z_MLL_KDE, '-', color='red', lw=3, label=r'MLL KDE (10ML)')
plt.plot(posX, store_Z_MLL_KDE_1ML, '--ok', color='lightcoral', lw=3, label=r'MLL KDE (1ML)')
plt.plot(posX, SrootB_WP2_XG, '--', color='darkorange', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[2] )
plt.plot(posX, SrootB_WP1_XG, '--', color='magenta', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[1] )
plt.plot(posX, SrootB_WP0_XG, '--', color='navy', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[0] )
plt.plot(posX, posX, ':', color='black', lw=lw, label=r'$S/\sqrt{B}$')

#plt.xlim([0.5, 10])
#plt.ylim([-0.5, 7.5])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=15)
plt.ylabel('$Z_{\mu}$', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title('<B> per ensemble: %0.2d' % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()
# Out:
# <ipython-input-61-415cc2f1cb5e>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "--ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_MLL_KDE_1ML, '--ok', color='lightcoral', lw=3, label=r'MLL KDE (1ML)')

# %% [markdown]
# ### Interpolate

# %%
    
# Interpolation, cubic
fcubic_bins_logbins = interp1d(posX, store_Z_bins_logbins, kind='cubic')
fcubic_bins_XG_15bins = interp1d(posX, store_Z_bins_XG_15bins, kind='cubic')
fcubic_bins_XG_15bins_1ML = interp1d(posX, store_Z_bins_XG_15bins_1ML, kind='cubic')
fcubic_XG_MLL = interp1d(posX, store_Z_MLL_KDE, kind='quadratic')
fcubic_XG_MLL_1ML = interp1d(posX, store_Z_MLL_KDE_1ML, kind='cubic')
fcubic_WP0_XG = interp1d(posX, SrootB_WP0_XG, kind='cubic')
fcubic_WP1_XG = interp1d(posX, SrootB_WP1_XG, kind='cubic')
fcubic_WP2_XG = interp1d(posX, SrootB_WP2_XG, kind='cubic')


# x to plot
plotX = np.linspace(min(posX), max(posX), num=50, endpoint=True)



plt.figure()
lw = 2

plt.plot(plotX, fcubic_bins_logbins(plotX), '-', color='dodgerblue', lw=3, label='x BL (15 log l.bins)') 
plt.plot(plotX, fcubic_bins_XG_15bins(plotX), '-', color='green', lw=3, label='o(x) BL (15 l.bins) (10ML)') 
plt.plot(plotX, fcubic_bins_XG_15bins_1ML(plotX), '--', color='green', lw=3, label='o(x) BL (15 l.bins) (1ML)') 
plt.plot(plotX, fcubic_XG_MLL(plotX), '-', color='red', lw=3, label=r'MLL KDE (10ML)')
plt.plot(plotX, fcubic_XG_MLL_1ML(plotX), '-', color='lightcoral', lw=3, label=r'MLL KDE (1ML)')
plt.plot(plotX, fcubic_WP0_XG(plotX), '--', color='darkorange', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[2] )
plt.plot(plotX, fcubic_WP1_XG(plotX), '--', color='magenta', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[1] )
plt.plot(plotX, fcubic_WP2_XG(plotX), '--', color='navy', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[0] )
plt.plot(posX, posX, ':', color='black', lw=lw, label=r'$S/\sqrt{B}$')

#plt.ylim([0., 6])
#plt.xlim([0.06, 10])
#plt.ylim([0., 3])
#plt.xlim([0.1, 0.2])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=15)
plt.ylabel('$Z_{\mu}$', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title('<B> per ensemble: %0.2d' % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()

# %%
# AUX FUNCTION TO FIND SOLUTIONS

def dx(fn, x, delta=0.001):
    return (fn(x+delta) - fn(x))/delta

def solve(fn, value, x=0.1, maxtries=1000, maxerr=0.00001):
    for tries in range(maxtries):
        err = fn(x) - value
        if abs(err) < maxerr:
            return x
        slope = dx(fn, x)
        x -= err/slope
    raise ValueError('no solution found')

# %%
##############################
# DO NOT FORGET THE K-factor #
##############################

k_factor = 3
SM_cross_section_fb = 0.3106
acceptance_SM = 0.4*2
true_B_expected = 3000 * SM_cross_section_fb * k_factor * acceptance_SM

correct_factor = true_B_expected / B_expected

print('correct_factor: ', correct_factor)
print('')


# Find S/\sqrt{B} such that 95%C.L. upper limit, i.e  ----> Z = 1.64

bins_logbins_95CL = solve(fcubic_bins_logbins, 1.64)
bins_XG_15bins_95CL = solve(fcubic_bins_XG_15bins, 1.64)
XG_MLL_95CL = solve(fcubic_XG_MLL, 1.64)
bins_XG_15bins_1ML_95CL = solve(fcubic_bins_XG_15bins_1ML, 1.64)
XG_MLL_1ML_95CL = solve(fcubic_XG_MLL_1ML, 1.64)


# corresponding to a number of signal events:
acceptance_Signal = 0.720128
S1 = ( (correct_factor * B_expected)**0.5 * bins_logbins_95CL ) / acceptance_Signal
S2 = ( (correct_factor * B_expected)**0.5 * bins_XG_15bins_95CL ) / acceptance_Signal
S3 = ( (correct_factor * B_expected)**0.5 * XG_MLL_95CL ) / acceptance_Signal
S4 = ( (correct_factor * B_expected)**0.5 * bins_XG_15bins_1ML_95CL ) / acceptance_Signal
S5 = ( (correct_factor * B_expected)**0.5 * XG_MLL_1ML_95CL ) / acceptance_Signal

# corresponding to a cross-section (pb)
cross_bins_logbins_95CL = S1 / 3000000
cross_bins_XG_15bins_95CL = S2 / 3000000
cross_XG_MLL_95CL = S3 / 3000000
cross_bins_XG_15bins_1ML_95CL = S4 / 3000000
cross_XG_MLL_1ML_95CL = S5 / 3000000



print('95%C.L. upper limit, i.e  ----> Z = 1.64: \n')
print('     S/\sqrt{B}              S          cross-section (pb)')
print(bins_logbins_95CL , S1 , cross_bins_logbins_95CL)
print(bins_XG_15bins_95CL , S2 , cross_bins_XG_15bins_95CL)
print(XG_MLL_95CL, S3 , cross_XG_MLL_95CL)
print(bins_XG_15bins_1ML_95CL , S4 , cross_bins_XG_15bins_1ML_95CL)
print(XG_MLL_1ML_95CL, S5 , cross_XG_MLL_1ML_95CL)



np.savetxt('saved-models/results5000GeV-mumu.txt', [cross_bins_logbins_95CL,cross_bins_XG_15bins_95CL,cross_XG_MLL_95CL,cross_bins_XG_15bins_1ML_95CL,cross_XG_MLL_1ML_95CL])
# Out:
# correct_factor:  0.44726399999999994
#
# 95%C.L. upper limit, i.e  ----> Z = 1.64:
#
#      S/\sqrt{B}              S          cross-section (pb)
# 0.1518445998280385 9.971411240957877 3.323803746985959e-06
# 0.19483996106166745 12.79485329157789 4.26495109719263e-06
# 0.10049032545397196 6.5990516750285115 2.1996838916761703e-06
# 0.19489502456851615 12.79846923097764 4.26615641032588e-06
# 0.09778336861930473 6.4212898063775565 2.1404299354591856e-06
