# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import gridspec
from matplotlib import patches
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

import os
import math
import random

import keras
from keras.models import Sequential
from keras.layers import Input, Dense, Conv2D, Flatten, MaxPooling2D
from keras.layers import Dropout
from keras.callbacks import EarlyStopping

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn import preprocessing
from sklearn.metrics import roc_curve, roc_auc_score, auc

import scipy.stats as st
from scipy.stats import poisson
from scipy.interpolate import interp1d
from scipy.stats import norm

# %%
from sklearn.neighbors import KernelDensity # paquete necesario
from sklearn.model_selection import GridSearchCV

import scipy.integrate as integrate

# %%
# !pip install xgboost

import xgboost
from xgboost import XGBRegressor, XGBClassifier
# Out:
# Requirement already satisfied: xgboost in /home/andres/anaconda3/lib/python3.8/site-packages (1.5.1)
# Requirement already satisfied: numpy in /home/andres/.local/lib/python3.8/site-packages (from xgboost) (1.22.4)
# Requirement already satisfied: scipy in /home/andres/.local/lib/python3.8/site-packages (from xgboost) (1.9.3)
# WARNING: You are using pip version 21.3.1; however, version 23.2 is available.
# You should consider upgrading via the '/home/andres/anaconda3/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# ## DATA

# %%
# data

folder_data = "../../MLL-exclusion/data/"

# %%
folder_saved = "Zprime-SSM-mumu-mZ6500GeV-variables/"

# 1st DATASET
e1pt_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-pt-6500-1.txt', delimiter=',')
e1eta_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-eta-6500-1.txt', delimiter=',')
e1phi_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-phi-6500-1.txt', delimiter=',')

e2pt_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-pt-6500-1.txt', delimiter=',')
e2eta_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-eta-6500-1.txt', delimiter=',')
e2phi_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-phi-6500-1.txt', delimiter=',')




# INVARIANT MASS

invariant_mass_eeSM = []

for i in range(len(e1pt_eeSSMZprime)):
    invariant_mass_eeSM.append( ( 2 * e1pt_eeSSMZprime[i] * e2pt_eeSSMZprime[i] * ( np.cosh(e1eta_eeSSMZprime[i] - e2eta_eeSSMZprime[i]) - np.cos(e1phi_eeSSMZprime[i] - e2phi_eeSSMZprime[i]) ) )**0.5 )
    
print(len(invariant_mass_eeSM))

f= open(folder_data + folder_saved + "mmumu-1.txt","w")
for i in range(len(invariant_mass_eeSM)):
    f.write("%.3f\n" % invariant_mass_eeSM[i] )
f.close()




# 2nd DATASET
e1pt_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-pt-6500-2.txt', delimiter=',')
e1eta_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-eta-6500-2.txt', delimiter=',')
e1phi_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-phi-6500-2.txt', delimiter=',')

e2pt_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-pt-6500-2.txt', delimiter=',')
e2eta_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-eta-6500-2.txt', delimiter=',')
e2phi_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-phi-6500-2.txt', delimiter=',')




# INVARIANT MASS

invariant_mass_eeSM = []

for i in range(len(e1pt_eeSSMZprime)):
    invariant_mass_eeSM.append( ( 2 * e1pt_eeSSMZprime[i] * e2pt_eeSSMZprime[i] * ( np.cosh(e1eta_eeSSMZprime[i] - e2eta_eeSSMZprime[i]) - np.cos(e1phi_eeSSMZprime[i] - e2phi_eeSSMZprime[i]) ) )**0.5 )
    
print(len(invariant_mass_eeSM))

f= open(folder_data + folder_saved + "mmumu-2.txt","w")
for i in range(len(invariant_mass_eeSM)):
    f.write("%.3f\n" % invariant_mass_eeSM[i] )
f.close()



# 3rd DATASET
e1pt_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-pt-6500-3.txt', delimiter=',')
e1eta_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-eta-6500-3.txt', delimiter=',')
e1phi_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-phi-6500-3.txt', delimiter=',')

e2pt_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-pt-6500-3.txt', delimiter=',')
e2eta_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-eta-6500-3.txt', delimiter=',')
e2phi_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-phi-6500-3.txt', delimiter=',')




# INVARIANT MASS

invariant_mass_eeSM = []

for i in range(len(e1pt_eeSSMZprime)):
    invariant_mass_eeSM.append( ( 2 * e1pt_eeSSMZprime[i] * e2pt_eeSSMZprime[i] * ( np.cosh(e1eta_eeSSMZprime[i] - e2eta_eeSSMZprime[i]) - np.cos(e1phi_eeSSMZprime[i] - e2phi_eeSSMZprime[i]) ) )**0.5 )
    
print(len(invariant_mass_eeSM))

f= open(folder_data + folder_saved + "mmumu-3.txt","w")
for i in range(len(invariant_mass_eeSM)):
    f.write("%.3f\n" % invariant_mass_eeSM[i] )
f.close()
# Out:
# 673574
# 672728
# 672733

# %%
# just to check that we need to ask again that the invariant mass has to be greater than 2000 GeV

bins_atlas = [70, 80.0, 90.0, 105.0, 120.0, 140.0, 160.0, 180.0, 210.0, 240.0, 275.0, 315.0, 360.0, 415.0, 475.0, 545.0, 625.0, 715.0, 825.0, 950.0, 1100.0, 1250.0, 1450.0, 1650.0, 1900.0, 2200.0, 2500.0, 2850.0, 3250.0, 3750.0, 4350.0, 5000.0, 5750.0, 6600.0, 7500.0, 8750.0, 10000.0, 11500.0, 13000.0, 20000]

folder_saved = "SM/mumu/"

invariant_mass_eeSM_1800 = np.loadtxt(folder_data + folder_saved +"mmumu-1800.txt", delimiter=',')
invariant_mass_eeSM_1800_2 = np.loadtxt(folder_data + folder_saved +"mmumu-1800-2.txt", delimiter=',')

plt.hist(invariant_mass_eeSM_1800, bins=bins_atlas, lw=2, edgecolor='lightblue', histtype='step', label="SM (dataset 1)")
plt.hist(invariant_mass_eeSM_1800_2, bins=bins_atlas, lw=2, edgecolor='green', histtype='step', label="SM (dataset 2)")


folder_saved = "Zprime-SSM-mumu-mZ6500GeV-variables/"

invariant_mass_eeSSMZprime_1 = np.loadtxt(folder_data + folder_saved +"mmumu-1.txt", delimiter=',')
invariant_mass_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved +"mmumu-2.txt", delimiter=',')
invariant_mass_eeSSMZprime_3 = np.loadtxt(folder_data + folder_saved +"mmumu-3.txt", delimiter=',')

plt.hist(invariant_mass_eeSSMZprime_1, bins=bins_atlas, lw=2, edgecolor='pink', histtype='step', label="$Z'_{SSM}$ (dataset 1)")
plt.hist(invariant_mass_eeSSMZprime_2, bins=bins_atlas, lw=2, edgecolor='darkorange', histtype='step', label="$Z'_{SSM}$ (dataset 2)")
plt.hist(invariant_mass_eeSSMZprime_3, bins=bins_atlas, lw=2, edgecolor='purple', histtype='step', label="$Z'_{SSM}$ (dataset 3)")


plt.grid()  # Add grid lines

plt.title(r"Z/Z'$\rightarrow$e+e-",fontsize=14)  # Titles etc
plt.xlabel("$m_{ll}$ (GeV)",fontsize=14)
plt.ylabel("Events",fontsize=14)

plt.xlim(70.,20000)
plt.ylim(1e0,1e7)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xscale('log')
plt.yscale('log')
plt.legend(loc='upper left',fontsize=12)

plt.show()

# %% [markdown]
# ### SM

# %%
######
# SM #
######


folder_saved = "SM/mumu/"


# 1st DATASET
invariant_mass_eeSM = np.loadtxt(folder_data + folder_saved +"mmumu-1800.txt", delimiter=',')

e1pt_eeSM = np.loadtxt(folder_data + folder_saved + 'mu1_pt_events_IM_1800.txt', delimiter=',')
e1eta_eeSM = np.loadtxt(folder_data + folder_saved + 'mu1_eta_events_IM_1800.txt', delimiter=',')
e1phi_eeSM = np.loadtxt(folder_data + folder_saved + 'mu1_phi_events_IM_1800.txt', delimiter=',')

e2pt_eeSM = np.loadtxt(folder_data + folder_saved + 'mu2_pt_events_IM_1800.txt', delimiter=',')
e2eta_eeSM = np.loadtxt(folder_data + folder_saved + 'mu2_eta_events_IM_1800.txt', delimiter=',')
e2phi_eeSM = np.loadtxt(folder_data + folder_saved + 'mu2_phi_events_IM_1800.txt', delimiter=',')


# only keep points where the invariant mass is greater than 2000 GeV
# and make sure that both electrons: |eta| < 2.65
for i in reversed(range(len(invariant_mass_eeSM))):
    if invariant_mass_eeSM[i]< 2000 or e1eta_eeSM[i] < -2.65 or e1eta_eeSM[i] > 2.65 or e2eta_eeSM[i] < -2.65 or e2eta_eeSM[i] > 2.65:
        e1pt_eeSM = np.delete(e1pt_eeSM, i)
        e1eta_eeSM = np.delete(e1eta_eeSM, i)
        e1phi_eeSM = np.delete(e1phi_eeSM, i)
        
        e2pt_eeSM = np.delete(e2pt_eeSM, i)
        e2eta_eeSM = np.delete(e2eta_eeSM, i)
        e2phi_eeSM = np.delete(e2phi_eeSM, i)
        
        invariant_mass_eeSM = np.delete(invariant_mass_eeSM, i)
        

        
        
# 2nd DATASET
invariant_mass_eeSM_1800 = np.loadtxt(folder_data + folder_saved +"mmumu-1800-2.txt", delimiter=',')

e1pt_eeSM_1800 = np.loadtxt(folder_data + folder_saved + 'mu1_pt_events_IM_1800_2.txt', delimiter=',')
e1eta_eeSM_1800 = np.loadtxt(folder_data + folder_saved + 'mu1_eta_events_IM_1800_2.txt', delimiter=',')
e1phi_eeSM_1800 = np.loadtxt(folder_data + folder_saved + 'mu1_phi_events_IM_1800_2.txt', delimiter=',')

e2pt_eeSM_1800 = np.loadtxt(folder_data + folder_saved + 'mu2_pt_events_IM_1800_2.txt', delimiter=',')
e2eta_eeSM_1800 = np.loadtxt(folder_data + folder_saved + 'mu2_eta_events_IM_1800_2.txt', delimiter=',')
e2phi_eeSM_1800 = np.loadtxt(folder_data + folder_saved + 'mu2_phi_events_IM_1800_2.txt', delimiter=',')


# only keep points where the invariant mass is greater than 2000 GeV
# and make sure that both electrons: |eta| < 2.65
for i in reversed(range(len(invariant_mass_eeSM_1800))):
    if invariant_mass_eeSM_1800[i]< 2000 or e1eta_eeSM_1800[i] < -2.65 or e1eta_eeSM_1800[i] > 2.65 or e2eta_eeSM_1800[i] < -2.65 or e2eta_eeSM_1800[i] > 2.65:
        e1pt_eeSM_1800 = np.delete(e1pt_eeSM_1800, i)
        e1eta_eeSM_1800 = np.delete(e1eta_eeSM_1800, i)
        e1phi_eeSM_1800 = np.delete(e1phi_eeSM_1800, i)
        
        e2pt_eeSM_1800 = np.delete(e2pt_eeSM_1800, i)
        e2eta_eeSM_1800 = np.delete(e2eta_eeSM_1800, i)
        e2phi_eeSM_1800 = np.delete(e2phi_eeSM_1800, i)
        
        invariant_mass_eeSM_1800 = np.delete(invariant_mass_eeSM_1800, i)
        


# concatenate results
e1pt_eeSM = np.concatenate([e1pt_eeSM,e1pt_eeSM_1800])
e1eta_eeSM = np.concatenate([e1eta_eeSM,e1eta_eeSM_1800])
e1phi_eeSM = np.concatenate([e1phi_eeSM,e1phi_eeSM_1800])

e2pt_eeSM = np.concatenate([e2pt_eeSM,e2pt_eeSM_1800])
e2eta_eeSM = np.concatenate([e2eta_eeSM,e2eta_eeSM_1800])
e2phi_eeSM = np.concatenate([e2phi_eeSM,e2phi_eeSM_1800])

invariant_mass_eeSM = np.concatenate([invariant_mass_eeSM,invariant_mass_eeSM_1800])



# remove the aux
del e1pt_eeSM_1800
del e1eta_eeSM_1800
del e1phi_eeSM_1800

del e2pt_eeSM_1800
del e2eta_eeSM_1800
del e2phi_eeSM_1800

del invariant_mass_eeSM_1800




# FINALLY

# compute \Delta \eta_{l+l-}
e1e2diffeta_eeSM = np.array([a-b for a,b in zip(e1eta_eeSM,e2eta_eeSM)])

# compute R = [ \Delta \eta_{l+l-}^2 + \Delta \eta_{l+l-}^2 ]^1/2
e1e2R_eeSM = np.array([( (a-b)**2. + (c-d)**2. )**0.5 for a,b,c,d in zip(e1eta_eeSM,e2eta_eeSM,e1phi_eeSM,e2phi_eeSM)])



print(e1pt_eeSM.shape)
print(e1eta_eeSM.shape)
print(e1phi_eeSM.shape)

print(e2pt_eeSM.shape)
print(e2eta_eeSM.shape)
print(e2phi_eeSM.shape)

print(invariant_mass_eeSM.shape)
print(e1e2diffeta_eeSM.shape)
print(e1e2R_eeSM.shape)
# Out:
# (804774,)
# (804774,)
# (804774,)
# (804774,)
# (804774,)
# (804774,)
# (804774,)
# (804774,)
# (804774,)

# %%
print(min(e1eta_eeSM))
print(max(e1eta_eeSM))

print(min(e2eta_eeSM))
print(max(e2eta_eeSM))
# Out:
# -2.646
# 2.648
# -2.649
# 2.649

# %% [markdown]
# ### SSM Z prime

# %%
##########
# Zprime #
##########


folder_saved = "Zprime-SSM-mumu-mZ6500GeV-variables/"


# 1st DATASET
invariant_mass_eeSSMZprime = np.loadtxt(folder_data + folder_saved +"mmumu-1.txt", delimiter=',')

e1pt_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-pt-6500-1.txt', delimiter=',')
e1eta_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-eta-6500-1.txt', delimiter=',')
e1phi_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-phi-6500-1.txt', delimiter=',')

e2pt_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-pt-6500-1.txt', delimiter=',')
e2eta_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-eta-6500-1.txt', delimiter=',')
e2phi_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-phi-6500-1.txt', delimiter=',')


# only keep points where the invariant mass is greater than 2000 GeV
# and make sure that both electrons: |eta| < 2.65
for i in reversed(range(len(invariant_mass_eeSSMZprime))):
    if invariant_mass_eeSSMZprime[i]< 2000 or e1eta_eeSSMZprime[i] < -2.65 or e1eta_eeSSMZprime[i] > 2.65 or e2eta_eeSSMZprime[i] < -2.65 or e2eta_eeSSMZprime[i] > 2.65:
        e1pt_eeSSMZprime = np.delete(e1pt_eeSSMZprime, i)
        e1eta_eeSSMZprime = np.delete(e1eta_eeSSMZprime, i)
        e1phi_eeSSMZprime = np.delete(e1phi_eeSSMZprime, i)
        
        e2pt_eeSSMZprime = np.delete(e2pt_eeSSMZprime, i)
        e2eta_eeSSMZprime = np.delete(e2eta_eeSSMZprime, i)
        e2phi_eeSSMZprime = np.delete(e2phi_eeSSMZprime, i)
        
        invariant_mass_eeSSMZprime = np.delete(invariant_mass_eeSSMZprime, i)

        
        
        
        
# 2nd DATASET
invariant_mass_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved +"mmumu-2.txt", delimiter=',')

e1pt_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved + 'mu1-pt-6500-2.txt', delimiter=',')
e1eta_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved + 'mu1-eta-6500-2.txt', delimiter=',')
e1phi_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved + 'mu1-phi-6500-2.txt', delimiter=',')

e2pt_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved + 'mu2-pt-6500-2.txt', delimiter=',')
e2eta_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved + 'mu2-eta-6500-2.txt', delimiter=',')
e2phi_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved + 'mu2-phi-6500-2.txt', delimiter=',')


# only keep points where the invariant mass is greater than 2000 GeV
# and make sure that both electrons: |eta| < 2.65
for i in reversed(range(len(invariant_mass_eeSSMZprime_2))):
    if invariant_mass_eeSSMZprime_2[i]< 2000 or e1eta_eeSSMZprime_2[i] < -2.65 or e1eta_eeSSMZprime_2[i] > 2.65 or e2eta_eeSSMZprime_2[i] < -2.65 or e2eta_eeSSMZprime_2[i] > 2.65:
        e1pt_eeSSMZprime_2 = np.delete(e1pt_eeSSMZprime_2, i)
        e1eta_eeSSMZprime_2 = np.delete(e1eta_eeSSMZprime_2, i)
        e1phi_eeSSMZprime_2 = np.delete(e1phi_eeSSMZprime_2, i)
        
        e2pt_eeSSMZprime_2 = np.delete(e2pt_eeSSMZprime_2, i)
        e2eta_eeSSMZprime_2 = np.delete(e2eta_eeSSMZprime_2, i)
        e2phi_eeSSMZprime_2 = np.delete(e2phi_eeSSMZprime_2, i)
        
        invariant_mass_eeSSMZprime_2 = np.delete(invariant_mass_eeSSMZprime_2, i)
        
eventos_parton = 1000000
aceptancia_eeSSMZprime_2 = 1.*len(invariant_mass_eeSSMZprime_2) / eventos_parton
print(aceptancia_eeSSMZprime_2)


# concatenate results
e1pt_eeSSMZprime = np.concatenate([e1pt_eeSSMZprime,e1pt_eeSSMZprime_2])
e1eta_eeSSMZprime = np.concatenate([e1eta_eeSSMZprime,e1eta_eeSSMZprime_2])
e1phi_eeSSMZprime = np.concatenate([e1phi_eeSSMZprime,e1phi_eeSSMZprime_2])

e2pt_eeSSMZprime = np.concatenate([e2pt_eeSSMZprime,e2pt_eeSSMZprime_2])
e2eta_eeSSMZprime = np.concatenate([e2eta_eeSSMZprime,e2eta_eeSSMZprime_2])
e2phi_eeSSMZprime = np.concatenate([e2phi_eeSSMZprime,e2phi_eeSSMZprime_2])

invariant_mass_eeSSMZprime = np.concatenate([invariant_mass_eeSSMZprime,invariant_mass_eeSSMZprime_2])



# remove the aux
del e1pt_eeSSMZprime_2
del e1eta_eeSSMZprime_2
del e1phi_eeSSMZprime_2

del e2pt_eeSSMZprime_2
del e2eta_eeSSMZprime_2
del e2phi_eeSSMZprime_2

del invariant_mass_eeSSMZprime_2






# 3rd DATASET
invariant_mass_eeSSMZprime_3 = np.loadtxt(folder_data + folder_saved +"mmumu-3.txt", delimiter=',')

e1pt_eeSSMZprime_3 = np.loadtxt(folder_data + folder_saved + 'mu1-pt-6500-3.txt', delimiter=',')
e1eta_eeSSMZprime_3 = np.loadtxt(folder_data + folder_saved + 'mu1-eta-6500-3.txt', delimiter=',')
e1phi_eeSSMZprime_3 = np.loadtxt(folder_data + folder_saved + 'mu1-phi-6500-3.txt', delimiter=',')

e2pt_eeSSMZprime_3 = np.loadtxt(folder_data + folder_saved + 'mu2-pt-6500-3.txt', delimiter=',')
e2eta_eeSSMZprime_3 = np.loadtxt(folder_data + folder_saved + 'mu2-eta-6500-3.txt', delimiter=',')
e2phi_eeSSMZprime_3 = np.loadtxt(folder_data + folder_saved + 'mu2-phi-6500-3.txt', delimiter=',')


# only keep points where the invariant mass is greater than 2000 GeV
# and make sure that both electrons: |eta| < 2.65
for i in reversed(range(len(invariant_mass_eeSSMZprime_3))):
    if invariant_mass_eeSSMZprime_3[i]< 2000 or e1eta_eeSSMZprime_3[i] < -2.65 or e1eta_eeSSMZprime_3[i] > 2.65 or e2eta_eeSSMZprime_3[i] < -2.65 or e2eta_eeSSMZprime_3[i] > 2.65:
        e1pt_eeSSMZprime_3 = np.delete(e1pt_eeSSMZprime_3, i)
        e1eta_eeSSMZprime_3 = np.delete(e1eta_eeSSMZprime_3, i)
        e1phi_eeSSMZprime_3 = np.delete(e1phi_eeSSMZprime_3, i)
        
        e2pt_eeSSMZprime_3 = np.delete(e2pt_eeSSMZprime_3, i)
        e2eta_eeSSMZprime_3 = np.delete(e2eta_eeSSMZprime_3, i)
        e2phi_eeSSMZprime_3 = np.delete(e2phi_eeSSMZprime_3, i)
        
        invariant_mass_eeSSMZprime_3 = np.delete(invariant_mass_eeSSMZprime_3, i)
        
eventos_parton = 1000000
aceptancia_eeSSMZprime_3 = 1.*len(invariant_mass_eeSSMZprime_3) / eventos_parton
print(aceptancia_eeSSMZprime_3)


# concatenate results
e1pt_eeSSMZprime = np.concatenate([e1pt_eeSSMZprime,e1pt_eeSSMZprime_3])
e1eta_eeSSMZprime = np.concatenate([e1eta_eeSSMZprime,e1eta_eeSSMZprime_3])
e1phi_eeSSMZprime = np.concatenate([e1phi_eeSSMZprime,e1phi_eeSSMZprime_3])

e2pt_eeSSMZprime = np.concatenate([e2pt_eeSSMZprime,e2pt_eeSSMZprime_3])
e2eta_eeSSMZprime = np.concatenate([e2eta_eeSSMZprime,e2eta_eeSSMZprime_3])
e2phi_eeSSMZprime = np.concatenate([e2phi_eeSSMZprime,e2phi_eeSSMZprime_3])

invariant_mass_eeSSMZprime = np.concatenate([invariant_mass_eeSSMZprime,invariant_mass_eeSSMZprime_3])



# remove the aux
del e1pt_eeSSMZprime_3
del e1eta_eeSSMZprime_3
del e1phi_eeSSMZprime_3

del e2pt_eeSSMZprime_3
del e2eta_eeSSMZprime_3
del e2phi_eeSSMZprime_3

del invariant_mass_eeSSMZprime_3







# FINALLY

# compute \Delta \eta_{l+l-}
e1e2diffeta_eeSSMZprime = np.array([a-b for a,b in zip(e1eta_eeSSMZprime,e2eta_eeSSMZprime)])

# compute R = [ \Delta \eta_{l+l-}^2 + \Delta \eta_{l+l-}^2 ]^1/2
e1e2R_eeSSMZprime = np.array([( (a-b)**2. + (c-d)**2. )**0.5 for a,b,c,d in zip(e1eta_eeSSMZprime,e2eta_eeSSMZprime,e1phi_eeSSMZprime,e2phi_eeSSMZprime)])




print(e1pt_eeSSMZprime.shape)
print(e1eta_eeSSMZprime.shape)
print(e1phi_eeSSMZprime.shape)

print(e2pt_eeSSMZprime.shape)
print(e2eta_eeSSMZprime.shape)
print(e2phi_eeSSMZprime.shape)

print(invariant_mass_eeSSMZprime.shape)
print(e1e2diffeta_eeSSMZprime.shape)
print(e1e2R_eeSSMZprime.shape)
# Out:
# 0.672699
# 0.672715
# (2018964,)
# (2018964,)
# (2018964,)
# (2018964,)
# (2018964,)
# (2018964,)
# (2018964,)
# (2018964,)
# (2018964,)

# %%
print(min(e1eta_eeSSMZprime))
print(max(e1eta_eeSSMZprime))

print(min(e2eta_eeSSMZprime))
print(max(e2eta_eeSSMZprime))
# Out:
# -2.647
# 2.649
# -2.649
# 2.649

# %%
# NOW DATA IS CHECKED

bins_atlas = [70, 80.0, 90.0, 105.0, 120.0, 140.0, 160.0, 180.0, 210.0, 240.0, 275.0, 315.0, 360.0, 415.0, 475.0, 545.0, 625.0, 715.0, 825.0, 950.0, 1100.0, 1250.0, 1450.0, 1650.0, 1900.0, 2200.0, 2500.0, 2850.0, 3250.0, 3750.0, 4350.0, 5000.0, 5750.0, 6600.0, 7500.0, 8750.0, 10000.0, 11500.0, 13000.0, 20000]

plt.hist(invariant_mass_eeSM, bins=bins_atlas, lw=2, edgecolor='blue', histtype='step', label="SM")
plt.hist(invariant_mass_eeSSMZprime, bins=bins_atlas, lw=2, edgecolor='red', histtype='step', label="$Z'_{SSM}$")

plt.grid()  # Add grid lines

plt.title(r"Z/Z'$\rightarrow \mu+ \mu-$",fontsize=14)  # Titles etc
plt.xlabel("$m_{ll}$ (GeV)",fontsize=14)
plt.ylabel("Events",fontsize=14)

plt.xlim(70.,20000)
plt.ylim(1e0,1e7)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xscale('log')
plt.yscale('log')
plt.legend(loc='upper left',fontsize=12)

plt.show()




plt.hist(e1e2diffeta_eeSM, bins=100, range=[-5,5], lw=2, edgecolor='blue', histtype='step', label="SM")
plt.hist(e1e2diffeta_eeSSMZprime, bins=100, range=[-5,5], lw=2, edgecolor='red', histtype='step', label="$Z'_{SSM}$")

plt.grid()  # Add grid lines

plt.title(r"Z/Z'$\rightarrow \mu+ \mu-$",fontsize=14)  # Titles etc
plt.xlabel("$\Delta \eta_{ll}$",fontsize=14)
plt.ylabel("Events",fontsize=14)

plt.xlim(-5,5)
plt.ylim(1e0,1e7)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#plt.xscale('log')
plt.yscale('log')
plt.legend(loc='upper left',fontsize=12)

plt.show()




plt.hist(e1e2R_eeSM, bins=82, range=[0,8.2], lw=2, edgecolor='blue', histtype='step', label="SM")
plt.hist(e1e2R_eeSSMZprime, bins=82, range=[0,8.2], lw=2, edgecolor='red', histtype='step', label="$Z'_{SSM}$")

plt.grid()  # Add grid lines

plt.title(r"Z/Z'$\rightarrow \mu+ \mu-$",fontsize=14)  # Titles etc
plt.xlabel("$R$",fontsize=14)
plt.ylabel("Events",fontsize=14)

plt.xlim(0.,8.2)
plt.ylim(1e0,1e7)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#plt.xscale('log')
plt.yscale('log')
plt.legend(loc='upper left',fontsize=12)

plt.show()

# %% [markdown]
# ### Train-test-val datasets

# %%
# to normalize
scaler = preprocessing.MinMaxScaler()

# Number of data points (per-class) for the ML classifier
num_data = 750000



df = pd.DataFrame()

df['e1-pt']= np.concatenate([e1pt_eeSM[:num_data],e1pt_eeSSMZprime[:num_data]])
df['e1-eta']= np.concatenate([e1eta_eeSM[:num_data],e1eta_eeSSMZprime[:num_data]])
df['e1-phi']= np.concatenate([e1phi_eeSM[:num_data],e1phi_eeSSMZprime[:num_data]])

df['e2-pt']= np.concatenate([e2pt_eeSM[:num_data],e2pt_eeSSMZprime[:num_data]])
df['e2-eta']= np.concatenate([e2eta_eeSM[:num_data],e2eta_eeSSMZprime[:num_data]])
df['e2-phi']= np.concatenate([e2phi_eeSM[:num_data],e2phi_eeSSMZprime[:num_data]])

df['mll']= np.concatenate([invariant_mass_eeSM[:num_data],invariant_mass_eeSSMZprime[:num_data]])
df['delta-eta']= np.concatenate([e1e2diffeta_eeSM[:num_data],e1e2diffeta_eeSSMZprime[:num_data]])
df['R']= np.concatenate([e1e2R_eeSM[:num_data],e1e2R_eeSSMZprime[:num_data]])

df['Y'] = np.concatenate([np.zeros(num_data),np.ones(num_data)])


# remove the used data
del e1pt_eeSM
del e1eta_eeSM
del e1phi_eeSM

del e2pt_eeSM
del e2eta_eeSM
del e2phi_eeSM

del e1pt_eeSSMZprime
del e1eta_eeSSMZprime
del e1phi_eeSSMZprime

del e2pt_eeSSMZprime
del e2eta_eeSSMZprime
del e2phi_eeSSMZprime


# NORMALIZE
df = scaler.fit_transform(df)
df = pd.DataFrame(df,columns=['e1-pt','e1-eta','e1-phi','e2-pt','e2-eta','e2-phi','mll','delta-eta','R','Y'])


# print df to see the data
print(df)


# X and Y for the classifier
X_mon = df[['e1-pt','e1-eta','e1-phi','e2-pt','e2-eta','e2-phi']].values
y_mon = df[['Y']].values

del df

# divide into train-val and test data samples
test_ratio = 1./3
val_ratio = 0.25


X_mon_aux, X_mon_test, y_mon_aux, y_mon_test = train_test_split(X_mon,
                                                                y_mon,
                                                                test_size=test_ratio,
                                                                random_state=42,
                                                                #stratify = y_mon,
                                                                shuffle=True)


X_mon_train, X_mon_val, y_mon_train, y_mon_val = train_test_split(X_mon_aux,
                                                                  y_mon_aux,
                                                                  test_size=val_ratio,
                                                                  random_state=42,
                                                                  #stratify = y_mon_aux,
                                                                  shuffle=True)


print('')
print('X_mon_train : ', X_mon_train.shape)
print('y_mon_train : ', y_mon_train.shape)
print('X_mon_val : ', X_mon_val.shape)
print('y_mon_val : ', y_mon_val.shape)
print('X_mon_test : ', X_mon_test.shape)
print('y_mon_test : ', y_mon_test.shape)
print('')
# Out:
#             e1-pt    e1-eta    e1-phi     e2-pt    e2-eta    e2-phi       mll  \
# 0        0.206223  0.591235  0.081158  0.243769  0.609664  0.557288  0.037165
# 1        0.201299  0.636759  0.312540  0.231881  0.353341  0.827976  0.113848
# 2        0.272173  0.703627  0.972311  0.303712  0.502831  0.473265  0.169668
# 3        0.189502  0.581224  0.581158  0.203383  0.567573  0.101528  0.002663
# 4        0.167686  0.544012  0.273711  0.211492  0.285957  0.765595  0.057301
# ...           ...       ...       ...       ...       ...       ...       ...
# 1499995  0.219115  0.222138  0.067473  0.235661  0.822008  0.566518  0.515271
# 1499996  0.593486  0.390820  0.255570  0.675087  0.457531  0.760185  0.548725
# 1499997  0.260501  0.628258  0.048536  0.144361  0.202529  0.638447  0.177920
# 1499998  0.483060  0.309785  0.609166  0.429733  0.482069  0.111076  0.380241
# 1499999  0.316762  0.671704  0.312540  0.356342  0.196300  0.822884  0.570681
#
#          delta-eta         R    Y
# 0         0.488730  0.271816  0.0
# 1         0.643417  0.365378  0.0
# 2         0.601045  0.323406  0.0
# 3         0.505176  0.275273  0.0
# 4         0.630454  0.334536  0.0
# ...            ...       ...  ...
# 1499995   0.190868  0.510253  1.0
# 1499996   0.464061  0.303759  1.0
# 1499997   0.716359  0.490164  1.0
# 1499998   0.409984  0.315018  1.0
# 1499999   0.741801  0.447742  1.0
#
# [1500000 rows x 10 columns]
#
# X_mon_train :  (750000, 6)
# y_mon_train :  (750000, 1)
# X_mon_val :  (250000, 6)
# y_mon_val :  (250000, 1)
# X_mon_test :  (500000, 6)
# y_mon_test :  (500000, 1)

# %% [markdown]
# ### XGBoost (per-event)

# %% [markdown]
# ##### For 1 ML

# %%
# XGBoost with only the kinematic variables of the leptons

# CLASSIFIER
classifier = XGBClassifier(
    n_estimators=2500,
    learning_rate=0.1,
    reg_lambda=0.0,reg_alpha=0.0,
    gamma=0.0,objective='binary:logistic',
    max_depth=5)

# FIT
classifier.fit(X_mon_train,y_mon_train,eval_set=[(X_mon_train, y_mon_train), (X_mon_val, y_mon_val)],
        eval_metric='logloss',early_stopping_rounds=50,#early stopping
        verbose=True)

# PREDICTIONS
y_pred_xg_1ML = classifier.predict_proba(X_mon_test).T[1]


# ROC
fpr_mon_xg, tpr_mon_xg, _ = roc_curve(y_mon_test, y_pred_xg_1ML)
roc_auc_xg = auc(fpr_mon_xg, tpr_mon_xg)


# PLOT THE ROC WITH AUC
fig = plt.figure(figsize=(6, 6))
gs = gridspec.GridSpec(1, 1) 
ax0 = plt.subplot(gs[0])
ax0.yaxis.set_ticks_position('both')
ax0.xaxis.set_ticks_position('both')
ax0.tick_params(direction="in",which="both")
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
ax0.minorticks_on()


plt.plot(tpr_mon_xg,1-fpr_mon_xg,label="$f_{1}$, AUC = %0.2f" % roc_auc_xg,color="orange",ls=":",lw=4)
plt.plot([1,0],[0,1],ls=":",color="grey")
plt.xlabel("True Positive Rate",fontsize=16)
plt.ylabel("1 $-$ False Positive Rate",fontsize=16)
plt.legend()
plt.title(r"SSM Z' - XGBoost",fontsize=16)
plt.xlim([0,1])
plt.ylim([0,1])
plt.yticks([0.2,0.4,0.6,0.8,1.])
plt.legend(frameon=False,fontsize=16)
plt.show()




feature_names = np.array(['e1-pt','e1-eta','e1-phi','e2-pt','e2-eta','e2-phi'])
plt.barh(feature_names, classifier.feature_importances_)
plt.xlabel("Xgboost Feature Importance")
plt.show()
# Out:
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [0]	validation_0-logloss:0.65576	validation_1-logloss:0.65603
# [1]	validation_0-logloss:0.62517	validation_1-logloss:0.62543
# [2]	validation_0-logloss:0.59979	validation_1-logloss:0.60010
# [3]	validation_0-logloss:0.57812	validation_1-logloss:0.57861
# [4]	validation_0-logloss:0.55992	validation_1-logloss:0.56048
# [5]	validation_0-logloss:0.54431	validation_1-logloss:0.54492
# [6]	validation_0-logloss:0.53075	validation_1-logloss:0.53145
# [7]	validation_0-logloss:0.51871	validation_1-logloss:0.51952
# [8]	validation_0-logloss:0.50853	validation_1-logloss:0.50941
# [9]	validation_0-logloss:0.49969	validation_1-logloss:0.50062
# [10]	validation_0-logloss:0.49192	validation_1-logloss:0.49282
# [11]	validation_0-logloss:0.48498	validation_1-logloss:0.48592
# [12]	validation_0-logloss:0.47891	validation_1-logloss:0.47991
# [13]	validation_0-logloss:0.47363	validation_1-logloss:0.47465
# [14]	validation_0-logloss:0.46861	validation_1-logloss:0.46967
# [15]	validation_0-logloss:0.46422	validation_1-logloss:0.46532
# [16]	validation_0-logloss:0.46018	validation_1-logloss:0.46135
# [17]	validation_0-logloss:0.45659	validation_1-logloss:0.45777
# [18]	validation_0-logloss:0.45334	validation_1-logloss:0.45456
# [19]	validation_0-logloss:0.45044	validation_1-logloss:0.45165
# [20]	validation_0-logloss:0.44780	validation_1-logloss:0.44908
# [21]	validation_0-logloss:0.44548	validation_1-logloss:0.44676
# [22]	validation_0-logloss:0.44322	validation_1-logloss:0.44453
# [23]	validation_0-logloss:0.44141	validation_1-logloss:0.44277
# [24]	validation_0-logloss:0.43936	validation_1-logloss:0.44073
# [25]	validation_0-logloss:0.43768	validation_1-logloss:0.43908
# [26]	validation_0-logloss:0.43589	validation_1-logloss:0.43736
# [27]	validation_0-logloss:0.43425	validation_1-logloss:0.43572
# [28]	validation_0-logloss:0.43239	validation_1-logloss:0.43391
# [29]	validation_0-logloss:0.43104	validation_1-logloss:0.43260
# [30]	validation_0-logloss:0.42955	validation_1-logloss:0.43114
# [31]	validation_0-logloss:0.42819	validation_1-logloss:0.42983
# [32]	validation_0-logloss:0.42721	validation_1-logloss:0.42889
# [33]	validation_0-logloss:0.42638	validation_1-logloss:0.42805
# [34]	validation_0-logloss:0.42564	validation_1-logloss:0.42733
# [35]	validation_0-logloss:0.42486	validation_1-logloss:0.42657
# [36]	validation_0-logloss:0.42387	validation_1-logloss:0.42562
# [37]	validation_0-logloss:0.42308	validation_1-logloss:0.42487
# [38]	validation_0-logloss:0.42232	validation_1-logloss:0.42415
# [39]	validation_0-logloss:0.42155	validation_1-logloss:0.42338
# [40]	validation_0-logloss:0.42111	validation_1-logloss:0.42295
# [41]	validation_0-logloss:0.42064	validation_1-logloss:0.42250
# [42]	validation_0-logloss:0.42023	validation_1-logloss:0.42211
# [43]	validation_0-logloss:0.41986	validation_1-logloss:0.42178
# [44]	validation_0-logloss:0.41924	validation_1-logloss:0.42117
# [45]	validation_0-logloss:0.41880	validation_1-logloss:0.42077
# [46]	validation_0-logloss:0.41814	validation_1-logloss:0.42014
# [47]	validation_0-logloss:0.41776	validation_1-logloss:0.41981
# [48]	validation_0-logloss:0.41742	validation_1-logloss:0.41946
# [49]	validation_0-logloss:0.41695	validation_1-logloss:0.41897
# [50]	validation_0-logloss:0.41658	validation_1-logloss:0.41864
# [51]	validation_0-logloss:0.41621	validation_1-logloss:0.41831
# [52]	validation_0-logloss:0.41588	validation_1-logloss:0.41799
# [53]	validation_0-logloss:0.41560	validation_1-logloss:0.41776
# [54]	validation_0-logloss:0.41533	validation_1-logloss:0.41752
# [55]	validation_0-logloss:0.41493	validation_1-logloss:0.41714
# [56]	validation_0-logloss:0.41465	validation_1-logloss:0.41688
# [57]	validation_0-logloss:0.41427	validation_1-logloss:0.41651
# [58]	validation_0-logloss:0.41384	validation_1-logloss:0.41610
# [59]	validation_0-logloss:0.41359	validation_1-logloss:0.41586
# [60]	validation_0-logloss:0.41336	validation_1-logloss:0.41566
# [61]	validation_0-logloss:0.41316	validation_1-logloss:0.41548
# [62]	validation_0-logloss:0.41277	validation_1-logloss:0.41512
# [63]	validation_0-logloss:0.41240	validation_1-logloss:0.41479
# [64]	validation_0-logloss:0.41214	validation_1-logloss:0.41455
# [65]	validation_0-logloss:0.41197	validation_1-logloss:0.41441
# [66]	validation_0-logloss:0.41180	validation_1-logloss:0.41429
# [67]	validation_0-logloss:0.41155	validation_1-logloss:0.41406
# [68]	validation_0-logloss:0.41125	validation_1-logloss:0.41379
# [69]	validation_0-logloss:0.41109	validation_1-logloss:0.41365
# [70]	validation_0-logloss:0.41093	validation_1-logloss:0.41350
# [71]	validation_0-logloss:0.41068	validation_1-logloss:0.41326
# [72]	validation_0-logloss:0.41054	validation_1-logloss:0.41314
# [73]	validation_0-logloss:0.41041	validation_1-logloss:0.41302
# [74]	validation_0-logloss:0.41017	validation_1-logloss:0.41280
# [75]	validation_0-logloss:0.41005	validation_1-logloss:0.41269
# [76]	validation_0-logloss:0.40992	validation_1-logloss:0.41258
# [77]	validation_0-logloss:0.40981	validation_1-logloss:0.41250
# [78]	validation_0-logloss:0.40970	validation_1-logloss:0.41241
# [79]	validation_0-logloss:0.40955	validation_1-logloss:0.41228
# [80]	validation_0-logloss:0.40946	validation_1-logloss:0.41223
# [81]	validation_0-logloss:0.40933	validation_1-logloss:0.41211
# [82]	validation_0-logloss:0.40924	validation_1-logloss:0.41203
# [83]	validation_0-logloss:0.40915	validation_1-logloss:0.41196
# [84]	validation_0-logloss:0.40906	validation_1-logloss:0.41190
# [85]	validation_0-logloss:0.40898	validation_1-logloss:0.41184
# [86]	validation_0-logloss:0.40876	validation_1-logloss:0.41166
# [87]	validation_0-logloss:0.40868	validation_1-logloss:0.41159
# [88]	validation_0-logloss:0.40854	validation_1-logloss:0.41145
# [89]	validation_0-logloss:0.40841	validation_1-logloss:0.41135
# [90]	validation_0-logloss:0.40832	validation_1-logloss:0.41127
# [91]	validation_0-logloss:0.40821	validation_1-logloss:0.41119
# [92]	validation_0-logloss:0.40815	validation_1-logloss:0.41115
# [93]	validation_0-logloss:0.40809	validation_1-logloss:0.41110
# [94]	validation_0-logloss:0.40790	validation_1-logloss:0.41094
# [95]	validation_0-logloss:0.40784	validation_1-logloss:0.41089
# [96]	validation_0-logloss:0.40777	validation_1-logloss:0.41084
# [97]	validation_0-logloss:0.40772	validation_1-logloss:0.41080
# [98]	validation_0-logloss:0.40767	validation_1-logloss:0.41077
# [99]	validation_0-logloss:0.40761	validation_1-logloss:0.41073
# [100]	validation_0-logloss:0.40745	validation_1-logloss:0.41059
# [101]	validation_0-logloss:0.40740	validation_1-logloss:0.41055
# [102]	validation_0-logloss:0.40733	validation_1-logloss:0.41051
# [103]	validation_0-logloss:0.40727	validation_1-logloss:0.41047
# [104]	validation_0-logloss:0.40721	validation_1-logloss:0.41042
# [105]	validation_0-logloss:0.40716	validation_1-logloss:0.41039
# [106]	validation_0-logloss:0.40709	validation_1-logloss:0.41033
# [107]	validation_0-logloss:0.40705	validation_1-logloss:0.41031
# [108]	validation_0-logloss:0.40696	validation_1-logloss:0.41024
# [109]	validation_0-logloss:0.40692	validation_1-logloss:0.41022
# [110]	validation_0-logloss:0.40685	validation_1-logloss:0.41016
# [111]	validation_0-logloss:0.40680	validation_1-logloss:0.41013
# [112]	validation_0-logloss:0.40676	validation_1-logloss:0.41012
# [113]	validation_0-logloss:0.40669	validation_1-logloss:0.41006
# [114]	validation_0-logloss:0.40666	validation_1-logloss:0.41004
# [115]	validation_0-logloss:0.40661	validation_1-logloss:0.41001
# [116]	validation_0-logloss:0.40658	validation_1-logloss:0.40999
# [117]	validation_0-logloss:0.40653	validation_1-logloss:0.40997
# [118]	validation_0-logloss:0.40647	validation_1-logloss:0.40993
# [119]	validation_0-logloss:0.40643	validation_1-logloss:0.40992
# [120]	validation_0-logloss:0.40639	validation_1-logloss:0.40990
# [121]	validation_0-logloss:0.40636	validation_1-logloss:0.40988
# [122]	validation_0-logloss:0.40633	validation_1-logloss:0.40987
# [123]	validation_0-logloss:0.40630	validation_1-logloss:0.40986
# [124]	validation_0-logloss:0.40621	validation_1-logloss:0.40981
# [125]	validation_0-logloss:0.40618	validation_1-logloss:0.40979
# [126]	validation_0-logloss:0.40614	validation_1-logloss:0.40976
# [127]	validation_0-logloss:0.40611	validation_1-logloss:0.40974
# [128]	validation_0-logloss:0.40607	validation_1-logloss:0.40972
# [129]	validation_0-logloss:0.40605	validation_1-logloss:0.40972
# [130]	validation_0-logloss:0.40602	validation_1-logloss:0.40970
# [131]	validation_0-logloss:0.40598	validation_1-logloss:0.40970
# [132]	validation_0-logloss:0.40595	validation_1-logloss:0.40969
# [133]	validation_0-logloss:0.40593	validation_1-logloss:0.40969
# [134]	validation_0-logloss:0.40589	validation_1-logloss:0.40968
# [135]	validation_0-logloss:0.40585	validation_1-logloss:0.40966
# [136]	validation_0-logloss:0.40583	validation_1-logloss:0.40965
# [137]	validation_0-logloss:0.40581	validation_1-logloss:0.40965
# [138]	validation_0-logloss:0.40579	validation_1-logloss:0.40964
# [139]	validation_0-logloss:0.40577	validation_1-logloss:0.40964
# [140]	validation_0-logloss:0.40574	validation_1-logloss:0.40963
# [141]	validation_0-logloss:0.40572	validation_1-logloss:0.40962
# [142]	validation_0-logloss:0.40569	validation_1-logloss:0.40961
# [143]	validation_0-logloss:0.40567	validation_1-logloss:0.40961
# [144]	validation_0-logloss:0.40565	validation_1-logloss:0.40960
# [145]	validation_0-logloss:0.40562	validation_1-logloss:0.40959
# [146]	validation_0-logloss:0.40560	validation_1-logloss:0.40958
# [147]	validation_0-logloss:0.40557	validation_1-logloss:0.40957
# [148]	validation_0-logloss:0.40554	validation_1-logloss:0.40956
# [149]	validation_0-logloss:0.40552	validation_1-logloss:0.40956
# [150]	validation_0-logloss:0.40550	validation_1-logloss:0.40956
# [151]	validation_0-logloss:0.40542	validation_1-logloss:0.40950
# [152]	validation_0-logloss:0.40540	validation_1-logloss:0.40949
# [153]	validation_0-logloss:0.40538	validation_1-logloss:0.40948
# [154]	validation_0-logloss:0.40536	validation_1-logloss:0.40947
# [155]	validation_0-logloss:0.40535	validation_1-logloss:0.40947
# [156]	validation_0-logloss:0.40531	validation_1-logloss:0.40945
# [157]	validation_0-logloss:0.40527	validation_1-logloss:0.40943
# [158]	validation_0-logloss:0.40524	validation_1-logloss:0.40942
# [159]	validation_0-logloss:0.40522	validation_1-logloss:0.40942
# [160]	validation_0-logloss:0.40521	validation_1-logloss:0.40942
# [161]	validation_0-logloss:0.40519	validation_1-logloss:0.40941
# [162]	validation_0-logloss:0.40517	validation_1-logloss:0.40941
# [163]	validation_0-logloss:0.40515	validation_1-logloss:0.40941
# [164]	validation_0-logloss:0.40513	validation_1-logloss:0.40941
# [165]	validation_0-logloss:0.40511	validation_1-logloss:0.40941
# [166]	validation_0-logloss:0.40509	validation_1-logloss:0.40940
# [167]	validation_0-logloss:0.40507	validation_1-logloss:0.40940
# [168]	validation_0-logloss:0.40505	validation_1-logloss:0.40939
# [169]	validation_0-logloss:0.40501	validation_1-logloss:0.40938
# [170]	validation_0-logloss:0.40499	validation_1-logloss:0.40937
# [171]	validation_0-logloss:0.40498	validation_1-logloss:0.40937
# [172]	validation_0-logloss:0.40495	validation_1-logloss:0.40937
# [173]	validation_0-logloss:0.40493	validation_1-logloss:0.40936
# [174]	validation_0-logloss:0.40491	validation_1-logloss:0.40936
# [175]	validation_0-logloss:0.40490	validation_1-logloss:0.40936
# [176]	validation_0-logloss:0.40487	validation_1-logloss:0.40936
# [177]	validation_0-logloss:0.40481	validation_1-logloss:0.40933
# [178]	validation_0-logloss:0.40480	validation_1-logloss:0.40933
# [179]	validation_0-logloss:0.40478	validation_1-logloss:0.40932
# [180]	validation_0-logloss:0.40477	validation_1-logloss:0.40932
# [181]	validation_0-logloss:0.40476	validation_1-logloss:0.40932
# [182]	validation_0-logloss:0.40472	validation_1-logloss:0.40930
# [183]	validation_0-logloss:0.40469	validation_1-logloss:0.40930
# [184]	validation_0-logloss:0.40466	validation_1-logloss:0.40929
# [185]	validation_0-logloss:0.40465	validation_1-logloss:0.40929
# [186]	validation_0-logloss:0.40463	validation_1-logloss:0.40929
# [187]	validation_0-logloss:0.40461	validation_1-logloss:0.40929
# [188]	validation_0-logloss:0.40460	validation_1-logloss:0.40929
# [189]	validation_0-logloss:0.40459	validation_1-logloss:0.40929
# [190]	validation_0-logloss:0.40456	validation_1-logloss:0.40928
# [191]	validation_0-logloss:0.40455	validation_1-logloss:0.40928
# [192]	validation_0-logloss:0.40454	validation_1-logloss:0.40928
# [193]	validation_0-logloss:0.40453	validation_1-logloss:0.40928
# [194]	validation_0-logloss:0.40451	validation_1-logloss:0.40928
# [195]	validation_0-logloss:0.40446	validation_1-logloss:0.40925
# [196]	validation_0-logloss:0.40445	validation_1-logloss:0.40926
# [197]	validation_0-logloss:0.40441	validation_1-logloss:0.40925
# [198]	validation_0-logloss:0.40439	validation_1-logloss:0.40925
# [199]	validation_0-logloss:0.40438	validation_1-logloss:0.40925
# [200]	validation_0-logloss:0.40437	validation_1-logloss:0.40925
# [201]	validation_0-logloss:0.40436	validation_1-logloss:0.40925
# [202]	validation_0-logloss:0.40435	validation_1-logloss:0.40925
# [203]	validation_0-logloss:0.40433	validation_1-logloss:0.40924
# [204]	validation_0-logloss:0.40430	validation_1-logloss:0.40923
# [205]	validation_0-logloss:0.40425	validation_1-logloss:0.40921
# [206]	validation_0-logloss:0.40424	validation_1-logloss:0.40921
# [207]	validation_0-logloss:0.40422	validation_1-logloss:0.40921
# [208]	validation_0-logloss:0.40422	validation_1-logloss:0.40921
# [209]	validation_0-logloss:0.40420	validation_1-logloss:0.40921
# [210]	validation_0-logloss:0.40418	validation_1-logloss:0.40921
# [211]	validation_0-logloss:0.40413	validation_1-logloss:0.40919
# [212]	validation_0-logloss:0.40411	validation_1-logloss:0.40919
# [213]	validation_0-logloss:0.40410	validation_1-logloss:0.40919
# [214]	validation_0-logloss:0.40409	validation_1-logloss:0.40918
# [215]	validation_0-logloss:0.40407	validation_1-logloss:0.40918
# [216]	validation_0-logloss:0.40407	validation_1-logloss:0.40918
# [217]	validation_0-logloss:0.40406	validation_1-logloss:0.40918
# [218]	validation_0-logloss:0.40404	validation_1-logloss:0.40918
# [219]	validation_0-logloss:0.40403	validation_1-logloss:0.40918
# [220]	validation_0-logloss:0.40401	validation_1-logloss:0.40918
# [221]	validation_0-logloss:0.40398	validation_1-logloss:0.40918
# [222]	validation_0-logloss:0.40397	validation_1-logloss:0.40918
# [223]	validation_0-logloss:0.40394	validation_1-logloss:0.40918
# [224]	validation_0-logloss:0.40393	validation_1-logloss:0.40918
# [225]	validation_0-logloss:0.40391	validation_1-logloss:0.40917
# [226]	validation_0-logloss:0.40388	validation_1-logloss:0.40917
# [227]	validation_0-logloss:0.40386	validation_1-logloss:0.40918
# [228]	validation_0-logloss:0.40385	validation_1-logloss:0.40918
# [229]	validation_0-logloss:0.40381	validation_1-logloss:0.40916
# [230]	validation_0-logloss:0.40380	validation_1-logloss:0.40916
# [231]	validation_0-logloss:0.40378	validation_1-logloss:0.40916
# [232]	validation_0-logloss:0.40377	validation_1-logloss:0.40916
# [233]	validation_0-logloss:0.40375	validation_1-logloss:0.40916
# [234]	validation_0-logloss:0.40374	validation_1-logloss:0.40916
# [235]	validation_0-logloss:0.40373	validation_1-logloss:0.40916
# [236]	validation_0-logloss:0.40371	validation_1-logloss:0.40916
# [237]	validation_0-logloss:0.40369	validation_1-logloss:0.40915
# [238]	validation_0-logloss:0.40368	validation_1-logloss:0.40915
# [239]	validation_0-logloss:0.40367	validation_1-logloss:0.40915
# [240]	validation_0-logloss:0.40365	validation_1-logloss:0.40915
# [241]	validation_0-logloss:0.40362	validation_1-logloss:0.40914
# [242]	validation_0-logloss:0.40360	validation_1-logloss:0.40914
# [243]	validation_0-logloss:0.40360	validation_1-logloss:0.40914
# [244]	validation_0-logloss:0.40359	validation_1-logloss:0.40914
# [245]	validation_0-logloss:0.40358	validation_1-logloss:0.40914
# [246]	validation_0-logloss:0.40356	validation_1-logloss:0.40914
# [247]	validation_0-logloss:0.40354	validation_1-logloss:0.40914
# [248]	validation_0-logloss:0.40353	validation_1-logloss:0.40915
# [249]	validation_0-logloss:0.40352	validation_1-logloss:0.40915
# [250]	validation_0-logloss:0.40348	validation_1-logloss:0.40913
# [251]	validation_0-logloss:0.40346	validation_1-logloss:0.40913
# [252]	validation_0-logloss:0.40344	validation_1-logloss:0.40912
# [253]	validation_0-logloss:0.40343	validation_1-logloss:0.40913
# [254]	validation_0-logloss:0.40342	validation_1-logloss:0.40913
# [255]	validation_0-logloss:0.40340	validation_1-logloss:0.40913
# [256]	validation_0-logloss:0.40339	validation_1-logloss:0.40913
# [257]	validation_0-logloss:0.40337	validation_1-logloss:0.40913
# [258]	validation_0-logloss:0.40336	validation_1-logloss:0.40912
# [259]	validation_0-logloss:0.40334	validation_1-logloss:0.40912
# [260]	validation_0-logloss:0.40333	validation_1-logloss:0.40912
# [261]	validation_0-logloss:0.40332	validation_1-logloss:0.40912
# [262]	validation_0-logloss:0.40330	validation_1-logloss:0.40912
# [263]	validation_0-logloss:0.40329	validation_1-logloss:0.40912
# [264]	validation_0-logloss:0.40328	validation_1-logloss:0.40912
# [265]	validation_0-logloss:0.40326	validation_1-logloss:0.40912
# [266]	validation_0-logloss:0.40325	validation_1-logloss:0.40912
# [267]	validation_0-logloss:0.40325	validation_1-logloss:0.40912
# [268]	validation_0-logloss:0.40323	validation_1-logloss:0.40912
# [269]	validation_0-logloss:0.40320	validation_1-logloss:0.40912
# [270]	validation_0-logloss:0.40317	validation_1-logloss:0.40911
# [271]	validation_0-logloss:0.40315	validation_1-logloss:0.40911
# [272]	validation_0-logloss:0.40313	validation_1-logloss:0.40912
# [273]	validation_0-logloss:0.40311	validation_1-logloss:0.40912
# [274]	validation_0-logloss:0.40311	validation_1-logloss:0.40912
# [275]	validation_0-logloss:0.40310	validation_1-logloss:0.40911
# [276]	validation_0-logloss:0.40307	validation_1-logloss:0.40910
# [277]	validation_0-logloss:0.40307	validation_1-logloss:0.40911
# [278]	validation_0-logloss:0.40306	validation_1-logloss:0.40911
# [279]	validation_0-logloss:0.40304	validation_1-logloss:0.40911
# [280]	validation_0-logloss:0.40304	validation_1-logloss:0.40911
# [281]	validation_0-logloss:0.40302	validation_1-logloss:0.40911
# [282]	validation_0-logloss:0.40300	validation_1-logloss:0.40910
# [283]	validation_0-logloss:0.40297	validation_1-logloss:0.40909
# [284]	validation_0-logloss:0.40295	validation_1-logloss:0.40910
# [285]	validation_0-logloss:0.40293	validation_1-logloss:0.40910
# [286]	validation_0-logloss:0.40293	validation_1-logloss:0.40910
# [287]	validation_0-logloss:0.40292	validation_1-logloss:0.40910
# [288]	validation_0-logloss:0.40290	validation_1-logloss:0.40910
# [289]	validation_0-logloss:0.40288	validation_1-logloss:0.40910
# [290]	validation_0-logloss:0.40286	validation_1-logloss:0.40909
# [291]	validation_0-logloss:0.40282	validation_1-logloss:0.40907
# [292]	validation_0-logloss:0.40281	validation_1-logloss:0.40908
# [293]	validation_0-logloss:0.40280	validation_1-logloss:0.40908
# [294]	validation_0-logloss:0.40278	validation_1-logloss:0.40908
# [295]	validation_0-logloss:0.40277	validation_1-logloss:0.40908
# [296]	validation_0-logloss:0.40276	validation_1-logloss:0.40909
# [297]	validation_0-logloss:0.40274	validation_1-logloss:0.40909
# [298]	validation_0-logloss:0.40273	validation_1-logloss:0.40910
# [299]	validation_0-logloss:0.40273	validation_1-logloss:0.40910
# [300]	validation_0-logloss:0.40273	validation_1-logloss:0.40910
# [301]	validation_0-logloss:0.40271	validation_1-logloss:0.40910
# [302]	validation_0-logloss:0.40270	validation_1-logloss:0.40910
# [303]	validation_0-logloss:0.40270	validation_1-logloss:0.40910
# [304]	validation_0-logloss:0.40268	validation_1-logloss:0.40910
# [305]	validation_0-logloss:0.40267	validation_1-logloss:0.40910
# [306]	validation_0-logloss:0.40264	validation_1-logloss:0.40910
# [307]	validation_0-logloss:0.40262	validation_1-logloss:0.40909
# [308]	validation_0-logloss:0.40259	validation_1-logloss:0.40908
# [309]	validation_0-logloss:0.40259	validation_1-logloss:0.40909
# [310]	validation_0-logloss:0.40257	validation_1-logloss:0.40908
# [311]	validation_0-logloss:0.40257	validation_1-logloss:0.40908
# [312]	validation_0-logloss:0.40254	validation_1-logloss:0.40907
# [313]	validation_0-logloss:0.40253	validation_1-logloss:0.40907
# [314]	validation_0-logloss:0.40251	validation_1-logloss:0.40907
# [315]	validation_0-logloss:0.40249	validation_1-logloss:0.40907
# [316]	validation_0-logloss:0.40247	validation_1-logloss:0.40907
# [317]	validation_0-logloss:0.40246	validation_1-logloss:0.40907
# [318]	validation_0-logloss:0.40244	validation_1-logloss:0.40908
# [319]	validation_0-logloss:0.40242	validation_1-logloss:0.40908
# [320]	validation_0-logloss:0.40240	validation_1-logloss:0.40908
# [321]	validation_0-logloss:0.40239	validation_1-logloss:0.40908
# [322]	validation_0-logloss:0.40237	validation_1-logloss:0.40908
# [323]	validation_0-logloss:0.40237	validation_1-logloss:0.40908
# [324]	validation_0-logloss:0.40235	validation_1-logloss:0.40908
# [325]	validation_0-logloss:0.40233	validation_1-logloss:0.40908
# [326]	validation_0-logloss:0.40232	validation_1-logloss:0.40908
# [327]	validation_0-logloss:0.40231	validation_1-logloss:0.40908
# [328]	validation_0-logloss:0.40228	validation_1-logloss:0.40908
# [329]	validation_0-logloss:0.40226	validation_1-logloss:0.40907
# [330]	validation_0-logloss:0.40225	validation_1-logloss:0.40908
# [331]	validation_0-logloss:0.40223	validation_1-logloss:0.40908
# [332]	validation_0-logloss:0.40222	validation_1-logloss:0.40908
# [333]	validation_0-logloss:0.40220	validation_1-logloss:0.40909
# [334]	validation_0-logloss:0.40219	validation_1-logloss:0.40909
# [335]	validation_0-logloss:0.40218	validation_1-logloss:0.40909
# [336]	validation_0-logloss:0.40217	validation_1-logloss:0.40909
# [337]	validation_0-logloss:0.40215	validation_1-logloss:0.40910
# [338]	validation_0-logloss:0.40213	validation_1-logloss:0.40909
# [339]	validation_0-logloss:0.40211	validation_1-logloss:0.40909
# [340]	validation_0-logloss:0.40210	validation_1-logloss:0.40909
# [341]	validation_0-logloss:0.40208	validation_1-logloss:0.40909
# [342]	validation_0-logloss:0.40208	validation_1-logloss:0.40909
# [343]	validation_0-logloss:0.40206	validation_1-logloss:0.40909
# [344]	validation_0-logloss:0.40205	validation_1-logloss:0.40909
# [345]	validation_0-logloss:0.40202	validation_1-logloss:0.40909
# [346]	validation_0-logloss:0.40200	validation_1-logloss:0.40909
# [347]	validation_0-logloss:0.40198	validation_1-logloss:0.40909
# [348]	validation_0-logloss:0.40197	validation_1-logloss:0.40910
# [349]	validation_0-logloss:0.40197	validation_1-logloss:0.40910
# [350]	validation_0-logloss:0.40196	validation_1-logloss:0.40910
# [351]	validation_0-logloss:0.40195	validation_1-logloss:0.40910
# [352]	validation_0-logloss:0.40193	validation_1-logloss:0.40910
# [353]	validation_0-logloss:0.40192	validation_1-logloss:0.40910
# [354]	validation_0-logloss:0.40190	validation_1-logloss:0.40910
# [355]	validation_0-logloss:0.40187	validation_1-logloss:0.40910
# [356]	validation_0-logloss:0.40186	validation_1-logloss:0.40911
# [357]	validation_0-logloss:0.40185	validation_1-logloss:0.40911
# [358]	validation_0-logloss:0.40184	validation_1-logloss:0.40911
# [359]	validation_0-logloss:0.40182	validation_1-logloss:0.40911
# [360]	validation_0-logloss:0.40180	validation_1-logloss:0.40911
# [361]	validation_0-logloss:0.40178	validation_1-logloss:0.40911
# [362]	validation_0-logloss:0.40176	validation_1-logloss:0.40912
# [363]	validation_0-logloss:0.40175	validation_1-logloss:0.40912

# %% [markdown]
# ##### For 10 ML

# %%
# XGBoost with only the kinematic variables of the leptons

iterations_ML = 10

print('ML iteration 1')

# CLASSIFIER
classifier = XGBClassifier(
    n_estimators=2500,
    learning_rate=0.1,
    reg_lambda=0.0,reg_alpha=0.0,
    gamma=0.0,objective='binary:logistic',
    max_depth=5)

ran_ind = np.random.choice(np.arange(len(X_mon_train)), size = len(X_mon_train), replace = True)

# FIT
classifier.fit(X_mon_train[ran_ind],y_mon_train[ran_ind],eval_set=[(X_mon_train[ran_ind], y_mon_train[ran_ind]), (X_mon_val, y_mon_val)],
        eval_metric='logloss',early_stopping_rounds=50,#early stopping
        verbose=True)

# PREDICTIONS
y_pred_xg_aux = classifier.predict_proba(X_mon_test).T[1]
y_pred_xg_auxRE = np.reshape(y_pred_xg_aux, (1,len(y_pred_xg_aux)))


# ROC
fpr_mon_xg, tpr_mon_xg, _ = roc_curve(y_mon_test, y_pred_xg_aux)
roc_auc_xg = auc(fpr_mon_xg, tpr_mon_xg)


# PLOT THE ROC WITH AUC
fig = plt.figure(figsize=(6, 6))
gs = gridspec.GridSpec(1, 1) 
ax0 = plt.subplot(gs[0])
ax0.yaxis.set_ticks_position('both')
ax0.xaxis.set_ticks_position('both')
ax0.tick_params(direction="in",which="both")
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
ax0.minorticks_on()


plt.plot(tpr_mon_xg,1-fpr_mon_xg,label="$f_{1}$, AUC = %0.2f" % roc_auc_xg,color="orange",ls=":",lw=4)
plt.plot([1,0],[0,1],ls=":",color="grey")
plt.xlabel("True Positive Rate",fontsize=16)
plt.ylabel("1 $-$ False Positive Rate",fontsize=16)
plt.legend()
plt.title(r"SSM Z' - XGBoost",fontsize=16)
plt.xlim([0,1])
plt.ylim([0,1])
plt.yticks([0.2,0.4,0.6,0.8,1.])
plt.legend(frameon=False,fontsize=16)
plt.show()




print('\n ########################################\n')





for it in range(1,iterations_ML):

    print('ML iteration ', it)
    
    # CLASSIFIER
    classifier = XGBClassifier(
        n_estimators=2500,
        learning_rate=0.1,
        reg_lambda=0.0,reg_alpha=0.0,
        gamma=0.0,objective='binary:logistic',
        max_depth=5)

    ran_ind = np.random.choice(np.arange(len(X_mon_train)), size = len(X_mon_train), replace = True)

    # FIT
    classifier.fit(X_mon_train[ran_ind],y_mon_train[ran_ind],eval_set=[(X_mon_train[ran_ind], y_mon_train[ran_ind]), (X_mon_val, y_mon_val)],
            eval_metric='logloss',early_stopping_rounds=50,#early stopping
            verbose=True)

    # PREDICTIONS
    y_pred_xg_aux_it = classifier.predict_proba(X_mon_test).T[1]
    y_pred_xg_auxRE_it = np.reshape(y_pred_xg_aux_it, (1,len(y_pred_xg_aux_it)))
    
    y_pred_xg_auxRE = np.concatenate([y_pred_xg_auxRE,y_pred_xg_auxRE_it])


    # ROC
    fpr_mon_xg, tpr_mon_xg, _ = roc_curve(y_mon_test, y_pred_xg_aux)
    roc_auc_xg = auc(fpr_mon_xg, tpr_mon_xg)


    # PLOT THE ROC WITH AUC
    fig = plt.figure(figsize=(6, 6))
    gs = gridspec.GridSpec(1, 1) 
    ax0 = plt.subplot(gs[0])
    ax0.yaxis.set_ticks_position('both')
    ax0.xaxis.set_ticks_position('both')
    ax0.tick_params(direction="in",which="both")
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
    ax0.minorticks_on()


    plt.plot(tpr_mon_xg,1-fpr_mon_xg,label="$f_{1}$, AUC = %0.2f" % roc_auc_xg,color="orange",ls=":",lw=4)
    plt.plot([1,0],[0,1],ls=":",color="grey")
    plt.xlabel("True Positive Rate",fontsize=16)
    plt.ylabel("1 $-$ False Positive Rate",fontsize=16)
    plt.legend()
    plt.title(r"SSM Z' - XGBoost",fontsize=16)
    plt.xlim([0,1])
    plt.ylim([0,1])
    plt.yticks([0.2,0.4,0.6,0.8,1.])
    plt.legend(frameon=False,fontsize=16)
    plt.show()
    
    print('\n ########################################\n')
    
    
y_pred_xg = np.mean(y_pred_xg_auxRE, axis=0)
# Out:
# ML iteration 1
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [0]	validation_0-logloss:0.65598	validation_1-logloss:0.65621
# [1]	validation_0-logloss:0.62564	validation_1-logloss:0.62581
# [2]	validation_0-logloss:0.60008	validation_1-logloss:0.60049
# [3]	validation_0-logloss:0.57871	validation_1-logloss:0.57918
# [4]	validation_0-logloss:0.56048	validation_1-logloss:0.56105
# [5]	validation_0-logloss:0.54491	validation_1-logloss:0.54555
# [6]	validation_0-logloss:0.53108	validation_1-logloss:0.53175
# [7]	validation_0-logloss:0.51924	validation_1-logloss:0.52000
# [8]	validation_0-logloss:0.50880	validation_1-logloss:0.50967
# [9]	validation_0-logloss:0.49994	validation_1-logloss:0.50086
# [10]	validation_0-logloss:0.49202	validation_1-logloss:0.49301
# [11]	validation_0-logloss:0.48493	validation_1-logloss:0.48597
# [12]	validation_0-logloss:0.47875	validation_1-logloss:0.47984
# [13]	validation_0-logloss:0.47322	validation_1-logloss:0.47435
# [14]	validation_0-logloss:0.46834	validation_1-logloss:0.46954
# [15]	validation_0-logloss:0.46401	validation_1-logloss:0.46521
# [16]	validation_0-logloss:0.45993	validation_1-logloss:0.46116
# [17]	validation_0-logloss:0.45638	validation_1-logloss:0.45765
# [18]	validation_0-logloss:0.45330	validation_1-logloss:0.45459
# [19]	validation_0-logloss:0.45055	validation_1-logloss:0.45184
# [20]	validation_0-logloss:0.44775	validation_1-logloss:0.44906
# [21]	validation_0-logloss:0.44503	validation_1-logloss:0.44637
# [22]	validation_0-logloss:0.44315	validation_1-logloss:0.44453
# [23]	validation_0-logloss:0.44119	validation_1-logloss:0.44262
# [24]	validation_0-logloss:0.43932	validation_1-logloss:0.44076
# [25]	validation_0-logloss:0.43716	validation_1-logloss:0.43863
# [26]	validation_0-logloss:0.43561	validation_1-logloss:0.43711
# [27]	validation_0-logloss:0.43410	validation_1-logloss:0.43564
# [28]	validation_0-logloss:0.43209	validation_1-logloss:0.43372
# [29]	validation_0-logloss:0.43093	validation_1-logloss:0.43260
# [30]	validation_0-logloss:0.42974	validation_1-logloss:0.43148
# [31]	validation_0-logloss:0.42857	validation_1-logloss:0.43034
# [32]	validation_0-logloss:0.42738	validation_1-logloss:0.42920
# [33]	validation_0-logloss:0.42667	validation_1-logloss:0.42851
# [34]	validation_0-logloss:0.42589	validation_1-logloss:0.42777
# [35]	validation_0-logloss:0.42509	validation_1-logloss:0.42701
# [36]	validation_0-logloss:0.42422	validation_1-logloss:0.42618
# [37]	validation_0-logloss:0.42330	validation_1-logloss:0.42534
# [38]	validation_0-logloss:0.42259	validation_1-logloss:0.42467
# [39]	validation_0-logloss:0.42213	validation_1-logloss:0.42424
# [40]	validation_0-logloss:0.42147	validation_1-logloss:0.42362
# [41]	validation_0-logloss:0.42090	validation_1-logloss:0.42307
# [42]	validation_0-logloss:0.42020	validation_1-logloss:0.42243
# [43]	validation_0-logloss:0.41971	validation_1-logloss:0.42197
# [44]	validation_0-logloss:0.41931	validation_1-logloss:0.42159
# [45]	validation_0-logloss:0.41880	validation_1-logloss:0.42115
# [46]	validation_0-logloss:0.41817	validation_1-logloss:0.42056
# [47]	validation_0-logloss:0.41772	validation_1-logloss:0.42017
# [48]	validation_0-logloss:0.41719	validation_1-logloss:0.41965
# [49]	validation_0-logloss:0.41685	validation_1-logloss:0.41931
# [50]	validation_0-logloss:0.41654	validation_1-logloss:0.41906
# [51]	validation_0-logloss:0.41622	validation_1-logloss:0.41880
# [52]	validation_0-logloss:0.41591	validation_1-logloss:0.41852
# [53]	validation_0-logloss:0.41559	validation_1-logloss:0.41824
# [54]	validation_0-logloss:0.41506	validation_1-logloss:0.41776
# [55]	validation_0-logloss:0.41479	validation_1-logloss:0.41754
# [56]	validation_0-logloss:0.41457	validation_1-logloss:0.41735
# [57]	validation_0-logloss:0.41432	validation_1-logloss:0.41714
# [58]	validation_0-logloss:0.41368	validation_1-logloss:0.41656
# [59]	validation_0-logloss:0.41341	validation_1-logloss:0.41630
# [60]	validation_0-logloss:0.41305	validation_1-logloss:0.41602
# [61]	validation_0-logloss:0.41280	validation_1-logloss:0.41582
# [62]	validation_0-logloss:0.41250	validation_1-logloss:0.41558
# [63]	validation_0-logloss:0.41208	validation_1-logloss:0.41521
# [64]	validation_0-logloss:0.41187	validation_1-logloss:0.41501
# [65]	validation_0-logloss:0.41153	validation_1-logloss:0.41473
# [66]	validation_0-logloss:0.41139	validation_1-logloss:0.41460
# [67]	validation_0-logloss:0.41117	validation_1-logloss:0.41444
# [68]	validation_0-logloss:0.41098	validation_1-logloss:0.41428
# [69]	validation_0-logloss:0.41078	validation_1-logloss:0.41411
# [70]	validation_0-logloss:0.41054	validation_1-logloss:0.41391
# [71]	validation_0-logloss:0.41040	validation_1-logloss:0.41380
# [72]	validation_0-logloss:0.41015	validation_1-logloss:0.41358
# [73]	validation_0-logloss:0.41001	validation_1-logloss:0.41349
# [74]	validation_0-logloss:0.40981	validation_1-logloss:0.41334
# [75]	validation_0-logloss:0.40969	validation_1-logloss:0.41326
# [76]	validation_0-logloss:0.40932	validation_1-logloss:0.41296
# [77]	validation_0-logloss:0.40919	validation_1-logloss:0.41287
# [78]	validation_0-logloss:0.40892	validation_1-logloss:0.41265
# [79]	validation_0-logloss:0.40875	validation_1-logloss:0.41250
# [80]	validation_0-logloss:0.40864	validation_1-logloss:0.41243
# [81]	validation_0-logloss:0.40849	validation_1-logloss:0.41233
# [82]	validation_0-logloss:0.40837	validation_1-logloss:0.41224
# [83]	validation_0-logloss:0.40825	validation_1-logloss:0.41216
# [84]	validation_0-logloss:0.40816	validation_1-logloss:0.41209
# [85]	validation_0-logloss:0.40802	validation_1-logloss:0.41201
# [86]	validation_0-logloss:0.40792	validation_1-logloss:0.41193
# [87]	validation_0-logloss:0.40784	validation_1-logloss:0.41189
# [88]	validation_0-logloss:0.40776	validation_1-logloss:0.41185
# [89]	validation_0-logloss:0.40763	validation_1-logloss:0.41174
# [90]	validation_0-logloss:0.40756	validation_1-logloss:0.41170
# [91]	validation_0-logloss:0.40733	validation_1-logloss:0.41152
# [92]	validation_0-logloss:0.40727	validation_1-logloss:0.41148
# [93]	validation_0-logloss:0.40718	validation_1-logloss:0.41143
# [94]	validation_0-logloss:0.40712	validation_1-logloss:0.41138
# [95]	validation_0-logloss:0.40704	validation_1-logloss:0.41134
# [96]	validation_0-logloss:0.40684	validation_1-logloss:0.41119
# [97]	validation_0-logloss:0.40673	validation_1-logloss:0.41111
# [98]	validation_0-logloss:0.40666	validation_1-logloss:0.41109
# [99]	validation_0-logloss:0.40657	validation_1-logloss:0.41103
# [100]	validation_0-logloss:0.40648	validation_1-logloss:0.41098
# [101]	validation_0-logloss:0.40640	validation_1-logloss:0.41093
# [102]	validation_0-logloss:0.40630	validation_1-logloss:0.41086
# [103]	validation_0-logloss:0.40624	validation_1-logloss:0.41085
# [104]	validation_0-logloss:0.40610	validation_1-logloss:0.41075
# [105]	validation_0-logloss:0.40601	validation_1-logloss:0.41069
# [106]	validation_0-logloss:0.40595	validation_1-logloss:0.41067
# [107]	validation_0-logloss:0.40590	validation_1-logloss:0.41065
# [108]	validation_0-logloss:0.40585	validation_1-logloss:0.41062
# [109]	validation_0-logloss:0.40579	validation_1-logloss:0.41059
# [110]	validation_0-logloss:0.40573	validation_1-logloss:0.41057
# [111]	validation_0-logloss:0.40566	validation_1-logloss:0.41054
# [112]	validation_0-logloss:0.40560	validation_1-logloss:0.41051
# [113]	validation_0-logloss:0.40553	validation_1-logloss:0.41048
# [114]	validation_0-logloss:0.40546	validation_1-logloss:0.41045
# [115]	validation_0-logloss:0.40538	validation_1-logloss:0.41041
# [116]	validation_0-logloss:0.40530	validation_1-logloss:0.41037
# [117]	validation_0-logloss:0.40524	validation_1-logloss:0.41034
# [118]	validation_0-logloss:0.40518	validation_1-logloss:0.41032
# [119]	validation_0-logloss:0.40514	validation_1-logloss:0.41030
# [120]	validation_0-logloss:0.40509	validation_1-logloss:0.41028
# [121]	validation_0-logloss:0.40506	validation_1-logloss:0.41028
# [122]	validation_0-logloss:0.40501	validation_1-logloss:0.41025
# [123]	validation_0-logloss:0.40496	validation_1-logloss:0.41024
# [124]	validation_0-logloss:0.40491	validation_1-logloss:0.41022
# [125]	validation_0-logloss:0.40487	validation_1-logloss:0.41021
# [126]	validation_0-logloss:0.40484	validation_1-logloss:0.41021
# [127]	validation_0-logloss:0.40480	validation_1-logloss:0.41021
# [128]	validation_0-logloss:0.40476	validation_1-logloss:0.41020
# [129]	validation_0-logloss:0.40473	validation_1-logloss:0.41019
# [130]	validation_0-logloss:0.40465	validation_1-logloss:0.41015
# [131]	validation_0-logloss:0.40459	validation_1-logloss:0.41012
# [132]	validation_0-logloss:0.40453	validation_1-logloss:0.41010
# [133]	validation_0-logloss:0.40449	validation_1-logloss:0.41010
# [134]	validation_0-logloss:0.40446	validation_1-logloss:0.41009
# [135]	validation_0-logloss:0.40441	validation_1-logloss:0.41007
# [136]	validation_0-logloss:0.40438	validation_1-logloss:0.41007
# [137]	validation_0-logloss:0.40434	validation_1-logloss:0.41006
# [138]	validation_0-logloss:0.40427	validation_1-logloss:0.41004
# [139]	validation_0-logloss:0.40423	validation_1-logloss:0.41004
# [140]	validation_0-logloss:0.40418	validation_1-logloss:0.41003
# [141]	validation_0-logloss:0.40415	validation_1-logloss:0.41004
# [142]	validation_0-logloss:0.40412	validation_1-logloss:0.41002
# [143]	validation_0-logloss:0.40408	validation_1-logloss:0.41001
# [144]	validation_0-logloss:0.40401	validation_1-logloss:0.41000
# [145]	validation_0-logloss:0.40398	validation_1-logloss:0.41000
# [146]	validation_0-logloss:0.40393	validation_1-logloss:0.40998
# [147]	validation_0-logloss:0.40390	validation_1-logloss:0.40998
# [148]	validation_0-logloss:0.40381	validation_1-logloss:0.40993
# [149]	validation_0-logloss:0.40376	validation_1-logloss:0.40993
# [150]	validation_0-logloss:0.40373	validation_1-logloss:0.40992
# [151]	validation_0-logloss:0.40368	validation_1-logloss:0.40993
# [152]	validation_0-logloss:0.40362	validation_1-logloss:0.40991
# [153]	validation_0-logloss:0.40358	validation_1-logloss:0.40991
# [154]	validation_0-logloss:0.40353	validation_1-logloss:0.40991
# [155]	validation_0-logloss:0.40350	validation_1-logloss:0.40990
# [156]	validation_0-logloss:0.40348	validation_1-logloss:0.40990
# [157]	validation_0-logloss:0.40344	validation_1-logloss:0.40989
# [158]	validation_0-logloss:0.40338	validation_1-logloss:0.40988
# [159]	validation_0-logloss:0.40335	validation_1-logloss:0.40988
# [160]	validation_0-logloss:0.40332	validation_1-logloss:0.40988
# [161]	validation_0-logloss:0.40326	validation_1-logloss:0.40986
# [162]	validation_0-logloss:0.40322	validation_1-logloss:0.40985
# [163]	validation_0-logloss:0.40320	validation_1-logloss:0.40985
# [164]	validation_0-logloss:0.40316	validation_1-logloss:0.40986
# [165]	validation_0-logloss:0.40313	validation_1-logloss:0.40985
# [166]	validation_0-logloss:0.40310	validation_1-logloss:0.40986
# [167]	validation_0-logloss:0.40307	validation_1-logloss:0.40985
# [168]	validation_0-logloss:0.40304	validation_1-logloss:0.40984
# [169]	validation_0-logloss:0.40302	validation_1-logloss:0.40984
# [170]	validation_0-logloss:0.40294	validation_1-logloss:0.40981
# [171]	validation_0-logloss:0.40291	validation_1-logloss:0.40981
# [172]	validation_0-logloss:0.40286	validation_1-logloss:0.40980
# [173]	validation_0-logloss:0.40282	validation_1-logloss:0.40981
# [174]	validation_0-logloss:0.40276	validation_1-logloss:0.40978
# [175]	validation_0-logloss:0.40272	validation_1-logloss:0.40978
# [176]	validation_0-logloss:0.40270	validation_1-logloss:0.40978
# [177]	validation_0-logloss:0.40267	validation_1-logloss:0.40979
# [178]	validation_0-logloss:0.40262	validation_1-logloss:0.40979
# [179]	validation_0-logloss:0.40260	validation_1-logloss:0.40978
# [180]	validation_0-logloss:0.40256	validation_1-logloss:0.40978
# [181]	validation_0-logloss:0.40252	validation_1-logloss:0.40978
# [182]	validation_0-logloss:0.40250	validation_1-logloss:0.40978
# [183]	validation_0-logloss:0.40245	validation_1-logloss:0.40976
# [184]	validation_0-logloss:0.40241	validation_1-logloss:0.40976
# [185]	validation_0-logloss:0.40238	validation_1-logloss:0.40976
# [186]	validation_0-logloss:0.40234	validation_1-logloss:0.40975
# [187]	validation_0-logloss:0.40230	validation_1-logloss:0.40974
# [188]	validation_0-logloss:0.40226	validation_1-logloss:0.40975
# [189]	validation_0-logloss:0.40224	validation_1-logloss:0.40974
# [190]	validation_0-logloss:0.40221	validation_1-logloss:0.40975
# [191]	validation_0-logloss:0.40217	validation_1-logloss:0.40975
# [192]	validation_0-logloss:0.40214	validation_1-logloss:0.40974
# [193]	validation_0-logloss:0.40211	validation_1-logloss:0.40974
# [194]	validation_0-logloss:0.40208	validation_1-logloss:0.40974
# [195]	validation_0-logloss:0.40205	validation_1-logloss:0.40974
# [196]	validation_0-logloss:0.40204	validation_1-logloss:0.40973
# [197]	validation_0-logloss:0.40202	validation_1-logloss:0.40973
# [198]	validation_0-logloss:0.40198	validation_1-logloss:0.40974
# [199]	validation_0-logloss:0.40194	validation_1-logloss:0.40974
# [200]	validation_0-logloss:0.40191	validation_1-logloss:0.40974
# [201]	validation_0-logloss:0.40189	validation_1-logloss:0.40974
# [202]	validation_0-logloss:0.40184	validation_1-logloss:0.40973
# [203]	validation_0-logloss:0.40180	validation_1-logloss:0.40972
# [204]	validation_0-logloss:0.40178	validation_1-logloss:0.40972
# [205]	validation_0-logloss:0.40176	validation_1-logloss:0.40972
# [206]	validation_0-logloss:0.40173	validation_1-logloss:0.40972
# [207]	validation_0-logloss:0.40170	validation_1-logloss:0.40972
# [208]	validation_0-logloss:0.40166	validation_1-logloss:0.40973
# [209]	validation_0-logloss:0.40162	validation_1-logloss:0.40973
# [210]	validation_0-logloss:0.40161	validation_1-logloss:0.40973
# [211]	validation_0-logloss:0.40160	validation_1-logloss:0.40973
# [212]	validation_0-logloss:0.40159	validation_1-logloss:0.40973
# [213]	validation_0-logloss:0.40157	validation_1-logloss:0.40973
# [214]	validation_0-logloss:0.40153	validation_1-logloss:0.40971
# [215]	validation_0-logloss:0.40151	validation_1-logloss:0.40972
# [216]	validation_0-logloss:0.40148	validation_1-logloss:0.40972
# [217]	validation_0-logloss:0.40145	validation_1-logloss:0.40971
# [218]	validation_0-logloss:0.40142	validation_1-logloss:0.40970
# [219]	validation_0-logloss:0.40141	validation_1-logloss:0.40970
# [220]	validation_0-logloss:0.40138	validation_1-logloss:0.40971
# [221]	validation_0-logloss:0.40135	validation_1-logloss:0.40970
# [222]	validation_0-logloss:0.40132	validation_1-logloss:0.40970
# [223]	validation_0-logloss:0.40130	validation_1-logloss:0.40970
# [224]	validation_0-logloss:0.40127	validation_1-logloss:0.40971
# [225]	validation_0-logloss:0.40123	validation_1-logloss:0.40970
# [226]	validation_0-logloss:0.40120	validation_1-logloss:0.40970
# [227]	validation_0-logloss:0.40115	validation_1-logloss:0.40968
# [228]	validation_0-logloss:0.40114	validation_1-logloss:0.40968
# [229]	validation_0-logloss:0.40111	validation_1-logloss:0.40968
# [230]	validation_0-logloss:0.40110	validation_1-logloss:0.40968
# [231]	validation_0-logloss:0.40108	validation_1-logloss:0.40968
# [232]	validation_0-logloss:0.40103	validation_1-logloss:0.40968
# [233]	validation_0-logloss:0.40100	validation_1-logloss:0.40968
# [234]	validation_0-logloss:0.40094	validation_1-logloss:0.40967
# [235]	validation_0-logloss:0.40092	validation_1-logloss:0.40967
# [236]	validation_0-logloss:0.40090	validation_1-logloss:0.40968
# [237]	validation_0-logloss:0.40087	validation_1-logloss:0.40969
# [238]	validation_0-logloss:0.40085	validation_1-logloss:0.40969
# [239]	validation_0-logloss:0.40084	validation_1-logloss:0.40969
# [240]	validation_0-logloss:0.40081	validation_1-logloss:0.40969
# [241]	validation_0-logloss:0.40077	validation_1-logloss:0.40969
# [242]	validation_0-logloss:0.40073	validation_1-logloss:0.40969
# [243]	validation_0-logloss:0.40069	validation_1-logloss:0.40968
# [244]	validation_0-logloss:0.40066	validation_1-logloss:0.40969
# [245]	validation_0-logloss:0.40065	validation_1-logloss:0.40969
# [246]	validation_0-logloss:0.40065	validation_1-logloss:0.40969
# [247]	validation_0-logloss:0.40061	validation_1-logloss:0.40969
# [248]	validation_0-logloss:0.40059	validation_1-logloss:0.40969
# [249]	validation_0-logloss:0.40056	validation_1-logloss:0.40969
# [250]	validation_0-logloss:0.40051	validation_1-logloss:0.40968
# [251]	validation_0-logloss:0.40046	validation_1-logloss:0.40969
# [252]	validation_0-logloss:0.40043	validation_1-logloss:0.40969
# [253]	validation_0-logloss:0.40039	validation_1-logloss:0.40969
# [254]	validation_0-logloss:0.40035	validation_1-logloss:0.40970
# [255]	validation_0-logloss:0.40033	validation_1-logloss:0.40970
# [256]	validation_0-logloss:0.40030	validation_1-logloss:0.40970
# [257]	validation_0-logloss:0.40026	validation_1-logloss:0.40970
# [258]	validation_0-logloss:0.40022	validation_1-logloss:0.40969
# [259]	validation_0-logloss:0.40019	validation_1-logloss:0.40969
# [260]	validation_0-logloss:0.40014	validation_1-logloss:0.40968
# [261]	validation_0-logloss:0.40009	validation_1-logloss:0.40967
# [262]	validation_0-logloss:0.40008	validation_1-logloss:0.40968
# [263]	validation_0-logloss:0.40007	validation_1-logloss:0.40968
# [264]	validation_0-logloss:0.40006	validation_1-logloss:0.40968
# [265]	validation_0-logloss:0.40004	validation_1-logloss:0.40968
# [266]	validation_0-logloss:0.40001	validation_1-logloss:0.40969
# [267]	validation_0-logloss:0.39997	validation_1-logloss:0.40969
# [268]	validation_0-logloss:0.39995	validation_1-logloss:0.40970
# [269]	validation_0-logloss:0.39990	validation_1-logloss:0.40971
# [270]	validation_0-logloss:0.39990	validation_1-logloss:0.40971
# [271]	validation_0-logloss:0.39986	validation_1-logloss:0.40972
# [272]	validation_0-logloss:0.39982	validation_1-logloss:0.40972
# [273]	validation_0-logloss:0.39979	validation_1-logloss:0.40972
# [274]	validation_0-logloss:0.39974	validation_1-logloss:0.40972
# [275]	validation_0-logloss:0.39971	validation_1-logloss:0.40971
# [276]	validation_0-logloss:0.39970	validation_1-logloss:0.40972
# [277]	validation_0-logloss:0.39968	validation_1-logloss:0.40972
# [278]	validation_0-logloss:0.39964	validation_1-logloss:0.40973
# [279]	validation_0-logloss:0.39960	validation_1-logloss:0.40974
# [280]	validation_0-logloss:0.39959	validation_1-logloss:0.40974
# [281]	validation_0-logloss:0.39956	validation_1-logloss:0.40974
# [282]	validation_0-logloss:0.39955	validation_1-logloss:0.40974
# [283]	validation_0-logloss:0.39951	validation_1-logloss:0.40975
# [284]	validation_0-logloss:0.39949	validation_1-logloss:0.40975
#  ########################################
#
# ML iteration  1
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [0]	validation_0-logloss:0.65575	validation_1-logloss:0.65603
# [1]	validation_0-logloss:0.62535	validation_1-logloss:0.62562
# [2]	validation_0-logloss:0.59961	validation_1-logloss:0.60010
# [3]	validation_0-logloss:0.57805	validation_1-logloss:0.57864
# [4]	validation_0-logloss:0.55960	validation_1-logloss:0.56030
# [5]	validation_0-logloss:0.54407	validation_1-logloss:0.54483
# [6]	validation_0-logloss:0.53023	validation_1-logloss:0.53107
# [7]	validation_0-logloss:0.51858	validation_1-logloss:0.51957
# [8]	validation_0-logloss:0.50847	validation_1-logloss:0.50947
# [9]	validation_0-logloss:0.49952	validation_1-logloss:0.50071
# [10]	validation_0-logloss:0.49179	validation_1-logloss:0.49298
# [11]	validation_0-logloss:0.48504	validation_1-logloss:0.48630
# [12]	validation_0-logloss:0.47883	validation_1-logloss:0.48018
# [13]	validation_0-logloss:0.47340	validation_1-logloss:0.47478
# [14]	validation_0-logloss:0.46837	validation_1-logloss:0.46984
# [15]	validation_0-logloss:0.46383	validation_1-logloss:0.46538
# [16]	validation_0-logloss:0.45988	validation_1-logloss:0.46149
# [17]	validation_0-logloss:0.45633	validation_1-logloss:0.45801
# [18]	validation_0-logloss:0.45310	validation_1-logloss:0.45485
# [19]	validation_0-logloss:0.45000	validation_1-logloss:0.45180
# [20]	validation_0-logloss:0.44743	validation_1-logloss:0.44925
# [21]	validation_0-logloss:0.44532	validation_1-logloss:0.44717
# [22]	validation_0-logloss:0.44293	validation_1-logloss:0.44485
# [23]	validation_0-logloss:0.44055	validation_1-logloss:0.44257
# [24]	validation_0-logloss:0.43872	validation_1-logloss:0.44083
# [25]	validation_0-logloss:0.43703	validation_1-logloss:0.43922
# [26]	validation_0-logloss:0.43551	validation_1-logloss:0.43777
# [27]	validation_0-logloss:0.43380	validation_1-logloss:0.43611
# [28]	validation_0-logloss:0.43215	validation_1-logloss:0.43456
# [29]	validation_0-logloss:0.43089	validation_1-logloss:0.43334
# [30]	validation_0-logloss:0.42980	validation_1-logloss:0.43229
# [31]	validation_0-logloss:0.42834	validation_1-logloss:0.43091
# [32]	validation_0-logloss:0.42751	validation_1-logloss:0.43014
# [33]	validation_0-logloss:0.42664	validation_1-logloss:0.42925
# [34]	validation_0-logloss:0.42580	validation_1-logloss:0.42844
# [35]	validation_0-logloss:0.42509	validation_1-logloss:0.42781
# [36]	validation_0-logloss:0.42430	validation_1-logloss:0.42704
# [37]	validation_0-logloss:0.42339	validation_1-logloss:0.42617
# [38]	validation_0-logloss:0.42219	validation_1-logloss:0.42507
# [39]	validation_0-logloss:0.42161	validation_1-logloss:0.42453
# [40]	validation_0-logloss:0.42108	validation_1-logloss:0.42401
# [41]	validation_0-logloss:0.42061	validation_1-logloss:0.42361
# [42]	validation_0-logloss:0.42027	validation_1-logloss:0.42327
# [43]	validation_0-logloss:0.41933	validation_1-logloss:0.42243
# [44]	validation_0-logloss:0.41886	validation_1-logloss:0.42199
# [45]	validation_0-logloss:0.41817	validation_1-logloss:0.42136
# [46]	validation_0-logloss:0.41774	validation_1-logloss:0.42098
# [47]	validation_0-logloss:0.41722	validation_1-logloss:0.42053
# [48]	validation_0-logloss:0.41675	validation_1-logloss:0.42008
# [49]	validation_0-logloss:0.41629	validation_1-logloss:0.41965
# [50]	validation_0-logloss:0.41601	validation_1-logloss:0.41942
# [51]	validation_0-logloss:0.41562	validation_1-logloss:0.41908
# [52]	validation_0-logloss:0.41542	validation_1-logloss:0.41891
# [53]	validation_0-logloss:0.41511	validation_1-logloss:0.41865
# [54]	validation_0-logloss:0.41446	validation_1-logloss:0.41807
# [55]	validation_0-logloss:0.41400	validation_1-logloss:0.41765
# [56]	validation_0-logloss:0.41333	validation_1-logloss:0.41704
# [57]	validation_0-logloss:0.41277	validation_1-logloss:0.41655
# [58]	validation_0-logloss:0.41241	validation_1-logloss:0.41624
# [59]	validation_0-logloss:0.41199	validation_1-logloss:0.41587
# [60]	validation_0-logloss:0.41146	validation_1-logloss:0.41540
# [61]	validation_0-logloss:0.41121	validation_1-logloss:0.41519
# [62]	validation_0-logloss:0.41097	validation_1-logloss:0.41501
# [63]	validation_0-logloss:0.41062	validation_1-logloss:0.41470
# [64]	validation_0-logloss:0.41046	validation_1-logloss:0.41457
# [65]	validation_0-logloss:0.41019	validation_1-logloss:0.41435
# [66]	validation_0-logloss:0.40996	validation_1-logloss:0.41417
# [67]	validation_0-logloss:0.40978	validation_1-logloss:0.41404
# [68]	validation_0-logloss:0.40960	validation_1-logloss:0.41392
# [69]	validation_0-logloss:0.40948	validation_1-logloss:0.41383
# [70]	validation_0-logloss:0.40930	validation_1-logloss:0.41367
# [71]	validation_0-logloss:0.40914	validation_1-logloss:0.41356
# [72]	validation_0-logloss:0.40886	validation_1-logloss:0.41332
# [73]	validation_0-logloss:0.40859	validation_1-logloss:0.41309
# [74]	validation_0-logloss:0.40845	validation_1-logloss:0.41298
# [75]	validation_0-logloss:0.40827	validation_1-logloss:0.41284
# [76]	validation_0-logloss:0.40800	validation_1-logloss:0.41263
# [77]	validation_0-logloss:0.40785	validation_1-logloss:0.41252
# [78]	validation_0-logloss:0.40773	validation_1-logloss:0.41243
# [79]	validation_0-logloss:0.40763	validation_1-logloss:0.41235
# [80]	validation_0-logloss:0.40752	validation_1-logloss:0.41227
# [81]	validation_0-logloss:0.40743	validation_1-logloss:0.41221
# [82]	validation_0-logloss:0.40726	validation_1-logloss:0.41207
# [83]	validation_0-logloss:0.40714	validation_1-logloss:0.41201
# [84]	validation_0-logloss:0.40692	validation_1-logloss:0.41186
# [85]	validation_0-logloss:0.40682	validation_1-logloss:0.41178
# [86]	validation_0-logloss:0.40673	validation_1-logloss:0.41174
# [87]	validation_0-logloss:0.40661	validation_1-logloss:0.41166
# [88]	validation_0-logloss:0.40648	validation_1-logloss:0.41158
# [89]	validation_0-logloss:0.40637	validation_1-logloss:0.41151
# [90]	validation_0-logloss:0.40630	validation_1-logloss:0.41146
# [91]	validation_0-logloss:0.40618	validation_1-logloss:0.41139
# [92]	validation_0-logloss:0.40604	validation_1-logloss:0.41130
# [93]	validation_0-logloss:0.40590	validation_1-logloss:0.41120
# [94]	validation_0-logloss:0.40581	validation_1-logloss:0.41113
# [95]	validation_0-logloss:0.40571	validation_1-logloss:0.41108
# [96]	validation_0-logloss:0.40565	validation_1-logloss:0.41104
# [97]	validation_0-logloss:0.40558	validation_1-logloss:0.41100
# [98]	validation_0-logloss:0.40549	validation_1-logloss:0.41096
# [99]	validation_0-logloss:0.40541	validation_1-logloss:0.41092
# [100]	validation_0-logloss:0.40536	validation_1-logloss:0.41088
# [101]	validation_0-logloss:0.40526	validation_1-logloss:0.41083
# [102]	validation_0-logloss:0.40518	validation_1-logloss:0.41078
# [103]	validation_0-logloss:0.40508	validation_1-logloss:0.41074
# [104]	validation_0-logloss:0.40504	validation_1-logloss:0.41072
# [105]	validation_0-logloss:0.40501	validation_1-logloss:0.41071
# [106]	validation_0-logloss:0.40492	validation_1-logloss:0.41064
# [107]	validation_0-logloss:0.40484	validation_1-logloss:0.41060
# [108]	validation_0-logloss:0.40475	validation_1-logloss:0.41056
# [109]	validation_0-logloss:0.40467	validation_1-logloss:0.41053
# [110]	validation_0-logloss:0.40462	validation_1-logloss:0.41052
# [111]	validation_0-logloss:0.40459	validation_1-logloss:0.41051
# [112]	validation_0-logloss:0.40454	validation_1-logloss:0.41050
# [113]	validation_0-logloss:0.40442	validation_1-logloss:0.41044
# [114]	validation_0-logloss:0.40430	validation_1-logloss:0.41036
# [115]	validation_0-logloss:0.40425	validation_1-logloss:0.41036
# [116]	validation_0-logloss:0.40418	validation_1-logloss:0.41032
# [117]	validation_0-logloss:0.40413	validation_1-logloss:0.41031
# [118]	validation_0-logloss:0.40408	validation_1-logloss:0.41029
# [119]	validation_0-logloss:0.40405	validation_1-logloss:0.41028
# [120]	validation_0-logloss:0.40397	validation_1-logloss:0.41025
# [121]	validation_0-logloss:0.40392	validation_1-logloss:0.41024
# [122]	validation_0-logloss:0.40389	validation_1-logloss:0.41023
# [123]	validation_0-logloss:0.40384	validation_1-logloss:0.41022
# [124]	validation_0-logloss:0.40380	validation_1-logloss:0.41022
# [125]	validation_0-logloss:0.40376	validation_1-logloss:0.41021
# [126]	validation_0-logloss:0.40372	validation_1-logloss:0.41020
# [127]	validation_0-logloss:0.40365	validation_1-logloss:0.41016
# [128]	validation_0-logloss:0.40359	validation_1-logloss:0.41014
# [129]	validation_0-logloss:0.40357	validation_1-logloss:0.41013
# [130]	validation_0-logloss:0.40354	validation_1-logloss:0.41013
# [131]	validation_0-logloss:0.40348	validation_1-logloss:0.41012
# [132]	validation_0-logloss:0.40344	validation_1-logloss:0.41011
# [133]	validation_0-logloss:0.40339	validation_1-logloss:0.41011
# [134]	validation_0-logloss:0.40335	validation_1-logloss:0.41011
# [135]	validation_0-logloss:0.40329	validation_1-logloss:0.41010
# [136]	validation_0-logloss:0.40325	validation_1-logloss:0.41010
# [137]	validation_0-logloss:0.40321	validation_1-logloss:0.41010
# [138]	validation_0-logloss:0.40318	validation_1-logloss:0.41009
# [139]	validation_0-logloss:0.40313	validation_1-logloss:0.41008
# [140]	validation_0-logloss:0.40307	validation_1-logloss:0.41006
# [141]	validation_0-logloss:0.40304	validation_1-logloss:0.41006
# [142]	validation_0-logloss:0.40294	validation_1-logloss:0.41000
# [143]	validation_0-logloss:0.40291	validation_1-logloss:0.40999
# [144]	validation_0-logloss:0.40288	validation_1-logloss:0.40999
# [145]	validation_0-logloss:0.40286	validation_1-logloss:0.40999
# [146]	validation_0-logloss:0.40281	validation_1-logloss:0.41000
# [147]	validation_0-logloss:0.40278	validation_1-logloss:0.40999
# [148]	validation_0-logloss:0.40274	validation_1-logloss:0.40998
# [149]	validation_0-logloss:0.40271	validation_1-logloss:0.40998
# [150]	validation_0-logloss:0.40268	validation_1-logloss:0.40998
# [151]	validation_0-logloss:0.40265	validation_1-logloss:0.40998
# [152]	validation_0-logloss:0.40260	validation_1-logloss:0.40995
# [153]	validation_0-logloss:0.40252	validation_1-logloss:0.40991
# [154]	validation_0-logloss:0.40248	validation_1-logloss:0.40991
# [155]	validation_0-logloss:0.40245	validation_1-logloss:0.40991
# [156]	validation_0-logloss:0.40240	validation_1-logloss:0.40991
# [157]	validation_0-logloss:0.40238	validation_1-logloss:0.40991
# [158]	validation_0-logloss:0.40234	validation_1-logloss:0.40991
# [159]	validation_0-logloss:0.40229	validation_1-logloss:0.40990
# [160]	validation_0-logloss:0.40225	validation_1-logloss:0.40991
# [161]	validation_0-logloss:0.40221	validation_1-logloss:0.40989
# [162]	validation_0-logloss:0.40218	validation_1-logloss:0.40989
# [163]	validation_0-logloss:0.40214	validation_1-logloss:0.40990
# [164]	validation_0-logloss:0.40213	validation_1-logloss:0.40990
# [165]	validation_0-logloss:0.40211	validation_1-logloss:0.40990
# [166]	validation_0-logloss:0.40208	validation_1-logloss:0.40990
# [167]	validation_0-logloss:0.40203	validation_1-logloss:0.40991
# [168]	validation_0-logloss:0.40199	validation_1-logloss:0.40991
# [169]	validation_0-logloss:0.40196	validation_1-logloss:0.40992
# [170]	validation_0-logloss:0.40189	validation_1-logloss:0.40990
# [171]	validation_0-logloss:0.40183	validation_1-logloss:0.40987
# [172]	validation_0-logloss:0.40180	validation_1-logloss:0.40988
# [173]	validation_0-logloss:0.40179	validation_1-logloss:0.40988
# [174]	validation_0-logloss:0.40176	validation_1-logloss:0.40988
# [175]	validation_0-logloss:0.40173	validation_1-logloss:0.40988
# [176]	validation_0-logloss:0.40170	validation_1-logloss:0.40988
# [177]	validation_0-logloss:0.40165	validation_1-logloss:0.40987
# [178]	validation_0-logloss:0.40164	validation_1-logloss:0.40987
# [179]	validation_0-logloss:0.40161	validation_1-logloss:0.40988
# [180]	validation_0-logloss:0.40157	validation_1-logloss:0.40987
# [181]	validation_0-logloss:0.40152	validation_1-logloss:0.40987
# [182]	validation_0-logloss:0.40149	validation_1-logloss:0.40986
# [183]	validation_0-logloss:0.40147	validation_1-logloss:0.40986
# [184]	validation_0-logloss:0.40140	validation_1-logloss:0.40985
# [185]	validation_0-logloss:0.40138	validation_1-logloss:0.40985
# [186]	validation_0-logloss:0.40134	validation_1-logloss:0.40985
# [187]	validation_0-logloss:0.40131	validation_1-logloss:0.40984
# [188]	validation_0-logloss:0.40127	validation_1-logloss:0.40984
# [189]	validation_0-logloss:0.40124	validation_1-logloss:0.40984
# [190]	validation_0-logloss:0.40121	validation_1-logloss:0.40984
# [191]	validation_0-logloss:0.40117	validation_1-logloss:0.40984
# [192]	validation_0-logloss:0.40115	validation_1-logloss:0.40984
# [193]	validation_0-logloss:0.40113	validation_1-logloss:0.40984
# [194]	validation_0-logloss:0.40112	validation_1-logloss:0.40984
# [195]	validation_0-logloss:0.40111	validation_1-logloss:0.40984
# [196]	validation_0-logloss:0.40107	validation_1-logloss:0.40982
# [197]	validation_0-logloss:0.40102	validation_1-logloss:0.40982
# [198]	validation_0-logloss:0.40097	validation_1-logloss:0.40982
# [199]	validation_0-logloss:0.40093	validation_1-logloss:0.40982
# [200]	validation_0-logloss:0.40090	validation_1-logloss:0.40982
# [201]	validation_0-logloss:0.40087	validation_1-logloss:0.40982
# [202]	validation_0-logloss:0.40086	validation_1-logloss:0.40983
# [203]	validation_0-logloss:0.40083	validation_1-logloss:0.40984
# [204]	validation_0-logloss:0.40080	validation_1-logloss:0.40984
# [205]	validation_0-logloss:0.40076	validation_1-logloss:0.40984
# [206]	validation_0-logloss:0.40072	validation_1-logloss:0.40984
# [207]	validation_0-logloss:0.40068	validation_1-logloss:0.40984
# [208]	validation_0-logloss:0.40064	validation_1-logloss:0.40984
# [209]	validation_0-logloss:0.40060	validation_1-logloss:0.40981
# [210]	validation_0-logloss:0.40057	validation_1-logloss:0.40982
# [211]	validation_0-logloss:0.40054	validation_1-logloss:0.40981
# [212]	validation_0-logloss:0.40053	validation_1-logloss:0.40981
# [213]	validation_0-logloss:0.40050	validation_1-logloss:0.40981
# [214]	validation_0-logloss:0.40049	validation_1-logloss:0.40981
# [215]	validation_0-logloss:0.40046	validation_1-logloss:0.40980
# [216]	validation_0-logloss:0.40042	validation_1-logloss:0.40981
# [217]	validation_0-logloss:0.40041	validation_1-logloss:0.40980
# [218]	validation_0-logloss:0.40039	validation_1-logloss:0.40981
# [219]	validation_0-logloss:0.40035	validation_1-logloss:0.40981
# [220]	validation_0-logloss:0.40030	validation_1-logloss:0.40981
# [221]	validation_0-logloss:0.40027	validation_1-logloss:0.40981
# [222]	validation_0-logloss:0.40024	validation_1-logloss:0.40981
# [223]	validation_0-logloss:0.40021	validation_1-logloss:0.40981
# [224]	validation_0-logloss:0.40018	validation_1-logloss:0.40981
# [225]	validation_0-logloss:0.40016	validation_1-logloss:0.40981
# [226]	validation_0-logloss:0.40012	validation_1-logloss:0.40981
# [227]	validation_0-logloss:0.40006	validation_1-logloss:0.40981
# [228]	validation_0-logloss:0.40003	validation_1-logloss:0.40981
# [229]	validation_0-logloss:0.40001	validation_1-logloss:0.40980
# [230]	validation_0-logloss:0.39996	validation_1-logloss:0.40979
# [231]	validation_0-logloss:0.39993	validation_1-logloss:0.40979
# [232]	validation_0-logloss:0.39990	validation_1-logloss:0.40979
# [233]	validation_0-logloss:0.39988	validation_1-logloss:0.40979
# [234]	validation_0-logloss:0.39985	validation_1-logloss:0.40979
# [235]	validation_0-logloss:0.39981	validation_1-logloss:0.40979
# [236]	validation_0-logloss:0.39978	validation_1-logloss:0.40979
# [237]	validation_0-logloss:0.39975	validation_1-logloss:0.40980
# [238]	validation_0-logloss:0.39972	validation_1-logloss:0.40981
# [239]	validation_0-logloss:0.39971	validation_1-logloss:0.40981
# [240]	validation_0-logloss:0.39971	validation_1-logloss:0.40981
# [241]	validation_0-logloss:0.39967	validation_1-logloss:0.40981
# [242]	validation_0-logloss:0.39965	validation_1-logloss:0.40980
# [243]	validation_0-logloss:0.39961	validation_1-logloss:0.40980
# [244]	validation_0-logloss:0.39959	validation_1-logloss:0.40980
# [245]	validation_0-logloss:0.39956	validation_1-logloss:0.40981
# [246]	validation_0-logloss:0.39952	validation_1-logloss:0.40980
# [247]	validation_0-logloss:0.39949	validation_1-logloss:0.40981
# [248]	validation_0-logloss:0.39947	validation_1-logloss:0.40981
# [249]	validation_0-logloss:0.39947	validation_1-logloss:0.40981
# [250]	validation_0-logloss:0.39944	validation_1-logloss:0.40981
# [251]	validation_0-logloss:0.39943	validation_1-logloss:0.40980
# [252]	validation_0-logloss:0.39943	validation_1-logloss:0.40981
# [253]	validation_0-logloss:0.39942	validation_1-logloss:0.40981
# [254]	validation_0-logloss:0.39942	validation_1-logloss:0.40981
# [255]	validation_0-logloss:0.39938	validation_1-logloss:0.40981
# [256]	validation_0-logloss:0.39935	validation_1-logloss:0.40981
# [257]	validation_0-logloss:0.39932	validation_1-logloss:0.40980
# [258]	validation_0-logloss:0.39928	validation_1-logloss:0.40980
# [259]	validation_0-logloss:0.39925	validation_1-logloss:0.40980
# [260]	validation_0-logloss:0.39922	validation_1-logloss:0.40980
# [261]	validation_0-logloss:0.39919	validation_1-logloss:0.40979
# [262]	validation_0-logloss:0.39917	validation_1-logloss:0.40979
# [263]	validation_0-logloss:0.39913	validation_1-logloss:0.40980
# [264]	validation_0-logloss:0.39908	validation_1-logloss:0.40977
# [265]	validation_0-logloss:0.39904	validation_1-logloss:0.40978
# [266]	validation_0-logloss:0.39901	validation_1-logloss:0.40978
# [267]	validation_0-logloss:0.39898	validation_1-logloss:0.40978
# [268]	validation_0-logloss:0.39897	validation_1-logloss:0.40979
# [269]	validation_0-logloss:0.39894	validation_1-logloss:0.40978
# [270]	validation_0-logloss:0.39892	validation_1-logloss:0.40978
# [271]	validation_0-logloss:0.39890	validation_1-logloss:0.40978
# [272]	validation_0-logloss:0.39888	validation_1-logloss:0.40979
# [273]	validation_0-logloss:0.39886	validation_1-logloss:0.40979
# [274]	validation_0-logloss:0.39883	validation_1-logloss:0.40980
# [275]	validation_0-logloss:0.39879	validation_1-logloss:0.40979
# [276]	validation_0-logloss:0.39875	validation_1-logloss:0.40979
# [277]	validation_0-logloss:0.39873	validation_1-logloss:0.40979
# [278]	validation_0-logloss:0.39870	validation_1-logloss:0.40978
# [279]	validation_0-logloss:0.39868	validation_1-logloss:0.40978
# [280]	validation_0-logloss:0.39867	validation_1-logloss:0.40978
# [281]	validation_0-logloss:0.39867	validation_1-logloss:0.40978
# [282]	validation_0-logloss:0.39864	validation_1-logloss:0.40979
# [283]	validation_0-logloss:0.39864	validation_1-logloss:0.40979
# [284]	validation_0-logloss:0.39863	validation_1-logloss:0.40979
# [285]	validation_0-logloss:0.39859	validation_1-logloss:0.40980
# [286]	validation_0-logloss:0.39858	validation_1-logloss:0.40980
# [287]	validation_0-logloss:0.39854	validation_1-logloss:0.40980
# [288]	validation_0-logloss:0.39849	validation_1-logloss:0.40979
# [289]	validation_0-logloss:0.39845	validation_1-logloss:0.40979
# [290]	validation_0-logloss:0.39843	validation_1-logloss:0.40979
# [291]	validation_0-logloss:0.39839	validation_1-logloss:0.40979
# [292]	validation_0-logloss:0.39834	validation_1-logloss:0.40979
# [293]	validation_0-logloss:0.39831	validation_1-logloss:0.40979
# [294]	validation_0-logloss:0.39827	validation_1-logloss:0.40978
# [295]	validation_0-logloss:0.39826	validation_1-logloss:0.40978
# [296]	validation_0-logloss:0.39821	validation_1-logloss:0.40978
# [297]	validation_0-logloss:0.39819	validation_1-logloss:0.40979
# [298]	validation_0-logloss:0.39815	validation_1-logloss:0.40979
# [299]	validation_0-logloss:0.39813	validation_1-logloss:0.40979
# [300]	validation_0-logloss:0.39809	validation_1-logloss:0.40979
# [301]	validation_0-logloss:0.39806	validation_1-logloss:0.40979
# [302]	validation_0-logloss:0.39804	validation_1-logloss:0.40979
# [303]	validation_0-logloss:0.39802	validation_1-logloss:0.40980
# [304]	validation_0-logloss:0.39800	validation_1-logloss:0.40980
# [305]	validation_0-logloss:0.39797	validation_1-logloss:0.40981
# [306]	validation_0-logloss:0.39794	validation_1-logloss:0.40981
# [307]	validation_0-logloss:0.39793	validation_1-logloss:0.40981
# [308]	validation_0-logloss:0.39790	validation_1-logloss:0.40981
# [309]	validation_0-logloss:0.39787	validation_1-logloss:0.40982
# [310]	validation_0-logloss:0.39784	validation_1-logloss:0.40982
# [311]	validation_0-logloss:0.39781	validation_1-logloss:0.40982
# [312]	validation_0-logloss:0.39777	validation_1-logloss:0.40981
# [313]	validation_0-logloss:0.39772	validation_1-logloss:0.40981
#  ########################################
#
# ML iteration  2
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [0]	validation_0-logloss:0.65591	validation_1-logloss:0.65623
# [1]	validation_0-logloss:0.62543	validation_1-logloss:0.62580
# [2]	validation_0-logloss:0.59971	validation_1-logloss:0.60016
# [3]	validation_0-logloss:0.57818	validation_1-logloss:0.57878
# [4]	validation_0-logloss:0.55995	validation_1-logloss:0.56073
# [5]	validation_0-logloss:0.54433	validation_1-logloss:0.54507
# [6]	validation_0-logloss:0.53073	validation_1-logloss:0.53153
# [7]	validation_0-logloss:0.51887	validation_1-logloss:0.51982
# [8]	validation_0-logloss:0.50867	validation_1-logloss:0.50967
# [9]	validation_0-logloss:0.49948	validation_1-logloss:0.50051
# [10]	validation_0-logloss:0.49185	validation_1-logloss:0.49299
# [11]	validation_0-logloss:0.48493	validation_1-logloss:0.48620
# [12]	validation_0-logloss:0.47888	validation_1-logloss:0.48021
# [13]	validation_0-logloss:0.47338	validation_1-logloss:0.47477
# [14]	validation_0-logloss:0.46851	validation_1-logloss:0.47001
# [15]	validation_0-logloss:0.46416	validation_1-logloss:0.46578
# [16]	validation_0-logloss:0.46020	validation_1-logloss:0.46189
# [17]	validation_0-logloss:0.45673	validation_1-logloss:0.45850
# [18]	validation_0-logloss:0.45350	validation_1-logloss:0.45530
# [19]	validation_0-logloss:0.45036	validation_1-logloss:0.45224
# [20]	validation_0-logloss:0.44771	validation_1-logloss:0.44966
# [21]	validation_0-logloss:0.44523	validation_1-logloss:0.44724
# [22]	validation_0-logloss:0.44303	validation_1-logloss:0.44511
# [23]	validation_0-logloss:0.44094	validation_1-logloss:0.44312
# [24]	validation_0-logloss:0.43912	validation_1-logloss:0.44134
# [25]	validation_0-logloss:0.43750	validation_1-logloss:0.43976
# [26]	validation_0-logloss:0.43602	validation_1-logloss:0.43834
# [27]	validation_0-logloss:0.43438	validation_1-logloss:0.43672
# [28]	validation_0-logloss:0.43312	validation_1-logloss:0.43548
# [29]	validation_0-logloss:0.43128	validation_1-logloss:0.43371
# [30]	validation_0-logloss:0.43038	validation_1-logloss:0.43286
# [31]	validation_0-logloss:0.42928	validation_1-logloss:0.43182
# [32]	validation_0-logloss:0.42787	validation_1-logloss:0.43047
# [33]	validation_0-logloss:0.42711	validation_1-logloss:0.42973
# [34]	validation_0-logloss:0.42590	validation_1-logloss:0.42858
# [35]	validation_0-logloss:0.42513	validation_1-logloss:0.42785
# [36]	validation_0-logloss:0.42419	validation_1-logloss:0.42693
# [37]	validation_0-logloss:0.42310	validation_1-logloss:0.42590
# [38]	validation_0-logloss:0.42228	validation_1-logloss:0.42515
# [39]	validation_0-logloss:0.42183	validation_1-logloss:0.42471
# [40]	validation_0-logloss:0.42086	validation_1-logloss:0.42380
# [41]	validation_0-logloss:0.42044	validation_1-logloss:0.42338
# [42]	validation_0-logloss:0.42007	validation_1-logloss:0.42303
# [43]	validation_0-logloss:0.41924	validation_1-logloss:0.42226
# [44]	validation_0-logloss:0.41848	validation_1-logloss:0.42152
# [45]	validation_0-logloss:0.41800	validation_1-logloss:0.42109
# [46]	validation_0-logloss:0.41749	validation_1-logloss:0.42061
# [47]	validation_0-logloss:0.41701	validation_1-logloss:0.42020
# [48]	validation_0-logloss:0.41653	validation_1-logloss:0.41976
# [49]	validation_0-logloss:0.41614	validation_1-logloss:0.41936
# [50]	validation_0-logloss:0.41561	validation_1-logloss:0.41887
# [51]	validation_0-logloss:0.41526	validation_1-logloss:0.41854
# [52]	validation_0-logloss:0.41453	validation_1-logloss:0.41788
# [53]	validation_0-logloss:0.41419	validation_1-logloss:0.41757
# [54]	validation_0-logloss:0.41387	validation_1-logloss:0.41729
# [55]	validation_0-logloss:0.41354	validation_1-logloss:0.41701
# [56]	validation_0-logloss:0.41312	validation_1-logloss:0.41662
# [57]	validation_0-logloss:0.41266	validation_1-logloss:0.41624
# [58]	validation_0-logloss:0.41226	validation_1-logloss:0.41586
# [59]	validation_0-logloss:0.41198	validation_1-logloss:0.41561
# [60]	validation_0-logloss:0.41174	validation_1-logloss:0.41540
# [61]	validation_0-logloss:0.41133	validation_1-logloss:0.41504
# [62]	validation_0-logloss:0.41110	validation_1-logloss:0.41482
# [63]	validation_0-logloss:0.41090	validation_1-logloss:0.41468
# [64]	validation_0-logloss:0.41071	validation_1-logloss:0.41452
# [65]	validation_0-logloss:0.41053	validation_1-logloss:0.41435
# [66]	validation_0-logloss:0.41034	validation_1-logloss:0.41419
# [67]	validation_0-logloss:0.41005	validation_1-logloss:0.41396
# [68]	validation_0-logloss:0.40988	validation_1-logloss:0.41382
# [69]	validation_0-logloss:0.40958	validation_1-logloss:0.41358
# [70]	validation_0-logloss:0.40938	validation_1-logloss:0.41341
# [71]	validation_0-logloss:0.40919	validation_1-logloss:0.41324
# [72]	validation_0-logloss:0.40904	validation_1-logloss:0.41315
# [73]	validation_0-logloss:0.40875	validation_1-logloss:0.41290
# [74]	validation_0-logloss:0.40856	validation_1-logloss:0.41275
# [75]	validation_0-logloss:0.40842	validation_1-logloss:0.41267
# [76]	validation_0-logloss:0.40827	validation_1-logloss:0.41257
# [77]	validation_0-logloss:0.40817	validation_1-logloss:0.41249
# [78]	validation_0-logloss:0.40797	validation_1-logloss:0.41232
# [79]	validation_0-logloss:0.40777	validation_1-logloss:0.41216
# [80]	validation_0-logloss:0.40767	validation_1-logloss:0.41207
# [81]	validation_0-logloss:0.40756	validation_1-logloss:0.41200
# [82]	validation_0-logloss:0.40741	validation_1-logloss:0.41189
# [83]	validation_0-logloss:0.40722	validation_1-logloss:0.41172
# [84]	validation_0-logloss:0.40711	validation_1-logloss:0.41165
# [85]	validation_0-logloss:0.40698	validation_1-logloss:0.41156
# [86]	validation_0-logloss:0.40689	validation_1-logloss:0.41151
# [87]	validation_0-logloss:0.40681	validation_1-logloss:0.41147
# [88]	validation_0-logloss:0.40663	validation_1-logloss:0.41133
# [89]	validation_0-logloss:0.40647	validation_1-logloss:0.41122
# [90]	validation_0-logloss:0.40638	validation_1-logloss:0.41114
# [91]	validation_0-logloss:0.40630	validation_1-logloss:0.41110
# [92]	validation_0-logloss:0.40622	validation_1-logloss:0.41104
# [93]	validation_0-logloss:0.40609	validation_1-logloss:0.41093
# [94]	validation_0-logloss:0.40598	validation_1-logloss:0.41087
# [95]	validation_0-logloss:0.40590	validation_1-logloss:0.41082
# [96]	validation_0-logloss:0.40582	validation_1-logloss:0.41077
# [97]	validation_0-logloss:0.40575	validation_1-logloss:0.41075
# [98]	validation_0-logloss:0.40570	validation_1-logloss:0.41072
# [99]	validation_0-logloss:0.40566	validation_1-logloss:0.41071
# [100]	validation_0-logloss:0.40558	validation_1-logloss:0.41065
# [101]	validation_0-logloss:0.40552	validation_1-logloss:0.41063
# [102]	validation_0-logloss:0.40548	validation_1-logloss:0.41061
# [103]	validation_0-logloss:0.40542	validation_1-logloss:0.41058
# [104]	validation_0-logloss:0.40536	validation_1-logloss:0.41056
# [105]	validation_0-logloss:0.40529	validation_1-logloss:0.41051
# [106]	validation_0-logloss:0.40521	validation_1-logloss:0.41047
# [107]	validation_0-logloss:0.40513	validation_1-logloss:0.41043
# [108]	validation_0-logloss:0.40509	validation_1-logloss:0.41042
# [109]	validation_0-logloss:0.40502	validation_1-logloss:0.41039
# [110]	validation_0-logloss:0.40496	validation_1-logloss:0.41036
# [111]	validation_0-logloss:0.40492	validation_1-logloss:0.41034
# [112]	validation_0-logloss:0.40488	validation_1-logloss:0.41034
# [113]	validation_0-logloss:0.40483	validation_1-logloss:0.41032
# [114]	validation_0-logloss:0.40477	validation_1-logloss:0.41032
# [115]	validation_0-logloss:0.40470	validation_1-logloss:0.41028
# [116]	validation_0-logloss:0.40463	validation_1-logloss:0.41025
# [117]	validation_0-logloss:0.40457	validation_1-logloss:0.41024
# [118]	validation_0-logloss:0.40451	validation_1-logloss:0.41023
# ...
# [14]	validation_0-logloss:0.46727	validation_1-logloss:0.46926
# [15]	validation_0-logloss:0.46270	validation_1-logloss:0.46477
# [16]	validation_0-logloss:0.45849	validation_1-logloss:0.46064
# [17]	validation_0-logloss:0.45488	validation_1-logloss:0.45709
# [18]	validation_0-logloss:0.45177	validation_1-logloss:0.45404
# [19]	validation_0-logloss:0.44900	validation_1-logloss:0.45135
# [20]	validation_0-logloss:0.44654	validation_1-logloss:0.44894
# [21]	validation_0-logloss:0.44421	validation_1-logloss:0.44671
# [22]	validation_0-logloss:0.44181	validation_1-logloss:0.44435
# [23]	validation_0-logloss:0.43950	validation_1-logloss:0.44210
# [24]	validation_0-logloss:0.43750	validation_1-logloss:0.44014
# [25]	validation_0-logloss:0.43536	validation_1-logloss:0.43803
# [26]	validation_0-logloss:0.43392	validation_1-logloss:0.43665
# [27]	validation_0-logloss:0.43252	validation_1-logloss:0.43529
# [28]	validation_0-logloss:0.43127	validation_1-logloss:0.43405
# [29]	validation_0-logloss:0.43003	validation_1-logloss:0.43289
# [30]	validation_0-logloss:0.42883	validation_1-logloss:0.43174
# [31]	validation_0-logloss:0.42727	validation_1-logloss:0.43024
# [32]	validation_0-logloss:0.42636	validation_1-logloss:0.42938
# [33]	validation_0-logloss:0.42561	validation_1-logloss:0.42866
# [34]	validation_0-logloss:0.42482	validation_1-logloss:0.42790
# [35]	validation_0-logloss:0.42410	validation_1-logloss:0.42722
# [36]	validation_0-logloss:0.42326	validation_1-logloss:0.42641
# [37]	validation_0-logloss:0.42223	validation_1-logloss:0.42545
# [38]	validation_0-logloss:0.42163	validation_1-logloss:0.42488
# [39]	validation_0-logloss:0.42113	validation_1-logloss:0.42438
# [40]	validation_0-logloss:0.42053	validation_1-logloss:0.42380
# [41]	validation_0-logloss:0.41985	validation_1-logloss:0.42315
# [42]	validation_0-logloss:0.41939	validation_1-logloss:0.42273
# [43]	validation_0-logloss:0.41884	validation_1-logloss:0.42226
# [44]	validation_0-logloss:0.41820	validation_1-logloss:0.42164
# [45]	validation_0-logloss:0.41760	validation_1-logloss:0.42108
# [46]	validation_0-logloss:0.41699	validation_1-logloss:0.42053
# [47]	validation_0-logloss:0.41663	validation_1-logloss:0.42023
# [48]	validation_0-logloss:0.41634	validation_1-logloss:0.41998
# [49]	validation_0-logloss:0.41600	validation_1-logloss:0.41966
# [50]	validation_0-logloss:0.41544	validation_1-logloss:0.41917
# [51]	validation_0-logloss:0.41506	validation_1-logloss:0.41884
# [52]	validation_0-logloss:0.41455	validation_1-logloss:0.41837
# [53]	validation_0-logloss:0.41395	validation_1-logloss:0.41784
# [54]	validation_0-logloss:0.41357	validation_1-logloss:0.41748
# [55]	validation_0-logloss:0.41296	validation_1-logloss:0.41690
# [56]	validation_0-logloss:0.41264	validation_1-logloss:0.41663
# [57]	validation_0-logloss:0.41242	validation_1-logloss:0.41645
# [58]	validation_0-logloss:0.41218	validation_1-logloss:0.41624
# [59]	validation_0-logloss:0.41191	validation_1-logloss:0.41600
# [60]	validation_0-logloss:0.41163	validation_1-logloss:0.41577
# [61]	validation_0-logloss:0.41132	validation_1-logloss:0.41549
# [62]	validation_0-logloss:0.41081	validation_1-logloss:0.41506
# [63]	validation_0-logloss:0.41052	validation_1-logloss:0.41482
# [64]	validation_0-logloss:0.41030	validation_1-logloss:0.41463
# [65]	validation_0-logloss:0.41010	validation_1-logloss:0.41447
# [66]	validation_0-logloss:0.40992	validation_1-logloss:0.41435
# [67]	validation_0-logloss:0.40950	validation_1-logloss:0.41398
# [68]	validation_0-logloss:0.40939	validation_1-logloss:0.41390
# [69]	validation_0-logloss:0.40917	validation_1-logloss:0.41371
# [70]	validation_0-logloss:0.40901	validation_1-logloss:0.41359
# [71]	validation_0-logloss:0.40887	validation_1-logloss:0.41348
# [72]	validation_0-logloss:0.40866	validation_1-logloss:0.41332
# [73]	validation_0-logloss:0.40836	validation_1-logloss:0.41304
# [74]	validation_0-logloss:0.40823	validation_1-logloss:0.41295
# [75]	validation_0-logloss:0.40809	validation_1-logloss:0.41288
# [76]	validation_0-logloss:0.40794	validation_1-logloss:0.41276
# [77]	validation_0-logloss:0.40770	validation_1-logloss:0.41254
# [78]	validation_0-logloss:0.40753	validation_1-logloss:0.41241
# [79]	validation_0-logloss:0.40745	validation_1-logloss:0.41237
# [80]	validation_0-logloss:0.40731	validation_1-logloss:0.41228
# [81]	validation_0-logloss:0.40715	validation_1-logloss:0.41216
# [82]	validation_0-logloss:0.40705	validation_1-logloss:0.41209
# [83]	validation_0-logloss:0.40696	validation_1-logloss:0.41205
# [84]	validation_0-logloss:0.40687	validation_1-logloss:0.41199
# [85]	validation_0-logloss:0.40679	validation_1-logloss:0.41194
# [86]	validation_0-logloss:0.40667	validation_1-logloss:0.41186
# [87]	validation_0-logloss:0.40653	validation_1-logloss:0.41175
# [88]	validation_0-logloss:0.40642	validation_1-logloss:0.41169
# [89]	validation_0-logloss:0.40626	validation_1-logloss:0.41156
# [90]	validation_0-logloss:0.40618	validation_1-logloss:0.41151
# [91]	validation_0-logloss:0.40609	validation_1-logloss:0.41147
# [92]	validation_0-logloss:0.40598	validation_1-logloss:0.41141
# [93]	validation_0-logloss:0.40592	validation_1-logloss:0.41138
# [94]	validation_0-logloss:0.40581	validation_1-logloss:0.41132
# [95]	validation_0-logloss:0.40570	validation_1-logloss:0.41124
# [96]	validation_0-logloss:0.40561	validation_1-logloss:0.41120
# [97]	validation_0-logloss:0.40556	validation_1-logloss:0.41118
# [98]	validation_0-logloss:0.40543	validation_1-logloss:0.41108
# [99]	validation_0-logloss:0.40536	validation_1-logloss:0.41103
# [100]	validation_0-logloss:0.40527	validation_1-logloss:0.41099
# [101]	validation_0-logloss:0.40521	validation_1-logloss:0.41097
# [102]	validation_0-logloss:0.40513	validation_1-logloss:0.41091
# [103]	validation_0-logloss:0.40506	validation_1-logloss:0.41089
# [104]	validation_0-logloss:0.40499	validation_1-logloss:0.41085
# [105]	validation_0-logloss:0.40493	validation_1-logloss:0.41082
# [106]	validation_0-logloss:0.40486	validation_1-logloss:0.41081
# [107]	validation_0-logloss:0.40483	validation_1-logloss:0.41078
# [108]	validation_0-logloss:0.40477	validation_1-logloss:0.41076
# [109]	validation_0-logloss:0.40470	validation_1-logloss:0.41072
# [110]	validation_0-logloss:0.40465	validation_1-logloss:0.41070
# [111]	validation_0-logloss:0.40461	validation_1-logloss:0.41069
# [112]	validation_0-logloss:0.40454	validation_1-logloss:0.41067
# [113]	validation_0-logloss:0.40446	validation_1-logloss:0.41063
# [114]	validation_0-logloss:0.40438	validation_1-logloss:0.41058
# [115]	validation_0-logloss:0.40427	validation_1-logloss:0.41052
# [116]	validation_0-logloss:0.40421	validation_1-logloss:0.41050
# [117]	validation_0-logloss:0.40417	validation_1-logloss:0.41048
# [118]	validation_0-logloss:0.40409	validation_1-logloss:0.41044
# [119]	validation_0-logloss:0.40404	validation_1-logloss:0.41043
# [120]	validation_0-logloss:0.40402	validation_1-logloss:0.41042
# [121]	validation_0-logloss:0.40396	validation_1-logloss:0.41040
# [122]	validation_0-logloss:0.40389	validation_1-logloss:0.41038
# [123]	validation_0-logloss:0.40383	validation_1-logloss:0.41035
# [124]	validation_0-logloss:0.40379	validation_1-logloss:0.41034
# [125]	validation_0-logloss:0.40375	validation_1-logloss:0.41033
# [126]	validation_0-logloss:0.40368	validation_1-logloss:0.41029
# [127]	validation_0-logloss:0.40362	validation_1-logloss:0.41028
# [128]	validation_0-logloss:0.40356	validation_1-logloss:0.41027
# [129]	validation_0-logloss:0.40351	validation_1-logloss:0.41024
# [130]	validation_0-logloss:0.40346	validation_1-logloss:0.41024
# [131]	validation_0-logloss:0.40343	validation_1-logloss:0.41023
# [132]	validation_0-logloss:0.40341	validation_1-logloss:0.41023
# [133]	validation_0-logloss:0.40334	validation_1-logloss:0.41020
# [134]	validation_0-logloss:0.40329	validation_1-logloss:0.41020
# [135]	validation_0-logloss:0.40325	validation_1-logloss:0.41019
# [136]	validation_0-logloss:0.40321	validation_1-logloss:0.41018
# [137]	validation_0-logloss:0.40318	validation_1-logloss:0.41018
# [138]	validation_0-logloss:0.40307	validation_1-logloss:0.41012
# [139]	validation_0-logloss:0.40303	validation_1-logloss:0.41012
# [140]	validation_0-logloss:0.40297	validation_1-logloss:0.41008
# [141]	validation_0-logloss:0.40293	validation_1-logloss:0.41008
# [142]	validation_0-logloss:0.40286	validation_1-logloss:0.41003
# [143]	validation_0-logloss:0.40282	validation_1-logloss:0.41003
# [144]	validation_0-logloss:0.40279	validation_1-logloss:0.41003
# [145]	validation_0-logloss:0.40274	validation_1-logloss:0.41003
# [146]	validation_0-logloss:0.40268	validation_1-logloss:0.40999
# [147]	validation_0-logloss:0.40264	validation_1-logloss:0.40999
# [148]	validation_0-logloss:0.40261	validation_1-logloss:0.40998
# [149]	validation_0-logloss:0.40257	validation_1-logloss:0.40998
# [150]	validation_0-logloss:0.40255	validation_1-logloss:0.40998
# [151]	validation_0-logloss:0.40252	validation_1-logloss:0.40998
# [152]	validation_0-logloss:0.40249	validation_1-logloss:0.40998
# [153]	validation_0-logloss:0.40241	validation_1-logloss:0.40994
# [154]	validation_0-logloss:0.40239	validation_1-logloss:0.40994
# [155]	validation_0-logloss:0.40234	validation_1-logloss:0.40994
# [156]	validation_0-logloss:0.40230	validation_1-logloss:0.40994
# [157]	validation_0-logloss:0.40226	validation_1-logloss:0.40994
# [158]	validation_0-logloss:0.40222	validation_1-logloss:0.40994
# [159]	validation_0-logloss:0.40221	validation_1-logloss:0.40994
# [160]	validation_0-logloss:0.40214	validation_1-logloss:0.40993
# [161]	validation_0-logloss:0.40210	validation_1-logloss:0.40993
# [162]	validation_0-logloss:0.40210	validation_1-logloss:0.40992
# [163]	validation_0-logloss:0.40207	validation_1-logloss:0.40993
# [164]	validation_0-logloss:0.40203	validation_1-logloss:0.40993
# [165]	validation_0-logloss:0.40198	validation_1-logloss:0.40992
# [166]	validation_0-logloss:0.40195	validation_1-logloss:0.40992
# [167]	validation_0-logloss:0.40193	validation_1-logloss:0.40993
# [168]	validation_0-logloss:0.40190	validation_1-logloss:0.40994
# [169]	validation_0-logloss:0.40188	validation_1-logloss:0.40994
# [170]	validation_0-logloss:0.40187	validation_1-logloss:0.40993
# [171]	validation_0-logloss:0.40184	validation_1-logloss:0.40995
# [172]	validation_0-logloss:0.40179	validation_1-logloss:0.40992
# [173]	validation_0-logloss:0.40175	validation_1-logloss:0.40992
# [174]	validation_0-logloss:0.40170	validation_1-logloss:0.40991
# [175]	validation_0-logloss:0.40166	validation_1-logloss:0.40990
# [176]	validation_0-logloss:0.40164	validation_1-logloss:0.40991
# [177]	validation_0-logloss:0.40158	validation_1-logloss:0.40988
# [178]	validation_0-logloss:0.40156	validation_1-logloss:0.40988
# [179]	validation_0-logloss:0.40152	validation_1-logloss:0.40987
# [180]	validation_0-logloss:0.40148	validation_1-logloss:0.40988
# [181]	validation_0-logloss:0.40147	validation_1-logloss:0.40988
# [182]	validation_0-logloss:0.40142	validation_1-logloss:0.40988
# [183]	validation_0-logloss:0.40138	validation_1-logloss:0.40989
# [184]	validation_0-logloss:0.40133	validation_1-logloss:0.40988
# [185]	validation_0-logloss:0.40129	validation_1-logloss:0.40988
# [186]	validation_0-logloss:0.40126	validation_1-logloss:0.40988
# [187]	validation_0-logloss:0.40124	validation_1-logloss:0.40989
# [188]	validation_0-logloss:0.40121	validation_1-logloss:0.40990
# [189]	validation_0-logloss:0.40119	validation_1-logloss:0.40990
# [190]	validation_0-logloss:0.40116	validation_1-logloss:0.40990
# [191]	validation_0-logloss:0.40111	validation_1-logloss:0.40989
# [192]	validation_0-logloss:0.40107	validation_1-logloss:0.40989
# [193]	validation_0-logloss:0.40104	validation_1-logloss:0.40989
# [194]	validation_0-logloss:0.40101	validation_1-logloss:0.40989
# [195]	validation_0-logloss:0.40097	validation_1-logloss:0.40989
# [196]	validation_0-logloss:0.40091	validation_1-logloss:0.40987
# [197]	validation_0-logloss:0.40090	validation_1-logloss:0.40987
# [198]	validation_0-logloss:0.40088	validation_1-logloss:0.40987
# [199]	validation_0-logloss:0.40086	validation_1-logloss:0.40987
# [200]	validation_0-logloss:0.40085	validation_1-logloss:0.40987
# [201]	validation_0-logloss:0.40081	validation_1-logloss:0.40987
# [202]	validation_0-logloss:0.40078	validation_1-logloss:0.40988
# [203]	validation_0-logloss:0.40073	validation_1-logloss:0.40987
# [204]	validation_0-logloss:0.40069	validation_1-logloss:0.40988
# [205]	validation_0-logloss:0.40066	validation_1-logloss:0.40988
# [206]	validation_0-logloss:0.40062	validation_1-logloss:0.40987
# [207]	validation_0-logloss:0.40060	validation_1-logloss:0.40988
# [208]	validation_0-logloss:0.40057	validation_1-logloss:0.40987
# [209]	validation_0-logloss:0.40054	validation_1-logloss:0.40988
# [210]	validation_0-logloss:0.40052	validation_1-logloss:0.40988
# [211]	validation_0-logloss:0.40046	validation_1-logloss:0.40986
# [212]	validation_0-logloss:0.40044	validation_1-logloss:0.40986
# [213]	validation_0-logloss:0.40041	validation_1-logloss:0.40987
# [214]	validation_0-logloss:0.40037	validation_1-logloss:0.40986
# [215]	validation_0-logloss:0.40033	validation_1-logloss:0.40986
# [216]	validation_0-logloss:0.40031	validation_1-logloss:0.40987
# [217]	validation_0-logloss:0.40028	validation_1-logloss:0.40986
# [218]	validation_0-logloss:0.40025	validation_1-logloss:0.40987
# [219]	validation_0-logloss:0.40022	validation_1-logloss:0.40988
# [220]	validation_0-logloss:0.40018	validation_1-logloss:0.40989
# [221]	validation_0-logloss:0.40014	validation_1-logloss:0.40989
# [222]	validation_0-logloss:0.40011	validation_1-logloss:0.40989
# [223]	validation_0-logloss:0.40009	validation_1-logloss:0.40990
# [224]	validation_0-logloss:0.40004	validation_1-logloss:0.40990
# [225]	validation_0-logloss:0.40001	validation_1-logloss:0.40990
# [226]	validation_0-logloss:0.40000	validation_1-logloss:0.40990
# [227]	validation_0-logloss:0.39997	validation_1-logloss:0.40989
# [228]	validation_0-logloss:0.39993	validation_1-logloss:0.40990
# [229]	validation_0-logloss:0.39989	validation_1-logloss:0.40989
# [230]	validation_0-logloss:0.39986	validation_1-logloss:0.40990
# [231]	validation_0-logloss:0.39984	validation_1-logloss:0.40990
# [232]	validation_0-logloss:0.39980	validation_1-logloss:0.40989
# [233]	validation_0-logloss:0.39977	validation_1-logloss:0.40989
# [234]	validation_0-logloss:0.39976	validation_1-logloss:0.40989
# [235]	validation_0-logloss:0.39974	validation_1-logloss:0.40990
# [236]	validation_0-logloss:0.39971	validation_1-logloss:0.40990
# [237]	validation_0-logloss:0.39967	validation_1-logloss:0.40990
# [238]	validation_0-logloss:0.39962	validation_1-logloss:0.40990
# [239]	validation_0-logloss:0.39962	validation_1-logloss:0.40990
# [240]	validation_0-logloss:0.39958	validation_1-logloss:0.40990
# [241]	validation_0-logloss:0.39956	validation_1-logloss:0.40990
# [242]	validation_0-logloss:0.39955	validation_1-logloss:0.40990
# [243]	validation_0-logloss:0.39954	validation_1-logloss:0.40990
# [244]	validation_0-logloss:0.39952	validation_1-logloss:0.40990
# [245]	validation_0-logloss:0.39950	validation_1-logloss:0.40990
# [246]	validation_0-logloss:0.39948	validation_1-logloss:0.40991
# [247]	validation_0-logloss:0.39944	validation_1-logloss:0.40991
# [248]	validation_0-logloss:0.39942	validation_1-logloss:0.40991
# [249]	validation_0-logloss:0.39938	validation_1-logloss:0.40991
# [250]	validation_0-logloss:0.39936	validation_1-logloss:0.40991
# [251]	validation_0-logloss:0.39933	validation_1-logloss:0.40991
# [252]	validation_0-logloss:0.39930	validation_1-logloss:0.40991
# [253]	validation_0-logloss:0.39924	validation_1-logloss:0.40989
# [254]	validation_0-logloss:0.39922	validation_1-logloss:0.40989
# [255]	validation_0-logloss:0.39918	validation_1-logloss:0.40990
# [256]	validation_0-logloss:0.39915	validation_1-logloss:0.40990
# [257]	validation_0-logloss:0.39912	validation_1-logloss:0.40991
# [258]	validation_0-logloss:0.39909	validation_1-logloss:0.40990
# [259]	validation_0-logloss:0.39907	validation_1-logloss:0.40990
# [260]	validation_0-logloss:0.39903	validation_1-logloss:0.40991
# [261]	validation_0-logloss:0.39902	validation_1-logloss:0.40991
# [262]	validation_0-logloss:0.39900	validation_1-logloss:0.40992
# [263]	validation_0-logloss:0.39899	validation_1-logloss:0.40992
#  ########################################

# %%
# XGBoost with the kinematic variables of the leptons

########################
# CLASSIFICATION SCORE #
########################

# Outputs for validation data set

pred_XG_SM_1ML = []
pred_XG_NP_1ML = []

for i in range(len(y_mon_test)):
    if y_mon_test[i] == 0:
        pred_XG_SM_1ML.append(y_pred_xg_1ML[i])
    else:
        pred_XG_NP_1ML.append(y_pred_xg_1ML[i])
        
        
print('Classification score (1ML):')
        
weights = np.ones_like(pred_XG_SM_1ML)/float(len(pred_XG_SM_1ML))
nSM, binsSM, patchesSM = plt.hist(pred_XG_SM_1ML, 100, weights=weights, range=[0,1], histtype='step', color='firebrick', linewidth=2, label='Background')

weights = np.ones_like(pred_XG_NP_1ML)/float(len(pred_XG_NP_1ML))
nNP, binsNP, patchesNP = plt.hist(pred_XG_NP_1ML, 100, weights=weights, range=[0,1], histtype='step', color='forestgreen', linewidth=2, label='Signal')

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("Classication score (XGBoost)",fontsize=15)
plt.ylabel("Fraction of events",fontsize=14)
plt.grid()
plt.legend(fontsize=12)
plt.title('Multivariate monian distributions, $\mathcal{N}_{2}$', fontsize=14)
#plt.savefig('images/' + '2monian-output.pdf', format="pdf", bbox_inches="tight")
plt.show()




# Outputs for validation data set

pred_XG_SM = []
pred_XG_NP = []

for i in range(len(y_mon_test)):
    if y_mon_test[i] == 0:
        pred_XG_SM.append(y_pred_xg[i])
    else:
        pred_XG_NP.append(y_pred_xg[i])
        
        
print('Classification score (10ML):')
        
weights = np.ones_like(pred_XG_SM)/float(len(pred_XG_SM))
nSM, binsSM, patchesSM = plt.hist(pred_XG_SM, 100, weights=weights, range=[0,1], histtype='step', color='firebrick', linewidth=2, label='Background')

weights = np.ones_like(pred_XG_NP)/float(len(pred_XG_NP))
nNP, binsNP, patchesNP = plt.hist(pred_XG_NP, 100, weights=weights, range=[0,1], histtype='step', color='forestgreen', linewidth=2, label='Signal')

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("Classication score (XGBoost)",fontsize=15)
plt.ylabel("Fraction of events",fontsize=14)
plt.grid()
plt.legend(fontsize=12)
plt.title('Multivariate monian distributions, $\mathcal{N}_{2}$', fontsize=14)
#plt.savefig('images/' + '2monian-output.pdf', format="pdf", bbox_inches="tight")
plt.show()
# Out:
# Classification score (1ML):
# Classification score (10ML):

# %% [markdown]
# ## METHODS

# %% [markdown]
# ### 0. Ensembles characteristics

# %%
##############
# PARAMETERS #
##############

# requested number of ensembles
n_ensembles = 5000

# number of expected background events per ensemble
B_expected = 5000

# ratio S_expected/B_expected (signal ratio)
SB_ratio = [0.0006, 0.001, 0.0016, 0.0025, 0.005, 0.0075, 0.01, 0.025]





# SOME USEFUL DERIVATED PARAMETERS:

# S_expected:
S_expected = [ int(SB_ratio[iii]*B_expected) for iii in range(len(SB_ratio)) ]
print(S_expected)

# S/\sqrt{B}
SsqrtB = [ S_expected[iii]/(B_expected)**0.5 for iii in range(len(SB_ratio)) ]
# Out:
# [2, 5, 8, 12, 25, 37, 50, 125]

# %% [markdown]
# ### 1. BIN LOG LIKELIHOOD

# %%
# 1st variable: invariant mass
background_X_1 = invariant_mass_eeSM
signal_X_1 = invariant_mass_eeSSMZprime

N_B = len(background_X_1)
N_S = len(signal_X_1)

# bins
logbins = [2000.0, 2200.0, 2500.0, 2850.0, 3250.0, 3750.0, 4350.0, 5000.0, 5750.0, 6600.0, 7500.0, 8750.0, 10000.0, 11500.0, 13000.0, 20000.0]

# %%
#################################
# BINNED POISSON LOG-LIKELIHOOD #
#################################


store_Z_bins = []
store_Z_bins_logbins = []


for iii in range(len(SB_ratio)):

    print('B_expected: ', B_expected)
    print('S_expected: ', S_expected[iii])
    print(r'S/$\sqrt{B}$: ', SsqrtB[iii])

    # Les't use an integer number of possible ensembles
    N_ensembles_back = int(N_B / B_expected)
    N_events_back = N_ensembles_back * B_expected

    N_ensembles_sig = int(N_S / S_expected[iii])
    N_events_sig = N_ensembles_sig * S_expected[iii]


    #Let's find out the expected number of B and S events in each bin:

    # bin the parameter space of all background events
    hist_back, binedges_back = np.histogramdd([background_X_1[:N_events_back]], bins=(100), range = [[2000,20000]])
    # now divide by the number of possible ensembles
    back_prom = hist_back.T.ravel()/N_ensembles_back

    # same for signal
    hist_sig, binedges_sig = np.histogramdd([signal_X_1[:N_events_sig]], bins=(100), range = [[2000,20000]])
    sig_prom = hist_sig.T.ravel()/N_ensembles_sig

        

    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    back_prom_noceros = []
    for i in range(len(back_prom)):
        if back_prom[i]!=0:
            back_prom_noceros.append(back_prom[i])

    min_back = min(back_prom_noceros)

    # replace the zeros
    for i in range(len(back_prom)):
        if back_prom[i]==0:
            back_prom[i] = min_back

    # then the signif Z^binned-Asimov:
    Z_bins = ( 2* sum( ( back_prom * np.log( back_prom/(sig_prom + back_prom) ) ) + sig_prom ) )**0.5

    store_Z_bins.append(Z_bins)

    print('Z_bins : ', Z_bins)
    

    
    ############
    # LOG BINS #
    ############
    #Let's find out the expected number of B and S events in each bin:

    # bin the parameter space of all background events
    hist_back, binedges_back = np.histogramdd([background_X_1[:N_events_back]], bins=[logbins])
    # now divide by the number of possible ensembles
    back_prom = hist_back.T.ravel()/N_ensembles_back

    # same for signal
    hist_sig, binedges_sig = np.histogramdd([signal_X_1[:N_events_sig]], bins=[logbins])
    sig_prom = hist_sig.T.ravel()/N_ensembles_sig

        

    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    back_prom_noceros = []
    for i in range(len(back_prom)):
        if back_prom[i]!=0:
            back_prom_noceros.append(back_prom[i])

    min_back = min(back_prom_noceros)

    # replace the zeros
    for i in range(len(back_prom)):
        if back_prom[i]==0:
            back_prom[i] = min_back

    # then the signif Z^binned-Asimov:
    Z_bins_logbins = ( 2* sum( ( back_prom * np.log( back_prom/(sig_prom + back_prom) ) ) + sig_prom ) )**0.5

    store_Z_bins_logbins.append(Z_bins_logbins)

    print('Z_bins_logbins : ', Z_bins_logbins)
    
    
    
    print('\n ----------------------------------- \n')
# Out:
# B_expected:  5000
# S_expected:  2
# S/$\sqrt{B}$:  0.0282842712474619
# Z_bins :  0.7267575303197308
# Z_bins_logbins :  0.6470166171932079
#
#  -----------------------------------
#
# B_expected:  5000
# S_expected:  5
# S/$\sqrt{B}$:  0.07071067811865475
# Z_bins :  1.4392018778325846
# Z_bins_logbins :  1.3383696108633094
#
#  -----------------------------------
#
# B_expected:  5000
# S_expected:  8
# S/$\sqrt{B}$:  0.1131370849898476
# Z_bins :  1.9868610388579317
# Z_bins_logbins :  1.8825558660659536
#
#  -----------------------------------
#
# B_expected:  5000
# S_expected:  12
# S/$\sqrt{B}$:  0.1697056274847714
# Z_bins :  2.5903665404295326
# Z_bins_logbins :  2.486580172717145
#
#  -----------------------------------
#
# B_expected:  5000
# S_expected:  25
# S/$\sqrt{B}$:  0.35355339059327373
# Z_bins :  4.084807913662288
# Z_bins_logbins :  3.986012188626158
#
#  -----------------------------------
#
# B_expected:  5000
# S_expected:  37
# S/$\sqrt{B}$:  0.5232590180780452
# Z_bins :  5.157222948543219
# Z_bins_logbins :  5.061317241865792
#
#  -----------------------------------
#
# B_expected:  5000
# S_expected:  50
# S/$\sqrt{B}$:  0.7071067811865475
# Z_bins :  6.145966566680937
# Z_bins_logbins :  6.051983814777339
#
#  -----------------------------------
#
# B_expected:  5000
# S_expected:  125
# S/$\sqrt{B}$:  1.7677669529663687
# Z_bins :  10.33917161594237
# Z_bins_logbins :  10.249805678800298
#
#  -----------------------------------

# %%
print(store_Z_bins)
print(store_Z_bins_logbins)
# Out:
# [0.7267575303197308, 1.4392018778325846, 1.9868610388579317, 2.5903665404295326, 4.084807913662288, 5.157222948543219, 6.145966566680937, 10.33917161594237]
# [0.6470166171932079, 1.3383696108633094, 1.8825558660659536, 2.486580172717145, 3.986012188626158, 5.061317241865792, 6.051983814777339, 10.249805678800298]

# %%
store_Z_bins = [0.7267575303197308, 1.4392018778325846, 1.9868610388579317, 2.5903665404295326, 4.084807913662288, 5.157222948543219, 6.145966566680937, 10.33917161594237]

store_Z_bins_logbins = [0.6470166171932079, 1.3383696108633094, 1.8825558660659536, 2.486580172717145, 3.986012188626158, 5.061317241865792, 6.051983814777339, 10.249805678800298]

# %%
#########
# PLOTS #
#########

posX = []

for i in range(len(SB_ratio)):
    posX.append( (B_expected*SB_ratio[i]) / ( B_expected )**0.5 )


    
plt.figure()
lw = 2

plt.plot(posX, store_Z_bins, '-ok', color='blue', lw=lw, label='100 Linear Binned Likelihood') 
plt.plot(posX, store_Z_bins_logbins, '-ok', color='lightblue', lw=lw, label='15 Log Binned Likelihood')

#plt.xlim([0.5, 10])
#plt.ylim([-0.5, 7.5])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=14)
plt.ylabel('$Z_{\mu}$ (exclusion)', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title('<B> per ensemble: %0.2d' % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()
# Out:
# <ipython-input-18-3340ebf10fa5>:15: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins, '-ok', color='blue', lw=lw, label='100 Linear Binned Likelihood')
# <ipython-input-18-3340ebf10fa5>:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_logbins, '-ok', color='lightblue', lw=lw, label='15 Log Binned Likelihood')

# %% [markdown]
# ### 2. Binned OUTPUT and MLL Asimov

# %%
#################################
# MLL Asimov-like #
#################################


store_Z_bins_XG = []

store_Z_bins_XG_15bins = []
store_Z_bins_XG_15bins_1ML = []

store_Z_bins_XG_15bins_eq = []
store_Z_bins_XG_15bins_eq_1ML = []


for iii in range(len(SB_ratio)):

    print('B_expected: ', B_expected)
    print('S_expected: ', S_expected[iii])
    print(r'S/$\sqrt{B}$: ', SsqrtB[iii])

    # Les't find the number of possible ensembles
    N_ensembles_back = len(pred_XG_SM) / B_expected
    N_ensembles_sig = len(pred_XG_NP) / S_expected[iii]



    #Let's find out the expected number of B and S events in each bin:
 
    # bin the parameter space of all background events
    hist_back, binedges_back = np.histogramdd([pred_XG_SM], bins=(100), range = [[0,1]])
    
    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    hist_back_noceros = []
    for i in range(len(hist_back)):
        if hist_back[i]!=0:
            hist_back_noceros.append(hist_back[i])

    min_back = min(hist_back_noceros)

    # replace the zeros
    for i in range(len(hist_back)):
        if hist_back[i]==0:
            hist_back[i] = min_back
    
    # now divide by the number of possible ensembles
    back_prom = hist_back/N_ensembles_back
    # normalized (sum=1)
    back_norm = hist_back/np.sum(hist_back)

    
    
    # same for signal
    hist_sig, binedges_sig = np.histogramdd([pred_XG_NP], bins=(100), range = [[0,1]])
    sig_prom = hist_sig/N_ensembles_sig
    sig_norm = hist_sig/np.sum(hist_sig)
        


    ##########################################
    # BINNED LIKELIHOOD of CLASSIFIER OUTPUT #
    ##########################################

    # then the signif Z^binned-Asimov:
    Z_bins_XG = ( 2* sum( ( back_prom * np.log( back_prom / (sig_prom+back_prom) ) ) + sig_prom ) )**0.5

    store_Z_bins_XG.append(Z_bins_XG)

    print('Z_bins_XG : ', Z_bins_XG)
    
    
    
    
    
    ######################
    # linear bins, 10 ML #
    ######################
    
    #Let's find out the expected number of B and S events in each bin:
 
    # bin the parameter space of all background events
    hist_back, binedges_back = np.histogramdd([pred_XG_SM], bins=(15), range = [[0,1]])
    
    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    hist_back_noceros = []
    for i in range(len(hist_back)):
        if hist_back[i]!=0:
            hist_back_noceros.append(hist_back[i])

    min_back = min(hist_back_noceros)

    # replace the zeros
    for i in range(len(hist_back)):
        if hist_back[i]==0:
            hist_back[i] = min_back
    
    # now divide by the number of possible ensembles
    back_prom = hist_back/N_ensembles_back
    # normalized (sum=1)
    back_norm = hist_back/np.sum(hist_back)

    
    
    # same for signal
    hist_sig, binedges_sig = np.histogramdd([pred_XG_NP], bins=(15), range = [[0,1]])
    sig_prom = hist_sig/N_ensembles_sig
    sig_norm = hist_sig/np.sum(hist_sig)
        


    ##########################################
    # BINNED LIKELIHOOD of CLASSIFIER OUTPUT #
    ##########################################

    # then the signif Z^binned-Asimov:
    Z_bins_XG_15bins = ( 2* sum( ( back_prom * np.log( back_prom / (sig_prom+back_prom) ) ) + sig_prom ) )**0.5

    store_Z_bins_XG_15bins.append(Z_bins_XG_15bins)

    print('Z_bins_XG_15bins : ', Z_bins_XG_15bins)
    
    
    
    
    
    ######################
    # linear bins, 1  ML #
    ######################
    
    #Let's find out the expected number of B and S events in each bin:
 
    # bin the parameter space of all background events
    hist_back, binedges_back = np.histogramdd([pred_XG_SM_1ML], bins=(15), range = [[0,1]])
    
    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    hist_back_noceros = []
    for i in range(len(hist_back)):
        if hist_back[i]!=0:
            hist_back_noceros.append(hist_back[i])

    min_back = min(hist_back_noceros)

    # replace the zeros
    for i in range(len(hist_back)):
        if hist_back[i]==0:
            hist_back[i] = min_back
    
    # now divide by the number of possible ensembles
    back_prom = hist_back/N_ensembles_back
    # normalized (sum=1)
    back_norm = hist_back/np.sum(hist_back)

    
    
    # same for signal
    hist_sig, binedges_sig = np.histogramdd([pred_XG_NP], bins=(15), range = [[0,1]])
    sig_prom = hist_sig/N_ensembles_sig
    sig_norm = hist_sig/np.sum(hist_sig)
        


    ##########################################
    # BINNED LIKELIHOOD of CLASSIFIER OUTPUT #
    ##########################################

    # then the signif Z^binned-Asimov:
    Z_bins_XG_15bins_1ML = ( 2* sum( ( back_prom * np.log( back_prom / (sig_prom+back_prom) ) ) + sig_prom ) )**0.5

    store_Z_bins_XG_15bins_1ML.append(Z_bins_XG_15bins_1ML)

    print('Z_bins_XG_15bins_1ML : ', Z_bins_XG_15bins_1ML)
    
    
    
    
    
    ##########################
    # non linear bins, 10 ML #
    ##########################
    
    #Let's find out the expected number of B and S events in each bin:
    # same number of B events per bin
    bin_edges_same = pd.qcut(pd.DataFrame(pred_XG_SM)[0], q = 15, precision=0, retbins = True)[1]
 
    # bin the parameter space of all background events
    hist_back, binedges_back = np.histogramdd([pred_XG_SM], bins=[bin_edges_same], range = [[0,1]])
    
    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    hist_back_noceros = []
    for i in range(len(hist_back)):
        if hist_back[i]!=0:
            hist_back_noceros.append(hist_back[i])

    min_back = min(hist_back_noceros)

    # replace the zeros
    for i in range(len(hist_back)):
        if hist_back[i]==0:
            hist_back[i] = min_back
    
    # now divide by the number of possible ensembles
    back_prom = hist_back/N_ensembles_back
    # normalized (sum=1)
    back_norm = hist_back/np.sum(hist_back)

    
    
    # same for signal
    hist_sig, binedges_sig = np.histogramdd([pred_XG_NP], bins=[bin_edges_same], range = [[0,1]])
    sig_prom = hist_sig/N_ensembles_sig
    sig_norm = hist_sig/np.sum(hist_sig)
        


    ##########################################
    # BINNED LIKELIHOOD of CLASSIFIER OUTPUT #
    ##########################################

    # then the signif Z^binned-Asimov:
    Z_bins_XG_15bins_eq = ( 2* sum( ( back_prom * np.log( back_prom / (sig_prom+back_prom) ) ) + sig_prom ) )**0.5

    store_Z_bins_XG_15bins_eq.append(Z_bins_XG_15bins_eq)

    print('Z_bins_XG_15bins_eq : ', Z_bins_XG_15bins_eq)
    
    
    
    
    
    ##########################
    # non linear bins, 1  ML #
    ##########################
    
    #Let's find out the expected number of B and S events in each bin:
    # same number of B events per bin
    bin_edges_same = pd.qcut(pd.DataFrame(pred_XG_SM_1ML)[0], q = 15, precision=0, retbins = True)[1]
 
    # bin the parameter space of all background events
    hist_back, binedges_back = np.histogramdd([pred_XG_SM_1ML], bins=[bin_edges_same], range = [[0,1]])
    
    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    hist_back_noceros = []
    for i in range(len(hist_back)):
        if hist_back[i]!=0:
            hist_back_noceros.append(hist_back[i])

    min_back = min(hist_back_noceros)

    # replace the zeros
    for i in range(len(hist_back)):
        if hist_back[i]==0:
            hist_back[i] = min_back
    
    # now divide by the number of possible ensembles
    back_prom = hist_back/N_ensembles_back
    # normalized (sum=1)
    back_norm = hist_back/np.sum(hist_back)

    
    
    # same for signal
    hist_sig, binedges_sig = np.histogramdd([pred_XG_NP_1ML], bins=[bin_edges_same], range = [[0,1]])
    sig_prom = hist_sig/N_ensembles_sig
    sig_norm = hist_sig/np.sum(hist_sig)
        


    ##########################################
    # BINNED LIKELIHOOD of CLASSIFIER OUTPUT #
    ##########################################

    # then the signif Z^binned-Asimov:
    Z_bins_XG_15bins_eq_1ML = ( 2* sum( ( back_prom * np.log( back_prom / (sig_prom+back_prom) ) ) + sig_prom ) )**0.5

    store_Z_bins_XG_15bins_eq_1ML.append(Z_bins_XG_15bins_eq_1ML)

    print('Z_bins_XG_15bins_eq_1ML : ', Z_bins_XG_15bins_eq_1ML)


        
    print('\n ----------------------------------------- \n')
# Out:
# B_expected:  5000
# S_expected:  2
# S/$\sqrt{B}$:  0.0282842712474619
# Z_bins_XG :  0.47689373423768594
# Z_bins_XG_15bins :  0.24691450413076946
# Z_bins_XG_15bins_1ML :  0.24365043307595952
# Z_bins_XG_15bins_eq :  0.07426092108512158
# Z_bins_XG_15bins_eq_1ML :  0.07406150224201788
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  5
# S/$\sqrt{B}$:  0.07071067811865475
# Z_bins_XG :  1.0738841510021966
# Z_bins_XG_15bins :  0.6005145856718667
# Z_bins_XG_15bins_1ML :  0.5929858689651195
# Z_bins_XG_15bins_eq :  0.18528832340776413
# Z_bins_XG_15bins_eq_1ML :  0.18479178430173224
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  8
# S/$\sqrt{B}$:  0.1131370849898476
# Z_bins_XG :  1.5806742847597863
# Z_bins_XG_15bins :  0.9363808136417588
# Z_bins_XG_15bins_1ML :  0.9252021505779627
# Z_bins_XG_15bins_eq :  0.2958830217397001
# Z_bins_XG_15bins_eq_1ML :  0.2950917386073766
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  12
# S/$\sqrt{B}$:  0.1697056274847714
# Z_bins_XG :  2.165757615248736
# Z_bins_XG_15bins :  1.3603661008454664
# Z_bins_XG_15bins_1ML :  1.3450706974799977
# Z_bins_XG_15bins_eq :  0.4426773099951883
# Z_bins_XG_15bins_eq_1ML :  0.4414966677277562
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  25
# S/$\sqrt{B}$:  0.35355339059327373
# Z_bins_XG :  3.6684242313013797
# Z_bins_XG_15bins :  2.5916864793935552
# Z_bins_XG_15bins_1ML :  2.5669316708857077
# Z_bins_XG_15bins_eq :  0.914626648280304
# Z_bins_XG_15bins_eq_1ML :  0.912208301871902
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  37
# S/$\sqrt{B}$:  0.5232590180780452
# Z_bins_XG :  4.763362234278601
# Z_bins_XG_15bins :  3.582489587200975
# Z_bins_XG_15bins_1ML :  3.5521502746156624
# Z_bins_XG_15bins_eq :  1.3435300594569566
# Z_bins_XG_15bins_eq_1ML :  1.3400050502467282
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  50
# S/$\sqrt{B}$:  0.7071067811865475
# Z_bins_XG :  5.775242108071856
# Z_bins_XG_15bins :  4.5443066980661815
# Z_bins_XG_15bins_1ML :  4.509774802626322
# Z_bins_XG_15bins_eq :  1.8011728824974949
# Z_bins_XG_15bins_eq_1ML :  1.7964854530711982
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  125
# S/$\sqrt{B}$:  1.7677669529663687
# Z_bins_XG :  10.053465570222512
# Z_bins_XG_15bins :  8.845971526238747
# Z_bins_XG_15bins_1ML :  8.800890980836348
# Z_bins_XG_15bins_eq :  4.313207041763576
# Z_bins_XG_15bins_eq_1ML :  4.302449308721457
#
#  -----------------------------------------

# %%
print(store_Z_bins_XG)

print(store_Z_bins_XG_15bins)
print(store_Z_bins_XG_15bins_1ML)

print(store_Z_bins_XG_15bins_eq)
print(store_Z_bins_XG_15bins_eq_1ML)
# Out:
# [0.47689373423768594, 1.0738841510021966, 1.5806742847597863, 2.165757615248736, 3.6684242313013797, 4.763362234278601, 5.775242108071856, 10.053465570222512]
# [0.24691450413076946, 0.6005145856718667, 0.9363808136417588, 1.3603661008454664, 2.5916864793935552, 3.582489587200975, 4.5443066980661815, 8.845971526238747]
# [0.24365043307595952, 0.5929858689651195, 0.9252021505779627, 1.3450706974799977, 2.5669316708857077, 3.5521502746156624, 4.509774802626322, 8.800890980836348]
# [0.07426092108512158, 0.18528832340776413, 0.2958830217397001, 0.4426773099951883, 0.914626648280304, 1.3435300594569566, 1.8011728824974949, 4.313207041763576]
# [0.07406150224201788, 0.18479178430173224, 0.2950917386073766, 0.4414966677277562, 0.912208301871902, 1.3400050502467282, 1.7964854530711982, 4.302449308721457]

# %%
store_Z_bins_XG = [0.47689373423768594, 1.0738841510021966, 1.5806742847597863, 2.165757615248736, 3.6684242313013797, 4.763362234278601, 5.775242108071856, 10.053465570222512]

store_Z_bins_XG_15bins = [0.24691450413076946, 0.6005145856718667, 0.9363808136417588, 1.3603661008454664, 2.5916864793935552, 3.582489587200975, 4.5443066980661815, 8.845971526238747]
store_Z_bins_XG_15bins_1ML = [0.24365043307595952, 0.5929858689651195, 0.9252021505779627, 1.3450706974799977, 2.5669316708857077, 3.5521502746156624, 4.509774802626322, 8.800890980836348]

store_Z_bins_XG_15bins_eq = [0.07426092108512158, 0.18528832340776413, 0.2958830217397001, 0.4426773099951883, 0.914626648280304, 1.3435300594569566, 1.8011728824974949, 4.313207041763576]
store_Z_bins_XG_15bins_eq_1ML = [0.07406150224201788, 0.18479178430173224, 0.2950917386073766, 0.4414966677277562, 0.912208301871902, 1.3400050502467282, 1.7964854530711982, 4.302449308721457]

# %%
#########
# PLOTS #
#########

posX = []

for i in range(len(SB_ratio)):
    posX.append( (B_expected*SB_ratio[i]) / ( B_expected )**0.5 )



    
    
plt.figure()
lw = 2

plt.plot(posX, store_Z_bins_XG, '-ok', color='blue', lw=lw, label='o(x) BL (100 l.bins)') 
plt.plot(posX, store_Z_bins_XG_15bins, '-ok', color='red', lw=lw, label='o(x) BL (15 l.bins) (10ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_1ML, '-ok', color='green', lw=lw, label='o(x) BL (15 l.bins) (1ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_eq, '-ok', color='magenta', lw=lw, label='o(x) BL (15 n.l.bins) (10ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_eq_1ML, '-ok', color='darkorange', lw=lw, label='o(x) BL (15 n.l.bins) (1ML)') 

#plt.xlim([0.5, 10])
#plt.ylim([-0.5, 7.5])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=14)
plt.ylabel('$Z_{\mu}$ (exclusion)', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title("SSM Z', <B> per ensemble: %0.2d" % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()
# Out:
# <ipython-input-8-13c05c382495>:17: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG, '-ok', color='blue', lw=lw, label='o(x) BL (100 l.bins)')
# <ipython-input-8-13c05c382495>:18: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins, '-ok', color='red', lw=lw, label='o(x) BL (15 l.bins) (10ML)')
# <ipython-input-8-13c05c382495>:19: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_1ML, '-ok', color='green', lw=lw, label='o(x) BL (15 l.bins) (1ML)')
# <ipython-input-8-13c05c382495>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_eq, '-ok', color='magenta', lw=lw, label='o(x) BL (15 n.l.bins) (10ML)')
# <ipython-input-8-13c05c382495>:21: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_eq_1ML, '-ok', color='darkorange', lw=lw, label='o(x) BL (15 n.l.bins) (1ML)')

# %% [markdown]
# ### 3. MACHINE-LEARNED LIKELIHOOD with KDE

# %% [markdown]
# ##### For 10 ML

# %%
store_Z_MLL_KDE = []
store_Z_MLL_KDE_mu0 = []

store_muhat_mean_MLL = []




# FIND THE BANDWIDTH

bandwidth = np.logspace(-3.0, 0.05, 20)
print(bandwidth)

kde = KernelDensity(kernel='epanechnikov')
grid = GridSearchCV(kde, {'bandwidth': bandwidth})
grid.fit(np.c_[pred_XG_SM[:50000]])
print(grid.best_estimator_)

SM_bandwidth = grid.best_estimator_.bandwidth



kde = KernelDensity(kernel='epanechnikov')
grid = GridSearchCV(kde, {'bandwidth': bandwidth})
grid.fit(np.c_[pred_XG_NP[:50000]])
print(grid.best_estimator_)

NP_bandwidth = grid.best_estimator_.bandwidth







# aca fitteo 
kde_bkg = KernelDensity(kernel="epanechnikov", bandwidth=SM_bandwidth).fit(np.c_[pred_XG_SM, np.zeros(len(pred_XG_SM)) ])
kde_sig = KernelDensity(kernel="epanechnikov", bandwidth=NP_bandwidth).fit(np.c_[pred_XG_NP, np.ones(len(pred_XG_NP)) ])


# elijo los valores para graficar y calcular la significancia de Asimov
min_val = np.min([np.min(pred_XG_SM),np.min(pred_XG_NP)])
max_val = np.max([np.max(pred_XG_SM),np.max(pred_XG_NP)])

s_vals = np.linspace(min_val,max_val,100)





# evaluo las densidades en cada valor de s. esto es mas o menos equivalente a tomar bines continuos
dens_bkg = np.exp(kde_bkg.score_samples(np.c_[s_vals, np.zeros(len(s_vals)) ]) )
dens_sig = np.exp(kde_sig.score_samples(np.c_[s_vals, np.ones(len(s_vals)) ]) )





# PERO NO ESTA NORMALIZADO A 1 el area
# Area
factor_aux_SM = sum(dens_bkg*(s_vals[1]-s_vals[0]))
factor_aux_NP = sum(dens_sig*(s_vals[1]-s_vals[0]))

# normalizo
dens_bkg = dens_bkg / factor_aux_SM
dens_sig = dens_sig / factor_aux_NP






# grafico y verifico si la densidad es una buena aproximacion

plt.figure()

plt.hist(pred_XG_SM,density=True,bins=50,color='red',alpha=0.25,label='Sampled $p_{b}$');
plt.plot(s_vals,dens_bkg,color='red',label='Learned $p_{b}$',linestyle='dashed');

plt.hist(pred_XG_NP,density=True,bins=50,color='blue',alpha=0.25,label='Sampled $p_{s}$');
plt.plot(s_vals,dens_sig,color='blue',label='Learned $p_{s}$',linestyle='dashed');

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("o(x)",fontsize=15)
plt.ylabel("PDF",fontsize=14)
plt.grid()
plt.legend(fontsize=12)
#plt.title(r"Signal: W'$\rightarrow$XY, Background: QCD", fontsize=14)
#plt.savefig('images/' + 'Wprime-output.pdf', format="pdf", bbox_inches="tight")
plt.show()



  
    
    

# all the dataset though the SM and NP KDEs
# with this we'll form the toy samples for MLL

KDE_SM_pred_SM = np.exp(kde_bkg.score_samples(np.c_[pred_XG_SM, np.zeros(len(pred_XG_SM)) ]) )
KDE_NP_pred_SM = np.exp(kde_sig.score_samples(np.c_[pred_XG_SM, np.ones(len(pred_XG_SM)) ]) )

# Normalize

KDE_SM_pred_SM = KDE_SM_pred_SM / factor_aux_SM
KDE_NP_pred_SM = KDE_NP_pred_SM / factor_aux_NP




indices = [i for i in range(len(KDE_NP_pred_SM))]


########################
# METHOD: MLL with KDE #
########################

print('\n-------------------------------------')
print(' MLL with KDE')
print('-------------------------------------')




for iii in range(len(SB_ratio)):
    
    print('B_expected: ', B_expected)
    print('S_expected: ', S_expected[iii])
    print(r'S/$\sqrt{B}$: ', SsqrtB[iii])
    print('n_ensembles (initial): ', n_ensembles, '\n')

    
    

    ###########
    # NOW MLL #
    ###########

    # to construct ensembles B and S events are taken from Poisson distributions
    mu = S_expected[iii] + B_expected


    # Letś find the number of events per ensemble such that we get at least one ensemble populated if events are taken from a Poisson distribution

    # around the mean its populated so let's try (proposed range to be checked)
    list_events_per_ensembles = [i for i in range(int(mu*0.9),int(mu*1.1))]
    to_check = len(list_events_per_ensembles)

    # I want at least one ensemble populated
    list_nums_ensembles = [ int( poisson.pmf(list_events_per_ensembles[i],mu)*n_ensembles ) for i in range(len(list_events_per_ensembles)) ]



    # Remove from the list the elements without at least 1 ensemble possible
    for i in range(len(list_events_per_ensembles)):
        if list_nums_ensembles[i] > 1:
            list_events_per_ensembles = list_events_per_ensembles[i:]
            list_nums_ensembles = list_nums_ensembles[i:]
            break


    for i in range(len(list_events_per_ensembles)):
        if list_nums_ensembles[i] < 1:
            list_events_per_ensembles = list_events_per_ensembles[:i]
            list_nums_ensembles = list_nums_ensembles[:i]
            break

    print('\n If ', to_check, ' = ', len(list_events_per_ensembles), '   then the proposed range has to be extended')

    print('n_ensembles (actual): ', sum(list_nums_ensembles))



    # lists of S and B events per ensemble, w.r.t the total of number of events per ensemble found above:

    p_berno = S_expected[iii]/(S_expected[iii]+B_expected)

    list_S_per_ensembles = []
    list_B_per_ensembles = []

    for jj in range(len(list_events_per_ensembles)):
        list_S_per_ensembles.append( int(p_berno * list_events_per_ensembles[jj]) )
        list_B_per_ensembles.append( list_events_per_ensembles[jj] - int(p_berno * list_events_per_ensembles[jj]) )

    ######
    # NOW I HAVE 4 LISTS:
    # list_events_per_ensembles     list with the number of events per ensemble (its a range)
    # list_nums_ensembles           list with the number of ensembles, w.r.t the 1st list
    # list_S_per_ensembles          list with the number of signal events in each ensembles, w.r.t the 1st list
    # list_B_per_ensembles          list with the number of background events in each ensembles, w.r.t the 1st list
    ######



    print('\n This may take long... \n')


    # NOW LETS APPLY THE METHOD

    muhat_selected_list = []
    q_muhat = []
    q_muhat_mu0 = []

    for bb in range(len(list_nums_ensembles)):

        for kk in range(list_nums_ensembles[bb]):

            # KDE
            ran_ind = np.random.choice(indices, list_B_per_ensembles[bb])

            KDE_SM_pred_SM_shuf = []
            KDE_NP_pred_SM_shuf = []

            for i in ran_ind:
                KDE_SM_pred_SM_shuf.append(KDE_SM_pred_SM[i])
                KDE_NP_pred_SM_shuf.append(KDE_NP_pred_SM[i])

            KDE_SM_pred_SM_shuf  = np.array(KDE_SM_pred_SM_shuf)
            KDE_NP_pred_SM_shuf  = np.array(KDE_NP_pred_SM_shuf)



            # p_b(o(x_ensemble)) =    concatenate: p_b(o(B_ensemble)) and p_b(o(S_ensemble))  NOTICE THE o(x)
            prob_x_given_B = np.ndarray.tolist( KDE_SM_pred_SM_shuf ) #+ np.ndarray.tolist( KDE_SM_pred_NP_shuf )

            # p_s(o(x_ensemble)) =    concatenate: p_s(o(B_ensemble)) and p_s(o(S_ensemble))  NOTICE THE o(x)
            prob_x_given_S = np.ndarray.tolist( KDE_NP_pred_SM_shuf ) #+ np.ndarray.tolist( KDE_NP_pred_NP_shuf )









            # NOW WE HAVE p_{s,b}(x_ensemble) for this particular ensemble
            # WE NEED TO ESTIMATE mu_hat for this particular ensemble
            # we are going to obtain a mu_hat with a grid of values for this particular ensemble



            mu_hat_condition_equal_1 = []

            # grid, mu_hat is around 1
            muhat_test = np.arange(0., 1.5, 0.1).tolist()

            B_prob_x_given_B = [x * B_expected for x in prob_x_given_B]

            for vv in range(len(muhat_test)):

                mu_hat_condition_equal_1.append( sum ( [(x*1.) / ( (x * muhat_test[vv] * S_expected[iii]) + y ) for x, y in zip(prob_x_given_S, B_prob_x_given_B)] ) )



            muhat_selected = 0

            # from the grid, select the mu_hat such that the condition is equal to 1
            if mu_hat_condition_equal_1[0] < mu_hat_condition_equal_1[-1]:
                for ll in range(len(mu_hat_condition_equal_1)):
                    if mu_hat_condition_equal_1[ll] -1 > 0:
                        muhat_selected = muhat_test[ll]
                        break


            if mu_hat_condition_equal_1[0] > mu_hat_condition_equal_1[-1]:
                for ll in range(len(mu_hat_condition_equal_1)):
                    if mu_hat_condition_equal_1[ll] -1 < 0:
                        muhat_selected = muhat_test[ll]
                        break


            muhat_selected_list.append(muhat_selected)



            # NOW THAT WE HAVE mu_hat FOR THIS ENSEMBLE, CALCULATE THE TEST STATISTIC FOR THIS ENSEMBLE
            # and append it (we need the median over lots of ensembles)
            #q_muhat.append( 2 * ( (-1.*muhat_selected * S_expected[iii]) + sum( [np.log( 1 + ( (muhat_selected*S_expected[iii]/B_expected) * (x / y) ) ) for x, y in zip(prob_x_given_S, prob_x_given_B)] ) ) )
            # EXCLUSION:
            q_muhat.append( 2 * ( ( (1.-muhat_selected) * S_expected[iii] ) - sum( [np.log( ( (B_expected*y) + (S_expected[iii]*x) ) / ( (B_expected*y) + (muhat_selected*S_expected[iii]*x) ) ) for x, y in zip(prob_x_given_S, prob_x_given_B)] )
    ) )
            q_muhat_mu0.append( 2 * ( ( (1.-0.) * S_expected[iii] ) - sum( [np.log( ( (B_expected*y) + (S_expected[iii]*x) ) / ( (B_expected*y) + (0.*S_expected[iii]*x) ) ) for x, y in zip(prob_x_given_S, prob_x_given_B)] )
    ) )


    # Histogram of q_muhats

    weights = np.ones_like(q_muhat)/float(len(q_muhat))
    nMIX, binsMIX, patchesMIX = plt.hist(q_muhat, 25, weights=weights, histtype='step', color='blue', linewidth=2)
    #plt.xlim(0,1)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.xlabel("$q_0(\hat{\mu})$",fontsize=16)
    plt.ylabel("Fraction of ensembles",fontsize=16)
    plt.title(r"$\bar{B}$=%0.2i, $\bar{S}=$%0.2i" % (B_expected,S_expected[iii]),fontsize=14)
    plt.grid()
    #plt.legend(fontsize=14)
    plt.show()


    # Finally calculate muhat_mean and Z_gaussian

    # Remove nan if any
    q_muhat_mu0 = [x for x in q_muhat_mu0 if x == x]
    for jk in range(len(q_muhat_mu0)):
        if q_muhat_mu0[jk] < 0:
            q_muhat_mu0[jk] = 0

    q_muhat_median_mu0 = np.median(q_muhat_mu0)

    Z_KDE_mu0 = abs(q_muhat_median_mu0)**0.5
    store_Z_MLL_KDE_mu0.append(Z_KDE_mu0)


    # Finally calculate muhat_mean and Z_gaussian
    muhat_mean = np.mean(muhat_selected_list)
    store_muhat_mean_MLL.append(muhat_mean)

    # Remove nan if any
    q_muhat = [x for x in q_muhat if x == x]
    for jk in range(len(q_muhat)):
        if q_muhat[jk] < 0:
            q_muhat[jk] = 0

    q_muhat_median = np.median(q_muhat)

    Z_KDE = abs(q_muhat_median)**0.5
    store_Z_MLL_KDE.append(Z_KDE)

    print('muhat mean: ', muhat_mean)
    print('median q_muhat: ', q_muhat_median)
    print('Z_KDE: ', Z_KDE)
    print('Z_KDE mu=0: ', Z_KDE_mu0)
    
    print('\n ----------------------------------------- \n')
# Out:
# [1.00000000e-03 1.44719254e-03 2.09436625e-03 3.03095122e-03
#  4.38637001e-03 6.34792196e-03 9.18666532e-03 1.32948735e-02
#  1.92402418e-02 2.78443345e-02 4.02961132e-02 5.83162345e-02
#  8.43948197e-02 1.22135554e-01 1.76753662e-01 2.55796582e-01
#  3.70186906e-01 5.35731729e-01 7.75306963e-01 1.12201845e+00]
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [          -inf           -inf           -inf           -inf
#            -inf           -inf           -inf 10948.21199312
#  10923.61779029 10846.71022926 10650.14063198 10260.36999873
#   9621.45571566  8712.33011081  7483.67982262  5908.63941137
#   3955.74811491  1624.10295389 -1132.8632953  -4375.93811606]
#   warnings.warn(
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:929: RuntimeWarning: invalid value encountered in subtract
#   array_stds = np.sqrt(np.average((array -
# KernelDensity(bandwidth=0.01329487353451575, kernel='epanechnikov')
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [          -inf           -inf           -inf 16522.41824083
#  15980.66541378 15191.72409118 14174.49851861 12993.81040424
#  11694.06434586 10328.20684358  8920.39618023  7442.16631374
#   5880.18693091  4255.74609486  2558.28763548   781.49988933
#  -1071.89418522 -3024.1122857  -4649.19073507 -5862.32277915]
#   warnings.warn(
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:929: RuntimeWarning: invalid value encountered in subtract
#   array_stds = np.sqrt(np.average((array -
# KernelDensity(bandwidth=0.003030951223220623, kernel='epanechnikov')
# -------------------------------------
#  MLL with KDE
# -------------------------------------
# B_expected:  5000
# S_expected:  2
# S/$\sqrt{B}$:  0.0282842712474619
# n_ensembles (initial):  5000
#
#
#  If  1001  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4759
#
#  This may take long...
# muhat mean:  0.20804790922462704
# median q_muhat:  0.6242539248335208
# Z_KDE:  0.7900974147746092
# Z_KDE mu=0:  0.7900974147746092
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  5
# S/$\sqrt{B}$:  0.07071067811865475
# n_ensembles (initial):  5000
#
#
#  If  1001  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4757
#
#  This may take long...
# muhat mean:  0.21477822156821527
# median q_muhat:  2.278755330722369
# Z_KDE:  1.509554679606661
# Z_KDE mu=0:  1.509954322705003
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  8
# S/$\sqrt{B}$:  0.1131370849898476
# n_ensembles (initial):  5000
#
#
#  If  1001  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4757
#
#  This may take long...
# muhat mean:  0.16235022072734917
# median q_muhat:  4.260173245829238
# Z_KDE:  2.064018712567606
# Z_KDE mu=0:  2.065491832492382
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  12
# S/$\sqrt{B}$:  0.1697056274847714
# n_ensembles (initial):  5000
#
#
#  If  1003  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4757
#
#  This may take long...
# muhat mean:  0.11780533949968469
# median q_muhat:  7.415703721371099
# Z_KDE:  2.7231789734373133
# Z_KDE mu=0:  2.7325090110059795
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  25
# S/$\sqrt{B}$:  0.35355339059327373
# n_ensembles (initial):  5000
#
#
#  If  1005  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4753
#
#  This may take long...
# muhat mean:  0.07056595834209972
# median q_muhat:  19.174646276104152
# Z_KDE:  4.3788864196396045
# Z_KDE mu=0:  4.389790960883447
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  37
# S/$\sqrt{B}$:  0.5232590180780452
# n_ensembles (initial):  5000
#
#
#  If  1007  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4751
#
#  This may take long...
# muhat mean:  0.0567249000210482
# median q_muhat:  30.460330553061844
# Z_KDE:  5.519087837048967
# Z_KDE mu=0:  5.5508484668622815
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  50
# S/$\sqrt{B}$:  0.7071067811865475
# n_ensembles (initial):  5000
#
#
#  If  1010  =  347    then the proposed range has to be extended
# n_ensembles (actual):  4754
#
#  This may take long...
# muhat mean:  0.051998317206562894
# median q_muhat:  43.29799465435977
# Z_KDE:  6.580121173227722
# Z_KDE mu=0:  6.621730549827786
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  125
# S/$\sqrt{B}$:  1.7677669529663687
# n_ensembles (initial):  5000
#
#
#  If  1025  =  349    then the proposed range has to be extended
# n_ensembles (actual):  4744
#
#  This may take long...
# muhat mean:  0.04618465430016864
# median q_muhat:  122.09230859686227
# Z_KDE:  11.049538840913781
# Z_KDE mu=0:  11.16682153568581
#
#  -----------------------------------------

# %%
print(store_Z_MLL_KDE)
print(store_Z_MLL_KDE_mu0)

print(store_muhat_mean_MLL)
# Out:
# [0.7900974147746092, 1.509554679606661, 2.064018712567606, 2.7231789734373133, 4.3788864196396045, 5.519087837048967, 6.580121173227722, 11.049538840913781]
# [0.7900974147746092, 1.509954322705003, 2.065491832492382, 2.7325090110059795, 4.389790960883447, 5.5508484668622815, 6.621730549827786, 11.16682153568581]
# [0.20804790922462704, 0.21477822156821527, 0.16235022072734917, 0.11780533949968469, 0.07056595834209972, 0.0567249000210482, 0.051998317206562894, 0.04618465430016864]

# %%
store_Z_MLL_KDE = [0.7900974147746092, 1.509554679606661, 2.064018712567606, 2.7231789734373133, 4.3788864196396045, 5.519087837048967, 6.580121173227722, 11.049538840913781]
store_Z_MLL_KDE_mu0 = [0.7900974147746092, 1.509954322705003, 2.065491832492382, 2.7325090110059795, 4.389790960883447, 5.5508484668622815, 6.621730549827786, 11.16682153568581]

store_muhat_mean_MLL = [0.20804790922462704, 0.21477822156821527, 0.16235022072734917, 0.11780533949968469, 0.07056595834209972, 0.0567249000210482, 0.051998317206562894, 0.04618465430016864]

# %% [markdown]
# ##### For 1 ML

# %%
store_Z_KDE_bins = []

store_Z_MLL_KDE_1ML = []
store_Z_MLL_KDE_mu0_1ML = []

store_muhat_mean_MLL_1ML = []




# FIND THE BANDWIDTH

# bandwidth = np.logspace(-3.0, 0.05, 20)
# print(bandwidth)

# kde = KernelDensity(kernel='epanechnikov')
# grid = GridSearchCV(kde, {'bandwidth': bandwidth})
# grid.fit(np.c_[pred_XG_SM_1ML[:50000]])
# print(grid.best_estimator_)

# SM_bandwidth_1ML = grid.best_estimator_.bandwidth
SM_bandwidth_1ML = 0.01329487353451575


# kde = KernelDensity(kernel='epanechnikov')
# grid = GridSearchCV(kde, {'bandwidth': bandwidth})
# grid.fit(np.c_[pred_XG_NP_1ML[:50000]])
# print(grid.best_estimator_)

# NP_bandwidth_1ML = grid.best_estimator_.bandwidth
NP_bandwidth_1ML = 0.003030951223220623






# aca fitteo 
kde_bkg_1ML = KernelDensity(kernel="epanechnikov", bandwidth=SM_bandwidth_1ML).fit(np.c_[pred_XG_SM_1ML, np.zeros(len(pred_XG_SM_1ML)) ])
kde_sig_1ML = KernelDensity(kernel="epanechnikov", bandwidth=NP_bandwidth_1ML).fit(np.c_[pred_XG_NP_1ML, np.ones(len(pred_XG_NP_1ML)) ])


# elijo los valores para graficar y calcular la significancia de Asimov
min_val_1ML = np.min([np.min(pred_XG_SM_1ML),np.min(pred_XG_NP_1ML)])
max_val_1ML = np.max([np.max(pred_XG_SM_1ML),np.max(pred_XG_NP_1ML)])

s_vals_1ML = np.linspace(min_val_1ML,max_val_1ML,100)





# evaluo las densidades en cada valor de s. esto es mas o menos equivalente a tomar bines continuos
dens_bkg_1ML = np.exp(kde_bkg_1ML.score_samples(np.c_[s_vals_1ML, np.zeros(len(s_vals_1ML)) ]) )
dens_sig_1ML = np.exp(kde_sig_1ML.score_samples(np.c_[s_vals_1ML, np.ones(len(s_vals_1ML)) ]) )





# PERO NO ESTA NORMALIZADO A 1 el area
# Area
factor_aux_SM_1ML = sum(dens_bkg_1ML*(s_vals_1ML[1]-s_vals_1ML[0]))
factor_aux_NP_1ML = sum(dens_sig_1ML*(s_vals_1ML[1]-s_vals_1ML[0]))

# normalizo
dens_bkg_1ML = dens_bkg_1ML / factor_aux_SM_1ML
dens_sig_1ML = dens_sig_1ML / factor_aux_NP_1ML






# grafico y verifico si la densidad es una buena aproximacion

plt.figure()

plt.hist(pred_XG_SM_1ML,density=True,bins=100,color='red',alpha=0.25,label='Sampled $p_{b}$');
plt.plot(s_vals_1ML,dens_bkg_1ML,color='red',label='Learned $p_{b}$',linestyle='dashed');

plt.hist(pred_XG_NP_1ML,density=True,bins=100,color='blue',alpha=0.25,label='Sampled $p_{s}$');
plt.plot(s_vals_1ML,dens_sig_1ML,color='blue',label='Learned $p_{s}$',linestyle='dashed');

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("o(x)",fontsize=15)
plt.ylabel("PDF",fontsize=14)
plt.grid()
plt.legend(fontsize=12)
#plt.title(r"Signal: W'$\rightarrow$XY, Background: QCD", fontsize=14)
#plt.savefig('images/' + 'Wprime-output.pdf', format="pdf", bbox_inches="tight")
plt.show()



  
    
    

# all the dataset though the SM and NP KDEs
# with this we'll form the toy samples for MLL

KDE_SM_pred_SM_1ML = np.exp(kde_bkg_1ML.score_samples(np.c_[pred_XG_SM_1ML, np.zeros(len(pred_XG_SM_1ML)) ]) )
KDE_NP_pred_SM_1ML = np.exp(kde_sig_1ML.score_samples(np.c_[pred_XG_SM_1ML, np.ones(len(pred_XG_SM_1ML)) ]) )

# Normalize

KDE_SM_pred_SM_1ML = KDE_SM_pred_SM_1ML / factor_aux_SM_1ML
KDE_NP_pred_SM_1ML = KDE_NP_pred_SM_1ML / factor_aux_NP_1ML





indices = [i for i in range(len(KDE_NP_pred_SM_1ML))]


########################
# METHOD: MLL with KDE #
########################

print('\n-------------------------------------')
print(' MLL with KDE')
print('-------------------------------------')




for iii in range(len(SB_ratio)):
    
    print('B_expected: ', B_expected)
    print('S_expected: ', S_expected[iii])
    print(r'S/$\sqrt{B}$: ', SsqrtB[iii])
    print('n_ensembles (initial): ', n_ensembles, '\n')
    
    
    ####################
    # 1st a binned KDE #
    ####################
    
    # Bd: binned KDE background
    Bd = B_expected*dens_bkg_1ML*(s_vals_1ML[1]-s_vals_1ML[0])




    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    Bd_noceros = []
    for i in range(len(Bd)):
        if Bd[i]!=0:
            Bd_noceros.append(Bd[i])

    min_back = min(Bd_noceros)

    # replace the zeros
    for i in range(len(Bd)):
        if Bd[i]==0:
            Bd[i] = min_back


    # Sd: binned KDE signal
    Sd = SsqrtB[iii]*np.sqrt(B_expected)*dens_sig_1ML*(s_vals_1ML[1]-s_vals_1ML[0])

    #Z_KDE_bins = np.sqrt(2.0*np.sum(((Sd+Bd)*np.log(1.0+Sd/Bd)-Sd))) # Discovery
    Z_KDE_bins = np.sqrt(2.0*np.sum(Bd*np.log(Bd/(Sd+Bd))+Sd)) # Exclusion

    store_Z_KDE_bins.append(Z_KDE_bins)

    print('Z_KDE_bins : ', Z_KDE_bins)
    
    

    ###########
    # NOW MLL #
    ###########

    # to construct ensembles B and S events are taken from Poisson distributions
    mu = S_expected[iii] + B_expected


    # Letś find the number of events per ensemble such that we get at least one ensemble populated if events are taken from a Poisson distribution

    # around the mean its populated so let's try (proposed range to be checked)
    list_events_per_ensembles = [i for i in range(int(mu*0.9),int(mu*1.1))]
    to_check = len(list_events_per_ensembles)

    # I want at least one ensemble populated
    list_nums_ensembles = [ int( poisson.pmf(list_events_per_ensembles[i],mu)*n_ensembles ) for i in range(len(list_events_per_ensembles)) ]



    # Remove from the list the elements without at least 1 ensemble possible
    for i in range(len(list_events_per_ensembles)):
        if list_nums_ensembles[i] > 1:
            list_events_per_ensembles = list_events_per_ensembles[i:]
            list_nums_ensembles = list_nums_ensembles[i:]
            break


    for i in range(len(list_events_per_ensembles)):
        if list_nums_ensembles[i] < 1:
            list_events_per_ensembles = list_events_per_ensembles[:i]
            list_nums_ensembles = list_nums_ensembles[:i]
            break

    print('\n If ', to_check, ' = ', len(list_events_per_ensembles), '   then the proposed range has to be extended')

    print('n_ensembles (actual): ', sum(list_nums_ensembles))



    # lists of S and B events per ensemble, w.r.t the total of number of events per ensemble found above:

    p_berno = S_expected[iii]/(S_expected[iii]+B_expected)

    list_S_per_ensembles = []
    list_B_per_ensembles = []

    for jj in range(len(list_events_per_ensembles)):
        list_S_per_ensembles.append( int(p_berno * list_events_per_ensembles[jj]) )
        list_B_per_ensembles.append( list_events_per_ensembles[jj] - int(p_berno * list_events_per_ensembles[jj]) )

    ######
    # NOW I HAVE 4 LISTS:
    # list_events_per_ensembles     list with the number of events per ensemble (its a range)
    # list_nums_ensembles           list with the number of ensembles, w.r.t the 1st list
    # list_S_per_ensembles          list with the number of signal events in each ensembles, w.r.t the 1st list
    # list_B_per_ensembles          list with the number of background events in each ensembles, w.r.t the 1st list
    ######



    print('\n This may take long... \n')


    # NOW LETS APPLY THE METHOD

    muhat_selected_list = []
    q_muhat = []
    q_muhat_mu0 = []

    for bb in range(len(list_nums_ensembles)):

        for kk in range(list_nums_ensembles[bb]):

            # KDE
            ran_ind = np.random.choice(indices, list_B_per_ensembles[bb])

            KDE_SM_pred_SM_shuf = []
            KDE_NP_pred_SM_shuf = []

            for i in ran_ind:
                KDE_SM_pred_SM_shuf.append(KDE_SM_pred_SM_1ML[i])
                KDE_NP_pred_SM_shuf.append(KDE_NP_pred_SM_1ML[i])

            KDE_SM_pred_SM_shuf  = np.array(KDE_SM_pred_SM_shuf)
            KDE_NP_pred_SM_shuf  = np.array(KDE_NP_pred_SM_shuf)



            # p_b(o(x_ensemble)) =    concatenate: p_b(o(B_ensemble)) and p_b(o(S_ensemble))  NOTICE THE o(x)
            prob_x_given_B = np.ndarray.tolist( KDE_SM_pred_SM_shuf ) #+ np.ndarray.tolist( KDE_SM_pred_NP_shuf )

            # p_s(o(x_ensemble)) =    concatenate: p_s(o(B_ensemble)) and p_s(o(S_ensemble))  NOTICE THE o(x)
            prob_x_given_S = np.ndarray.tolist( KDE_NP_pred_SM_shuf ) #+ np.ndarray.tolist( KDE_NP_pred_NP_shuf )









            # NOW WE HAVE p_{s,b}(x_ensemble) for this particular ensemble
            # WE NEED TO ESTIMATE mu_hat for this particular ensemble
            # we are going to obtain a mu_hat with a grid of values for this particular ensemble



            mu_hat_condition_equal_1 = []

            # grid, mu_hat is around 1
            muhat_test = np.arange(0., 1.5, 0.1).tolist()

            B_prob_x_given_B = [x * B_expected for x in prob_x_given_B]

            for vv in range(len(muhat_test)):

                mu_hat_condition_equal_1.append( sum ( [(x*1.) / ( (x * muhat_test[vv] * S_expected[iii]) + y ) for x, y in zip(prob_x_given_S, B_prob_x_given_B)] ) )



            muhat_selected = 0

            # from the grid, select the mu_hat such that the condition is equal to 1
            if mu_hat_condition_equal_1[0] < mu_hat_condition_equal_1[-1]:
                for ll in range(len(mu_hat_condition_equal_1)):
                    if mu_hat_condition_equal_1[ll] -1 > 0:
                        muhat_selected = muhat_test[ll]
                        break


            if mu_hat_condition_equal_1[0] > mu_hat_condition_equal_1[-1]:
                for ll in range(len(mu_hat_condition_equal_1)):
                    if mu_hat_condition_equal_1[ll] -1 < 0:
                        muhat_selected = muhat_test[ll]
                        break


            muhat_selected_list.append(muhat_selected)



            # NOW THAT WE HAVE mu_hat FOR THIS ENSEMBLE, CALCULATE THE TEST STATISTIC FOR THIS ENSEMBLE
            # and append it (we need the median over lots of ensembles)
            #q_muhat.append( 2 * ( (-1.*muhat_selected * S_expected[iii]) + sum( [np.log( 1 + ( (muhat_selected*S_expected[iii]/B_expected) * (x / y) ) ) for x, y in zip(prob_x_given_S, prob_x_given_B)] ) ) )
            # EXCLUSION:
            q_muhat.append( 2 * ( ( (1.-muhat_selected) * S_expected[iii] ) - sum( [np.log( ( (B_expected*y) + (S_expected[iii]*x) ) / ( (B_expected*y) + (muhat_selected*S_expected[iii]*x) ) ) for x, y in zip(prob_x_given_S, prob_x_given_B)] )
    ) )
            q_muhat_mu0.append( 2 * ( ( (1.-0.) * S_expected[iii] ) - sum( [np.log( ( (B_expected*y) + (S_expected[iii]*x) ) / ( (B_expected*y) + (0.*S_expected[iii]*x) ) ) for x, y in zip(prob_x_given_S, prob_x_given_B)] )
    ) )


    # Histogram of q_muhats

    weights = np.ones_like(q_muhat)/float(len(q_muhat))
    nMIX, binsMIX, patchesMIX = plt.hist(q_muhat, 25, weights=weights, histtype='step', color='blue', linewidth=2)
    #plt.xlim(0,1)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.xlabel("$q_0(\hat{\mu})$",fontsize=16)
    plt.ylabel("Fraction of ensembles",fontsize=16)
    plt.title(r"$\bar{B}$=%0.2i, $\bar{S}=$%0.2i" % (B_expected,S_expected[iii]),fontsize=14)
    plt.grid()
    #plt.legend(fontsize=14)
    plt.show()


    # Finally calculate muhat_mean and Z_gaussian

    # Remove nan if any
    q_muhat_mu0 = [x for x in q_muhat_mu0 if x == x]

    q_muhat_median_mu0 = np.median(q_muhat_mu0)

    Z_KDE_mu0 = abs(q_muhat_median_mu0)**0.5
    store_Z_MLL_KDE_mu0_1ML.append(Z_KDE_mu0)


    # Finally calculate muhat_mean and Z_gaussian
    muhat_mean = np.mean(muhat_selected_list)
    store_muhat_mean_MLL_1ML.append(muhat_mean)

    # Remove nan if any
    q_muhat = [x for x in q_muhat if x == x]

    q_muhat_median = np.median(q_muhat)

    Z_KDE = abs(q_muhat_median)**0.5
    store_Z_MLL_KDE_1ML.append(Z_KDE)

    print('muhat mean: ', muhat_mean)
    print('median q_muhat: ', q_muhat_median)
    print('Z_KDE: ', Z_KDE)
    print('Z_KDE mu=0: ', Z_KDE_mu0)
    
    print('\n ----------------------------------------- \n')
# Out:
# -------------------------------------
#  MLL with KDE
# -------------------------------------
# B_expected:  5000
# S_expected:  2
# S/$\sqrt{B}$:  0.0282842712474619
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  0.7264358941625878
#
#  If  1001  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4759
#
#  This may take long...
# muhat mean:  0.20403446102122294
# median q_muhat:  0.7214818892662587
# Z_KDE:  0.8494009002033485
# Z_KDE mu=0:  0.8494009002033485
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  5
# S/$\sqrt{B}$:  0.07071067811865475
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  1.5188256979043289
#
#  If  1001  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4757
#
#  This may take long...
# muhat mean:  0.19445028379230608
# median q_muhat:  2.5492575890010425
# Z_KDE:  1.5966394674443702
# Z_KDE mu=0:  1.5966394674443702
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  8
# S/$\sqrt{B}$:  0.1131370849898476
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  2.1417565000276237
#
#  If  1001  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4757
#
#  This may take long...
# muhat mean:  0.1433886903510616
# median q_muhat:  4.802987217744093
# Z_KDE:  2.1915718600456824
# Z_KDE mu=0:  2.1915718600456824
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  12
# S/$\sqrt{B}$:  0.1697056274847714
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  2.8301768116189874
#
#  If  1003  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4757
#
#  This may take long...
# muhat mean:  0.10338448602060123
# median q_muhat:  8.017748767581883
# Z_KDE:  2.8315629549035077
# Z_KDE mu=0:  2.8332655361394914
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  25
# S/$\sqrt{B}$:  0.35355339059327373
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  4.524319781248331
#
#  If  1005  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4753
#
#  This may take long...
# muhat mean:  0.0629076372817168
# median q_muhat:  20.274672996297756
# Z_KDE:  4.502740609484157
# Z_KDE mu=0:  4.515707954757498
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  37
# S/$\sqrt{B}$:  0.5232590180780452
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  5.7274296910106965
#
#  If  1007  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4751
#
#  This may take long...
# muhat mean:  0.048600294674805304
# median q_muhat:  32.661204337240676
# Z_KDE:  5.714998192234244
# Z_KDE mu=0:  5.734485225730141
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  50
# S/$\sqrt{B}$:  0.7071067811865475
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  6.82832112574435
#
#  If  1010  =  347    then the proposed range has to be extended
# n_ensembles (actual):  4754
#
#  This may take long...
# muhat mean:  0.046865797223390834
# median q_muhat:  45.836785425621486
# Z_KDE:  6.770286952974851
# Z_KDE mu=0:  6.805569291551425
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  125
# S/$\sqrt{B}$:  1.7677669529663687
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  11.432012158943486
#
#  If  1025  =  349    then the proposed range has to be extended
# n_ensembles (actual):  4744
#
#  This may take long...
# muhat mean:  0.044287521079258006
# median q_muhat:  127.71684887809332
# Z_KDE:  11.301187941012808
# Z_KDE mu=0:  11.39640944749608
#
#  -----------------------------------------

# %%
print(store_Z_KDE_bins)

print(store_Z_MLL_KDE_1ML)
print(store_Z_MLL_KDE_mu0_1ML)

print(store_muhat_mean_MLL_1ML)
# Out:
# [0.7264358941625878, 1.5188256979043289, 2.1417565000276237, 2.8301768116189874, 4.524319781248331, 5.7274296910106965, 6.82832112574435, 11.432012158943486]
# [0.8494009002033485, 1.5966394674443702, 2.1915718600456824, 2.8315629549035077, 4.502740609484157, 5.714998192234244, 6.770286952974851, 11.301187941012808]
# [0.8494009002033485, 1.5966394674443702, 2.1915718600456824, 2.8332655361394914, 4.515707954757498, 5.734485225730141, 6.805569291551425, 11.39640944749608]
# [0.20403446102122294, 0.19445028379230608, 0.1433886903510616, 0.10338448602060123, 0.0629076372817168, 0.048600294674805304, 0.046865797223390834, 0.044287521079258006]

# %%
store_Z_KDE_bins = [0.7264358941625878, 1.5188256979043289, 2.1417565000276237, 2.8301768116189874, 4.524319781248331, 5.7274296910106965, 6.82832112574435, 11.432012158943486]

store_Z_MLL_KDE_1ML = [0.8494009002033485, 1.5966394674443702, 2.1915718600456824, 2.8315629549035077, 4.502740609484157, 5.714998192234244, 6.770286952974851, 11.301187941012808]
store_Z_MLL_KDE_mu0_1ML = [0.8494009002033485, 1.5966394674443702, 2.1915718600456824, 2.8332655361394914, 4.515707954757498, 5.734485225730141, 6.805569291551425, 11.39640944749608]

store_muhat_mean_MLL_1ML = [0.20403446102122294, 0.19445028379230608, 0.1433886903510616, 0.10338448602060123, 0.0629076372817168, 0.048600294674805304, 0.046865797223390834, 0.044287521079258006]

# %%
#########
# PLOTS #
#########

posX = []

for i in range(len(SB_ratio)):
    posX.append( (B_expected*SB_ratio[i]) / ( B_expected )**0.5 )




plt.figure()
lw = 2

plt.plot(posX, store_muhat_mean_MLL, '-ok', color='red', lw=lw, label='mu_hat XGBoost (10ML)')
plt.plot(posX, store_muhat_mean_MLL_1ML, '-ok', color='blue', lw=lw, label='mu_hat XGBoost (1ML)')

#plt.xlim([0.5, 100])
#plt.ylim([-0.5, 7.5])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=14)
plt.ylabel(r'$\hat{\mu}$', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title('<B> per ensemble: %0.2d' % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()






plt.figure()
lw = 2

plt.plot(posX, store_Z_bins, ':ok', color='blue', lw=lw, label='100 Linear Binned Likelihood') 
plt.plot(posX, store_Z_bins_logbins, ':ok', color='lightblue', lw=lw, label='15 Log Binned Likelihood') 
plt.plot(posX, store_Z_bins_XG, '--ok', color='green', lw=lw, label='o(x) BL (100 l.bins)') 
plt.plot(posX, store_Z_bins_XG_15bins, '-ok', color='navy', lw=lw, label='o(x) BL (15 l.bins) (10ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_1ML, '-ok', color='green', lw=lw, label='o(x) BL (15 l.bins) (1ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_eq, '-ok', color='magenta', lw=lw, label='o(x) BL (15 n.l.bins) (10ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_eq_1ML, '-ok', color='darkorange', lw=lw, label='o(x) BL (15 n.l.bins) (1ML)') 
plt.plot(posX, store_Z_MLL_KDE, '-ok', color='red', lw=3, label=r'MLL KDE (10ML)')
plt.plot(posX, store_Z_MLL_KDE_1ML, '--ok', color='lightcoral', lw=3, label=r'MLL KDE (1ML)')
#plt.plot(posX, store_Z_MLL_KDE_mu0, '-ok', color='pink', lw=3, label=r'MLL KDE (XGBoost) muhat=0')
#plt.plot(posX, store_Z_KDE_bins, '-ok', color='magenta', lw=3, label=r'100 Bins KDE')

#plt.xlim([0.5, 10])
#plt.ylim([-0.5, 7.5])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=14)
plt.ylabel('$Z_{\mu}$ (exclusion)', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title('<B> per ensemble: %0.2d' % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()
# Out:
# <ipython-input-23-8bc2cdbd1b25>:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_muhat_mean_MLL, '-ok', color='red', lw=lw, label='mu_hat XGBoost (10ML)')
# <ipython-input-23-8bc2cdbd1b25>:17: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_muhat_mean_MLL_1ML, '-ok', color='blue', lw=lw, label='mu_hat XGBoost (1ML)')
# <ipython-input-23-8bc2cdbd1b25>:39: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string ":ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins, ':ok', color='blue', lw=lw, label='100 Linear Binned Likelihood')
# <ipython-input-23-8bc2cdbd1b25>:40: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string ":ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_logbins, ':ok', color='lightblue', lw=lw, label='15 Log Binned Likelihood')
# <ipython-input-23-8bc2cdbd1b25>:41: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "--ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG, '--ok', color='green', lw=lw, label='o(x) BL (100 l.bins)')
# <ipython-input-23-8bc2cdbd1b25>:42: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins, '-ok', color='navy', lw=lw, label='o(x) BL (15 l.bins) (10ML)')
# <ipython-input-23-8bc2cdbd1b25>:43: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_1ML, '-ok', color='green', lw=lw, label='o(x) BL (15 l.bins) (1ML)')
# <ipython-input-23-8bc2cdbd1b25>:44: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_eq, '-ok', color='magenta', lw=lw, label='o(x) BL (15 n.l.bins) (10ML)')
# <ipython-input-23-8bc2cdbd1b25>:45: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_eq_1ML, '-ok', color='darkorange', lw=lw, label='o(x) BL (15 n.l.bins) (1ML)')
# <ipython-input-23-8bc2cdbd1b25>:46: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_MLL_KDE, '-ok', color='red', lw=3, label=r'MLL KDE (10ML)')
# <ipython-input-23-8bc2cdbd1b25>:47: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "--ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_MLL_KDE_1ML, '--ok', color='lightcoral', lw=3, label=r'MLL KDE (1ML)')

# %% [markdown]
# ### 4.Working points, counting over 1 bin

# %%
WP = [0.25, 0.5, 0.75]

S_expected = [int(SB_ratio[i]*B_expected) for i in range(len(SB_ratio))]

print(S_expected)
# Out:
# [2, 5, 8, 12, 25, 37, 50, 125]

# %%
# XGBoost #

SrootB_WP0_XG = []
SrootB_WP1_XG = []
SrootB_WP2_XG = []


# number of background ensembles
B_ensembles = int(len(pred_XG_SM)/B_expected)

# shorten the number of B events so I get an integer number of ensembles
pred_XG_SM_entero = pred_XG_SM[:int(len(pred_XG_SM)/B_expected) * B_expected]

XG_SM_passWP0 = 0
XG_SM_passWP1 = 0
XG_SM_passWP2 = 0

for i in range(len(pred_XG_SM_entero)):
    if pred_XG_SM_entero[i] > WP[0]:
        XG_SM_passWP0 += 1
    if pred_XG_SM_entero[i] > WP[1]:
        XG_SM_passWP1 += 1
    if pred_XG_SM_entero[i] > WP[2]:
        XG_SM_passWP2 += 1



# SIGNAL

for j in range(len(S_expected)):
    
    # number of signal ensembles
    S_ensembles = int(len(pred_XG_NP)/S_expected[j])

    # shorten the number of S events so I get an integer number of ensembles
    pred_XG_NP_entero = pred_XG_NP[:int(len(pred_XG_NP)/S_expected[j]) * S_expected[j]]

    XG_NP_passWP0 = 0
    XG_NP_passWP1 = 0
    XG_NP_passWP2 = 0

    for i in range(len(pred_XG_NP_entero)):
        if pred_XG_NP_entero[i] > WP[0]:
            XG_NP_passWP0 += 1
        if pred_XG_NP_entero[i] > WP[1]:
            XG_NP_passWP1 += 1
        if pred_XG_NP_entero[i] > WP[2]:
            XG_NP_passWP2 += 1

            
    # save the results Z_binned after WP
    SrootB_WP0_XG.append( ( XG_NP_passWP0 / S_ensembles ) / ( XG_SM_passWP0 / B_ensembles )**0.5 )
    SrootB_WP1_XG.append( ( XG_NP_passWP1 / S_ensembles ) / ( XG_SM_passWP1 / B_ensembles )**0.5 )
    SrootB_WP2_XG.append( ( XG_NP_passWP2 / S_ensembles ) / ( XG_SM_passWP2 / B_ensembles )**0.5 )
    
    print('S_expected = ', S_expected[j])
    print('WP: 0     S/B**0.5= ', S_expected[j]/(B_expected)**0.5)
    print('WP: ', WP[0], '    S/B**0.5= ', SrootB_WP0_XG[j] )
    print('WP: ', WP[1], '    S/B**0.5= ', SrootB_WP1_XG[j] )
    print('WP: ', WP[2], '    S/B**0.5= ', SrootB_WP2_XG[j] )
    print('------------------------')
    print('')
    
print('SrootB_WP0_XG: ', SrootB_WP0_XG)
print('SrootB_WP1_XG: ', SrootB_WP1_XG)
print('SrootB_WP2_XG: ', SrootB_WP2_XG)
# Out:
# S_expected =  2
# WP: 0     S/B**0.5=  0.0282842712474619
# WP:  0.25     S/B**0.5=  0.03990024669814878
# WP:  0.5     S/B**0.5=  0.06998019438669789
# WP:  0.75     S/B**0.5=  0.12100843089272376
# ------------------------
#
# S_expected =  5
# WP: 0     S/B**0.5=  0.07071067811865475
# WP:  0.25     S/B**0.5=  0.09975055086849857
# WP:  0.5     S/B**0.5=  0.17495018129599335
# WP:  0.75     S/B**0.5=  0.3025202699188336
# ------------------------
#
# S_expected =  8
# WP: 0     S/B**0.5=  0.1131370849898476
# WP:  0.25     S/B**0.5=  0.1596013081880253
# WP:  0.5     S/B**0.5=  0.2799204333971451
# WP:  0.75     S/B**0.5=  0.48403500758162976
# ------------------------
#
# S_expected =  12
# WP: 0     S/B**0.5=  0.1697056274847714
# WP:  0.25     S/B**0.5=  0.2394035589271107
# WP:  0.5     S/B**0.5=  0.4198825425430381
# WP:  0.75     S/B**0.5=  0.7260544374501036
# ------------------------
#
# S_expected =  25
# WP: 0     S/B**0.5=  0.35355339059327373
# WP:  0.25     S/B**0.5=  0.4987547793370474
# WP:  0.5     S/B**0.5=  0.8747531460178891
# WP:  0.75     S/B**0.5=  1.5126214370627145
# ------------------------
#
# S_expected =  37
# WP: 0     S/B**0.5=  0.5232590180780452
# WP:  0.25     S/B**0.5=  0.7381595109103949
# WP:  0.5     S/B**0.5=  1.294638502475564
# WP:  0.75     S/B**0.5=  2.238679762017259
# ------------------------
#
# S_expected =  50
# WP: 0     S/B**0.5=  0.7071067811865475
# WP:  0.25     S/B**0.5=  0.9975095586740949
# WP:  0.5     S/B**0.5=  1.7495062920357782
# WP:  0.75     S/B**0.5=  3.025242874125429
# ------------------------
#
# S_expected =  125
# WP: 0     S/B**0.5=  1.7677669529663687
# WP:  0.25     S/B**0.5=  2.49374959312977
# WP:  0.5     S/B**0.5=  4.373811430855854
# WP:  0.75     S/B**0.5=  7.563105997064591
# ------------------------
#
# SrootB_WP0_XG:  [0.03990024669814878, 0.09975055086849857, 0.1596013081880253, 0.2394035589271107, 0.4987547793370474, 0.7381595109103949, 0.9975095586740949, 2.49374959312977]
# SrootB_WP1_XG:  [0.06998019438669789, 0.17495018129599335, 0.2799204333971451, 0.4198825425430381, 0.8747531460178891, 1.294638502475564, 1.7495062920357782, 4.373811430855854]
# SrootB_WP2_XG:  [0.12100843089272376, 0.3025202699188336, 0.48403500758162976, 0.7260544374501036, 1.5126214370627145, 2.238679762017259, 3.025242874125429, 7.563105997064591]

# %%
# To use if you dont want to run everything again. Its the previous results
SrootB_WP0_XG = [0.03990024669814878, 0.09975055086849857, 0.1596013081880253, 0.2394035589271107, 0.4987547793370474, 0.7381595109103949, 0.9975095586740949, 2.49374959312977]
SrootB_WP1_XG = [0.06998019438669789, 0.17495018129599335, 0.2799204333971451, 0.4198825425430381, 0.8747531460178891, 1.294638502475564, 1.7495062920357782, 4.373811430855854]
SrootB_WP2_XG = [0.12100843089272376, 0.3025202699188336, 0.48403500758162976, 0.7260544374501036, 1.5126214370627145, 2.238679762017259, 3.025242874125429, 7.563105997064591]

# %%
#########
# PLOTS #
#########

posX = []

for i in range(len(SB_ratio)):
    posX.append( (B_expected*SB_ratio[i]) / ( B_expected )**0.5 )



plt.figure()
lw = 2

plt.plot(posX, store_Z_bins, ':ok', color='blue', lw=lw, label='100 Linear Binned Likelihood') 
plt.plot(posX, store_Z_bins_logbins, ':ok', color='lightblue', lw=lw, label='15 Log Binned Likelihood') 
plt.plot(posX, store_Z_bins_XG, '--ok', color='green', lw=lw, label='o(x) BL (100 l.bins)') 
plt.plot(posX, store_Z_bins_XG_15bins, '-ok', color='navy', lw=lw, label='o(x) BL (15 l.bins) (10ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_1ML, '-ok', color='green', lw=lw, label='o(x) BL (15 l.bins) (1ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_eq, '-ok', color='magenta', lw=lw, label='o(x) BL (15 n.l.bins) (10ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_eq_1ML, '-ok', color='darkorange', lw=lw, label='o(x) BL (15 n.l.bins) (1ML)') 
plt.plot(posX, store_Z_MLL_KDE, '-ok', color='red', lw=3, label=r'MLL KDE (10ML)')
plt.plot(posX, store_Z_MLL_KDE_1ML, '--ok', color='lightcoral', lw=3, label=r'MLL KDE (1ML)')
#plt.plot(posX, store_Z_MLL_KDE_mu0, '-ok', color='pink', lw=3, label=r'MLL KDE (XGBoost) muhat=0')
#plt.plot(posX, store_Z_KDE_bins, '-ok', color='magenta', lw=3, label=r'100 Bins KDE')
plt.plot(posX, SrootB_WP2_XG, '--', color='darkorange', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[2] )
plt.plot(posX, SrootB_WP1_XG, '--', color='magenta', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[1] )
plt.plot(posX, SrootB_WP0_XG, '--', color='navy', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[0] )
plt.plot(posX, posX, ':', color='black', lw=lw, label=r'$S/\sqrt{B}$')

#plt.xlim([0.5, 10])
#plt.ylim([-0.5, 7.5])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=14)
plt.ylabel('$Z_{\mu}$ (exclusion)', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title('<B> per ensemble: %0.2d' % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()
# Out:
# <ipython-input-26-1231ce6ddeb8>:15: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string ":ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins, ':ok', color='blue', lw=lw, label='100 Linear Binned Likelihood')
# <ipython-input-26-1231ce6ddeb8>:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string ":ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_logbins, ':ok', color='lightblue', lw=lw, label='15 Log Binned Likelihood')
# <ipython-input-26-1231ce6ddeb8>:17: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "--ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG, '--ok', color='green', lw=lw, label='o(x) BL (100 l.bins)')
# <ipython-input-26-1231ce6ddeb8>:18: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins, '-ok', color='navy', lw=lw, label='o(x) BL (15 l.bins) (10ML)')
# <ipython-input-26-1231ce6ddeb8>:19: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_1ML, '-ok', color='green', lw=lw, label='o(x) BL (15 l.bins) (1ML)')
# <ipython-input-26-1231ce6ddeb8>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_eq, '-ok', color='magenta', lw=lw, label='o(x) BL (15 n.l.bins) (10ML)')
# <ipython-input-26-1231ce6ddeb8>:21: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_eq_1ML, '-ok', color='darkorange', lw=lw, label='o(x) BL (15 n.l.bins) (1ML)')
# <ipython-input-26-1231ce6ddeb8>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_MLL_KDE, '-ok', color='red', lw=3, label=r'MLL KDE (10ML)')
# <ipython-input-26-1231ce6ddeb8>:23: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "--ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_MLL_KDE_1ML, '--ok', color='lightcoral', lw=3, label=r'MLL KDE (1ML)')

# %%
posX = []

for i in range(len(SB_ratio)):
    posX.append( (B_expected*SB_ratio[i]) / ( B_expected )**0.5 )


plt.figure()
lw = 2

plt.plot(posX, store_Z_bins_logbins, '-', color='dodgerblue', lw=3, label='x BL (15 log l.bins)') 
plt.plot(posX, store_Z_bins_XG_15bins, '-', color='green', lw=3, label='o(x) BL (15 l.bins) (10ML)') 
plt.plot(posX, store_Z_MLL_KDE, '-', color='red', lw=3, label=r'MLL KDE (10ML)')
plt.plot(posX, store_Z_MLL_KDE_1ML, '--ok', color='lightcoral', lw=3, label=r'MLL KDE (1ML)')
plt.plot(posX, SrootB_WP2_XG, '--', color='darkorange', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[2] )
plt.plot(posX, SrootB_WP1_XG, '--', color='magenta', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[1] )
plt.plot(posX, SrootB_WP0_XG, '--', color='navy', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[0] )
plt.plot(posX, posX, ':', color='black', lw=lw, label=r'$S/\sqrt{B}$')

#plt.xlim([0.5, 10])
#plt.ylim([-0.5, 7.5])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=15)
plt.ylabel('$Z_{\mu}$', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title('<B> per ensemble: %0.2d' % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()
# Out:
# <ipython-input-27-415cc2f1cb5e>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "--ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_MLL_KDE_1ML, '--ok', color='lightcoral', lw=3, label=r'MLL KDE (1ML)')

# %% [markdown]
# ### Interpolate

# %%
    
# Interpolation, cubic
fcubic_bins_logbins = interp1d(posX, store_Z_bins_logbins, kind='cubic')
fcubic_bins_XG_15bins = interp1d(posX, store_Z_bins_XG_15bins, kind='cubic')
fcubic_bins_XG_15bins_1ML = interp1d(posX, store_Z_bins_XG_15bins_1ML, kind='cubic')
fcubic_XG_MLL = interp1d(posX, store_Z_MLL_KDE, kind='cubic')
fcubic_XG_MLL_1ML = interp1d(posX, store_Z_MLL_KDE_1ML, kind='cubic')
fcubic_WP0_XG = interp1d(posX, SrootB_WP0_XG, kind='cubic')
fcubic_WP1_XG = interp1d(posX, SrootB_WP1_XG, kind='cubic')
fcubic_WP2_XG = interp1d(posX, SrootB_WP2_XG, kind='cubic')


# x to plot
plotX = np.linspace(min(posX), max(posX), num=50, endpoint=True)



plt.figure()
lw = 2

plt.plot(plotX, fcubic_bins_logbins(plotX), '-', color='dodgerblue', lw=3, label='x BL (15 log l.bins)') 
plt.plot(plotX, fcubic_bins_XG_15bins(plotX), '-', color='green', lw=3, label='o(x) BL (15 l.bins) (10ML)') 
plt.plot(plotX, fcubic_bins_XG_15bins_1ML(plotX), '--', color='green', lw=3, label='o(x) BL (15 l.bins) (1ML)') 
plt.plot(plotX, fcubic_XG_MLL(plotX), '-', color='red', lw=3, label=r'MLL KDE (10ML)')
plt.plot(plotX, fcubic_XG_MLL_1ML(plotX), '-', color='lightcoral', lw=3, label=r'MLL KDE (1ML)')
plt.plot(plotX, fcubic_WP0_XG(plotX), '--', color='darkorange', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[2] )
plt.plot(plotX, fcubic_WP1_XG(plotX), '--', color='magenta', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[1] )
plt.plot(plotX, fcubic_WP2_XG(plotX), '--', color='navy', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[0] )
plt.plot(posX, posX, ':', color='black', lw=lw, label=r'$S/\sqrt{B}$')

#plt.ylim([0., 6])
#plt.xlim([0.06, 10])
#plt.ylim([0., 3])
#plt.xlim([0.1, 0.2])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=15)
plt.ylabel('$Z_{\mu}$', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title('<B> per ensemble: %0.2d' % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()

# %%
# AUX FUNCTION TO FIND SOLUTIONS

def dx(fn, x, delta=0.001):
    return (fn(x+delta) - fn(x))/delta

def solve(fn, value, x=0.1, maxtries=1000, maxerr=0.00001):
    for tries in range(maxtries):
        err = fn(x) - value
        if abs(err) < maxerr:
            return x
        slope = dx(fn, x)
        x -= err/slope
    raise ValueError('no solution found')

# %%
##############################
# DO NOT FORGET THE K-factor #
##############################

k_factor = 3
SM_cross_section_fb = 0.3106
acceptance_SM = 0.4*2
true_B_expected = 3000 * SM_cross_section_fb * k_factor * acceptance_SM

correct_factor = true_B_expected / B_expected

print('correct_factor: ', correct_factor)
print('')


# Find S/\sqrt{B} such that 95%C.L. upper limit, i.e  ----> Z = 1.64

bins_logbins_95CL = solve(fcubic_bins_logbins, 1.64)
bins_XG_15bins_95CL = solve(fcubic_bins_XG_15bins, 1.64)
XG_MLL_95CL = solve(fcubic_XG_MLL, 1.64)
bins_XG_15bins_1ML_95CL = solve(fcubic_bins_XG_15bins_1ML, 1.64)
XG_MLL_1ML_95CL = solve(fcubic_XG_MLL_1ML, 1.64)


# corresponding to a number of signal events:
acceptance_Signal = 0.672699
S1 = ( (correct_factor * B_expected)**0.5 * bins_logbins_95CL ) / acceptance_Signal
S2 = ( (correct_factor * B_expected)**0.5 * bins_XG_15bins_95CL ) / acceptance_Signal
S3 = ( (correct_factor * B_expected)**0.5 * XG_MLL_95CL ) / acceptance_Signal
S4 = ( (correct_factor * B_expected)**0.5 * bins_XG_15bins_1ML_95CL ) / acceptance_Signal
S5 = ( (correct_factor * B_expected)**0.5 * XG_MLL_1ML_95CL ) / acceptance_Signal

# corresponding to a cross-section (pb)
cross_bins_logbins_95CL = S1 / 3000000
cross_bins_XG_15bins_95CL = S2 / 3000000
cross_XG_MLL_95CL = S3 / 3000000
cross_bins_XG_15bins_1ML_95CL = S4 / 3000000
cross_XG_MLL_1ML_95CL = S5 / 3000000



print('95%C.L. upper limit, i.e  ----> Z = 1.64: \n')
print('     S/\sqrt{B}              S          cross-section (pb)')
print(bins_logbins_95CL , S1 , cross_bins_logbins_95CL)
print(bins_XG_15bins_95CL , S2 , cross_bins_XG_15bins_95CL)
print(XG_MLL_95CL, S3 , cross_XG_MLL_95CL)
print(bins_XG_15bins_1ML_95CL , S4 , cross_bins_XG_15bins_1ML_95CL)
print(XG_MLL_1ML_95CL, S5 , cross_XG_MLL_1ML_95CL)



np.savetxt('saved-models/results6500GeV-mumu.txt', [cross_bins_logbins_95CL,cross_bins_XG_15bins_95CL,cross_XG_MLL_95CL,cross_bins_XG_15bins_1ML_95CL,cross_XG_MLL_1ML_95CL])
# Out:
# correct_factor:  0.44726399999999994
#
# 95%C.L. upper limit, i.e  ----> Z = 1.64:
#
#      S/\sqrt{B}              S          cross-section (pb)
# 0.09078566576656429 6.382098086775249 2.127366028925083e-06
# 0.2169897198368135 15.25405650911088 5.08468550303696e-06
# 0.07828852985933492 5.503567908136925 1.8345226360456417e-06
# 0.21950917736610778 15.431170648679624 5.1437235495598746e-06
# 0.07295015014935281 5.128287706731999 1.7094292355773332e-06
