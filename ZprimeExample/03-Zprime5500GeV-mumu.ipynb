# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import gridspec
from matplotlib import patches
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

import os
import math
import random

import keras
from keras.models import Sequential
from keras.layers import Input, Dense, Conv2D, Flatten, MaxPooling2D
from keras.layers import Dropout
from keras.callbacks import EarlyStopping

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn import preprocessing
from sklearn.metrics import roc_curve, roc_auc_score, auc

import scipy.stats as st
from scipy.stats import poisson
from scipy.interpolate import interp1d
from scipy.stats import norm

# %%
from sklearn.neighbors import KernelDensity # paquete necesario
from sklearn.model_selection import GridSearchCV

import scipy.integrate as integrate

# %%
# !pip install xgboost

import xgboost
from xgboost import XGBRegressor, XGBClassifier
# Out:
# Requirement already satisfied: xgboost in /home/andres/anaconda3/lib/python3.8/site-packages (1.5.1)
# Requirement already satisfied: scipy in /home/andres/.local/lib/python3.8/site-packages (from xgboost) (1.9.3)
# Requirement already satisfied: numpy in /home/andres/.local/lib/python3.8/site-packages (from xgboost) (1.22.4)
# WARNING: You are using pip version 21.3.1; however, version 23.2 is available.
# You should consider upgrading via the '/home/andres/anaconda3/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# ## DATA

# %%
# data

folder_data = "../../MLL-exclusion/data/"

# %%
folder_saved = "Zprime-SSM-mumu-mZ5500GeV-variables/"

# 1st DATASET
e1pt_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-pt-5500-1.txt', delimiter=',')
e1eta_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-eta-5500-1.txt', delimiter=',')
e1phi_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-phi-5500-1.txt', delimiter=',')

e2pt_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-pt-5500-1.txt', delimiter=',')
e2eta_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-eta-5500-1.txt', delimiter=',')
e2phi_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-phi-5500-1.txt', delimiter=',')




# INVARIANT MASS

invariant_mass_eeSM = []

for i in range(len(e1pt_eeSSMZprime)):
    invariant_mass_eeSM.append( ( 2 * e1pt_eeSSMZprime[i] * e2pt_eeSSMZprime[i] * ( np.cosh(e1eta_eeSSMZprime[i] - e2eta_eeSSMZprime[i]) - np.cos(e1phi_eeSSMZprime[i] - e2phi_eeSSMZprime[i]) ) )**0.5 )
    
print(len(invariant_mass_eeSM))

f= open(folder_data + folder_saved + "mmumu-1.txt","w")
for i in range(len(invariant_mass_eeSM)):
    f.write("%.3f\n" % invariant_mass_eeSM[i] )
f.close()




# 2nd DATASET
e1pt_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-pt-5500-2.txt', delimiter=',')
e1eta_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-eta-5500-2.txt', delimiter=',')
e1phi_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-phi-5500-2.txt', delimiter=',')

e2pt_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-pt-5500-2.txt', delimiter=',')
e2eta_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-eta-5500-2.txt', delimiter=',')
e2phi_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-phi-5500-2.txt', delimiter=',')




# INVARIANT MASS

invariant_mass_eeSM = []

for i in range(len(e1pt_eeSSMZprime)):
    invariant_mass_eeSM.append( ( 2 * e1pt_eeSSMZprime[i] * e2pt_eeSSMZprime[i] * ( np.cosh(e1eta_eeSSMZprime[i] - e2eta_eeSSMZprime[i]) - np.cos(e1phi_eeSSMZprime[i] - e2phi_eeSSMZprime[i]) ) )**0.5 )
    
print(len(invariant_mass_eeSM))

f= open(folder_data + folder_saved + "mmumu-2.txt","w")
for i in range(len(invariant_mass_eeSM)):
    f.write("%.3f\n" % invariant_mass_eeSM[i] )
f.close()
# Out:
# 709375
# 707458

# %%
# just to check that we need to ask again that the invariant mass has to be greater than 2000 GeV

bins_atlas = [70, 80.0, 90.0, 105.0, 120.0, 140.0, 160.0, 180.0, 210.0, 240.0, 275.0, 315.0, 360.0, 415.0, 475.0, 545.0, 625.0, 715.0, 825.0, 950.0, 1100.0, 1250.0, 1450.0, 1650.0, 1900.0, 2200.0, 2500.0, 2850.0, 3250.0, 3750.0, 4350.0, 5000.0, 5750.0, 6600.0, 7500.0, 8750.0, 10000.0, 11500.0, 13000.0, 20000]

folder_saved = "SM/mumu/"

invariant_mass_eeSM_1800 = np.loadtxt(folder_data + folder_saved +"mmumu-1800.txt", delimiter=',')
invariant_mass_eeSM_1800_2 = np.loadtxt(folder_data + folder_saved +"mmumu-1800-2.txt", delimiter=',')

plt.hist(invariant_mass_eeSM_1800, bins=bins_atlas, lw=2, edgecolor='lightblue', histtype='step', label="SM (dataset 1)")
plt.hist(invariant_mass_eeSM_1800_2, bins=bins_atlas, lw=2, edgecolor='green', histtype='step', label="SM (dataset 2)")


folder_saved = "Zprime-SSM-mumu-mZ5500GeV-variables/"

invariant_mass_eeSSMZprime_1 = np.loadtxt(folder_data + folder_saved +"mmumu-1.txt", delimiter=',')
invariant_mass_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved +"mmumu-2.txt", delimiter=',')

plt.hist(invariant_mass_eeSSMZprime_1, bins=bins_atlas, lw=2, edgecolor='pink', histtype='step', label="$Z'_{SSM}$ (dataset 1)")
plt.hist(invariant_mass_eeSSMZprime_2, bins=bins_atlas, lw=2, edgecolor='darkorange', histtype='step', label="$Z'_{SSM}$ (dataset 2)")


plt.grid()  # Add grid lines

plt.title(r"Z/Z'$\rightarrow$e+e-",fontsize=14)  # Titles etc
plt.xlabel("$m_{ll}$ (GeV)",fontsize=14)
plt.ylabel("Events",fontsize=14)

plt.xlim(70.,20000)
plt.ylim(1e0,1e7)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xscale('log')
plt.yscale('log')
plt.legend(loc='upper left',fontsize=12)

plt.show()

# %% [markdown]
# ### SM

# %%
######
# SM #
######


folder_saved = "SM/mumu/"


# 1st DATASET
invariant_mass_eeSM = np.loadtxt(folder_data + folder_saved +"mmumu-1800.txt", delimiter=',')

e1pt_eeSM = np.loadtxt(folder_data + folder_saved + 'mu1_pt_events_IM_1800.txt', delimiter=',')
e1eta_eeSM = np.loadtxt(folder_data + folder_saved + 'mu1_eta_events_IM_1800.txt', delimiter=',')
e1phi_eeSM = np.loadtxt(folder_data + folder_saved + 'mu1_phi_events_IM_1800.txt', delimiter=',')

e2pt_eeSM = np.loadtxt(folder_data + folder_saved + 'mu2_pt_events_IM_1800.txt', delimiter=',')
e2eta_eeSM = np.loadtxt(folder_data + folder_saved + 'mu2_eta_events_IM_1800.txt', delimiter=',')
e2phi_eeSM = np.loadtxt(folder_data + folder_saved + 'mu2_phi_events_IM_1800.txt', delimiter=',')


# only keep points where the invariant mass is greater than 2000 GeV
# and make sure that both electrons: |eta| < 2.65
for i in reversed(range(len(invariant_mass_eeSM))):
    if invariant_mass_eeSM[i]< 2000 or e1eta_eeSM[i] < -2.65 or e1eta_eeSM[i] > 2.65 or e2eta_eeSM[i] < -2.65 or e2eta_eeSM[i] > 2.65:
        e1pt_eeSM = np.delete(e1pt_eeSM, i)
        e1eta_eeSM = np.delete(e1eta_eeSM, i)
        e1phi_eeSM = np.delete(e1phi_eeSM, i)
        
        e2pt_eeSM = np.delete(e2pt_eeSM, i)
        e2eta_eeSM = np.delete(e2eta_eeSM, i)
        e2phi_eeSM = np.delete(e2phi_eeSM, i)
        
        invariant_mass_eeSM = np.delete(invariant_mass_eeSM, i)
        

        
        
# 2nd DATASET
invariant_mass_eeSM_1800 = np.loadtxt(folder_data + folder_saved +"mmumu-1800-2.txt", delimiter=',')

e1pt_eeSM_1800 = np.loadtxt(folder_data + folder_saved + 'mu1_pt_events_IM_1800_2.txt', delimiter=',')
e1eta_eeSM_1800 = np.loadtxt(folder_data + folder_saved + 'mu1_eta_events_IM_1800_2.txt', delimiter=',')
e1phi_eeSM_1800 = np.loadtxt(folder_data + folder_saved + 'mu1_phi_events_IM_1800_2.txt', delimiter=',')

e2pt_eeSM_1800 = np.loadtxt(folder_data + folder_saved + 'mu2_pt_events_IM_1800_2.txt', delimiter=',')
e2eta_eeSM_1800 = np.loadtxt(folder_data + folder_saved + 'mu2_eta_events_IM_1800_2.txt', delimiter=',')
e2phi_eeSM_1800 = np.loadtxt(folder_data + folder_saved + 'mu2_phi_events_IM_1800_2.txt', delimiter=',')


# only keep points where the invariant mass is greater than 2000 GeV
# and make sure that both electrons: |eta| < 2.65
for i in reversed(range(len(invariant_mass_eeSM_1800))):
    if invariant_mass_eeSM_1800[i]< 2000 or e1eta_eeSM_1800[i] < -2.65 or e1eta_eeSM_1800[i] > 2.65 or e2eta_eeSM_1800[i] < -2.65 or e2eta_eeSM_1800[i] > 2.65:
        e1pt_eeSM_1800 = np.delete(e1pt_eeSM_1800, i)
        e1eta_eeSM_1800 = np.delete(e1eta_eeSM_1800, i)
        e1phi_eeSM_1800 = np.delete(e1phi_eeSM_1800, i)
        
        e2pt_eeSM_1800 = np.delete(e2pt_eeSM_1800, i)
        e2eta_eeSM_1800 = np.delete(e2eta_eeSM_1800, i)
        e2phi_eeSM_1800 = np.delete(e2phi_eeSM_1800, i)
        
        invariant_mass_eeSM_1800 = np.delete(invariant_mass_eeSM_1800, i)
        


# concatenate results
e1pt_eeSM = np.concatenate([e1pt_eeSM,e1pt_eeSM_1800])
e1eta_eeSM = np.concatenate([e1eta_eeSM,e1eta_eeSM_1800])
e1phi_eeSM = np.concatenate([e1phi_eeSM,e1phi_eeSM_1800])

e2pt_eeSM = np.concatenate([e2pt_eeSM,e2pt_eeSM_1800])
e2eta_eeSM = np.concatenate([e2eta_eeSM,e2eta_eeSM_1800])
e2phi_eeSM = np.concatenate([e2phi_eeSM,e2phi_eeSM_1800])

invariant_mass_eeSM = np.concatenate([invariant_mass_eeSM,invariant_mass_eeSM_1800])



# remove the aux
del e1pt_eeSM_1800
del e1eta_eeSM_1800
del e1phi_eeSM_1800

del e2pt_eeSM_1800
del e2eta_eeSM_1800
del e2phi_eeSM_1800

del invariant_mass_eeSM_1800




# FINALLY

# compute \Delta \eta_{l+l-}
e1e2diffeta_eeSM = np.array([a-b for a,b in zip(e1eta_eeSM,e2eta_eeSM)])

# compute R = [ \Delta \eta_{l+l-}^2 + \Delta \eta_{l+l-}^2 ]^1/2
e1e2R_eeSM = np.array([( (a-b)**2. + (c-d)**2. )**0.5 for a,b,c,d in zip(e1eta_eeSM,e2eta_eeSM,e1phi_eeSM,e2phi_eeSM)])



print(e1pt_eeSM.shape)
print(e1eta_eeSM.shape)
print(e1phi_eeSM.shape)

print(e2pt_eeSM.shape)
print(e2eta_eeSM.shape)
print(e2phi_eeSM.shape)

print(invariant_mass_eeSM.shape)
print(e1e2diffeta_eeSM.shape)
print(e1e2R_eeSM.shape)
# Out:
# (804774,)
# (804774,)
# (804774,)
# (804774,)
# (804774,)
# (804774,)
# (804774,)
# (804774,)
# (804774,)

# %%
print(min(e1eta_eeSM))
print(max(e1eta_eeSM))

print(min(e2eta_eeSM))
print(max(e2eta_eeSM))
# Out:
# -2.646
# 2.648
# -2.649
# 2.649

# %% [markdown]
# ### SSM Z prime

# %%
##########
# Zprime #
##########


folder_saved = "Zprime-SSM-mumu-mZ5500GeV-variables/"


# 1st DATASET
invariant_mass_eeSSMZprime = np.loadtxt(folder_data + folder_saved +"mmumu-1.txt", delimiter=',')

e1pt_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-pt-5500-1.txt', delimiter=',')
e1eta_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-eta-5500-1.txt', delimiter=',')
e1phi_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-phi-5500-1.txt', delimiter=',')

e2pt_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-pt-5500-1.txt', delimiter=',')
e2eta_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-eta-5500-1.txt', delimiter=',')
e2phi_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-phi-5500-1.txt', delimiter=',')


# only keep points where the invariant mass is greater than 2000 GeV
# and make sure that both electrons: |eta| < 2.65
for i in reversed(range(len(invariant_mass_eeSSMZprime))):
    if invariant_mass_eeSSMZprime[i]< 2000 or e1eta_eeSSMZprime[i] < -2.65 or e1eta_eeSSMZprime[i] > 2.65 or e2eta_eeSSMZprime[i] < -2.65 or e2eta_eeSSMZprime[i] > 2.65:
        e1pt_eeSSMZprime = np.delete(e1pt_eeSSMZprime, i)
        e1eta_eeSSMZprime = np.delete(e1eta_eeSSMZprime, i)
        e1phi_eeSSMZprime = np.delete(e1phi_eeSSMZprime, i)
        
        e2pt_eeSSMZprime = np.delete(e2pt_eeSSMZprime, i)
        e2eta_eeSSMZprime = np.delete(e2eta_eeSSMZprime, i)
        e2phi_eeSSMZprime = np.delete(e2phi_eeSSMZprime, i)
        
        invariant_mass_eeSSMZprime = np.delete(invariant_mass_eeSSMZprime, i)

        
        
        
        
# 2nd DATASET
invariant_mass_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved +"mmumu-2.txt", delimiter=',')

e1pt_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved + 'mu1-pt-5500-2.txt', delimiter=',')
e1eta_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved + 'mu1-eta-5500-2.txt', delimiter=',')
e1phi_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved + 'mu1-phi-5500-2.txt', delimiter=',')

e2pt_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved + 'mu2-pt-5500-2.txt', delimiter=',')
e2eta_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved + 'mu2-eta-5500-2.txt', delimiter=',')
e2phi_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved + 'mu2-phi-5500-2.txt', delimiter=',')


# only keep points where the invariant mass is greater than 2000 GeV
# and make sure that both electrons: |eta| < 2.65
for i in reversed(range(len(invariant_mass_eeSSMZprime_2))):
    if invariant_mass_eeSSMZprime_2[i]< 2000 or e1eta_eeSSMZprime_2[i] < -2.65 or e1eta_eeSSMZprime_2[i] > 2.65 or e2eta_eeSSMZprime_2[i] < -2.65 or e2eta_eeSSMZprime_2[i] > 2.65:
        e1pt_eeSSMZprime_2 = np.delete(e1pt_eeSSMZprime_2, i)
        e1eta_eeSSMZprime_2 = np.delete(e1eta_eeSSMZprime_2, i)
        e1phi_eeSSMZprime_2 = np.delete(e1phi_eeSSMZprime_2, i)
        
        e2pt_eeSSMZprime_2 = np.delete(e2pt_eeSSMZprime_2, i)
        e2eta_eeSSMZprime_2 = np.delete(e2eta_eeSSMZprime_2, i)
        e2phi_eeSSMZprime_2 = np.delete(e2phi_eeSSMZprime_2, i)
        
        invariant_mass_eeSSMZprime_2 = np.delete(invariant_mass_eeSSMZprime_2, i)
        
eventos_parton = 1000000
aceptancia_eeSSMZprime_2 = 1.*len(invariant_mass_eeSSMZprime_2) / eventos_parton
print(aceptancia_eeSSMZprime_2)


# concatenate results
e1pt_eeSSMZprime = np.concatenate([e1pt_eeSSMZprime,e1pt_eeSSMZprime_2])
e1eta_eeSSMZprime = np.concatenate([e1eta_eeSSMZprime,e1eta_eeSSMZprime_2])
e1phi_eeSSMZprime = np.concatenate([e1phi_eeSSMZprime,e1phi_eeSSMZprime_2])

e2pt_eeSSMZprime = np.concatenate([e2pt_eeSSMZprime,e2pt_eeSSMZprime_2])
e2eta_eeSSMZprime = np.concatenate([e2eta_eeSSMZprime,e2eta_eeSSMZprime_2])
e2phi_eeSSMZprime = np.concatenate([e2phi_eeSSMZprime,e2phi_eeSSMZprime_2])

invariant_mass_eeSSMZprime = np.concatenate([invariant_mass_eeSSMZprime,invariant_mass_eeSSMZprime_2])



# remove the aux
del e1pt_eeSSMZprime_2
del e1eta_eeSSMZprime_2
del e1phi_eeSSMZprime_2

del e2pt_eeSSMZprime_2
del e2eta_eeSSMZprime_2
del e2phi_eeSSMZprime_2

del invariant_mass_eeSSMZprime_2








# FINALLY

# compute \Delta \eta_{l+l-}
e1e2diffeta_eeSSMZprime = np.array([a-b for a,b in zip(e1eta_eeSSMZprime,e2eta_eeSSMZprime)])

# compute R = [ \Delta \eta_{l+l-}^2 + \Delta \eta_{l+l-}^2 ]^1/2
e1e2R_eeSSMZprime = np.array([( (a-b)**2. + (c-d)**2. )**0.5 for a,b,c,d in zip(e1eta_eeSSMZprime,e2eta_eeSSMZprime,e1phi_eeSSMZprime,e2phi_eeSSMZprime)])




print(e1pt_eeSSMZprime.shape)
print(e1eta_eeSSMZprime.shape)
print(e1phi_eeSSMZprime.shape)

print(e2pt_eeSSMZprime.shape)
print(e2eta_eeSSMZprime.shape)
print(e2phi_eeSSMZprime.shape)

print(invariant_mass_eeSSMZprime.shape)
print(e1e2diffeta_eeSSMZprime.shape)
print(e1e2R_eeSSMZprime.shape)
# Out:
# 0.707437
# (1416794,)
# (1416794,)
# (1416794,)
# (1416794,)
# (1416794,)
# (1416794,)
# (1416794,)
# (1416794,)
# (1416794,)

# %%
print(min(e1eta_eeSSMZprime))
print(max(e1eta_eeSSMZprime))

print(min(e2eta_eeSSMZprime))
print(max(e2eta_eeSSMZprime))
# Out:
# -2.627
# 2.644
# -2.649
# 2.649

# %%
# NOW DATA IS CHECKED

bins_atlas = [70, 80.0, 90.0, 105.0, 120.0, 140.0, 160.0, 180.0, 210.0, 240.0, 275.0, 315.0, 360.0, 415.0, 475.0, 545.0, 625.0, 715.0, 825.0, 950.0, 1100.0, 1250.0, 1450.0, 1650.0, 1900.0, 2200.0, 2500.0, 2850.0, 3250.0, 3750.0, 4350.0, 5000.0, 5750.0, 6600.0, 7500.0, 8750.0, 10000.0, 11500.0, 13000.0, 20000]

plt.hist(invariant_mass_eeSM, bins=bins_atlas, lw=2, edgecolor='blue', histtype='step', label="SM")
plt.hist(invariant_mass_eeSSMZprime, bins=bins_atlas, lw=2, edgecolor='red', histtype='step', label="$Z'_{SSM}$")

plt.grid()  # Add grid lines

plt.title(r"Z/Z'$\rightarrow \mu+ \mu-$",fontsize=14)  # Titles etc
plt.xlabel("$m_{ll}$ (GeV)",fontsize=14)
plt.ylabel("Events",fontsize=14)

plt.xlim(70.,20000)
plt.ylim(1e0,1e7)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xscale('log')
plt.yscale('log')
plt.legend(loc='upper left',fontsize=12)

plt.show()




plt.hist(e1e2diffeta_eeSM, bins=100, range=[-5,5], lw=2, edgecolor='blue', histtype='step', label="SM")
plt.hist(e1e2diffeta_eeSSMZprime, bins=100, range=[-5,5], lw=2, edgecolor='red', histtype='step', label="$Z'_{SSM}$")

plt.grid()  # Add grid lines

plt.title(r"Z/Z'$\rightarrow \mu+ \mu-$",fontsize=14)  # Titles etc
plt.xlabel("$\Delta \eta_{ll}$",fontsize=14)
plt.ylabel("Events",fontsize=14)

plt.xlim(-5,5)
plt.ylim(1e0,1e7)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#plt.xscale('log')
plt.yscale('log')
plt.legend(loc='upper left',fontsize=12)

plt.show()




plt.hist(e1e2R_eeSM, bins=82, range=[0,8.2], lw=2, edgecolor='blue', histtype='step', label="SM")
plt.hist(e1e2R_eeSSMZprime, bins=82, range=[0,8.2], lw=2, edgecolor='red', histtype='step', label="$Z'_{SSM}$")

plt.grid()  # Add grid lines

plt.title(r"Z/Z'$\rightarrow \mu+ \mu-$",fontsize=14)  # Titles etc
plt.xlabel("$R$",fontsize=14)
plt.ylabel("Events",fontsize=14)

plt.xlim(0.,8.2)
plt.ylim(1e0,1e7)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#plt.xscale('log')
plt.yscale('log')
plt.legend(loc='upper left',fontsize=12)

plt.show()

# %% [markdown]
# ### Train-test-val datasets

# %%
# to normalize
scaler = preprocessing.MinMaxScaler()

# Number of data points (per-class) for the ML classifier
num_data = 750000



df = pd.DataFrame()

df['e1-pt']= np.concatenate([e1pt_eeSM[:num_data],e1pt_eeSSMZprime[:num_data]])
df['e1-eta']= np.concatenate([e1eta_eeSM[:num_data],e1eta_eeSSMZprime[:num_data]])
df['e1-phi']= np.concatenate([e1phi_eeSM[:num_data],e1phi_eeSSMZprime[:num_data]])

df['e2-pt']= np.concatenate([e2pt_eeSM[:num_data],e2pt_eeSSMZprime[:num_data]])
df['e2-eta']= np.concatenate([e2eta_eeSM[:num_data],e2eta_eeSSMZprime[:num_data]])
df['e2-phi']= np.concatenate([e2phi_eeSM[:num_data],e2phi_eeSSMZprime[:num_data]])

df['mll']= np.concatenate([invariant_mass_eeSM[:num_data],invariant_mass_eeSSMZprime[:num_data]])
df['delta-eta']= np.concatenate([e1e2diffeta_eeSM[:num_data],e1e2diffeta_eeSSMZprime[:num_data]])
df['R']= np.concatenate([e1e2R_eeSM[:num_data],e1e2R_eeSSMZprime[:num_data]])

df['Y'] = np.concatenate([np.zeros(num_data),np.ones(num_data)])


# remove the used data
del e1pt_eeSM
del e1eta_eeSM
del e1phi_eeSM

del e2pt_eeSM
del e2eta_eeSM
del e2phi_eeSM

del e1pt_eeSSMZprime
del e1eta_eeSSMZprime
del e1phi_eeSSMZprime

del e2pt_eeSSMZprime
del e2eta_eeSSMZprime
del e2phi_eeSSMZprime


# NORMALIZE
df = scaler.fit_transform(df)
df = pd.DataFrame(df,columns=['e1-pt','e1-eta','e1-phi','e2-pt','e2-eta','e2-phi','mll','delta-eta','R','Y'])


# print df to see the data
print(df)


# X and Y for the classifier
X_mon = df[['e1-pt','e1-eta','e1-phi','e2-pt','e2-eta','e2-phi']].values
y_mon = df[['Y']].values

del df

# divide into train-val and test data samples
test_ratio = 1./3
val_ratio = 0.25


X_mon_aux, X_mon_test, y_mon_aux, y_mon_test = train_test_split(X_mon,
                                                                y_mon,
                                                                test_size=test_ratio,
                                                                random_state=42,
                                                                #stratify = y_mon,
                                                                shuffle=True)


X_mon_train, X_mon_val, y_mon_train, y_mon_val = train_test_split(X_mon_aux,
                                                                  y_mon_aux,
                                                                  test_size=val_ratio,
                                                                  random_state=42,
                                                                  #stratify = y_mon_aux,
                                                                  shuffle=True)


print('')
print('X_mon_train : ', X_mon_train.shape)
print('y_mon_train : ', y_mon_train.shape)
print('X_mon_val : ', X_mon_val.shape)
print('y_mon_val : ', y_mon_val.shape)
print('X_mon_test : ', X_mon_test.shape)
print('y_mon_test : ', y_mon_test.shape)
print('')
# Out:
#             e1-pt    e1-eta    e1-phi     e2-pt    e2-eta    e2-phi       mll  \
# 0        0.218132  0.591235  0.081158  0.255918  0.609664  0.557288  0.038970
# 1        0.212923  0.636759  0.312540  0.243438  0.353341  0.827976  0.119378
# 2        0.287890  0.703627  0.972311  0.318849  0.502831  0.473265  0.177909
# 3        0.200446  0.581224  0.581158  0.213519  0.567573  0.101528  0.002792
# 4        0.177369  0.544012  0.273711  0.222033  0.285957  0.765595  0.060085
# ...           ...       ...       ...       ...       ...       ...       ...
# 1499995  0.395728  0.634492  0.137174  0.451975  0.367686  0.644653  0.407762
# 1499996  0.305459  0.786173  0.516391  0.330546  0.332201  0.936028  0.469896
# 1499997  0.552210  0.331696  0.295672  0.608866  0.486976  0.796149  0.519188
# 1499998  0.604741  0.566868  0.087842  0.603324  0.502076  0.592934  0.496398
# 1499999  0.136570  0.811674  0.640993  0.161550  0.495092  0.153087  0.011449
#
#          delta-eta         R    Y
# 0         0.488730  0.271333  0.0
# 1         0.643417  0.364958  0.0
# 2         0.601045  0.322957  0.0
# 3         0.505176  0.274793  0.0
# 4         0.630454  0.334095  0.0
# ...            ...       ...  ...
# 1499995   0.634904  0.351665  1.0
# 1499996   0.730773  0.364745  1.0
# 1499997   0.418690  0.313024  1.0
# 1499998   0.531392  0.303640  1.0
# 1499999   0.660346  0.352678  1.0
#
# [1500000 rows x 10 columns]
#
# X_mon_train :  (750000, 6)
# y_mon_train :  (750000, 1)
# X_mon_val :  (250000, 6)
# y_mon_val :  (250000, 1)
# X_mon_test :  (500000, 6)
# y_mon_test :  (500000, 1)

# %% [markdown]
# ### XGBoost (per-event)

# %% [markdown]
# ##### For 1 ML

# %%
# XGBoost with only the kinematic variables of the leptons

# CLASSIFIER
classifier = XGBClassifier(
    n_estimators=2500,
    learning_rate=0.1,
    reg_lambda=0.0,reg_alpha=0.0,
    gamma=0.0,objective='binary:logistic',
    max_depth=5)

# FIT
classifier.fit(X_mon_train,y_mon_train,eval_set=[(X_mon_train, y_mon_train), (X_mon_val, y_mon_val)],
        eval_metric='logloss',early_stopping_rounds=50,#early stopping
        verbose=True)

# PREDICTIONS
y_pred_xg_1ML = classifier.predict_proba(X_mon_test).T[1]


# ROC
fpr_mon_xg, tpr_mon_xg, _ = roc_curve(y_mon_test, y_pred_xg_1ML)
roc_auc_xg = auc(fpr_mon_xg, tpr_mon_xg)


# PLOT THE ROC WITH AUC
fig = plt.figure(figsize=(6, 6))
gs = gridspec.GridSpec(1, 1) 
ax0 = plt.subplot(gs[0])
ax0.yaxis.set_ticks_position('both')
ax0.xaxis.set_ticks_position('both')
ax0.tick_params(direction="in",which="both")
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
ax0.minorticks_on()


plt.plot(tpr_mon_xg,1-fpr_mon_xg,label="$f_{1}$, AUC = %0.2f" % roc_auc_xg,color="orange",ls=":",lw=4)
plt.plot([1,0],[0,1],ls=":",color="grey")
plt.xlabel("True Positive Rate",fontsize=16)
plt.ylabel("1 $-$ False Positive Rate",fontsize=16)
plt.legend()
plt.title(r"SSM Z' - XGBoost",fontsize=16)
plt.xlim([0,1])
plt.ylim([0,1])
plt.yticks([0.2,0.4,0.6,0.8,1.])
plt.legend(frameon=False,fontsize=16)
plt.show()




feature_names = np.array(['e1-pt','e1-eta','e1-phi','e2-pt','e2-eta','e2-phi'])
plt.barh(feature_names, classifier.feature_importances_)
plt.xlabel("Xgboost Feature Importance")
plt.show()
# Out:
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [0]	validation_0-logloss:0.64019	validation_1-logloss:0.63996
# [1]	validation_0-logloss:0.59632	validation_1-logloss:0.59606
# [2]	validation_0-logloss:0.55943	validation_1-logloss:0.55924
# [3]	validation_0-logloss:0.52825	validation_1-logloss:0.52802
# [4]	validation_0-logloss:0.50152	validation_1-logloss:0.50129
# [5]	validation_0-logloss:0.47866	validation_1-logloss:0.47844
# [6]	validation_0-logloss:0.45887	validation_1-logloss:0.45862
# [7]	validation_0-logloss:0.44166	validation_1-logloss:0.44142
# [8]	validation_0-logloss:0.42624	validation_1-logloss:0.42605
# [9]	validation_0-logloss:0.41260	validation_1-logloss:0.41239
# [10]	validation_0-logloss:0.40083	validation_1-logloss:0.40061
# [11]	validation_0-logloss:0.39050	validation_1-logloss:0.39030
# [12]	validation_0-logloss:0.38137	validation_1-logloss:0.38115
# [13]	validation_0-logloss:0.37313	validation_1-logloss:0.37286
# [14]	validation_0-logloss:0.36591	validation_1-logloss:0.36566
# [15]	validation_0-logloss:0.35945	validation_1-logloss:0.35922
# [16]	validation_0-logloss:0.35386	validation_1-logloss:0.35360
# [17]	validation_0-logloss:0.34859	validation_1-logloss:0.34836
# [18]	validation_0-logloss:0.34388	validation_1-logloss:0.34363
# [19]	validation_0-logloss:0.33887	validation_1-logloss:0.33864
# [20]	validation_0-logloss:0.33472	validation_1-logloss:0.33448
# [21]	validation_0-logloss:0.33106	validation_1-logloss:0.33086
# [22]	validation_0-logloss:0.32730	validation_1-logloss:0.32709
# [23]	validation_0-logloss:0.32468	validation_1-logloss:0.32443
# [24]	validation_0-logloss:0.32176	validation_1-logloss:0.32155
# [25]	validation_0-logloss:0.31942	validation_1-logloss:0.31922
# [26]	validation_0-logloss:0.31669	validation_1-logloss:0.31651
# [27]	validation_0-logloss:0.31462	validation_1-logloss:0.31450
# [28]	validation_0-logloss:0.31309	validation_1-logloss:0.31294
# [29]	validation_0-logloss:0.31086	validation_1-logloss:0.31071
# [30]	validation_0-logloss:0.30915	validation_1-logloss:0.30904
# [31]	validation_0-logloss:0.30785	validation_1-logloss:0.30773
# [32]	validation_0-logloss:0.30643	validation_1-logloss:0.30632
# [33]	validation_0-logloss:0.30514	validation_1-logloss:0.30507
# [34]	validation_0-logloss:0.30416	validation_1-logloss:0.30411
# [35]	validation_0-logloss:0.30305	validation_1-logloss:0.30299
# [36]	validation_0-logloss:0.30184	validation_1-logloss:0.30181
# [37]	validation_0-logloss:0.30095	validation_1-logloss:0.30094
# [38]	validation_0-logloss:0.29988	validation_1-logloss:0.29991
# [39]	validation_0-logloss:0.29894	validation_1-logloss:0.29900
# [40]	validation_0-logloss:0.29815	validation_1-logloss:0.29821
# [41]	validation_0-logloss:0.29751	validation_1-logloss:0.29759
# [42]	validation_0-logloss:0.29655	validation_1-logloss:0.29665
# [43]	validation_0-logloss:0.29574	validation_1-logloss:0.29589
# [44]	validation_0-logloss:0.29502	validation_1-logloss:0.29522
# [45]	validation_0-logloss:0.29436	validation_1-logloss:0.29459
# [46]	validation_0-logloss:0.29386	validation_1-logloss:0.29410
# [47]	validation_0-logloss:0.29335	validation_1-logloss:0.29361
# [48]	validation_0-logloss:0.29278	validation_1-logloss:0.29308
# [49]	validation_0-logloss:0.29237	validation_1-logloss:0.29268
# [50]	validation_0-logloss:0.29185	validation_1-logloss:0.29219
# [51]	validation_0-logloss:0.29145	validation_1-logloss:0.29183
# [52]	validation_0-logloss:0.29102	validation_1-logloss:0.29142
# [53]	validation_0-logloss:0.29077	validation_1-logloss:0.29119
# [54]	validation_0-logloss:0.29042	validation_1-logloss:0.29085
# [55]	validation_0-logloss:0.29007	validation_1-logloss:0.29054
# [56]	validation_0-logloss:0.28971	validation_1-logloss:0.29020
# [57]	validation_0-logloss:0.28932	validation_1-logloss:0.28985
# [58]	validation_0-logloss:0.28901	validation_1-logloss:0.28958
# [59]	validation_0-logloss:0.28873	validation_1-logloss:0.28932
# [60]	validation_0-logloss:0.28833	validation_1-logloss:0.28895
# [61]	validation_0-logloss:0.28808	validation_1-logloss:0.28870
# [62]	validation_0-logloss:0.28782	validation_1-logloss:0.28845
# [63]	validation_0-logloss:0.28750	validation_1-logloss:0.28816
# [64]	validation_0-logloss:0.28728	validation_1-logloss:0.28798
# [65]	validation_0-logloss:0.28705	validation_1-logloss:0.28778
# [66]	validation_0-logloss:0.28689	validation_1-logloss:0.28764
# [67]	validation_0-logloss:0.28668	validation_1-logloss:0.28745
# [68]	validation_0-logloss:0.28651	validation_1-logloss:0.28731
# [69]	validation_0-logloss:0.28634	validation_1-logloss:0.28717
# [70]	validation_0-logloss:0.28620	validation_1-logloss:0.28705
# [71]	validation_0-logloss:0.28599	validation_1-logloss:0.28687
# [72]	validation_0-logloss:0.28585	validation_1-logloss:0.28674
# [73]	validation_0-logloss:0.28569	validation_1-logloss:0.28662
# [74]	validation_0-logloss:0.28548	validation_1-logloss:0.28645
# [75]	validation_0-logloss:0.28537	validation_1-logloss:0.28635
# [76]	validation_0-logloss:0.28523	validation_1-logloss:0.28623
# [77]	validation_0-logloss:0.28515	validation_1-logloss:0.28616
# [78]	validation_0-logloss:0.28498	validation_1-logloss:0.28602
# [79]	validation_0-logloss:0.28486	validation_1-logloss:0.28592
# [80]	validation_0-logloss:0.28476	validation_1-logloss:0.28584
# [81]	validation_0-logloss:0.28468	validation_1-logloss:0.28578
# [82]	validation_0-logloss:0.28456	validation_1-logloss:0.28568
# [83]	validation_0-logloss:0.28448	validation_1-logloss:0.28562
# [84]	validation_0-logloss:0.28441	validation_1-logloss:0.28557
# [85]	validation_0-logloss:0.28428	validation_1-logloss:0.28547
# [86]	validation_0-logloss:0.28419	validation_1-logloss:0.28541
# [87]	validation_0-logloss:0.28411	validation_1-logloss:0.28534
# [88]	validation_0-logloss:0.28406	validation_1-logloss:0.28530
# [89]	validation_0-logloss:0.28400	validation_1-logloss:0.28526
# [90]	validation_0-logloss:0.28395	validation_1-logloss:0.28523
# [91]	validation_0-logloss:0.28386	validation_1-logloss:0.28517
# [92]	validation_0-logloss:0.28375	validation_1-logloss:0.28508
# [93]	validation_0-logloss:0.28369	validation_1-logloss:0.28504
# [94]	validation_0-logloss:0.28362	validation_1-logloss:0.28499
# [95]	validation_0-logloss:0.28356	validation_1-logloss:0.28494
# [96]	validation_0-logloss:0.28350	validation_1-logloss:0.28490
# [97]	validation_0-logloss:0.28344	validation_1-logloss:0.28486
# [98]	validation_0-logloss:0.28339	validation_1-logloss:0.28482
# [99]	validation_0-logloss:0.28330	validation_1-logloss:0.28475
# [100]	validation_0-logloss:0.28326	validation_1-logloss:0.28474
# [101]	validation_0-logloss:0.28320	validation_1-logloss:0.28470
# [102]	validation_0-logloss:0.28312	validation_1-logloss:0.28465
# [103]	validation_0-logloss:0.28309	validation_1-logloss:0.28464
# [104]	validation_0-logloss:0.28305	validation_1-logloss:0.28462
# [105]	validation_0-logloss:0.28299	validation_1-logloss:0.28458
# [106]	validation_0-logloss:0.28297	validation_1-logloss:0.28456
# [107]	validation_0-logloss:0.28289	validation_1-logloss:0.28451
# [108]	validation_0-logloss:0.28285	validation_1-logloss:0.28448
# [109]	validation_0-logloss:0.28281	validation_1-logloss:0.28446
# [110]	validation_0-logloss:0.28274	validation_1-logloss:0.28442
# [111]	validation_0-logloss:0.28266	validation_1-logloss:0.28437
# [112]	validation_0-logloss:0.28263	validation_1-logloss:0.28436
# [113]	validation_0-logloss:0.28259	validation_1-logloss:0.28434
# [114]	validation_0-logloss:0.28256	validation_1-logloss:0.28432
# [115]	validation_0-logloss:0.28252	validation_1-logloss:0.28430
# [116]	validation_0-logloss:0.28248	validation_1-logloss:0.28429
# [117]	validation_0-logloss:0.28245	validation_1-logloss:0.28427
# [118]	validation_0-logloss:0.28243	validation_1-logloss:0.28426
# [119]	validation_0-logloss:0.28238	validation_1-logloss:0.28424
# [120]	validation_0-logloss:0.28236	validation_1-logloss:0.28423
# [121]	validation_0-logloss:0.28232	validation_1-logloss:0.28420
# [122]	validation_0-logloss:0.28227	validation_1-logloss:0.28416
# [123]	validation_0-logloss:0.28224	validation_1-logloss:0.28415
# [124]	validation_0-logloss:0.28220	validation_1-logloss:0.28413
# [125]	validation_0-logloss:0.28218	validation_1-logloss:0.28413
# [126]	validation_0-logloss:0.28216	validation_1-logloss:0.28412
# [127]	validation_0-logloss:0.28214	validation_1-logloss:0.28411
# [128]	validation_0-logloss:0.28211	validation_1-logloss:0.28411
# [129]	validation_0-logloss:0.28207	validation_1-logloss:0.28408
# [130]	validation_0-logloss:0.28204	validation_1-logloss:0.28408
# [131]	validation_0-logloss:0.28202	validation_1-logloss:0.28408
# [132]	validation_0-logloss:0.28197	validation_1-logloss:0.28404
# [133]	validation_0-logloss:0.28194	validation_1-logloss:0.28403
# [134]	validation_0-logloss:0.28192	validation_1-logloss:0.28403
# [135]	validation_0-logloss:0.28189	validation_1-logloss:0.28402
# [136]	validation_0-logloss:0.28184	validation_1-logloss:0.28398
# [137]	validation_0-logloss:0.28182	validation_1-logloss:0.28398
# [138]	validation_0-logloss:0.28181	validation_1-logloss:0.28399
# [139]	validation_0-logloss:0.28179	validation_1-logloss:0.28398
# [140]	validation_0-logloss:0.28178	validation_1-logloss:0.28397
# [141]	validation_0-logloss:0.28174	validation_1-logloss:0.28396
# [142]	validation_0-logloss:0.28171	validation_1-logloss:0.28395
# [143]	validation_0-logloss:0.28169	validation_1-logloss:0.28395
# [144]	validation_0-logloss:0.28168	validation_1-logloss:0.28395
# [145]	validation_0-logloss:0.28165	validation_1-logloss:0.28393
# [146]	validation_0-logloss:0.28163	validation_1-logloss:0.28392
# [147]	validation_0-logloss:0.28161	validation_1-logloss:0.28392
# [148]	validation_0-logloss:0.28159	validation_1-logloss:0.28392
# [149]	validation_0-logloss:0.28158	validation_1-logloss:0.28391
# [150]	validation_0-logloss:0.28155	validation_1-logloss:0.28391
# [151]	validation_0-logloss:0.28152	validation_1-logloss:0.28390
# [152]	validation_0-logloss:0.28151	validation_1-logloss:0.28389
# [153]	validation_0-logloss:0.28149	validation_1-logloss:0.28389
# [154]	validation_0-logloss:0.28147	validation_1-logloss:0.28388
# [155]	validation_0-logloss:0.28145	validation_1-logloss:0.28388
# [156]	validation_0-logloss:0.28143	validation_1-logloss:0.28388
# [157]	validation_0-logloss:0.28141	validation_1-logloss:0.28387
# [158]	validation_0-logloss:0.28139	validation_1-logloss:0.28387
# [159]	validation_0-logloss:0.28136	validation_1-logloss:0.28385
# [160]	validation_0-logloss:0.28135	validation_1-logloss:0.28385
# [161]	validation_0-logloss:0.28133	validation_1-logloss:0.28385
# [162]	validation_0-logloss:0.28131	validation_1-logloss:0.28385
# [163]	validation_0-logloss:0.28130	validation_1-logloss:0.28385
# [164]	validation_0-logloss:0.28127	validation_1-logloss:0.28385
# [165]	validation_0-logloss:0.28126	validation_1-logloss:0.28385
# [166]	validation_0-logloss:0.28124	validation_1-logloss:0.28384
# [167]	validation_0-logloss:0.28122	validation_1-logloss:0.28384
# [168]	validation_0-logloss:0.28121	validation_1-logloss:0.28384
# [169]	validation_0-logloss:0.28119	validation_1-logloss:0.28384
# [170]	validation_0-logloss:0.28114	validation_1-logloss:0.28383
# [171]	validation_0-logloss:0.28113	validation_1-logloss:0.28383
# [172]	validation_0-logloss:0.28111	validation_1-logloss:0.28383
# [173]	validation_0-logloss:0.28110	validation_1-logloss:0.28383
# [174]	validation_0-logloss:0.28106	validation_1-logloss:0.28381
# [175]	validation_0-logloss:0.28102	validation_1-logloss:0.28379
# [176]	validation_0-logloss:0.28101	validation_1-logloss:0.28379
# [177]	validation_0-logloss:0.28100	validation_1-logloss:0.28379
# [178]	validation_0-logloss:0.28098	validation_1-logloss:0.28379
# [179]	validation_0-logloss:0.28096	validation_1-logloss:0.28378
# [180]	validation_0-logloss:0.28093	validation_1-logloss:0.28378
# [181]	validation_0-logloss:0.28091	validation_1-logloss:0.28377
# [182]	validation_0-logloss:0.28090	validation_1-logloss:0.28377
# [183]	validation_0-logloss:0.28088	validation_1-logloss:0.28377
# [184]	validation_0-logloss:0.28086	validation_1-logloss:0.28377
# [185]	validation_0-logloss:0.28084	validation_1-logloss:0.28377
# [186]	validation_0-logloss:0.28082	validation_1-logloss:0.28376
# [187]	validation_0-logloss:0.28079	validation_1-logloss:0.28375
# [188]	validation_0-logloss:0.28078	validation_1-logloss:0.28376
# [189]	validation_0-logloss:0.28075	validation_1-logloss:0.28375
# [190]	validation_0-logloss:0.28073	validation_1-logloss:0.28374
# [191]	validation_0-logloss:0.28072	validation_1-logloss:0.28374
# [192]	validation_0-logloss:0.28070	validation_1-logloss:0.28374
# [193]	validation_0-logloss:0.28069	validation_1-logloss:0.28374
# [194]	validation_0-logloss:0.28068	validation_1-logloss:0.28374
# [195]	validation_0-logloss:0.28066	validation_1-logloss:0.28374
# [196]	validation_0-logloss:0.28065	validation_1-logloss:0.28374
# [197]	validation_0-logloss:0.28061	validation_1-logloss:0.28374
# [198]	validation_0-logloss:0.28059	validation_1-logloss:0.28373
# [199]	validation_0-logloss:0.28057	validation_1-logloss:0.28373
# [200]	validation_0-logloss:0.28055	validation_1-logloss:0.28372
# [201]	validation_0-logloss:0.28052	validation_1-logloss:0.28372
# [202]	validation_0-logloss:0.28049	validation_1-logloss:0.28371
# [203]	validation_0-logloss:0.28048	validation_1-logloss:0.28371
# [204]	validation_0-logloss:0.28047	validation_1-logloss:0.28372
# [205]	validation_0-logloss:0.28045	validation_1-logloss:0.28371
# [206]	validation_0-logloss:0.28044	validation_1-logloss:0.28371
# [207]	validation_0-logloss:0.28042	validation_1-logloss:0.28370
# [208]	validation_0-logloss:0.28039	validation_1-logloss:0.28370
# [209]	validation_0-logloss:0.28037	validation_1-logloss:0.28370
# [210]	validation_0-logloss:0.28036	validation_1-logloss:0.28370
# [211]	validation_0-logloss:0.28033	validation_1-logloss:0.28369
# [212]	validation_0-logloss:0.28031	validation_1-logloss:0.28369
# [213]	validation_0-logloss:0.28030	validation_1-logloss:0.28369
# [214]	validation_0-logloss:0.28029	validation_1-logloss:0.28368
# [215]	validation_0-logloss:0.28026	validation_1-logloss:0.28368
# [216]	validation_0-logloss:0.28024	validation_1-logloss:0.28368
# [217]	validation_0-logloss:0.28024	validation_1-logloss:0.28368
# [218]	validation_0-logloss:0.28022	validation_1-logloss:0.28368
# [219]	validation_0-logloss:0.28020	validation_1-logloss:0.28368
# [220]	validation_0-logloss:0.28018	validation_1-logloss:0.28368
# [221]	validation_0-logloss:0.28015	validation_1-logloss:0.28367
# [222]	validation_0-logloss:0.28014	validation_1-logloss:0.28367
# [223]	validation_0-logloss:0.28013	validation_1-logloss:0.28367
# [224]	validation_0-logloss:0.28011	validation_1-logloss:0.28367
# [225]	validation_0-logloss:0.28009	validation_1-logloss:0.28367
# [226]	validation_0-logloss:0.28008	validation_1-logloss:0.28367
# [227]	validation_0-logloss:0.28006	validation_1-logloss:0.28367
# [228]	validation_0-logloss:0.28005	validation_1-logloss:0.28367
# [229]	validation_0-logloss:0.28003	validation_1-logloss:0.28367
# [230]	validation_0-logloss:0.28000	validation_1-logloss:0.28366
# [231]	validation_0-logloss:0.27999	validation_1-logloss:0.28366
# [232]	validation_0-logloss:0.27998	validation_1-logloss:0.28366
# [233]	validation_0-logloss:0.27998	validation_1-logloss:0.28366
# [234]	validation_0-logloss:0.27996	validation_1-logloss:0.28366
# [235]	validation_0-logloss:0.27996	validation_1-logloss:0.28366
# [236]	validation_0-logloss:0.27995	validation_1-logloss:0.28366
# [237]	validation_0-logloss:0.27993	validation_1-logloss:0.28366
# [238]	validation_0-logloss:0.27992	validation_1-logloss:0.28367
# [239]	validation_0-logloss:0.27991	validation_1-logloss:0.28367
# [240]	validation_0-logloss:0.27989	validation_1-logloss:0.28366
# [241]	validation_0-logloss:0.27987	validation_1-logloss:0.28366
# [242]	validation_0-logloss:0.27985	validation_1-logloss:0.28366
# [243]	validation_0-logloss:0.27983	validation_1-logloss:0.28366
# [244]	validation_0-logloss:0.27981	validation_1-logloss:0.28366
# [245]	validation_0-logloss:0.27980	validation_1-logloss:0.28366
# [246]	validation_0-logloss:0.27979	validation_1-logloss:0.28366
# [247]	validation_0-logloss:0.27978	validation_1-logloss:0.28366
# [248]	validation_0-logloss:0.27976	validation_1-logloss:0.28366
# [249]	validation_0-logloss:0.27975	validation_1-logloss:0.28366
# [250]	validation_0-logloss:0.27972	validation_1-logloss:0.28365
# [251]	validation_0-logloss:0.27969	validation_1-logloss:0.28366
# [252]	validation_0-logloss:0.27967	validation_1-logloss:0.28365
# [253]	validation_0-logloss:0.27965	validation_1-logloss:0.28365
# [254]	validation_0-logloss:0.27961	validation_1-logloss:0.28364
# [255]	validation_0-logloss:0.27959	validation_1-logloss:0.28364
# [256]	validation_0-logloss:0.27958	validation_1-logloss:0.28365
# [257]	validation_0-logloss:0.27955	validation_1-logloss:0.28364
# [258]	validation_0-logloss:0.27954	validation_1-logloss:0.28364
# [259]	validation_0-logloss:0.27953	validation_1-logloss:0.28364
# [260]	validation_0-logloss:0.27952	validation_1-logloss:0.28364
# [261]	validation_0-logloss:0.27951	validation_1-logloss:0.28364
# [262]	validation_0-logloss:0.27950	validation_1-logloss:0.28364
# [263]	validation_0-logloss:0.27949	validation_1-logloss:0.28364
# [264]	validation_0-logloss:0.27947	validation_1-logloss:0.28364
# [265]	validation_0-logloss:0.27945	validation_1-logloss:0.28364
# [266]	validation_0-logloss:0.27944	validation_1-logloss:0.28364
# [267]	validation_0-logloss:0.27942	validation_1-logloss:0.28364
# [268]	validation_0-logloss:0.27942	validation_1-logloss:0.28364
# [269]	validation_0-logloss:0.27940	validation_1-logloss:0.28364
# [270]	validation_0-logloss:0.27938	validation_1-logloss:0.28365
# [271]	validation_0-logloss:0.27937	validation_1-logloss:0.28365
# [272]	validation_0-logloss:0.27937	validation_1-logloss:0.28365
# [273]	validation_0-logloss:0.27935	validation_1-logloss:0.28364
# [274]	validation_0-logloss:0.27933	validation_1-logloss:0.28364
# [275]	validation_0-logloss:0.27932	validation_1-logloss:0.28364
# [276]	validation_0-logloss:0.27931	validation_1-logloss:0.28364
# [277]	validation_0-logloss:0.27929	validation_1-logloss:0.28364
# [278]	validation_0-logloss:0.27927	validation_1-logloss:0.28364
# [279]	validation_0-logloss:0.27926	validation_1-logloss:0.28364
# [280]	validation_0-logloss:0.27924	validation_1-logloss:0.28364
# [281]	validation_0-logloss:0.27922	validation_1-logloss:0.28364
# [282]	validation_0-logloss:0.27921	validation_1-logloss:0.28364
# [283]	validation_0-logloss:0.27919	validation_1-logloss:0.28364
# [284]	validation_0-logloss:0.27916	validation_1-logloss:0.28365
# [285]	validation_0-logloss:0.27915	validation_1-logloss:0.28365
# [286]	validation_0-logloss:0.27913	validation_1-logloss:0.28365
# [287]	validation_0-logloss:0.27912	validation_1-logloss:0.28365
# [288]	validation_0-logloss:0.27912	validation_1-logloss:0.28365
# [289]	validation_0-logloss:0.27909	validation_1-logloss:0.28365
# [290]	validation_0-logloss:0.27909	validation_1-logloss:0.28365
# [291]	validation_0-logloss:0.27908	validation_1-logloss:0.28365
# [292]	validation_0-logloss:0.27905	validation_1-logloss:0.28365
# [293]	validation_0-logloss:0.27903	validation_1-logloss:0.28365
# [294]	validation_0-logloss:0.27901	validation_1-logloss:0.28365
# [295]	validation_0-logloss:0.27900	validation_1-logloss:0.28365
# [296]	validation_0-logloss:0.27898	validation_1-logloss:0.28365
# [297]	validation_0-logloss:0.27897	validation_1-logloss:0.28365
# [298]	validation_0-logloss:0.27894	validation_1-logloss:0.28364
# [299]	validation_0-logloss:0.27893	validation_1-logloss:0.28364
# [300]	validation_0-logloss:0.27892	validation_1-logloss:0.28364
# [301]	validation_0-logloss:0.27891	validation_1-logloss:0.28365
# [302]	validation_0-logloss:0.27890	validation_1-logloss:0.28364
# [303]	validation_0-logloss:0.27889	validation_1-logloss:0.28364
# [304]	validation_0-logloss:0.27887	validation_1-logloss:0.28364
# [305]	validation_0-logloss:0.27885	validation_1-logloss:0.28364
# [306]	validation_0-logloss:0.27881	validation_1-logloss:0.28363
# [307]	validation_0-logloss:0.27880	validation_1-logloss:0.28364
# [308]	validation_0-logloss:0.27879	validation_1-logloss:0.28364
# [309]	validation_0-logloss:0.27878	validation_1-logloss:0.28364
# [310]	validation_0-logloss:0.27877	validation_1-logloss:0.28364
# [311]	validation_0-logloss:0.27876	validation_1-logloss:0.28363
# [312]	validation_0-logloss:0.27875	validation_1-logloss:0.28363
# [313]	validation_0-logloss:0.27874	validation_1-logloss:0.28364
# [314]	validation_0-logloss:0.27872	validation_1-logloss:0.28364
# [315]	validation_0-logloss:0.27870	validation_1-logloss:0.28364
# [316]	validation_0-logloss:0.27869	validation_1-logloss:0.28364
# [317]	validation_0-logloss:0.27866	validation_1-logloss:0.28364
# [318]	validation_0-logloss:0.27865	validation_1-logloss:0.28364
# [319]	validation_0-logloss:0.27863	validation_1-logloss:0.28364
# [320]	validation_0-logloss:0.27861	validation_1-logloss:0.28364
# [321]	validation_0-logloss:0.27861	validation_1-logloss:0.28364
# [322]	validation_0-logloss:0.27858	validation_1-logloss:0.28363
# [323]	validation_0-logloss:0.27856	validation_1-logloss:0.28364
# [324]	validation_0-logloss:0.27855	validation_1-logloss:0.28364
# [325]	validation_0-logloss:0.27854	validation_1-logloss:0.28364
# [326]	validation_0-logloss:0.27852	validation_1-logloss:0.28364
# [327]	validation_0-logloss:0.27849	validation_1-logloss:0.28364
# [328]	validation_0-logloss:0.27847	validation_1-logloss:0.28364
# [329]	validation_0-logloss:0.27846	validation_1-logloss:0.28364
# [330]	validation_0-logloss:0.27845	validation_1-logloss:0.28365
# [331]	validation_0-logloss:0.27844	validation_1-logloss:0.28365
# [332]	validation_0-logloss:0.27842	validation_1-logloss:0.28365
# [333]	validation_0-logloss:0.27841	validation_1-logloss:0.28365
# [334]	validation_0-logloss:0.27840	validation_1-logloss:0.28365
# [335]	validation_0-logloss:0.27837	validation_1-logloss:0.28366
# [336]	validation_0-logloss:0.27836	validation_1-logloss:0.28366
# [337]	validation_0-logloss:0.27835	validation_1-logloss:0.28366
# [338]	validation_0-logloss:0.27835	validation_1-logloss:0.28366
# [339]	validation_0-logloss:0.27834	validation_1-logloss:0.28367
# [340]	validation_0-logloss:0.27833	validation_1-logloss:0.28367
# [341]	validation_0-logloss:0.27830	validation_1-logloss:0.28367
# [342]	validation_0-logloss:0.27829	validation_1-logloss:0.28366
# [343]	validation_0-logloss:0.27827	validation_1-logloss:0.28366
# [344]	validation_0-logloss:0.27824	validation_1-logloss:0.28366
# [345]	validation_0-logloss:0.27823	validation_1-logloss:0.28366
# [346]	validation_0-logloss:0.27822	validation_1-logloss:0.28366
# [347]	validation_0-logloss:0.27821	validation_1-logloss:0.28365
# [348]	validation_0-logloss:0.27820	validation_1-logloss:0.28366
# [349]	validation_0-logloss:0.27818	validation_1-logloss:0.28366
# [350]	validation_0-logloss:0.27816	validation_1-logloss:0.28366
# [351]	validation_0-logloss:0.27816	validation_1-logloss:0.28367
# [352]	validation_0-logloss:0.27814	validation_1-logloss:0.28367
# [353]	validation_0-logloss:0.27813	validation_1-logloss:0.28367
# [354]	validation_0-logloss:0.27812	validation_1-logloss:0.28367
# [355]	validation_0-logloss:0.27811	validation_1-logloss:0.28367
# [356]	validation_0-logloss:0.27810	validation_1-logloss:0.28367

# %% [markdown]
# ##### For 10 ML

# %%
# XGBoost with only the kinematic variables of the leptons

iterations_ML = 10

print('ML iteration 1')

# CLASSIFIER
classifier = XGBClassifier(
    n_estimators=2500,
    learning_rate=0.1,
    reg_lambda=0.0,reg_alpha=0.0,
    gamma=0.0,objective='binary:logistic',
    max_depth=5)

ran_ind = np.random.choice(np.arange(len(X_mon_train)), size = len(X_mon_train), replace = True)

# FIT
classifier.fit(X_mon_train[ran_ind],y_mon_train[ran_ind],eval_set=[(X_mon_train[ran_ind], y_mon_train[ran_ind]), (X_mon_val, y_mon_val)],
        eval_metric='logloss',early_stopping_rounds=50,#early stopping
        verbose=True)

# PREDICTIONS
y_pred_xg_aux = classifier.predict_proba(X_mon_test).T[1]
y_pred_xg_auxRE = np.reshape(y_pred_xg_aux, (1,len(y_pred_xg_aux)))


# ROC
fpr_mon_xg, tpr_mon_xg, _ = roc_curve(y_mon_test, y_pred_xg_aux)
roc_auc_xg = auc(fpr_mon_xg, tpr_mon_xg)


# PLOT THE ROC WITH AUC
fig = plt.figure(figsize=(6, 6))
gs = gridspec.GridSpec(1, 1) 
ax0 = plt.subplot(gs[0])
ax0.yaxis.set_ticks_position('both')
ax0.xaxis.set_ticks_position('both')
ax0.tick_params(direction="in",which="both")
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
ax0.minorticks_on()


plt.plot(tpr_mon_xg,1-fpr_mon_xg,label="$f_{1}$, AUC = %0.2f" % roc_auc_xg,color="orange",ls=":",lw=4)
plt.plot([1,0],[0,1],ls=":",color="grey")
plt.xlabel("True Positive Rate",fontsize=16)
plt.ylabel("1 $-$ False Positive Rate",fontsize=16)
plt.legend()
plt.title(r"SSM Z' - XGBoost",fontsize=16)
plt.xlim([0,1])
plt.ylim([0,1])
plt.yticks([0.2,0.4,0.6,0.8,1.])
plt.legend(frameon=False,fontsize=16)
plt.show()




print('\n ########################################\n')





for it in range(1,iterations_ML):

    print('ML iteration ', it)
    
    # CLASSIFIER
    classifier = XGBClassifier(
        n_estimators=2500,
        learning_rate=0.1,
        reg_lambda=0.0,reg_alpha=0.0,
        gamma=0.0,objective='binary:logistic',
        max_depth=5)

    ran_ind = np.random.choice(np.arange(len(X_mon_train)), size = len(X_mon_train), replace = True)

    # FIT
    classifier.fit(X_mon_train[ran_ind],y_mon_train[ran_ind],eval_set=[(X_mon_train[ran_ind], y_mon_train[ran_ind]), (X_mon_val, y_mon_val)],
            eval_metric='logloss',early_stopping_rounds=50,#early stopping
            verbose=True)

    # PREDICTIONS
    y_pred_xg_aux_it = classifier.predict_proba(X_mon_test).T[1]
    y_pred_xg_auxRE_it = np.reshape(y_pred_xg_aux_it, (1,len(y_pred_xg_aux_it)))
    
    y_pred_xg_auxRE = np.concatenate([y_pred_xg_auxRE,y_pred_xg_auxRE_it])


    # ROC
    fpr_mon_xg, tpr_mon_xg, _ = roc_curve(y_mon_test, y_pred_xg_aux)
    roc_auc_xg = auc(fpr_mon_xg, tpr_mon_xg)


    # PLOT THE ROC WITH AUC
    fig = plt.figure(figsize=(6, 6))
    gs = gridspec.GridSpec(1, 1) 
    ax0 = plt.subplot(gs[0])
    ax0.yaxis.set_ticks_position('both')
    ax0.xaxis.set_ticks_position('both')
    ax0.tick_params(direction="in",which="both")
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
    ax0.minorticks_on()


    plt.plot(tpr_mon_xg,1-fpr_mon_xg,label="$f_{1}$, AUC = %0.2f" % roc_auc_xg,color="orange",ls=":",lw=4)
    plt.plot([1,0],[0,1],ls=":",color="grey")
    plt.xlabel("True Positive Rate",fontsize=16)
    plt.ylabel("1 $-$ False Positive Rate",fontsize=16)
    plt.legend()
    plt.title(r"SSM Z' - XGBoost",fontsize=16)
    plt.xlim([0,1])
    plt.ylim([0,1])
    plt.yticks([0.2,0.4,0.6,0.8,1.])
    plt.legend(frameon=False,fontsize=16)
    plt.show()
    
    print('\n ########################################\n')
    
    
y_pred_xg = np.mean(y_pred_xg_auxRE, axis=0)
# Out:
# ML iteration 1
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [0]	validation_0-logloss:0.63982	validation_1-logloss:0.63994
# [1]	validation_0-logloss:0.59607	validation_1-logloss:0.59610
# [2]	validation_0-logloss:0.55906	validation_1-logloss:0.55899
# [3]	validation_0-logloss:0.52813	validation_1-logloss:0.52812
# [4]	validation_0-logloss:0.50161	validation_1-logloss:0.50159
# [5]	validation_0-logloss:0.47912	validation_1-logloss:0.47918
# [6]	validation_0-logloss:0.45894	validation_1-logloss:0.45900
# [7]	validation_0-logloss:0.44196	validation_1-logloss:0.44188
# [8]	validation_0-logloss:0.42689	validation_1-logloss:0.42685
# [9]	validation_0-logloss:0.41359	validation_1-logloss:0.41347
# [10]	validation_0-logloss:0.40178	validation_1-logloss:0.40169
# [11]	validation_0-logloss:0.39140	validation_1-logloss:0.39127
# [12]	validation_0-logloss:0.38204	validation_1-logloss:0.38194
# [13]	validation_0-logloss:0.37401	validation_1-logloss:0.37393
# [14]	validation_0-logloss:0.36699	validation_1-logloss:0.36682
# [15]	validation_0-logloss:0.36048	validation_1-logloss:0.36032
# [16]	validation_0-logloss:0.35439	validation_1-logloss:0.35425
# [17]	validation_0-logloss:0.34912	validation_1-logloss:0.34901
# [18]	validation_0-logloss:0.34447	validation_1-logloss:0.34435
# [19]	validation_0-logloss:0.34018	validation_1-logloss:0.34008
# [20]	validation_0-logloss:0.33560	validation_1-logloss:0.33555
# [21]	validation_0-logloss:0.33217	validation_1-logloss:0.33214
# [22]	validation_0-logloss:0.32819	validation_1-logloss:0.32815
# [23]	validation_0-logloss:0.32466	validation_1-logloss:0.32469
# [24]	validation_0-logloss:0.32184	validation_1-logloss:0.32192
# [25]	validation_0-logloss:0.31972	validation_1-logloss:0.31978
# [26]	validation_0-logloss:0.31761	validation_1-logloss:0.31772
# [27]	validation_0-logloss:0.31511	validation_1-logloss:0.31524
# [28]	validation_0-logloss:0.31316	validation_1-logloss:0.31333
# [29]	validation_0-logloss:0.31138	validation_1-logloss:0.31160
# [30]	validation_0-logloss:0.30940	validation_1-logloss:0.30961
# [31]	validation_0-logloss:0.30806	validation_1-logloss:0.30830
# [32]	validation_0-logloss:0.30674	validation_1-logloss:0.30701
# [33]	validation_0-logloss:0.30525	validation_1-logloss:0.30557
# [34]	validation_0-logloss:0.30426	validation_1-logloss:0.30462
# [35]	validation_0-logloss:0.30315	validation_1-logloss:0.30351
# [36]	validation_0-logloss:0.30219	validation_1-logloss:0.30259
# [37]	validation_0-logloss:0.30125	validation_1-logloss:0.30168
# [38]	validation_0-logloss:0.30007	validation_1-logloss:0.30055
# [39]	validation_0-logloss:0.29920	validation_1-logloss:0.29972
# [40]	validation_0-logloss:0.29852	validation_1-logloss:0.29906
# [41]	validation_0-logloss:0.29763	validation_1-logloss:0.29820
# [42]	validation_0-logloss:0.29700	validation_1-logloss:0.29762
# [43]	validation_0-logloss:0.29617	validation_1-logloss:0.29684
# [44]	validation_0-logloss:0.29557	validation_1-logloss:0.29627
# [45]	validation_0-logloss:0.29498	validation_1-logloss:0.29575
# [46]	validation_0-logloss:0.29441	validation_1-logloss:0.29520
# [47]	validation_0-logloss:0.29394	validation_1-logloss:0.29478
# [48]	validation_0-logloss:0.29358	validation_1-logloss:0.29443
# [49]	validation_0-logloss:0.29296	validation_1-logloss:0.29386
# [50]	validation_0-logloss:0.29251	validation_1-logloss:0.29342
# [51]	validation_0-logloss:0.29189	validation_1-logloss:0.29285
# [52]	validation_0-logloss:0.29145	validation_1-logloss:0.29245
# [53]	validation_0-logloss:0.29103	validation_1-logloss:0.29207
# [54]	validation_0-logloss:0.29070	validation_1-logloss:0.29178
# [55]	validation_0-logloss:0.29033	validation_1-logloss:0.29142
# [56]	validation_0-logloss:0.28986	validation_1-logloss:0.29102
# [57]	validation_0-logloss:0.28944	validation_1-logloss:0.29064
# [58]	validation_0-logloss:0.28923	validation_1-logloss:0.29047
# [59]	validation_0-logloss:0.28878	validation_1-logloss:0.29008
# [60]	validation_0-logloss:0.28845	validation_1-logloss:0.28979
# [61]	validation_0-logloss:0.28798	validation_1-logloss:0.28938
# [62]	validation_0-logloss:0.28765	validation_1-logloss:0.28909
# [63]	validation_0-logloss:0.28738	validation_1-logloss:0.28884
# [64]	validation_0-logloss:0.28703	validation_1-logloss:0.28856
# [65]	validation_0-logloss:0.28683	validation_1-logloss:0.28839
# [66]	validation_0-logloss:0.28657	validation_1-logloss:0.28818
# [67]	validation_0-logloss:0.28629	validation_1-logloss:0.28795
# [68]	validation_0-logloss:0.28608	validation_1-logloss:0.28778
# [69]	validation_0-logloss:0.28592	validation_1-logloss:0.28765
# [70]	validation_0-logloss:0.28578	validation_1-logloss:0.28753
# [71]	validation_0-logloss:0.28557	validation_1-logloss:0.28737
# [72]	validation_0-logloss:0.28541	validation_1-logloss:0.28725
# [73]	validation_0-logloss:0.28523	validation_1-logloss:0.28710
# [74]	validation_0-logloss:0.28510	validation_1-logloss:0.28701
# [75]	validation_0-logloss:0.28484	validation_1-logloss:0.28682
# [76]	validation_0-logloss:0.28473	validation_1-logloss:0.28674
# [77]	validation_0-logloss:0.28460	validation_1-logloss:0.28662
# [78]	validation_0-logloss:0.28445	validation_1-logloss:0.28651
# [79]	validation_0-logloss:0.28434	validation_1-logloss:0.28644
# [80]	validation_0-logloss:0.28419	validation_1-logloss:0.28632
# [81]	validation_0-logloss:0.28407	validation_1-logloss:0.28624
# [82]	validation_0-logloss:0.28390	validation_1-logloss:0.28611
# [83]	validation_0-logloss:0.28382	validation_1-logloss:0.28606
# [84]	validation_0-logloss:0.28367	validation_1-logloss:0.28596
# [85]	validation_0-logloss:0.28360	validation_1-logloss:0.28592
# [86]	validation_0-logloss:0.28351	validation_1-logloss:0.28585
# [87]	validation_0-logloss:0.28340	validation_1-logloss:0.28579
# [88]	validation_0-logloss:0.28334	validation_1-logloss:0.28576
# [89]	validation_0-logloss:0.28323	validation_1-logloss:0.28569
# [90]	validation_0-logloss:0.28316	validation_1-logloss:0.28564
# [91]	validation_0-logloss:0.28309	validation_1-logloss:0.28559
# [92]	validation_0-logloss:0.28304	validation_1-logloss:0.28556
# [93]	validation_0-logloss:0.28292	validation_1-logloss:0.28549
# [94]	validation_0-logloss:0.28283	validation_1-logloss:0.28543
# [95]	validation_0-logloss:0.28275	validation_1-logloss:0.28538
# [96]	validation_0-logloss:0.28263	validation_1-logloss:0.28532
# [97]	validation_0-logloss:0.28257	validation_1-logloss:0.28528
# [98]	validation_0-logloss:0.28250	validation_1-logloss:0.28523
# [99]	validation_0-logloss:0.28245	validation_1-logloss:0.28521
# [100]	validation_0-logloss:0.28240	validation_1-logloss:0.28519
# [101]	validation_0-logloss:0.28232	validation_1-logloss:0.28515
# [102]	validation_0-logloss:0.28225	validation_1-logloss:0.28514
# [103]	validation_0-logloss:0.28219	validation_1-logloss:0.28511
# [104]	validation_0-logloss:0.28215	validation_1-logloss:0.28509
# [105]	validation_0-logloss:0.28206	validation_1-logloss:0.28504
# [106]	validation_0-logloss:0.28202	validation_1-logloss:0.28502
# [107]	validation_0-logloss:0.28191	validation_1-logloss:0.28497
# [108]	validation_0-logloss:0.28187	validation_1-logloss:0.28495
# [109]	validation_0-logloss:0.28184	validation_1-logloss:0.28495
# [110]	validation_0-logloss:0.28176	validation_1-logloss:0.28492
# [111]	validation_0-logloss:0.28172	validation_1-logloss:0.28490
# [112]	validation_0-logloss:0.28166	validation_1-logloss:0.28488
# [113]	validation_0-logloss:0.28157	validation_1-logloss:0.28482
# [114]	validation_0-logloss:0.28151	validation_1-logloss:0.28479
# [115]	validation_0-logloss:0.28147	validation_1-logloss:0.28479
# [116]	validation_0-logloss:0.28144	validation_1-logloss:0.28478
# [117]	validation_0-logloss:0.28135	validation_1-logloss:0.28474
# [118]	validation_0-logloss:0.28131	validation_1-logloss:0.28472
# [119]	validation_0-logloss:0.28126	validation_1-logloss:0.28470
# [120]	validation_0-logloss:0.28121	validation_1-logloss:0.28470
# [121]	validation_0-logloss:0.28117	validation_1-logloss:0.28469
# [122]	validation_0-logloss:0.28114	validation_1-logloss:0.28469
# [123]	validation_0-logloss:0.28110	validation_1-logloss:0.28468
# [124]	validation_0-logloss:0.28102	validation_1-logloss:0.28465
# [125]	validation_0-logloss:0.28095	validation_1-logloss:0.28463
# [126]	validation_0-logloss:0.28092	validation_1-logloss:0.28462
# [127]	validation_0-logloss:0.28087	validation_1-logloss:0.28460
# [128]	validation_0-logloss:0.28084	validation_1-logloss:0.28459
# [129]	validation_0-logloss:0.28079	validation_1-logloss:0.28458
# [130]	validation_0-logloss:0.28073	validation_1-logloss:0.28456
# [131]	validation_0-logloss:0.28072	validation_1-logloss:0.28456
# [132]	validation_0-logloss:0.28068	validation_1-logloss:0.28456
# [133]	validation_0-logloss:0.28064	validation_1-logloss:0.28455
# [134]	validation_0-logloss:0.28056	validation_1-logloss:0.28452
# [135]	validation_0-logloss:0.28052	validation_1-logloss:0.28451
# [136]	validation_0-logloss:0.28048	validation_1-logloss:0.28452
# [137]	validation_0-logloss:0.28041	validation_1-logloss:0.28448
# [138]	validation_0-logloss:0.28036	validation_1-logloss:0.28447
# [139]	validation_0-logloss:0.28032	validation_1-logloss:0.28447
# [140]	validation_0-logloss:0.28030	validation_1-logloss:0.28447
# [141]	validation_0-logloss:0.28025	validation_1-logloss:0.28446
# [142]	validation_0-logloss:0.28023	validation_1-logloss:0.28445
# [143]	validation_0-logloss:0.28018	validation_1-logloss:0.28444
# [144]	validation_0-logloss:0.28015	validation_1-logloss:0.28443
# [145]	validation_0-logloss:0.28010	validation_1-logloss:0.28443
# [146]	validation_0-logloss:0.28006	validation_1-logloss:0.28443
# [147]	validation_0-logloss:0.28004	validation_1-logloss:0.28443
# [148]	validation_0-logloss:0.27999	validation_1-logloss:0.28441
# [149]	validation_0-logloss:0.27997	validation_1-logloss:0.28441
# [150]	validation_0-logloss:0.27995	validation_1-logloss:0.28441
# [151]	validation_0-logloss:0.27994	validation_1-logloss:0.28441
# [152]	validation_0-logloss:0.27988	validation_1-logloss:0.28440
# [153]	validation_0-logloss:0.27982	validation_1-logloss:0.28438
# [154]	validation_0-logloss:0.27980	validation_1-logloss:0.28438
# [155]	validation_0-logloss:0.27976	validation_1-logloss:0.28437
# [156]	validation_0-logloss:0.27972	validation_1-logloss:0.28438
# [157]	validation_0-logloss:0.27969	validation_1-logloss:0.28437
# [158]	validation_0-logloss:0.27964	validation_1-logloss:0.28436
# [159]	validation_0-logloss:0.27962	validation_1-logloss:0.28437
# [160]	validation_0-logloss:0.27959	validation_1-logloss:0.28436
# [161]	validation_0-logloss:0.27958	validation_1-logloss:0.28437
# [162]	validation_0-logloss:0.27954	validation_1-logloss:0.28436
# [163]	validation_0-logloss:0.27949	validation_1-logloss:0.28435
# [164]	validation_0-logloss:0.27946	validation_1-logloss:0.28434
# [165]	validation_0-logloss:0.27942	validation_1-logloss:0.28433
# [166]	validation_0-logloss:0.27938	validation_1-logloss:0.28433
# [167]	validation_0-logloss:0.27934	validation_1-logloss:0.28432
# [168]	validation_0-logloss:0.27931	validation_1-logloss:0.28431
# [169]	validation_0-logloss:0.27929	validation_1-logloss:0.28432
# [170]	validation_0-logloss:0.27926	validation_1-logloss:0.28432
# [171]	validation_0-logloss:0.27923	validation_1-logloss:0.28432
# [172]	validation_0-logloss:0.27920	validation_1-logloss:0.28432
# [173]	validation_0-logloss:0.27919	validation_1-logloss:0.28431
# [174]	validation_0-logloss:0.27916	validation_1-logloss:0.28432
# [175]	validation_0-logloss:0.27914	validation_1-logloss:0.28432
# [176]	validation_0-logloss:0.27910	validation_1-logloss:0.28432
# [177]	validation_0-logloss:0.27908	validation_1-logloss:0.28431
# [178]	validation_0-logloss:0.27905	validation_1-logloss:0.28431
# [179]	validation_0-logloss:0.27901	validation_1-logloss:0.28431
# [180]	validation_0-logloss:0.27899	validation_1-logloss:0.28431
# [181]	validation_0-logloss:0.27894	validation_1-logloss:0.28431
# [182]	validation_0-logloss:0.27891	validation_1-logloss:0.28431
# [183]	validation_0-logloss:0.27885	validation_1-logloss:0.28430
# [184]	validation_0-logloss:0.27881	validation_1-logloss:0.28430
# [185]	validation_0-logloss:0.27875	validation_1-logloss:0.28430
# [186]	validation_0-logloss:0.27871	validation_1-logloss:0.28429
# [187]	validation_0-logloss:0.27870	validation_1-logloss:0.28430
# [188]	validation_0-logloss:0.27865	validation_1-logloss:0.28430
# [189]	validation_0-logloss:0.27862	validation_1-logloss:0.28430
# [190]	validation_0-logloss:0.27858	validation_1-logloss:0.28430
# [191]	validation_0-logloss:0.27856	validation_1-logloss:0.28430
# [192]	validation_0-logloss:0.27855	validation_1-logloss:0.28430
# [193]	validation_0-logloss:0.27852	validation_1-logloss:0.28430
# [194]	validation_0-logloss:0.27851	validation_1-logloss:0.28430
# [195]	validation_0-logloss:0.27849	validation_1-logloss:0.28430
# [196]	validation_0-logloss:0.27848	validation_1-logloss:0.28430
# [197]	validation_0-logloss:0.27846	validation_1-logloss:0.28430
# [198]	validation_0-logloss:0.27842	validation_1-logloss:0.28430
# [199]	validation_0-logloss:0.27838	validation_1-logloss:0.28430
# [200]	validation_0-logloss:0.27834	validation_1-logloss:0.28430
# [201]	validation_0-logloss:0.27831	validation_1-logloss:0.28429
# [202]	validation_0-logloss:0.27825	validation_1-logloss:0.28428
# [203]	validation_0-logloss:0.27821	validation_1-logloss:0.28428
# [204]	validation_0-logloss:0.27816	validation_1-logloss:0.28428
# [205]	validation_0-logloss:0.27813	validation_1-logloss:0.28428
# [206]	validation_0-logloss:0.27810	validation_1-logloss:0.28428
# [207]	validation_0-logloss:0.27806	validation_1-logloss:0.28428
# [208]	validation_0-logloss:0.27802	validation_1-logloss:0.28429
# [209]	validation_0-logloss:0.27798	validation_1-logloss:0.28429
# [210]	validation_0-logloss:0.27794	validation_1-logloss:0.28429
# [211]	validation_0-logloss:0.27793	validation_1-logloss:0.28429
# [212]	validation_0-logloss:0.27791	validation_1-logloss:0.28430
# [213]	validation_0-logloss:0.27789	validation_1-logloss:0.28429
# [214]	validation_0-logloss:0.27784	validation_1-logloss:0.28430
# [215]	validation_0-logloss:0.27781	validation_1-logloss:0.28430
# [216]	validation_0-logloss:0.27777	validation_1-logloss:0.28430
# [217]	validation_0-logloss:0.27774	validation_1-logloss:0.28430
# [218]	validation_0-logloss:0.27771	validation_1-logloss:0.28430
# [219]	validation_0-logloss:0.27769	validation_1-logloss:0.28430
# [220]	validation_0-logloss:0.27765	validation_1-logloss:0.28430
# [221]	validation_0-logloss:0.27764	validation_1-logloss:0.28431
# [222]	validation_0-logloss:0.27762	validation_1-logloss:0.28431
# [223]	validation_0-logloss:0.27760	validation_1-logloss:0.28431
# [224]	validation_0-logloss:0.27754	validation_1-logloss:0.28430
# [225]	validation_0-logloss:0.27752	validation_1-logloss:0.28430
# [226]	validation_0-logloss:0.27749	validation_1-logloss:0.28430
# [227]	validation_0-logloss:0.27745	validation_1-logloss:0.28430
# [228]	validation_0-logloss:0.27742	validation_1-logloss:0.28430
# [229]	validation_0-logloss:0.27740	validation_1-logloss:0.28430
# [230]	validation_0-logloss:0.27738	validation_1-logloss:0.28430
# [231]	validation_0-logloss:0.27736	validation_1-logloss:0.28430
# [232]	validation_0-logloss:0.27733	validation_1-logloss:0.28430
# [233]	validation_0-logloss:0.27729	validation_1-logloss:0.28429
# [234]	validation_0-logloss:0.27725	validation_1-logloss:0.28427
# [235]	validation_0-logloss:0.27724	validation_1-logloss:0.28427
# [236]	validation_0-logloss:0.27720	validation_1-logloss:0.28427
# [237]	validation_0-logloss:0.27719	validation_1-logloss:0.28426
# [238]	validation_0-logloss:0.27718	validation_1-logloss:0.28426
# [239]	validation_0-logloss:0.27715	validation_1-logloss:0.28426
# [240]	validation_0-logloss:0.27712	validation_1-logloss:0.28426
# [241]	validation_0-logloss:0.27710	validation_1-logloss:0.28426
# [242]	validation_0-logloss:0.27708	validation_1-logloss:0.28427
# [243]	validation_0-logloss:0.27707	validation_1-logloss:0.28427
# [244]	validation_0-logloss:0.27705	validation_1-logloss:0.28427
# [245]	validation_0-logloss:0.27704	validation_1-logloss:0.28427
# [246]	validation_0-logloss:0.27703	validation_1-logloss:0.28426
# [247]	validation_0-logloss:0.27700	validation_1-logloss:0.28426
# [248]	validation_0-logloss:0.27698	validation_1-logloss:0.28427
# [249]	validation_0-logloss:0.27695	validation_1-logloss:0.28427
# [250]	validation_0-logloss:0.27692	validation_1-logloss:0.28427
# [251]	validation_0-logloss:0.27690	validation_1-logloss:0.28427
# [252]	validation_0-logloss:0.27685	validation_1-logloss:0.28427
# [253]	validation_0-logloss:0.27682	validation_1-logloss:0.28428
# [254]	validation_0-logloss:0.27681	validation_1-logloss:0.28427
# [255]	validation_0-logloss:0.27675	validation_1-logloss:0.28426
# [256]	validation_0-logloss:0.27672	validation_1-logloss:0.28427
# [257]	validation_0-logloss:0.27669	validation_1-logloss:0.28427
# [258]	validation_0-logloss:0.27665	validation_1-logloss:0.28427
# [259]	validation_0-logloss:0.27662	validation_1-logloss:0.28427
# [260]	validation_0-logloss:0.27660	validation_1-logloss:0.28427
# [261]	validation_0-logloss:0.27656	validation_1-logloss:0.28427
# [262]	validation_0-logloss:0.27652	validation_1-logloss:0.28427
# [263]	validation_0-logloss:0.27648	validation_1-logloss:0.28428
# [264]	validation_0-logloss:0.27648	validation_1-logloss:0.28428
# [265]	validation_0-logloss:0.27646	validation_1-logloss:0.28427
# [266]	validation_0-logloss:0.27643	validation_1-logloss:0.28428
# [267]	validation_0-logloss:0.27642	validation_1-logloss:0.28428
# [268]	validation_0-logloss:0.27638	validation_1-logloss:0.28428
# [269]	validation_0-logloss:0.27635	validation_1-logloss:0.28428
# [270]	validation_0-logloss:0.27632	validation_1-logloss:0.28428
# [271]	validation_0-logloss:0.27631	validation_1-logloss:0.28428
# [272]	validation_0-logloss:0.27630	validation_1-logloss:0.28428
# [273]	validation_0-logloss:0.27628	validation_1-logloss:0.28428
# [274]	validation_0-logloss:0.27625	validation_1-logloss:0.28428
# [275]	validation_0-logloss:0.27622	validation_1-logloss:0.28428
# [276]	validation_0-logloss:0.27619	validation_1-logloss:0.28428
# [277]	validation_0-logloss:0.27614	validation_1-logloss:0.28429
# [278]	validation_0-logloss:0.27611	validation_1-logloss:0.28429
# [279]	validation_0-logloss:0.27607	validation_1-logloss:0.28429
# [280]	validation_0-logloss:0.27606	validation_1-logloss:0.28429
# [281]	validation_0-logloss:0.27602	validation_1-logloss:0.28429
# [282]	validation_0-logloss:0.27599	validation_1-logloss:0.28429
# [283]	validation_0-logloss:0.27595	validation_1-logloss:0.28429
# [284]	validation_0-logloss:0.27593	validation_1-logloss:0.28429
# [285]	validation_0-logloss:0.27590	validation_1-logloss:0.28430
# [286]	validation_0-logloss:0.27589	validation_1-logloss:0.28430
# [287]	validation_0-logloss:0.27585	validation_1-logloss:0.28430
# [288]	validation_0-logloss:0.27584	validation_1-logloss:0.28430
#  ########################################
#
# ML iteration  1
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [0]	validation_0-logloss:0.63985	validation_1-logloss:0.63989
# [1]	validation_0-logloss:0.59584	validation_1-logloss:0.59585
# [2]	validation_0-logloss:0.55913	validation_1-logloss:0.55906
# [3]	validation_0-logloss:0.52801	validation_1-logloss:0.52790
# [4]	validation_0-logloss:0.50142	validation_1-logloss:0.50131
# [5]	validation_0-logloss:0.47860	validation_1-logloss:0.47853
# [6]	validation_0-logloss:0.45871	validation_1-logloss:0.45858
# [7]	validation_0-logloss:0.44201	validation_1-logloss:0.44192
# [8]	validation_0-logloss:0.42683	validation_1-logloss:0.42679
# [9]	validation_0-logloss:0.41323	validation_1-logloss:0.41320
# [10]	validation_0-logloss:0.40161	validation_1-logloss:0.40147
# [11]	validation_0-logloss:0.39103	validation_1-logloss:0.39095
# [12]	validation_0-logloss:0.38233	validation_1-logloss:0.38225
# [13]	validation_0-logloss:0.37411	validation_1-logloss:0.37400
# [14]	validation_0-logloss:0.36679	validation_1-logloss:0.36670
# [15]	validation_0-logloss:0.35986	validation_1-logloss:0.35977
# [16]	validation_0-logloss:0.35384	validation_1-logloss:0.35381
# [17]	validation_0-logloss:0.34869	validation_1-logloss:0.34868
# [18]	validation_0-logloss:0.34388	validation_1-logloss:0.34382
# [19]	validation_0-logloss:0.33935	validation_1-logloss:0.33934
# [20]	validation_0-logloss:0.33536	validation_1-logloss:0.33539
# [21]	validation_0-logloss:0.33193	validation_1-logloss:0.33193
# [22]	validation_0-logloss:0.32786	validation_1-logloss:0.32793
# [23]	validation_0-logloss:0.32524	validation_1-logloss:0.32527
# [24]	validation_0-logloss:0.32253	validation_1-logloss:0.32260
# [25]	validation_0-logloss:0.31953	validation_1-logloss:0.31961
# [26]	validation_0-logloss:0.31673	validation_1-logloss:0.31684
# [27]	validation_0-logloss:0.31405	validation_1-logloss:0.31429
# [28]	validation_0-logloss:0.31223	validation_1-logloss:0.31248
# [29]	validation_0-logloss:0.31075	validation_1-logloss:0.31097
# [30]	validation_0-logloss:0.30878	validation_1-logloss:0.30903
# [31]	validation_0-logloss:0.30695	validation_1-logloss:0.30726
# [32]	validation_0-logloss:0.30553	validation_1-logloss:0.30586
# [33]	validation_0-logloss:0.30415	validation_1-logloss:0.30458
# [34]	validation_0-logloss:0.30316	validation_1-logloss:0.30362
# [35]	validation_0-logloss:0.30197	validation_1-logloss:0.30245
# [36]	validation_0-logloss:0.30065	validation_1-logloss:0.30122
# [37]	validation_0-logloss:0.29960	validation_1-logloss:0.30021
# [38]	validation_0-logloss:0.29883	validation_1-logloss:0.29948
# [39]	validation_0-logloss:0.29792	validation_1-logloss:0.29860
# [40]	validation_0-logloss:0.29736	validation_1-logloss:0.29801
# [41]	validation_0-logloss:0.29645	validation_1-logloss:0.29718
# [42]	validation_0-logloss:0.29582	validation_1-logloss:0.29659
# [43]	validation_0-logloss:0.29511	validation_1-logloss:0.29591
# [44]	validation_0-logloss:0.29462	validation_1-logloss:0.29544
# [45]	validation_0-logloss:0.29390	validation_1-logloss:0.29479
# [46]	validation_0-logloss:0.29336	validation_1-logloss:0.29426
# [47]	validation_0-logloss:0.29279	validation_1-logloss:0.29374
# [48]	validation_0-logloss:0.29226	validation_1-logloss:0.29323
# [49]	validation_0-logloss:0.29195	validation_1-logloss:0.29296
# [50]	validation_0-logloss:0.29155	validation_1-logloss:0.29259
# [51]	validation_0-logloss:0.29095	validation_1-logloss:0.29207
# [52]	validation_0-logloss:0.29048	validation_1-logloss:0.29164
# [53]	validation_0-logloss:0.28994	validation_1-logloss:0.29116
# [54]	validation_0-logloss:0.28960	validation_1-logloss:0.29084
# [55]	validation_0-logloss:0.28926	validation_1-logloss:0.29055
# [56]	validation_0-logloss:0.28883	validation_1-logloss:0.29018
# [57]	validation_0-logloss:0.28851	validation_1-logloss:0.28991
# [58]	validation_0-logloss:0.28824	validation_1-logloss:0.28968
# [59]	validation_0-logloss:0.28789	validation_1-logloss:0.28939
# [60]	validation_0-logloss:0.28768	validation_1-logloss:0.28920
# [61]	validation_0-logloss:0.28745	validation_1-logloss:0.28901
# [62]	validation_0-logloss:0.28713	validation_1-logloss:0.28875
# [63]	validation_0-logloss:0.28679	validation_1-logloss:0.28847
# [64]	validation_0-logloss:0.28655	validation_1-logloss:0.28826
# [65]	validation_0-logloss:0.28622	validation_1-logloss:0.28798
# [66]	validation_0-logloss:0.28606	validation_1-logloss:0.28785
# [67]	validation_0-logloss:0.28583	validation_1-logloss:0.28767
# [68]	validation_0-logloss:0.28559	validation_1-logloss:0.28748
# [69]	validation_0-logloss:0.28539	validation_1-logloss:0.28731
# [70]	validation_0-logloss:0.28520	validation_1-logloss:0.28717
# [71]	validation_0-logloss:0.28507	validation_1-logloss:0.28707
# [72]	validation_0-logloss:0.28490	validation_1-logloss:0.28693
# [73]	validation_0-logloss:0.28473	validation_1-logloss:0.28679
# [74]	validation_0-logloss:0.28456	validation_1-logloss:0.28667
# [75]	validation_0-logloss:0.28441	validation_1-logloss:0.28656
# [76]	validation_0-logloss:0.28427	validation_1-logloss:0.28647
# [77]	validation_0-logloss:0.28411	validation_1-logloss:0.28635
# [78]	validation_0-logloss:0.28397	validation_1-logloss:0.28625
# [79]	validation_0-logloss:0.28385	validation_1-logloss:0.28617
# [80]	validation_0-logloss:0.28373	validation_1-logloss:0.28608
# [81]	validation_0-logloss:0.28359	validation_1-logloss:0.28599
# [82]	validation_0-logloss:0.28345	validation_1-logloss:0.28590
# [83]	validation_0-logloss:0.28331	validation_1-logloss:0.28580
# [84]	validation_0-logloss:0.28321	validation_1-logloss:0.28574
# [85]	validation_0-logloss:0.28314	validation_1-logloss:0.28570
# [86]	validation_0-logloss:0.28300	validation_1-logloss:0.28561
# [87]	validation_0-logloss:0.28289	validation_1-logloss:0.28554
# [88]	validation_0-logloss:0.28280	validation_1-logloss:0.28548
# [89]	validation_0-logloss:0.28273	validation_1-logloss:0.28546
# [90]	validation_0-logloss:0.28264	validation_1-logloss:0.28539
# [91]	validation_0-logloss:0.28259	validation_1-logloss:0.28537
# [92]	validation_0-logloss:0.28251	validation_1-logloss:0.28532
# [93]	validation_0-logloss:0.28243	validation_1-logloss:0.28527
# [94]	validation_0-logloss:0.28237	validation_1-logloss:0.28524
# [95]	validation_0-logloss:0.28227	validation_1-logloss:0.28519
# [96]	validation_0-logloss:0.28219	validation_1-logloss:0.28516
# [97]	validation_0-logloss:0.28209	validation_1-logloss:0.28510
# [98]	validation_0-logloss:0.28202	validation_1-logloss:0.28506
# [99]	validation_0-logloss:0.28196	validation_1-logloss:0.28504
# [100]	validation_0-logloss:0.28188	validation_1-logloss:0.28502
# [101]	validation_0-logloss:0.28183	validation_1-logloss:0.28500
# [102]	validation_0-logloss:0.28172	validation_1-logloss:0.28494
# [103]	validation_0-logloss:0.28166	validation_1-logloss:0.28491
# [104]	validation_0-logloss:0.28159	validation_1-logloss:0.28487
# [105]	validation_0-logloss:0.28150	validation_1-logloss:0.28480
# [106]	validation_0-logloss:0.28143	validation_1-logloss:0.28478
# [107]	validation_0-logloss:0.28137	validation_1-logloss:0.28476
# [108]	validation_0-logloss:0.28127	validation_1-logloss:0.28471
# [109]	validation_0-logloss:0.28122	validation_1-logloss:0.28469
# [110]	validation_0-logloss:0.28118	validation_1-logloss:0.28468
# [111]	validation_0-logloss:0.28112	validation_1-logloss:0.28466
# [112]	validation_0-logloss:0.28106	validation_1-logloss:0.28466
# [113]	validation_0-logloss:0.28097	validation_1-logloss:0.28462
# [114]	validation_0-logloss:0.28091	validation_1-logloss:0.28460
# [115]	validation_0-logloss:0.28087	validation_1-logloss:0.28459
# [116]	validation_0-logloss:0.28081	validation_1-logloss:0.28456
# [117]	validation_0-logloss:0.28075	validation_1-logloss:0.28454
# [118]	validation_0-logloss:0.28072	validation_1-logloss:0.28453
# [119]	validation_0-logloss:0.28069	validation_1-logloss:0.28453
# [120]	validation_0-logloss:0.28065	validation_1-logloss:0.28452
# [121]	validation_0-logloss:0.28060	validation_1-logloss:0.28451
# [122]	validation_0-logloss:0.28052	validation_1-logloss:0.28448
# [123]	validation_0-logloss:0.28047	validation_1-logloss:0.28446
# [124]	validation_0-logloss:0.28045	validation_1-logloss:0.28446
# [125]	validation_0-logloss:0.28040	validation_1-logloss:0.28444
# [126]	validation_0-logloss:0.28033	validation_1-logloss:0.28442
# [127]	validation_0-logloss:0.28031	validation_1-logloss:0.28441
# [128]	validation_0-logloss:0.28026	validation_1-logloss:0.28441
# [129]	validation_0-logloss:0.28021	validation_1-logloss:0.28441
# [130]	validation_0-logloss:0.28014	validation_1-logloss:0.28438
# [131]	validation_0-logloss:0.28011	validation_1-logloss:0.28438
# [132]	validation_0-logloss:0.28006	validation_1-logloss:0.28436
# [133]	validation_0-logloss:0.28004	validation_1-logloss:0.28436
# [134]	validation_0-logloss:0.28000	validation_1-logloss:0.28436
# [135]	validation_0-logloss:0.27997	validation_1-logloss:0.28436
# [136]	validation_0-logloss:0.27993	validation_1-logloss:0.28435
# [137]	validation_0-logloss:0.27987	validation_1-logloss:0.28434
# [138]	validation_0-logloss:0.27982	validation_1-logloss:0.28433
# [139]	validation_0-logloss:0.27978	validation_1-logloss:0.28433
# [140]	validation_0-logloss:0.27975	validation_1-logloss:0.28434
# [141]	validation_0-logloss:0.27970	validation_1-logloss:0.28433
# [142]	validation_0-logloss:0.27967	validation_1-logloss:0.28434
# [143]	validation_0-logloss:0.27959	validation_1-logloss:0.28431
# [144]	validation_0-logloss:0.27954	validation_1-logloss:0.28430
# [145]	validation_0-logloss:0.27951	validation_1-logloss:0.28430
# [146]	validation_0-logloss:0.27948	validation_1-logloss:0.28430
# [147]	validation_0-logloss:0.27943	validation_1-logloss:0.28429
# [148]	validation_0-logloss:0.27939	validation_1-logloss:0.28428
# [149]	validation_0-logloss:0.27936	validation_1-logloss:0.28428
# [150]	validation_0-logloss:0.27932	validation_1-logloss:0.28427
# [151]	validation_0-logloss:0.27926	validation_1-logloss:0.28426
# [152]	validation_0-logloss:0.27923	validation_1-logloss:0.28426
# [153]	validation_0-logloss:0.27921	validation_1-logloss:0.28426
# [154]	validation_0-logloss:0.27918	validation_1-logloss:0.28425
# [155]	validation_0-logloss:0.27914	validation_1-logloss:0.28425
# [156]	validation_0-logloss:0.27911	validation_1-logloss:0.28425
# [157]	validation_0-logloss:0.27909	validation_1-logloss:0.28425
# [158]	validation_0-logloss:0.27902	validation_1-logloss:0.28425
# [159]	validation_0-logloss:0.27898	validation_1-logloss:0.28425
# [160]	validation_0-logloss:0.27896	validation_1-logloss:0.28425
# [161]	validation_0-logloss:0.27892	validation_1-logloss:0.28424
# [162]	validation_0-logloss:0.27890	validation_1-logloss:0.28424
# [163]	validation_0-logloss:0.27887	validation_1-logloss:0.28424
# [164]	validation_0-logloss:0.27882	validation_1-logloss:0.28424
# [165]	validation_0-logloss:0.27879	validation_1-logloss:0.28425
# [166]	validation_0-logloss:0.27875	validation_1-logloss:0.28424
# [167]	validation_0-logloss:0.27872	validation_1-logloss:0.28424
# [168]	validation_0-logloss:0.27871	validation_1-logloss:0.28423
# [169]	validation_0-logloss:0.27867	validation_1-logloss:0.28422
# [170]	validation_0-logloss:0.27862	validation_1-logloss:0.28422
# [171]	validation_0-logloss:0.27859	validation_1-logloss:0.28422
# [172]	validation_0-logloss:0.27856	validation_1-logloss:0.28422
# [173]	validation_0-logloss:0.27854	validation_1-logloss:0.28422
# [174]	validation_0-logloss:0.27852	validation_1-logloss:0.28422
# [175]	validation_0-logloss:0.27847	validation_1-logloss:0.28421
# [176]	validation_0-logloss:0.27843	validation_1-logloss:0.28421
# [177]	validation_0-logloss:0.27839	validation_1-logloss:0.28420
# [178]	validation_0-logloss:0.27837	validation_1-logloss:0.28419
# [179]	validation_0-logloss:0.27835	validation_1-logloss:0.28419
# [180]	validation_0-logloss:0.27830	validation_1-logloss:0.28419
# [181]	validation_0-logloss:0.27826	validation_1-logloss:0.28420
# [182]	validation_0-logloss:0.27821	validation_1-logloss:0.28420
# [183]	validation_0-logloss:0.27818	validation_1-logloss:0.28420
# [184]	validation_0-logloss:0.27816	validation_1-logloss:0.28420
# [185]	validation_0-logloss:0.27815	validation_1-logloss:0.28420
# [186]	validation_0-logloss:0.27812	validation_1-logloss:0.28421
# [187]	validation_0-logloss:0.27809	validation_1-logloss:0.28420
# [188]	validation_0-logloss:0.27804	validation_1-logloss:0.28421
# [189]	validation_0-logloss:0.27802	validation_1-logloss:0.28420
# [190]	validation_0-logloss:0.27797	validation_1-logloss:0.28420
# [191]	validation_0-logloss:0.27793	validation_1-logloss:0.28420
# [192]	validation_0-logloss:0.27791	validation_1-logloss:0.28420
# [193]	validation_0-logloss:0.27789	validation_1-logloss:0.28419
# [194]	validation_0-logloss:0.27787	validation_1-logloss:0.28419
# [195]	validation_0-logloss:0.27783	validation_1-logloss:0.28419
# [196]	validation_0-logloss:0.27778	validation_1-logloss:0.28420
# [197]	validation_0-logloss:0.27775	validation_1-logloss:0.28420
# [198]	validation_0-logloss:0.27772	validation_1-logloss:0.28420
# [199]	validation_0-logloss:0.27769	validation_1-logloss:0.28420
# [200]	validation_0-logloss:0.27765	validation_1-logloss:0.28420
# [201]	validation_0-logloss:0.27762	validation_1-logloss:0.28420
# [202]	validation_0-logloss:0.27759	validation_1-logloss:0.28420
# [203]	validation_0-logloss:0.27756	validation_1-logloss:0.28420
# [204]	validation_0-logloss:0.27752	validation_1-logloss:0.28420
# [205]	validation_0-logloss:0.27750	validation_1-logloss:0.28420
# [206]	validation_0-logloss:0.27745	validation_1-logloss:0.28420
# [207]	validation_0-logloss:0.27742	validation_1-logloss:0.28420
# [208]	validation_0-logloss:0.27738	validation_1-logloss:0.28420
# [209]	validation_0-logloss:0.27734	validation_1-logloss:0.28420
# [210]	validation_0-logloss:0.27729	validation_1-logloss:0.28420
# [211]	validation_0-logloss:0.27726	validation_1-logloss:0.28420
# [212]	validation_0-logloss:0.27722	validation_1-logloss:0.28421
# [213]	validation_0-logloss:0.27719	validation_1-logloss:0.28421
# [214]	validation_0-logloss:0.27717	validation_1-logloss:0.28421
# [215]	validation_0-logloss:0.27713	validation_1-logloss:0.28421
# [216]	validation_0-logloss:0.27711	validation_1-logloss:0.28421
# [217]	validation_0-logloss:0.27707	validation_1-logloss:0.28421
# [218]	validation_0-logloss:0.27702	validation_1-logloss:0.28422
# [219]	validation_0-logloss:0.27699	validation_1-logloss:0.28422
# [220]	validation_0-logloss:0.27696	validation_1-logloss:0.28423
# [221]	validation_0-logloss:0.27693	validation_1-logloss:0.28422
# [222]	validation_0-logloss:0.27688	validation_1-logloss:0.28423
# [223]	validation_0-logloss:0.27686	validation_1-logloss:0.28423
# [224]	validation_0-logloss:0.27683	validation_1-logloss:0.28423
# [225]	validation_0-logloss:0.27682	validation_1-logloss:0.28423
# [226]	validation_0-logloss:0.27679	validation_1-logloss:0.28422
# [227]	validation_0-logloss:0.27676	validation_1-logloss:0.28423
# [228]	validation_0-logloss:0.27673	validation_1-logloss:0.28423
# [229]	validation_0-logloss:0.27672	validation_1-logloss:0.28423
# [230]	validation_0-logloss:0.27667	validation_1-logloss:0.28423
# [231]	validation_0-logloss:0.27664	validation_1-logloss:0.28423
# [232]	validation_0-logloss:0.27660	validation_1-logloss:0.28423
# [233]	validation_0-logloss:0.27655	validation_1-logloss:0.28423
# [234]	validation_0-logloss:0.27654	validation_1-logloss:0.28423
# [235]	validation_0-logloss:0.27652	validation_1-logloss:0.28423
# [236]	validation_0-logloss:0.27648	validation_1-logloss:0.28423
# [237]	validation_0-logloss:0.27646	validation_1-logloss:0.28424
# [238]	validation_0-logloss:0.27644	validation_1-logloss:0.28423
# [239]	validation_0-logloss:0.27642	validation_1-logloss:0.28423
# [240]	validation_0-logloss:0.27639	validation_1-logloss:0.28424
# [241]	validation_0-logloss:0.27637	validation_1-logloss:0.28424
# [242]	validation_0-logloss:0.27633	validation_1-logloss:0.28424
# [243]	validation_0-logloss:0.27630	validation_1-logloss:0.28424
# [244]	validation_0-logloss:0.27626	validation_1-logloss:0.28424
#  ########################################
#
# ML iteration  2
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [0]	validation_0-logloss:0.64009	validation_1-logloss:0.64004
# [1]	validation_0-logloss:0.59617	validation_1-logloss:0.59597
# [2]	validation_0-logloss:0.55936	validation_1-logloss:0.55922
# [3]	validation_0-logloss:0.52849	validation_1-logloss:0.52827
# [4]	validation_0-logloss:0.50159	validation_1-logloss:0.50137
# [5]	validation_0-logloss:0.47867	validation_1-logloss:0.47844
# [6]	validation_0-logloss:0.45862	validation_1-logloss:0.45847
# [7]	validation_0-logloss:0.44167	validation_1-logloss:0.44146
# [8]	validation_0-logloss:0.42624	validation_1-logloss:0.42603
# [9]	validation_0-logloss:0.41342	validation_1-logloss:0.41315
# [10]	validation_0-logloss:0.40170	validation_1-logloss:0.40143
# [11]	validation_0-logloss:0.39110	validation_1-logloss:0.39087
# [12]	validation_0-logloss:0.38177	validation_1-logloss:0.38160
# [13]	validation_0-logloss:0.37366	validation_1-logloss:0.37350
# [14]	validation_0-logloss:0.36669	validation_1-logloss:0.36651
# [15]	validation_0-logloss:0.36005	validation_1-logloss:0.35988
# [16]	validation_0-logloss:0.35382	validation_1-logloss:0.35363
# [17]	validation_0-logloss:0.34879	validation_1-logloss:0.34857
# [18]	validation_0-logloss:0.34398	validation_1-logloss:0.34379
# [19]	validation_0-logloss:0.33962	validation_1-logloss:0.33948
# [20]	validation_0-logloss:0.33589	validation_1-logloss:0.33574
# [21]	validation_0-logloss:0.33269	validation_1-logloss:0.33248
# [22]	validation_0-logloss:0.32875	validation_1-logloss:0.32855
# [23]	validation_0-logloss:0.32592	validation_1-logloss:0.32573
# [24]	validation_0-logloss:0.32245	validation_1-logloss:0.32239
# [25]	validation_0-logloss:0.32016	validation_1-logloss:0.32012
# [26]	validation_0-logloss:0.31780	validation_1-logloss:0.31784
# [27]	validation_0-logloss:0.31533	validation_1-logloss:0.31539
# [28]	validation_0-logloss:0.31316	validation_1-logloss:0.31322
# [29]	validation_0-logloss:0.31130	validation_1-logloss:0.31145
# [30]	validation_0-logloss:0.30980	validation_1-logloss:0.30996
# [31]	validation_0-logloss:0.30814	validation_1-logloss:0.30836
# [32]	validation_0-logloss:0.30648	validation_1-logloss:0.30675
# [33]	validation_0-logloss:0.30523	validation_1-logloss:0.30556
# [34]	validation_0-logloss:0.30386	validation_1-logloss:0.30419
# [35]	validation_0-logloss:0.30257	validation_1-logloss:0.30296
# [36]	validation_0-logloss:0.30137	validation_1-logloss:0.30180
# [37]	validation_0-logloss:0.30025	validation_1-logloss:0.30071
# [38]	validation_0-logloss:0.29940	validation_1-logloss:0.29992
# [39]	validation_0-logloss:0.29860	validation_1-logloss:0.29918
# [40]	validation_0-logloss:0.29780	validation_1-logloss:0.29840
# [41]	validation_0-logloss:0.29713	validation_1-logloss:0.29779
# [42]	validation_0-logloss:0.29655	validation_1-logloss:0.29722
# [43]	validation_0-logloss:0.29578	validation_1-logloss:0.29648
# [44]	validation_0-logloss:0.29501	validation_1-logloss:0.29576
# [45]	validation_0-logloss:0.29439	validation_1-logloss:0.29518
# [46]	validation_0-logloss:0.29388	validation_1-logloss:0.29470
# [47]	validation_0-logloss:0.29347	validation_1-logloss:0.29432
# [48]	validation_0-logloss:0.29303	validation_1-logloss:0.29391
# [49]	validation_0-logloss:0.29258	validation_1-logloss:0.29344
# [50]	validation_0-logloss:0.29200	validation_1-logloss:0.29294
# [51]	validation_0-logloss:0.29141	validation_1-logloss:0.29240
# [52]	validation_0-logloss:0.29103	validation_1-logloss:0.29205
# [53]	validation_0-logloss:0.29061	validation_1-logloss:0.29169
# [54]	validation_0-logloss:0.29015	validation_1-logloss:0.29129
# [55]	validation_0-logloss:0.28981	validation_1-logloss:0.29100
# [56]	validation_0-logloss:0.28924	validation_1-logloss:0.29049
# [57]	validation_0-logloss:0.28894	validation_1-logloss:0.29023
# [58]	validation_0-logloss:0.28858	validation_1-logloss:0.28993
# [59]	validation_0-logloss:0.28820	validation_1-logloss:0.28962
# [60]	validation_0-logloss:0.28779	validation_1-logloss:0.28926
# [61]	validation_0-logloss:0.28741	validation_1-logloss:0.28890
# [62]	validation_0-logloss:0.28716	validation_1-logloss:0.28869
# [63]	validation_0-logloss:0.28693	validation_1-logloss:0.28849
# [64]	validation_0-logloss:0.28655	validation_1-logloss:0.28820
# [65]	validation_0-logloss:0.28634	validation_1-logloss:0.28801
# [66]	validation_0-logloss:0.28614	validation_1-logloss:0.28784
# [67]	validation_0-logloss:0.28595	validation_1-logloss:0.28767
# [68]	validation_0-logloss:0.28570	validation_1-logloss:0.28748
# [69]	validation_0-logloss:0.28556	validation_1-logloss:0.28736
# [70]	validation_0-logloss:0.28542	validation_1-logloss:0.28725
# [71]	validation_0-logloss:0.28519	validation_1-logloss:0.28708
# [72]	validation_0-logloss:0.28504	validation_1-logloss:0.28698
# [73]	validation_0-logloss:0.28493	validation_1-logloss:0.28690
# [74]	validation_0-logloss:0.28481	validation_1-logloss:0.28679
# [75]	validation_0-logloss:0.28465	validation_1-logloss:0.28668
# [76]	validation_0-logloss:0.28447	validation_1-logloss:0.28655
# [77]	validation_0-logloss:0.28432	validation_1-logloss:0.28644
# [78]	validation_0-logloss:0.28419	validation_1-logloss:0.28634
# [79]	validation_0-logloss:0.28406	validation_1-logloss:0.28626
# [80]	validation_0-logloss:0.28390	validation_1-logloss:0.28615
# [81]	validation_0-logloss:0.28379	validation_1-logloss:0.28610
# [82]	validation_0-logloss:0.28368	validation_1-logloss:0.28602
# [83]	validation_0-logloss:0.28359	validation_1-logloss:0.28596
# [84]	validation_0-logloss:0.28349	validation_1-logloss:0.28589
# [85]	validation_0-logloss:0.28340	validation_1-logloss:0.28583
# [86]	validation_0-logloss:0.28326	validation_1-logloss:0.28574
# [87]	validation_0-logloss:0.28311	validation_1-logloss:0.28563
# [88]	validation_0-logloss:0.28302	validation_1-logloss:0.28558
# [89]	validation_0-logloss:0.28292	validation_1-logloss:0.28553
# [90]	validation_0-logloss:0.28288	validation_1-logloss:0.28551
# [91]	validation_0-logloss:0.28280	validation_1-logloss:0.28545
# [92]	validation_0-logloss:0.28274	validation_1-logloss:0.28543
# [93]	validation_0-logloss:0.28267	validation_1-logloss:0.28540
# [94]	validation_0-logloss:0.28254	validation_1-logloss:0.28533
# [95]	validation_0-logloss:0.28247	validation_1-logloss:0.28530
# [96]	validation_0-logloss:0.28241	validation_1-logloss:0.28526
# [97]	validation_0-logloss:0.28234	validation_1-logloss:0.28523
# [98]	validation_0-logloss:0.28227	validation_1-logloss:0.28520
# [99]	validation_0-logloss:0.28220	validation_1-logloss:0.28518
# [100]	validation_0-logloss:0.28213	validation_1-logloss:0.28517
# [101]	validation_0-logloss:0.28205	validation_1-logloss:0.28513
# [102]	validation_0-logloss:0.28198	validation_1-logloss:0.28510
# [103]	validation_0-logloss:0.28188	validation_1-logloss:0.28504
# [104]	validation_0-logloss:0.28181	validation_1-logloss:0.28502
# [105]	validation_0-logloss:0.28174	validation_1-logloss:0.28499
# [106]	validation_0-logloss:0.28168	validation_1-logloss:0.28497
# [107]	validation_0-logloss:0.28161	validation_1-logloss:0.28495
# [108]	validation_0-logloss:0.28155	validation_1-logloss:0.28494
# [109]	validation_0-logloss:0.28151	validation_1-logloss:0.28492
# [110]	validation_0-logloss:0.28144	validation_1-logloss:0.28492
# [111]	validation_0-logloss:0.28138	validation_1-logloss:0.28488
# [112]	validation_0-logloss:0.28133	validation_1-logloss:0.28486
# [113]	validation_0-logloss:0.28128	validation_1-logloss:0.28485
# [114]	validation_0-logloss:0.28124	validation_1-logloss:0.28484
# [115]	validation_0-logloss:0.28119	validation_1-logloss:0.28483
# [116]	validation_0-logloss:0.28113	validation_1-logloss:0.28482
# [117]	validation_0-logloss:0.28109	validation_1-logloss:0.28479
# [118]	validation_0-logloss:0.28106	validation_1-logloss:0.28478
# [119]	validation_0-logloss:0.28101	validation_1-logloss:0.28476
# [120]	validation_0-logloss:0.28097	validation_1-logloss:0.28476
# [121]	validation_0-logloss:0.28093	validation_1-logloss:0.28474
# [122]	validation_0-logloss:0.28084	validation_1-logloss:0.28470
# [123]	validation_0-logloss:0.28080	validation_1-logloss:0.28469
# [124]	validation_0-logloss:0.28077	validation_1-logloss:0.28468
# [125]	validation_0-logloss:0.28071	validation_1-logloss:0.28466
# [126]	validation_0-logloss:0.28067	validation_1-logloss:0.28465
# [127]	validation_0-logloss:0.28065	validation_1-logloss:0.28464
# [128]	validation_0-logloss:0.28062	validation_1-logloss:0.28464
# [129]	validation_0-logloss:0.28058	validation_1-logloss:0.28464
# [130]	validation_0-logloss:0.28052	validation_1-logloss:0.28463
# [131]	validation_0-logloss:0.28043	validation_1-logloss:0.28459
# [132]	validation_0-logloss:0.28039	validation_1-logloss:0.28458
# [133]	validation_0-logloss:0.28036	validation_1-logloss:0.28457
# [134]	validation_0-logloss:0.28031	validation_1-logloss:0.28456
# [135]	validation_0-logloss:0.28027	validation_1-logloss:0.28455
# [136]	validation_0-logloss:0.28023	validation_1-logloss:0.28455
# [137]	validation_0-logloss:0.28018	validation_1-logloss:0.28454
# [138]	validation_0-logloss:0.28014	validation_1-logloss:0.28453
# [139]	validation_0-logloss:0.28008	validation_1-logloss:0.28454
# [140]	validation_0-logloss:0.28005	validation_1-logloss:0.28453
# [141]	validation_0-logloss:0.28003	validation_1-logloss:0.28453
# [142]	validation_0-logloss:0.27998	validation_1-logloss:0.28454
# [143]	validation_0-logloss:0.27995	validation_1-logloss:0.28453
# [144]	validation_0-logloss:0.27988	validation_1-logloss:0.28451
# [145]	validation_0-logloss:0.27985	validation_1-logloss:0.28450
# [146]	validation_0-logloss:0.27980	validation_1-logloss:0.28450
# [147]	validation_0-logloss:0.27976	validation_1-logloss:0.28449
# [148]	validation_0-logloss:0.27973	validation_1-logloss:0.28448
# [149]	validation_0-logloss:0.27970	validation_1-logloss:0.28448
# [150]	validation_0-logloss:0.27963	validation_1-logloss:0.28447
# [151]	validation_0-logloss:0.27960	validation_1-logloss:0.28447
# [152]	validation_0-logloss:0.27955	validation_1-logloss:0.28447
# [153]	validation_0-logloss:0.27953	validation_1-logloss:0.28446
# [154]	validation_0-logloss:0.27949	validation_1-logloss:0.28446
# [155]	validation_0-logloss:0.27946	validation_1-logloss:0.28446
# [156]	validation_0-logloss:0.27944	validation_1-logloss:0.28446
# [157]	validation_0-logloss:0.27938	validation_1-logloss:0.28443
# [158]	validation_0-logloss:0.27934	validation_1-logloss:0.28443
# [159]	validation_0-logloss:0.27930	validation_1-logloss:0.28443
# [160]	validation_0-logloss:0.27925	validation_1-logloss:0.28441
# [161]	validation_0-logloss:0.27923	validation_1-logloss:0.28442
# [162]	validation_0-logloss:0.27920	validation_1-logloss:0.28441
# [163]	validation_0-logloss:0.27914	validation_1-logloss:0.28442
# [164]	validation_0-logloss:0.27911	validation_1-logloss:0.28441
# [165]	validation_0-logloss:0.27907	validation_1-logloss:0.28440
# [166]	validation_0-logloss:0.27905	validation_1-logloss:0.28440
# [167]	validation_0-logloss:0.27903	validation_1-logloss:0.28439
# [168]	validation_0-logloss:0.27901	validation_1-logloss:0.28440
# [169]	validation_0-logloss:0.27897	validation_1-logloss:0.28439
# [170]	validation_0-logloss:0.27895	validation_1-logloss:0.28439
# [171]	validation_0-logloss:0.27892	validation_1-logloss:0.28438
# [172]	validation_0-logloss:0.27889	validation_1-logloss:0.28438
# [173]	validation_0-logloss:0.27884	validation_1-logloss:0.28437
# [174]	validation_0-logloss:0.27879	validation_1-logloss:0.28438
# [175]	validation_0-logloss:0.27875	validation_1-logloss:0.28437
# [176]	validation_0-logloss:0.27871	validation_1-logloss:0.28437
# [177]	validation_0-logloss:0.27870	validation_1-logloss:0.28436
# [178]	validation_0-logloss:0.27867	validation_1-logloss:0.28437
# [179]	validation_0-logloss:0.27864	validation_1-logloss:0.28437
# [180]	validation_0-logloss:0.27863	validation_1-logloss:0.28437
# [181]	validation_0-logloss:0.27859	validation_1-logloss:0.28437
# [182]	validation_0-logloss:0.27857	validation_1-logloss:0.28437
# [183]	validation_0-logloss:0.27852	validation_1-logloss:0.28437
# ...
# [250]	validation_0-logloss:0.27572	validation_1-logloss:0.28443
# [251]	validation_0-logloss:0.27570	validation_1-logloss:0.28443
# [252]	validation_0-logloss:0.27568	validation_1-logloss:0.28443
# [253]	validation_0-logloss:0.27565	validation_1-logloss:0.28443
# [254]	validation_0-logloss:0.27564	validation_1-logloss:0.28443
# [255]	validation_0-logloss:0.27561	validation_1-logloss:0.28443
# [256]	validation_0-logloss:0.27560	validation_1-logloss:0.28443
#  ########################################
#
# ML iteration  9
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [0]	validation_0-logloss:0.63999	validation_1-logloss:0.63980
# [1]	validation_0-logloss:0.59588	validation_1-logloss:0.59582
# [2]	validation_0-logloss:0.55872	validation_1-logloss:0.55868
# [3]	validation_0-logloss:0.52771	validation_1-logloss:0.52748
# [4]	validation_0-logloss:0.50097	validation_1-logloss:0.50074
# [5]	validation_0-logloss:0.47823	validation_1-logloss:0.47792
# [6]	validation_0-logloss:0.45873	validation_1-logloss:0.45850
# [7]	validation_0-logloss:0.44148	validation_1-logloss:0.44122
# [8]	validation_0-logloss:0.42669	validation_1-logloss:0.42643
# [9]	validation_0-logloss:0.41312	validation_1-logloss:0.41286
# [10]	validation_0-logloss:0.40168	validation_1-logloss:0.40130
# [11]	validation_0-logloss:0.39113	validation_1-logloss:0.39082
# [12]	validation_0-logloss:0.38222	validation_1-logloss:0.38182
# [13]	validation_0-logloss:0.37383	validation_1-logloss:0.37347
# [14]	validation_0-logloss:0.36690	validation_1-logloss:0.36650
# [15]	validation_0-logloss:0.36033	validation_1-logloss:0.35997
# [16]	validation_0-logloss:0.35451	validation_1-logloss:0.35419
# [17]	validation_0-logloss:0.34921	validation_1-logloss:0.34887
# [18]	validation_0-logloss:0.34451	validation_1-logloss:0.34418
# [19]	validation_0-logloss:0.33994	validation_1-logloss:0.33966
# [20]	validation_0-logloss:0.33598	validation_1-logloss:0.33568
# [21]	validation_0-logloss:0.33252	validation_1-logloss:0.33228
# [22]	validation_0-logloss:0.32867	validation_1-logloss:0.32846
# [23]	validation_0-logloss:0.32607	validation_1-logloss:0.32584
# [24]	validation_0-logloss:0.32325	validation_1-logloss:0.32310
# [25]	validation_0-logloss:0.32028	validation_1-logloss:0.32012
# [26]	validation_0-logloss:0.31822	validation_1-logloss:0.31807
# [27]	validation_0-logloss:0.31599	validation_1-logloss:0.31589
# [28]	validation_0-logloss:0.31416	validation_1-logloss:0.31409
# [29]	validation_0-logloss:0.31211	validation_1-logloss:0.31202
# [30]	validation_0-logloss:0.31054	validation_1-logloss:0.31045
# [31]	validation_0-logloss:0.30850	validation_1-logloss:0.30846
# [32]	validation_0-logloss:0.30717	validation_1-logloss:0.30716
# [33]	validation_0-logloss:0.30603	validation_1-logloss:0.30606
# [34]	validation_0-logloss:0.30437	validation_1-logloss:0.30444
# [35]	validation_0-logloss:0.30317	validation_1-logloss:0.30325
# [36]	validation_0-logloss:0.30199	validation_1-logloss:0.30207
# [37]	validation_0-logloss:0.30085	validation_1-logloss:0.30098
# [38]	validation_0-logloss:0.29989	validation_1-logloss:0.30008
# [39]	validation_0-logloss:0.29918	validation_1-logloss:0.29940
# [40]	validation_0-logloss:0.29830	validation_1-logloss:0.29855
# [41]	validation_0-logloss:0.29771	validation_1-logloss:0.29796
# [42]	validation_0-logloss:0.29685	validation_1-logloss:0.29714
# [43]	validation_0-logloss:0.29629	validation_1-logloss:0.29658
# [44]	validation_0-logloss:0.29565	validation_1-logloss:0.29597
# [45]	validation_0-logloss:0.29484	validation_1-logloss:0.29524
# [46]	validation_0-logloss:0.29429	validation_1-logloss:0.29469
# [47]	validation_0-logloss:0.29363	validation_1-logloss:0.29409
# [48]	validation_0-logloss:0.29317	validation_1-logloss:0.29366
# [49]	validation_0-logloss:0.29281	validation_1-logloss:0.29331
# [50]	validation_0-logloss:0.29222	validation_1-logloss:0.29277
# [51]	validation_0-logloss:0.29176	validation_1-logloss:0.29238
# [52]	validation_0-logloss:0.29142	validation_1-logloss:0.29205
# [53]	validation_0-logloss:0.29092	validation_1-logloss:0.29158
# [54]	validation_0-logloss:0.29058	validation_1-logloss:0.29130
# [55]	validation_0-logloss:0.29022	validation_1-logloss:0.29099
# [56]	validation_0-logloss:0.28975	validation_1-logloss:0.29057
# [57]	validation_0-logloss:0.28927	validation_1-logloss:0.29015
# [58]	validation_0-logloss:0.28891	validation_1-logloss:0.28984
# [59]	validation_0-logloss:0.28854	validation_1-logloss:0.28954
# [60]	validation_0-logloss:0.28831	validation_1-logloss:0.28935
# [61]	validation_0-logloss:0.28797	validation_1-logloss:0.28907
# [62]	validation_0-logloss:0.28769	validation_1-logloss:0.28882
# [63]	validation_0-logloss:0.28747	validation_1-logloss:0.28864
# [64]	validation_0-logloss:0.28720	validation_1-logloss:0.28840
# [65]	validation_0-logloss:0.28695	validation_1-logloss:0.28820
# [66]	validation_0-logloss:0.28674	validation_1-logloss:0.28803
# [67]	validation_0-logloss:0.28651	validation_1-logloss:0.28782
# [68]	validation_0-logloss:0.28633	validation_1-logloss:0.28768
# [69]	validation_0-logloss:0.28598	validation_1-logloss:0.28740
# [70]	validation_0-logloss:0.28584	validation_1-logloss:0.28730
# [71]	validation_0-logloss:0.28570	validation_1-logloss:0.28718
# [72]	validation_0-logloss:0.28544	validation_1-logloss:0.28698
# [73]	validation_0-logloss:0.28526	validation_1-logloss:0.28684
# [74]	validation_0-logloss:0.28507	validation_1-logloss:0.28672
# [75]	validation_0-logloss:0.28494	validation_1-logloss:0.28663
# [76]	validation_0-logloss:0.28482	validation_1-logloss:0.28654
# [77]	validation_0-logloss:0.28462	validation_1-logloss:0.28637
# [78]	validation_0-logloss:0.28448	validation_1-logloss:0.28627
# [79]	validation_0-logloss:0.28436	validation_1-logloss:0.28618
# [80]	validation_0-logloss:0.28416	validation_1-logloss:0.28604
# [81]	validation_0-logloss:0.28403	validation_1-logloss:0.28595
# [82]	validation_0-logloss:0.28393	validation_1-logloss:0.28589
# [83]	validation_0-logloss:0.28379	validation_1-logloss:0.28578
# [84]	validation_0-logloss:0.28371	validation_1-logloss:0.28574
# [85]	validation_0-logloss:0.28358	validation_1-logloss:0.28566
# [86]	validation_0-logloss:0.28350	validation_1-logloss:0.28561
# [87]	validation_0-logloss:0.28335	validation_1-logloss:0.28552
# [88]	validation_0-logloss:0.28326	validation_1-logloss:0.28546
# [89]	validation_0-logloss:0.28318	validation_1-logloss:0.28542
# [90]	validation_0-logloss:0.28310	validation_1-logloss:0.28537
# [91]	validation_0-logloss:0.28302	validation_1-logloss:0.28532
# [92]	validation_0-logloss:0.28295	validation_1-logloss:0.28529
# [93]	validation_0-logloss:0.28289	validation_1-logloss:0.28525
# [94]	validation_0-logloss:0.28282	validation_1-logloss:0.28522
# [95]	validation_0-logloss:0.28274	validation_1-logloss:0.28518
# [96]	validation_0-logloss:0.28261	validation_1-logloss:0.28510
# [97]	validation_0-logloss:0.28254	validation_1-logloss:0.28505
# [98]	validation_0-logloss:0.28246	validation_1-logloss:0.28502
# [99]	validation_0-logloss:0.28239	validation_1-logloss:0.28499
# [100]	validation_0-logloss:0.28232	validation_1-logloss:0.28497
# [101]	validation_0-logloss:0.28225	validation_1-logloss:0.28493
# [102]	validation_0-logloss:0.28218	validation_1-logloss:0.28491
# [103]	validation_0-logloss:0.28212	validation_1-logloss:0.28489
# [104]	validation_0-logloss:0.28208	validation_1-logloss:0.28488
# [105]	validation_0-logloss:0.28202	validation_1-logloss:0.28485
# [106]	validation_0-logloss:0.28196	validation_1-logloss:0.28483
# [107]	validation_0-logloss:0.28191	validation_1-logloss:0.28482
# [108]	validation_0-logloss:0.28185	validation_1-logloss:0.28479
# [109]	validation_0-logloss:0.28181	validation_1-logloss:0.28479
# [110]	validation_0-logloss:0.28178	validation_1-logloss:0.28478
# [111]	validation_0-logloss:0.28171	validation_1-logloss:0.28477
# [112]	validation_0-logloss:0.28159	validation_1-logloss:0.28470
# [113]	validation_0-logloss:0.28156	validation_1-logloss:0.28470
# [114]	validation_0-logloss:0.28152	validation_1-logloss:0.28467
# [115]	validation_0-logloss:0.28146	validation_1-logloss:0.28464
# [116]	validation_0-logloss:0.28136	validation_1-logloss:0.28459
# [117]	validation_0-logloss:0.28131	validation_1-logloss:0.28458
# [118]	validation_0-logloss:0.28127	validation_1-logloss:0.28458
# [119]	validation_0-logloss:0.28124	validation_1-logloss:0.28458
# [120]	validation_0-logloss:0.28121	validation_1-logloss:0.28458
# [121]	validation_0-logloss:0.28112	validation_1-logloss:0.28455
# [122]	validation_0-logloss:0.28108	validation_1-logloss:0.28455
# [123]	validation_0-logloss:0.28105	validation_1-logloss:0.28454
# [124]	validation_0-logloss:0.28099	validation_1-logloss:0.28452
# [125]	validation_0-logloss:0.28094	validation_1-logloss:0.28451
# [126]	validation_0-logloss:0.28092	validation_1-logloss:0.28452
# [127]	validation_0-logloss:0.28086	validation_1-logloss:0.28450
# [128]	validation_0-logloss:0.28082	validation_1-logloss:0.28449
# [129]	validation_0-logloss:0.28078	validation_1-logloss:0.28447
# [130]	validation_0-logloss:0.28074	validation_1-logloss:0.28447
# [131]	validation_0-logloss:0.28070	validation_1-logloss:0.28447
# [132]	validation_0-logloss:0.28067	validation_1-logloss:0.28447
# [133]	validation_0-logloss:0.28063	validation_1-logloss:0.28447
# [134]	validation_0-logloss:0.28058	validation_1-logloss:0.28446
# [135]	validation_0-logloss:0.28048	validation_1-logloss:0.28443
# [136]	validation_0-logloss:0.28044	validation_1-logloss:0.28442
# [137]	validation_0-logloss:0.28042	validation_1-logloss:0.28442
# [138]	validation_0-logloss:0.28035	validation_1-logloss:0.28440
# [139]	validation_0-logloss:0.28032	validation_1-logloss:0.28440
# [140]	validation_0-logloss:0.28029	validation_1-logloss:0.28439
# [141]	validation_0-logloss:0.28024	validation_1-logloss:0.28438
# [142]	validation_0-logloss:0.28020	validation_1-logloss:0.28437
# [143]	validation_0-logloss:0.28014	validation_1-logloss:0.28436
# [144]	validation_0-logloss:0.28009	validation_1-logloss:0.28436
# [145]	validation_0-logloss:0.28006	validation_1-logloss:0.28436
# [146]	validation_0-logloss:0.28001	validation_1-logloss:0.28434
# [147]	validation_0-logloss:0.27999	validation_1-logloss:0.28434
# [148]	validation_0-logloss:0.27993	validation_1-logloss:0.28432
# [149]	validation_0-logloss:0.27991	validation_1-logloss:0.28432
# [150]	validation_0-logloss:0.27986	validation_1-logloss:0.28431
# [151]	validation_0-logloss:0.27982	validation_1-logloss:0.28432
# [152]	validation_0-logloss:0.27976	validation_1-logloss:0.28429
# [153]	validation_0-logloss:0.27972	validation_1-logloss:0.28429
# [154]	validation_0-logloss:0.27968	validation_1-logloss:0.28429
# [155]	validation_0-logloss:0.27965	validation_1-logloss:0.28429
# [156]	validation_0-logloss:0.27964	validation_1-logloss:0.28429
# [157]	validation_0-logloss:0.27962	validation_1-logloss:0.28429
# [158]	validation_0-logloss:0.27958	validation_1-logloss:0.28429
# [159]	validation_0-logloss:0.27952	validation_1-logloss:0.28428
# [160]	validation_0-logloss:0.27947	validation_1-logloss:0.28428
# [161]	validation_0-logloss:0.27944	validation_1-logloss:0.28428
# [162]	validation_0-logloss:0.27938	validation_1-logloss:0.28426
# [163]	validation_0-logloss:0.27936	validation_1-logloss:0.28426
# [164]	validation_0-logloss:0.27932	validation_1-logloss:0.28424
# [165]	validation_0-logloss:0.27929	validation_1-logloss:0.28425
# [166]	validation_0-logloss:0.27924	validation_1-logloss:0.28425
# [167]	validation_0-logloss:0.27921	validation_1-logloss:0.28425
# [168]	validation_0-logloss:0.27919	validation_1-logloss:0.28425
# [169]	validation_0-logloss:0.27917	validation_1-logloss:0.28425
# [170]	validation_0-logloss:0.27916	validation_1-logloss:0.28425
# [171]	validation_0-logloss:0.27913	validation_1-logloss:0.28426
# [172]	validation_0-logloss:0.27908	validation_1-logloss:0.28425
# [173]	validation_0-logloss:0.27904	validation_1-logloss:0.28424
# [174]	validation_0-logloss:0.27901	validation_1-logloss:0.28425
# [175]	validation_0-logloss:0.27898	validation_1-logloss:0.28425
# [176]	validation_0-logloss:0.27894	validation_1-logloss:0.28425
# [177]	validation_0-logloss:0.27892	validation_1-logloss:0.28425
# [178]	validation_0-logloss:0.27891	validation_1-logloss:0.28425
# [179]	validation_0-logloss:0.27888	validation_1-logloss:0.28424
# [180]	validation_0-logloss:0.27883	validation_1-logloss:0.28424
# [181]	validation_0-logloss:0.27880	validation_1-logloss:0.28424
# [182]	validation_0-logloss:0.27879	validation_1-logloss:0.28424
# [183]	validation_0-logloss:0.27874	validation_1-logloss:0.28425
# [184]	validation_0-logloss:0.27870	validation_1-logloss:0.28425
# [185]	validation_0-logloss:0.27866	validation_1-logloss:0.28425
# [186]	validation_0-logloss:0.27864	validation_1-logloss:0.28426
# [187]	validation_0-logloss:0.27864	validation_1-logloss:0.28426
# [188]	validation_0-logloss:0.27861	validation_1-logloss:0.28426
# [189]	validation_0-logloss:0.27856	validation_1-logloss:0.28427
# [190]	validation_0-logloss:0.27852	validation_1-logloss:0.28426
# [191]	validation_0-logloss:0.27848	validation_1-logloss:0.28426
# [192]	validation_0-logloss:0.27846	validation_1-logloss:0.28427
# [193]	validation_0-logloss:0.27844	validation_1-logloss:0.28427
# [194]	validation_0-logloss:0.27839	validation_1-logloss:0.28426
# [195]	validation_0-logloss:0.27835	validation_1-logloss:0.28426
# [196]	validation_0-logloss:0.27830	validation_1-logloss:0.28426
# [197]	validation_0-logloss:0.27824	validation_1-logloss:0.28425
# [198]	validation_0-logloss:0.27820	validation_1-logloss:0.28426
# [199]	validation_0-logloss:0.27817	validation_1-logloss:0.28426
# [200]	validation_0-logloss:0.27816	validation_1-logloss:0.28427
# [201]	validation_0-logloss:0.27812	validation_1-logloss:0.28427
# [202]	validation_0-logloss:0.27808	validation_1-logloss:0.28426
# [203]	validation_0-logloss:0.27806	validation_1-logloss:0.28426
# [204]	validation_0-logloss:0.27803	validation_1-logloss:0.28427
# [205]	validation_0-logloss:0.27800	validation_1-logloss:0.28427
# [206]	validation_0-logloss:0.27799	validation_1-logloss:0.28427
# [207]	validation_0-logloss:0.27795	validation_1-logloss:0.28428
# [208]	validation_0-logloss:0.27790	validation_1-logloss:0.28427
# [209]	validation_0-logloss:0.27787	validation_1-logloss:0.28428
# [210]	validation_0-logloss:0.27782	validation_1-logloss:0.28427
# [211]	validation_0-logloss:0.27780	validation_1-logloss:0.28428
# [212]	validation_0-logloss:0.27774	validation_1-logloss:0.28427
# [213]	validation_0-logloss:0.27771	validation_1-logloss:0.28427
# [214]	validation_0-logloss:0.27767	validation_1-logloss:0.28428
# [215]	validation_0-logloss:0.27763	validation_1-logloss:0.28428
# [216]	validation_0-logloss:0.27762	validation_1-logloss:0.28428
# [217]	validation_0-logloss:0.27759	validation_1-logloss:0.28428
# [218]	validation_0-logloss:0.27754	validation_1-logloss:0.28428
# [219]	validation_0-logloss:0.27752	validation_1-logloss:0.28429
# [220]	validation_0-logloss:0.27750	validation_1-logloss:0.28429
# [221]	validation_0-logloss:0.27749	validation_1-logloss:0.28428
# [222]	validation_0-logloss:0.27747	validation_1-logloss:0.28428
# [223]	validation_0-logloss:0.27744	validation_1-logloss:0.28428
# [224]	validation_0-logloss:0.27739	validation_1-logloss:0.28426
# [225]	validation_0-logloss:0.27737	validation_1-logloss:0.28427
# [226]	validation_0-logloss:0.27735	validation_1-logloss:0.28426
# [227]	validation_0-logloss:0.27732	validation_1-logloss:0.28426
# [228]	validation_0-logloss:0.27728	validation_1-logloss:0.28426
# [229]	validation_0-logloss:0.27725	validation_1-logloss:0.28426
# [230]	validation_0-logloss:0.27725	validation_1-logloss:0.28426
#  ########################################

# %%
# XGBoost with the kinematic variables of the leptons

########################
# CLASSIFICATION SCORE #
########################

# Outputs for validation data set

pred_XG_SM_1ML = []
pred_XG_NP_1ML = []

for i in range(len(y_mon_test)):
    if y_mon_test[i] == 0:
        pred_XG_SM_1ML.append(y_pred_xg_1ML[i])
    else:
        pred_XG_NP_1ML.append(y_pred_xg_1ML[i])
        
        
print('Classification score (1ML):')
        
weights = np.ones_like(pred_XG_SM_1ML)/float(len(pred_XG_SM_1ML))
nSM, binsSM, patchesSM = plt.hist(pred_XG_SM_1ML, 100, weights=weights, range=[0,1], histtype='step', color='firebrick', linewidth=2, label='Background')

weights = np.ones_like(pred_XG_NP_1ML)/float(len(pred_XG_NP_1ML))
nNP, binsNP, patchesNP = plt.hist(pred_XG_NP_1ML, 100, weights=weights, range=[0,1], histtype='step', color='forestgreen', linewidth=2, label='Signal')

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("Classication score (XGBoost)",fontsize=15)
plt.ylabel("Fraction of events",fontsize=14)
plt.grid()
plt.legend(fontsize=12)
plt.title('Multivariate monian distributions, $\mathcal{N}_{2}$', fontsize=14)
#plt.savefig('images/' + '2monian-output.pdf', format="pdf", bbox_inches="tight")
plt.show()




# Outputs for validation data set

pred_XG_SM = []
pred_XG_NP = []

for i in range(len(y_mon_test)):
    if y_mon_test[i] == 0:
        pred_XG_SM.append(y_pred_xg[i])
    else:
        pred_XG_NP.append(y_pred_xg[i])
        
        
print('Classification score (10ML):')
        
weights = np.ones_like(pred_XG_SM)/float(len(pred_XG_SM))
nSM, binsSM, patchesSM = plt.hist(pred_XG_SM, 100, weights=weights, range=[0,1], histtype='step', color='firebrick', linewidth=2, label='Background')

weights = np.ones_like(pred_XG_NP)/float(len(pred_XG_NP))
nNP, binsNP, patchesNP = plt.hist(pred_XG_NP, 100, weights=weights, range=[0,1], histtype='step', color='forestgreen', linewidth=2, label='Signal')

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("Classication score (XGBoost)",fontsize=15)
plt.ylabel("Fraction of events",fontsize=14)
plt.grid()
plt.legend(fontsize=12)
plt.title('Multivariate monian distributions, $\mathcal{N}_{2}$', fontsize=14)
#plt.savefig('images/' + '2monian-output.pdf', format="pdf", bbox_inches="tight")
plt.show()
# Out:
# Classification score (1ML):
# Classification score (10ML):

# %% [markdown]
# ## METHODS

# %% [markdown]
# ### 0. Ensembles characteristics

# %%
##############
# PARAMETERS #
##############

# requested number of ensembles
n_ensembles = 5000

# number of expected background events per ensemble
B_expected = 5000

# ratio S_expected/B_expected (signal ratio)
SB_ratio = [0.0006, 0.001, 0.0016, 0.0025, 0.005, 0.0075, 0.01, 0.025]





# SOME USEFUL DERIVATED PARAMETERS:

# S_expected:
S_expected = [ int(SB_ratio[iii]*B_expected) for iii in range(len(SB_ratio)) ]
print(S_expected)

# S/\sqrt{B}
SsqrtB = [ S_expected[iii]/(B_expected)**0.5 for iii in range(len(SB_ratio)) ]
# Out:
# [2, 5, 8, 12, 25, 37, 50, 125]

# %% [markdown]
# ### 1. BIN LOG LIKELIHOOD

# %%
# 1st variable: invariant mass
background_X_1 = invariant_mass_eeSM
signal_X_1 = invariant_mass_eeSSMZprime

N_B = len(background_X_1)
N_S = len(signal_X_1)

# bins
logbins = [2000.0, 2200.0, 2500.0, 2850.0, 3250.0, 3750.0, 4350.0, 5000.0, 5750.0, 6600.0, 7500.0, 8750.0, 10000.0, 11500.0, 13000.0, 20000.0]

# %%
#################################
# BINNED POISSON LOG-LIKELIHOOD #
#################################


store_Z_bins = []
store_Z_bins_logbins = []


for iii in range(len(SB_ratio)):

    print('B_expected: ', B_expected)
    print('S_expected: ', S_expected[iii])
    print(r'S/$\sqrt{B}$: ', SsqrtB[iii])

    # Les't use an integer number of possible ensembles
    N_ensembles_back = int(N_B / B_expected)
    N_events_back = N_ensembles_back * B_expected

    N_ensembles_sig = int(N_S / S_expected[iii])
    N_events_sig = N_ensembles_sig * S_expected[iii]


    #Let's find out the expected number of B and S events in each bin:

    # bin the parameter space of all background events
    hist_back, binedges_back = np.histogramdd([background_X_1[:N_events_back]], bins=(100), range = [[2000,20000]])
    # now divide by the number of possible ensembles
    back_prom = hist_back.T.ravel()/N_ensembles_back

    # same for signal
    hist_sig, binedges_sig = np.histogramdd([signal_X_1[:N_events_sig]], bins=(100), range = [[2000,20000]])
    sig_prom = hist_sig.T.ravel()/N_ensembles_sig

        

    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    back_prom_noceros = []
    for i in range(len(back_prom)):
        if back_prom[i]!=0:
            back_prom_noceros.append(back_prom[i])

    min_back = min(back_prom_noceros)

    # replace the zeros
    for i in range(len(back_prom)):
        if back_prom[i]==0:
            back_prom[i] = min_back

    # then the signif Z^binned-Asimov:
    Z_bins = ( 2* sum( ( back_prom * np.log( back_prom/(sig_prom + back_prom) ) ) + sig_prom ) )**0.5

    store_Z_bins.append(Z_bins)

    print('Z_bins : ', Z_bins)
    

    
    ############
    # LOG BINS #
    ############
    #Let's find out the expected number of B and S events in each bin:

    # bin the parameter space of all background events
    hist_back, binedges_back = np.histogramdd([background_X_1[:N_events_back]], bins=[logbins])
    # now divide by the number of possible ensembles
    back_prom = hist_back.T.ravel()/N_ensembles_back

    # same for signal
    hist_sig, binedges_sig = np.histogramdd([signal_X_1[:N_events_sig]], bins=[logbins])
    sig_prom = hist_sig.T.ravel()/N_ensembles_sig

        

    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    back_prom_noceros = []
    for i in range(len(back_prom)):
        if back_prom[i]!=0:
            back_prom_noceros.append(back_prom[i])

    min_back = min(back_prom_noceros)

    # replace the zeros
    for i in range(len(back_prom)):
        if back_prom[i]==0:
            back_prom[i] = min_back

    # then the signif Z^binned-Asimov:
    Z_bins_logbins = ( 2* sum( ( back_prom * np.log( back_prom/(sig_prom + back_prom) ) ) + sig_prom ) )**0.5

    store_Z_bins_logbins.append(Z_bins_logbins)

    print('Z_bins_logbins : ', Z_bins_logbins)
    
    
    
    print('\n ----------------------------------- \n')
# Out:
# B_expected:  5000
# S_expected:  2
# S/$\sqrt{B}$:  0.0282842712474619
# Z_bins :  0.5662920175149203
# Z_bins_logbins :  0.5055324555585907
#
#  -----------------------------------
#
# B_expected:  5000
# S_expected:  5
# S/$\sqrt{B}$:  0.07071067811865475
# Z_bins :  1.2594436981974313
# Z_bins_logbins :  1.156234043966104
#
#  -----------------------------------
#
# B_expected:  5000
# S_expected:  8
# S/$\sqrt{B}$:  0.1131370849898476
# Z_bins :  1.8431317286440372
# Z_bins_logbins :  1.7198752746805874
#
#  -----------------------------------
#
# B_expected:  5000
# S_expected:  12
# S/$\sqrt{B}$:  0.1697056274847714
# Z_bins :  2.5161567215640885
# Z_bins_logbins :  2.3797030175337506
#
#  -----------------------------------
#
# B_expected:  5000
# S_expected:  25
# S/$\sqrt{B}$:  0.35355339059327373
# Z_bins :  4.25088814387028
# Z_bins_logbins :  4.101588516848113
#
#  -----------------------------------
#
# B_expected:  5000
# S_expected:  37
# S/$\sqrt{B}$:  0.5232590180780452
# Z_bins :  5.522005937372217
# Z_bins_logbins :  5.369580329520027
#
#  -----------------------------------
#
# B_expected:  5000
# S_expected:  50
# S/$\sqrt{B}$:  0.7071067811865475
# Z_bins :  6.700449402521481
# Z_bins_logbins :  6.545967913718435
#
#  -----------------------------------
#
# B_expected:  5000
# S_expected:  125
# S/$\sqrt{B}$:  1.7677669529663687
# Z_bins :  11.689944503157342
# Z_bins_logbins :  11.527094538921911
#
#  -----------------------------------

# %%
print(store_Z_bins)
print(store_Z_bins_logbins)
# Out:
# [0.5662920175149203, 1.2594436981974313, 1.8431317286440372, 2.5161567215640885, 4.25088814387028, 5.522005937372217, 6.700449402521481, 11.689944503157342]
# [0.5055324555585907, 1.156234043966104, 1.7198752746805874, 2.3797030175337506, 4.101588516848113, 5.369580329520027, 6.545967913718435, 11.527094538921911]

# %%
store_Z_bins = [0.5662920175149203, 1.2594436981974313, 1.8431317286440372, 2.5161567215640885, 4.25088814387028, 5.522005937372217, 6.700449402521481, 11.689944503157342]

store_Z_bins_logbins = [0.5055324555585907, 1.156234043966104, 1.7198752746805874, 2.3797030175337506, 4.101588516848113, 5.369580329520027, 6.545967913718435, 11.527094538921911]

# %%
#########
# PLOTS #
#########

posX = []

for i in range(len(SB_ratio)):
    posX.append( (B_expected*SB_ratio[i]) / ( B_expected )**0.5 )


    
plt.figure()
lw = 2

plt.plot(posX, store_Z_bins, '-ok', color='blue', lw=lw, label='100 Linear Binned Likelihood') 
plt.plot(posX, store_Z_bins_logbins, '-ok', color='lightblue', lw=lw, label='15 Log Binned Likelihood')

#plt.xlim([0.5, 10])
#plt.ylim([-0.5, 7.5])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=14)
plt.ylabel('$Z_{\mu}$ (exclusion)', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title('<B> per ensemble: %0.2d' % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()
# Out:
# <ipython-input-6-3340ebf10fa5>:15: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins, '-ok', color='blue', lw=lw, label='100 Linear Binned Likelihood')
# <ipython-input-6-3340ebf10fa5>:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_logbins, '-ok', color='lightblue', lw=lw, label='15 Log Binned Likelihood')

# %% [markdown]
# ### 2. Binned OUTPUT and MLL Asimov

# %%
#################################
# MLL Asimov-like #
#################################


store_Z_bins_XG = []

store_Z_bins_XG_15bins = []
store_Z_bins_XG_15bins_1ML = []

store_Z_bins_XG_15bins_eq = []
store_Z_bins_XG_15bins_eq_1ML = []


for iii in range(len(SB_ratio)):

    print('B_expected: ', B_expected)
    print('S_expected: ', S_expected[iii])
    print(r'S/$\sqrt{B}$: ', SsqrtB[iii])

    # Les't find the number of possible ensembles
    N_ensembles_back = len(pred_XG_SM) / B_expected
    N_ensembles_sig = len(pred_XG_NP) / S_expected[iii]



    #Let's find out the expected number of B and S events in each bin:
 
    # bin the parameter space of all background events
    hist_back, binedges_back = np.histogramdd([pred_XG_SM], bins=(100), range = [[0,1]])
    
    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    hist_back_noceros = []
    for i in range(len(hist_back)):
        if hist_back[i]!=0:
            hist_back_noceros.append(hist_back[i])

    min_back = min(hist_back_noceros)

    # replace the zeros
    for i in range(len(hist_back)):
        if hist_back[i]==0:
            hist_back[i] = min_back
    
    # now divide by the number of possible ensembles
    back_prom = hist_back/N_ensembles_back
    # normalized (sum=1)
    back_norm = hist_back/np.sum(hist_back)

    
    
    # same for signal
    hist_sig, binedges_sig = np.histogramdd([pred_XG_NP], bins=(100), range = [[0,1]])
    sig_prom = hist_sig/N_ensembles_sig
    sig_norm = hist_sig/np.sum(hist_sig)
        


    ##########################################
    # BINNED LIKELIHOOD of CLASSIFIER OUTPUT #
    ##########################################

    # then the signif Z^binned-Asimov:
    Z_bins_XG = ( 2* sum( ( back_prom * np.log( back_prom / (sig_prom+back_prom) ) ) + sig_prom ) )**0.5

    store_Z_bins_XG.append(Z_bins_XG)

    print('Z_bins_XG : ', Z_bins_XG)
    
    
    
    
    
    ######################
    # linear bins, 10 ML #
    ######################
    
    #Let's find out the expected number of B and S events in each bin:
 
    # bin the parameter space of all background events
    hist_back, binedges_back = np.histogramdd([pred_XG_SM], bins=(15), range = [[0,1]])
    
    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    hist_back_noceros = []
    for i in range(len(hist_back)):
        if hist_back[i]!=0:
            hist_back_noceros.append(hist_back[i])

    min_back = min(hist_back_noceros)

    # replace the zeros
    for i in range(len(hist_back)):
        if hist_back[i]==0:
            hist_back[i] = min_back
    
    # now divide by the number of possible ensembles
    back_prom = hist_back/N_ensembles_back
    # normalized (sum=1)
    back_norm = hist_back/np.sum(hist_back)

    
    
    # same for signal
    hist_sig, binedges_sig = np.histogramdd([pred_XG_NP], bins=(15), range = [[0,1]])
    sig_prom = hist_sig/N_ensembles_sig
    sig_norm = hist_sig/np.sum(hist_sig)
        


    ##########################################
    # BINNED LIKELIHOOD of CLASSIFIER OUTPUT #
    ##########################################

    # then the signif Z^binned-Asimov:
    Z_bins_XG_15bins = ( 2* sum( ( back_prom * np.log( back_prom / (sig_prom+back_prom) ) ) + sig_prom ) )**0.5

    store_Z_bins_XG_15bins.append(Z_bins_XG_15bins)

    print('Z_bins_XG_15bins : ', Z_bins_XG_15bins)
    
    
    
    
    
    ######################
    # linear bins, 1  ML #
    ######################
    
    #Let's find out the expected number of B and S events in each bin:
 
    # bin the parameter space of all background events
    hist_back, binedges_back = np.histogramdd([pred_XG_SM_1ML], bins=(15), range = [[0,1]])
    
    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    hist_back_noceros = []
    for i in range(len(hist_back)):
        if hist_back[i]!=0:
            hist_back_noceros.append(hist_back[i])

    min_back = min(hist_back_noceros)

    # replace the zeros
    for i in range(len(hist_back)):
        if hist_back[i]==0:
            hist_back[i] = min_back
    
    # now divide by the number of possible ensembles
    back_prom = hist_back/N_ensembles_back
    # normalized (sum=1)
    back_norm = hist_back/np.sum(hist_back)

    
    
    # same for signal
    hist_sig, binedges_sig = np.histogramdd([pred_XG_NP], bins=(15), range = [[0,1]])
    sig_prom = hist_sig/N_ensembles_sig
    sig_norm = hist_sig/np.sum(hist_sig)
        


    ##########################################
    # BINNED LIKELIHOOD of CLASSIFIER OUTPUT #
    ##########################################

    # then the signif Z^binned-Asimov:
    Z_bins_XG_15bins_1ML = ( 2* sum( ( back_prom * np.log( back_prom / (sig_prom+back_prom) ) ) + sig_prom ) )**0.5

    store_Z_bins_XG_15bins_1ML.append(Z_bins_XG_15bins_1ML)

    print('Z_bins_XG_15bins_1ML : ', Z_bins_XG_15bins_1ML)
    
    
    
    
    
    ##########################
    # non linear bins, 10 ML #
    ##########################
    
    #Let's find out the expected number of B and S events in each bin:
    # same number of B events per bin
    bin_edges_same = pd.qcut(pd.DataFrame(pred_XG_SM)[0], q = 15, precision=0, retbins = True)[1]
 
    # bin the parameter space of all background events
    hist_back, binedges_back = np.histogramdd([pred_XG_SM], bins=[bin_edges_same], range = [[0,1]])
    
    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    hist_back_noceros = []
    for i in range(len(hist_back)):
        if hist_back[i]!=0:
            hist_back_noceros.append(hist_back[i])

    min_back = min(hist_back_noceros)

    # replace the zeros
    for i in range(len(hist_back)):
        if hist_back[i]==0:
            hist_back[i] = min_back
    
    # now divide by the number of possible ensembles
    back_prom = hist_back/N_ensembles_back
    # normalized (sum=1)
    back_norm = hist_back/np.sum(hist_back)

    
    
    # same for signal
    hist_sig, binedges_sig = np.histogramdd([pred_XG_NP], bins=[bin_edges_same], range = [[0,1]])
    sig_prom = hist_sig/N_ensembles_sig
    sig_norm = hist_sig/np.sum(hist_sig)
        


    ##########################################
    # BINNED LIKELIHOOD of CLASSIFIER OUTPUT #
    ##########################################

    # then the signif Z^binned-Asimov:
    Z_bins_XG_15bins_eq = ( 2* sum( ( back_prom * np.log( back_prom / (sig_prom+back_prom) ) ) + sig_prom ) )**0.5

    store_Z_bins_XG_15bins_eq.append(Z_bins_XG_15bins_eq)

    print('Z_bins_XG_15bins_eq : ', Z_bins_XG_15bins_eq)
    
    
    
    
    
    ##########################
    # non linear bins, 1  ML #
    ##########################
    
    #Let's find out the expected number of B and S events in each bin:
    # same number of B events per bin
    bin_edges_same = pd.qcut(pd.DataFrame(pred_XG_SM_1ML)[0], q = 15, precision=0, retbins = True)[1]
 
    # bin the parameter space of all background events
    hist_back, binedges_back = np.histogramdd([pred_XG_SM_1ML], bins=[bin_edges_same], range = [[0,1]])
    
    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    hist_back_noceros = []
    for i in range(len(hist_back)):
        if hist_back[i]!=0:
            hist_back_noceros.append(hist_back[i])

    min_back = min(hist_back_noceros)

    # replace the zeros
    for i in range(len(hist_back)):
        if hist_back[i]==0:
            hist_back[i] = min_back
    
    # now divide by the number of possible ensembles
    back_prom = hist_back/N_ensembles_back
    # normalized (sum=1)
    back_norm = hist_back/np.sum(hist_back)

    
    
    # same for signal
    hist_sig, binedges_sig = np.histogramdd([pred_XG_NP_1ML], bins=[bin_edges_same], range = [[0,1]])
    sig_prom = hist_sig/N_ensembles_sig
    sig_norm = hist_sig/np.sum(hist_sig)
        


    ##########################################
    # BINNED LIKELIHOOD of CLASSIFIER OUTPUT #
    ##########################################

    # then the signif Z^binned-Asimov:
    Z_bins_XG_15bins_eq_1ML = ( 2* sum( ( back_prom * np.log( back_prom / (sig_prom+back_prom) ) ) + sig_prom ) )**0.5

    store_Z_bins_XG_15bins_eq_1ML.append(Z_bins_XG_15bins_eq_1ML)

    print('Z_bins_XG_15bins_eq_1ML : ', Z_bins_XG_15bins_eq_1ML)


        
    print('\n ----------------------------------------- \n')
# Out:
# B_expected:  5000
# S_expected:  2
# S/$\sqrt{B}$:  0.0282842712474619
# Z_bins_XG :  0.45616705906485044
# Z_bins_XG_15bins :  0.2925153957714496
# Z_bins_XG_15bins_1ML :  0.28843046621639556
# Z_bins_XG_15bins_eq :  0.09143643156834629
# Z_bins_XG_15bins_eq_1ML :  0.0914021717888956
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  5
# S/$\sqrt{B}$:  0.07071067811865475
# Z_bins_XG :  1.06024817459429
# Z_bins_XG_15bins :  0.7110187950310004
# Z_bins_XG_15bins_1ML :  0.7016168362666699
# Z_bins_XG_15bins_eq :  0.22802597634580105
# Z_bins_XG_15bins_eq_1ML :  0.22794074624097438
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  8
# S/$\sqrt{B}$:  0.1131370849898476
# Z_bins_XG :  1.5949958041694656
# Z_bins_XG_15bins :  1.1081222256499326
# Z_bins_XG_15bins_1ML :  1.094190373422215
# Z_bins_XG_15bins_eq :  0.36394520330717467
# Z_bins_XG_15bins_eq_1ML :  0.363809497432828
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  12
# S/$\sqrt{B}$:  0.1697056274847714
# Z_bins_XG :  2.230966641945092
# Z_bins_XG_15bins :  1.6088749753984757
# Z_bins_XG_15bins_1ML :  1.589861334109271
# Z_bins_XG_15bins_eq :  0.5441429903593713
# Z_bins_XG_15bins_eq_1ML :  0.543940736391258
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  25
# S/$\sqrt{B}$:  0.35355339059327373
# Z_bins_XG :  3.9233558135832873
# Z_bins_XG_15bins :  3.0600466279995633
# Z_bins_XG_15bins_1ML :  3.0295114243533594
# Z_bins_XG_15bins_eq :  1.121898897515157
# Z_bins_XG_15bins_eq_1ML :  1.1214860595271872
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  37
# S/$\sqrt{B}$:  0.5232590180780452
# Z_bins_XG :  5.187565349312186
# Z_bins_XG_15bins :  4.224701105473196
# Z_bins_XG_15bins_1ML :  4.187530304055226
# Z_bins_XG_15bins_eq :  1.6449272625538234
# Z_bins_XG_15bins_eq_1ML :  1.644327322865729
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  50
# S/$\sqrt{B}$:  0.7071067811865475
# Z_bins_XG :  6.3678158084056715
# Z_bins_XG_15bins :  5.352847065066797
# Z_bins_XG_15bins_1ML :  5.3108447173088
# Z_bins_XG_15bins_eq :  2.200958231113595
# Z_bins_XG_15bins_eq_1ML :  2.2001629046695044
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  125
# S/$\sqrt{B}$:  1.7677669529663687
# Z_bins_XG :  11.392628958131683
# Z_bins_XG_15bins :  10.369981689375955
# Z_bins_XG_15bins_1ML :  10.317436672016242
# Z_bins_XG_15bins_eq :  5.2190956586208905
# Z_bins_XG_15bins_eq_1ML :  5.217296564829512
#
#  -----------------------------------------

# %%
print(store_Z_bins_XG)

print(store_Z_bins_XG_15bins)
print(store_Z_bins_XG_15bins_1ML)

print(store_Z_bins_XG_15bins_eq)
print(store_Z_bins_XG_15bins_eq_1ML)
# Out:
# [0.45616705906485044, 1.06024817459429, 1.5949958041694656, 2.230966641945092, 3.9233558135832873, 5.187565349312186, 6.3678158084056715, 11.392628958131683]
# [0.2925153957714496, 0.7110187950310004, 1.1081222256499326, 1.6088749753984757, 3.0600466279995633, 4.224701105473196, 5.352847065066797, 10.369981689375955]
# [0.28843046621639556, 0.7016168362666699, 1.094190373422215, 1.589861334109271, 3.0295114243533594, 4.187530304055226, 5.3108447173088, 10.317436672016242]
# [0.09143643156834629, 0.22802597634580105, 0.36394520330717467, 0.5441429903593713, 1.121898897515157, 1.6449272625538234, 2.200958231113595, 5.2190956586208905]
# [0.0914021717888956, 0.22794074624097438, 0.363809497432828, 0.543940736391258, 1.1214860595271872, 1.644327322865729, 2.2001629046695044, 5.217296564829512]

# %%
store_Z_bins_XG = [0.45616705906485044, 1.06024817459429, 1.5949958041694656, 2.230966641945092, 3.9233558135832873, 5.187565349312186, 6.3678158084056715, 11.392628958131683]

store_Z_bins_XG_15bins = [0.2925153957714496, 0.7110187950310004, 1.1081222256499326, 1.6088749753984757, 3.0600466279995633, 4.224701105473196, 5.352847065066797, 10.369981689375955]
store_Z_bins_XG_15bins_1ML = [0.28843046621639556, 0.7016168362666699, 1.094190373422215, 1.589861334109271, 3.0295114243533594, 4.187530304055226, 5.3108447173088, 10.317436672016242]

store_Z_bins_XG_15bins_eq = [0.09143643156834629, 0.22802597634580105, 0.36394520330717467, 0.5441429903593713, 1.121898897515157, 1.6449272625538234, 2.200958231113595, 5.2190956586208905]
store_Z_bins_XG_15bins_eq_1ML = [0.0914021717888956, 0.22794074624097438, 0.363809497432828, 0.543940736391258, 1.1214860595271872, 1.644327322865729, 2.2001629046695044, 5.217296564829512]

# %%
#########
# PLOTS #
#########

posX = []

for i in range(len(SB_ratio)):
    posX.append( (B_expected*SB_ratio[i]) / ( B_expected )**0.5 )



    
    
plt.figure()
lw = 2

plt.plot(posX, store_Z_bins_XG, '-ok', color='blue', lw=lw, label='o(x) BL (100 l.bins)') 
plt.plot(posX, store_Z_bins_XG_15bins, '-ok', color='red', lw=lw, label='o(x) BL (15 l.bins) (10ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_1ML, '-ok', color='green', lw=lw, label='o(x) BL (15 l.bins) (1ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_eq, '-ok', color='magenta', lw=lw, label='o(x) BL (15 n.l.bins) (10ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_eq_1ML, '-ok', color='darkorange', lw=lw, label='o(x) BL (15 n.l.bins) (1ML)') 

#plt.xlim([0.5, 10])
#plt.ylim([-0.5, 7.5])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=14)
plt.ylabel('$Z_{\mu}$ (exclusion)', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title("SSM Z', <B> per ensemble: %0.2d" % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()
# Out:
# <ipython-input-8-13c05c382495>:17: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG, '-ok', color='blue', lw=lw, label='o(x) BL (100 l.bins)')
# <ipython-input-8-13c05c382495>:18: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins, '-ok', color='red', lw=lw, label='o(x) BL (15 l.bins) (10ML)')
# <ipython-input-8-13c05c382495>:19: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_1ML, '-ok', color='green', lw=lw, label='o(x) BL (15 l.bins) (1ML)')
# <ipython-input-8-13c05c382495>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_eq, '-ok', color='magenta', lw=lw, label='o(x) BL (15 n.l.bins) (10ML)')
# <ipython-input-8-13c05c382495>:21: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_eq_1ML, '-ok', color='darkorange', lw=lw, label='o(x) BL (15 n.l.bins) (1ML)')

# %% [markdown]
# ### 3. MACHINE-LEARNED LIKELIHOOD with KDE

# %% [markdown]
# ##### For 10 ML

# %%
store_Z_MLL_KDE = []
store_Z_MLL_KDE_mu0 = []

store_muhat_mean_MLL = []




# FIND THE BANDWIDTH

bandwidth = np.logspace(-3.5, 0.05, 20)
print(bandwidth)

kde = KernelDensity(kernel='epanechnikov')
grid = GridSearchCV(kde, {'bandwidth': bandwidth})
grid.fit(np.c_[pred_XG_SM[:50000]])
print(grid.best_estimator_)

SM_bandwidth = grid.best_estimator_.bandwidth



kde = KernelDensity(kernel='epanechnikov')
grid = GridSearchCV(kde, {'bandwidth': bandwidth})
grid.fit(np.c_[pred_XG_NP[:50000]])
print(grid.best_estimator_)

NP_bandwidth = grid.best_estimator_.bandwidth







# aca fitteo 
kde_bkg = KernelDensity(kernel="epanechnikov", bandwidth=SM_bandwidth).fit(np.c_[pred_XG_SM, np.zeros(len(pred_XG_SM)) ])
kde_sig = KernelDensity(kernel="epanechnikov", bandwidth=NP_bandwidth).fit(np.c_[pred_XG_NP, np.ones(len(pred_XG_NP)) ])


# elijo los valores para graficar y calcular la significancia de Asimov
min_val = np.min([np.min(pred_XG_SM),np.min(pred_XG_NP)])
max_val = np.max([np.max(pred_XG_SM),np.max(pred_XG_NP)])

s_vals = np.linspace(min_val,max_val,100)





# evaluo las densidades en cada valor de s. esto es mas o menos equivalente a tomar bines continuos
dens_bkg = np.exp(kde_bkg.score_samples(np.c_[s_vals, np.zeros(len(s_vals)) ]) )
dens_sig = np.exp(kde_sig.score_samples(np.c_[s_vals, np.ones(len(s_vals)) ]) )





# PERO NO ESTA NORMALIZADO A 1 el area
# Area
factor_aux_SM = sum(dens_bkg*(s_vals[1]-s_vals[0]))
factor_aux_NP = sum(dens_sig*(s_vals[1]-s_vals[0]))

# normalizo
dens_bkg = dens_bkg / factor_aux_SM
dens_sig = dens_sig / factor_aux_NP






# grafico y verifico si la densidad es una buena aproximacion

plt.figure()

plt.hist(pred_XG_SM,density=True,bins=50,color='red',alpha=0.25,label='Sampled $p_{b}$');
plt.plot(s_vals,dens_bkg,color='red',label='Learned $p_{b}$',linestyle='dashed');

plt.hist(pred_XG_NP,density=True,bins=50,color='blue',alpha=0.25,label='Sampled $p_{s}$');
plt.plot(s_vals,dens_sig,color='blue',label='Learned $p_{s}$',linestyle='dashed');

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("o(x)",fontsize=15)
plt.ylabel("PDF",fontsize=14)
plt.grid()
plt.legend(fontsize=12)
#plt.title(r"Signal: W'$\rightarrow$XY, Background: QCD", fontsize=14)
#plt.savefig('images/' + 'Wprime-output.pdf', format="pdf", bbox_inches="tight")
plt.show()



  
    
    

# all the dataset though the SM and NP KDEs
# with this we'll form the toy samples for MLL

KDE_SM_pred_SM = np.exp(kde_bkg.score_samples(np.c_[pred_XG_SM, np.zeros(len(pred_XG_SM)) ]) )
KDE_NP_pred_SM = np.exp(kde_sig.score_samples(np.c_[pred_XG_SM, np.ones(len(pred_XG_SM)) ]) )

# Normalize

KDE_SM_pred_SM = KDE_SM_pred_SM / factor_aux_SM
KDE_NP_pred_SM = KDE_NP_pred_SM / factor_aux_NP




indices = [i for i in range(len(KDE_NP_pred_SM))]


########################
# METHOD: MLL with KDE #
########################

print('\n-------------------------------------')
print(' MLL with KDE')
print('-------------------------------------')




for iii in range(len(SB_ratio)):
    
    print('B_expected: ', B_expected)
    print('S_expected: ', S_expected[iii])
    print(r'S/$\sqrt{B}$: ', SsqrtB[iii])
    print('n_ensembles (initial): ', n_ensembles, '\n')

    
    

    ###########
    # NOW MLL #
    ###########

    # to construct ensembles B and S events are taken from Poisson distributions
    mu = S_expected[iii] + B_expected


    # Letś find the number of events per ensemble such that we get at least one ensemble populated if events are taken from a Poisson distribution

    # around the mean its populated so let's try (proposed range to be checked)
    list_events_per_ensembles = [i for i in range(int(mu*0.9),int(mu*1.1))]
    to_check = len(list_events_per_ensembles)

    # I want at least one ensemble populated
    list_nums_ensembles = [ int( poisson.pmf(list_events_per_ensembles[i],mu)*n_ensembles ) for i in range(len(list_events_per_ensembles)) ]



    # Remove from the list the elements without at least 1 ensemble possible
    for i in range(len(list_events_per_ensembles)):
        if list_nums_ensembles[i] > 1:
            list_events_per_ensembles = list_events_per_ensembles[i:]
            list_nums_ensembles = list_nums_ensembles[i:]
            break


    for i in range(len(list_events_per_ensembles)):
        if list_nums_ensembles[i] < 1:
            list_events_per_ensembles = list_events_per_ensembles[:i]
            list_nums_ensembles = list_nums_ensembles[:i]
            break

    print('\n If ', to_check, ' = ', len(list_events_per_ensembles), '   then the proposed range has to be extended')

    print('n_ensembles (actual): ', sum(list_nums_ensembles))



    # lists of S and B events per ensemble, w.r.t the total of number of events per ensemble found above:

    p_berno = S_expected[iii]/(S_expected[iii]+B_expected)

    list_S_per_ensembles = []
    list_B_per_ensembles = []

    for jj in range(len(list_events_per_ensembles)):
        list_S_per_ensembles.append( int(p_berno * list_events_per_ensembles[jj]) )
        list_B_per_ensembles.append( list_events_per_ensembles[jj] - int(p_berno * list_events_per_ensembles[jj]) )

    ######
    # NOW I HAVE 4 LISTS:
    # list_events_per_ensembles     list with the number of events per ensemble (its a range)
    # list_nums_ensembles           list with the number of ensembles, w.r.t the 1st list
    # list_S_per_ensembles          list with the number of signal events in each ensembles, w.r.t the 1st list
    # list_B_per_ensembles          list with the number of background events in each ensembles, w.r.t the 1st list
    ######



    print('\n This may take long... \n')


    # NOW LETS APPLY THE METHOD

    muhat_selected_list = []
    q_muhat = []
    q_muhat_mu0 = []

    for bb in range(len(list_nums_ensembles)):

        for kk in range(list_nums_ensembles[bb]):

            # KDE
            ran_ind = np.random.choice(indices, list_B_per_ensembles[bb])

            KDE_SM_pred_SM_shuf = []
            KDE_NP_pred_SM_shuf = []

            for i in ran_ind:
                KDE_SM_pred_SM_shuf.append(KDE_SM_pred_SM[i])
                KDE_NP_pred_SM_shuf.append(KDE_NP_pred_SM[i])

            KDE_SM_pred_SM_shuf  = np.array(KDE_SM_pred_SM_shuf)
            KDE_NP_pred_SM_shuf  = np.array(KDE_NP_pred_SM_shuf)



            # p_b(o(x_ensemble)) =    concatenate: p_b(o(B_ensemble)) and p_b(o(S_ensemble))  NOTICE THE o(x)
            prob_x_given_B = np.ndarray.tolist( KDE_SM_pred_SM_shuf ) #+ np.ndarray.tolist( KDE_SM_pred_NP_shuf )

            # p_s(o(x_ensemble)) =    concatenate: p_s(o(B_ensemble)) and p_s(o(S_ensemble))  NOTICE THE o(x)
            prob_x_given_S = np.ndarray.tolist( KDE_NP_pred_SM_shuf ) #+ np.ndarray.tolist( KDE_NP_pred_NP_shuf )









            # NOW WE HAVE p_{s,b}(x_ensemble) for this particular ensemble
            # WE NEED TO ESTIMATE mu_hat for this particular ensemble
            # we are going to obtain a mu_hat with a grid of values for this particular ensemble



            mu_hat_condition_equal_1 = []

            # grid, mu_hat is around 1
            muhat_test = np.arange(0., 1.5, 0.1).tolist()

            B_prob_x_given_B = [x * B_expected for x in prob_x_given_B]

            for vv in range(len(muhat_test)):

                mu_hat_condition_equal_1.append( sum ( [(x*1.) / ( (x * muhat_test[vv] * S_expected[iii]) + y ) for x, y in zip(prob_x_given_S, B_prob_x_given_B)] ) )



            muhat_selected = 0

            # from the grid, select the mu_hat such that the condition is equal to 1
            if mu_hat_condition_equal_1[0] < mu_hat_condition_equal_1[-1]:
                for ll in range(len(mu_hat_condition_equal_1)):
                    if mu_hat_condition_equal_1[ll] -1 > 0:
                        muhat_selected = muhat_test[ll]
                        break


            if mu_hat_condition_equal_1[0] > mu_hat_condition_equal_1[-1]:
                for ll in range(len(mu_hat_condition_equal_1)):
                    if mu_hat_condition_equal_1[ll] -1 < 0:
                        muhat_selected = muhat_test[ll]
                        break


            muhat_selected_list.append(muhat_selected)



            # NOW THAT WE HAVE mu_hat FOR THIS ENSEMBLE, CALCULATE THE TEST STATISTIC FOR THIS ENSEMBLE
            # and append it (we need the median over lots of ensembles)
            #q_muhat.append( 2 * ( (-1.*muhat_selected * S_expected[iii]) + sum( [np.log( 1 + ( (muhat_selected*S_expected[iii]/B_expected) * (x / y) ) ) for x, y in zip(prob_x_given_S, prob_x_given_B)] ) ) )
            # EXCLUSION:
            q_muhat.append( 2 * ( ( (1.-muhat_selected) * S_expected[iii] ) - sum( [np.log( ( (B_expected*y) + (S_expected[iii]*x) ) / ( (B_expected*y) + (muhat_selected*S_expected[iii]*x) ) ) for x, y in zip(prob_x_given_S, prob_x_given_B)] )
    ) )
            q_muhat_mu0.append( 2 * ( ( (1.-0.) * S_expected[iii] ) - sum( [np.log( ( (B_expected*y) + (S_expected[iii]*x) ) / ( (B_expected*y) + (0.*S_expected[iii]*x) ) ) for x, y in zip(prob_x_given_S, prob_x_given_B)] )
    ) )


    # Histogram of q_muhats

    weights = np.ones_like(q_muhat)/float(len(q_muhat))
    nMIX, binsMIX, patchesMIX = plt.hist(q_muhat, 25, weights=weights, histtype='step', color='blue', linewidth=2)
    #plt.xlim(0,1)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.xlabel("$q_0(\hat{\mu})$",fontsize=16)
    plt.ylabel("Fraction of ensembles",fontsize=16)
    plt.title(r"$\bar{B}$=%0.2i, $\bar{S}=$%0.2i" % (B_expected,S_expected[iii]),fontsize=14)
    plt.grid()
    #plt.legend(fontsize=14)
    plt.show()


    # Finally calculate muhat_mean and Z_gaussian

    # Remove nan if any
    q_muhat_mu0 = [x for x in q_muhat_mu0 if x == x]
    for jk in range(len(q_muhat_mu0)):
        if q_muhat_mu0[jk] < 0:
            q_muhat_mu0[jk] = 0

    q_muhat_median_mu0 = np.median(q_muhat_mu0)

    Z_KDE_mu0 = abs(q_muhat_median_mu0)**0.5
    store_Z_MLL_KDE_mu0.append(Z_KDE_mu0)


    # Finally calculate muhat_mean and Z_gaussian
    muhat_mean = np.mean(muhat_selected_list)
    store_muhat_mean_MLL.append(muhat_mean)

    # Remove nan if any
    q_muhat = [x for x in q_muhat if x == x]
    for jk in range(len(q_muhat)):
        if q_muhat[jk] < 0:
            q_muhat[jk] = 0

    q_muhat_median = np.median(q_muhat)

    Z_KDE = abs(q_muhat_median)**0.5
    store_Z_MLL_KDE.append(Z_KDE)

    print('muhat mean: ', muhat_mean)
    print('median q_muhat: ', q_muhat_median)
    print('Z_KDE: ', Z_KDE)
    print('Z_KDE mu=0: ', Z_KDE_mu0)
    
    print('\n ----------------------------------------- \n')
# Out:
# [3.16227766e-04 4.86230397e-04 7.47625680e-04 1.14954590e-03
#  1.76753662e-03 2.71775639e-03 4.17881006e-03 6.42531963e-03
#  9.87954269e-03 1.51907406e-02 2.33572147e-02 3.59139487e-02
#  5.52211267e-02 8.49077570e-02 1.30553787e-01 2.00738918e-01
#  3.08655261e-01 4.74586947e-01 7.29722764e-01 1.12201845e+00]
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [          -inf           -inf           -inf           -inf
#            -inf           -inf           -inf           -inf
#  14274.72723284 14215.56605738 14023.92909884 13579.74324757
#  12796.04593131 11622.97389651 10033.16916452  8021.77886704
#   5527.90806985  2604.59917901  -696.9377252  -4375.66930939]
#   warnings.warn(
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:929: RuntimeWarning: invalid value encountered in subtract
#   array_stds = np.sqrt(np.average((array -
# KernelDensity(bandwidth=0.009879542688342922, kernel='epanechnikov')
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [          -inf           -inf           -inf           -inf
#            -inf           -inf           -inf           -inf
#            -inf 20046.01343441 18093.76862197 15807.56275417
#  13324.01408293 10688.49346638  7915.25700432  5028.051669
#   2067.34017585  -981.42361556 -3989.47622822 -5781.82603305]
#   warnings.warn(
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:929: RuntimeWarning: invalid value encountered in subtract
#   array_stds = np.sqrt(np.average((array -
# KernelDensity(bandwidth=0.015190740588251416, kernel='epanechnikov')
# -------------------------------------
#  MLL with KDE
# -------------------------------------
# B_expected:  5000
# S_expected:  2
# S/$\sqrt{B}$:  0.0282842712474619
# n_ensembles (initial):  5000
#
#
#  If  1001  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4759
#
#  This may take long...
# muhat mean:  0.14505148140365626
# median q_muhat:  0.27643167296462146
# Z_KDE:  0.5257676986698797
# Z_KDE mu=0:  0.5257676986698797
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  5
# S/$\sqrt{B}$:  0.07071067811865475
# n_ensembles (initial):  5000
#
#
#  If  1001  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4757
#
#  This may take long...
# muhat mean:  0.2316586083666176
# median q_muhat:  1.0973008356399863
# Z_KDE:  1.0475212817122077
# Z_KDE mu=0:  1.0475212817122077
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  8
# S/$\sqrt{B}$:  0.1131370849898476
# n_ensembles (initial):  5000
#
#
#  If  1001  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4757
#
#  This may take long...
# muhat mean:  0.20445659028799665
# median q_muhat:  2.4805133886669974
# Z_KDE:  1.574964567432232
# Z_KDE mu=0:  1.574964567432232
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  12
# S/$\sqrt{B}$:  0.1697056274847714
# n_ensembles (initial):  5000
#
#
#  If  1003  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4757
#
#  This may take long...
# muhat mean:  0.16506201387429054
# median q_muhat:  4.5861653783496195
# Z_KDE:  2.1415334175187692
# Z_KDE mu=0:  2.1415334175187692
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  25
# S/$\sqrt{B}$:  0.35355339059327373
# n_ensembles (initial):  5000
#
#
#  If  1005  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4753
#
#  This may take long...
# muhat mean:  0.09450873132758258
# median q_muhat:  13.672058242171488
# Z_KDE:  3.6975746432183745
# Z_KDE mu=0:  3.7013351379006427
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  37
# S/$\sqrt{B}$:  0.5232590180780452
# n_ensembles (initial):  5000
#
#
#  If  1007  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4751
#
#  This may take long...
# muhat mean:  0.0723216165017891
# median q_muhat:  24.271094818047757
# Z_KDE:  4.926570289567353
# Z_KDE mu=0:  4.931181670673728
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  50
# S/$\sqrt{B}$:  0.7071067811865475
# n_ensembles (initial):  5000
#
#
#  If  1010  =  347    then the proposed range has to be extended
# n_ensembles (actual):  4754
#
#  This may take long...
# muhat mean:  0.05896087505258731
# median q_muhat:  37.151344749856776
# Z_KDE:  6.095190296443318
# Z_KDE mu=0:  6.097715641302649
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  125
# S/$\sqrt{B}$:  1.7677669529663687
# n_ensembles (initial):  5000
#
#
#  If  1025  =  349    then the proposed range has to be extended
# n_ensembles (actual):  4744
#
#  This may take long...
# muhat mean:  0.04578414839797639
# median q_muhat:  120.51923682051734
# Z_KDE:  10.978125378247295
# Z_KDE mu=0:  11.01675633049187
#
#  -----------------------------------------

# %%
print(store_Z_MLL_KDE)
print(store_Z_MLL_KDE_mu0)

print(store_muhat_mean_MLL)
# Out:
# [0.5257676986698797, 1.0475212817122077, 1.574964567432232, 2.1415334175187692, 3.6975746432183745, 4.926570289567353, 6.095190296443318, 10.978125378247295]
# [0.5257676986698797, 1.0475212817122077, 1.574964567432232, 2.1415334175187692, 3.7013351379006427, 4.931181670673728, 6.097715641302649, 11.01675633049187]
# [0.14505148140365626, 0.2316586083666176, 0.20445659028799665, 0.16506201387429054, 0.09450873132758258, 0.0723216165017891, 0.05896087505258731, 0.04578414839797639]

# %%
store_Z_MLL_KDE = [0.5257676986698797, 1.0475212817122077, 1.574964567432232, 2.1415334175187692, 3.6975746432183745, 4.926570289567353, 6.095190296443318, 10.978125378247295]
store_Z_MLL_KDE_mu0 = [0.5257676986698797, 1.0475212817122077, 1.574964567432232, 2.1415334175187692, 3.7013351379006427, 4.931181670673728, 6.097715641302649, 11.01675633049187]

store_muhat_mean_MLL = [0.14505148140365626, 0.2316586083666176, 0.20445659028799665, 0.16506201387429054, 0.09450873132758258, 0.0723216165017891, 0.05896087505258731, 0.04578414839797639]

# %% [markdown]
# ##### For 1 ML

# %%
store_Z_KDE_bins = []

store_Z_MLL_KDE_1ML = []
store_Z_MLL_KDE_mu0_1ML = []

store_muhat_mean_MLL_1ML = []




# # FIND THE BANDWIDTH

# bandwidth = np.logspace(-3.0, 0.05, 20)
# print(bandwidth)

# kde = KernelDensity(kernel='epanechnikov')
# grid = GridSearchCV(kde, {'bandwidth': bandwidth})
# grid.fit(np.c_[pred_XG_SM_1ML[:50000]])
# print(grid.best_estimator_)

# SM_bandwidth_1ML = grid.best_estimator_.bandwidth
SM_bandwidth_1ML = 0.009879542688342922


# kde = KernelDensity(kernel='epanechnikov')
# grid = GridSearchCV(kde, {'bandwidth': bandwidth})
# grid.fit(np.c_[pred_XG_NP_1ML[:50000]])
# print(grid.best_estimator_)

# NP_bandwidth_1ML = grid.best_estimator_.bandwidth
NP_bandwidth_1ML = 0.015190740588251416






# aca fitteo 
kde_bkg_1ML = KernelDensity(kernel="epanechnikov", bandwidth=SM_bandwidth_1ML).fit(np.c_[pred_XG_SM_1ML, np.zeros(len(pred_XG_SM_1ML)) ])
kde_sig_1ML = KernelDensity(kernel="epanechnikov", bandwidth=NP_bandwidth_1ML).fit(np.c_[pred_XG_NP_1ML, np.ones(len(pred_XG_NP_1ML)) ])


# elijo los valores para graficar y calcular la significancia de Asimov
min_val_1ML = np.min([np.min(pred_XG_SM_1ML),np.min(pred_XG_NP_1ML)])
max_val_1ML = np.max([np.max(pred_XG_SM_1ML),np.max(pred_XG_NP_1ML)])

s_vals_1ML = np.linspace(min_val_1ML,max_val_1ML,100)





# evaluo las densidades en cada valor de s. esto es mas o menos equivalente a tomar bines continuos
dens_bkg_1ML = np.exp(kde_bkg_1ML.score_samples(np.c_[s_vals_1ML, np.zeros(len(s_vals_1ML)) ]) )
dens_sig_1ML = np.exp(kde_sig_1ML.score_samples(np.c_[s_vals_1ML, np.ones(len(s_vals_1ML)) ]) )





# PERO NO ESTA NORMALIZADO A 1 el area
# Area
factor_aux_SM_1ML = sum(dens_bkg_1ML*(s_vals_1ML[1]-s_vals_1ML[0]))
factor_aux_NP_1ML = sum(dens_sig_1ML*(s_vals_1ML[1]-s_vals_1ML[0]))

# normalizo
dens_bkg_1ML = dens_bkg_1ML / factor_aux_SM_1ML
dens_sig_1ML = dens_sig_1ML / factor_aux_NP_1ML






# grafico y verifico si la densidad es una buena aproximacion

plt.figure()

plt.hist(pred_XG_SM_1ML,density=True,bins=100,color='red',alpha=0.25,label='Sampled $p_{b}$');
plt.plot(s_vals_1ML,dens_bkg_1ML,color='red',label='Learned $p_{b}$',linestyle='dashed');

plt.hist(pred_XG_NP_1ML,density=True,bins=100,color='blue',alpha=0.25,label='Sampled $p_{s}$');
plt.plot(s_vals_1ML,dens_sig_1ML,color='blue',label='Learned $p_{s}$',linestyle='dashed');

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("o(x)",fontsize=15)
plt.ylabel("PDF",fontsize=14)
plt.grid()
plt.legend(fontsize=12)
#plt.title(r"Signal: W'$\rightarrow$XY, Background: QCD", fontsize=14)
#plt.savefig('images/' + 'Wprime-output.pdf', format="pdf", bbox_inches="tight")
plt.show()



  
    
    

# all the dataset though the SM and NP KDEs
# with this we'll form the toy samples for MLL

KDE_SM_pred_SM_1ML = np.exp(kde_bkg_1ML.score_samples(np.c_[pred_XG_SM_1ML, np.zeros(len(pred_XG_SM_1ML)) ]) )
KDE_NP_pred_SM_1ML = np.exp(kde_sig_1ML.score_samples(np.c_[pred_XG_SM_1ML, np.ones(len(pred_XG_SM_1ML)) ]) )

# Normalize

KDE_SM_pred_SM_1ML = KDE_SM_pred_SM_1ML / factor_aux_SM_1ML
KDE_NP_pred_SM_1ML = KDE_NP_pred_SM_1ML / factor_aux_NP_1ML





indices = [i for i in range(len(KDE_NP_pred_SM_1ML))]


########################
# METHOD: MLL with KDE #
########################

print('\n-------------------------------------')
print(' MLL with KDE')
print('-------------------------------------')




for iii in range(len(SB_ratio)):
    
    print('B_expected: ', B_expected)
    print('S_expected: ', S_expected[iii])
    print(r'S/$\sqrt{B}$: ', SsqrtB[iii])
    print('n_ensembles (initial): ', n_ensembles, '\n')
    
    
    ####################
    # 1st a binned KDE #
    ####################
    
    # Bd: binned KDE background
    Bd = B_expected*dens_bkg_1ML*(s_vals_1ML[1]-s_vals_1ML[0])




    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    Bd_noceros = []
    for i in range(len(Bd)):
        if Bd[i]!=0:
            Bd_noceros.append(Bd[i])

    min_back = min(Bd_noceros)

    # replace the zeros
    for i in range(len(Bd)):
        if Bd[i]==0:
            Bd[i] = min_back


    # Sd: binned KDE signal
    Sd = SsqrtB[iii]*np.sqrt(B_expected)*dens_sig_1ML*(s_vals_1ML[1]-s_vals_1ML[0])

    #Z_KDE_bins = np.sqrt(2.0*np.sum(((Sd+Bd)*np.log(1.0+Sd/Bd)-Sd))) # Discovery
    Z_KDE_bins = np.sqrt(2.0*np.sum(Bd*np.log(Bd/(Sd+Bd))+Sd)) # Exclusion

    store_Z_KDE_bins.append(Z_KDE_bins)

    print('Z_KDE_bins : ', Z_KDE_bins)
    
    

    ###########
    # NOW MLL #
    ###########

    # to construct ensembles B and S events are taken from Poisson distributions
    mu = S_expected[iii] + B_expected


    # Letś find the number of events per ensemble such that we get at least one ensemble populated if events are taken from a Poisson distribution

    # around the mean its populated so let's try (proposed range to be checked)
    list_events_per_ensembles = [i for i in range(int(mu*0.9),int(mu*1.1))]
    to_check = len(list_events_per_ensembles)

    # I want at least one ensemble populated
    list_nums_ensembles = [ int( poisson.pmf(list_events_per_ensembles[i],mu)*n_ensembles ) for i in range(len(list_events_per_ensembles)) ]



    # Remove from the list the elements without at least 1 ensemble possible
    for i in range(len(list_events_per_ensembles)):
        if list_nums_ensembles[i] > 1:
            list_events_per_ensembles = list_events_per_ensembles[i:]
            list_nums_ensembles = list_nums_ensembles[i:]
            break


    for i in range(len(list_events_per_ensembles)):
        if list_nums_ensembles[i] < 1:
            list_events_per_ensembles = list_events_per_ensembles[:i]
            list_nums_ensembles = list_nums_ensembles[:i]
            break

    print('\n If ', to_check, ' = ', len(list_events_per_ensembles), '   then the proposed range has to be extended')

    print('n_ensembles (actual): ', sum(list_nums_ensembles))



    # lists of S and B events per ensemble, w.r.t the total of number of events per ensemble found above:

    p_berno = S_expected[iii]/(S_expected[iii]+B_expected)

    list_S_per_ensembles = []
    list_B_per_ensembles = []

    for jj in range(len(list_events_per_ensembles)):
        list_S_per_ensembles.append( int(p_berno * list_events_per_ensembles[jj]) )
        list_B_per_ensembles.append( list_events_per_ensembles[jj] - int(p_berno * list_events_per_ensembles[jj]) )

    ######
    # NOW I HAVE 4 LISTS:
    # list_events_per_ensembles     list with the number of events per ensemble (its a range)
    # list_nums_ensembles           list with the number of ensembles, w.r.t the 1st list
    # list_S_per_ensembles          list with the number of signal events in each ensembles, w.r.t the 1st list
    # list_B_per_ensembles          list with the number of background events in each ensembles, w.r.t the 1st list
    ######



    print('\n This may take long... \n')


    # NOW LETS APPLY THE METHOD

    muhat_selected_list = []
    q_muhat = []
    q_muhat_mu0 = []

    for bb in range(len(list_nums_ensembles)):

        for kk in range(list_nums_ensembles[bb]):

            # KDE
            ran_ind = np.random.choice(indices, list_B_per_ensembles[bb])

            KDE_SM_pred_SM_shuf = []
            KDE_NP_pred_SM_shuf = []

            for i in ran_ind:
                KDE_SM_pred_SM_shuf.append(KDE_SM_pred_SM_1ML[i])
                KDE_NP_pred_SM_shuf.append(KDE_NP_pred_SM_1ML[i])

            KDE_SM_pred_SM_shuf  = np.array(KDE_SM_pred_SM_shuf)
            KDE_NP_pred_SM_shuf  = np.array(KDE_NP_pred_SM_shuf)



            # p_b(o(x_ensemble)) =    concatenate: p_b(o(B_ensemble)) and p_b(o(S_ensemble))  NOTICE THE o(x)
            prob_x_given_B = np.ndarray.tolist( KDE_SM_pred_SM_shuf ) #+ np.ndarray.tolist( KDE_SM_pred_NP_shuf )

            # p_s(o(x_ensemble)) =    concatenate: p_s(o(B_ensemble)) and p_s(o(S_ensemble))  NOTICE THE o(x)
            prob_x_given_S = np.ndarray.tolist( KDE_NP_pred_SM_shuf ) #+ np.ndarray.tolist( KDE_NP_pred_NP_shuf )









            # NOW WE HAVE p_{s,b}(x_ensemble) for this particular ensemble
            # WE NEED TO ESTIMATE mu_hat for this particular ensemble
            # we are going to obtain a mu_hat with a grid of values for this particular ensemble



            mu_hat_condition_equal_1 = []

            # grid, mu_hat is around 1
            muhat_test = np.arange(0., 1.5, 0.1).tolist()

            B_prob_x_given_B = [x * B_expected for x in prob_x_given_B]

            for vv in range(len(muhat_test)):

                mu_hat_condition_equal_1.append( sum ( [(x*1.) / ( (x * muhat_test[vv] * S_expected[iii]) + y ) for x, y in zip(prob_x_given_S, B_prob_x_given_B)] ) )



            muhat_selected = 0

            # from the grid, select the mu_hat such that the condition is equal to 1
            if mu_hat_condition_equal_1[0] < mu_hat_condition_equal_1[-1]:
                for ll in range(len(mu_hat_condition_equal_1)):
                    if mu_hat_condition_equal_1[ll] -1 > 0:
                        muhat_selected = muhat_test[ll]
                        break


            if mu_hat_condition_equal_1[0] > mu_hat_condition_equal_1[-1]:
                for ll in range(len(mu_hat_condition_equal_1)):
                    if mu_hat_condition_equal_1[ll] -1 < 0:
                        muhat_selected = muhat_test[ll]
                        break


            muhat_selected_list.append(muhat_selected)



            # NOW THAT WE HAVE mu_hat FOR THIS ENSEMBLE, CALCULATE THE TEST STATISTIC FOR THIS ENSEMBLE
            # and append it (we need the median over lots of ensembles)
            #q_muhat.append( 2 * ( (-1.*muhat_selected * S_expected[iii]) + sum( [np.log( 1 + ( (muhat_selected*S_expected[iii]/B_expected) * (x / y) ) ) for x, y in zip(prob_x_given_S, prob_x_given_B)] ) ) )
            # EXCLUSION:
            q_muhat.append( 2 * ( ( (1.-muhat_selected) * S_expected[iii] ) - sum( [np.log( ( (B_expected*y) + (S_expected[iii]*x) ) / ( (B_expected*y) + (muhat_selected*S_expected[iii]*x) ) ) for x, y in zip(prob_x_given_S, prob_x_given_B)] )
    ) )
            q_muhat_mu0.append( 2 * ( ( (1.-0.) * S_expected[iii] ) - sum( [np.log( ( (B_expected*y) + (S_expected[iii]*x) ) / ( (B_expected*y) + (0.*S_expected[iii]*x) ) ) for x, y in zip(prob_x_given_S, prob_x_given_B)] )
    ) )


    # Histogram of q_muhats

    weights = np.ones_like(q_muhat)/float(len(q_muhat))
    nMIX, binsMIX, patchesMIX = plt.hist(q_muhat, 25, weights=weights, histtype='step', color='blue', linewidth=2)
    #plt.xlim(0,1)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.xlabel("$q_0(\hat{\mu})$",fontsize=16)
    plt.ylabel("Fraction of ensembles",fontsize=16)
    plt.title(r"$\bar{B}$=%0.2i, $\bar{S}=$%0.2i" % (B_expected,S_expected[iii]),fontsize=14)
    plt.grid()
    #plt.legend(fontsize=14)
    plt.show()


    # Finally calculate muhat_mean and Z_gaussian

    # Remove nan if any
    q_muhat_mu0 = [x for x in q_muhat_mu0 if x == x]

    q_muhat_median_mu0 = np.median(q_muhat_mu0)

    Z_KDE_mu0 = abs(q_muhat_median_mu0)**0.5
    store_Z_MLL_KDE_mu0_1ML.append(Z_KDE_mu0)


    # Finally calculate muhat_mean and Z_gaussian
    muhat_mean = np.mean(muhat_selected_list)
    store_muhat_mean_MLL_1ML.append(muhat_mean)

    # Remove nan if any
    q_muhat = [x for x in q_muhat if x == x]

    q_muhat_median = np.median(q_muhat)

    Z_KDE = abs(q_muhat_median)**0.5
    store_Z_MLL_KDE_1ML.append(Z_KDE)

    print('muhat mean: ', muhat_mean)
    print('median q_muhat: ', q_muhat_median)
    print('Z_KDE: ', Z_KDE)
    print('Z_KDE mu=0: ', Z_KDE_mu0)
    
    print('\n ----------------------------------------- \n')
# Out:
# -------------------------------------
#  MLL with KDE
# -------------------------------------
# B_expected:  5000
# S_expected:  2
# S/$\sqrt{B}$:  0.0282842712474619
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  0.4005479464582869
#
#  If  1001  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4759
#
#  This may take long...
# muhat mean:  0.1434965328850599
# median q_muhat:  0.28022203541221247
# Z_KDE:  0.5293600243805839
# Z_KDE mu=0:  0.5293600243805839
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  5
# S/$\sqrt{B}$:  0.07071067811865475
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  0.9439695944004481
#
#  If  1001  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4757
#
#  This may take long...
# muhat mean:  0.2227454277906243
# median q_muhat:  1.1594103640878473
# Z_KDE:  1.076759195032876
# Z_KDE mu=0:  1.076759195032876
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  8
# S/$\sqrt{B}$:  0.1131370849898476
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  1.434969749624672
#
#  If  1001  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4757
#
#  This may take long...
# muhat mean:  0.21280218625183941
# median q_muhat:  2.384916905883397
# Z_KDE:  1.5443176182001541
# Z_KDE mu=0:  1.5443176182001541
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  12
# S/$\sqrt{B}$:  0.1697056274847714
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  2.0284392120336645
#
#  If  1003  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4757
#
#  This may take long...
# muhat mean:  0.16453647256674375
# median q_muhat:  4.4567163571479504
# Z_KDE:  2.111093640070935
# Z_KDE mu=0:  2.111093640070935
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  25
# S/$\sqrt{B}$:  0.35355339059327373
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  3.642187726396562
#
#  If  1005  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4753
#
#  This may take long...
# muhat mean:  0.09362507889753839
# median q_muhat:  13.74813812375831
# Z_KDE:  3.7078481797072422
# Z_KDE mu=0:  3.7080239356108144
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  37
# S/$\sqrt{B}$:  0.5232590180780452
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  4.867885658984931
#
#  If  1007  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4751
#
#  This may take long...
# muhat mean:  0.07116396548095139
# median q_muhat:  24.432063230610346
# Z_KDE:  4.94288005424068
# Z_KDE mu=0:  4.944181743180018
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  50
# S/$\sqrt{B}$:  0.7071067811865475
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  6.021102649691391
#
#  If  1010  =  347    then the proposed range has to be extended
# n_ensembles (actual):  4754
#
#  This may take long...
# muhat mean:  0.05908708456037021
# median q_muhat:  36.413587542302864
# Z_KDE:  6.034367203137614
# Z_KDE mu=0:  6.042768835236616
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  125
# S/$\sqrt{B}$:  1.7677669529663687
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  10.972714774722895
#
#  If  1025  =  349    then the proposed range has to be extended
# n_ensembles (actual):  4744
#
#  This may take long...
# muhat mean:  0.0444983136593592
# median q_muhat:  120.63495545783447
# Z_KDE:  10.983394532558432
# Z_KDE mu=0:  11.011358383129295
#
#  -----------------------------------------

# %%
print(store_Z_KDE_bins)

print(store_Z_MLL_KDE_1ML)
print(store_Z_MLL_KDE_mu0_1ML)

print(store_muhat_mean_MLL_1ML)
# Out:
# [0.4005479464582869, 0.9439695944004481, 1.434969749624672, 2.0284392120336645, 3.642187726396562, 4.867885658984931, 6.021102649691391, 10.972714774722895]
# [0.5293600243805839, 1.076759195032876, 1.5443176182001541, 2.111093640070935, 3.7078481797072422, 4.94288005424068, 6.034367203137614, 10.983394532558432]
# [0.5293600243805839, 1.076759195032876, 1.5443176182001541, 2.111093640070935, 3.7080239356108144, 4.944181743180018, 6.042768835236616, 11.011358383129295]
# [0.1434965328850599, 0.2227454277906243, 0.21280218625183941, 0.16453647256674375, 0.09362507889753839, 0.07116396548095139, 0.05908708456037021, 0.0444983136593592]

# %%
store_Z_KDE_bins = [0.4005479464582869, 0.9439695944004481, 1.434969749624672, 2.0284392120336645, 3.642187726396562, 4.867885658984931, 6.021102649691391, 10.972714774722895]

store_Z_MLL_KDE_1ML = [0.5293600243805839, 1.076759195032876, 1.5443176182001541, 2.111093640070935, 3.7078481797072422, 4.94288005424068, 6.034367203137614, 10.983394532558432]
store_Z_MLL_KDE_mu0_1ML = [0.5293600243805839, 1.076759195032876, 1.5443176182001541, 2.111093640070935, 3.7080239356108144, 4.944181743180018, 6.042768835236616, 11.011358383129295]

store_muhat_mean_MLL_1ML = [0.1434965328850599, 0.2227454277906243, 0.21280218625183941, 0.16453647256674375, 0.09362507889753839, 0.07116396548095139, 0.05908708456037021, 0.0444983136593592]

# %%
#########
# PLOTS #
#########

posX = []

for i in range(len(SB_ratio)):
    posX.append( (B_expected*SB_ratio[i]) / ( B_expected )**0.5 )




plt.figure()
lw = 2

plt.plot(posX, store_muhat_mean_MLL, '-ok', color='red', lw=lw, label='mu_hat XGBoost (10ML)')
plt.plot(posX, store_muhat_mean_MLL_1ML, '-ok', color='blue', lw=lw, label='mu_hat XGBoost (1ML)')

#plt.xlim([0.5, 100])
#plt.ylim([-0.5, 7.5])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=14)
plt.ylabel(r'$\hat{\mu}$', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title('<B> per ensemble: %0.2d' % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()






plt.figure()
lw = 2

plt.plot(posX, store_Z_bins, ':ok', color='blue', lw=lw, label='100 Linear Binned Likelihood') 
plt.plot(posX, store_Z_bins_logbins, ':ok', color='lightblue', lw=lw, label='15 Log Binned Likelihood') 
plt.plot(posX, store_Z_bins_XG, '--ok', color='green', lw=lw, label='o(x) BL (100 l.bins)') 
plt.plot(posX, store_Z_bins_XG_15bins, '-ok', color='navy', lw=lw, label='o(x) BL (15 l.bins) (10ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_1ML, '-ok', color='green', lw=lw, label='o(x) BL (15 l.bins) (1ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_eq, '-ok', color='magenta', lw=lw, label='o(x) BL (15 n.l.bins) (10ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_eq_1ML, '-ok', color='darkorange', lw=lw, label='o(x) BL (15 n.l.bins) (1ML)') 
plt.plot(posX, store_Z_MLL_KDE, '-ok', color='red', lw=3, label=r'MLL KDE (10ML)')
plt.plot(posX, store_Z_MLL_KDE_1ML, '--ok', color='lightcoral', lw=3, label=r'MLL KDE (1ML)')
#plt.plot(posX, store_Z_MLL_KDE_mu0, '-ok', color='pink', lw=3, label=r'MLL KDE (XGBoost) muhat=0')
#plt.plot(posX, store_Z_KDE_bins, '-ok', color='magenta', lw=3, label=r'100 Bins KDE')

#plt.xlim([0.5, 10])
#plt.ylim([-0.5, 7.5])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=14)
plt.ylabel('$Z_{\mu}$ (exclusion)', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title('<B> per ensemble: %0.2d' % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()
# Out:
# <ipython-input-22-8bc2cdbd1b25>:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_muhat_mean_MLL, '-ok', color='red', lw=lw, label='mu_hat XGBoost (10ML)')
# <ipython-input-22-8bc2cdbd1b25>:17: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_muhat_mean_MLL_1ML, '-ok', color='blue', lw=lw, label='mu_hat XGBoost (1ML)')
# <ipython-input-22-8bc2cdbd1b25>:39: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string ":ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins, ':ok', color='blue', lw=lw, label='100 Linear Binned Likelihood')
# <ipython-input-22-8bc2cdbd1b25>:40: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string ":ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_logbins, ':ok', color='lightblue', lw=lw, label='15 Log Binned Likelihood')
# <ipython-input-22-8bc2cdbd1b25>:41: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "--ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG, '--ok', color='green', lw=lw, label='o(x) BL (100 l.bins)')
# <ipython-input-22-8bc2cdbd1b25>:42: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins, '-ok', color='navy', lw=lw, label='o(x) BL (15 l.bins) (10ML)')
# <ipython-input-22-8bc2cdbd1b25>:43: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_1ML, '-ok', color='green', lw=lw, label='o(x) BL (15 l.bins) (1ML)')
# <ipython-input-22-8bc2cdbd1b25>:44: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_eq, '-ok', color='magenta', lw=lw, label='o(x) BL (15 n.l.bins) (10ML)')
# <ipython-input-22-8bc2cdbd1b25>:45: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_eq_1ML, '-ok', color='darkorange', lw=lw, label='o(x) BL (15 n.l.bins) (1ML)')
# <ipython-input-22-8bc2cdbd1b25>:46: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_MLL_KDE, '-ok', color='red', lw=3, label=r'MLL KDE (10ML)')
# <ipython-input-22-8bc2cdbd1b25>:47: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "--ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_MLL_KDE_1ML, '--ok', color='lightcoral', lw=3, label=r'MLL KDE (1ML)')

# %% [markdown]
# ### 4.Working points, counting over 1 bin

# %%
WP = [0.25, 0.5, 0.75]

S_expected = [int(SB_ratio[i]*B_expected) for i in range(len(SB_ratio))]

print(S_expected)
# Out:
# [2, 5, 8, 12, 25, 37, 50, 125]

# %%
# XGBoost #

SrootB_WP0_XG = []
SrootB_WP1_XG = []
SrootB_WP2_XG = []


# number of background ensembles
B_ensembles = int(len(pred_XG_SM)/B_expected)

# shorten the number of B events so I get an integer number of ensembles
pred_XG_SM_entero = pred_XG_SM[:int(len(pred_XG_SM)/B_expected) * B_expected]

XG_SM_passWP0 = 0
XG_SM_passWP1 = 0
XG_SM_passWP2 = 0

for i in range(len(pred_XG_SM_entero)):
    if pred_XG_SM_entero[i] > WP[0]:
        XG_SM_passWP0 += 1
    if pred_XG_SM_entero[i] > WP[1]:
        XG_SM_passWP1 += 1
    if pred_XG_SM_entero[i] > WP[2]:
        XG_SM_passWP2 += 1



# SIGNAL

for j in range(len(S_expected)):
    
    # number of signal ensembles
    S_ensembles = int(len(pred_XG_NP)/S_expected[j])

    # shorten the number of S events so I get an integer number of ensembles
    pred_XG_NP_entero = pred_XG_NP[:int(len(pred_XG_NP)/S_expected[j]) * S_expected[j]]

    XG_NP_passWP0 = 0
    XG_NP_passWP1 = 0
    XG_NP_passWP2 = 0

    for i in range(len(pred_XG_NP_entero)):
        if pred_XG_NP_entero[i] > WP[0]:
            XG_NP_passWP0 += 1
        if pred_XG_NP_entero[i] > WP[1]:
            XG_NP_passWP1 += 1
        if pred_XG_NP_entero[i] > WP[2]:
            XG_NP_passWP2 += 1

            
    # save the results Z_binned after WP
    SrootB_WP0_XG.append( ( XG_NP_passWP0 / S_ensembles ) / ( XG_SM_passWP0 / B_ensembles )**0.5 )
    SrootB_WP1_XG.append( ( XG_NP_passWP1 / S_ensembles ) / ( XG_SM_passWP1 / B_ensembles )**0.5 )
    SrootB_WP2_XG.append( ( XG_NP_passWP2 / S_ensembles ) / ( XG_SM_passWP2 / B_ensembles )**0.5 )
    
    print('S_expected = ', S_expected[j])
    print('WP: 0     S/B**0.5= ', S_expected[j]/(B_expected)**0.5)
    print('WP: ', WP[0], '    S/B**0.5= ', SrootB_WP0_XG[j] )
    print('WP: ', WP[1], '    S/B**0.5= ', SrootB_WP1_XG[j] )
    print('WP: ', WP[2], '    S/B**0.5= ', SrootB_WP2_XG[j] )
    print('------------------------')
    print('')
    
print('SrootB_WP0_XG: ', SrootB_WP0_XG)
print('SrootB_WP1_XG: ', SrootB_WP1_XG)
print('SrootB_WP2_XG: ', SrootB_WP2_XG)
# Out:
# S_expected =  2
# WP: 0     S/B**0.5=  0.0282842712474619
# WP:  0.25     S/B**0.5=  0.06434449365918775
# WP:  0.5     S/B**0.5=  0.11257052530143465
# WP:  0.75     S/B**0.5=  0.17522550827546662
# ------------------------
#
# S_expected =  5
# WP: 0     S/B**0.5=  0.07071067811865475
# WP:  0.25     S/B**0.5=  0.160861141814429
# WP:  0.5     S/B**0.5=  0.28142605558432143
# WP:  0.75     S/B**0.5=  0.4380632539875687
# ------------------------
#
# S_expected =  8
# WP: 0     S/B**0.5=  0.1131370849898476
# WP:  0.25     S/B**0.5=  0.25737855965911466
# WP:  0.5     S/B**0.5=  0.4502826632618408
# WP:  0.75     S/B**0.5=  0.7009023530204623
# ------------------------
#
# S_expected =  12
# WP: 0     S/B**0.5=  0.1697056274847714
# WP:  0.25     S/B**0.5=  0.38606695307591915
# WP:  0.5     S/B**0.5=  0.6754248380038599
# WP:  0.75     S/B**0.5=  1.0513540094239247
# ------------------------
#
# S_expected =  25
# WP: 0     S/B**0.5=  0.35355339059327373
# WP:  0.25     S/B**0.5=  0.804306133741967
# WP:  0.5     S/B**0.5=  1.4071316821023767
# WP:  0.75     S/B**0.5=  2.1903228526175025
# ------------------------
#
# S_expected =  37
# WP: 0     S/B**0.5=  0.5232590180780452
# WP:  0.25     S/B**0.5=  1.1903764944166852
# WP:  0.5     S/B**0.5=  2.082564423651791
# WP:  0.75     S/B**0.5=  3.241680165831669
# ------------------------
#
# S_expected =  50
# WP: 0     S/B**0.5=  0.7071067811865475
# WP:  0.25     S/B**0.5=  1.608612267483934
# WP:  0.5     S/B**0.5=  2.8142633642047534
# WP:  0.75     S/B**0.5=  4.380645705235005
# ------------------------
#
# S_expected =  125
# WP: 0     S/B**0.5=  1.7677669529663687
# WP:  0.25     S/B**0.5=  4.021562253700516
# WP:  0.5     S/B**0.5=  7.035612703760182
# WP:  0.75     S/B**0.5=  10.951648424915472
# ------------------------
#
# SrootB_WP0_XG:  [0.06434449365918775, 0.160861141814429, 0.25737855965911466, 0.38606695307591915, 0.804306133741967, 1.1903764944166852, 1.608612267483934, 4.021562253700516]
# SrootB_WP1_XG:  [0.11257052530143465, 0.28142605558432143, 0.4502826632618408, 0.6754248380038599, 1.4071316821023767, 2.082564423651791, 2.8142633642047534, 7.035612703760182]
# SrootB_WP2_XG:  [0.17522550827546662, 0.4380632539875687, 0.7009023530204623, 1.0513540094239247, 2.1903228526175025, 3.241680165831669, 4.380645705235005, 10.951648424915472]

# %%
# To use if you dont want to run everything again. Its the previous results
SrootB_WP0_XG = [0.06434449365918775, 0.160861141814429, 0.25737855965911466, 0.38606695307591915, 0.804306133741967, 1.1903764944166852, 1.608612267483934, 4.021562253700516]
SrootB_WP1_XG = [0.11257052530143465, 0.28142605558432143, 0.4502826632618408, 0.6754248380038599, 1.4071316821023767, 2.082564423651791, 2.8142633642047534, 7.035612703760182]
SrootB_WP2_XG = [0.17522550827546662, 0.4380632539875687, 0.7009023530204623, 1.0513540094239247, 2.1903228526175025, 3.241680165831669, 4.380645705235005, 10.951648424915472]

# %%
#########
# PLOTS #
#########

posX = []

for i in range(len(SB_ratio)):
    posX.append( (B_expected*SB_ratio[i]) / ( B_expected )**0.5 )



plt.figure()
lw = 2

plt.plot(posX, store_Z_bins, ':ok', color='blue', lw=lw, label='100 Linear Binned Likelihood') 
plt.plot(posX, store_Z_bins_logbins, ':ok', color='lightblue', lw=lw, label='15 Log Binned Likelihood') 
plt.plot(posX, store_Z_bins_XG, '--ok', color='green', lw=lw, label='o(x) BL (100 l.bins)') 
plt.plot(posX, store_Z_bins_XG_15bins, '-ok', color='navy', lw=lw, label='o(x) BL (15 l.bins) (10ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_1ML, '-ok', color='green', lw=lw, label='o(x) BL (15 l.bins) (1ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_eq, '-ok', color='magenta', lw=lw, label='o(x) BL (15 n.l.bins) (10ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_eq_1ML, '-ok', color='darkorange', lw=lw, label='o(x) BL (15 n.l.bins) (1ML)') 
plt.plot(posX, store_Z_MLL_KDE, '-ok', color='red', lw=3, label=r'MLL KDE (10ML)')
plt.plot(posX, store_Z_MLL_KDE_1ML, '--ok', color='lightcoral', lw=3, label=r'MLL KDE (1ML)')
#plt.plot(posX, store_Z_MLL_KDE_mu0, '-ok', color='pink', lw=3, label=r'MLL KDE (XGBoost) muhat=0')
#plt.plot(posX, store_Z_KDE_bins, '-ok', color='magenta', lw=3, label=r'100 Bins KDE')
plt.plot(posX, SrootB_WP2_XG, '--', color='darkorange', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[2] )
plt.plot(posX, SrootB_WP1_XG, '--', color='magenta', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[1] )
plt.plot(posX, SrootB_WP0_XG, '--', color='navy', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[0] )
plt.plot(posX, posX, ':', color='black', lw=lw, label=r'$S/\sqrt{B}$')

#plt.xlim([0.5, 10])
#plt.ylim([-0.5, 7.5])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=14)
plt.ylabel('$Z_{\mu}$ (exclusion)', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title('<B> per ensemble: %0.2d' % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()
# Out:
# <ipython-input-25-1231ce6ddeb8>:15: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string ":ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins, ':ok', color='blue', lw=lw, label='100 Linear Binned Likelihood')
# <ipython-input-25-1231ce6ddeb8>:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string ":ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_logbins, ':ok', color='lightblue', lw=lw, label='15 Log Binned Likelihood')
# <ipython-input-25-1231ce6ddeb8>:17: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "--ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG, '--ok', color='green', lw=lw, label='o(x) BL (100 l.bins)')
# <ipython-input-25-1231ce6ddeb8>:18: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins, '-ok', color='navy', lw=lw, label='o(x) BL (15 l.bins) (10ML)')
# <ipython-input-25-1231ce6ddeb8>:19: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_1ML, '-ok', color='green', lw=lw, label='o(x) BL (15 l.bins) (1ML)')
# <ipython-input-25-1231ce6ddeb8>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_eq, '-ok', color='magenta', lw=lw, label='o(x) BL (15 n.l.bins) (10ML)')
# <ipython-input-25-1231ce6ddeb8>:21: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_eq_1ML, '-ok', color='darkorange', lw=lw, label='o(x) BL (15 n.l.bins) (1ML)')
# <ipython-input-25-1231ce6ddeb8>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_MLL_KDE, '-ok', color='red', lw=3, label=r'MLL KDE (10ML)')
# <ipython-input-25-1231ce6ddeb8>:23: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "--ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_MLL_KDE_1ML, '--ok', color='lightcoral', lw=3, label=r'MLL KDE (1ML)')

# %%
posX = []

for i in range(len(SB_ratio)):
    posX.append( (B_expected*SB_ratio[i]) / ( B_expected )**0.5 )


plt.figure()
lw = 2

plt.plot(posX, store_Z_bins_logbins, '-', color='dodgerblue', lw=3, label='x BL (15 log l.bins)') 
plt.plot(posX, store_Z_bins_XG_15bins, '-', color='green', lw=3, label='o(x) BL (15 l.bins) (10ML)') 
plt.plot(posX, store_Z_MLL_KDE, '-', color='red', lw=3, label=r'MLL KDE (10ML)')
plt.plot(posX, store_Z_MLL_KDE_1ML, '--ok', color='lightcoral', lw=3, label=r'MLL KDE (1ML)')
plt.plot(posX, SrootB_WP2_XG, '--', color='darkorange', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[2] )
plt.plot(posX, SrootB_WP1_XG, '--', color='magenta', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[1] )
plt.plot(posX, SrootB_WP0_XG, '--', color='navy', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[0] )
plt.plot(posX, posX, ':', color='black', lw=lw, label=r'$S/\sqrt{B}$')

#plt.xlim([0.5, 10])
#plt.ylim([-0.5, 7.5])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=15)
plt.ylabel('$Z_{\mu}$', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title('<B> per ensemble: %0.2d' % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()
# Out:
# <ipython-input-26-415cc2f1cb5e>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "--ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_MLL_KDE_1ML, '--ok', color='lightcoral', lw=3, label=r'MLL KDE (1ML)')

# %% [markdown]
# ### Interpolate

# %%
    
# Interpolation, cubic
fcubic_bins_logbins = interp1d(posX, store_Z_bins_logbins, kind='cubic')
fcubic_bins_XG_15bins = interp1d(posX, store_Z_bins_XG_15bins, kind='cubic')
fcubic_bins_XG_15bins_1ML = interp1d(posX, store_Z_bins_XG_15bins_1ML, kind='cubic')
fcubic_XG_MLL = interp1d(posX, store_Z_MLL_KDE, kind='cubic')
fcubic_XG_MLL_1ML = interp1d(posX, store_Z_MLL_KDE_1ML, kind='cubic')
fcubic_WP0_XG = interp1d(posX, SrootB_WP0_XG, kind='cubic')
fcubic_WP1_XG = interp1d(posX, SrootB_WP1_XG, kind='cubic')
fcubic_WP2_XG = interp1d(posX, SrootB_WP2_XG, kind='cubic')


# x to plot
plotX = np.linspace(min(posX), max(posX), num=50, endpoint=True)



plt.figure()
lw = 2

plt.plot(plotX, fcubic_bins_logbins(plotX), '-', color='dodgerblue', lw=3, label='x BL (15 log l.bins)') 
plt.plot(plotX, fcubic_bins_XG_15bins(plotX), '-', color='green', lw=3, label='o(x) BL (15 l.bins) (10ML)') 
plt.plot(plotX, fcubic_bins_XG_15bins_1ML(plotX), '--', color='green', lw=3, label='o(x) BL (15 l.bins) (1ML)') 
plt.plot(plotX, fcubic_XG_MLL(plotX), '-', color='red', lw=3, label=r'MLL KDE (10ML)')
plt.plot(plotX, fcubic_XG_MLL_1ML(plotX), '-', color='lightcoral', lw=3, label=r'MLL KDE (1ML)')
plt.plot(plotX, fcubic_WP0_XG(plotX), '--', color='darkorange', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[2] )
plt.plot(plotX, fcubic_WP1_XG(plotX), '--', color='magenta', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[1] )
plt.plot(plotX, fcubic_WP2_XG(plotX), '--', color='navy', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[0] )
plt.plot(posX, posX, ':', color='black', lw=lw, label=r'$S/\sqrt{B}$')

#plt.ylim([0., 6])
#plt.xlim([0.06, 10])
#plt.ylim([0., 3])
#plt.xlim([0.1, 0.2])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=15)
plt.ylabel('$Z_{\mu}$', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title('<B> per ensemble: %0.2d' % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()

# %%
# AUX FUNCTION TO FIND SOLUTIONS

def dx(fn, x, delta=0.001):
    return (fn(x+delta) - fn(x))/delta

def solve(fn, value, x=0.1, maxtries=1000, maxerr=0.00001):
    for tries in range(maxtries):
        err = fn(x) - value
        if abs(err) < maxerr:
            return x
        slope = dx(fn, x)
        x -= err/slope
    raise ValueError('no solution found')

# %%
##############################
# DO NOT FORGET THE K-factor #
##############################

k_factor = 3
SM_cross_section_fb = 0.3106
acceptance_SM = 0.4*2
true_B_expected = 3000 * SM_cross_section_fb * k_factor * acceptance_SM

correct_factor = true_B_expected / B_expected

print('correct_factor: ', correct_factor)
print('')


# Find S/\sqrt{B} such that 95%C.L. upper limit, i.e  ----> Z = 1.64

bins_logbins_95CL = solve(fcubic_bins_logbins, 1.64)
bins_XG_15bins_95CL = solve(fcubic_bins_XG_15bins, 1.64)
XG_MLL_95CL = solve(fcubic_XG_MLL, 1.64)
bins_XG_15bins_1ML_95CL = solve(fcubic_bins_XG_15bins_1ML, 1.64)
XG_MLL_1ML_95CL = solve(fcubic_XG_MLL_1ML, 1.64)


# corresponding to a number of signal events:
acceptance_Signal = 0.707437
S1 = ( (correct_factor * B_expected)**0.5 * bins_logbins_95CL ) / acceptance_Signal
S2 = ( (correct_factor * B_expected)**0.5 * bins_XG_15bins_95CL ) / acceptance_Signal
S3 = ( (correct_factor * B_expected)**0.5 * XG_MLL_95CL ) / acceptance_Signal
S4 = ( (correct_factor * B_expected)**0.5 * bins_XG_15bins_1ML_95CL ) / acceptance_Signal
S5 = ( (correct_factor * B_expected)**0.5 * XG_MLL_1ML_95CL ) / acceptance_Signal

# corresponding to a cross-section (pb)
cross_bins_logbins_95CL = S1 / 3000000
cross_bins_XG_15bins_95CL = S2 / 3000000
cross_XG_MLL_95CL = S3 / 3000000
cross_bins_XG_15bins_1ML_95CL = S4 / 3000000
cross_XG_MLL_1ML_95CL = S5 / 3000000



print('95%C.L. upper limit, i.e  ----> Z = 1.64: \n')
print('     S/\sqrt{B}              S          cross-section (pb)')
print(bins_logbins_95CL , S1 , cross_bins_logbins_95CL)
print(bins_XG_15bins_95CL , S2 , cross_bins_XG_15bins_95CL)
print(XG_MLL_95CL, S3 , cross_XG_MLL_95CL)
print(bins_XG_15bins_1ML_95CL , S4 , cross_bins_XG_15bins_1ML_95CL)
print(XG_MLL_1ML_95CL, S5 , cross_XG_MLL_1ML_95CL)



np.savetxt('saved-models/results5500GeV-mumu.txt', [cross_bins_logbins_95CL,cross_bins_XG_15bins_95CL,cross_XG_MLL_95CL,cross_bins_XG_15bins_1ML_95CL,cross_XG_MLL_1ML_95CL])
# Out:
# correct_factor:  0.44726399999999994
#
# 95%C.L. upper limit, i.e  ----> Z = 1.64:
#
#      S/\sqrt{B}              S          cross-section (pb)
# 0.10583849925752657 7.074941883205461 2.358313961068487e-06
# 0.18065384466780102 12.076091979463959 4.025363993154653e-06
# 0.11966116226969091 7.998939654982651 2.6663132183275503e-06
# 0.1830705645638103 12.237641443337674 4.079213814445891e-06
# 0.12381023859821111 8.276291224583412 2.758763741527804e-06
