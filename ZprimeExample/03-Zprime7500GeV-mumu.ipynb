# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import gridspec
from matplotlib import patches
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

import os
import math
import random

import keras
from keras.models import Sequential
from keras.layers import Input, Dense, Conv2D, Flatten, MaxPooling2D
from keras.layers import Dropout
from keras.callbacks import EarlyStopping

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn import preprocessing
from sklearn.metrics import roc_curve, roc_auc_score, auc

import scipy.stats as st
from scipy.stats import poisson
from scipy.interpolate import interp1d
from scipy.stats import norm

# %%
from sklearn.neighbors import KernelDensity # paquete necesario
from sklearn.model_selection import GridSearchCV

import scipy.integrate as integrate

# %%
# !pip install xgboost

import xgboost
from xgboost import XGBRegressor, XGBClassifier
# Out:
# Requirement already satisfied: xgboost in /home/andres/anaconda3/lib/python3.8/site-packages (1.5.1)
# Requirement already satisfied: scipy in /home/andres/.local/lib/python3.8/site-packages (from xgboost) (1.9.3)
# Requirement already satisfied: numpy in /home/andres/.local/lib/python3.8/site-packages (from xgboost) (1.22.4)
# WARNING: You are using pip version 21.3.1; however, version 23.2 is available.
# You should consider upgrading via the '/home/andres/anaconda3/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# ## DATA

# %%
# data

folder_data = "../../MLL-exclusion/data/"

# %%
folder_saved = "Zprime-SSM-mumu-mZ7500GeV-variables/"

# 1st DATASET
e1pt_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-pt-7500-1.txt', delimiter=',')
e1eta_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-eta-7500-1.txt', delimiter=',')
e1phi_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-phi-7500-1.txt', delimiter=',')

e2pt_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-pt-7500-1.txt', delimiter=',')
e2eta_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-eta-7500-1.txt', delimiter=',')
e2phi_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-phi-7500-1.txt', delimiter=',')




# INVARIANT MASS

invariant_mass_eeSM = []

for i in range(len(e1pt_eeSSMZprime)):
    invariant_mass_eeSM.append( ( 2 * e1pt_eeSSMZprime[i] * e2pt_eeSSMZprime[i] * ( np.cosh(e1eta_eeSSMZprime[i] - e2eta_eeSSMZprime[i]) - np.cos(e1phi_eeSSMZprime[i] - e2phi_eeSSMZprime[i]) ) )**0.5 )
    
print(len(invariant_mass_eeSM))

f= open(folder_data + folder_saved + "mmumu-1.txt","w")
for i in range(len(invariant_mass_eeSM)):
    f.write("%.3f\n" % invariant_mass_eeSM[i] )
f.close()




# 2nd DATASET
e1pt_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-pt-7500-2.txt', delimiter=',')
e1eta_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-eta-7500-2.txt', delimiter=',')
e1phi_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-phi-7500-2.txt', delimiter=',')

e2pt_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-pt-7500-2.txt', delimiter=',')
e2eta_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-eta-7500-2.txt', delimiter=',')
e2phi_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-phi-7500-2.txt', delimiter=',')




# INVARIANT MASS

invariant_mass_eeSM = []

for i in range(len(e1pt_eeSSMZprime)):
    invariant_mass_eeSM.append( ( 2 * e1pt_eeSSMZprime[i] * e2pt_eeSSMZprime[i] * ( np.cosh(e1eta_eeSSMZprime[i] - e2eta_eeSSMZprime[i]) - np.cos(e1phi_eeSSMZprime[i] - e2phi_eeSSMZprime[i]) ) )**0.5 )
    
print(len(invariant_mass_eeSM))

f= open(folder_data + folder_saved + "mmumu-2.txt","w")
for i in range(len(invariant_mass_eeSM)):
    f.write("%.3f\n" % invariant_mass_eeSM[i] )
f.close()



# 3rd DATASET
e1pt_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-pt-7500-3.txt', delimiter=',')
e1eta_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-eta-7500-3.txt', delimiter=',')
e1phi_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-phi-7500-3.txt', delimiter=',')

e2pt_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-pt-7500-3.txt', delimiter=',')
e2eta_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-eta-7500-3.txt', delimiter=',')
e2phi_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-phi-7500-3.txt', delimiter=',')




# INVARIANT MASS

invariant_mass_eeSM = []

for i in range(len(e1pt_eeSSMZprime)):
    invariant_mass_eeSM.append( ( 2 * e1pt_eeSSMZprime[i] * e2pt_eeSSMZprime[i] * ( np.cosh(e1eta_eeSSMZprime[i] - e2eta_eeSSMZprime[i]) - np.cos(e1phi_eeSSMZprime[i] - e2phi_eeSSMZprime[i]) ) )**0.5 )
    
print(len(invariant_mass_eeSM))

f= open(folder_data + folder_saved + "mmumu-3.txt","w")
for i in range(len(invariant_mass_eeSM)):
    f.write("%.3f\n" % invariant_mass_eeSM[i] )
f.close()
# Out:
# 635558
# 636742
# 636558

# %%
# just to check that we need to ask again that the invariant mass has to be greater than 2000 GeV

bins_atlas = [70, 80.0, 90.0, 105.0, 120.0, 140.0, 160.0, 180.0, 210.0, 240.0, 275.0, 315.0, 360.0, 415.0, 475.0, 545.0, 625.0, 715.0, 825.0, 950.0, 1100.0, 1250.0, 1450.0, 1650.0, 1900.0, 2200.0, 2500.0, 2850.0, 3250.0, 3750.0, 4350.0, 5000.0, 5750.0, 6600.0, 7500.0, 8750.0, 10000.0, 11500.0, 13000.0, 20000]

folder_saved = "SM/mumu/"

invariant_mass_eeSM_1800 = np.loadtxt(folder_data + folder_saved +"mmumu-1800.txt", delimiter=',')
invariant_mass_eeSM_1800_2 = np.loadtxt(folder_data + folder_saved +"mmumu-1800-2.txt", delimiter=',')

plt.hist(invariant_mass_eeSM_1800, bins=bins_atlas, lw=2, edgecolor='lightblue', histtype='step', label="SM (dataset 1)")
plt.hist(invariant_mass_eeSM_1800_2, bins=bins_atlas, lw=2, edgecolor='green', histtype='step', label="SM (dataset 2)")


folder_saved = "Zprime-SSM-mumu-mZ7500GeV-variables/"

invariant_mass_eeSSMZprime_1 = np.loadtxt(folder_data + folder_saved +"mmumu-1.txt", delimiter=',')
invariant_mass_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved +"mmumu-2.txt", delimiter=',')
invariant_mass_eeSSMZprime_3 = np.loadtxt(folder_data + folder_saved +"mmumu-3.txt", delimiter=',')

plt.hist(invariant_mass_eeSSMZprime_1, bins=bins_atlas, lw=2, edgecolor='pink', histtype='step', label="$Z'_{SSM}$ (dataset 1)")
plt.hist(invariant_mass_eeSSMZprime_2, bins=bins_atlas, lw=2, edgecolor='darkorange', histtype='step', label="$Z'_{SSM}$ (dataset 2)")
plt.hist(invariant_mass_eeSSMZprime_3, bins=bins_atlas, lw=2, edgecolor='purple', histtype='step', label="$Z'_{SSM}$ (dataset 3)")


plt.grid()  # Add grid lines

plt.title(r"Z/Z'$\rightarrow$e+e-",fontsize=14)  # Titles etc
plt.xlabel("$m_{ll}$ (GeV)",fontsize=14)
plt.ylabel("Events",fontsize=14)

plt.xlim(70.,20000)
plt.ylim(1e0,1e7)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xscale('log')
plt.yscale('log')
plt.legend(loc='upper left',fontsize=12)

plt.show()

# %% [markdown]
# ### SM

# %%
######
# SM #
######


folder_saved = "SM/mumu/"


# 1st DATASET
invariant_mass_eeSM = np.loadtxt(folder_data + folder_saved +"mmumu-1800.txt", delimiter=',')

e1pt_eeSM = np.loadtxt(folder_data + folder_saved + 'mu1_pt_events_IM_1800.txt', delimiter=',')
e1eta_eeSM = np.loadtxt(folder_data + folder_saved + 'mu1_eta_events_IM_1800.txt', delimiter=',')
e1phi_eeSM = np.loadtxt(folder_data + folder_saved + 'mu1_phi_events_IM_1800.txt', delimiter=',')

e2pt_eeSM = np.loadtxt(folder_data + folder_saved + 'mu2_pt_events_IM_1800.txt', delimiter=',')
e2eta_eeSM = np.loadtxt(folder_data + folder_saved + 'mu2_eta_events_IM_1800.txt', delimiter=',')
e2phi_eeSM = np.loadtxt(folder_data + folder_saved + 'mu2_phi_events_IM_1800.txt', delimiter=',')


# only keep points where the invariant mass is greater than 2000 GeV
# and make sure that both electrons: |eta| < 2.65
for i in reversed(range(len(invariant_mass_eeSM))):
    if invariant_mass_eeSM[i]< 2000 or e1eta_eeSM[i] < -2.65 or e1eta_eeSM[i] > 2.65 or e2eta_eeSM[i] < -2.65 or e2eta_eeSM[i] > 2.65:
        e1pt_eeSM = np.delete(e1pt_eeSM, i)
        e1eta_eeSM = np.delete(e1eta_eeSM, i)
        e1phi_eeSM = np.delete(e1phi_eeSM, i)
        
        e2pt_eeSM = np.delete(e2pt_eeSM, i)
        e2eta_eeSM = np.delete(e2eta_eeSM, i)
        e2phi_eeSM = np.delete(e2phi_eeSM, i)
        
        invariant_mass_eeSM = np.delete(invariant_mass_eeSM, i)
        

        
        
# 2nd DATASET
invariant_mass_eeSM_1800 = np.loadtxt(folder_data + folder_saved +"mmumu-1800-2.txt", delimiter=',')

e1pt_eeSM_1800 = np.loadtxt(folder_data + folder_saved + 'mu1_pt_events_IM_1800_2.txt', delimiter=',')
e1eta_eeSM_1800 = np.loadtxt(folder_data + folder_saved + 'mu1_eta_events_IM_1800_2.txt', delimiter=',')
e1phi_eeSM_1800 = np.loadtxt(folder_data + folder_saved + 'mu1_phi_events_IM_1800_2.txt', delimiter=',')

e2pt_eeSM_1800 = np.loadtxt(folder_data + folder_saved + 'mu2_pt_events_IM_1800_2.txt', delimiter=',')
e2eta_eeSM_1800 = np.loadtxt(folder_data + folder_saved + 'mu2_eta_events_IM_1800_2.txt', delimiter=',')
e2phi_eeSM_1800 = np.loadtxt(folder_data + folder_saved + 'mu2_phi_events_IM_1800_2.txt', delimiter=',')


# only keep points where the invariant mass is greater than 2000 GeV
# and make sure that both electrons: |eta| < 2.65
for i in reversed(range(len(invariant_mass_eeSM_1800))):
    if invariant_mass_eeSM_1800[i]< 2000 or e1eta_eeSM_1800[i] < -2.65 or e1eta_eeSM_1800[i] > 2.65 or e2eta_eeSM_1800[i] < -2.65 or e2eta_eeSM_1800[i] > 2.65:
        e1pt_eeSM_1800 = np.delete(e1pt_eeSM_1800, i)
        e1eta_eeSM_1800 = np.delete(e1eta_eeSM_1800, i)
        e1phi_eeSM_1800 = np.delete(e1phi_eeSM_1800, i)
        
        e2pt_eeSM_1800 = np.delete(e2pt_eeSM_1800, i)
        e2eta_eeSM_1800 = np.delete(e2eta_eeSM_1800, i)
        e2phi_eeSM_1800 = np.delete(e2phi_eeSM_1800, i)
        
        invariant_mass_eeSM_1800 = np.delete(invariant_mass_eeSM_1800, i)
        


# concatenate results
e1pt_eeSM = np.concatenate([e1pt_eeSM,e1pt_eeSM_1800])
e1eta_eeSM = np.concatenate([e1eta_eeSM,e1eta_eeSM_1800])
e1phi_eeSM = np.concatenate([e1phi_eeSM,e1phi_eeSM_1800])

e2pt_eeSM = np.concatenate([e2pt_eeSM,e2pt_eeSM_1800])
e2eta_eeSM = np.concatenate([e2eta_eeSM,e2eta_eeSM_1800])
e2phi_eeSM = np.concatenate([e2phi_eeSM,e2phi_eeSM_1800])

invariant_mass_eeSM = np.concatenate([invariant_mass_eeSM,invariant_mass_eeSM_1800])



# remove the aux
del e1pt_eeSM_1800
del e1eta_eeSM_1800
del e1phi_eeSM_1800

del e2pt_eeSM_1800
del e2eta_eeSM_1800
del e2phi_eeSM_1800

del invariant_mass_eeSM_1800




# FINALLY

# compute \Delta \eta_{l+l-}
e1e2diffeta_eeSM = np.array([a-b for a,b in zip(e1eta_eeSM,e2eta_eeSM)])

# compute R = [ \Delta \eta_{l+l-}^2 + \Delta \eta_{l+l-}^2 ]^1/2
e1e2R_eeSM = np.array([( (a-b)**2. + (c-d)**2. )**0.5 for a,b,c,d in zip(e1eta_eeSM,e2eta_eeSM,e1phi_eeSM,e2phi_eeSM)])



print(e1pt_eeSM.shape)
print(e1eta_eeSM.shape)
print(e1phi_eeSM.shape)

print(e2pt_eeSM.shape)
print(e2eta_eeSM.shape)
print(e2phi_eeSM.shape)

print(invariant_mass_eeSM.shape)
print(e1e2diffeta_eeSM.shape)
print(e1e2R_eeSM.shape)
# Out:
# (804774,)
# (804774,)
# (804774,)
# (804774,)
# (804774,)
# (804774,)
# (804774,)
# (804774,)
# (804774,)

# %%
print(min(e1eta_eeSM))
print(max(e1eta_eeSM))

print(min(e2eta_eeSM))
print(max(e2eta_eeSM))
# Out:
# -2.646
# 2.648
# -2.649
# 2.649

# %% [markdown]
# ### SSM Z prime

# %%
##########
# Zprime #
##########


folder_saved = "Zprime-SSM-mumu-mZ7500GeV-variables/"


# 1st DATASET
invariant_mass_eeSSMZprime = np.loadtxt(folder_data + folder_saved +"mmumu-1.txt", delimiter=',')

e1pt_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-pt-7500-1.txt', delimiter=',')
e1eta_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-eta-7500-1.txt', delimiter=',')
e1phi_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu1-phi-7500-1.txt', delimiter=',')

e2pt_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-pt-7500-1.txt', delimiter=',')
e2eta_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-eta-7500-1.txt', delimiter=',')
e2phi_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'mu2-phi-7500-1.txt', delimiter=',')


# only keep points where the invariant mass is greater than 2000 GeV
# and make sure that both electrons: |eta| < 2.65
for i in reversed(range(len(invariant_mass_eeSSMZprime))):
    if invariant_mass_eeSSMZprime[i]< 2000 or e1eta_eeSSMZprime[i] < -2.65 or e1eta_eeSSMZprime[i] > 2.65 or e2eta_eeSSMZprime[i] < -2.65 or e2eta_eeSSMZprime[i] > 2.65:
        e1pt_eeSSMZprime = np.delete(e1pt_eeSSMZprime, i)
        e1eta_eeSSMZprime = np.delete(e1eta_eeSSMZprime, i)
        e1phi_eeSSMZprime = np.delete(e1phi_eeSSMZprime, i)
        
        e2pt_eeSSMZprime = np.delete(e2pt_eeSSMZprime, i)
        e2eta_eeSSMZprime = np.delete(e2eta_eeSSMZprime, i)
        e2phi_eeSSMZprime = np.delete(e2phi_eeSSMZprime, i)
        
        invariant_mass_eeSSMZprime = np.delete(invariant_mass_eeSSMZprime, i)

        
        
        
        
# 2nd DATASET
invariant_mass_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved +"mmumu-2.txt", delimiter=',')

e1pt_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved + 'mu1-pt-7500-2.txt', delimiter=',')
e1eta_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved + 'mu1-eta-7500-2.txt', delimiter=',')
e1phi_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved + 'mu1-phi-7500-2.txt', delimiter=',')

e2pt_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved + 'mu2-pt-7500-2.txt', delimiter=',')
e2eta_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved + 'mu2-eta-7500-2.txt', delimiter=',')
e2phi_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved + 'mu2-phi-7500-2.txt', delimiter=',')


# only keep points where the invariant mass is greater than 2000 GeV
# and make sure that both electrons: |eta| < 2.65
for i in reversed(range(len(invariant_mass_eeSSMZprime_2))):
    if invariant_mass_eeSSMZprime_2[i]< 2000 or e1eta_eeSSMZprime_2[i] < -2.65 or e1eta_eeSSMZprime_2[i] > 2.65 or e2eta_eeSSMZprime_2[i] < -2.65 or e2eta_eeSSMZprime_2[i] > 2.65:
        e1pt_eeSSMZprime_2 = np.delete(e1pt_eeSSMZprime_2, i)
        e1eta_eeSSMZprime_2 = np.delete(e1eta_eeSSMZprime_2, i)
        e1phi_eeSSMZprime_2 = np.delete(e1phi_eeSSMZprime_2, i)
        
        e2pt_eeSSMZprime_2 = np.delete(e2pt_eeSSMZprime_2, i)
        e2eta_eeSSMZprime_2 = np.delete(e2eta_eeSSMZprime_2, i)
        e2phi_eeSSMZprime_2 = np.delete(e2phi_eeSSMZprime_2, i)
        
        invariant_mass_eeSSMZprime_2 = np.delete(invariant_mass_eeSSMZprime_2, i)
        
eventos_parton = 1000000
aceptancia_eeSSMZprime_2 = 1.*len(invariant_mass_eeSSMZprime_2) / eventos_parton
print(aceptancia_eeSSMZprime_2)


# concatenate results
e1pt_eeSSMZprime = np.concatenate([e1pt_eeSSMZprime,e1pt_eeSSMZprime_2])
e1eta_eeSSMZprime = np.concatenate([e1eta_eeSSMZprime,e1eta_eeSSMZprime_2])
e1phi_eeSSMZprime = np.concatenate([e1phi_eeSSMZprime,e1phi_eeSSMZprime_2])

e2pt_eeSSMZprime = np.concatenate([e2pt_eeSSMZprime,e2pt_eeSSMZprime_2])
e2eta_eeSSMZprime = np.concatenate([e2eta_eeSSMZprime,e2eta_eeSSMZprime_2])
e2phi_eeSSMZprime = np.concatenate([e2phi_eeSSMZprime,e2phi_eeSSMZprime_2])

invariant_mass_eeSSMZprime = np.concatenate([invariant_mass_eeSSMZprime,invariant_mass_eeSSMZprime_2])



# remove the aux
del e1pt_eeSSMZprime_2
del e1eta_eeSSMZprime_2
del e1phi_eeSSMZprime_2

del e2pt_eeSSMZprime_2
del e2eta_eeSSMZprime_2
del e2phi_eeSSMZprime_2

del invariant_mass_eeSSMZprime_2






# 3rd DATASET
invariant_mass_eeSSMZprime_3 = np.loadtxt(folder_data + folder_saved +"mmumu-3.txt", delimiter=',')

e1pt_eeSSMZprime_3 = np.loadtxt(folder_data + folder_saved + 'mu1-pt-7500-3.txt', delimiter=',')
e1eta_eeSSMZprime_3 = np.loadtxt(folder_data + folder_saved + 'mu1-eta-7500-3.txt', delimiter=',')
e1phi_eeSSMZprime_3 = np.loadtxt(folder_data + folder_saved + 'mu1-phi-7500-3.txt', delimiter=',')

e2pt_eeSSMZprime_3 = np.loadtxt(folder_data + folder_saved + 'mu2-pt-7500-3.txt', delimiter=',')
e2eta_eeSSMZprime_3 = np.loadtxt(folder_data + folder_saved + 'mu2-eta-7500-3.txt', delimiter=',')
e2phi_eeSSMZprime_3 = np.loadtxt(folder_data + folder_saved + 'mu2-phi-7500-3.txt', delimiter=',')


# only keep points where the invariant mass is greater than 2000 GeV
# and make sure that both electrons: |eta| < 2.65
for i in reversed(range(len(invariant_mass_eeSSMZprime_3))):
    if invariant_mass_eeSSMZprime_3[i]< 2000 or e1eta_eeSSMZprime_3[i] < -2.65 or e1eta_eeSSMZprime_3[i] > 2.65 or e2eta_eeSSMZprime_3[i] < -2.65 or e2eta_eeSSMZprime_3[i] > 2.65:
        e1pt_eeSSMZprime_3 = np.delete(e1pt_eeSSMZprime_3, i)
        e1eta_eeSSMZprime_3 = np.delete(e1eta_eeSSMZprime_3, i)
        e1phi_eeSSMZprime_3 = np.delete(e1phi_eeSSMZprime_3, i)
        
        e2pt_eeSSMZprime_3 = np.delete(e2pt_eeSSMZprime_3, i)
        e2eta_eeSSMZprime_3 = np.delete(e2eta_eeSSMZprime_3, i)
        e2phi_eeSSMZprime_3 = np.delete(e2phi_eeSSMZprime_3, i)
        
        invariant_mass_eeSSMZprime_3 = np.delete(invariant_mass_eeSSMZprime_3, i)
        
eventos_parton = 1000000
aceptancia_eeSSMZprime_3 = 1.*len(invariant_mass_eeSSMZprime_3) / eventos_parton
print(aceptancia_eeSSMZprime_3)


# concatenate results
e1pt_eeSSMZprime = np.concatenate([e1pt_eeSSMZprime,e1pt_eeSSMZprime_3])
e1eta_eeSSMZprime = np.concatenate([e1eta_eeSSMZprime,e1eta_eeSSMZprime_3])
e1phi_eeSSMZprime = np.concatenate([e1phi_eeSSMZprime,e1phi_eeSSMZprime_3])

e2pt_eeSSMZprime = np.concatenate([e2pt_eeSSMZprime,e2pt_eeSSMZprime_3])
e2eta_eeSSMZprime = np.concatenate([e2eta_eeSSMZprime,e2eta_eeSSMZprime_3])
e2phi_eeSSMZprime = np.concatenate([e2phi_eeSSMZprime,e2phi_eeSSMZprime_3])

invariant_mass_eeSSMZprime = np.concatenate([invariant_mass_eeSSMZprime,invariant_mass_eeSSMZprime_3])



# remove the aux
del e1pt_eeSSMZprime_3
del e1eta_eeSSMZprime_3
del e1phi_eeSSMZprime_3

del e2pt_eeSSMZprime_3
del e2eta_eeSSMZprime_3
del e2phi_eeSSMZprime_3

del invariant_mass_eeSSMZprime_3







# FINALLY

# compute \Delta \eta_{l+l-}
e1e2diffeta_eeSSMZprime = np.array([a-b for a,b in zip(e1eta_eeSSMZprime,e2eta_eeSSMZprime)])

# compute R = [ \Delta \eta_{l+l-}^2 + \Delta \eta_{l+l-}^2 ]^1/2
e1e2R_eeSSMZprime = np.array([( (a-b)**2. + (c-d)**2. )**0.5 for a,b,c,d in zip(e1eta_eeSSMZprime,e2eta_eeSSMZprime,e1phi_eeSSMZprime,e2phi_eeSSMZprime)])




print(e1pt_eeSSMZprime.shape)
print(e1eta_eeSSMZprime.shape)
print(e1phi_eeSSMZprime.shape)

print(e2pt_eeSSMZprime.shape)
print(e2eta_eeSSMZprime.shape)
print(e2phi_eeSSMZprime.shape)

print(invariant_mass_eeSSMZprime.shape)
print(e1e2diffeta_eeSSMZprime.shape)
print(e1e2R_eeSSMZprime.shape)
# Out:
# 0.636719
# 0.636541
# (1908796,)
# (1908796,)
# (1908796,)
# (1908796,)
# (1908796,)
# (1908796,)
# (1908796,)
# (1908796,)
# (1908796,)

# %%
print(min(e1eta_eeSSMZprime))
print(max(e1eta_eeSSMZprime))

print(min(e2eta_eeSSMZprime))
print(max(e2eta_eeSSMZprime))
# Out:
# -2.646
# 2.649
# -2.649
# 2.649

# %%
# NOW DATA IS CHECKED

bins_atlas = [70, 80.0, 90.0, 105.0, 120.0, 140.0, 160.0, 180.0, 210.0, 240.0, 275.0, 315.0, 360.0, 415.0, 475.0, 545.0, 625.0, 715.0, 825.0, 950.0, 1100.0, 1250.0, 1450.0, 1650.0, 1900.0, 2200.0, 2500.0, 2850.0, 3250.0, 3750.0, 4350.0, 5000.0, 5750.0, 6600.0, 7500.0, 8750.0, 10000.0, 11500.0, 13000.0, 20000]

plt.hist(invariant_mass_eeSM, bins=bins_atlas, lw=2, edgecolor='blue', histtype='step', label="SM")
plt.hist(invariant_mass_eeSSMZprime, bins=bins_atlas, lw=2, edgecolor='red', histtype='step', label="$Z'_{SSM}$")

plt.grid()  # Add grid lines

plt.title(r"Z/Z'$\rightarrow \mu+ \mu-$",fontsize=14)  # Titles etc
plt.xlabel("$m_{ll}$ (GeV)",fontsize=14)
plt.ylabel("Events",fontsize=14)

plt.xlim(70.,20000)
plt.ylim(1e0,1e7)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xscale('log')
plt.yscale('log')
plt.legend(loc='upper left',fontsize=12)

plt.show()




plt.hist(e1e2diffeta_eeSM, bins=100, range=[-5,5], lw=2, edgecolor='blue', histtype='step', label="SM")
plt.hist(e1e2diffeta_eeSSMZprime, bins=100, range=[-5,5], lw=2, edgecolor='red', histtype='step', label="$Z'_{SSM}$")

plt.grid()  # Add grid lines

plt.title(r"Z/Z'$\rightarrow \mu+ \mu-$",fontsize=14)  # Titles etc
plt.xlabel("$\Delta \eta_{ll}$",fontsize=14)
plt.ylabel("Events",fontsize=14)

plt.xlim(-5,5)
plt.ylim(1e0,1e7)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#plt.xscale('log')
plt.yscale('log')
plt.legend(loc='upper left',fontsize=12)

plt.show()




plt.hist(e1e2R_eeSM, bins=82, range=[0,8.2], lw=2, edgecolor='blue', histtype='step', label="SM")
plt.hist(e1e2R_eeSSMZprime, bins=82, range=[0,8.2], lw=2, edgecolor='red', histtype='step', label="$Z'_{SSM}$")

plt.grid()  # Add grid lines

plt.title(r"Z/Z'$\rightarrow \mu+ \mu-$",fontsize=14)  # Titles etc
plt.xlabel("$R$",fontsize=14)
plt.ylabel("Events",fontsize=14)

plt.xlim(0.,8.2)
plt.ylim(1e0,1e7)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#plt.xscale('log')
plt.yscale('log')
plt.legend(loc='upper left',fontsize=12)

plt.show()

# %% [markdown]
# ### Train-test-val datasets

# %%
# to normalize
scaler = preprocessing.MinMaxScaler()

# Number of data points (per-class) for the ML classifier
num_data = 750000



df = pd.DataFrame()

df['e1-pt']= np.concatenate([e1pt_eeSM[:num_data],e1pt_eeSSMZprime[:num_data]])
df['e1-eta']= np.concatenate([e1eta_eeSM[:num_data],e1eta_eeSSMZprime[:num_data]])
df['e1-phi']= np.concatenate([e1phi_eeSM[:num_data],e1phi_eeSSMZprime[:num_data]])

df['e2-pt']= np.concatenate([e2pt_eeSM[:num_data],e2pt_eeSSMZprime[:num_data]])
df['e2-eta']= np.concatenate([e2eta_eeSM[:num_data],e2eta_eeSSMZprime[:num_data]])
df['e2-phi']= np.concatenate([e2phi_eeSM[:num_data],e2phi_eeSSMZprime[:num_data]])

df['mll']= np.concatenate([invariant_mass_eeSM[:num_data],invariant_mass_eeSSMZprime[:num_data]])
df['delta-eta']= np.concatenate([e1e2diffeta_eeSM[:num_data],e1e2diffeta_eeSSMZprime[:num_data]])
df['R']= np.concatenate([e1e2R_eeSM[:num_data],e1e2R_eeSSMZprime[:num_data]])

df['Y'] = np.concatenate([np.zeros(num_data),np.ones(num_data)])


# remove the used data
del e1pt_eeSM
del e1eta_eeSM
del e1phi_eeSM

del e2pt_eeSM
del e2eta_eeSM
del e2phi_eeSM

del e1pt_eeSSMZprime
del e1eta_eeSSMZprime
del e1phi_eeSSMZprime

del e2pt_eeSSMZprime
del e2eta_eeSSMZprime
del e2phi_eeSSMZprime


# NORMALIZE
df = scaler.fit_transform(df)
df = pd.DataFrame(df,columns=['e1-pt','e1-eta','e1-phi','e2-pt','e2-eta','e2-phi','mll','delta-eta','R','Y'])


# print df to see the data
print(df)


# X and Y for the classifier
X_mon = df[['e1-pt','e1-eta','e1-phi','e2-pt','e2-eta','e2-phi']].values
y_mon = df[['Y']].values

del df

# divide into train-val and test data samples
test_ratio = 1./3
val_ratio = 0.25


X_mon_aux, X_mon_test, y_mon_aux, y_mon_test = train_test_split(X_mon,
                                                                y_mon,
                                                                test_size=test_ratio,
                                                                random_state=42,
                                                                #stratify = y_mon,
                                                                shuffle=True)


X_mon_train, X_mon_val, y_mon_train, y_mon_val = train_test_split(X_mon_aux,
                                                                  y_mon_aux,
                                                                  test_size=val_ratio,
                                                                  random_state=42,
                                                                  #stratify = y_mon_aux,
                                                                  shuffle=True)


print('')
print('X_mon_train : ', X_mon_train.shape)
print('y_mon_train : ', y_mon_train.shape)
print('X_mon_val : ', X_mon_val.shape)
print('y_mon_val : ', y_mon_val.shape)
print('X_mon_test : ', X_mon_test.shape)
print('y_mon_test : ', y_mon_test.shape)
print('')
# Out:
#             e1-pt    e1-eta    e1-phi     e2-pt    e2-eta    e2-phi       mll  \
# 0        0.185753  0.591124  0.081158  0.223323  0.609664  0.557288  0.032343
# 1        0.181318  0.636638  0.312540  0.212468  0.353341  0.827976  0.099079
# 2        0.245156  0.703494  0.972311  0.278057  0.502831  0.473265  0.147658
# 3        0.170692  0.581114  0.581158  0.186446  0.567573  0.101528  0.002317
# 4        0.151041  0.543909  0.273711  0.193851  0.285957  0.765595  0.049868
# ...           ...       ...       ...       ...       ...       ...       ...
# 1499995  0.176453  0.565250  0.207670  0.223621  0.625142  0.708943  0.030399
# 1499996  0.249848  0.375449  0.859803  0.263638  0.510759  0.366645  0.115101
# 1499997  0.750491  0.532200  0.621897  0.760213  0.490940  0.121897  0.683489
# 1499998  0.116444  0.786025  0.214513  0.153794  0.388448  0.710376  0.062306
# 1499999  0.197233  0.327668  0.329726  0.229237  0.586825  0.808721  0.109581
#
#          delta-eta         R    Y
# 0         0.490548  0.271333  0.0
# 1         0.643988  0.364958  0.0
# 2         0.601958  0.322957  0.0
# 3         0.506861  0.274793  0.0
# 4         0.631129  0.334095  0.0
# ...            ...       ...  ...
# 1499995   0.469533  0.299293  1.0
# 1499996   0.431245  0.301664  1.0
# 1499997   0.520967  0.296677  1.0
# 1499998   0.702044  0.395995  1.0
# 1499999   0.368295  0.322299  1.0
#
# [1500000 rows x 10 columns]
#
# X_mon_train :  (750000, 6)
# y_mon_train :  (750000, 1)
# X_mon_val :  (250000, 6)
# y_mon_val :  (250000, 1)
# X_mon_test :  (500000, 6)
# y_mon_test :  (500000, 1)

# %% [markdown]
# ### XGBoost (per-event)

# %% [markdown]
# ##### For 1 ML

# %%
# XGBoost with only the kinematic variables of the leptons

# CLASSIFIER
classifier = XGBClassifier(
    n_estimators=2500,
    learning_rate=0.1,
    reg_lambda=0.0,reg_alpha=0.0,
    gamma=0.0,objective='binary:logistic',
    max_depth=5)

# FIT
classifier.fit(X_mon_train,y_mon_train,eval_set=[(X_mon_train, y_mon_train), (X_mon_val, y_mon_val)],
        eval_metric='logloss',early_stopping_rounds=50,#early stopping
        verbose=True)

# PREDICTIONS
y_pred_xg_1ML = classifier.predict_proba(X_mon_test).T[1]


# ROC
fpr_mon_xg, tpr_mon_xg, _ = roc_curve(y_mon_test, y_pred_xg_1ML)
roc_auc_xg = auc(fpr_mon_xg, tpr_mon_xg)


# PLOT THE ROC WITH AUC
fig = plt.figure(figsize=(6, 6))
gs = gridspec.GridSpec(1, 1) 
ax0 = plt.subplot(gs[0])
ax0.yaxis.set_ticks_position('both')
ax0.xaxis.set_ticks_position('both')
ax0.tick_params(direction="in",which="both")
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
ax0.minorticks_on()


plt.plot(tpr_mon_xg,1-fpr_mon_xg,label="$f_{1}$, AUC = %0.2f" % roc_auc_xg,color="orange",ls=":",lw=4)
plt.plot([1,0],[0,1],ls=":",color="grey")
plt.xlabel("True Positive Rate",fontsize=16)
plt.ylabel("1 $-$ False Positive Rate",fontsize=16)
plt.legend()
plt.title(r"SSM Z' - XGBoost",fontsize=16)
plt.xlim([0,1])
plt.ylim([0,1])
plt.yticks([0.2,0.4,0.6,0.8,1.])
plt.legend(frameon=False,fontsize=16)
plt.show()




feature_names = np.array(['e1-pt','e1-eta','e1-phi','e2-pt','e2-eta','e2-phi'])
plt.barh(feature_names, classifier.feature_importances_)
plt.xlabel("Xgboost Feature Importance")
plt.show()
# Out:
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [0]	validation_0-logloss:0.67108	validation_1-logloss:0.67137
# [1]	validation_0-logloss:0.65335	validation_1-logloss:0.65352
# [2]	validation_0-logloss:0.63801	validation_1-logloss:0.63850
# [3]	validation_0-logloss:0.62523	validation_1-logloss:0.62564
# [4]	validation_0-logloss:0.61433	validation_1-logloss:0.61492
# [5]	validation_0-logloss:0.60478	validation_1-logloss:0.60546
# [6]	validation_0-logloss:0.59676	validation_1-logloss:0.59757
# [7]	validation_0-logloss:0.58993	validation_1-logloss:0.59080
# [8]	validation_0-logloss:0.58407	validation_1-logloss:0.58499
# [9]	validation_0-logloss:0.57849	validation_1-logloss:0.57950
# [10]	validation_0-logloss:0.57396	validation_1-logloss:0.57499
# [11]	validation_0-logloss:0.56985	validation_1-logloss:0.57098
# [12]	validation_0-logloss:0.56624	validation_1-logloss:0.56736
# [13]	validation_0-logloss:0.56280	validation_1-logloss:0.56398
# [14]	validation_0-logloss:0.55982	validation_1-logloss:0.56102
# [15]	validation_0-logloss:0.55727	validation_1-logloss:0.55852
# [16]	validation_0-logloss:0.55472	validation_1-logloss:0.55603
# [17]	validation_0-logloss:0.55251	validation_1-logloss:0.55385
# [18]	validation_0-logloss:0.55058	validation_1-logloss:0.55196
# [19]	validation_0-logloss:0.54870	validation_1-logloss:0.55013
# [20]	validation_0-logloss:0.54712	validation_1-logloss:0.54860
# [21]	validation_0-logloss:0.54548	validation_1-logloss:0.54697
# [22]	validation_0-logloss:0.54414	validation_1-logloss:0.54563
# [23]	validation_0-logloss:0.54281	validation_1-logloss:0.54434
# [24]	validation_0-logloss:0.54174	validation_1-logloss:0.54331
# [25]	validation_0-logloss:0.54078	validation_1-logloss:0.54237
# [26]	validation_0-logloss:0.53975	validation_1-logloss:0.54139
# [27]	validation_0-logloss:0.53857	validation_1-logloss:0.54029
# [28]	validation_0-logloss:0.53751	validation_1-logloss:0.53923
# [29]	validation_0-logloss:0.53656	validation_1-logloss:0.53828
# [30]	validation_0-logloss:0.53567	validation_1-logloss:0.53742
# [31]	validation_0-logloss:0.53512	validation_1-logloss:0.53687
# [32]	validation_0-logloss:0.53425	validation_1-logloss:0.53605
# [33]	validation_0-logloss:0.53364	validation_1-logloss:0.53546
# [34]	validation_0-logloss:0.53312	validation_1-logloss:0.53495
# [35]	validation_0-logloss:0.53231	validation_1-logloss:0.53416
# [36]	validation_0-logloss:0.53181	validation_1-logloss:0.53373
# [37]	validation_0-logloss:0.53113	validation_1-logloss:0.53304
# [38]	validation_0-logloss:0.53033	validation_1-logloss:0.53232
# [39]	validation_0-logloss:0.52989	validation_1-logloss:0.53185
# [40]	validation_0-logloss:0.52933	validation_1-logloss:0.53134
# [41]	validation_0-logloss:0.52888	validation_1-logloss:0.53090
# [42]	validation_0-logloss:0.52849	validation_1-logloss:0.53053
# [43]	validation_0-logloss:0.52803	validation_1-logloss:0.53010
# [44]	validation_0-logloss:0.52769	validation_1-logloss:0.52975
# [45]	validation_0-logloss:0.52704	validation_1-logloss:0.52914
# [46]	validation_0-logloss:0.52660	validation_1-logloss:0.52875
# [47]	validation_0-logloss:0.52580	validation_1-logloss:0.52803
# [48]	validation_0-logloss:0.52535	validation_1-logloss:0.52761
# [49]	validation_0-logloss:0.52501	validation_1-logloss:0.52729
# [50]	validation_0-logloss:0.52451	validation_1-logloss:0.52683
# [51]	validation_0-logloss:0.52407	validation_1-logloss:0.52644
# [52]	validation_0-logloss:0.52364	validation_1-logloss:0.52603
# [53]	validation_0-logloss:0.52344	validation_1-logloss:0.52584
# [54]	validation_0-logloss:0.52315	validation_1-logloss:0.52559
# [55]	validation_0-logloss:0.52284	validation_1-logloss:0.52532
# [56]	validation_0-logloss:0.52224	validation_1-logloss:0.52477
# [57]	validation_0-logloss:0.52179	validation_1-logloss:0.52437
# [58]	validation_0-logloss:0.52157	validation_1-logloss:0.52418
# [59]	validation_0-logloss:0.52136	validation_1-logloss:0.52400
# [60]	validation_0-logloss:0.52113	validation_1-logloss:0.52379
# [61]	validation_0-logloss:0.52089	validation_1-logloss:0.52359
# [62]	validation_0-logloss:0.52061	validation_1-logloss:0.52336
# [63]	validation_0-logloss:0.52039	validation_1-logloss:0.52315
# [64]	validation_0-logloss:0.52021	validation_1-logloss:0.52298
# [65]	validation_0-logloss:0.52006	validation_1-logloss:0.52284
# [66]	validation_0-logloss:0.51977	validation_1-logloss:0.52257
# [67]	validation_0-logloss:0.51961	validation_1-logloss:0.52243
# [68]	validation_0-logloss:0.51930	validation_1-logloss:0.52217
# [69]	validation_0-logloss:0.51889	validation_1-logloss:0.52183
# [70]	validation_0-logloss:0.51873	validation_1-logloss:0.52170
# [71]	validation_0-logloss:0.51855	validation_1-logloss:0.52155
# [72]	validation_0-logloss:0.51824	validation_1-logloss:0.52127
# [73]	validation_0-logloss:0.51811	validation_1-logloss:0.52117
# [74]	validation_0-logloss:0.51794	validation_1-logloss:0.52102
# [75]	validation_0-logloss:0.51783	validation_1-logloss:0.52094
# [76]	validation_0-logloss:0.51762	validation_1-logloss:0.52077
# [77]	validation_0-logloss:0.51751	validation_1-logloss:0.52069
# [78]	validation_0-logloss:0.51737	validation_1-logloss:0.52056
# [79]	validation_0-logloss:0.51719	validation_1-logloss:0.52041
# [80]	validation_0-logloss:0.51709	validation_1-logloss:0.52033
# [81]	validation_0-logloss:0.51698	validation_1-logloss:0.52024
# [82]	validation_0-logloss:0.51682	validation_1-logloss:0.52012
# [83]	validation_0-logloss:0.51668	validation_1-logloss:0.52000
# [84]	validation_0-logloss:0.51654	validation_1-logloss:0.51990
# [85]	validation_0-logloss:0.51645	validation_1-logloss:0.51982
# [86]	validation_0-logloss:0.51636	validation_1-logloss:0.51975
# [87]	validation_0-logloss:0.51620	validation_1-logloss:0.51961
# [88]	validation_0-logloss:0.51609	validation_1-logloss:0.51955
# [89]	validation_0-logloss:0.51600	validation_1-logloss:0.51947
# [90]	validation_0-logloss:0.51592	validation_1-logloss:0.51940
# [91]	validation_0-logloss:0.51579	validation_1-logloss:0.51931
# [92]	validation_0-logloss:0.51573	validation_1-logloss:0.51927
# [93]	validation_0-logloss:0.51565	validation_1-logloss:0.51920
# [94]	validation_0-logloss:0.51559	validation_1-logloss:0.51915
# [95]	validation_0-logloss:0.51553	validation_1-logloss:0.51911
# [96]	validation_0-logloss:0.51537	validation_1-logloss:0.51899
# [97]	validation_0-logloss:0.51528	validation_1-logloss:0.51892
# [98]	validation_0-logloss:0.51524	validation_1-logloss:0.51890
# [99]	validation_0-logloss:0.51517	validation_1-logloss:0.51885
# [100]	validation_0-logloss:0.51512	validation_1-logloss:0.51882
# [101]	validation_0-logloss:0.51503	validation_1-logloss:0.51876
# [102]	validation_0-logloss:0.51497	validation_1-logloss:0.51873
# [103]	validation_0-logloss:0.51492	validation_1-logloss:0.51868
# [104]	validation_0-logloss:0.51487	validation_1-logloss:0.51866
# [105]	validation_0-logloss:0.51483	validation_1-logloss:0.51864
# [106]	validation_0-logloss:0.51471	validation_1-logloss:0.51856
# [107]	validation_0-logloss:0.51466	validation_1-logloss:0.51852
# [108]	validation_0-logloss:0.51459	validation_1-logloss:0.51848
# [109]	validation_0-logloss:0.51455	validation_1-logloss:0.51845
# [110]	validation_0-logloss:0.51449	validation_1-logloss:0.51843
# [111]	validation_0-logloss:0.51445	validation_1-logloss:0.51839
# [112]	validation_0-logloss:0.51442	validation_1-logloss:0.51838
# [113]	validation_0-logloss:0.51437	validation_1-logloss:0.51835
# [114]	validation_0-logloss:0.51432	validation_1-logloss:0.51831
# [115]	validation_0-logloss:0.51426	validation_1-logloss:0.51827
# [116]	validation_0-logloss:0.51421	validation_1-logloss:0.51825
# [117]	validation_0-logloss:0.51417	validation_1-logloss:0.51824
# [118]	validation_0-logloss:0.51413	validation_1-logloss:0.51820
# [119]	validation_0-logloss:0.51409	validation_1-logloss:0.51819
# [120]	validation_0-logloss:0.51401	validation_1-logloss:0.51813
# [121]	validation_0-logloss:0.51397	validation_1-logloss:0.51811
# [122]	validation_0-logloss:0.51392	validation_1-logloss:0.51809
# [123]	validation_0-logloss:0.51390	validation_1-logloss:0.51809
# [124]	validation_0-logloss:0.51386	validation_1-logloss:0.51808
# [125]	validation_0-logloss:0.51384	validation_1-logloss:0.51806
# [126]	validation_0-logloss:0.51382	validation_1-logloss:0.51805
# [127]	validation_0-logloss:0.51378	validation_1-logloss:0.51803
# [128]	validation_0-logloss:0.51376	validation_1-logloss:0.51802
# [129]	validation_0-logloss:0.51373	validation_1-logloss:0.51801
# [130]	validation_0-logloss:0.51368	validation_1-logloss:0.51799
# [131]	validation_0-logloss:0.51364	validation_1-logloss:0.51796
# [132]	validation_0-logloss:0.51361	validation_1-logloss:0.51796
# [133]	validation_0-logloss:0.51357	validation_1-logloss:0.51792
# [134]	validation_0-logloss:0.51353	validation_1-logloss:0.51790
# [135]	validation_0-logloss:0.51349	validation_1-logloss:0.51789
# [136]	validation_0-logloss:0.51347	validation_1-logloss:0.51789
# [137]	validation_0-logloss:0.51344	validation_1-logloss:0.51788
# [138]	validation_0-logloss:0.51340	validation_1-logloss:0.51785
# [139]	validation_0-logloss:0.51337	validation_1-logloss:0.51784
# [140]	validation_0-logloss:0.51334	validation_1-logloss:0.51782
# [141]	validation_0-logloss:0.51331	validation_1-logloss:0.51781
# [142]	validation_0-logloss:0.51326	validation_1-logloss:0.51777
# [143]	validation_0-logloss:0.51323	validation_1-logloss:0.51775
# [144]	validation_0-logloss:0.51320	validation_1-logloss:0.51775
# [145]	validation_0-logloss:0.51318	validation_1-logloss:0.51774
# [146]	validation_0-logloss:0.51316	validation_1-logloss:0.51775
# [147]	validation_0-logloss:0.51313	validation_1-logloss:0.51774
# [148]	validation_0-logloss:0.51310	validation_1-logloss:0.51774
# [149]	validation_0-logloss:0.51301	validation_1-logloss:0.51769
# [150]	validation_0-logloss:0.51299	validation_1-logloss:0.51768
# [151]	validation_0-logloss:0.51298	validation_1-logloss:0.51768
# [152]	validation_0-logloss:0.51295	validation_1-logloss:0.51767
# [153]	validation_0-logloss:0.51292	validation_1-logloss:0.51767
# [154]	validation_0-logloss:0.51291	validation_1-logloss:0.51767
# [155]	validation_0-logloss:0.51288	validation_1-logloss:0.51766
# [156]	validation_0-logloss:0.51284	validation_1-logloss:0.51763
# [157]	validation_0-logloss:0.51282	validation_1-logloss:0.51763
# [158]	validation_0-logloss:0.51280	validation_1-logloss:0.51763
# [159]	validation_0-logloss:0.51278	validation_1-logloss:0.51763
# [160]	validation_0-logloss:0.51277	validation_1-logloss:0.51762
# [161]	validation_0-logloss:0.51275	validation_1-logloss:0.51762
# [162]	validation_0-logloss:0.51273	validation_1-logloss:0.51762
# [163]	validation_0-logloss:0.51267	validation_1-logloss:0.51758
# [164]	validation_0-logloss:0.51261	validation_1-logloss:0.51755
# [165]	validation_0-logloss:0.51259	validation_1-logloss:0.51756
# [166]	validation_0-logloss:0.51258	validation_1-logloss:0.51755
# [167]	validation_0-logloss:0.51257	validation_1-logloss:0.51755
# [168]	validation_0-logloss:0.51254	validation_1-logloss:0.51754
# [169]	validation_0-logloss:0.51253	validation_1-logloss:0.51754
# [170]	validation_0-logloss:0.51248	validation_1-logloss:0.51751
# [171]	validation_0-logloss:0.51245	validation_1-logloss:0.51751
# [172]	validation_0-logloss:0.51244	validation_1-logloss:0.51751
# [173]	validation_0-logloss:0.51242	validation_1-logloss:0.51750
# [174]	validation_0-logloss:0.51238	validation_1-logloss:0.51750
# [175]	validation_0-logloss:0.51237	validation_1-logloss:0.51749
# [176]	validation_0-logloss:0.51236	validation_1-logloss:0.51749
# [177]	validation_0-logloss:0.51234	validation_1-logloss:0.51749
# [178]	validation_0-logloss:0.51230	validation_1-logloss:0.51747
# [179]	validation_0-logloss:0.51227	validation_1-logloss:0.51747
# [180]	validation_0-logloss:0.51225	validation_1-logloss:0.51747
# [181]	validation_0-logloss:0.51222	validation_1-logloss:0.51746
# [182]	validation_0-logloss:0.51220	validation_1-logloss:0.51746
# [183]	validation_0-logloss:0.51218	validation_1-logloss:0.51746
# [184]	validation_0-logloss:0.51216	validation_1-logloss:0.51746
# [185]	validation_0-logloss:0.51215	validation_1-logloss:0.51746
# [186]	validation_0-logloss:0.51214	validation_1-logloss:0.51746
# [187]	validation_0-logloss:0.51212	validation_1-logloss:0.51746
# [188]	validation_0-logloss:0.51210	validation_1-logloss:0.51745
# [189]	validation_0-logloss:0.51208	validation_1-logloss:0.51745
# [190]	validation_0-logloss:0.51207	validation_1-logloss:0.51745
# [191]	validation_0-logloss:0.51206	validation_1-logloss:0.51744
# [192]	validation_0-logloss:0.51205	validation_1-logloss:0.51745
# [193]	validation_0-logloss:0.51204	validation_1-logloss:0.51745
# [194]	validation_0-logloss:0.51201	validation_1-logloss:0.51743
# [195]	validation_0-logloss:0.51198	validation_1-logloss:0.51743
# [196]	validation_0-logloss:0.51197	validation_1-logloss:0.51743
# [197]	validation_0-logloss:0.51196	validation_1-logloss:0.51743
# [198]	validation_0-logloss:0.51194	validation_1-logloss:0.51742
# [199]	validation_0-logloss:0.51192	validation_1-logloss:0.51742
# [200]	validation_0-logloss:0.51190	validation_1-logloss:0.51742
# [201]	validation_0-logloss:0.51187	validation_1-logloss:0.51742
# [202]	validation_0-logloss:0.51186	validation_1-logloss:0.51742
# [203]	validation_0-logloss:0.51186	validation_1-logloss:0.51743
# [204]	validation_0-logloss:0.51184	validation_1-logloss:0.51743
# [205]	validation_0-logloss:0.51181	validation_1-logloss:0.51742
# [206]	validation_0-logloss:0.51179	validation_1-logloss:0.51742
# [207]	validation_0-logloss:0.51179	validation_1-logloss:0.51742
# [208]	validation_0-logloss:0.51177	validation_1-logloss:0.51742
# [209]	validation_0-logloss:0.51175	validation_1-logloss:0.51742
# [210]	validation_0-logloss:0.51172	validation_1-logloss:0.51740
# [211]	validation_0-logloss:0.51170	validation_1-logloss:0.51740
# [212]	validation_0-logloss:0.51168	validation_1-logloss:0.51741
# [213]	validation_0-logloss:0.51166	validation_1-logloss:0.51740
# [214]	validation_0-logloss:0.51166	validation_1-logloss:0.51740
# [215]	validation_0-logloss:0.51165	validation_1-logloss:0.51740
# [216]	validation_0-logloss:0.51163	validation_1-logloss:0.51740
# [217]	validation_0-logloss:0.51161	validation_1-logloss:0.51740
# [218]	validation_0-logloss:0.51160	validation_1-logloss:0.51740
# [219]	validation_0-logloss:0.51157	validation_1-logloss:0.51740
# [220]	validation_0-logloss:0.51156	validation_1-logloss:0.51740
# [221]	validation_0-logloss:0.51154	validation_1-logloss:0.51740
# [222]	validation_0-logloss:0.51150	validation_1-logloss:0.51738
# [223]	validation_0-logloss:0.51148	validation_1-logloss:0.51739
# [224]	validation_0-logloss:0.51146	validation_1-logloss:0.51739
# [225]	validation_0-logloss:0.51145	validation_1-logloss:0.51739
# [226]	validation_0-logloss:0.51143	validation_1-logloss:0.51739
# [227]	validation_0-logloss:0.51142	validation_1-logloss:0.51739
# [228]	validation_0-logloss:0.51140	validation_1-logloss:0.51739
# [229]	validation_0-logloss:0.51138	validation_1-logloss:0.51738
# [230]	validation_0-logloss:0.51137	validation_1-logloss:0.51738
# [231]	validation_0-logloss:0.51135	validation_1-logloss:0.51738
# [232]	validation_0-logloss:0.51134	validation_1-logloss:0.51738
# [233]	validation_0-logloss:0.51133	validation_1-logloss:0.51738
# [234]	validation_0-logloss:0.51131	validation_1-logloss:0.51737
# [235]	validation_0-logloss:0.51129	validation_1-logloss:0.51738
# [236]	validation_0-logloss:0.51128	validation_1-logloss:0.51738
# [237]	validation_0-logloss:0.51127	validation_1-logloss:0.51738
# [238]	validation_0-logloss:0.51124	validation_1-logloss:0.51738
# [239]	validation_0-logloss:0.51123	validation_1-logloss:0.51737
# [240]	validation_0-logloss:0.51122	validation_1-logloss:0.51737
# [241]	validation_0-logloss:0.51119	validation_1-logloss:0.51737
# [242]	validation_0-logloss:0.51116	validation_1-logloss:0.51737
# [243]	validation_0-logloss:0.51112	validation_1-logloss:0.51734
# [244]	validation_0-logloss:0.51110	validation_1-logloss:0.51734
# [245]	validation_0-logloss:0.51108	validation_1-logloss:0.51735
# [246]	validation_0-logloss:0.51107	validation_1-logloss:0.51735
# [247]	validation_0-logloss:0.51107	validation_1-logloss:0.51734
# [248]	validation_0-logloss:0.51106	validation_1-logloss:0.51735
# [249]	validation_0-logloss:0.51105	validation_1-logloss:0.51735
# [250]	validation_0-logloss:0.51101	validation_1-logloss:0.51733
# [251]	validation_0-logloss:0.51099	validation_1-logloss:0.51734
# [252]	validation_0-logloss:0.51097	validation_1-logloss:0.51734
# [253]	validation_0-logloss:0.51094	validation_1-logloss:0.51734
# [254]	validation_0-logloss:0.51093	validation_1-logloss:0.51734
# [255]	validation_0-logloss:0.51091	validation_1-logloss:0.51734
# [256]	validation_0-logloss:0.51089	validation_1-logloss:0.51733
# [257]	validation_0-logloss:0.51088	validation_1-logloss:0.51733
# [258]	validation_0-logloss:0.51086	validation_1-logloss:0.51733
# [259]	validation_0-logloss:0.51084	validation_1-logloss:0.51733
# [260]	validation_0-logloss:0.51082	validation_1-logloss:0.51733
# [261]	validation_0-logloss:0.51078	validation_1-logloss:0.51732
# [262]	validation_0-logloss:0.51077	validation_1-logloss:0.51732
# [263]	validation_0-logloss:0.51076	validation_1-logloss:0.51732
# [264]	validation_0-logloss:0.51075	validation_1-logloss:0.51732
# [265]	validation_0-logloss:0.51074	validation_1-logloss:0.51732
# [266]	validation_0-logloss:0.51073	validation_1-logloss:0.51733
# [267]	validation_0-logloss:0.51071	validation_1-logloss:0.51733
# [268]	validation_0-logloss:0.51070	validation_1-logloss:0.51733
# [269]	validation_0-logloss:0.51069	validation_1-logloss:0.51733
# [270]	validation_0-logloss:0.51067	validation_1-logloss:0.51732
# [271]	validation_0-logloss:0.51064	validation_1-logloss:0.51732
# [272]	validation_0-logloss:0.51062	validation_1-logloss:0.51732
# [273]	validation_0-logloss:0.51060	validation_1-logloss:0.51733
# [274]	validation_0-logloss:0.51058	validation_1-logloss:0.51733
# [275]	validation_0-logloss:0.51058	validation_1-logloss:0.51733
# [276]	validation_0-logloss:0.51056	validation_1-logloss:0.51733
# [277]	validation_0-logloss:0.51055	validation_1-logloss:0.51733
# [278]	validation_0-logloss:0.51053	validation_1-logloss:0.51733
# [279]	validation_0-logloss:0.51052	validation_1-logloss:0.51733
# [280]	validation_0-logloss:0.51051	validation_1-logloss:0.51733
# [281]	validation_0-logloss:0.51050	validation_1-logloss:0.51733
# [282]	validation_0-logloss:0.51048	validation_1-logloss:0.51733
# [283]	validation_0-logloss:0.51047	validation_1-logloss:0.51733
# [284]	validation_0-logloss:0.51045	validation_1-logloss:0.51733
# [285]	validation_0-logloss:0.51042	validation_1-logloss:0.51732
# [286]	validation_0-logloss:0.51040	validation_1-logloss:0.51733
# [287]	validation_0-logloss:0.51038	validation_1-logloss:0.51732
# [288]	validation_0-logloss:0.51037	validation_1-logloss:0.51732
# [289]	validation_0-logloss:0.51036	validation_1-logloss:0.51732
# [290]	validation_0-logloss:0.51035	validation_1-logloss:0.51732
# [291]	validation_0-logloss:0.51033	validation_1-logloss:0.51732
# [292]	validation_0-logloss:0.51032	validation_1-logloss:0.51732
# [293]	validation_0-logloss:0.51031	validation_1-logloss:0.51732
# [294]	validation_0-logloss:0.51029	validation_1-logloss:0.51733
# [295]	validation_0-logloss:0.51027	validation_1-logloss:0.51733
# [296]	validation_0-logloss:0.51026	validation_1-logloss:0.51733
# [297]	validation_0-logloss:0.51025	validation_1-logloss:0.51733
# [298]	validation_0-logloss:0.51024	validation_1-logloss:0.51733
# [299]	validation_0-logloss:0.51021	validation_1-logloss:0.51732
# [300]	validation_0-logloss:0.51019	validation_1-logloss:0.51732
# [301]	validation_0-logloss:0.51017	validation_1-logloss:0.51733
# [302]	validation_0-logloss:0.51016	validation_1-logloss:0.51733
# [303]	validation_0-logloss:0.51015	validation_1-logloss:0.51732
# [304]	validation_0-logloss:0.51013	validation_1-logloss:0.51732
# [305]	validation_0-logloss:0.51011	validation_1-logloss:0.51732
# [306]	validation_0-logloss:0.51010	validation_1-logloss:0.51732
# [307]	validation_0-logloss:0.51008	validation_1-logloss:0.51733
# [308]	validation_0-logloss:0.51006	validation_1-logloss:0.51733
# [309]	validation_0-logloss:0.51005	validation_1-logloss:0.51734
# [310]	validation_0-logloss:0.51004	validation_1-logloss:0.51733
# [311]	validation_0-logloss:0.51001	validation_1-logloss:0.51733
# [312]	validation_0-logloss:0.51000	validation_1-logloss:0.51733
# [313]	validation_0-logloss:0.50999	validation_1-logloss:0.51733
# [314]	validation_0-logloss:0.50998	validation_1-logloss:0.51733
# [315]	validation_0-logloss:0.50996	validation_1-logloss:0.51733
# [316]	validation_0-logloss:0.50994	validation_1-logloss:0.51733
# [317]	validation_0-logloss:0.50994	validation_1-logloss:0.51733
# [318]	validation_0-logloss:0.50992	validation_1-logloss:0.51732
# [319]	validation_0-logloss:0.50991	validation_1-logloss:0.51733
# [320]	validation_0-logloss:0.50989	validation_1-logloss:0.51733
# [321]	validation_0-logloss:0.50986	validation_1-logloss:0.51733
# [322]	validation_0-logloss:0.50983	validation_1-logloss:0.51733
# [323]	validation_0-logloss:0.50982	validation_1-logloss:0.51733
# [324]	validation_0-logloss:0.50980	validation_1-logloss:0.51733
# [325]	validation_0-logloss:0.50979	validation_1-logloss:0.51734
# [326]	validation_0-logloss:0.50978	validation_1-logloss:0.51733
# [327]	validation_0-logloss:0.50976	validation_1-logloss:0.51734
# [328]	validation_0-logloss:0.50974	validation_1-logloss:0.51733
# [329]	validation_0-logloss:0.50972	validation_1-logloss:0.51734
# [330]	validation_0-logloss:0.50971	validation_1-logloss:0.51734
# [331]	validation_0-logloss:0.50968	validation_1-logloss:0.51733
# [332]	validation_0-logloss:0.50965	validation_1-logloss:0.51733
# [333]	validation_0-logloss:0.50964	validation_1-logloss:0.51733
# [334]	validation_0-logloss:0.50962	validation_1-logloss:0.51733
# [335]	validation_0-logloss:0.50960	validation_1-logloss:0.51733
# [336]	validation_0-logloss:0.50959	validation_1-logloss:0.51733
# [337]	validation_0-logloss:0.50957	validation_1-logloss:0.51732
# [338]	validation_0-logloss:0.50955	validation_1-logloss:0.51733
# [339]	validation_0-logloss:0.50955	validation_1-logloss:0.51733
# [340]	validation_0-logloss:0.50953	validation_1-logloss:0.51733
# [341]	validation_0-logloss:0.50950	validation_1-logloss:0.51732

# %% [markdown]
# ##### For 10 ML

# %%
# XGBoost with only the kinematic variables of the leptons

iterations_ML = 10

print('ML iteration 1')

# CLASSIFIER
classifier = XGBClassifier(
    n_estimators=2500,
    learning_rate=0.1,
    reg_lambda=0.0,reg_alpha=0.0,
    gamma=0.0,objective='binary:logistic',
    max_depth=5)

ran_ind = np.random.choice(np.arange(len(X_mon_train)), size = len(X_mon_train), replace = True)

# FIT
classifier.fit(X_mon_train[ran_ind],y_mon_train[ran_ind],eval_set=[(X_mon_train[ran_ind], y_mon_train[ran_ind]), (X_mon_val, y_mon_val)],
        eval_metric='logloss',early_stopping_rounds=50,#early stopping
        verbose=True)

# PREDICTIONS
y_pred_xg_aux = classifier.predict_proba(X_mon_test).T[1]
y_pred_xg_auxRE = np.reshape(y_pred_xg_aux, (1,len(y_pred_xg_aux)))


# ROC
fpr_mon_xg, tpr_mon_xg, _ = roc_curve(y_mon_test, y_pred_xg_aux)
roc_auc_xg = auc(fpr_mon_xg, tpr_mon_xg)


# PLOT THE ROC WITH AUC
fig = plt.figure(figsize=(6, 6))
gs = gridspec.GridSpec(1, 1) 
ax0 = plt.subplot(gs[0])
ax0.yaxis.set_ticks_position('both')
ax0.xaxis.set_ticks_position('both')
ax0.tick_params(direction="in",which="both")
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
ax0.minorticks_on()


plt.plot(tpr_mon_xg,1-fpr_mon_xg,label="$f_{1}$, AUC = %0.2f" % roc_auc_xg,color="orange",ls=":",lw=4)
plt.plot([1,0],[0,1],ls=":",color="grey")
plt.xlabel("True Positive Rate",fontsize=16)
plt.ylabel("1 $-$ False Positive Rate",fontsize=16)
plt.legend()
plt.title(r"SSM Z' - XGBoost",fontsize=16)
plt.xlim([0,1])
plt.ylim([0,1])
plt.yticks([0.2,0.4,0.6,0.8,1.])
plt.legend(frameon=False,fontsize=16)
plt.show()




print('\n ########################################\n')





for it in range(1,iterations_ML):

    print('ML iteration ', it)
    
    # CLASSIFIER
    classifier = XGBClassifier(
        n_estimators=2500,
        learning_rate=0.1,
        reg_lambda=0.0,reg_alpha=0.0,
        gamma=0.0,objective='binary:logistic',
        max_depth=5)

    ran_ind = np.random.choice(np.arange(len(X_mon_train)), size = len(X_mon_train), replace = True)

    # FIT
    classifier.fit(X_mon_train[ran_ind],y_mon_train[ran_ind],eval_set=[(X_mon_train[ran_ind], y_mon_train[ran_ind]), (X_mon_val, y_mon_val)],
            eval_metric='logloss',early_stopping_rounds=50,#early stopping
            verbose=True)

    # PREDICTIONS
    y_pred_xg_aux_it = classifier.predict_proba(X_mon_test).T[1]
    y_pred_xg_auxRE_it = np.reshape(y_pred_xg_aux_it, (1,len(y_pred_xg_aux_it)))
    
    y_pred_xg_auxRE = np.concatenate([y_pred_xg_auxRE,y_pred_xg_auxRE_it])


    # ROC
    fpr_mon_xg, tpr_mon_xg, _ = roc_curve(y_mon_test, y_pred_xg_aux)
    roc_auc_xg = auc(fpr_mon_xg, tpr_mon_xg)


    # PLOT THE ROC WITH AUC
    fig = plt.figure(figsize=(6, 6))
    gs = gridspec.GridSpec(1, 1) 
    ax0 = plt.subplot(gs[0])
    ax0.yaxis.set_ticks_position('both')
    ax0.xaxis.set_ticks_position('both')
    ax0.tick_params(direction="in",which="both")
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
    ax0.minorticks_on()


    plt.plot(tpr_mon_xg,1-fpr_mon_xg,label="$f_{1}$, AUC = %0.2f" % roc_auc_xg,color="orange",ls=":",lw=4)
    plt.plot([1,0],[0,1],ls=":",color="grey")
    plt.xlabel("True Positive Rate",fontsize=16)
    plt.ylabel("1 $-$ False Positive Rate",fontsize=16)
    plt.legend()
    plt.title(r"SSM Z' - XGBoost",fontsize=16)
    plt.xlim([0,1])
    plt.ylim([0,1])
    plt.yticks([0.2,0.4,0.6,0.8,1.])
    plt.legend(frameon=False,fontsize=16)
    plt.show()
    
    print('\n ########################################\n')
    
    
y_pred_xg = np.mean(y_pred_xg_auxRE, axis=0)
# Out:
# ML iteration 1
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [0]	validation_0-logloss:0.67121	validation_1-logloss:0.67148
# [1]	validation_0-logloss:0.65315	validation_1-logloss:0.65346
# [2]	validation_0-logloss:0.63799	validation_1-logloss:0.63850
# [3]	validation_0-logloss:0.62524	validation_1-logloss:0.62591
# [4]	validation_0-logloss:0.61453	validation_1-logloss:0.61529
# [5]	validation_0-logloss:0.60559	validation_1-logloss:0.60640
# [6]	validation_0-logloss:0.59758	validation_1-logloss:0.59855
# [7]	validation_0-logloss:0.59095	validation_1-logloss:0.59195
# [8]	validation_0-logloss:0.58493	validation_1-logloss:0.58606
# [9]	validation_0-logloss:0.57958	validation_1-logloss:0.58077
# [10]	validation_0-logloss:0.57483	validation_1-logloss:0.57604
# [11]	validation_0-logloss:0.57062	validation_1-logloss:0.57192
# [12]	validation_0-logloss:0.56698	validation_1-logloss:0.56831
# [13]	validation_0-logloss:0.56360	validation_1-logloss:0.56504
# [14]	validation_0-logloss:0.56041	validation_1-logloss:0.56188
# [15]	validation_0-logloss:0.55779	validation_1-logloss:0.55930
# [16]	validation_0-logloss:0.55537	validation_1-logloss:0.55693
# [17]	validation_0-logloss:0.55310	validation_1-logloss:0.55471
# [18]	validation_0-logloss:0.55111	validation_1-logloss:0.55279
# [19]	validation_0-logloss:0.54929	validation_1-logloss:0.55103
# [20]	validation_0-logloss:0.54778	validation_1-logloss:0.54958
# [21]	validation_0-logloss:0.54607	validation_1-logloss:0.54794
# [22]	validation_0-logloss:0.54484	validation_1-logloss:0.54675
# [23]	validation_0-logloss:0.54340	validation_1-logloss:0.54537
# [24]	validation_0-logloss:0.54214	validation_1-logloss:0.54414
# [25]	validation_0-logloss:0.54079	validation_1-logloss:0.54283
# [26]	validation_0-logloss:0.53959	validation_1-logloss:0.54168
# [27]	validation_0-logloss:0.53887	validation_1-logloss:0.54098
# [28]	validation_0-logloss:0.53780	validation_1-logloss:0.53995
# [29]	validation_0-logloss:0.53691	validation_1-logloss:0.53908
# [30]	validation_0-logloss:0.53630	validation_1-logloss:0.53853
# [31]	validation_0-logloss:0.53502	validation_1-logloss:0.53732
# [32]	validation_0-logloss:0.53397	validation_1-logloss:0.53626
# [33]	validation_0-logloss:0.53348	validation_1-logloss:0.53578
# [34]	validation_0-logloss:0.53281	validation_1-logloss:0.53512
# [35]	validation_0-logloss:0.53221	validation_1-logloss:0.53454
# [36]	validation_0-logloss:0.53158	validation_1-logloss:0.53399
# [37]	validation_0-logloss:0.53110	validation_1-logloss:0.53353
# [38]	validation_0-logloss:0.53052	validation_1-logloss:0.53298
# [39]	validation_0-logloss:0.52974	validation_1-logloss:0.53224
# [40]	validation_0-logloss:0.52913	validation_1-logloss:0.53172
# [41]	validation_0-logloss:0.52872	validation_1-logloss:0.53130
# [42]	validation_0-logloss:0.52831	validation_1-logloss:0.53094
# [43]	validation_0-logloss:0.52801	validation_1-logloss:0.53065
# [44]	validation_0-logloss:0.52745	validation_1-logloss:0.53010
# [45]	validation_0-logloss:0.52705	validation_1-logloss:0.52972
# [46]	validation_0-logloss:0.52670	validation_1-logloss:0.52941
# [47]	validation_0-logloss:0.52625	validation_1-logloss:0.52901
# [48]	validation_0-logloss:0.52588	validation_1-logloss:0.52871
# [49]	validation_0-logloss:0.52551	validation_1-logloss:0.52838
# [50]	validation_0-logloss:0.52518	validation_1-logloss:0.52806
# [51]	validation_0-logloss:0.52486	validation_1-logloss:0.52778
# [52]	validation_0-logloss:0.52407	validation_1-logloss:0.52706
# [53]	validation_0-logloss:0.52367	validation_1-logloss:0.52671
# [54]	validation_0-logloss:0.52321	validation_1-logloss:0.52630
# [55]	validation_0-logloss:0.52287	validation_1-logloss:0.52600
# [56]	validation_0-logloss:0.52264	validation_1-logloss:0.52580
# [57]	validation_0-logloss:0.52207	validation_1-logloss:0.52533
# [58]	validation_0-logloss:0.52141	validation_1-logloss:0.52475
# [59]	validation_0-logloss:0.52107	validation_1-logloss:0.52442
# [60]	validation_0-logloss:0.52081	validation_1-logloss:0.52422
# [61]	validation_0-logloss:0.52057	validation_1-logloss:0.52401
# [62]	validation_0-logloss:0.52016	validation_1-logloss:0.52365
# [63]	validation_0-logloss:0.51997	validation_1-logloss:0.52350
# [64]	validation_0-logloss:0.51977	validation_1-logloss:0.52336
# [65]	validation_0-logloss:0.51947	validation_1-logloss:0.52311
# [66]	validation_0-logloss:0.51906	validation_1-logloss:0.52276
# [67]	validation_0-logloss:0.51865	validation_1-logloss:0.52242
# [68]	validation_0-logloss:0.51836	validation_1-logloss:0.52219
# [69]	validation_0-logloss:0.51820	validation_1-logloss:0.52206
# [70]	validation_0-logloss:0.51801	validation_1-logloss:0.52190
# [71]	validation_0-logloss:0.51768	validation_1-logloss:0.52164
# [72]	validation_0-logloss:0.51749	validation_1-logloss:0.52151
# [73]	validation_0-logloss:0.51735	validation_1-logloss:0.52141
# [74]	validation_0-logloss:0.51723	validation_1-logloss:0.52133
# [75]	validation_0-logloss:0.51708	validation_1-logloss:0.52122
# [76]	validation_0-logloss:0.51699	validation_1-logloss:0.52116
# [77]	validation_0-logloss:0.51672	validation_1-logloss:0.52094
# [78]	validation_0-logloss:0.51655	validation_1-logloss:0.52082
# [79]	validation_0-logloss:0.51640	validation_1-logloss:0.52072
# [80]	validation_0-logloss:0.51628	validation_1-logloss:0.52062
# [81]	validation_0-logloss:0.51613	validation_1-logloss:0.52052
# [82]	validation_0-logloss:0.51603	validation_1-logloss:0.52045
# [83]	validation_0-logloss:0.51594	validation_1-logloss:0.52037
# [84]	validation_0-logloss:0.51581	validation_1-logloss:0.52028
# [85]	validation_0-logloss:0.51571	validation_1-logloss:0.52023
# [86]	validation_0-logloss:0.51560	validation_1-logloss:0.52016
# [87]	validation_0-logloss:0.51553	validation_1-logloss:0.52011
# [88]	validation_0-logloss:0.51545	validation_1-logloss:0.52006
# [89]	validation_0-logloss:0.51536	validation_1-logloss:0.52002
# [90]	validation_0-logloss:0.51516	validation_1-logloss:0.51986
# [91]	validation_0-logloss:0.51507	validation_1-logloss:0.51980
# [92]	validation_0-logloss:0.51501	validation_1-logloss:0.51977
# [93]	validation_0-logloss:0.51492	validation_1-logloss:0.51973
# [94]	validation_0-logloss:0.51485	validation_1-logloss:0.51968
# [95]	validation_0-logloss:0.51473	validation_1-logloss:0.51961
# [96]	validation_0-logloss:0.51464	validation_1-logloss:0.51954
# [97]	validation_0-logloss:0.51457	validation_1-logloss:0.51950
# [98]	validation_0-logloss:0.51442	validation_1-logloss:0.51940
# [99]	validation_0-logloss:0.51430	validation_1-logloss:0.51934
# [100]	validation_0-logloss:0.51423	validation_1-logloss:0.51930
# [101]	validation_0-logloss:0.51414	validation_1-logloss:0.51925
# [102]	validation_0-logloss:0.51398	validation_1-logloss:0.51914
# [103]	validation_0-logloss:0.51390	validation_1-logloss:0.51910
# [104]	validation_0-logloss:0.51384	validation_1-logloss:0.51908
# [105]	validation_0-logloss:0.51380	validation_1-logloss:0.51906
# [106]	validation_0-logloss:0.51374	validation_1-logloss:0.51903
# [107]	validation_0-logloss:0.51370	validation_1-logloss:0.51903
# [108]	validation_0-logloss:0.51355	validation_1-logloss:0.51894
# [109]	validation_0-logloss:0.51349	validation_1-logloss:0.51891
# [110]	validation_0-logloss:0.51345	validation_1-logloss:0.51890
# [111]	validation_0-logloss:0.51339	validation_1-logloss:0.51886
# [112]	validation_0-logloss:0.51330	validation_1-logloss:0.51881
# [113]	validation_0-logloss:0.51323	validation_1-logloss:0.51879
# [114]	validation_0-logloss:0.51315	validation_1-logloss:0.51875
# [115]	validation_0-logloss:0.51310	validation_1-logloss:0.51874
# [116]	validation_0-logloss:0.51303	validation_1-logloss:0.51871
# [117]	validation_0-logloss:0.51297	validation_1-logloss:0.51869
# [118]	validation_0-logloss:0.51293	validation_1-logloss:0.51869
# [119]	validation_0-logloss:0.51288	validation_1-logloss:0.51868
# [120]	validation_0-logloss:0.51279	validation_1-logloss:0.51865
# [121]	validation_0-logloss:0.51274	validation_1-logloss:0.51865
# [122]	validation_0-logloss:0.51268	validation_1-logloss:0.51862
# [123]	validation_0-logloss:0.51262	validation_1-logloss:0.51858
# [124]	validation_0-logloss:0.51257	validation_1-logloss:0.51857
# [125]	validation_0-logloss:0.51252	validation_1-logloss:0.51855
# [126]	validation_0-logloss:0.51245	validation_1-logloss:0.51855
# [127]	validation_0-logloss:0.51240	validation_1-logloss:0.51853
# [128]	validation_0-logloss:0.51236	validation_1-logloss:0.51853
# [129]	validation_0-logloss:0.51228	validation_1-logloss:0.51849
# [130]	validation_0-logloss:0.51221	validation_1-logloss:0.51846
# [131]	validation_0-logloss:0.51217	validation_1-logloss:0.51845
# [132]	validation_0-logloss:0.51215	validation_1-logloss:0.51844
# [133]	validation_0-logloss:0.51211	validation_1-logloss:0.51843
# [134]	validation_0-logloss:0.51208	validation_1-logloss:0.51843
# [135]	validation_0-logloss:0.51204	validation_1-logloss:0.51843
# [136]	validation_0-logloss:0.51199	validation_1-logloss:0.51841
# [137]	validation_0-logloss:0.51196	validation_1-logloss:0.51841
# [138]	validation_0-logloss:0.51193	validation_1-logloss:0.51841
# [139]	validation_0-logloss:0.51184	validation_1-logloss:0.51837
# [140]	validation_0-logloss:0.51178	validation_1-logloss:0.51835
# [141]	validation_0-logloss:0.51174	validation_1-logloss:0.51834
# [142]	validation_0-logloss:0.51169	validation_1-logloss:0.51833
# [143]	validation_0-logloss:0.51164	validation_1-logloss:0.51833
# [144]	validation_0-logloss:0.51158	validation_1-logloss:0.51831
# [145]	validation_0-logloss:0.51154	validation_1-logloss:0.51831
# [146]	validation_0-logloss:0.51152	validation_1-logloss:0.51831
# [147]	validation_0-logloss:0.51149	validation_1-logloss:0.51832
# [148]	validation_0-logloss:0.51142	validation_1-logloss:0.51830
# [149]	validation_0-logloss:0.51137	validation_1-logloss:0.51830
# [150]	validation_0-logloss:0.51132	validation_1-logloss:0.51830
# [151]	validation_0-logloss:0.51130	validation_1-logloss:0.51830
# [152]	validation_0-logloss:0.51127	validation_1-logloss:0.51829
# [153]	validation_0-logloss:0.51124	validation_1-logloss:0.51828
# [154]	validation_0-logloss:0.51118	validation_1-logloss:0.51825
# [155]	validation_0-logloss:0.51115	validation_1-logloss:0.51825
# [156]	validation_0-logloss:0.51112	validation_1-logloss:0.51825
# [157]	validation_0-logloss:0.51106	validation_1-logloss:0.51822
# [158]	validation_0-logloss:0.51104	validation_1-logloss:0.51822
# [159]	validation_0-logloss:0.51100	validation_1-logloss:0.51821
# [160]	validation_0-logloss:0.51095	validation_1-logloss:0.51821
# [161]	validation_0-logloss:0.51092	validation_1-logloss:0.51821
# [162]	validation_0-logloss:0.51090	validation_1-logloss:0.51822
# [163]	validation_0-logloss:0.51085	validation_1-logloss:0.51822
# [164]	validation_0-logloss:0.51081	validation_1-logloss:0.51822
# [165]	validation_0-logloss:0.51079	validation_1-logloss:0.51821
# [166]	validation_0-logloss:0.51076	validation_1-logloss:0.51821
# [167]	validation_0-logloss:0.51073	validation_1-logloss:0.51822
# [168]	validation_0-logloss:0.51072	validation_1-logloss:0.51822
# [169]	validation_0-logloss:0.51068	validation_1-logloss:0.51822
# [170]	validation_0-logloss:0.51067	validation_1-logloss:0.51822
# [171]	validation_0-logloss:0.51063	validation_1-logloss:0.51821
# [172]	validation_0-logloss:0.51060	validation_1-logloss:0.51820
# [173]	validation_0-logloss:0.51058	validation_1-logloss:0.51820
# [174]	validation_0-logloss:0.51053	validation_1-logloss:0.51818
# [175]	validation_0-logloss:0.51047	validation_1-logloss:0.51818
# [176]	validation_0-logloss:0.51045	validation_1-logloss:0.51818
# [177]	validation_0-logloss:0.51041	validation_1-logloss:0.51818
# [178]	validation_0-logloss:0.51036	validation_1-logloss:0.51817
# [179]	validation_0-logloss:0.51028	validation_1-logloss:0.51813
# [180]	validation_0-logloss:0.51022	validation_1-logloss:0.51814
# [181]	validation_0-logloss:0.51018	validation_1-logloss:0.51812
# [182]	validation_0-logloss:0.51014	validation_1-logloss:0.51812
# [183]	validation_0-logloss:0.51009	validation_1-logloss:0.51811
# [184]	validation_0-logloss:0.51007	validation_1-logloss:0.51811
# [185]	validation_0-logloss:0.51003	validation_1-logloss:0.51811
# [186]	validation_0-logloss:0.50999	validation_1-logloss:0.51811
# [187]	validation_0-logloss:0.50995	validation_1-logloss:0.51812
# [188]	validation_0-logloss:0.50994	validation_1-logloss:0.51812
# [189]	validation_0-logloss:0.50992	validation_1-logloss:0.51812
# [190]	validation_0-logloss:0.50989	validation_1-logloss:0.51812
# [191]	validation_0-logloss:0.50986	validation_1-logloss:0.51813
# [192]	validation_0-logloss:0.50982	validation_1-logloss:0.51813
# [193]	validation_0-logloss:0.50978	validation_1-logloss:0.51812
# [194]	validation_0-logloss:0.50976	validation_1-logloss:0.51812
# [195]	validation_0-logloss:0.50970	validation_1-logloss:0.51809
# [196]	validation_0-logloss:0.50967	validation_1-logloss:0.51809
# [197]	validation_0-logloss:0.50964	validation_1-logloss:0.51808
# [198]	validation_0-logloss:0.50961	validation_1-logloss:0.51809
# [199]	validation_0-logloss:0.50954	validation_1-logloss:0.51806
# [200]	validation_0-logloss:0.50952	validation_1-logloss:0.51806
# [201]	validation_0-logloss:0.50949	validation_1-logloss:0.51806
# [202]	validation_0-logloss:0.50946	validation_1-logloss:0.51807
# [203]	validation_0-logloss:0.50943	validation_1-logloss:0.51806
# [204]	validation_0-logloss:0.50942	validation_1-logloss:0.51806
# [205]	validation_0-logloss:0.50940	validation_1-logloss:0.51805
# [206]	validation_0-logloss:0.50937	validation_1-logloss:0.51806
# [207]	validation_0-logloss:0.50934	validation_1-logloss:0.51806
# [208]	validation_0-logloss:0.50929	validation_1-logloss:0.51807
# [209]	validation_0-logloss:0.50927	validation_1-logloss:0.51807
# [210]	validation_0-logloss:0.50923	validation_1-logloss:0.51807
# [211]	validation_0-logloss:0.50919	validation_1-logloss:0.51807
# [212]	validation_0-logloss:0.50913	validation_1-logloss:0.51806
# [213]	validation_0-logloss:0.50909	validation_1-logloss:0.51806
# [214]	validation_0-logloss:0.50906	validation_1-logloss:0.51806
# [215]	validation_0-logloss:0.50903	validation_1-logloss:0.51806
# [216]	validation_0-logloss:0.50900	validation_1-logloss:0.51806
# [217]	validation_0-logloss:0.50896	validation_1-logloss:0.51806
# [218]	validation_0-logloss:0.50891	validation_1-logloss:0.51806
# [219]	validation_0-logloss:0.50888	validation_1-logloss:0.51806
# [220]	validation_0-logloss:0.50885	validation_1-logloss:0.51806
# [221]	validation_0-logloss:0.50884	validation_1-logloss:0.51806
# [222]	validation_0-logloss:0.50882	validation_1-logloss:0.51807
# [223]	validation_0-logloss:0.50876	validation_1-logloss:0.51804
# [224]	validation_0-logloss:0.50874	validation_1-logloss:0.51804
# [225]	validation_0-logloss:0.50872	validation_1-logloss:0.51804
# [226]	validation_0-logloss:0.50869	validation_1-logloss:0.51805
# [227]	validation_0-logloss:0.50865	validation_1-logloss:0.51805
# [228]	validation_0-logloss:0.50862	validation_1-logloss:0.51805
# [229]	validation_0-logloss:0.50859	validation_1-logloss:0.51806
# [230]	validation_0-logloss:0.50857	validation_1-logloss:0.51806
# [231]	validation_0-logloss:0.50855	validation_1-logloss:0.51806
# [232]	validation_0-logloss:0.50850	validation_1-logloss:0.51806
# [233]	validation_0-logloss:0.50848	validation_1-logloss:0.51806
# [234]	validation_0-logloss:0.50847	validation_1-logloss:0.51806
# [235]	validation_0-logloss:0.50843	validation_1-logloss:0.51806
# [236]	validation_0-logloss:0.50840	validation_1-logloss:0.51807
# [237]	validation_0-logloss:0.50837	validation_1-logloss:0.51807
# [238]	validation_0-logloss:0.50836	validation_1-logloss:0.51807
# [239]	validation_0-logloss:0.50835	validation_1-logloss:0.51808
# [240]	validation_0-logloss:0.50833	validation_1-logloss:0.51807
# [241]	validation_0-logloss:0.50831	validation_1-logloss:0.51807
# [242]	validation_0-logloss:0.50827	validation_1-logloss:0.51807
# [243]	validation_0-logloss:0.50823	validation_1-logloss:0.51806
# [244]	validation_0-logloss:0.50819	validation_1-logloss:0.51806
# [245]	validation_0-logloss:0.50816	validation_1-logloss:0.51806
# [246]	validation_0-logloss:0.50811	validation_1-logloss:0.51806
# [247]	validation_0-logloss:0.50807	validation_1-logloss:0.51806
# [248]	validation_0-logloss:0.50801	validation_1-logloss:0.51804
# [249]	validation_0-logloss:0.50799	validation_1-logloss:0.51804
# [250]	validation_0-logloss:0.50795	validation_1-logloss:0.51805
# [251]	validation_0-logloss:0.50791	validation_1-logloss:0.51805
# [252]	validation_0-logloss:0.50785	validation_1-logloss:0.51804
# [253]	validation_0-logloss:0.50780	validation_1-logloss:0.51804
# [254]	validation_0-logloss:0.50777	validation_1-logloss:0.51805
# [255]	validation_0-logloss:0.50776	validation_1-logloss:0.51805
# [256]	validation_0-logloss:0.50774	validation_1-logloss:0.51805
# [257]	validation_0-logloss:0.50772	validation_1-logloss:0.51806
# [258]	validation_0-logloss:0.50767	validation_1-logloss:0.51806
# [259]	validation_0-logloss:0.50764	validation_1-logloss:0.51807
# [260]	validation_0-logloss:0.50762	validation_1-logloss:0.51807
# [261]	validation_0-logloss:0.50757	validation_1-logloss:0.51806
# [262]	validation_0-logloss:0.50755	validation_1-logloss:0.51806
# [263]	validation_0-logloss:0.50751	validation_1-logloss:0.51806
# [264]	validation_0-logloss:0.50748	validation_1-logloss:0.51806
# [265]	validation_0-logloss:0.50743	validation_1-logloss:0.51806
# [266]	validation_0-logloss:0.50743	validation_1-logloss:0.51806
# [267]	validation_0-logloss:0.50739	validation_1-logloss:0.51806
# [268]	validation_0-logloss:0.50736	validation_1-logloss:0.51807
# [269]	validation_0-logloss:0.50733	validation_1-logloss:0.51806
# [270]	validation_0-logloss:0.50729	validation_1-logloss:0.51806
# [271]	validation_0-logloss:0.50728	validation_1-logloss:0.51806
# [272]	validation_0-logloss:0.50726	validation_1-logloss:0.51806
# [273]	validation_0-logloss:0.50723	validation_1-logloss:0.51806
# [274]	validation_0-logloss:0.50719	validation_1-logloss:0.51807
# [275]	validation_0-logloss:0.50717	validation_1-logloss:0.51807
#  ########################################
#
# ML iteration  1
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [0]	validation_0-logloss:0.67126	validation_1-logloss:0.67139
# [1]	validation_0-logloss:0.65335	validation_1-logloss:0.65355
# [2]	validation_0-logloss:0.63815	validation_1-logloss:0.63855
# [3]	validation_0-logloss:0.62537	validation_1-logloss:0.62587
# [4]	validation_0-logloss:0.61446	validation_1-logloss:0.61513
# [5]	validation_0-logloss:0.60510	validation_1-logloss:0.60574
# [6]	validation_0-logloss:0.59688	validation_1-logloss:0.59763
# [7]	validation_0-logloss:0.58997	validation_1-logloss:0.59083
# [8]	validation_0-logloss:0.58375	validation_1-logloss:0.58468
# [9]	validation_0-logloss:0.57862	validation_1-logloss:0.57961
# [10]	validation_0-logloss:0.57407	validation_1-logloss:0.57510
# [11]	validation_0-logloss:0.56973	validation_1-logloss:0.57086
# [12]	validation_0-logloss:0.56605	validation_1-logloss:0.56727
# [13]	validation_0-logloss:0.56286	validation_1-logloss:0.56411
# [14]	validation_0-logloss:0.55986	validation_1-logloss:0.56120
# [15]	validation_0-logloss:0.55710	validation_1-logloss:0.55847
# [16]	validation_0-logloss:0.55471	validation_1-logloss:0.55615
# [17]	validation_0-logloss:0.55254	validation_1-logloss:0.55404
# [18]	validation_0-logloss:0.55031	validation_1-logloss:0.55187
# [19]	validation_0-logloss:0.54866	validation_1-logloss:0.55028
# [20]	validation_0-logloss:0.54717	validation_1-logloss:0.54887
# [21]	validation_0-logloss:0.54554	validation_1-logloss:0.54727
# [22]	validation_0-logloss:0.54399	validation_1-logloss:0.54575
# [23]	validation_0-logloss:0.54256	validation_1-logloss:0.54437
# [24]	validation_0-logloss:0.54142	validation_1-logloss:0.54326
# [25]	validation_0-logloss:0.54001	validation_1-logloss:0.54192
# [26]	validation_0-logloss:0.53904	validation_1-logloss:0.54099
# [27]	validation_0-logloss:0.53778	validation_1-logloss:0.53978
# [28]	validation_0-logloss:0.53706	validation_1-logloss:0.53907
# [29]	validation_0-logloss:0.53612	validation_1-logloss:0.53817
# [30]	validation_0-logloss:0.53546	validation_1-logloss:0.53755
# [31]	validation_0-logloss:0.53476	validation_1-logloss:0.53686
# [32]	validation_0-logloss:0.53402	validation_1-logloss:0.53618
# [33]	validation_0-logloss:0.53302	validation_1-logloss:0.53526
# [34]	validation_0-logloss:0.53257	validation_1-logloss:0.53480
# [35]	validation_0-logloss:0.53203	validation_1-logloss:0.53430
# [36]	validation_0-logloss:0.53136	validation_1-logloss:0.53368
# [37]	validation_0-logloss:0.53089	validation_1-logloss:0.53321
# [38]	validation_0-logloss:0.53024	validation_1-logloss:0.53262
# [39]	validation_0-logloss:0.52957	validation_1-logloss:0.53200
# [40]	validation_0-logloss:0.52903	validation_1-logloss:0.53150
# [41]	validation_0-logloss:0.52863	validation_1-logloss:0.53110
# [42]	validation_0-logloss:0.52821	validation_1-logloss:0.53076
# [43]	validation_0-logloss:0.52777	validation_1-logloss:0.53034
# [44]	validation_0-logloss:0.52741	validation_1-logloss:0.53000
# [45]	validation_0-logloss:0.52686	validation_1-logloss:0.52949
# [46]	validation_0-logloss:0.52652	validation_1-logloss:0.52921
# [47]	validation_0-logloss:0.52613	validation_1-logloss:0.52890
# [48]	validation_0-logloss:0.52578	validation_1-logloss:0.52856
# [49]	validation_0-logloss:0.52533	validation_1-logloss:0.52814
# [50]	validation_0-logloss:0.52449	validation_1-logloss:0.52738
# [51]	validation_0-logloss:0.52394	validation_1-logloss:0.52691
# [52]	validation_0-logloss:0.52326	validation_1-logloss:0.52633
# [53]	validation_0-logloss:0.52288	validation_1-logloss:0.52600
# [54]	validation_0-logloss:0.52259	validation_1-logloss:0.52577
# [55]	validation_0-logloss:0.52231	validation_1-logloss:0.52554
# [56]	validation_0-logloss:0.52205	validation_1-logloss:0.52532
# [57]	validation_0-logloss:0.52149	validation_1-logloss:0.52482
# [58]	validation_0-logloss:0.52102	validation_1-logloss:0.52439
# [59]	validation_0-logloss:0.52075	validation_1-logloss:0.52417
# [60]	validation_0-logloss:0.52056	validation_1-logloss:0.52402
# [61]	validation_0-logloss:0.52018	validation_1-logloss:0.52370
# [62]	validation_0-logloss:0.51983	validation_1-logloss:0.52340
# [63]	validation_0-logloss:0.51957	validation_1-logloss:0.52316
# [64]	validation_0-logloss:0.51925	validation_1-logloss:0.52290
# [65]	validation_0-logloss:0.51907	validation_1-logloss:0.52276
# [66]	validation_0-logloss:0.51885	validation_1-logloss:0.52258
# [67]	validation_0-logloss:0.51866	validation_1-logloss:0.52243
# [68]	validation_0-logloss:0.51853	validation_1-logloss:0.52234
# [69]	validation_0-logloss:0.51834	validation_1-logloss:0.52218
# [70]	validation_0-logloss:0.51801	validation_1-logloss:0.52191
# [71]	validation_0-logloss:0.51767	validation_1-logloss:0.52162
# [72]	validation_0-logloss:0.51746	validation_1-logloss:0.52146
# [73]	validation_0-logloss:0.51730	validation_1-logloss:0.52135
# [74]	validation_0-logloss:0.51716	validation_1-logloss:0.52125
# [75]	validation_0-logloss:0.51699	validation_1-logloss:0.52113
# [76]	validation_0-logloss:0.51688	validation_1-logloss:0.52105
# [77]	validation_0-logloss:0.51668	validation_1-logloss:0.52089
# [78]	validation_0-logloss:0.51651	validation_1-logloss:0.52077
# [79]	validation_0-logloss:0.51637	validation_1-logloss:0.52068
# [80]	validation_0-logloss:0.51616	validation_1-logloss:0.52050
# [81]	validation_0-logloss:0.51605	validation_1-logloss:0.52043
# [82]	validation_0-logloss:0.51592	validation_1-logloss:0.52034
# [83]	validation_0-logloss:0.51583	validation_1-logloss:0.52028
# [84]	validation_0-logloss:0.51570	validation_1-logloss:0.52020
# [85]	validation_0-logloss:0.51563	validation_1-logloss:0.52016
# [86]	validation_0-logloss:0.51555	validation_1-logloss:0.52012
# [87]	validation_0-logloss:0.51541	validation_1-logloss:0.52001
# [88]	validation_0-logloss:0.51525	validation_1-logloss:0.51989
# [89]	validation_0-logloss:0.51517	validation_1-logloss:0.51985
# [90]	validation_0-logloss:0.51505	validation_1-logloss:0.51979
# [91]	validation_0-logloss:0.51491	validation_1-logloss:0.51970
# [92]	validation_0-logloss:0.51481	validation_1-logloss:0.51965
# [93]	validation_0-logloss:0.51475	validation_1-logloss:0.51962
# [94]	validation_0-logloss:0.51467	validation_1-logloss:0.51957
# [95]	validation_0-logloss:0.51459	validation_1-logloss:0.51953
# [96]	validation_0-logloss:0.51436	validation_1-logloss:0.51935
# [97]	validation_0-logloss:0.51429	validation_1-logloss:0.51931
# [98]	validation_0-logloss:0.51423	validation_1-logloss:0.51928
# [99]	validation_0-logloss:0.51416	validation_1-logloss:0.51926
# [100]	validation_0-logloss:0.51407	validation_1-logloss:0.51921
# [101]	validation_0-logloss:0.51395	validation_1-logloss:0.51913
# [102]	validation_0-logloss:0.51388	validation_1-logloss:0.51910
# [103]	validation_0-logloss:0.51376	validation_1-logloss:0.51902
# [104]	validation_0-logloss:0.51371	validation_1-logloss:0.51901
# [105]	validation_0-logloss:0.51364	validation_1-logloss:0.51898
# [106]	validation_0-logloss:0.51359	validation_1-logloss:0.51896
# [107]	validation_0-logloss:0.51350	validation_1-logloss:0.51889
# [108]	validation_0-logloss:0.51344	validation_1-logloss:0.51887
# [109]	validation_0-logloss:0.51338	validation_1-logloss:0.51885
# [110]	validation_0-logloss:0.51326	validation_1-logloss:0.51879
# [111]	validation_0-logloss:0.51319	validation_1-logloss:0.51877
# [112]	validation_0-logloss:0.51314	validation_1-logloss:0.51876
# [113]	validation_0-logloss:0.51309	validation_1-logloss:0.51875
# [114]	validation_0-logloss:0.51304	validation_1-logloss:0.51873
# [115]	validation_0-logloss:0.51298	validation_1-logloss:0.51872
# [116]	validation_0-logloss:0.51295	validation_1-logloss:0.51870
# [117]	validation_0-logloss:0.51292	validation_1-logloss:0.51870
# [118]	validation_0-logloss:0.51289	validation_1-logloss:0.51869
# [119]	validation_0-logloss:0.51282	validation_1-logloss:0.51866
# [120]	validation_0-logloss:0.51273	validation_1-logloss:0.51862
# [121]	validation_0-logloss:0.51268	validation_1-logloss:0.51862
# [122]	validation_0-logloss:0.51256	validation_1-logloss:0.51854
# [123]	validation_0-logloss:0.51253	validation_1-logloss:0.51854
# [124]	validation_0-logloss:0.51249	validation_1-logloss:0.51852
# [125]	validation_0-logloss:0.51241	validation_1-logloss:0.51847
# [126]	validation_0-logloss:0.51236	validation_1-logloss:0.51846
# [127]	validation_0-logloss:0.51230	validation_1-logloss:0.51844
# [128]	validation_0-logloss:0.51226	validation_1-logloss:0.51843
# [129]	validation_0-logloss:0.51222	validation_1-logloss:0.51842
# [130]	validation_0-logloss:0.51219	validation_1-logloss:0.51841
# [131]	validation_0-logloss:0.51216	validation_1-logloss:0.51840
# [132]	validation_0-logloss:0.51211	validation_1-logloss:0.51840
# [133]	validation_0-logloss:0.51200	validation_1-logloss:0.51833
# [134]	validation_0-logloss:0.51192	validation_1-logloss:0.51828
# [135]	validation_0-logloss:0.51185	validation_1-logloss:0.51826
# [136]	validation_0-logloss:0.51177	validation_1-logloss:0.51822
# [137]	validation_0-logloss:0.51172	validation_1-logloss:0.51821
# [138]	validation_0-logloss:0.51169	validation_1-logloss:0.51819
# [139]	validation_0-logloss:0.51165	validation_1-logloss:0.51819
# [140]	validation_0-logloss:0.51161	validation_1-logloss:0.51819
# [141]	validation_0-logloss:0.51156	validation_1-logloss:0.51818
# [142]	validation_0-logloss:0.51152	validation_1-logloss:0.51818
# [143]	validation_0-logloss:0.51149	validation_1-logloss:0.51817
# [144]	validation_0-logloss:0.51146	validation_1-logloss:0.51817
# [145]	validation_0-logloss:0.51142	validation_1-logloss:0.51816
# [146]	validation_0-logloss:0.51140	validation_1-logloss:0.51815
# [147]	validation_0-logloss:0.51137	validation_1-logloss:0.51815
# [148]	validation_0-logloss:0.51134	validation_1-logloss:0.51814
# [149]	validation_0-logloss:0.51126	validation_1-logloss:0.51810
# [150]	validation_0-logloss:0.51122	validation_1-logloss:0.51809
# [151]	validation_0-logloss:0.51118	validation_1-logloss:0.51809
# [152]	validation_0-logloss:0.51115	validation_1-logloss:0.51808
# [153]	validation_0-logloss:0.51111	validation_1-logloss:0.51807
# [154]	validation_0-logloss:0.51108	validation_1-logloss:0.51806
# [155]	validation_0-logloss:0.51105	validation_1-logloss:0.51806
# [156]	validation_0-logloss:0.51102	validation_1-logloss:0.51806
# [157]	validation_0-logloss:0.51100	validation_1-logloss:0.51807
# [158]	validation_0-logloss:0.51095	validation_1-logloss:0.51806
# [159]	validation_0-logloss:0.51088	validation_1-logloss:0.51804
# [160]	validation_0-logloss:0.51086	validation_1-logloss:0.51804
# [161]	validation_0-logloss:0.51081	validation_1-logloss:0.51802
# [162]	validation_0-logloss:0.51076	validation_1-logloss:0.51802
# [163]	validation_0-logloss:0.51075	validation_1-logloss:0.51801
# [164]	validation_0-logloss:0.51072	validation_1-logloss:0.51801
# [165]	validation_0-logloss:0.51069	validation_1-logloss:0.51802
# [166]	validation_0-logloss:0.51065	validation_1-logloss:0.51801
# [167]	validation_0-logloss:0.51061	validation_1-logloss:0.51800
# [168]	validation_0-logloss:0.51058	validation_1-logloss:0.51800
# [169]	validation_0-logloss:0.51057	validation_1-logloss:0.51799
# [170]	validation_0-logloss:0.51053	validation_1-logloss:0.51798
# [171]	validation_0-logloss:0.51050	validation_1-logloss:0.51798
# [172]	validation_0-logloss:0.51044	validation_1-logloss:0.51795
# [173]	validation_0-logloss:0.51040	validation_1-logloss:0.51795
# [174]	validation_0-logloss:0.51035	validation_1-logloss:0.51794
# [175]	validation_0-logloss:0.51033	validation_1-logloss:0.51794
# [176]	validation_0-logloss:0.51030	validation_1-logloss:0.51795
# [177]	validation_0-logloss:0.51026	validation_1-logloss:0.51795
# [178]	validation_0-logloss:0.51022	validation_1-logloss:0.51794
# [179]	validation_0-logloss:0.51019	validation_1-logloss:0.51795
# [180]	validation_0-logloss:0.51018	validation_1-logloss:0.51794
# [181]	validation_0-logloss:0.51016	validation_1-logloss:0.51794
# [182]	validation_0-logloss:0.51013	validation_1-logloss:0.51795
# [183]	validation_0-logloss:0.51010	validation_1-logloss:0.51795
# [184]	validation_0-logloss:0.51003	validation_1-logloss:0.51794
# [185]	validation_0-logloss:0.50999	validation_1-logloss:0.51793
# [186]	validation_0-logloss:0.50996	validation_1-logloss:0.51794
# [187]	validation_0-logloss:0.50993	validation_1-logloss:0.51794
# [188]	validation_0-logloss:0.50991	validation_1-logloss:0.51793
# [189]	validation_0-logloss:0.50983	validation_1-logloss:0.51790
# [190]	validation_0-logloss:0.50981	validation_1-logloss:0.51790
# [191]	validation_0-logloss:0.50977	validation_1-logloss:0.51790
# [192]	validation_0-logloss:0.50974	validation_1-logloss:0.51790
# [193]	validation_0-logloss:0.50969	validation_1-logloss:0.51790
# [194]	validation_0-logloss:0.50965	validation_1-logloss:0.51789
# [195]	validation_0-logloss:0.50963	validation_1-logloss:0.51789
# [196]	validation_0-logloss:0.50962	validation_1-logloss:0.51789
# [197]	validation_0-logloss:0.50959	validation_1-logloss:0.51790
# [198]	validation_0-logloss:0.50955	validation_1-logloss:0.51789
# [199]	validation_0-logloss:0.50951	validation_1-logloss:0.51790
# [200]	validation_0-logloss:0.50950	validation_1-logloss:0.51790
# [201]	validation_0-logloss:0.50947	validation_1-logloss:0.51790
# [202]	validation_0-logloss:0.50944	validation_1-logloss:0.51791
# [203]	validation_0-logloss:0.50941	validation_1-logloss:0.51791
# [204]	validation_0-logloss:0.50934	validation_1-logloss:0.51789
# [205]	validation_0-logloss:0.50932	validation_1-logloss:0.51789
# [206]	validation_0-logloss:0.50931	validation_1-logloss:0.51789
# [207]	validation_0-logloss:0.50929	validation_1-logloss:0.51789
# [208]	validation_0-logloss:0.50925	validation_1-logloss:0.51789
# [209]	validation_0-logloss:0.50921	validation_1-logloss:0.51788
# [210]	validation_0-logloss:0.50918	validation_1-logloss:0.51788
# [211]	validation_0-logloss:0.50914	validation_1-logloss:0.51788
# [212]	validation_0-logloss:0.50910	validation_1-logloss:0.51786
# [213]	validation_0-logloss:0.50906	validation_1-logloss:0.51786
# [214]	validation_0-logloss:0.50904	validation_1-logloss:0.51786
# [215]	validation_0-logloss:0.50901	validation_1-logloss:0.51787
# [216]	validation_0-logloss:0.50898	validation_1-logloss:0.51786
# [217]	validation_0-logloss:0.50896	validation_1-logloss:0.51787
# [218]	validation_0-logloss:0.50894	validation_1-logloss:0.51787
# [219]	validation_0-logloss:0.50893	validation_1-logloss:0.51787
# [220]	validation_0-logloss:0.50890	validation_1-logloss:0.51786
# [221]	validation_0-logloss:0.50885	validation_1-logloss:0.51787
# [222]	validation_0-logloss:0.50882	validation_1-logloss:0.51788
# [223]	validation_0-logloss:0.50879	validation_1-logloss:0.51788
# [224]	validation_0-logloss:0.50874	validation_1-logloss:0.51789
# [225]	validation_0-logloss:0.50871	validation_1-logloss:0.51790
# [226]	validation_0-logloss:0.50869	validation_1-logloss:0.51790
# [227]	validation_0-logloss:0.50868	validation_1-logloss:0.51789
# [228]	validation_0-logloss:0.50865	validation_1-logloss:0.51789
# [229]	validation_0-logloss:0.50865	validation_1-logloss:0.51789
# [230]	validation_0-logloss:0.50861	validation_1-logloss:0.51790
# [231]	validation_0-logloss:0.50859	validation_1-logloss:0.51790
# [232]	validation_0-logloss:0.50857	validation_1-logloss:0.51790
# [233]	validation_0-logloss:0.50853	validation_1-logloss:0.51790
# [234]	validation_0-logloss:0.50850	validation_1-logloss:0.51790
# [235]	validation_0-logloss:0.50847	validation_1-logloss:0.51791
# [236]	validation_0-logloss:0.50843	validation_1-logloss:0.51791
# [237]	validation_0-logloss:0.50841	validation_1-logloss:0.51791
# [238]	validation_0-logloss:0.50840	validation_1-logloss:0.51791
# [239]	validation_0-logloss:0.50840	validation_1-logloss:0.51791
# [240]	validation_0-logloss:0.50834	validation_1-logloss:0.51789
# [241]	validation_0-logloss:0.50827	validation_1-logloss:0.51788
# [242]	validation_0-logloss:0.50823	validation_1-logloss:0.51789
# [243]	validation_0-logloss:0.50820	validation_1-logloss:0.51789
# [244]	validation_0-logloss:0.50818	validation_1-logloss:0.51788
# [245]	validation_0-logloss:0.50815	validation_1-logloss:0.51788
# [246]	validation_0-logloss:0.50811	validation_1-logloss:0.51788
# [247]	validation_0-logloss:0.50806	validation_1-logloss:0.51787
# [248]	validation_0-logloss:0.50802	validation_1-logloss:0.51787
# [249]	validation_0-logloss:0.50797	validation_1-logloss:0.51788
# [250]	validation_0-logloss:0.50793	validation_1-logloss:0.51787
# [251]	validation_0-logloss:0.50792	validation_1-logloss:0.51787
# [252]	validation_0-logloss:0.50789	validation_1-logloss:0.51788
# [253]	validation_0-logloss:0.50786	validation_1-logloss:0.51788
# [254]	validation_0-logloss:0.50784	validation_1-logloss:0.51788
# [255]	validation_0-logloss:0.50783	validation_1-logloss:0.51787
# [256]	validation_0-logloss:0.50781	validation_1-logloss:0.51788
# [257]	validation_0-logloss:0.50778	validation_1-logloss:0.51788
# [258]	validation_0-logloss:0.50777	validation_1-logloss:0.51789
# [259]	validation_0-logloss:0.50773	validation_1-logloss:0.51789
# [260]	validation_0-logloss:0.50771	validation_1-logloss:0.51789
# [261]	validation_0-logloss:0.50768	validation_1-logloss:0.51789
# [262]	validation_0-logloss:0.50765	validation_1-logloss:0.51789
#  ########################################
#
# ML iteration  2
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [0]	validation_0-logloss:0.67108	validation_1-logloss:0.67132
# [1]	validation_0-logloss:0.65307	validation_1-logloss:0.65348
# [2]	validation_0-logloss:0.63784	validation_1-logloss:0.63847
# [3]	validation_0-logloss:0.62479	validation_1-logloss:0.62560
# [4]	validation_0-logloss:0.61382	validation_1-logloss:0.61482
# [5]	validation_0-logloss:0.60454	validation_1-logloss:0.60557
# [6]	validation_0-logloss:0.59627	validation_1-logloss:0.59747
# [7]	validation_0-logloss:0.58934	validation_1-logloss:0.59069
# [8]	validation_0-logloss:0.58349	validation_1-logloss:0.58491
# [9]	validation_0-logloss:0.57813	validation_1-logloss:0.57973
# [10]	validation_0-logloss:0.57338	validation_1-logloss:0.57502
# [11]	validation_0-logloss:0.56919	validation_1-logloss:0.57098
# [12]	validation_0-logloss:0.56562	validation_1-logloss:0.56745
# [13]	validation_0-logloss:0.56241	validation_1-logloss:0.56431
# [14]	validation_0-logloss:0.55936	validation_1-logloss:0.56137
# [15]	validation_0-logloss:0.55664	validation_1-logloss:0.55871
# [16]	validation_0-logloss:0.55408	validation_1-logloss:0.55622
# [17]	validation_0-logloss:0.55165	validation_1-logloss:0.55387
# [18]	validation_0-logloss:0.54963	validation_1-logloss:0.55187
# [19]	validation_0-logloss:0.54792	validation_1-logloss:0.55024
# [20]	validation_0-logloss:0.54634	validation_1-logloss:0.54871
# [21]	validation_0-logloss:0.54472	validation_1-logloss:0.54717
# [22]	validation_0-logloss:0.54329	validation_1-logloss:0.54575
# [23]	validation_0-logloss:0.54153	validation_1-logloss:0.54414
# [24]	validation_0-logloss:0.54030	validation_1-logloss:0.54295
# [25]	validation_0-logloss:0.53919	validation_1-logloss:0.54190
# [26]	validation_0-logloss:0.53761	validation_1-logloss:0.54037
# [27]	validation_0-logloss:0.53679	validation_1-logloss:0.53958
# [28]	validation_0-logloss:0.53580	validation_1-logloss:0.53864
# [29]	validation_0-logloss:0.53514	validation_1-logloss:0.53802
# [30]	validation_0-logloss:0.53441	validation_1-logloss:0.53731
# [31]	validation_0-logloss:0.53343	validation_1-logloss:0.53636
# [32]	validation_0-logloss:0.53291	validation_1-logloss:0.53586
# [33]	validation_0-logloss:0.53229	validation_1-logloss:0.53531
# [34]	validation_0-logloss:0.53173	validation_1-logloss:0.53476
# [35]	validation_0-logloss:0.53124	validation_1-logloss:0.53431
# [36]	validation_0-logloss:0.53063	validation_1-logloss:0.53378
# [37]	validation_0-logloss:0.52994	validation_1-logloss:0.53311
# [38]	validation_0-logloss:0.52945	validation_1-logloss:0.53267
# [39]	validation_0-logloss:0.52900	validation_1-logloss:0.53223
# [40]	validation_0-logloss:0.52847	validation_1-logloss:0.53176
# [41]	validation_0-logloss:0.52814	validation_1-logloss:0.53144
# [42]	validation_0-logloss:0.52767	validation_1-logloss:0.53100
# [43]	validation_0-logloss:0.52737	validation_1-logloss:0.53074
# [44]	validation_0-logloss:0.52661	validation_1-logloss:0.53003
# [45]	validation_0-logloss:0.52630	validation_1-logloss:0.52974
# [46]	validation_0-logloss:0.52599	validation_1-logloss:0.52947
# [47]	validation_0-logloss:0.52548	validation_1-logloss:0.52901
# [48]	validation_0-logloss:0.52510	validation_1-logloss:0.52866
# [49]	validation_0-logloss:0.52453	validation_1-logloss:0.52814
# [50]	validation_0-logloss:0.52370	validation_1-logloss:0.52742
# [51]	validation_0-logloss:0.52310	validation_1-logloss:0.52686
# [52]	validation_0-logloss:0.52258	validation_1-logloss:0.52641
# [53]	validation_0-logloss:0.52202	validation_1-logloss:0.52591
# [54]	validation_0-logloss:0.52160	validation_1-logloss:0.52555
# [55]	validation_0-logloss:0.52127	validation_1-logloss:0.52526
# [56]	validation_0-logloss:0.52088	validation_1-logloss:0.52493
# [57]	validation_0-logloss:0.52063	validation_1-logloss:0.52472
# [58]	validation_0-logloss:0.52038	validation_1-logloss:0.52451
# [59]	validation_0-logloss:0.52007	validation_1-logloss:0.52428
# [60]	validation_0-logloss:0.51987	validation_1-logloss:0.52411
# [61]	validation_0-logloss:0.51958	validation_1-logloss:0.52384
# [62]	validation_0-logloss:0.51932	validation_1-logloss:0.52362
# [63]	validation_0-logloss:0.51911	validation_1-logloss:0.52345
# [64]	validation_0-logloss:0.51885	validation_1-logloss:0.52325
# [65]	validation_0-logloss:0.51867	validation_1-logloss:0.52309
# [66]	validation_0-logloss:0.51839	validation_1-logloss:0.52285
# [67]	validation_0-logloss:0.51812	validation_1-logloss:0.52265
# [68]	validation_0-logloss:0.51773	validation_1-logloss:0.52233
# [69]	validation_0-logloss:0.51743	validation_1-logloss:0.52210
# [70]	validation_0-logloss:0.51725	validation_1-logloss:0.52194
# [71]	validation_0-logloss:0.51707	validation_1-logloss:0.52180
# [72]	validation_0-logloss:0.51692	validation_1-logloss:0.52169
# [73]	validation_0-logloss:0.51678	validation_1-logloss:0.52158
# [74]	validation_0-logloss:0.51659	validation_1-logloss:0.52143
# [75]	validation_0-logloss:0.51640	validation_1-logloss:0.52126
# [76]	validation_0-logloss:0.51625	validation_1-logloss:0.52115
# [77]	validation_0-logloss:0.51612	validation_1-logloss:0.52104
# [78]	validation_0-logloss:0.51601	validation_1-logloss:0.52095
# [79]	validation_0-logloss:0.51591	validation_1-logloss:0.52091
# [80]	validation_0-logloss:0.51581	validation_1-logloss:0.52086
# [81]	validation_0-logloss:0.51557	validation_1-logloss:0.52068
# [82]	validation_0-logloss:0.51539	validation_1-logloss:0.52055
# [83]	validation_0-logloss:0.51528	validation_1-logloss:0.52049
# [84]	validation_0-logloss:0.51517	validation_1-logloss:0.52041
# [85]	validation_0-logloss:0.51498	validation_1-logloss:0.52028
# [86]	validation_0-logloss:0.51487	validation_1-logloss:0.52021
# [87]	validation_0-logloss:0.51478	validation_1-logloss:0.52016
# [88]	validation_0-logloss:0.51469	validation_1-logloss:0.52012
# [89]	validation_0-logloss:0.51460	validation_1-logloss:0.52006
# [90]	validation_0-logloss:0.51453	validation_1-logloss:0.52002
# [91]	validation_0-logloss:0.51443	validation_1-logloss:0.51996
# [92]	validation_0-logloss:0.51424	validation_1-logloss:0.51980
# [93]	validation_0-logloss:0.51404	validation_1-logloss:0.51967
# [94]	validation_0-logloss:0.51397	validation_1-logloss:0.51962
# [95]	validation_0-logloss:0.51390	validation_1-logloss:0.51958
# [96]	validation_0-logloss:0.51376	validation_1-logloss:0.51951
# [97]	validation_0-logloss:0.51363	validation_1-logloss:0.51942
# [98]	validation_0-logloss:0.51354	validation_1-logloss:0.51938
# [99]	validation_0-logloss:0.51349	validation_1-logloss:0.51934
# [100]	validation_0-logloss:0.51344	validation_1-logloss:0.51932
# [101]	validation_0-logloss:0.51336	validation_1-logloss:0.51928
# [102]	validation_0-logloss:0.51328	validation_1-logloss:0.51924
# [103]	validation_0-logloss:0.51320	validation_1-logloss:0.51921
# [104]	validation_0-logloss:0.51310	validation_1-logloss:0.51914
# [105]	validation_0-logloss:0.51301	validation_1-logloss:0.51911
# [106]	validation_0-logloss:0.51296	validation_1-logloss:0.51909
# [107]	validation_0-logloss:0.51288	validation_1-logloss:0.51906
# [108]	validation_0-logloss:0.51282	validation_1-logloss:0.51904
# [109]	validation_0-logloss:0.51276	validation_1-logloss:0.51902
# [110]	validation_0-logloss:0.51270	validation_1-logloss:0.51899
# [111]	validation_0-logloss:0.51265	validation_1-logloss:0.51898
# [112]	validation_0-logloss:0.51259	validation_1-logloss:0.51898
# [113]	validation_0-logloss:0.51255	validation_1-logloss:0.51897
# [114]	validation_0-logloss:0.51238	validation_1-logloss:0.51885
# [115]	validation_0-logloss:0.51231	validation_1-logloss:0.51882
# [116]	validation_0-logloss:0.51225	validation_1-logloss:0.51880
# [117]	validation_0-logloss:0.51218	validation_1-logloss:0.51876
# [118]	validation_0-logloss:0.51208	validation_1-logloss:0.51870
# [119]	validation_0-logloss:0.51203	validation_1-logloss:0.51870
# [120]	validation_0-logloss:0.51199	validation_1-logloss:0.51869
# [121]	validation_0-logloss:0.51193	validation_1-logloss:0.51867
# [122]	validation_0-logloss:0.51190	validation_1-logloss:0.51866
# [123]	validation_0-logloss:0.51182	validation_1-logloss:0.51862
# [124]	validation_0-logloss:0.51176	validation_1-logloss:0.51860
# [125]	validation_0-logloss:0.51169	validation_1-logloss:0.51857
# [126]	validation_0-logloss:0.51165	validation_1-logloss:0.51857
# [127]	validation_0-logloss:0.51160	validation_1-logloss:0.51856
# [128]	validation_0-logloss:0.51157	validation_1-logloss:0.51856
# [129]	validation_0-logloss:0.51154	validation_1-logloss:0.51855
# [130]	validation_0-logloss:0.51149	validation_1-logloss:0.51855
# [131]	validation_0-logloss:0.51144	validation_1-logloss:0.51853
# [132]	validation_0-logloss:0.51140	validation_1-logloss:0.51853
# [133]	validation_0-logloss:0.51133	validation_1-logloss:0.51851
# [134]	validation_0-logloss:0.51129	validation_1-logloss:0.51849
# [135]	validation_0-logloss:0.51125	validation_1-logloss:0.51849
# [136]	validation_0-logloss:0.51120	validation_1-logloss:0.51847
# [137]	validation_0-logloss:0.51118	validation_1-logloss:0.51847
# [138]	validation_0-logloss:0.51114	validation_1-logloss:0.51847
# [139]	validation_0-logloss:0.51111	validation_1-logloss:0.51847
# [140]	validation_0-logloss:0.51105	validation_1-logloss:0.51843
# [141]	validation_0-logloss:0.51101	validation_1-logloss:0.51842
# [142]	validation_0-logloss:0.51097	validation_1-logloss:0.51841
# [143]	validation_0-logloss:0.51095	validation_1-logloss:0.51841
# [144]	validation_0-logloss:0.51092	validation_1-logloss:0.51841
# [145]	validation_0-logloss:0.51084	validation_1-logloss:0.51839
# [146]	validation_0-logloss:0.51080	validation_1-logloss:0.51838
# [147]	validation_0-logloss:0.51077	validation_1-logloss:0.51838
# [148]	validation_0-logloss:0.51072	validation_1-logloss:0.51837
# [149]	validation_0-logloss:0.51069	validation_1-logloss:0.51836
# [150]	validation_0-logloss:0.51064	validation_1-logloss:0.51836
# [151]	validation_0-logloss:0.51062	validation_1-logloss:0.51836
# [152]	validation_0-logloss:0.51060	validation_1-logloss:0.51835
# [153]	validation_0-logloss:0.51056	validation_1-logloss:0.51835
# [154]	validation_0-logloss:0.51052	validation_1-logloss:0.51834
# [155]	validation_0-logloss:0.51048	validation_1-logloss:0.51834
# [156]	validation_0-logloss:0.51046	validation_1-logloss:0.51834
# [157]	validation_0-logloss:0.51042	validation_1-logloss:0.51833
# [158]	validation_0-logloss:0.51038	validation_1-logloss:0.51832
# [159]	validation_0-logloss:0.51031	validation_1-logloss:0.51828
# [160]	validation_0-logloss:0.51027	validation_1-logloss:0.51828
# [161]	validation_0-logloss:0.51022	validation_1-logloss:0.51828
# [162]	validation_0-logloss:0.51018	validation_1-logloss:0.51826
# [163]	validation_0-logloss:0.51015	validation_1-logloss:0.51826
# [164]	validation_0-logloss:0.51012	validation_1-logloss:0.51826
# [165]	validation_0-logloss:0.51008	validation_1-logloss:0.51825
# [166]	validation_0-logloss:0.51005	validation_1-logloss:0.51825
# [167]	validation_0-logloss:0.51000	validation_1-logloss:0.51824
# [168]	validation_0-logloss:0.50996	validation_1-logloss:0.51824
# [169]	validation_0-logloss:0.50994	validation_1-logloss:0.51824
# [170]	validation_0-logloss:0.50991	validation_1-logloss:0.51823
# [171]	validation_0-logloss:0.50986	validation_1-logloss:0.51821
# [172]	validation_0-logloss:0.50983	validation_1-logloss:0.51821
# [173]	validation_0-logloss:0.50978	validation_1-logloss:0.51821
# [174]	validation_0-logloss:0.50975	validation_1-logloss:0.51821
# [175]	validation_0-logloss:0.50971	validation_1-logloss:0.51821
# [176]	validation_0-logloss:0.50970	validation_1-logloss:0.51821
# [177]	validation_0-logloss:0.50964	validation_1-logloss:0.51817
# [178]	validation_0-logloss:0.50959	validation_1-logloss:0.51817
# ...
# [2]	validation_0-logloss:0.63774	validation_1-logloss:0.63832
# [3]	validation_0-logloss:0.62521	validation_1-logloss:0.62583
# [4]	validation_0-logloss:0.61431	validation_1-logloss:0.61500
# [5]	validation_0-logloss:0.60498	validation_1-logloss:0.60583
# [6]	validation_0-logloss:0.59684	validation_1-logloss:0.59778
# [7]	validation_0-logloss:0.58977	validation_1-logloss:0.59084
# [8]	validation_0-logloss:0.58364	validation_1-logloss:0.58480
# [9]	validation_0-logloss:0.57827	validation_1-logloss:0.57956
# [10]	validation_0-logloss:0.57336	validation_1-logloss:0.57476
# [11]	validation_0-logloss:0.56914	validation_1-logloss:0.57063
# [12]	validation_0-logloss:0.56544	validation_1-logloss:0.56695
# [13]	validation_0-logloss:0.56205	validation_1-logloss:0.56362
# [14]	validation_0-logloss:0.55917	validation_1-logloss:0.56083
# [15]	validation_0-logloss:0.55651	validation_1-logloss:0.55823
# [16]	validation_0-logloss:0.55403	validation_1-logloss:0.55580
# [17]	validation_0-logloss:0.55188	validation_1-logloss:0.55371
# [18]	validation_0-logloss:0.54973	validation_1-logloss:0.55162
# [19]	validation_0-logloss:0.54786	validation_1-logloss:0.54980
# [20]	validation_0-logloss:0.54606	validation_1-logloss:0.54810
# [21]	validation_0-logloss:0.54456	validation_1-logloss:0.54662
# [22]	validation_0-logloss:0.54314	validation_1-logloss:0.54525
# [23]	validation_0-logloss:0.54187	validation_1-logloss:0.54402
# [24]	validation_0-logloss:0.54068	validation_1-logloss:0.54286
# [25]	validation_0-logloss:0.53951	validation_1-logloss:0.54175
# [26]	validation_0-logloss:0.53852	validation_1-logloss:0.54080
# [27]	validation_0-logloss:0.53774	validation_1-logloss:0.54005
# [28]	validation_0-logloss:0.53639	validation_1-logloss:0.53878
# [29]	validation_0-logloss:0.53488	validation_1-logloss:0.53737
# [30]	validation_0-logloss:0.53413	validation_1-logloss:0.53667
# [31]	validation_0-logloss:0.53331	validation_1-logloss:0.53591
# [32]	validation_0-logloss:0.53274	validation_1-logloss:0.53536
# [33]	validation_0-logloss:0.53205	validation_1-logloss:0.53474
# [34]	validation_0-logloss:0.53137	validation_1-logloss:0.53410
# [35]	validation_0-logloss:0.53067	validation_1-logloss:0.53345
# [36]	validation_0-logloss:0.53002	validation_1-logloss:0.53287
# [37]	validation_0-logloss:0.52945	validation_1-logloss:0.53231
# [38]	validation_0-logloss:0.52895	validation_1-logloss:0.53188
# [39]	validation_0-logloss:0.52849	validation_1-logloss:0.53145
# [40]	validation_0-logloss:0.52780	validation_1-logloss:0.53082
# [41]	validation_0-logloss:0.52744	validation_1-logloss:0.53050
# [42]	validation_0-logloss:0.52703	validation_1-logloss:0.53012
# [43]	validation_0-logloss:0.52648	validation_1-logloss:0.52960
# [44]	validation_0-logloss:0.52602	validation_1-logloss:0.52916
# [45]	validation_0-logloss:0.52563	validation_1-logloss:0.52880
# [46]	validation_0-logloss:0.52512	validation_1-logloss:0.52837
# [47]	validation_0-logloss:0.52448	validation_1-logloss:0.52784
# [48]	validation_0-logloss:0.52419	validation_1-logloss:0.52758
# [49]	validation_0-logloss:0.52379	validation_1-logloss:0.52723
# [50]	validation_0-logloss:0.52321	validation_1-logloss:0.52677
# [51]	validation_0-logloss:0.52279	validation_1-logloss:0.52642
# [52]	validation_0-logloss:0.52240	validation_1-logloss:0.52610
# [53]	validation_0-logloss:0.52207	validation_1-logloss:0.52582
# [54]	validation_0-logloss:0.52177	validation_1-logloss:0.52558
# [55]	validation_0-logloss:0.52126	validation_1-logloss:0.52512
# [56]	validation_0-logloss:0.52094	validation_1-logloss:0.52484
# [57]	validation_0-logloss:0.52056	validation_1-logloss:0.52451
# [58]	validation_0-logloss:0.52033	validation_1-logloss:0.52431
# [59]	validation_0-logloss:0.52008	validation_1-logloss:0.52410
# [60]	validation_0-logloss:0.51980	validation_1-logloss:0.52387
# [61]	validation_0-logloss:0.51960	validation_1-logloss:0.52371
# [62]	validation_0-logloss:0.51916	validation_1-logloss:0.52334
# [63]	validation_0-logloss:0.51896	validation_1-logloss:0.52319
# [64]	validation_0-logloss:0.51868	validation_1-logloss:0.52298
# [65]	validation_0-logloss:0.51825	validation_1-logloss:0.52262
# [66]	validation_0-logloss:0.51789	validation_1-logloss:0.52231
# [67]	validation_0-logloss:0.51768	validation_1-logloss:0.52216
# [68]	validation_0-logloss:0.51753	validation_1-logloss:0.52206
# [69]	validation_0-logloss:0.51717	validation_1-logloss:0.52175
# [70]	validation_0-logloss:0.51700	validation_1-logloss:0.52163
# [71]	validation_0-logloss:0.51680	validation_1-logloss:0.52146
# [72]	validation_0-logloss:0.51663	validation_1-logloss:0.52133
# [73]	validation_0-logloss:0.51646	validation_1-logloss:0.52120
# [74]	validation_0-logloss:0.51631	validation_1-logloss:0.52109
# [75]	validation_0-logloss:0.51601	validation_1-logloss:0.52086
# [76]	validation_0-logloss:0.51586	validation_1-logloss:0.52076
# [77]	validation_0-logloss:0.51574	validation_1-logloss:0.52068
# [78]	validation_0-logloss:0.51560	validation_1-logloss:0.52057
# [79]	validation_0-logloss:0.51548	validation_1-logloss:0.52050
# [80]	validation_0-logloss:0.51528	validation_1-logloss:0.52036
# [81]	validation_0-logloss:0.51517	validation_1-logloss:0.52029
# [82]	validation_0-logloss:0.51500	validation_1-logloss:0.52018
# [83]	validation_0-logloss:0.51489	validation_1-logloss:0.52011
# [84]	validation_0-logloss:0.51477	validation_1-logloss:0.52002
# [85]	validation_0-logloss:0.51467	validation_1-logloss:0.51996
# [86]	validation_0-logloss:0.51458	validation_1-logloss:0.51989
# [87]	validation_0-logloss:0.51448	validation_1-logloss:0.51983
# [88]	validation_0-logloss:0.51439	validation_1-logloss:0.51975
# [89]	validation_0-logloss:0.51431	validation_1-logloss:0.51971
# [90]	validation_0-logloss:0.51424	validation_1-logloss:0.51967
# [91]	validation_0-logloss:0.51412	validation_1-logloss:0.51958
# [92]	validation_0-logloss:0.51400	validation_1-logloss:0.51951
# [93]	validation_0-logloss:0.51387	validation_1-logloss:0.51941
# [94]	validation_0-logloss:0.51379	validation_1-logloss:0.51936
# [95]	validation_0-logloss:0.51373	validation_1-logloss:0.51933
# [96]	validation_0-logloss:0.51365	validation_1-logloss:0.51929
# [97]	validation_0-logloss:0.51357	validation_1-logloss:0.51926
# [98]	validation_0-logloss:0.51351	validation_1-logloss:0.51925
# [99]	validation_0-logloss:0.51340	validation_1-logloss:0.51916
# [100]	validation_0-logloss:0.51321	validation_1-logloss:0.51904
# [101]	validation_0-logloss:0.51316	validation_1-logloss:0.51902
# [102]	validation_0-logloss:0.51307	validation_1-logloss:0.51897
# [103]	validation_0-logloss:0.51301	validation_1-logloss:0.51892
# [104]	validation_0-logloss:0.51288	validation_1-logloss:0.51885
# [105]	validation_0-logloss:0.51282	validation_1-logloss:0.51883
# [106]	validation_0-logloss:0.51275	validation_1-logloss:0.51880
# [107]	validation_0-logloss:0.51270	validation_1-logloss:0.51879
# [108]	validation_0-logloss:0.51261	validation_1-logloss:0.51874
# [109]	validation_0-logloss:0.51250	validation_1-logloss:0.51869
# [110]	validation_0-logloss:0.51243	validation_1-logloss:0.51867
# [111]	validation_0-logloss:0.51237	validation_1-logloss:0.51865
# [112]	validation_0-logloss:0.51230	validation_1-logloss:0.51863
# [113]	validation_0-logloss:0.51224	validation_1-logloss:0.51862
# [114]	validation_0-logloss:0.51219	validation_1-logloss:0.51860
# [115]	validation_0-logloss:0.51213	validation_1-logloss:0.51859
# [116]	validation_0-logloss:0.51201	validation_1-logloss:0.51852
# [117]	validation_0-logloss:0.51197	validation_1-logloss:0.51851
# [118]	validation_0-logloss:0.51192	validation_1-logloss:0.51849
# [119]	validation_0-logloss:0.51186	validation_1-logloss:0.51846
# [120]	validation_0-logloss:0.51183	validation_1-logloss:0.51845
# [121]	validation_0-logloss:0.51179	validation_1-logloss:0.51845
# [122]	validation_0-logloss:0.51173	validation_1-logloss:0.51845
# [123]	validation_0-logloss:0.51167	validation_1-logloss:0.51842
# [124]	validation_0-logloss:0.51162	validation_1-logloss:0.51841
# [125]	validation_0-logloss:0.51158	validation_1-logloss:0.51839
# [126]	validation_0-logloss:0.51153	validation_1-logloss:0.51838
# [127]	validation_0-logloss:0.51149	validation_1-logloss:0.51836
# [128]	validation_0-logloss:0.51145	validation_1-logloss:0.51836
# [129]	validation_0-logloss:0.51143	validation_1-logloss:0.51834
# [130]	validation_0-logloss:0.51139	validation_1-logloss:0.51834
# [131]	validation_0-logloss:0.51131	validation_1-logloss:0.51831
# [132]	validation_0-logloss:0.51127	validation_1-logloss:0.51831
# [133]	validation_0-logloss:0.51122	validation_1-logloss:0.51831
# [134]	validation_0-logloss:0.51109	validation_1-logloss:0.51825
# [135]	validation_0-logloss:0.51105	validation_1-logloss:0.51825
# [136]	validation_0-logloss:0.51098	validation_1-logloss:0.51821
# [137]	validation_0-logloss:0.51094	validation_1-logloss:0.51819
# [138]	validation_0-logloss:0.51091	validation_1-logloss:0.51819
# [139]	validation_0-logloss:0.51085	validation_1-logloss:0.51817
# [140]	validation_0-logloss:0.51082	validation_1-logloss:0.51817
# [141]	validation_0-logloss:0.51079	validation_1-logloss:0.51817
# [142]	validation_0-logloss:0.51074	validation_1-logloss:0.51814
# [143]	validation_0-logloss:0.51070	validation_1-logloss:0.51813
# [144]	validation_0-logloss:0.51064	validation_1-logloss:0.51810
# [145]	validation_0-logloss:0.51059	validation_1-logloss:0.51809
# [146]	validation_0-logloss:0.51055	validation_1-logloss:0.51809
# [147]	validation_0-logloss:0.51052	validation_1-logloss:0.51809
# [148]	validation_0-logloss:0.51047	validation_1-logloss:0.51806
# [149]	validation_0-logloss:0.51042	validation_1-logloss:0.51806
# [150]	validation_0-logloss:0.51037	validation_1-logloss:0.51805
# [151]	validation_0-logloss:0.51034	validation_1-logloss:0.51805
# [152]	validation_0-logloss:0.51031	validation_1-logloss:0.51805
# [153]	validation_0-logloss:0.51027	validation_1-logloss:0.51804
# [154]	validation_0-logloss:0.51023	validation_1-logloss:0.51804
# [155]	validation_0-logloss:0.51018	validation_1-logloss:0.51803
# [156]	validation_0-logloss:0.51015	validation_1-logloss:0.51802
# [157]	validation_0-logloss:0.51012	validation_1-logloss:0.51802
# [158]	validation_0-logloss:0.51010	validation_1-logloss:0.51802
# [159]	validation_0-logloss:0.51000	validation_1-logloss:0.51797
# [160]	validation_0-logloss:0.50997	validation_1-logloss:0.51796
# [161]	validation_0-logloss:0.50992	validation_1-logloss:0.51797
# [162]	validation_0-logloss:0.50987	validation_1-logloss:0.51796
# [163]	validation_0-logloss:0.50984	validation_1-logloss:0.51796
# [164]	validation_0-logloss:0.50980	validation_1-logloss:0.51796
# [165]	validation_0-logloss:0.50976	validation_1-logloss:0.51796
# [166]	validation_0-logloss:0.50973	validation_1-logloss:0.51795
# [167]	validation_0-logloss:0.50971	validation_1-logloss:0.51795
# [168]	validation_0-logloss:0.50969	validation_1-logloss:0.51794
# [169]	validation_0-logloss:0.50966	validation_1-logloss:0.51794
# [170]	validation_0-logloss:0.50964	validation_1-logloss:0.51794
# [171]	validation_0-logloss:0.50961	validation_1-logloss:0.51795
# [172]	validation_0-logloss:0.50953	validation_1-logloss:0.51791
# [173]	validation_0-logloss:0.50952	validation_1-logloss:0.51791
# [174]	validation_0-logloss:0.50950	validation_1-logloss:0.51791
# [175]	validation_0-logloss:0.50947	validation_1-logloss:0.51790
# [176]	validation_0-logloss:0.50940	validation_1-logloss:0.51789
# [177]	validation_0-logloss:0.50936	validation_1-logloss:0.51789
# [178]	validation_0-logloss:0.50934	validation_1-logloss:0.51789
# [179]	validation_0-logloss:0.50932	validation_1-logloss:0.51789
# [180]	validation_0-logloss:0.50929	validation_1-logloss:0.51789
# [181]	validation_0-logloss:0.50923	validation_1-logloss:0.51787
# [182]	validation_0-logloss:0.50919	validation_1-logloss:0.51787
# [183]	validation_0-logloss:0.50915	validation_1-logloss:0.51787
# [184]	validation_0-logloss:0.50913	validation_1-logloss:0.51787
# [185]	validation_0-logloss:0.50911	validation_1-logloss:0.51787
# [186]	validation_0-logloss:0.50909	validation_1-logloss:0.51787
# [187]	validation_0-logloss:0.50908	validation_1-logloss:0.51787
# [188]	validation_0-logloss:0.50906	validation_1-logloss:0.51787
# [189]	validation_0-logloss:0.50902	validation_1-logloss:0.51787
# [190]	validation_0-logloss:0.50895	validation_1-logloss:0.51785
# [191]	validation_0-logloss:0.50892	validation_1-logloss:0.51784
# [192]	validation_0-logloss:0.50888	validation_1-logloss:0.51785
# [193]	validation_0-logloss:0.50884	validation_1-logloss:0.51785
# [194]	validation_0-logloss:0.50877	validation_1-logloss:0.51784
# [195]	validation_0-logloss:0.50873	validation_1-logloss:0.51784
# [196]	validation_0-logloss:0.50871	validation_1-logloss:0.51784
# [197]	validation_0-logloss:0.50869	validation_1-logloss:0.51785
# [198]	validation_0-logloss:0.50866	validation_1-logloss:0.51784
# [199]	validation_0-logloss:0.50865	validation_1-logloss:0.51784
# [200]	validation_0-logloss:0.50862	validation_1-logloss:0.51783
# [201]	validation_0-logloss:0.50859	validation_1-logloss:0.51783
# [202]	validation_0-logloss:0.50856	validation_1-logloss:0.51783
# [203]	validation_0-logloss:0.50853	validation_1-logloss:0.51783
# [204]	validation_0-logloss:0.50849	validation_1-logloss:0.51783
# [205]	validation_0-logloss:0.50845	validation_1-logloss:0.51784
# [206]	validation_0-logloss:0.50844	validation_1-logloss:0.51784
# [207]	validation_0-logloss:0.50841	validation_1-logloss:0.51785
# [208]	validation_0-logloss:0.50838	validation_1-logloss:0.51786
# [209]	validation_0-logloss:0.50831	validation_1-logloss:0.51784
# [210]	validation_0-logloss:0.50828	validation_1-logloss:0.51783
# [211]	validation_0-logloss:0.50826	validation_1-logloss:0.51784
# [212]	validation_0-logloss:0.50824	validation_1-logloss:0.51784
# [213]	validation_0-logloss:0.50820	validation_1-logloss:0.51784
# [214]	validation_0-logloss:0.50817	validation_1-logloss:0.51785
# [215]	validation_0-logloss:0.50814	validation_1-logloss:0.51785
# [216]	validation_0-logloss:0.50811	validation_1-logloss:0.51785
# [217]	validation_0-logloss:0.50809	validation_1-logloss:0.51786
# [218]	validation_0-logloss:0.50804	validation_1-logloss:0.51785
# [219]	validation_0-logloss:0.50801	validation_1-logloss:0.51785
# [220]	validation_0-logloss:0.50796	validation_1-logloss:0.51784
# [221]	validation_0-logloss:0.50794	validation_1-logloss:0.51785
# [222]	validation_0-logloss:0.50789	validation_1-logloss:0.51785
# [223]	validation_0-logloss:0.50787	validation_1-logloss:0.51785
# [224]	validation_0-logloss:0.50784	validation_1-logloss:0.51786
# [225]	validation_0-logloss:0.50783	validation_1-logloss:0.51786
# [226]	validation_0-logloss:0.50781	validation_1-logloss:0.51786
# [227]	validation_0-logloss:0.50777	validation_1-logloss:0.51786
# [228]	validation_0-logloss:0.50774	validation_1-logloss:0.51785
# [229]	validation_0-logloss:0.50768	validation_1-logloss:0.51785
# [230]	validation_0-logloss:0.50765	validation_1-logloss:0.51785
# [231]	validation_0-logloss:0.50761	validation_1-logloss:0.51785
# [232]	validation_0-logloss:0.50758	validation_1-logloss:0.51785
# [233]	validation_0-logloss:0.50756	validation_1-logloss:0.51784
# [234]	validation_0-logloss:0.50753	validation_1-logloss:0.51785
# [235]	validation_0-logloss:0.50750	validation_1-logloss:0.51785
# [236]	validation_0-logloss:0.50748	validation_1-logloss:0.51785
# [237]	validation_0-logloss:0.50747	validation_1-logloss:0.51785
# [238]	validation_0-logloss:0.50746	validation_1-logloss:0.51785
# [239]	validation_0-logloss:0.50745	validation_1-logloss:0.51786
# [240]	validation_0-logloss:0.50743	validation_1-logloss:0.51786
# [241]	validation_0-logloss:0.50740	validation_1-logloss:0.51786
# [242]	validation_0-logloss:0.50738	validation_1-logloss:0.51786
# [243]	validation_0-logloss:0.50731	validation_1-logloss:0.51784
# [244]	validation_0-logloss:0.50729	validation_1-logloss:0.51784
# [245]	validation_0-logloss:0.50728	validation_1-logloss:0.51785
# [246]	validation_0-logloss:0.50724	validation_1-logloss:0.51785
# [247]	validation_0-logloss:0.50723	validation_1-logloss:0.51784
# [248]	validation_0-logloss:0.50720	validation_1-logloss:0.51785
# [249]	validation_0-logloss:0.50717	validation_1-logloss:0.51785
# [250]	validation_0-logloss:0.50714	validation_1-logloss:0.51786
# [251]	validation_0-logloss:0.50713	validation_1-logloss:0.51785
# [252]	validation_0-logloss:0.50709	validation_1-logloss:0.51785
#  ########################################

# %%
# XGBoost with the kinematic variables of the leptons

########################
# CLASSIFICATION SCORE #
########################

# Outputs for validation data set

pred_XG_SM_1ML = []
pred_XG_NP_1ML = []

for i in range(len(y_mon_test)):
    if y_mon_test[i] == 0:
        pred_XG_SM_1ML.append(y_pred_xg_1ML[i])
    else:
        pred_XG_NP_1ML.append(y_pred_xg_1ML[i])
        
        
print('Classification score (1ML):')
        
weights = np.ones_like(pred_XG_SM_1ML)/float(len(pred_XG_SM_1ML))
nSM, binsSM, patchesSM = plt.hist(pred_XG_SM_1ML, 100, weights=weights, range=[0,1], histtype='step', color='firebrick', linewidth=2, label='Background')

weights = np.ones_like(pred_XG_NP_1ML)/float(len(pred_XG_NP_1ML))
nNP, binsNP, patchesNP = plt.hist(pred_XG_NP_1ML, 100, weights=weights, range=[0,1], histtype='step', color='forestgreen', linewidth=2, label='Signal')

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("Classication score (XGBoost)",fontsize=15)
plt.ylabel("Fraction of events",fontsize=14)
plt.grid()
plt.legend(fontsize=12)
plt.title('Multivariate monian distributions, $\mathcal{N}_{2}$', fontsize=14)
#plt.savefig('images/' + '2monian-output.pdf', format="pdf", bbox_inches="tight")
plt.show()




# Outputs for validation data set

pred_XG_SM = []
pred_XG_NP = []

for i in range(len(y_mon_test)):
    if y_mon_test[i] == 0:
        pred_XG_SM.append(y_pred_xg[i])
    else:
        pred_XG_NP.append(y_pred_xg[i])
        
        
print('Classification score (10ML):')
        
weights = np.ones_like(pred_XG_SM)/float(len(pred_XG_SM))
nSM, binsSM, patchesSM = plt.hist(pred_XG_SM, 100, weights=weights, range=[0,1], histtype='step', color='firebrick', linewidth=2, label='Background')

weights = np.ones_like(pred_XG_NP)/float(len(pred_XG_NP))
nNP, binsNP, patchesNP = plt.hist(pred_XG_NP, 100, weights=weights, range=[0,1], histtype='step', color='forestgreen', linewidth=2, label='Signal')

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("Classication score (XGBoost)",fontsize=15)
plt.ylabel("Fraction of events",fontsize=14)
plt.grid()
plt.legend(fontsize=12)
plt.title('Multivariate monian distributions, $\mathcal{N}_{2}$', fontsize=14)
#plt.savefig('images/' + '2monian-output.pdf', format="pdf", bbox_inches="tight")
plt.show()
# Out:
# Classification score (1ML):
# Classification score (10ML):

# %% [markdown]
# ## METHODS

# %% [markdown]
# ### 0. Ensembles characteristics

# %%
##############
# PARAMETERS #
##############

# requested number of ensembles
n_ensembles = 5000

# number of expected background events per ensemble
B_expected = 5000

# ratio S_expected/B_expected (signal ratio)
SB_ratio = [0.0006, 0.001, 0.0016, 0.0025, 0.005, 0.0075, 0.01, 0.025]





# SOME USEFUL DERIVATED PARAMETERS:

# S_expected:
S_expected = [ int(SB_ratio[iii]*B_expected) for iii in range(len(SB_ratio)) ]
print(S_expected)

# S/\sqrt{B}
SsqrtB = [ S_expected[iii]/(B_expected)**0.5 for iii in range(len(SB_ratio)) ]
# Out:
# [2, 5, 8, 12, 25, 37, 50, 125]

# %% [markdown]
# ### 1. BIN LOG LIKELIHOOD

# %%
# 1st variable: invariant mass
background_X_1 = invariant_mass_eeSM
signal_X_1 = invariant_mass_eeSSMZprime

N_B = len(background_X_1)
N_S = len(signal_X_1)

# bins
logbins = [2000.0, 2200.0, 2500.0, 2850.0, 3250.0, 3750.0, 4350.0, 5000.0, 5750.0, 6600.0, 7500.0, 8750.0, 10000.0, 11500.0, 13000.0, 20000.0]

# %%
#################################
# BINNED POISSON LOG-LIKELIHOOD #
#################################


store_Z_bins = []
store_Z_bins_logbins = []


for iii in range(len(SB_ratio)):

    print('B_expected: ', B_expected)
    print('S_expected: ', S_expected[iii])
    print(r'S/$\sqrt{B}$: ', SsqrtB[iii])

    # Les't use an integer number of possible ensembles
    N_ensembles_back = int(N_B / B_expected)
    N_events_back = N_ensembles_back * B_expected

    N_ensembles_sig = int(N_S / S_expected[iii])
    N_events_sig = N_ensembles_sig * S_expected[iii]


    #Let's find out the expected number of B and S events in each bin:

    # bin the parameter space of all background events
    hist_back, binedges_back = np.histogramdd([background_X_1[:N_events_back]], bins=(100), range = [[2000,20000]])
    # now divide by the number of possible ensembles
    back_prom = hist_back.T.ravel()/N_ensembles_back

    # same for signal
    hist_sig, binedges_sig = np.histogramdd([signal_X_1[:N_events_sig]], bins=(100), range = [[2000,20000]])
    sig_prom = hist_sig.T.ravel()/N_ensembles_sig

        

    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    back_prom_noceros = []
    for i in range(len(back_prom)):
        if back_prom[i]!=0:
            back_prom_noceros.append(back_prom[i])

    min_back = min(back_prom_noceros)

    # replace the zeros
    for i in range(len(back_prom)):
        if back_prom[i]==0:
            back_prom[i] = min_back

    # then the signif Z^binned-Asimov:
    Z_bins = ( 2* sum( ( back_prom * np.log( back_prom/(sig_prom + back_prom) ) ) + sig_prom ) )**0.5

    store_Z_bins.append(Z_bins)

    print('Z_bins : ', Z_bins)
    

    
    ############
    # LOG BINS #
    ############
    #Let's find out the expected number of B and S events in each bin:

    # bin the parameter space of all background events
    hist_back, binedges_back = np.histogramdd([background_X_1[:N_events_back]], bins=[logbins])
    # now divide by the number of possible ensembles
    back_prom = hist_back.T.ravel()/N_ensembles_back

    # same for signal
    hist_sig, binedges_sig = np.histogramdd([signal_X_1[:N_events_sig]], bins=[logbins])
    sig_prom = hist_sig.T.ravel()/N_ensembles_sig

        

    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    back_prom_noceros = []
    for i in range(len(back_prom)):
        if back_prom[i]!=0:
            back_prom_noceros.append(back_prom[i])

    min_back = min(back_prom_noceros)

    # replace the zeros
    for i in range(len(back_prom)):
        if back_prom[i]==0:
            back_prom[i] = min_back

    # then the signif Z^binned-Asimov:
    Z_bins_logbins = ( 2* sum( ( back_prom * np.log( back_prom/(sig_prom + back_prom) ) ) + sig_prom ) )**0.5

    store_Z_bins_logbins.append(Z_bins_logbins)

    print('Z_bins_logbins : ', Z_bins_logbins)
    
    
    
    print('\n ----------------------------------- \n')
# Out:
# B_expected:  5000
# S_expected:  2
# S/$\sqrt{B}$:  0.0282842712474619
# Z_bins :  0.5940367426883248
# Z_bins_logbins :  0.5698074677567132
#
#  -----------------------------------
#
# B_expected:  5000
# S_expected:  5
# S/$\sqrt{B}$:  0.07071067811865475
# Z_bins :  1.1100675009007188
# Z_bins_logbins :  1.0869956281904634
#
#  -----------------------------------
#
# B_expected:  5000
# S_expected:  8
# S/$\sqrt{B}$:  0.1131370849898476
# Z_bins :  1.497997689302027
# Z_bins_logbins :  1.4757459352161848
#
#  -----------------------------------
#
# B_expected:  5000
# S_expected:  12
# S/$\sqrt{B}$:  0.1697056274847714
# Z_bins :  1.9234872002995989
# Z_bins_logbins :  1.9012301371028577
#
#  -----------------------------------
#
# B_expected:  5000
# S_expected:  25
# S/$\sqrt{B}$:  0.35355339059327373
# Z_bins :  2.982131588524039
# Z_bins_logbins :  2.95759050318771
#
#  -----------------------------------
#
# B_expected:  5000
# S_expected:  37
# S/$\sqrt{B}$:  0.5232590180780452
# Z_bins :  3.751831258644401
# Z_bins_logbins :  3.7250330805294642
#
#  -----------------------------------
#
# B_expected:  5000
# S_expected:  50
# S/$\sqrt{B}$:  0.7071067811865475
# Z_bins :  4.470653135566163
# Z_bins_logbins :  4.441743209834702
#
#  -----------------------------------
#
# B_expected:  5000
# S_expected:  125
# S/$\sqrt{B}$:  1.7677669529663687
# Z_bins :  7.620020417292141
# Z_bins_logbins :  7.582435460778635
#
#  -----------------------------------

# %%
print(store_Z_bins)
print(store_Z_bins_logbins)
# Out:
# [0.5940367426883248, 1.1100675009007188, 1.497997689302027, 1.9234872002995989, 2.982131588524039, 3.751831258644401, 4.470653135566163, 7.620020417292141]
# [0.5698074677567132, 1.0869956281904634, 1.4757459352161848, 1.9012301371028577, 2.95759050318771, 3.7250330805294642, 4.441743209834702, 7.582435460778635]

# %%
store_Z_bins = [0.5940367426883248, 1.1100675009007188, 1.497997689302027, 1.9234872002995989, 2.982131588524039, 3.751831258644401, 4.470653135566163, 7.620020417292141]

store_Z_bins_logbins = [0.5698074677567132, 1.0869956281904634, 1.4757459352161848, 1.9012301371028577, 2.95759050318771, 3.7250330805294642, 4.441743209834702, 7.582435460778635]

# %%
#########
# PLOTS #
#########

posX = []

for i in range(len(SB_ratio)):
    posX.append( (B_expected*SB_ratio[i]) / ( B_expected )**0.5 )


    
plt.figure()
lw = 2

plt.plot(posX, store_Z_bins, '-ok', color='blue', lw=lw, label='100 Linear Binned Likelihood') 
plt.plot(posX, store_Z_bins_logbins, '-ok', color='lightblue', lw=lw, label='15 Log Binned Likelihood')

#plt.xlim([0.5, 10])
#plt.ylim([-0.5, 7.5])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=14)
plt.ylabel('$Z_{\mu}$ (exclusion)', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title('<B> per ensemble: %0.2d' % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()
# Out:
# <ipython-input-20-3340ebf10fa5>:15: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins, '-ok', color='blue', lw=lw, label='100 Linear Binned Likelihood')
# <ipython-input-20-3340ebf10fa5>:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_logbins, '-ok', color='lightblue', lw=lw, label='15 Log Binned Likelihood')

# %% [markdown]
# ### 2. Binned OUTPUT and MLL Asimov

# %%
#################################
# MLL Asimov-like #
#################################


store_Z_bins_XG = []

store_Z_bins_XG_15bins = []
store_Z_bins_XG_15bins_1ML = []

store_Z_bins_XG_15bins_eq = []
store_Z_bins_XG_15bins_eq_1ML = []


for iii in range(len(SB_ratio)):

    print('B_expected: ', B_expected)
    print('S_expected: ', S_expected[iii])
    print(r'S/$\sqrt{B}$: ', SsqrtB[iii])

    # Les't find the number of possible ensembles
    N_ensembles_back = len(pred_XG_SM) / B_expected
    N_ensembles_sig = len(pred_XG_NP) / S_expected[iii]



    #Let's find out the expected number of B and S events in each bin:
 
    # bin the parameter space of all background events
    hist_back, binedges_back = np.histogramdd([pred_XG_SM], bins=(100), range = [[0,1]])
    
    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    hist_back_noceros = []
    for i in range(len(hist_back)):
        if hist_back[i]!=0:
            hist_back_noceros.append(hist_back[i])

    min_back = min(hist_back_noceros)

    # replace the zeros
    for i in range(len(hist_back)):
        if hist_back[i]==0:
            hist_back[i] = min_back
    
    # now divide by the number of possible ensembles
    back_prom = hist_back/N_ensembles_back
    # normalized (sum=1)
    back_norm = hist_back/np.sum(hist_back)

    
    
    # same for signal
    hist_sig, binedges_sig = np.histogramdd([pred_XG_NP], bins=(100), range = [[0,1]])
    sig_prom = hist_sig/N_ensembles_sig
    sig_norm = hist_sig/np.sum(hist_sig)
        


    ##########################################
    # BINNED LIKELIHOOD of CLASSIFIER OUTPUT #
    ##########################################

    # then the signif Z^binned-Asimov:
    Z_bins_XG = ( 2* sum( ( back_prom * np.log( back_prom / (sig_prom+back_prom) ) ) + sig_prom ) )**0.5

    store_Z_bins_XG.append(Z_bins_XG)

    print('Z_bins_XG : ', Z_bins_XG)
    
    
    
    
    
    ######################
    # linear bins, 10 ML #
    ######################
    
    #Let's find out the expected number of B and S events in each bin:
 
    # bin the parameter space of all background events
    hist_back, binedges_back = np.histogramdd([pred_XG_SM], bins=(15), range = [[0,1]])
    
    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    hist_back_noceros = []
    for i in range(len(hist_back)):
        if hist_back[i]!=0:
            hist_back_noceros.append(hist_back[i])

    min_back = min(hist_back_noceros)

    # replace the zeros
    for i in range(len(hist_back)):
        if hist_back[i]==0:
            hist_back[i] = min_back
    
    # now divide by the number of possible ensembles
    back_prom = hist_back/N_ensembles_back
    # normalized (sum=1)
    back_norm = hist_back/np.sum(hist_back)

    
    
    # same for signal
    hist_sig, binedges_sig = np.histogramdd([pred_XG_NP], bins=(15), range = [[0,1]])
    sig_prom = hist_sig/N_ensembles_sig
    sig_norm = hist_sig/np.sum(hist_sig)
        


    ##########################################
    # BINNED LIKELIHOOD of CLASSIFIER OUTPUT #
    ##########################################

    # then the signif Z^binned-Asimov:
    Z_bins_XG_15bins = ( 2* sum( ( back_prom * np.log( back_prom / (sig_prom+back_prom) ) ) + sig_prom ) )**0.5

    store_Z_bins_XG_15bins.append(Z_bins_XG_15bins)

    print('Z_bins_XG_15bins : ', Z_bins_XG_15bins)
    
    
    
    
    
    ######################
    # linear bins, 1  ML #
    ######################
    
    #Let's find out the expected number of B and S events in each bin:
 
    # bin the parameter space of all background events
    hist_back, binedges_back = np.histogramdd([pred_XG_SM_1ML], bins=(15), range = [[0,1]])
    
    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    hist_back_noceros = []
    for i in range(len(hist_back)):
        if hist_back[i]!=0:
            hist_back_noceros.append(hist_back[i])

    min_back = min(hist_back_noceros)

    # replace the zeros
    for i in range(len(hist_back)):
        if hist_back[i]==0:
            hist_back[i] = min_back
    
    # now divide by the number of possible ensembles
    back_prom = hist_back/N_ensembles_back
    # normalized (sum=1)
    back_norm = hist_back/np.sum(hist_back)

    
    
    # same for signal
    hist_sig, binedges_sig = np.histogramdd([pred_XG_NP], bins=(15), range = [[0,1]])
    sig_prom = hist_sig/N_ensembles_sig
    sig_norm = hist_sig/np.sum(hist_sig)
        


    ##########################################
    # BINNED LIKELIHOOD of CLASSIFIER OUTPUT #
    ##########################################

    # then the signif Z^binned-Asimov:
    Z_bins_XG_15bins_1ML = ( 2* sum( ( back_prom * np.log( back_prom / (sig_prom+back_prom) ) ) + sig_prom ) )**0.5

    store_Z_bins_XG_15bins_1ML.append(Z_bins_XG_15bins_1ML)

    print('Z_bins_XG_15bins_1ML : ', Z_bins_XG_15bins_1ML)
    
    
    
    
    
    ##########################
    # non linear bins, 10 ML #
    ##########################
    
    #Let's find out the expected number of B and S events in each bin:
    # same number of B events per bin
    bin_edges_same = pd.qcut(pd.DataFrame(pred_XG_SM)[0], q = 15, precision=0, retbins = True)[1]
 
    # bin the parameter space of all background events
    hist_back, binedges_back = np.histogramdd([pred_XG_SM], bins=[bin_edges_same], range = [[0,1]])
    
    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    hist_back_noceros = []
    for i in range(len(hist_back)):
        if hist_back[i]!=0:
            hist_back_noceros.append(hist_back[i])

    min_back = min(hist_back_noceros)

    # replace the zeros
    for i in range(len(hist_back)):
        if hist_back[i]==0:
            hist_back[i] = min_back
    
    # now divide by the number of possible ensembles
    back_prom = hist_back/N_ensembles_back
    # normalized (sum=1)
    back_norm = hist_back/np.sum(hist_back)

    
    
    # same for signal
    hist_sig, binedges_sig = np.histogramdd([pred_XG_NP], bins=[bin_edges_same], range = [[0,1]])
    sig_prom = hist_sig/N_ensembles_sig
    sig_norm = hist_sig/np.sum(hist_sig)
        


    ##########################################
    # BINNED LIKELIHOOD of CLASSIFIER OUTPUT #
    ##########################################

    # then the signif Z^binned-Asimov:
    Z_bins_XG_15bins_eq = ( 2* sum( ( back_prom * np.log( back_prom / (sig_prom+back_prom) ) ) + sig_prom ) )**0.5

    store_Z_bins_XG_15bins_eq.append(Z_bins_XG_15bins_eq)

    print('Z_bins_XG_15bins_eq : ', Z_bins_XG_15bins_eq)
    
    
    
    
    
    ##########################
    # non linear bins, 1  ML #
    ##########################
    
    #Let's find out the expected number of B and S events in each bin:
    # same number of B events per bin
    bin_edges_same = pd.qcut(pd.DataFrame(pred_XG_SM_1ML)[0], q = 15, precision=0, retbins = True)[1]
 
    # bin the parameter space of all background events
    hist_back, binedges_back = np.histogramdd([pred_XG_SM_1ML], bins=[bin_edges_same], range = [[0,1]])
    
    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    hist_back_noceros = []
    for i in range(len(hist_back)):
        if hist_back[i]!=0:
            hist_back_noceros.append(hist_back[i])

    min_back = min(hist_back_noceros)

    # replace the zeros
    for i in range(len(hist_back)):
        if hist_back[i]==0:
            hist_back[i] = min_back
    
    # now divide by the number of possible ensembles
    back_prom = hist_back/N_ensembles_back
    # normalized (sum=1)
    back_norm = hist_back/np.sum(hist_back)

    
    
    # same for signal
    hist_sig, binedges_sig = np.histogramdd([pred_XG_NP_1ML], bins=[bin_edges_same], range = [[0,1]])
    sig_prom = hist_sig/N_ensembles_sig
    sig_norm = hist_sig/np.sum(hist_sig)
        


    ##########################################
    # BINNED LIKELIHOOD of CLASSIFIER OUTPUT #
    ##########################################

    # then the signif Z^binned-Asimov:
    Z_bins_XG_15bins_eq_1ML = ( 2* sum( ( back_prom * np.log( back_prom / (sig_prom+back_prom) ) ) + sig_prom ) )**0.5

    store_Z_bins_XG_15bins_eq_1ML.append(Z_bins_XG_15bins_eq_1ML)

    print('Z_bins_XG_15bins_eq_1ML : ', Z_bins_XG_15bins_eq_1ML)


        
    print('\n ----------------------------------------- \n')
# Out:
# B_expected:  5000
# S_expected:  2
# S/$\sqrt{B}$:  0.0282842712474619
# Z_bins_XG :  0.33702424030301237
# Z_bins_XG_15bins :  0.14832844831099473
# Z_bins_XG_15bins_1ML :  0.1448340881828426
# Z_bins_XG_15bins_eq :  0.05770545851710914
# Z_bins_XG_15bins_eq_1ML :  0.057059491174002636
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  5
# S/$\sqrt{B}$:  0.07071067811865475
# Z_bins_XG :  0.7596602712997451
# Z_bins_XG_15bins :  0.3646913803804097
# Z_bins_XG_15bins_1ML :  0.3563755448532078
# Z_bins_XG_15bins_eq :  0.14406165168446175
# Z_bins_XG_15bins_eq_1ML :  0.14245184312161097
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  8
# S/$\sqrt{B}$:  0.1131370849898476
# Z_bins_XG :  1.1194256037347121
# Z_bins_XG_15bins :  0.5742705393847328
# Z_bins_XG_15bins_1ML :  0.5615750827263757
# Z_bins_XG_15bins_eq :  0.23017716542483432
# Z_bins_XG_15bins_eq_1ML :  0.22760958346893256
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  12
# S/$\sqrt{B}$:  0.1697056274847714
# Z_bins_XG :  1.5362235188171118
# Z_bins_XG_15bins :  0.8441242250453542
# Z_bins_XG_15bins_1ML :  0.8261766434432305
# Z_bins_XG_15bins_eq :  0.3446267513830938
# Z_bins_XG_15bins_eq_1ML :  0.34079145481984724
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  25
# S/$\sqrt{B}$:  0.35355339059327373
# Z_bins_XG :  2.6156397547100863
# Z_bins_XG_15bins :  1.6574914553545492
# Z_bins_XG_15bins_1ML :  1.625974869553275
# Z_bins_XG_15bins_eq :  0.7137095990663996
# Z_bins_XG_15bins_eq_1ML :  0.7058258942196919
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  37
# S/$\sqrt{B}$:  0.5232590180780452
# Z_bins_XG :  3.411734136421051
# Z_bins_XG_15bins :  2.339311852225146
# Z_bins_XG_15bins_1ML :  2.298546954304
# Z_bins_XG_15bins_eq :  1.0505908624676292
# Z_bins_XG_15bins_eq_1ML :  1.0390639215915352
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  50
# S/$\sqrt{B}$:  0.7071067811865475
# Z_bins_XG :  4.155413289944306
# Z_bins_XG_15bins :  3.020493574569155
# Z_bins_XG_15bins_1ML :  2.9719879219959675
# Z_bins_XG_15bins_eq :  1.4115488229517754
# Z_bins_XG_15bins_eq_1ML :  1.3961718806222485
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  125
# S/$\sqrt{B}$:  1.7677669529663687
# Z_bins_XG :  7.389854382376398
# Z_bins_XG_15bins :  6.237033466464155
# Z_bins_XG_15bins_1ML :  6.16443782831926
# Z_bins_XG_15bins_eq :  3.419128009928327
# Z_bins_XG_15bins_eq_1ML :  3.383286891579042
#
#  -----------------------------------------

# %%
print(store_Z_bins_XG)

print(store_Z_bins_XG_15bins)
print(store_Z_bins_XG_15bins_1ML)

print(store_Z_bins_XG_15bins_eq)
print(store_Z_bins_XG_15bins_eq_1ML)
# Out:
# [0.33702424030301237, 0.7596602712997451, 1.1194256037347121, 1.5362235188171118, 2.6156397547100863, 3.411734136421051, 4.155413289944306, 7.389854382376398]
# [0.14832844831099473, 0.3646913803804097, 0.5742705393847328, 0.8441242250453542, 1.6574914553545492, 2.339311852225146, 3.020493574569155, 6.237033466464155]
# [0.1448340881828426, 0.3563755448532078, 0.5615750827263757, 0.8261766434432305, 1.625974869553275, 2.298546954304, 2.9719879219959675, 6.16443782831926]
# [0.05770545851710914, 0.14406165168446175, 0.23017716542483432, 0.3446267513830938, 0.7137095990663996, 1.0505908624676292, 1.4115488229517754, 3.419128009928327]
# [0.057059491174002636, 0.14245184312161097, 0.22760958346893256, 0.34079145481984724, 0.7058258942196919, 1.0390639215915352, 1.3961718806222485, 3.383286891579042]

# %%
store_Z_bins_XG = [0.33702424030301237, 0.7596602712997451, 1.1194256037347121, 1.5362235188171118, 2.6156397547100863, 3.411734136421051, 4.155413289944306, 7.389854382376398]

store_Z_bins_XG_15bins = [0.14832844831099473, 0.3646913803804097, 0.5742705393847328, 0.8441242250453542, 1.6574914553545492, 2.339311852225146, 3.020493574569155, 6.237033466464155]
store_Z_bins_XG_15bins_1ML = [0.1448340881828426, 0.3563755448532078, 0.5615750827263757, 0.8261766434432305, 1.625974869553275, 2.298546954304, 2.9719879219959675, 6.16443782831926]

store_Z_bins_XG_15bins_eq = [0.05770545851710914, 0.14406165168446175, 0.23017716542483432, 0.3446267513830938, 0.7137095990663996, 1.0505908624676292, 1.4115488229517754, 3.419128009928327]
store_Z_bins_XG_15bins_eq_1ML = [0.057059491174002636, 0.14245184312161097, 0.22760958346893256, 0.34079145481984724, 0.7058258942196919, 1.0390639215915352, 1.3961718806222485, 3.383286891579042]

# %%
#########
# PLOTS #
#########

posX = []

for i in range(len(SB_ratio)):
    posX.append( (B_expected*SB_ratio[i]) / ( B_expected )**0.5 )



    
    
plt.figure()
lw = 2

plt.plot(posX, store_Z_bins_XG, '-ok', color='blue', lw=lw, label='o(x) BL (100 l.bins)') 
plt.plot(posX, store_Z_bins_XG_15bins, '-ok', color='red', lw=lw, label='o(x) BL (15 l.bins) (10ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_1ML, '-ok', color='green', lw=lw, label='o(x) BL (15 l.bins) (1ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_eq, '-ok', color='magenta', lw=lw, label='o(x) BL (15 n.l.bins) (10ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_eq_1ML, '-ok', color='darkorange', lw=lw, label='o(x) BL (15 n.l.bins) (1ML)') 

#plt.xlim([0.5, 10])
#plt.ylim([-0.5, 7.5])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=14)
plt.ylabel('$Z_{\mu}$ (exclusion)', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title("SSM Z', <B> per ensemble: %0.2d" % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()
# Out:
# <ipython-input-23-13c05c382495>:17: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG, '-ok', color='blue', lw=lw, label='o(x) BL (100 l.bins)')
# <ipython-input-23-13c05c382495>:18: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins, '-ok', color='red', lw=lw, label='o(x) BL (15 l.bins) (10ML)')
# <ipython-input-23-13c05c382495>:19: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_1ML, '-ok', color='green', lw=lw, label='o(x) BL (15 l.bins) (1ML)')
# <ipython-input-23-13c05c382495>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_eq, '-ok', color='magenta', lw=lw, label='o(x) BL (15 n.l.bins) (10ML)')
# <ipython-input-23-13c05c382495>:21: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_eq_1ML, '-ok', color='darkorange', lw=lw, label='o(x) BL (15 n.l.bins) (1ML)')

# %% [markdown]
# ### 3. MACHINE-LEARNED LIKELIHOOD with KDE

# %% [markdown]
# ##### For 10 ML

# %%
store_Z_MLL_KDE = []
store_Z_MLL_KDE_mu0 = []

store_muhat_mean_MLL = []




# FIND THE BANDWIDTH

bandwidth = np.logspace(-3.0, 0.05, 20)
print(bandwidth)

kde = KernelDensity(kernel='epanechnikov')
grid = GridSearchCV(kde, {'bandwidth': bandwidth})
grid.fit(np.c_[pred_XG_SM[:50000]])
print(grid.best_estimator_)

SM_bandwidth = grid.best_estimator_.bandwidth



kde = KernelDensity(kernel='epanechnikov')
grid = GridSearchCV(kde, {'bandwidth': bandwidth})
grid.fit(np.c_[pred_XG_NP[:50000]])
print(grid.best_estimator_)

NP_bandwidth = grid.best_estimator_.bandwidth







# aca fitteo 
kde_bkg = KernelDensity(kernel="epanechnikov", bandwidth=SM_bandwidth).fit(np.c_[pred_XG_SM, np.zeros(len(pred_XG_SM)) ])
kde_sig = KernelDensity(kernel="epanechnikov", bandwidth=NP_bandwidth).fit(np.c_[pred_XG_NP, np.ones(len(pred_XG_NP)) ])


# elijo los valores para graficar y calcular la significancia de Asimov
min_val = np.min([np.min(pred_XG_SM),np.min(pred_XG_NP)])
max_val = np.max([np.max(pred_XG_SM),np.max(pred_XG_NP)])

s_vals = np.linspace(min_val,max_val,100)





# evaluo las densidades en cada valor de s. esto es mas o menos equivalente a tomar bines continuos
dens_bkg = np.exp(kde_bkg.score_samples(np.c_[s_vals, np.zeros(len(s_vals)) ]) )
dens_sig = np.exp(kde_sig.score_samples(np.c_[s_vals, np.ones(len(s_vals)) ]) )





# PERO NO ESTA NORMALIZADO A 1 el area
# Area
factor_aux_SM = sum(dens_bkg*(s_vals[1]-s_vals[0]))
factor_aux_NP = sum(dens_sig*(s_vals[1]-s_vals[0]))

# normalizo
dens_bkg = dens_bkg / factor_aux_SM
dens_sig = dens_sig / factor_aux_NP






# grafico y verifico si la densidad es una buena aproximacion

plt.figure()

plt.hist(pred_XG_SM,density=True,bins=50,color='red',alpha=0.25,label='Sampled $p_{b}$');
plt.plot(s_vals,dens_bkg,color='red',label='Learned $p_{b}$',linestyle='dashed');

plt.hist(pred_XG_NP,density=True,bins=50,color='blue',alpha=0.25,label='Sampled $p_{s}$');
plt.plot(s_vals,dens_sig,color='blue',label='Learned $p_{s}$',linestyle='dashed');

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("o(x)",fontsize=15)
plt.ylabel("PDF",fontsize=14)
plt.grid()
plt.legend(fontsize=12)
#plt.title(r"Signal: W'$\rightarrow$XY, Background: QCD", fontsize=14)
#plt.savefig('images/' + 'Wprime-output.pdf', format="pdf", bbox_inches="tight")
plt.show()



  
    
    

# all the dataset though the SM and NP KDEs
# with this we'll form the toy samples for MLL

KDE_SM_pred_SM = np.exp(kde_bkg.score_samples(np.c_[pred_XG_SM, np.zeros(len(pred_XG_SM)) ]) )
KDE_NP_pred_SM = np.exp(kde_sig.score_samples(np.c_[pred_XG_SM, np.ones(len(pred_XG_SM)) ]) )

# Normalize

KDE_SM_pred_SM = KDE_SM_pred_SM / factor_aux_SM
KDE_NP_pred_SM = KDE_NP_pred_SM / factor_aux_NP




indices = [i for i in range(len(KDE_NP_pred_SM))]


########################
# METHOD: MLL with KDE #
########################

print('\n-------------------------------------')
print(' MLL with KDE')
print('-------------------------------------')




for iii in range(len(SB_ratio)):
    
    print('B_expected: ', B_expected)
    print('S_expected: ', S_expected[iii])
    print(r'S/$\sqrt{B}$: ', SsqrtB[iii])
    print('n_ensembles (initial): ', n_ensembles, '\n')

    
    

    ###########
    # NOW MLL #
    ###########

    # to construct ensembles B and S events are taken from Poisson distributions
    mu = S_expected[iii] + B_expected


    # Letś find the number of events per ensemble such that we get at least one ensemble populated if events are taken from a Poisson distribution

    # around the mean its populated so let's try (proposed range to be checked)
    list_events_per_ensembles = [i for i in range(int(mu*0.9),int(mu*1.1))]
    to_check = len(list_events_per_ensembles)

    # I want at least one ensemble populated
    list_nums_ensembles = [ int( poisson.pmf(list_events_per_ensembles[i],mu)*n_ensembles ) for i in range(len(list_events_per_ensembles)) ]



    # Remove from the list the elements without at least 1 ensemble possible
    for i in range(len(list_events_per_ensembles)):
        if list_nums_ensembles[i] > 1:
            list_events_per_ensembles = list_events_per_ensembles[i:]
            list_nums_ensembles = list_nums_ensembles[i:]
            break


    for i in range(len(list_events_per_ensembles)):
        if list_nums_ensembles[i] < 1:
            list_events_per_ensembles = list_events_per_ensembles[:i]
            list_nums_ensembles = list_nums_ensembles[:i]
            break

    print('\n If ', to_check, ' = ', len(list_events_per_ensembles), '   then the proposed range has to be extended')

    print('n_ensembles (actual): ', sum(list_nums_ensembles))



    # lists of S and B events per ensemble, w.r.t the total of number of events per ensemble found above:

    p_berno = S_expected[iii]/(S_expected[iii]+B_expected)

    list_S_per_ensembles = []
    list_B_per_ensembles = []

    for jj in range(len(list_events_per_ensembles)):
        list_S_per_ensembles.append( int(p_berno * list_events_per_ensembles[jj]) )
        list_B_per_ensembles.append( list_events_per_ensembles[jj] - int(p_berno * list_events_per_ensembles[jj]) )

    ######
    # NOW I HAVE 4 LISTS:
    # list_events_per_ensembles     list with the number of events per ensemble (its a range)
    # list_nums_ensembles           list with the number of ensembles, w.r.t the 1st list
    # list_S_per_ensembles          list with the number of signal events in each ensembles, w.r.t the 1st list
    # list_B_per_ensembles          list with the number of background events in each ensembles, w.r.t the 1st list
    ######



    print('\n This may take long... \n')


    # NOW LETS APPLY THE METHOD

    muhat_selected_list = []
    q_muhat = []
    q_muhat_mu0 = []

    for bb in range(len(list_nums_ensembles)):

        for kk in range(list_nums_ensembles[bb]):

            # KDE
            ran_ind = np.random.choice(indices, list_B_per_ensembles[bb])

            KDE_SM_pred_SM_shuf = []
            KDE_NP_pred_SM_shuf = []

            for i in ran_ind:
                KDE_SM_pred_SM_shuf.append(KDE_SM_pred_SM[i])
                KDE_NP_pred_SM_shuf.append(KDE_NP_pred_SM[i])

            KDE_SM_pred_SM_shuf  = np.array(KDE_SM_pred_SM_shuf)
            KDE_NP_pred_SM_shuf  = np.array(KDE_NP_pred_SM_shuf)



            # p_b(o(x_ensemble)) =    concatenate: p_b(o(B_ensemble)) and p_b(o(S_ensemble))  NOTICE THE o(x)
            prob_x_given_B = np.ndarray.tolist( KDE_SM_pred_SM_shuf ) #+ np.ndarray.tolist( KDE_SM_pred_NP_shuf )

            # p_s(o(x_ensemble)) =    concatenate: p_s(o(B_ensemble)) and p_s(o(S_ensemble))  NOTICE THE o(x)
            prob_x_given_S = np.ndarray.tolist( KDE_NP_pred_SM_shuf ) #+ np.ndarray.tolist( KDE_NP_pred_NP_shuf )









            # NOW WE HAVE p_{s,b}(x_ensemble) for this particular ensemble
            # WE NEED TO ESTIMATE mu_hat for this particular ensemble
            # we are going to obtain a mu_hat with a grid of values for this particular ensemble



            mu_hat_condition_equal_1 = []

            # grid, mu_hat is around 1
            muhat_test = np.arange(0., 1.5, 0.1).tolist()

            B_prob_x_given_B = [x * B_expected for x in prob_x_given_B]

            for vv in range(len(muhat_test)):

                mu_hat_condition_equal_1.append( sum ( [(x*1.) / ( (x * muhat_test[vv] * S_expected[iii]) + y ) for x, y in zip(prob_x_given_S, B_prob_x_given_B)] ) )



            muhat_selected = 0

            # from the grid, select the mu_hat such that the condition is equal to 1
            if mu_hat_condition_equal_1[0] < mu_hat_condition_equal_1[-1]:
                for ll in range(len(mu_hat_condition_equal_1)):
                    if mu_hat_condition_equal_1[ll] -1 > 0:
                        muhat_selected = muhat_test[ll]
                        break


            if mu_hat_condition_equal_1[0] > mu_hat_condition_equal_1[-1]:
                for ll in range(len(mu_hat_condition_equal_1)):
                    if mu_hat_condition_equal_1[ll] -1 < 0:
                        muhat_selected = muhat_test[ll]
                        break


            muhat_selected_list.append(muhat_selected)



            # NOW THAT WE HAVE mu_hat FOR THIS ENSEMBLE, CALCULATE THE TEST STATISTIC FOR THIS ENSEMBLE
            # and append it (we need the median over lots of ensembles)
            #q_muhat.append( 2 * ( (-1.*muhat_selected * S_expected[iii]) + sum( [np.log( 1 + ( (muhat_selected*S_expected[iii]/B_expected) * (x / y) ) ) for x, y in zip(prob_x_given_S, prob_x_given_B)] ) ) )
            # EXCLUSION:
            q_muhat.append( 2 * ( ( (1.-muhat_selected) * S_expected[iii] ) - sum( [np.log( ( (B_expected*y) + (S_expected[iii]*x) ) / ( (B_expected*y) + (muhat_selected*S_expected[iii]*x) ) ) for x, y in zip(prob_x_given_S, prob_x_given_B)] )
    ) )
            q_muhat_mu0.append( 2 * ( ( (1.-0.) * S_expected[iii] ) - sum( [np.log( ( (B_expected*y) + (S_expected[iii]*x) ) / ( (B_expected*y) + (0.*S_expected[iii]*x) ) ) for x, y in zip(prob_x_given_S, prob_x_given_B)] )
    ) )


    # Histogram of q_muhats

    weights = np.ones_like(q_muhat)/float(len(q_muhat))
    nMIX, binsMIX, patchesMIX = plt.hist(q_muhat, 25, weights=weights, histtype='step', color='blue', linewidth=2)
    #plt.xlim(0,1)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.xlabel("$q_0(\hat{\mu})$",fontsize=16)
    plt.ylabel("Fraction of ensembles",fontsize=16)
    plt.title(r"$\bar{B}$=%0.2i, $\bar{S}=$%0.2i" % (B_expected,S_expected[iii]),fontsize=14)
    plt.grid()
    #plt.legend(fontsize=14)
    plt.show()


    # Finally calculate muhat_mean and Z_gaussian

    # Remove nan if any
    q_muhat_mu0 = [x for x in q_muhat_mu0 if x == x]
    for jk in range(len(q_muhat_mu0)):
        if q_muhat_mu0[jk] < 0:
            q_muhat_mu0[jk] = 0

    q_muhat_median_mu0 = np.median(q_muhat_mu0)

    Z_KDE_mu0 = abs(q_muhat_median_mu0)**0.5
    store_Z_MLL_KDE_mu0.append(Z_KDE_mu0)


    # Finally calculate muhat_mean and Z_gaussian
    muhat_mean = np.mean(muhat_selected_list)
    store_muhat_mean_MLL.append(muhat_mean)

    # Remove nan if any
    q_muhat = [x for x in q_muhat if x == x]
    for jk in range(len(q_muhat)):
        if q_muhat[jk] < 0:
            q_muhat[jk] = 0

    q_muhat_median = np.median(q_muhat)

    Z_KDE = abs(q_muhat_median)**0.5
    store_Z_MLL_KDE.append(Z_KDE)

    print('muhat mean: ', muhat_mean)
    print('median q_muhat: ', q_muhat_median)
    print('Z_KDE: ', Z_KDE)
    print('Z_KDE mu=0: ', Z_KDE_mu0)
    
    print('\n ----------------------------------------- \n')
# Out:
# [1.00000000e-03 1.44719254e-03 2.09436625e-03 3.03095122e-03
#  4.38637001e-03 6.34792196e-03 9.18666532e-03 1.32948735e-02
#  1.92402418e-02 2.78443345e-02 4.02961132e-02 5.83162345e-02
#  8.43948197e-02 1.22135554e-01 1.76753662e-01 2.55796582e-01
#  3.70186906e-01 5.35731729e-01 7.75306963e-01 1.12201845e+00]
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [          -inf           -inf           -inf  9562.77786983
#   9567.77062251  9569.69438723  9570.9121533   9569.1733583
#   9556.98552126  9517.08313612  9404.82373221  9148.40645653
#   8678.46428568  7951.77159148  6923.65914534  5557.57675215
#   3819.43501686  1641.02058513 -1090.33481371 -4369.36125646]
#   warnings.warn(
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:929: RuntimeWarning: invalid value encountered in subtract
#   array_stds = np.sqrt(np.average((array -
# KernelDensity(bandwidth=0.0091866653175426, kernel='epanechnikov')
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [          -inf           -inf  8215.70360826  8013.91543338
#   7711.67878757  7285.8990925   6767.8486063   6200.22365176
#   5607.90200611  4979.76066645  4335.58072944  3636.98494897
#   2879.27553384  2034.54206489  1097.77348329    36.61824567
#  -1171.14302706 -2495.49201385 -3585.61138152 -5434.17126916]
#   warnings.warn(
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:929: RuntimeWarning: invalid value encountered in subtract
#   array_stds = np.sqrt(np.average((array -
# KernelDensity(bandwidth=0.002094366253972675, kernel='epanechnikov')
# -------------------------------------
#  MLL with KDE
# -------------------------------------
# B_expected:  5000
# S_expected:  2
# S/$\sqrt{B}$:  0.0282842712474619
# n_ensembles (initial):  5000
#
#
#  If  1001  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4759
#
#  This may take long...
# muhat mean:  0.16190376129438958
# median q_muhat:  0.7531091201681743
# Z_KDE:  0.8678185986530678
# Z_KDE mu=0:  0.8678185986530678
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  5
# S/$\sqrt{B}$:  0.07071067811865475
# n_ensembles (initial):  5000
#
#
#  If  1001  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4757
#
#  This may take long...
# muhat mean:  0.1626235022072735
# median q_muhat:  2.034483228112789
# Z_KDE:  1.4263531218154881
# Z_KDE mu=0:  1.4263531218154881
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  8
# S/$\sqrt{B}$:  0.1131370849898476
# n_ensembles (initial):  5000
#
#
#  If  1001  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4757
#
#  This may take long...
# muhat mean:  0.11967626655455117
# median q_muhat:  3.5817023756093036
# Z_KDE:  1.8925386061080243
# Z_KDE mu=0:  1.8925386061080243
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  12
# S/$\sqrt{B}$:  0.1697056274847714
# n_ensembles (initial):  5000
#
#
#  If  1003  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4757
#
#  This may take long...
# muhat mean:  0.0885011561908766
# median q_muhat:  5.91146133806086
# Z_KDE:  2.4313496947294233
# Z_KDE mu=0:  2.4313496947294233
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  25
# S/$\sqrt{B}$:  0.35355339059327373
# n_ensembles (initial):  5000
#
#
#  If  1005  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4753
#
#  This may take long...
# muhat mean:  0.05381864085840522
# median q_muhat:  13.564823687080867
# Z_KDE:  3.683045436467064
# Z_KDE mu=0:  3.6858529840781933
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  37
# S/$\sqrt{B}$:  0.5232590180780452
# n_ensembles (initial):  5000
#
#
#  If  1007  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4751
#
#  This may take long...
# muhat mean:  0.04329614817933067
# median q_muhat:  21.194499370732416
# Z_KDE:  4.6037484043692505
# Z_KDE mu=0:  4.614955440475566
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  50
# S/$\sqrt{B}$:  0.7071067811865475
# n_ensembles (initial):  5000
#
#
#  If  1010  =  347    then the proposed range has to be extended
# n_ensembles (actual):  4754
#
#  This may take long...
# muhat mean:  0.040366007572570466
# median q_muhat:  29.588951769800374
# Z_KDE:  5.43957275618227
# Z_KDE mu=0:  5.461979294830967
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  125
# S/$\sqrt{B}$:  1.7677669529663687
# n_ensembles (initial):  5000
#
#
#  If  1025  =  349    then the proposed range has to be extended
# n_ensembles (actual):  4744
#
#  This may take long...
# muhat mean:  0.03631956155143339
# median q_muhat:  82.12362525605566
# Z_KDE:  9.062208630132925
# Z_KDE mu=0:  9.116539261578021
#
#  -----------------------------------------

# %%
print(store_Z_MLL_KDE)
print(store_Z_MLL_KDE_mu0)

print(store_muhat_mean_MLL)
# Out:
# [0.8678185986530678, 1.4263531218154881, 1.8925386061080243, 2.4313496947294233, 3.683045436467064, 4.6037484043692505, 5.43957275618227, 9.062208630132925]
# [0.8678185986530678, 1.4263531218154881, 1.8925386061080243, 2.4313496947294233, 3.6858529840781933, 4.614955440475566, 5.461979294830967, 9.116539261578021]
# [0.16190376129438958, 0.1626235022072735, 0.11967626655455117, 0.0885011561908766, 0.05381864085840522, 0.04329614817933067, 0.040366007572570466, 0.03631956155143339]

# %%
store_Z_MLL_KDE = [0.8678185986530678, 1.4263531218154881, 1.8925386061080243, 2.4313496947294233, 3.683045436467064, 4.6037484043692505, 5.43957275618227, 9.062208630132925]
store_Z_MLL_KDE_mu0 = [0.8678185986530678, 1.4263531218154881, 1.8925386061080243, 2.4313496947294233, 3.6858529840781933, 4.614955440475566, 5.461979294830967, 9.116539261578021]

store_muhat_mean_MLL = [0.16190376129438958, 0.1626235022072735, 0.11967626655455117, 0.0885011561908766, 0.05381864085840522, 0.04329614817933067, 0.040366007572570466, 0.03631956155143339]

# %% [markdown]
# ##### For 1 ML

# %%
store_Z_KDE_bins = []

store_Z_MLL_KDE_1ML = []
store_Z_MLL_KDE_mu0_1ML = []

store_muhat_mean_MLL_1ML = []




# FIND THE BANDWIDTH

# bandwidth = np.logspace(-3.0, 0.05, 20)
# print(bandwidth)

# kde = KernelDensity(kernel='epanechnikov')
# grid = GridSearchCV(kde, {'bandwidth': bandwidth})
# grid.fit(np.c_[pred_XG_SM_1ML[:50000]])
# print(grid.best_estimator_)

# SM_bandwidth_1ML = grid.best_estimator_.bandwidth
SM_bandwidth_1ML = 0.0091866653175426


#kde = KernelDensity(kernel='epanechnikov')
#grid = GridSearchCV(kde, {'bandwidth': bandwidth})
#grid.fit(np.c_[pred_XG_NP_1ML[:50000]])
#print(grid.best_estimator_)

#NP_bandwidth_1ML = grid.best_estimator_.bandwidth
NP_bandwidth_1ML = 0.003094366253972675






# aca fitteo 
kde_bkg_1ML = KernelDensity(kernel="epanechnikov", bandwidth=SM_bandwidth_1ML).fit(np.c_[pred_XG_SM_1ML, np.zeros(len(pred_XG_SM_1ML)) ])
kde_sig_1ML = KernelDensity(kernel="epanechnikov", bandwidth=NP_bandwidth_1ML).fit(np.c_[pred_XG_NP_1ML, np.ones(len(pred_XG_NP_1ML)) ])


# elijo los valores para graficar y calcular la significancia de Asimov
min_val_1ML = np.min([np.min(pred_XG_SM_1ML),np.min(pred_XG_NP_1ML)])
max_val_1ML = np.max([np.max(pred_XG_SM_1ML),np.max(pred_XG_NP_1ML)])

s_vals_1ML = np.linspace(min_val_1ML,max_val_1ML,100)





# evaluo las densidades en cada valor de s. esto es mas o menos equivalente a tomar bines continuos
dens_bkg_1ML = np.exp(kde_bkg_1ML.score_samples(np.c_[s_vals_1ML, np.zeros(len(s_vals_1ML)) ]) )
dens_sig_1ML = np.exp(kde_sig_1ML.score_samples(np.c_[s_vals_1ML, np.ones(len(s_vals_1ML)) ]) )





# PERO NO ESTA NORMALIZADO A 1 el area
# Area
factor_aux_SM_1ML = sum(dens_bkg_1ML*(s_vals_1ML[1]-s_vals_1ML[0]))
factor_aux_NP_1ML = sum(dens_sig_1ML*(s_vals_1ML[1]-s_vals_1ML[0]))

# normalizo
dens_bkg_1ML = dens_bkg_1ML / factor_aux_SM_1ML
dens_sig_1ML = dens_sig_1ML / factor_aux_NP_1ML






# grafico y verifico si la densidad es una buena aproximacion

plt.figure()

plt.hist(pred_XG_SM_1ML,density=True,bins=100,color='red',alpha=0.25,label='Sampled $p_{b}$');
plt.plot(s_vals_1ML,dens_bkg_1ML,color='red',label='Learned $p_{b}$',linestyle='dashed');

plt.hist(pred_XG_NP_1ML,density=True,bins=100,color='blue',alpha=0.25,label='Sampled $p_{s}$');
plt.plot(s_vals_1ML,dens_sig_1ML,color='blue',label='Learned $p_{s}$',linestyle='dashed');

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("o(x)",fontsize=15)
plt.ylabel("PDF",fontsize=14)
plt.grid()
plt.legend(fontsize=12)
#plt.title(r"Signal: W'$\rightarrow$XY, Background: QCD", fontsize=14)
#plt.savefig('images/' + 'Wprime-output.pdf', format="pdf", bbox_inches="tight")
plt.show()



  
    
    

# all the dataset though the SM and NP KDEs
# with this we'll form the toy samples for MLL

KDE_SM_pred_SM_1ML = np.exp(kde_bkg_1ML.score_samples(np.c_[pred_XG_SM_1ML, np.zeros(len(pred_XG_SM_1ML)) ]) )
KDE_NP_pred_SM_1ML = np.exp(kde_sig_1ML.score_samples(np.c_[pred_XG_SM_1ML, np.ones(len(pred_XG_SM_1ML)) ]) )

# Normalize

KDE_SM_pred_SM_1ML = KDE_SM_pred_SM_1ML / factor_aux_SM_1ML
KDE_NP_pred_SM_1ML = KDE_NP_pred_SM_1ML / factor_aux_NP_1ML





indices = [i for i in range(len(KDE_NP_pred_SM_1ML))]


########################
# METHOD: MLL with KDE #
########################

print('\n-------------------------------------')
print(' MLL with KDE')
print('-------------------------------------')




for iii in range(len(SB_ratio)):
    
    print('B_expected: ', B_expected)
    print('S_expected: ', S_expected[iii])
    print(r'S/$\sqrt{B}$: ', SsqrtB[iii])
    print('n_ensembles (initial): ', n_ensembles, '\n')
    
    
    ####################
    # 1st a binned KDE #
    ####################
    
    # Bd: binned KDE background
    Bd = B_expected*dens_bkg_1ML*(s_vals_1ML[1]-s_vals_1ML[0])




    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    Bd_noceros = []
    for i in range(len(Bd)):
        if Bd[i]!=0:
            Bd_noceros.append(Bd[i])

    min_back = min(Bd_noceros)

    # replace the zeros
    for i in range(len(Bd)):
        if Bd[i]==0:
            Bd[i] = min_back


    # Sd: binned KDE signal
    Sd = SsqrtB[iii]*np.sqrt(B_expected)*dens_sig_1ML*(s_vals_1ML[1]-s_vals_1ML[0])

    #Z_KDE_bins = np.sqrt(2.0*np.sum(((Sd+Bd)*np.log(1.0+Sd/Bd)-Sd))) # Discovery
    Z_KDE_bins = np.sqrt(2.0*np.sum(Bd*np.log(Bd/(Sd+Bd))+Sd)) # Exclusion

    store_Z_KDE_bins.append(Z_KDE_bins)

    print('Z_KDE_bins : ', Z_KDE_bins)
    
    

    ###########
    # NOW MLL #
    ###########

    # to construct ensembles B and S events are taken from Poisson distributions
    mu = S_expected[iii] + B_expected


    # Letś find the number of events per ensemble such that we get at least one ensemble populated if events are taken from a Poisson distribution

    # around the mean its populated so let's try (proposed range to be checked)
    list_events_per_ensembles = [i for i in range(int(mu*0.9),int(mu*1.1))]
    to_check = len(list_events_per_ensembles)

    # I want at least one ensemble populated
    list_nums_ensembles = [ int( poisson.pmf(list_events_per_ensembles[i],mu)*n_ensembles ) for i in range(len(list_events_per_ensembles)) ]



    # Remove from the list the elements without at least 1 ensemble possible
    for i in range(len(list_events_per_ensembles)):
        if list_nums_ensembles[i] > 1:
            list_events_per_ensembles = list_events_per_ensembles[i:]
            list_nums_ensembles = list_nums_ensembles[i:]
            break


    for i in range(len(list_events_per_ensembles)):
        if list_nums_ensembles[i] < 1:
            list_events_per_ensembles = list_events_per_ensembles[:i]
            list_nums_ensembles = list_nums_ensembles[:i]
            break

    print('\n If ', to_check, ' = ', len(list_events_per_ensembles), '   then the proposed range has to be extended')

    print('n_ensembles (actual): ', sum(list_nums_ensembles))



    # lists of S and B events per ensemble, w.r.t the total of number of events per ensemble found above:

    p_berno = S_expected[iii]/(S_expected[iii]+B_expected)

    list_S_per_ensembles = []
    list_B_per_ensembles = []

    for jj in range(len(list_events_per_ensembles)):
        list_S_per_ensembles.append( int(p_berno * list_events_per_ensembles[jj]) )
        list_B_per_ensembles.append( list_events_per_ensembles[jj] - int(p_berno * list_events_per_ensembles[jj]) )

    ######
    # NOW I HAVE 4 LISTS:
    # list_events_per_ensembles     list with the number of events per ensemble (its a range)
    # list_nums_ensembles           list with the number of ensembles, w.r.t the 1st list
    # list_S_per_ensembles          list with the number of signal events in each ensembles, w.r.t the 1st list
    # list_B_per_ensembles          list with the number of background events in each ensembles, w.r.t the 1st list
    ######



    print('\n This may take long... \n')


    # NOW LETS APPLY THE METHOD

    muhat_selected_list = []
    q_muhat = []
    q_muhat_mu0 = []

    for bb in range(len(list_nums_ensembles)):

        for kk in range(list_nums_ensembles[bb]):

            # KDE
            ran_ind = np.random.choice(indices, list_B_per_ensembles[bb])

            KDE_SM_pred_SM_shuf = []
            KDE_NP_pred_SM_shuf = []

            for i in ran_ind:
                KDE_SM_pred_SM_shuf.append(KDE_SM_pred_SM_1ML[i])
                KDE_NP_pred_SM_shuf.append(KDE_NP_pred_SM_1ML[i])

            KDE_SM_pred_SM_shuf  = np.array(KDE_SM_pred_SM_shuf)
            KDE_NP_pred_SM_shuf  = np.array(KDE_NP_pred_SM_shuf)



            # p_b(o(x_ensemble)) =    concatenate: p_b(o(B_ensemble)) and p_b(o(S_ensemble))  NOTICE THE o(x)
            prob_x_given_B = np.ndarray.tolist( KDE_SM_pred_SM_shuf ) #+ np.ndarray.tolist( KDE_SM_pred_NP_shuf )

            # p_s(o(x_ensemble)) =    concatenate: p_s(o(B_ensemble)) and p_s(o(S_ensemble))  NOTICE THE o(x)
            prob_x_given_S = np.ndarray.tolist( KDE_NP_pred_SM_shuf ) #+ np.ndarray.tolist( KDE_NP_pred_NP_shuf )









            # NOW WE HAVE p_{s,b}(x_ensemble) for this particular ensemble
            # WE NEED TO ESTIMATE mu_hat for this particular ensemble
            # we are going to obtain a mu_hat with a grid of values for this particular ensemble



            mu_hat_condition_equal_1 = []

            # grid, mu_hat is around 1
            muhat_test = np.arange(0., 1.5, 0.1).tolist()

            B_prob_x_given_B = [x * B_expected for x in prob_x_given_B]

            for vv in range(len(muhat_test)):

                mu_hat_condition_equal_1.append( sum ( [(x*1.) / ( (x * muhat_test[vv] * S_expected[iii]) + y ) for x, y in zip(prob_x_given_S, B_prob_x_given_B)] ) )



            muhat_selected = 0

            # from the grid, select the mu_hat such that the condition is equal to 1
            if mu_hat_condition_equal_1[0] < mu_hat_condition_equal_1[-1]:
                for ll in range(len(mu_hat_condition_equal_1)):
                    if mu_hat_condition_equal_1[ll] -1 > 0:
                        muhat_selected = muhat_test[ll]
                        break


            if mu_hat_condition_equal_1[0] > mu_hat_condition_equal_1[-1]:
                for ll in range(len(mu_hat_condition_equal_1)):
                    if mu_hat_condition_equal_1[ll] -1 < 0:
                        muhat_selected = muhat_test[ll]
                        break


            muhat_selected_list.append(muhat_selected)



            # NOW THAT WE HAVE mu_hat FOR THIS ENSEMBLE, CALCULATE THE TEST STATISTIC FOR THIS ENSEMBLE
            # and append it (we need the median over lots of ensembles)
            #q_muhat.append( 2 * ( (-1.*muhat_selected * S_expected[iii]) + sum( [np.log( 1 + ( (muhat_selected*S_expected[iii]/B_expected) * (x / y) ) ) for x, y in zip(prob_x_given_S, prob_x_given_B)] ) ) )
            # EXCLUSION:
            q_muhat.append( 2 * ( ( (1.-muhat_selected) * S_expected[iii] ) - sum( [np.log( ( (B_expected*y) + (S_expected[iii]*x) ) / ( (B_expected*y) + (muhat_selected*S_expected[iii]*x) ) ) for x, y in zip(prob_x_given_S, prob_x_given_B)] )
    ) )
            q_muhat_mu0.append( 2 * ( ( (1.-0.) * S_expected[iii] ) - sum( [np.log( ( (B_expected*y) + (S_expected[iii]*x) ) / ( (B_expected*y) + (0.*S_expected[iii]*x) ) ) for x, y in zip(prob_x_given_S, prob_x_given_B)] )
    ) )


    # Histogram of q_muhats

    weights = np.ones_like(q_muhat)/float(len(q_muhat))
    nMIX, binsMIX, patchesMIX = plt.hist(q_muhat, 25, weights=weights, histtype='step', color='blue', linewidth=2)
    #plt.xlim(0,1)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.xlabel("$q_0(\hat{\mu})$",fontsize=16)
    plt.ylabel("Fraction of ensembles",fontsize=16)
    plt.title(r"$\bar{B}$=%0.2i, $\bar{S}=$%0.2i" % (B_expected,S_expected[iii]),fontsize=14)
    plt.grid()
    #plt.legend(fontsize=14)
    plt.show()


    # Finally calculate muhat_mean and Z_gaussian

    # Remove nan if any
    q_muhat_mu0 = [x for x in q_muhat_mu0 if x == x]

    q_muhat_median_mu0 = np.median(q_muhat_mu0)

    Z_KDE_mu0 = abs(q_muhat_median_mu0)**0.5
    store_Z_MLL_KDE_mu0_1ML.append(Z_KDE_mu0)


    # Finally calculate muhat_mean and Z_gaussian
    muhat_mean = np.mean(muhat_selected_list)
    store_muhat_mean_MLL_1ML.append(muhat_mean)

    # Remove nan if any
    q_muhat = [x for x in q_muhat if x == x]

    q_muhat_median = np.median(q_muhat)

    Z_KDE = abs(q_muhat_median)**0.5
    store_Z_MLL_KDE_1ML.append(Z_KDE)

    print('muhat mean: ', muhat_mean)
    print('median q_muhat: ', q_muhat_median)
    print('Z_KDE: ', Z_KDE)
    print('Z_KDE mu=0: ', Z_KDE_mu0)
    
    print('\n ----------------------------------------- \n')
# Out:
# -------------------------------------
#  MLL with KDE
# -------------------------------------
# B_expected:  5000
# S_expected:  2
# S/$\sqrt{B}$:  0.0282842712474619
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  0.5673706196013847
#
#  If  1001  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4759
#
#  This may take long...
# muhat mean:  0.13376759823492332
# median q_muhat:  0.7426779582999923
# Z_KDE:  0.8617876526732048
# Z_KDE mu=0:  0.8617876526732048
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  5
# S/$\sqrt{B}$:  0.07071067811865475
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  1.1792689730424808
#
#  If  1001  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4757
#
#  This may take long...
# muhat mean:  0.14660500315324787
# median q_muhat:  1.9989884317097548
# Z_KDE:  1.413855873740232
# Z_KDE mu=0:  1.413855873740232
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  8
# S/$\sqrt{B}$:  0.1131370849898476
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  1.6585315315279145
#
#  If  1001  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4757
#
#  This may take long...
# muhat mean:  0.11206642842127391
# median q_muhat:  3.421402876256245
# Z_KDE:  1.849703456302184
# Z_KDE mu=0:  1.849703456302184
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  12
# S/$\sqrt{B}$:  0.1697056274847714
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  2.1879352001450636
#
#  If  1003  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4757
#
#  This may take long...
# muhat mean:  0.08585242800084088
# median q_muhat:  5.6040527152621955
# Z_KDE:  2.3672880507581233
# Z_KDE mu=0:  2.367398178548241
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  25
# S/$\sqrt{B}$:  0.35355339059327373
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  3.494363041727386
#
#  If  1005  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4753
#
#  This may take long...
# muhat mean:  0.05249316221333895
# median q_muhat:  13.06002893598955
# Z_KDE:  3.6138662033879383
# Z_KDE mu=0:  3.6224468528084808
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  37
# S/$\sqrt{B}$:  0.5232590180780452
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  4.427745320054705
#
#  If  1007  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4751
#
#  This may take long...
# muhat mean:  0.04531677541570196
# median q_muhat:  20.321871411627995
# Z_KDE:  4.507978639216028
# Z_KDE mu=0:  4.523775005805484
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  50
# S/$\sqrt{B}$:  0.7071067811865475
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  5.2869961545393105
#
#  If  1010  =  347    then the proposed range has to be extended
# n_ensembles (actual):  4754
#
#  This may take long...
# muhat mean:  0.04011358855700463
# median q_muhat:  28.62972380971962
# Z_KDE:  5.3506750798118565
# Z_KDE mu=0:  5.370768715095358
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  125
# S/$\sqrt{B}$:  1.7677669529663687
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  8.941404427369264
#
#  If  1025  =  349    then the proposed range has to be extended
# n_ensembles (actual):  4744
#
#  This may take long...
# muhat mean:  0.035392074198988197
# median q_muhat:  79.82288423510902
# Z_KDE:  8.93436535155738
# Z_KDE mu=0:  8.984767085214658
#
#  -----------------------------------------

# %%
print(store_Z_KDE_bins)

print(store_Z_MLL_KDE_1ML)
print(store_Z_MLL_KDE_mu0_1ML)

print(store_muhat_mean_MLL_1ML)
# Out:
# [0.5673706196013847, 1.1792689730424808, 1.6585315315279145, 2.1879352001450636, 3.494363041727386, 4.427745320054705, 5.2869961545393105, 8.941404427369264]
# [0.8617876526732048, 1.413855873740232, 1.849703456302184, 2.3672880507581233, 3.6138662033879383, 4.507978639216028, 5.3506750798118565, 8.93436535155738]
# [0.8617876526732048, 1.413855873740232, 1.849703456302184, 2.367398178548241, 3.6224468528084808, 4.523775005805484, 5.370768715095358, 8.984767085214658]
# [0.13376759823492332, 0.14660500315324787, 0.11206642842127391, 0.08585242800084088, 0.05249316221333895, 0.04531677541570196, 0.04011358855700463, 0.035392074198988197]

# %%
store_Z_KDE_bins = [0.5673706196013847, 1.1792689730424808, 1.6585315315279145, 2.1879352001450636, 3.494363041727386, 4.427745320054705, 5.2869961545393105, 8.941404427369264]

store_Z_MLL_KDE_1ML = [0.8617876526732048, 1.413855873740232, 1.849703456302184, 2.3672880507581233, 3.6138662033879383, 4.507978639216028, 5.3506750798118565, 8.93436535155738]
store_Z_MLL_KDE_mu0_1ML = [0.8617876526732048, 1.413855873740232, 1.849703456302184, 2.367398178548241, 3.6224468528084808, 4.523775005805484, 5.370768715095358, 8.984767085214658]

store_muhat_mean_MLL_1ML = [0.13376759823492332, 0.14660500315324787, 0.11206642842127391, 0.08585242800084088, 0.05249316221333895, 0.04531677541570196, 0.04011358855700463, 0.035392074198988197]

# %%
#########
# PLOTS #
#########

posX = []

for i in range(len(SB_ratio)):
    posX.append( (B_expected*SB_ratio[i]) / ( B_expected )**0.5 )




plt.figure()
lw = 2

plt.plot(posX, store_muhat_mean_MLL, '-ok', color='red', lw=lw, label='mu_hat XGBoost (10ML)')
plt.plot(posX, store_muhat_mean_MLL_1ML, '-ok', color='blue', lw=lw, label='mu_hat XGBoost (1ML)')

#plt.xlim([0.5, 100])
#plt.ylim([-0.5, 7.5])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=14)
plt.ylabel(r'$\hat{\mu}$', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title('<B> per ensemble: %0.2d' % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()






plt.figure()
lw = 2

plt.plot(posX, store_Z_bins, ':ok', color='blue', lw=lw, label='100 Linear Binned Likelihood') 
plt.plot(posX, store_Z_bins_logbins, ':ok', color='lightblue', lw=lw, label='15 Log Binned Likelihood') 
plt.plot(posX, store_Z_bins_XG, '--ok', color='green', lw=lw, label='o(x) BL (100 l.bins)') 
plt.plot(posX, store_Z_bins_XG_15bins, '-ok', color='navy', lw=lw, label='o(x) BL (15 l.bins) (10ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_1ML, '-ok', color='green', lw=lw, label='o(x) BL (15 l.bins) (1ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_eq, '-ok', color='magenta', lw=lw, label='o(x) BL (15 n.l.bins) (10ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_eq_1ML, '-ok', color='darkorange', lw=lw, label='o(x) BL (15 n.l.bins) (1ML)') 
plt.plot(posX, store_Z_MLL_KDE, '-ok', color='red', lw=3, label=r'MLL KDE (10ML)')
plt.plot(posX, store_Z_MLL_KDE_1ML, '--ok', color='lightcoral', lw=3, label=r'MLL KDE (1ML)')
#plt.plot(posX, store_Z_MLL_KDE_mu0, '-ok', color='pink', lw=3, label=r'MLL KDE (XGBoost) muhat=0')
#plt.plot(posX, store_Z_KDE_bins, '-ok', color='magenta', lw=3, label=r'100 Bins KDE')

#plt.xlim([0.5, 10])
#plt.ylim([-0.5, 7.5])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=14)
plt.ylabel('$Z_{\mu}$ (exclusion)', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title('<B> per ensemble: %0.2d' % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()
# Out:
# <ipython-input-34-8bc2cdbd1b25>:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_muhat_mean_MLL, '-ok', color='red', lw=lw, label='mu_hat XGBoost (10ML)')
# <ipython-input-34-8bc2cdbd1b25>:17: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_muhat_mean_MLL_1ML, '-ok', color='blue', lw=lw, label='mu_hat XGBoost (1ML)')
# <ipython-input-34-8bc2cdbd1b25>:39: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string ":ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins, ':ok', color='blue', lw=lw, label='100 Linear Binned Likelihood')
# <ipython-input-34-8bc2cdbd1b25>:40: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string ":ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_logbins, ':ok', color='lightblue', lw=lw, label='15 Log Binned Likelihood')
# <ipython-input-34-8bc2cdbd1b25>:41: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "--ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG, '--ok', color='green', lw=lw, label='o(x) BL (100 l.bins)')
# <ipython-input-34-8bc2cdbd1b25>:42: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins, '-ok', color='navy', lw=lw, label='o(x) BL (15 l.bins) (10ML)')
# <ipython-input-34-8bc2cdbd1b25>:43: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_1ML, '-ok', color='green', lw=lw, label='o(x) BL (15 l.bins) (1ML)')
# <ipython-input-34-8bc2cdbd1b25>:44: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_eq, '-ok', color='magenta', lw=lw, label='o(x) BL (15 n.l.bins) (10ML)')
# <ipython-input-34-8bc2cdbd1b25>:45: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_eq_1ML, '-ok', color='darkorange', lw=lw, label='o(x) BL (15 n.l.bins) (1ML)')
# <ipython-input-34-8bc2cdbd1b25>:46: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_MLL_KDE, '-ok', color='red', lw=3, label=r'MLL KDE (10ML)')
# <ipython-input-34-8bc2cdbd1b25>:47: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "--ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_MLL_KDE_1ML, '--ok', color='lightcoral', lw=3, label=r'MLL KDE (1ML)')

# %% [markdown]
# ### 4.Working points, counting over 1 bin

# %%
WP = [0.25, 0.5, 0.75]

S_expected = [int(SB_ratio[i]*B_expected) for i in range(len(SB_ratio))]

print(S_expected)
# Out:
# [2, 5, 8, 12, 25, 37, 50, 125]

# %%
# XGBoost #

SrootB_WP0_XG = []
SrootB_WP1_XG = []
SrootB_WP2_XG = []


# number of background ensembles
B_ensembles = int(len(pred_XG_SM)/B_expected)

# shorten the number of B events so I get an integer number of ensembles
pred_XG_SM_entero = pred_XG_SM[:int(len(pred_XG_SM)/B_expected) * B_expected]

XG_SM_passWP0 = 0
XG_SM_passWP1 = 0
XG_SM_passWP2 = 0

for i in range(len(pred_XG_SM_entero)):
    if pred_XG_SM_entero[i] > WP[0]:
        XG_SM_passWP0 += 1
    if pred_XG_SM_entero[i] > WP[1]:
        XG_SM_passWP1 += 1
    if pred_XG_SM_entero[i] > WP[2]:
        XG_SM_passWP2 += 1



# SIGNAL

for j in range(len(S_expected)):
    
    # number of signal ensembles
    S_ensembles = int(len(pred_XG_NP)/S_expected[j])

    # shorten the number of S events so I get an integer number of ensembles
    pred_XG_NP_entero = pred_XG_NP[:int(len(pred_XG_NP)/S_expected[j]) * S_expected[j]]

    XG_NP_passWP0 = 0
    XG_NP_passWP1 = 0
    XG_NP_passWP2 = 0

    for i in range(len(pred_XG_NP_entero)):
        if pred_XG_NP_entero[i] > WP[0]:
            XG_NP_passWP0 += 1
        if pred_XG_NP_entero[i] > WP[1]:
            XG_NP_passWP1 += 1
        if pred_XG_NP_entero[i] > WP[2]:
            XG_NP_passWP2 += 1

            
    # save the results Z_binned after WP
    SrootB_WP0_XG.append( ( XG_NP_passWP0 / S_ensembles ) / ( XG_SM_passWP0 / B_ensembles )**0.5 )
    SrootB_WP1_XG.append( ( XG_NP_passWP1 / S_ensembles ) / ( XG_SM_passWP1 / B_ensembles )**0.5 )
    SrootB_WP2_XG.append( ( XG_NP_passWP2 / S_ensembles ) / ( XG_SM_passWP2 / B_ensembles )**0.5 )
    
    print('S_expected = ', S_expected[j])
    print('WP: 0     S/B**0.5= ', S_expected[j]/(B_expected)**0.5)
    print('WP: ', WP[0], '    S/B**0.5= ', SrootB_WP0_XG[j] )
    print('WP: ', WP[1], '    S/B**0.5= ', SrootB_WP1_XG[j] )
    print('WP: ', WP[2], '    S/B**0.5= ', SrootB_WP2_XG[j] )
    print('------------------------')
    print('')
    
print('SrootB_WP0_XG: ', SrootB_WP0_XG)
print('SrootB_WP1_XG: ', SrootB_WP1_XG)
print('SrootB_WP2_XG: ', SrootB_WP2_XG)
# Out:
# S_expected =  2
# WP: 0     S/B**0.5=  0.0282842712474619
# WP:  0.25     S/B**0.5=  0.029944198694093194
# WP:  0.5     S/B**0.5=  0.04597885545471952
# WP:  0.75     S/B**0.5=  0.07084685991627326
# ------------------------
#
# S_expected =  5
# WP: 0     S/B**0.5=  0.07071067811865475
# WP:  0.25     S/B**0.5=  0.0748604784457164
# WP:  0.5     S/B**0.5=  0.11494759784674882
# WP:  0.75     S/B**0.5=  0.17711785736773522
# ------------------------
#
# S_expected =  8
# WP: 0     S/B**0.5=  0.1131370849898476
# WP:  0.25     S/B**0.5=  0.11977667772206373
# WP:  0.5     S/B**0.5=  0.183914736385976
# WP:  0.75     S/B**0.5=  0.28338931500292275
# ------------------------
#
# S_expected =  12
# WP: 0     S/B**0.5=  0.1697056274847714
# WP:  0.25     S/B**0.5=  0.17966484099602034
# WP:  0.5     S/B**0.5=  0.2758710763967505
# WP:  0.75     S/B**0.5=  0.4250867856010341
# ------------------------
#
# S_expected =  25
# WP: 0     S/B**0.5=  0.35355339059327373
# WP:  0.25     S/B**0.5=  0.3743010204271534
# WP:  0.5     S/B**0.5=  0.5747271248619508
# WP:  0.75     S/B**0.5=  0.8856009001227061
# ------------------------
#
# S_expected =  37
# WP: 0     S/B**0.5=  0.5232590180780452
# WP:  0.25     S/B**0.5=  0.5539661870145958
# WP:  0.5     S/B**0.5=  0.8505959169754375
# WP:  0.75     S/B**0.5=  1.3106876932117504
# ------------------------
#
# S_expected =  50
# WP: 0     S/B**0.5=  0.7071067811865475
# WP:  0.25     S/B**0.5=  0.7486020408543068
# WP:  0.5     S/B**0.5=  1.1494542497239015
# WP:  0.75     S/B**0.5=  1.7712018002454122
# ------------------------
#
# S_expected =  125
# WP: 0     S/B**0.5=  1.7677669529663687
# WP:  0.25     S/B**0.5=  1.8715060406234312
# WP:  0.5     S/B**0.5=  2.8736622044530518
# WP:  0.75     S/B**0.5=  4.427935483374381
# ------------------------
#
# SrootB_WP0_XG:  [0.029944198694093194, 0.0748604784457164, 0.11977667772206373, 0.17966484099602034, 0.3743010204271534, 0.5539661870145958, 0.7486020408543068, 1.8715060406234312]
# SrootB_WP1_XG:  [0.04597885545471952, 0.11494759784674882, 0.183914736385976, 0.2758710763967505, 0.5747271248619508, 0.8505959169754375, 1.1494542497239015, 2.8736622044530518]
# SrootB_WP2_XG:  [0.07084685991627326, 0.17711785736773522, 0.28338931500292275, 0.4250867856010341, 0.8856009001227061, 1.3106876932117504, 1.7712018002454122, 4.427935483374381]

# %%
# To use if you dont want to run everything again. Its the previous results
SrootB_WP0_XG = [0.029944198694093194, 0.0748604784457164, 0.11977667772206373, 0.17966484099602034, 0.3743010204271534, 0.5539661870145958, 0.7486020408543068, 1.8715060406234312]
SrootB_WP1_XG = [0.04597885545471952, 0.11494759784674882, 0.183914736385976, 0.2758710763967505, 0.5747271248619508, 0.8505959169754375, 1.1494542497239015, 2.8736622044530518]
SrootB_WP2_XG = [0.07084685991627326, 0.17711785736773522, 0.28338931500292275, 0.4250867856010341, 0.8856009001227061, 1.3106876932117504, 1.7712018002454122, 4.427935483374381]

# %%
#########
# PLOTS #
#########

posX = []

for i in range(len(SB_ratio)):
    posX.append( (B_expected*SB_ratio[i]) / ( B_expected )**0.5 )



plt.figure()
lw = 2

plt.plot(posX, store_Z_bins, ':ok', color='blue', lw=lw, label='100 Linear Binned Likelihood') 
plt.plot(posX, store_Z_bins_logbins, ':ok', color='lightblue', lw=lw, label='15 Log Binned Likelihood') 
plt.plot(posX, store_Z_bins_XG, '--ok', color='green', lw=lw, label='o(x) BL (100 l.bins)') 
plt.plot(posX, store_Z_bins_XG_15bins, '-ok', color='navy', lw=lw, label='o(x) BL (15 l.bins) (10ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_1ML, '-ok', color='green', lw=lw, label='o(x) BL (15 l.bins) (1ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_eq, '-ok', color='magenta', lw=lw, label='o(x) BL (15 n.l.bins) (10ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_eq_1ML, '-ok', color='darkorange', lw=lw, label='o(x) BL (15 n.l.bins) (1ML)') 
plt.plot(posX, store_Z_MLL_KDE, '-ok', color='red', lw=3, label=r'MLL KDE (10ML)')
plt.plot(posX, store_Z_MLL_KDE_1ML, '--ok', color='lightcoral', lw=3, label=r'MLL KDE (1ML)')
#plt.plot(posX, store_Z_MLL_KDE_mu0, '-ok', color='pink', lw=3, label=r'MLL KDE (XGBoost) muhat=0')
#plt.plot(posX, store_Z_KDE_bins, '-ok', color='magenta', lw=3, label=r'100 Bins KDE')
plt.plot(posX, SrootB_WP2_XG, '--', color='darkorange', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[2] )
plt.plot(posX, SrootB_WP1_XG, '--', color='magenta', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[1] )
plt.plot(posX, SrootB_WP0_XG, '--', color='navy', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[0] )
plt.plot(posX, posX, ':', color='black', lw=lw, label=r'$S/\sqrt{B}$')

#plt.xlim([0.5, 10])
#plt.ylim([-0.5, 7.5])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=14)
plt.ylabel('$Z_{\mu}$ (exclusion)', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title('<B> per ensemble: %0.2d' % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()
# Out:
# <ipython-input-37-1231ce6ddeb8>:15: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string ":ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins, ':ok', color='blue', lw=lw, label='100 Linear Binned Likelihood')
# <ipython-input-37-1231ce6ddeb8>:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string ":ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_logbins, ':ok', color='lightblue', lw=lw, label='15 Log Binned Likelihood')
# <ipython-input-37-1231ce6ddeb8>:17: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "--ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG, '--ok', color='green', lw=lw, label='o(x) BL (100 l.bins)')
# <ipython-input-37-1231ce6ddeb8>:18: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins, '-ok', color='navy', lw=lw, label='o(x) BL (15 l.bins) (10ML)')
# <ipython-input-37-1231ce6ddeb8>:19: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_1ML, '-ok', color='green', lw=lw, label='o(x) BL (15 l.bins) (1ML)')
# <ipython-input-37-1231ce6ddeb8>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_eq, '-ok', color='magenta', lw=lw, label='o(x) BL (15 n.l.bins) (10ML)')
# <ipython-input-37-1231ce6ddeb8>:21: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_eq_1ML, '-ok', color='darkorange', lw=lw, label='o(x) BL (15 n.l.bins) (1ML)')
# <ipython-input-37-1231ce6ddeb8>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_MLL_KDE, '-ok', color='red', lw=3, label=r'MLL KDE (10ML)')
# <ipython-input-37-1231ce6ddeb8>:23: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "--ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_MLL_KDE_1ML, '--ok', color='lightcoral', lw=3, label=r'MLL KDE (1ML)')

# %%
posX = []

for i in range(len(SB_ratio)):
    posX.append( (B_expected*SB_ratio[i]) / ( B_expected )**0.5 )


plt.figure()
lw = 2

plt.plot(posX, store_Z_bins_logbins, '-', color='dodgerblue', lw=3, label='x BL (15 log l.bins)') 
plt.plot(posX, store_Z_bins_XG_15bins, '-', color='green', lw=3, label='o(x) BL (15 l.bins) (10ML)') 
plt.plot(posX, store_Z_MLL_KDE, '-', color='red', lw=3, label=r'MLL KDE (10ML)')
plt.plot(posX, store_Z_MLL_KDE_1ML, '--ok', color='lightcoral', lw=3, label=r'MLL KDE (1ML)')
plt.plot(posX, SrootB_WP2_XG, '--', color='darkorange', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[2] )
plt.plot(posX, SrootB_WP1_XG, '--', color='magenta', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[1] )
plt.plot(posX, SrootB_WP0_XG, '--', color='navy', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[0] )
plt.plot(posX, posX, ':', color='black', lw=lw, label=r'$S/\sqrt{B}$')

#plt.xlim([0.5, 10])
#plt.ylim([-0.5, 7.5])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=15)
plt.ylabel('$Z_{\mu}$', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title('<B> per ensemble: %0.2d' % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()
# Out:
# <ipython-input-38-415cc2f1cb5e>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "--ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_MLL_KDE_1ML, '--ok', color='lightcoral', lw=3, label=r'MLL KDE (1ML)')

# %% [markdown]
# ### Interpolate

# %%
    
# Interpolation, cubic
fcubic_bins_logbins = interp1d(posX, store_Z_bins_logbins, kind='cubic')
fcubic_bins_XG_15bins = interp1d(posX, store_Z_bins_XG_15bins, kind='cubic')
fcubic_bins_XG_15bins_1ML = interp1d(posX, store_Z_bins_XG_15bins_1ML, kind='cubic')
fcubic_XG_MLL = interp1d(posX, store_Z_MLL_KDE, kind='cubic')
fcubic_XG_MLL_1ML = interp1d(posX, store_Z_MLL_KDE_1ML, kind='cubic')
fcubic_WP0_XG = interp1d(posX, SrootB_WP0_XG, kind='cubic')
fcubic_WP1_XG = interp1d(posX, SrootB_WP1_XG, kind='cubic')
fcubic_WP2_XG = interp1d(posX, SrootB_WP2_XG, kind='cubic')


# x to plot
plotX = np.linspace(min(posX), max(posX), num=50, endpoint=True)



plt.figure()
lw = 2

plt.plot(plotX, fcubic_bins_logbins(plotX), '-', color='dodgerblue', lw=3, label='x BL (15 log l.bins)') 
plt.plot(plotX, fcubic_bins_XG_15bins(plotX), '-', color='green', lw=3, label='o(x) BL (15 l.bins) (10ML)') 
plt.plot(plotX, fcubic_bins_XG_15bins_1ML(plotX), '--', color='green', lw=3, label='o(x) BL (15 l.bins) (1ML)') 
plt.plot(plotX, fcubic_XG_MLL(plotX), '-', color='red', lw=3, label=r'MLL KDE (10ML)')
plt.plot(plotX, fcubic_XG_MLL_1ML(plotX), '-', color='lightcoral', lw=3, label=r'MLL KDE (1ML)')
plt.plot(plotX, fcubic_WP0_XG(plotX), '--', color='darkorange', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[2] )
plt.plot(plotX, fcubic_WP1_XG(plotX), '--', color='magenta', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[1] )
plt.plot(plotX, fcubic_WP2_XG(plotX), '--', color='navy', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[0] )
plt.plot(posX, posX, ':', color='black', lw=lw, label=r'$S/\sqrt{B}$')

#plt.ylim([0., 6])
#plt.xlim([0.06, 10])
#plt.ylim([0., 3])
#plt.xlim([0.1, 0.2])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=15)
plt.ylabel('$Z_{\mu}$', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title('<B> per ensemble: %0.2d' % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()

# %%
# AUX FUNCTION TO FIND SOLUTIONS

def dx(fn, x, delta=0.001):
    return (fn(x+delta) - fn(x))/delta

def solve(fn, value, x=0.1, maxtries=1000, maxerr=0.00001):
    for tries in range(maxtries):
        err = fn(x) - value
        if abs(err) < maxerr:
            return x
        slope = dx(fn, x)
        x -= err/slope
    raise ValueError('no solution found')

# %%
##############################
# DO NOT FORGET THE K-factor #
##############################

k_factor = 3
SM_cross_section_fb = 0.3106
acceptance_SM = 0.4*2
true_B_expected = 3000 * SM_cross_section_fb * k_factor * acceptance_SM

correct_factor = true_B_expected / B_expected

print('correct_factor: ', correct_factor)
print('')


# Find S/\sqrt{B} such that 95%C.L. upper limit, i.e  ----> Z = 1.64

bins_logbins_95CL = solve(fcubic_bins_logbins, 1.64)
bins_XG_15bins_95CL = solve(fcubic_bins_XG_15bins, 1.64)
XG_MLL_95CL = solve(fcubic_XG_MLL, 1.64)
bins_XG_15bins_1ML_95CL = solve(fcubic_bins_XG_15bins_1ML, 1.64)
XG_MLL_1ML_95CL = solve(fcubic_XG_MLL_1ML, 1.64)


# corresponding to a number of signal events:
acceptance_Signal = 0.636719
S1 = ( (correct_factor * B_expected)**0.5 * bins_logbins_95CL ) / acceptance_Signal
S2 = ( (correct_factor * B_expected)**0.5 * bins_XG_15bins_95CL ) / acceptance_Signal
S3 = ( (correct_factor * B_expected)**0.5 * XG_MLL_95CL ) / acceptance_Signal
S4 = ( (correct_factor * B_expected)**0.5 * bins_XG_15bins_1ML_95CL ) / acceptance_Signal
S5 = ( (correct_factor * B_expected)**0.5 * XG_MLL_1ML_95CL ) / acceptance_Signal

# corresponding to a cross-section (pb)
cross_bins_logbins_95CL = S1 / 3000000
cross_bins_XG_15bins_95CL = S2 / 3000000
cross_XG_MLL_95CL = S3 / 3000000
cross_bins_XG_15bins_1ML_95CL = S4 / 3000000
cross_XG_MLL_1ML_95CL = S5 / 3000000



print('95%C.L. upper limit, i.e  ----> Z = 1.64: \n')
print('     S/\sqrt{B}              S          cross-section (pb)')
print(bins_logbins_95CL , S1 , cross_bins_logbins_95CL)
print(bins_XG_15bins_95CL , S2 , cross_bins_XG_15bins_95CL)
print(XG_MLL_95CL, S3 , cross_XG_MLL_95CL)
print(bins_XG_15bins_1ML_95CL , S4 , cross_bins_XG_15bins_1ML_95CL)
print(XG_MLL_1ML_95CL, S5 , cross_XG_MLL_1ML_95CL)



np.savetxt('saved-models/results7500GeV-mumu.txt', [cross_bins_logbins_95CL,cross_bins_XG_15bins_95CL,cross_XG_MLL_95CL,cross_bins_XG_15bins_1ML_95CL,cross_XG_MLL_1ML_95CL])
# Out:
# correct_factor:  0.44726399999999994
#
# 95%C.L. upper limit, i.e  ----> Z = 1.64:
#
#      S/\sqrt{B}              S          cross-section (pb)
# 0.1371812346050432 10.188584963109484 3.3961949877031613e-06
# 0.34952494777849763 25.959560995500105 8.653186998500035e-06
# 0.08714487699240868 6.472335563192544 2.157445187730848e-06
# 0.3568574788522022 26.504155276592346 8.834718425530782e-06
# 0.08942885734912064 6.64196902643867 2.213989675479557e-06
