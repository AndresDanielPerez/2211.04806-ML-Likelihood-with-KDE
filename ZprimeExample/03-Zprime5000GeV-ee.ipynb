# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import gridspec
from matplotlib import patches
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

import os
import math
import random

import keras
from keras.models import Sequential
from keras.layers import Input, Dense, Conv2D, Flatten, MaxPooling2D
from keras.layers import Dropout
from keras.callbacks import EarlyStopping

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn import preprocessing
from sklearn.metrics import roc_curve, roc_auc_score, auc

import scipy.stats as st
from scipy.stats import poisson
from scipy.interpolate import interp1d
from scipy.stats import norm

# %%
from sklearn.neighbors import KernelDensity # paquete necesario
from sklearn.model_selection import GridSearchCV

import scipy.integrate as integrate

# %%
# !pip install xgboost

import xgboost
from xgboost import XGBRegressor, XGBClassifier
# Out:
# Requirement already satisfied: xgboost in /home/andres/anaconda3/lib/python3.8/site-packages (1.5.1)
# Requirement already satisfied: scipy in /home/andres/.local/lib/python3.8/site-packages (from xgboost) (1.9.3)
# Requirement already satisfied: numpy in /home/andres/.local/lib/python3.8/site-packages (from xgboost) (1.22.4)
# WARNING: You are using pip version 21.3.1; however, version 23.3.1 is available.
# You should consider upgrading via the '/home/andres/anaconda3/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# ## DATA

# %%
# data

folder_data = "../../MLL-exclusion/data/"

# %%
folder_saved = "Zprime-SSM-ee-mZ5000GeV-variables/"

# 1st DATASET
e1pt_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'e1-pt-5000-1.txt', delimiter=',')
e1eta_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'e1-eta-5000-1.txt', delimiter=',')
e1phi_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'e1-phi-5000-1.txt', delimiter=',')

e2pt_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'e2-pt-5000-1.txt', delimiter=',')
e2eta_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'e2-eta-5000-1.txt', delimiter=',')
e2phi_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'e2-phi-5000-1.txt', delimiter=',')




# INVARIANT MASS

invariant_mass_eeSM = []

for i in range(len(e1pt_eeSSMZprime)):
    invariant_mass_eeSM.append( ( 2 * e1pt_eeSSMZprime[i] * e2pt_eeSSMZprime[i] * ( np.cosh(e1eta_eeSSMZprime[i] - e2eta_eeSSMZprime[i]) - np.cos(e1phi_eeSSMZprime[i] - e2phi_eeSSMZprime[i]) ) )**0.5 )
    
print(len(invariant_mass_eeSM))

f= open(folder_data + folder_saved + "mee-1.txt","w")
for i in range(len(invariant_mass_eeSM)):
    f.write("%.3f\n" % invariant_mass_eeSM[i] )
f.close()




# 2nd DATASET
e1pt_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'e1-pt-5000-2.txt', delimiter=',')
e1eta_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'e1-eta-5000-2.txt', delimiter=',')
e1phi_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'e1-phi-5000-2.txt', delimiter=',')

e2pt_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'e2-pt-5000-2.txt', delimiter=',')
e2eta_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'e2-eta-5000-2.txt', delimiter=',')
e2phi_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'e2-phi-5000-2.txt', delimiter=',')




# INVARIANT MASS

invariant_mass_eeSM = []

for i in range(len(e1pt_eeSSMZprime)):
    invariant_mass_eeSM.append( ( 2 * e1pt_eeSSMZprime[i] * e2pt_eeSSMZprime[i] * ( np.cosh(e1eta_eeSSMZprime[i] - e2eta_eeSSMZprime[i]) - np.cos(e1phi_eeSSMZprime[i] - e2phi_eeSSMZprime[i]) ) )**0.5 )
    
print(len(invariant_mass_eeSM))

f= open(folder_data + folder_saved + "mee-2.txt","w")
for i in range(len(invariant_mass_eeSM)):
    f.write("%.3f\n" % invariant_mass_eeSM[i] )
f.close()





# 3rd DATASET
e1pt_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'e1-pt-5000-3.txt', delimiter=',')
e1eta_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'e1-eta-5000-3.txt', delimiter=',')
e1phi_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'e1-phi-5000-3.txt', delimiter=',')

e2pt_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'e2-pt-5000-3.txt', delimiter=',')
e2eta_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'e2-eta-5000-3.txt', delimiter=',')
e2phi_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'e2-phi-5000-3.txt', delimiter=',')




# INVARIANT MASS

invariant_mass_eeSM = []

for i in range(len(e1pt_eeSSMZprime)):
    invariant_mass_eeSM.append( ( 2 * e1pt_eeSSMZprime[i] * e2pt_eeSSMZprime[i] * ( np.cosh(e1eta_eeSSMZprime[i] - e2eta_eeSSMZprime[i]) - np.cos(e1phi_eeSSMZprime[i] - e2phi_eeSSMZprime[i]) ) )**0.5 )
    
print(len(invariant_mass_eeSM))

f= open(folder_data + folder_saved + "mee-3.txt","w")
for i in range(len(invariant_mass_eeSM)):
    f.write("%.3f\n" % invariant_mass_eeSM[i] )
f.close()
# Out:
# 410244
# 199770
# 439758

# %%
# just to check that we need to ask again that the invariant mass has to be greater than 2000 GeV

bins_atlas = [70, 80.0, 90.0, 105.0, 120.0, 140.0, 160.0, 180.0, 210.0, 240.0, 275.0, 315.0, 360.0, 415.0, 475.0, 545.0, 625.0, 715.0, 825.0, 950.0, 1100.0, 1250.0, 1450.0, 1650.0, 1900.0, 2200.0, 2500.0, 2850.0, 3250.0, 3750.0, 4350.0, 5000.0, 5750.0, 6600.0, 7500.0, 8750.0, 10000.0, 11500.0, 13000.0, 20000]

folder_saved = "SM/ee/"

invariant_mass_eeSM = np.loadtxt(folder_data + folder_saved +"mee.txt", delimiter=',')
invariant_mass_eeSM_1800 = np.loadtxt(folder_data + folder_saved +"mee-1800.txt", delimiter=',')
invariant_mass_eeSM_1800_2 = np.loadtxt(folder_data + folder_saved +"mee-1800-2.txt", delimiter=',')

plt.hist(invariant_mass_eeSM, bins=bins_atlas, lw=2, edgecolor='blue', histtype='step', label="SM (dataset 1)")
plt.hist(invariant_mass_eeSM_1800, bins=bins_atlas, lw=2, edgecolor='lightblue', histtype='step', label="SM (dataset 2)")
plt.hist(invariant_mass_eeSM_1800_2, bins=bins_atlas, lw=2, edgecolor='green', histtype='step', label="SM (dataset 3)")


folder_saved = "Zprime-SSM-ee-mZ5000GeV-variables/"

invariant_mass_eeSSMZprime_1 = np.loadtxt(folder_data + folder_saved +"mee-1.txt", delimiter=',')
invariant_mass_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved +"mee-2.txt", delimiter=',')
invariant_mass_eeSSMZprime_3 = np.loadtxt(folder_data + folder_saved +"mee-3.txt", delimiter=',')

plt.hist(invariant_mass_eeSSMZprime_1, bins=bins_atlas, lw=2, edgecolor='pink', histtype='step', label="$Z'_{SSM}$ (dataset 1)")
plt.hist(invariant_mass_eeSSMZprime_2, bins=bins_atlas, lw=2, edgecolor='darkorange', histtype='step', label="$Z'_{SSM}$ (dataset 2)")
plt.hist(invariant_mass_eeSSMZprime_3, bins=bins_atlas, lw=2, edgecolor='magenta', histtype='step', label="$Z'_{SSM}$ (dataset 3)")


plt.grid()  # Add grid lines

plt.title(r"Z/Z'$\rightarrow$e+e-",fontsize=14)  # Titles etc
plt.xlabel("$m_{ll}$ (GeV)",fontsize=14)
plt.ylabel("Events",fontsize=14)

plt.xlim(70.,20000)
plt.ylim(1e0,1e7)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xscale('log')
plt.yscale('log')
plt.legend(loc='upper left',fontsize=12)

plt.show()

# %% [markdown]
# ### SM

# %%
######
# SM #
######


folder_saved = "SM/ee/"


# 1st DATASET
invariant_mass_eeSM = np.loadtxt(folder_data + folder_saved +"mee.txt", delimiter=',')

e1pt_eeSM = np.loadtxt(folder_data + folder_saved + 'e1-pt.txt', delimiter=',')
e1eta_eeSM = np.loadtxt(folder_data + folder_saved + 'e1-eta.txt', delimiter=',')
e1phi_eeSM = np.loadtxt(folder_data + folder_saved + 'e1-phi.txt', delimiter=',')

e2pt_eeSM = np.loadtxt(folder_data + folder_saved + 'e2-pt.txt', delimiter=',')
e2eta_eeSM = np.loadtxt(folder_data + folder_saved + 'e2-eta.txt', delimiter=',')
e2phi_eeSM = np.loadtxt(folder_data + folder_saved + 'e2-phi.txt', delimiter=',')


# only keep points where the invariant mass is greater than 2000 GeV
# and make sure that both electrons: |eta| < 2.47, excluding 1.37 < |eta| < 1.52
for i in reversed(range(len(invariant_mass_eeSM))):
    if invariant_mass_eeSM[i]< 2000 or e1eta_eeSM[i] < -2.47 or -1.52 < e1eta_eeSM[i] < -1.37 or 1.37 < e1eta_eeSM[i] < 1.52 or e1eta_eeSM[i] > 2.47 or e2eta_eeSM[i] < -2.47 or -1.52 < e2eta_eeSM[i] < -1.37 or 1.37 < e2eta_eeSM[i] < 1.52 or e2eta_eeSM[i] > 2.47:
        e1pt_eeSM = np.delete(e1pt_eeSM, i)
        e1eta_eeSM = np.delete(e1eta_eeSM, i)
        e1phi_eeSM = np.delete(e1phi_eeSM, i)
        
        e2pt_eeSM = np.delete(e2pt_eeSM, i)
        e2eta_eeSM = np.delete(e2eta_eeSM, i)
        e2phi_eeSM = np.delete(e2phi_eeSM, i)
        
        invariant_mass_eeSM = np.delete(invariant_mass_eeSM, i)
        

        
        
# 2nd DATASET
invariant_mass_eeSM_1800 = np.loadtxt(folder_data + folder_saved +"mee-1800.txt", delimiter=',')

e1pt_eeSM_1800 = np.loadtxt(folder_data + folder_saved + 'e1-pt-1800.txt', delimiter=',')
e1eta_eeSM_1800 = np.loadtxt(folder_data + folder_saved + 'e1-eta-1800.txt', delimiter=',')
e1phi_eeSM_1800 = np.loadtxt(folder_data + folder_saved + 'e1-phi-1800.txt', delimiter=',')

e2pt_eeSM_1800 = np.loadtxt(folder_data + folder_saved + 'e2-pt-1800.txt', delimiter=',')
e2eta_eeSM_1800 = np.loadtxt(folder_data + folder_saved + 'e2-eta-1800.txt', delimiter=',')
e2phi_eeSM_1800 = np.loadtxt(folder_data + folder_saved + 'e2-phi-1800.txt', delimiter=',')


# only keep points where the invariant mass is greater than 2000 GeV
# and make sure that both electrons: |eta| < 2.47, excluding 1.37 < |eta| < 1.52
for i in reversed(range(len(invariant_mass_eeSM_1800))):
    if invariant_mass_eeSM_1800[i]< 2000 or e1eta_eeSM_1800[i] < -2.47 or -1.52 < e1eta_eeSM_1800[i] < -1.37 or 1.37 < e1eta_eeSM_1800[i] < 1.52 or e1eta_eeSM_1800[i] > 2.47 or e2eta_eeSM_1800[i] < -2.47 or -1.52 < e2eta_eeSM_1800[i] < -1.37 or 1.37 < e2eta_eeSM_1800[i] < 1.52 or e2eta_eeSM_1800[i] > 2.47:
        e1pt_eeSM_1800 = np.delete(e1pt_eeSM_1800, i)
        e1eta_eeSM_1800 = np.delete(e1eta_eeSM_1800, i)
        e1phi_eeSM_1800 = np.delete(e1phi_eeSM_1800, i)
        
        e2pt_eeSM_1800 = np.delete(e2pt_eeSM_1800, i)
        e2eta_eeSM_1800 = np.delete(e2eta_eeSM_1800, i)
        e2phi_eeSM_1800 = np.delete(e2phi_eeSM_1800, i)
        
        invariant_mass_eeSM_1800 = np.delete(invariant_mass_eeSM_1800, i)
        


# concatenate results
e1pt_eeSM = np.concatenate([e1pt_eeSM,e1pt_eeSM_1800])
e1eta_eeSM = np.concatenate([e1eta_eeSM,e1eta_eeSM_1800])
e1phi_eeSM = np.concatenate([e1phi_eeSM,e1phi_eeSM_1800])

e2pt_eeSM = np.concatenate([e2pt_eeSM,e2pt_eeSM_1800])
e2eta_eeSM = np.concatenate([e2eta_eeSM,e2eta_eeSM_1800])
e2phi_eeSM = np.concatenate([e2phi_eeSM,e2phi_eeSM_1800])

invariant_mass_eeSM = np.concatenate([invariant_mass_eeSM,invariant_mass_eeSM_1800])



# remove the aux
del e1pt_eeSM_1800
del e1eta_eeSM_1800
del e1phi_eeSM_1800

del e2pt_eeSM_1800
del e2eta_eeSM_1800
del e2phi_eeSM_1800

del invariant_mass_eeSM_1800








# 3rd DATASET
invariant_mass_eeSM_1800 = np.loadtxt(folder_data + folder_saved +"mee-1800-2.txt", delimiter=',')

e1pt_eeSM_1800 = np.loadtxt(folder_data + folder_saved + 'e1-pt-1800-2.txt', delimiter=',')
e1eta_eeSM_1800 = np.loadtxt(folder_data + folder_saved + 'e1-eta-1800-2.txt', delimiter=',')
e1phi_eeSM_1800 = np.loadtxt(folder_data + folder_saved + 'e1-phi-1800-2.txt', delimiter=',')

e2pt_eeSM_1800 = np.loadtxt(folder_data + folder_saved + 'e2-pt-1800-2.txt', delimiter=',')
e2eta_eeSM_1800 = np.loadtxt(folder_data + folder_saved + 'e2-eta-1800-2.txt', delimiter=',')
e2phi_eeSM_1800 = np.loadtxt(folder_data + folder_saved + 'e2-phi-1800-2.txt', delimiter=',')


# only keep points where the invariant mass is greater than 2000 GeV
# and make sure that both electrons: |eta| < 2.47, excluding 1.37 < |eta| < 1.52
for i in reversed(range(len(invariant_mass_eeSM_1800))):
    if invariant_mass_eeSM_1800[i]< 2000 or e1eta_eeSM_1800[i] < -2.47 or -1.52 < e1eta_eeSM_1800[i] < -1.37 or 1.37 < e1eta_eeSM_1800[i] < 1.52 or e1eta_eeSM_1800[i] > 2.47 or e2eta_eeSM_1800[i] < -2.47 or -1.52 < e2eta_eeSM_1800[i] < -1.37 or 1.37 < e2eta_eeSM_1800[i] < 1.52 or e2eta_eeSM_1800[i] > 2.47:
        e1pt_eeSM_1800 = np.delete(e1pt_eeSM_1800, i)
        e1eta_eeSM_1800 = np.delete(e1eta_eeSM_1800, i)
        e1phi_eeSM_1800 = np.delete(e1phi_eeSM_1800, i)
        
        e2pt_eeSM_1800 = np.delete(e2pt_eeSM_1800, i)
        e2eta_eeSM_1800 = np.delete(e2eta_eeSM_1800, i)
        e2phi_eeSM_1800 = np.delete(e2phi_eeSM_1800, i)
        
        invariant_mass_eeSM_1800 = np.delete(invariant_mass_eeSM_1800, i)
        


# concatenate results
e1pt_eeSM = np.concatenate([e1pt_eeSM,e1pt_eeSM_1800])
e1eta_eeSM = np.concatenate([e1eta_eeSM,e1eta_eeSM_1800])
e1phi_eeSM = np.concatenate([e1phi_eeSM,e1phi_eeSM_1800])

e2pt_eeSM = np.concatenate([e2pt_eeSM,e2pt_eeSM_1800])
e2eta_eeSM = np.concatenate([e2eta_eeSM,e2eta_eeSM_1800])
e2phi_eeSM = np.concatenate([e2phi_eeSM,e2phi_eeSM_1800])

invariant_mass_eeSM = np.concatenate([invariant_mass_eeSM,invariant_mass_eeSM_1800])



# remove the aux
del e1pt_eeSM_1800
del e1eta_eeSM_1800
del e1phi_eeSM_1800

del e2pt_eeSM_1800
del e2eta_eeSM_1800
del e2phi_eeSM_1800

del invariant_mass_eeSM_1800





# FINALLY

# compute \Delta \eta_{l+l-}
e1e2diffeta_eeSM = np.array([a-b for a,b in zip(e1eta_eeSM,e2eta_eeSM)])

# compute R = [ \Delta \eta_{l+l-}^2 + \Delta \eta_{l+l-}^2 ]^1/2
e1e2R_eeSM = np.array([( (a-b)**2. + (c-d)**2. )**0.5 for a,b,c,d in zip(e1eta_eeSM,e2eta_eeSM,e1phi_eeSM,e2phi_eeSM)])



print(e1pt_eeSM.shape)
print(e1eta_eeSM.shape)
print(e1phi_eeSM.shape)

print(e2pt_eeSM.shape)
print(e2eta_eeSM.shape)
print(e2phi_eeSM.shape)

print(invariant_mass_eeSM.shape)
print(e1e2diffeta_eeSM.shape)
print(e1e2R_eeSM.shape)
# Out:
# (918041,)
# (918041,)
# (918041,)
# (918041,)
# (918041,)
# (918041,)
# (918041,)
# (918041,)
# (918041,)

# %%
print(min(e1eta_eeSM))
print(max(e1eta_eeSM))

print(min(e2eta_eeSM))
print(max(e2eta_eeSM))
# Out:
# -2.47
# 2.47
# -2.47
# 2.47

# %% [markdown]
# ### SSM Z prime

# %%
##########
# Zprime #
##########


folder_saved = "Zprime-SSM-ee-mZ5000GeV-variables/"


# 1st DATASET
invariant_mass_eeSSMZprime = np.loadtxt(folder_data + folder_saved +"mee-1.txt", delimiter=',')

e1pt_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'e1-pt-5000-1.txt', delimiter=',')
e1eta_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'e1-eta-5000-1.txt', delimiter=',')
e1phi_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'e1-phi-5000-1.txt', delimiter=',')

e2pt_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'e2-pt-5000-1.txt', delimiter=',')
e2eta_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'e2-eta-5000-1.txt', delimiter=',')
e2phi_eeSSMZprime = np.loadtxt(folder_data + folder_saved + 'e2-phi-5000-1.txt', delimiter=',')


# only keep points where the invariant mass is greater than 2000 GeV
# and make sure that both electrons: |eta| < 2.47, excluding 1.37 < |eta| < 1.52
for i in reversed(range(len(invariant_mass_eeSSMZprime))):
    if invariant_mass_eeSSMZprime[i]< 2000 or e1eta_eeSSMZprime[i] < -2.47 or -1.52 < e1eta_eeSSMZprime[i] < -1.37 or 1.37 < e1eta_eeSSMZprime[i] < 1.52 or e1eta_eeSSMZprime[i] > 2.47 or e2eta_eeSSMZprime[i] < -2.47 or -1.52 < e2eta_eeSSMZprime[i] < -1.37 or 1.37 < e2eta_eeSSMZprime[i] < 1.52 or e2eta_eeSSMZprime[i] > 2.47:
        e1pt_eeSSMZprime = np.delete(e1pt_eeSSMZprime, i)
        e1eta_eeSSMZprime = np.delete(e1eta_eeSSMZprime, i)
        e1phi_eeSSMZprime = np.delete(e1phi_eeSSMZprime, i)
        
        e2pt_eeSSMZprime = np.delete(e2pt_eeSSMZprime, i)
        e2eta_eeSSMZprime = np.delete(e2eta_eeSSMZprime, i)
        e2phi_eeSSMZprime = np.delete(e2phi_eeSSMZprime, i)
        
        invariant_mass_eeSSMZprime = np.delete(invariant_mass_eeSSMZprime, i)
        
        
        
        
# 2nd DATASET
invariant_mass_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved +"mee-2.txt", delimiter=',')

e1pt_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved + 'e1-pt-5000-2.txt', delimiter=',')
e1eta_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved + 'e1-eta-5000-2.txt', delimiter=',')
e1phi_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved + 'e1-phi-5000-2.txt', delimiter=',')

e2pt_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved + 'e2-pt-5000-2.txt', delimiter=',')
e2eta_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved + 'e2-eta-5000-2.txt', delimiter=',')
e2phi_eeSSMZprime_2 = np.loadtxt(folder_data + folder_saved + 'e2-phi-5000-2.txt', delimiter=',')


# only keep points where the invariant mass is greater than 2000 GeV
# and make sure that both electrons: |eta| < 2.47, excluding 1.37 < |eta| < 1.52
for i in reversed(range(len(invariant_mass_eeSSMZprime_2))):
    if invariant_mass_eeSSMZprime_2[i]< 2000 or e1eta_eeSSMZprime_2[i] < -2.47 or -1.52 < e1eta_eeSSMZprime_2[i] < -1.37 or 1.37 < e1eta_eeSSMZprime_2[i] < 1.52 or e1eta_eeSSMZprime_2[i] > 2.47 or e2eta_eeSSMZprime_2[i] < -2.47 or -1.52 < e2eta_eeSSMZprime_2[i] < -1.37 or 1.37 < e2eta_eeSSMZprime_2[i] < 1.52 or e2eta_eeSSMZprime_2[i] > 2.47:
        e1pt_eeSSMZprime_2 = np.delete(e1pt_eeSSMZprime_2, i)
        e1eta_eeSSMZprime_2 = np.delete(e1eta_eeSSMZprime_2, i)
        e1phi_eeSSMZprime_2 = np.delete(e1phi_eeSSMZprime_2, i)
        
        e2pt_eeSSMZprime_2 = np.delete(e2pt_eeSSMZprime_2, i)
        e2eta_eeSSMZprime_2 = np.delete(e2eta_eeSSMZprime_2, i)
        e2phi_eeSSMZprime_2 = np.delete(e2phi_eeSSMZprime_2, i)
        
        invariant_mass_eeSSMZprime_2 = np.delete(invariant_mass_eeSSMZprime_2, i)
        
eventos_parton = 500000
aceptancia_eeSSMZprime_2 = 1.*len(invariant_mass_eeSSMZprime_2) / eventos_parton
print(aceptancia_eeSSMZprime_2)


# concatenate results
e1pt_eeSSMZprime = np.concatenate([e1pt_eeSSMZprime,e1pt_eeSSMZprime_2])
e1eta_eeSSMZprime = np.concatenate([e1eta_eeSSMZprime,e1eta_eeSSMZprime_2])
e1phi_eeSSMZprime = np.concatenate([e1phi_eeSSMZprime,e1phi_eeSSMZprime_2])

e2pt_eeSSMZprime = np.concatenate([e2pt_eeSSMZprime,e2pt_eeSSMZprime_2])
e2eta_eeSSMZprime = np.concatenate([e2eta_eeSSMZprime,e2eta_eeSSMZprime_2])
e2phi_eeSSMZprime = np.concatenate([e2phi_eeSSMZprime,e2phi_eeSSMZprime_2])

invariant_mass_eeSSMZprime = np.concatenate([invariant_mass_eeSSMZprime,invariant_mass_eeSSMZprime_2])



# remove the aux
del e1pt_eeSSMZprime_2
del e1eta_eeSSMZprime_2
del e1phi_eeSSMZprime_2

del e2pt_eeSSMZprime_2
del e2eta_eeSSMZprime_2
del e2phi_eeSSMZprime_2

del invariant_mass_eeSSMZprime_2







        
# 3rd DATASET
invariant_mass_eeSSMZprime_3 = np.loadtxt(folder_data + folder_saved +"mee-3.txt", delimiter=',')

e1pt_eeSSMZprime_3 = np.loadtxt(folder_data + folder_saved + 'e1-pt-5000-3.txt', delimiter=',')
e1eta_eeSSMZprime_3 = np.loadtxt(folder_data + folder_saved + 'e1-eta-5000-3.txt', delimiter=',')
e1phi_eeSSMZprime_3 = np.loadtxt(folder_data + folder_saved + 'e1-phi-5000-3.txt', delimiter=',')

e2pt_eeSSMZprime_3 = np.loadtxt(folder_data + folder_saved + 'e2-pt-5000-3.txt', delimiter=',')
e2eta_eeSSMZprime_3 = np.loadtxt(folder_data + folder_saved + 'e2-eta-5000-3.txt', delimiter=',')
e2phi_eeSSMZprime_3 = np.loadtxt(folder_data + folder_saved + 'e2-phi-5000-3.txt', delimiter=',')


# only keep points where the invariant mass is greater than 2000 GeV
# and make sure that both electrons: |eta| < 2.47, excluding 1.37 < |eta| < 1.52
for i in reversed(range(len(invariant_mass_eeSSMZprime_3))):
    if invariant_mass_eeSSMZprime_3[i]< 2000 or e1eta_eeSSMZprime_3[i] < -2.47 or -1.52 < e1eta_eeSSMZprime_3[i] < -1.37 or 1.37 < e1eta_eeSSMZprime_3[i] < 1.52 or e1eta_eeSSMZprime_3[i] > 2.47 or e2eta_eeSSMZprime_3[i] < -2.47 or -1.52 < e2eta_eeSSMZprime_3[i] < -1.37 or 1.37 < e2eta_eeSSMZprime_3[i] < 1.52 or e2eta_eeSSMZprime_3[i] > 2.47:
        e1pt_eeSSMZprime_3 = np.delete(e1pt_eeSSMZprime_3, i)
        e1eta_eeSSMZprime_3 = np.delete(e1eta_eeSSMZprime_3, i)
        e1phi_eeSSMZprime_3 = np.delete(e1phi_eeSSMZprime_3, i)
        
        e2pt_eeSSMZprime_3 = np.delete(e2pt_eeSSMZprime_3, i)
        e2eta_eeSSMZprime_3 = np.delete(e2eta_eeSSMZprime_3, i)
        e2phi_eeSSMZprime_3 = np.delete(e2phi_eeSSMZprime_3, i)
        
        invariant_mass_eeSSMZprime_3 = np.delete(invariant_mass_eeSSMZprime_3, i)
        
eventos_parton = 500000
aceptancia_eeSSMZprime_3 = 1.*len(invariant_mass_eeSSMZprime_3) / eventos_parton
print(aceptancia_eeSSMZprime_3)


# concatenate results
e1pt_eeSSMZprime = np.concatenate([e1pt_eeSSMZprime,e1pt_eeSSMZprime_3])
e1eta_eeSSMZprime = np.concatenate([e1eta_eeSSMZprime,e1eta_eeSSMZprime_3])
e1phi_eeSSMZprime = np.concatenate([e1phi_eeSSMZprime,e1phi_eeSSMZprime_3])

e2pt_eeSSMZprime = np.concatenate([e2pt_eeSSMZprime,e2pt_eeSSMZprime_3])
e2eta_eeSSMZprime = np.concatenate([e2eta_eeSSMZprime,e2eta_eeSSMZprime_3])
e2phi_eeSSMZprime = np.concatenate([e2phi_eeSSMZprime,e2phi_eeSSMZprime_3])

invariant_mass_eeSSMZprime = np.concatenate([invariant_mass_eeSSMZprime,invariant_mass_eeSSMZprime_3])



# remove the aux
del e1pt_eeSSMZprime_3
del e1eta_eeSSMZprime_3
del e1phi_eeSSMZprime_3

del e2pt_eeSSMZprime_3
del e2eta_eeSSMZprime_3
del e2phi_eeSSMZprime_3

del invariant_mass_eeSSMZprime_3






# FINALLY

# compute \Delta \eta_{l+l-}
e1e2diffeta_eeSSMZprime = np.array([a-b for a,b in zip(e1eta_eeSSMZprime,e2eta_eeSSMZprime)])

# compute R = [ \Delta \eta_{l+l-}^2 + \Delta \eta_{l+l-}^2 ]^1/2
e1e2R_eeSSMZprime = np.array([( (a-b)**2. + (c-d)**2. )**0.5 for a,b,c,d in zip(e1eta_eeSSMZprime,e2eta_eeSSMZprime,e1phi_eeSSMZprime,e2phi_eeSSMZprime)])




print(e1pt_eeSSMZprime.shape)
print(e1eta_eeSSMZprime.shape)
print(e1phi_eeSSMZprime.shape)

print(e2pt_eeSSMZprime.shape)
print(e2eta_eeSSMZprime.shape)
print(e2phi_eeSSMZprime.shape)

print(invariant_mass_eeSSMZprime.shape)
print(e1e2diffeta_eeSSMZprime.shape)
print(e1e2R_eeSSMZprime.shape)
# Out:
# 0.385648
# 0.879466
# (885641,)
# (885641,)
# (885641,)
# (885641,)
# (885641,)
# (885641,)
# (885641,)
# (885641,)
# (885641,)

# %%
print(min(e1eta_eeSSMZprime))
print(max(e1eta_eeSSMZprime))

print(min(e2eta_eeSSMZprime))
print(max(e2eta_eeSSMZprime))
# Out:
# -2.469
# 2.469
# -2.469
# 2.469

# %%
# NOW DATA IS CHECKED

bins_atlas = [70, 80.0, 90.0, 105.0, 120.0, 140.0, 160.0, 180.0, 210.0, 240.0, 275.0, 315.0, 360.0, 415.0, 475.0, 545.0, 625.0, 715.0, 825.0, 950.0, 1100.0, 1250.0, 1450.0, 1650.0, 1900.0, 2200.0, 2500.0, 2850.0, 3250.0, 3750.0, 4350.0, 5000.0, 5750.0, 6600.0, 7500.0, 8750.0, 10000.0, 11500.0, 13000.0, 20000]

plt.hist(invariant_mass_eeSM, bins=bins_atlas, lw=2, edgecolor='blue', histtype='step', label="SM")
plt.hist(invariant_mass_eeSSMZprime, bins=bins_atlas, lw=2, edgecolor='red', histtype='step', label="$Z'_{SSM}$")

plt.grid()  # Add grid lines

plt.title(r"Z/Z'$\rightarrow \mu+ \mu-$",fontsize=14)  # Titles etc
plt.xlabel("$m_{ll}$ (GeV)",fontsize=14)
plt.ylabel("Events",fontsize=14)

plt.xlim(70.,20000)
plt.ylim(1e0,1e7)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xscale('log')
plt.yscale('log')
plt.legend(loc='upper left',fontsize=12)

plt.show()




plt.hist(e1e2diffeta_eeSM, bins=100, range=[-5,5], lw=2, edgecolor='blue', histtype='step', label="SM")
plt.hist(e1e2diffeta_eeSSMZprime, bins=100, range=[-5,5], lw=2, edgecolor='red', histtype='step', label="$Z'_{SSM}$")

plt.grid()  # Add grid lines

plt.title(r"Z/Z'$\rightarrow \mu+ \mu-$",fontsize=14)  # Titles etc
plt.xlabel("$\Delta \eta_{ll}$",fontsize=14)
plt.ylabel("Events",fontsize=14)

plt.xlim(-5,5)
plt.ylim(1e0,1e7)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#plt.xscale('log')
plt.yscale('log')
plt.legend(loc='upper left',fontsize=12)

plt.show()




plt.hist(e1e2R_eeSM, bins=82, range=[0,8.2], lw=2, edgecolor='blue', histtype='step', label="SM")
plt.hist(e1e2R_eeSSMZprime, bins=82, range=[0,8.2], lw=2, edgecolor='red', histtype='step', label="$Z'_{SSM}$")

plt.grid()  # Add grid lines

plt.title(r"Z/Z'$\rightarrow \mu+ \mu-$",fontsize=14)  # Titles etc
plt.xlabel("$R$",fontsize=14)
plt.ylabel("Events",fontsize=14)

plt.xlim(0.,8.2)
plt.ylim(1e0,1e7)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#plt.xscale('log')
plt.yscale('log')
plt.legend(loc='upper left',fontsize=12)

plt.show()

# %% [markdown]
# ### Train-test-val datasets

# %%
# to normalize
scaler = preprocessing.MinMaxScaler()

# Number of data points (per-class) for the ML classifier
num_data = 750000



df = pd.DataFrame()

df['e1-pt']= np.concatenate([e1pt_eeSM[:num_data],e1pt_eeSSMZprime[:num_data]])
df['e1-eta']= np.concatenate([e1eta_eeSM[:num_data],e1eta_eeSSMZprime[:num_data]])
df['e1-phi']= np.concatenate([e1phi_eeSM[:num_data],e1phi_eeSSMZprime[:num_data]])

df['e2-pt']= np.concatenate([e2pt_eeSM[:num_data],e2pt_eeSSMZprime[:num_data]])
df['e2-eta']= np.concatenate([e2eta_eeSM[:num_data],e2eta_eeSSMZprime[:num_data]])
df['e2-phi']= np.concatenate([e2phi_eeSM[:num_data],e2phi_eeSSMZprime[:num_data]])

df['mll']= np.concatenate([invariant_mass_eeSM[:num_data],invariant_mass_eeSSMZprime[:num_data]])
df['delta-eta']= np.concatenate([e1e2diffeta_eeSM[:num_data],e1e2diffeta_eeSSMZprime[:num_data]])
df['R']= np.concatenate([e1e2R_eeSM[:num_data],e1e2R_eeSSMZprime[:num_data]])

df['Y'] = np.concatenate([np.zeros(num_data),np.ones(num_data)])


# remove the used data
del e1pt_eeSM
del e1eta_eeSM
del e1phi_eeSM

del e2pt_eeSM
del e2eta_eeSM
del e2phi_eeSM

del e1pt_eeSSMZprime
del e1eta_eeSSMZprime
del e1phi_eeSSMZprime

del e2pt_eeSSMZprime
del e2eta_eeSSMZprime
del e2phi_eeSSMZprime


# NORMALIZE
df = scaler.fit_transform(df)
df = pd.DataFrame(df,columns=['e1-pt','e1-eta','e1-phi','e2-pt','e2-eta','e2-phi','mll','delta-eta','R','Y'])


# print df to see the data
print(df)


# X and Y for the classifier
X_mon = df[['e1-pt','e1-eta','e1-phi','e2-pt','e2-eta','e2-phi']].values
y_mon = df[['Y']].values

del df

# divide into train-val and test data samples
test_ratio = 1./3
val_ratio = 0.25


X_mon_aux, X_mon_test, y_mon_aux, y_mon_test = train_test_split(X_mon,
                                                                y_mon,
                                                                test_size=test_ratio,
                                                                random_state=42,
                                                                #stratify = y_mon,
                                                                shuffle=True)


X_mon_train, X_mon_val, y_mon_train, y_mon_val = train_test_split(X_mon_aux,
                                                                  y_mon_aux,
                                                                  test_size=val_ratio,
                                                                  random_state=42,
                                                                  #stratify = y_mon_aux,
                                                                  shuffle=True)


print('')
print('X_mon_train : ', X_mon_train.shape)
print('y_mon_train : ', y_mon_train.shape)
print('X_mon_val : ', X_mon_val.shape)
print('y_mon_val : ', y_mon_val.shape)
print('X_mon_test : ', X_mon_test.shape)
print('y_mon_test : ', y_mon_test.shape)
print('')
# Out:
#             e1-pt    e1-eta    e1-phi     e2-pt    e2-eta    e2-phi       mll  \
# 0        0.185525  0.458097  0.458625  0.213083  0.617409  0.964036  0.011698
# 1        0.105476  0.242713  0.782623  0.134066  0.738462  0.299013  0.046466
# 2        0.236823  0.516397  0.277371  0.268319  0.470648  0.789306  0.055798
# 3        0.148065  0.424089  0.408498  0.177052  0.895951  0.924570  0.120553
# 4        0.208545  0.415182  0.181254  0.232257  0.386235  0.636219  0.013300
# ...           ...       ...       ...       ...       ...       ...       ...
# 1499995  0.300855  0.299798  0.655315  0.326100  0.762146  0.154997  0.424167
# 1499996  0.334749  0.225709  0.490611  0.361277  0.642713  0.988861  0.429024
# 1499997  0.215051  0.279150  0.403724  0.223579  0.928947  0.831158  0.483472
# 1499998  0.201851  0.495749  0.094048  0.218412  0.495547  0.593571  0.003218
# 1499999  0.523741  0.429150  0.191279  0.567866  0.511134  0.690325  0.418118
#
#          delta-eta         R    Y
# 0         0.420940  0.313476  0.0
# 1         0.251832  0.417037  0.0
# 2         0.524013  0.305740  0.0
# 3         0.263838  0.431951  0.0
# 4         0.515568  0.246261  0.0
# ...            ...       ...  ...
# 1499995   0.268620  0.414261  1.0
# 1499996   0.291412  0.391584  1.0
# 1499997   0.174400  0.463419  1.0
# 1499998   0.501119  0.291636  1.0
# 1499999   0.459809  0.295418  1.0
#
# [1500000 rows x 10 columns]
#
# X_mon_train :  (750000, 6)
# y_mon_train :  (750000, 1)
# X_mon_val :  (250000, 6)
# y_mon_val :  (250000, 1)
# X_mon_test :  (500000, 6)
# y_mon_test :  (500000, 1)

# %% [markdown]
# ### XGBoost (per-event)

# %% [markdown]
# ##### For 1 ML

# %%
# XGBoost with only the kinematic variables of the leptons

# CLASSIFIER
classifier = XGBClassifier(
    n_estimators=2500,
    learning_rate=0.1,
    reg_lambda=0.0,reg_alpha=0.0,
    gamma=0.0,objective='binary:logistic',
    max_depth=5)

# FIT
classifier.fit(X_mon_train,y_mon_train,eval_set=[(X_mon_train, y_mon_train), (X_mon_val, y_mon_val)],
        eval_metric='logloss',early_stopping_rounds=50,#early stopping
        verbose=True)

# PREDICTIONS
y_pred_xg_1ML = classifier.predict_proba(X_mon_test).T[1]


# ROC
fpr_mon_xg, tpr_mon_xg, _ = roc_curve(y_mon_test, y_pred_xg_1ML)
roc_auc_xg = auc(fpr_mon_xg, tpr_mon_xg)


# PLOT THE ROC WITH AUC
fig = plt.figure(figsize=(6, 6))
gs = gridspec.GridSpec(1, 1) 
ax0 = plt.subplot(gs[0])
ax0.yaxis.set_ticks_position('both')
ax0.xaxis.set_ticks_position('both')
ax0.tick_params(direction="in",which="both")
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
ax0.minorticks_on()


plt.plot(tpr_mon_xg,1-fpr_mon_xg,label="$f_{1}$, AUC = %0.2f" % roc_auc_xg,color="orange",ls=":",lw=4)
plt.plot([1,0],[0,1],ls=":",color="grey")
plt.xlabel("True Positive Rate",fontsize=16)
plt.ylabel("1 $-$ False Positive Rate",fontsize=16)
plt.legend()
plt.title(r"SSM Z' - XGBoost",fontsize=16)
plt.xlim([0,1])
plt.ylim([0,1])
plt.yticks([0.2,0.4,0.6,0.8,1.])
plt.legend(frameon=False,fontsize=16)
plt.show()




feature_names = np.array(['e1-pt','e1-eta','e1-phi','e2-pt','e2-eta','e2-phi'])
plt.barh(feature_names, classifier.feature_importances_)
plt.xlabel("Xgboost Feature Importance")
plt.show()
# Out:
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [0]	validation_0-logloss:0.63528	validation_1-logloss:0.63525
# [1]	validation_0-logloss:0.58725	validation_1-logloss:0.58721
# [2]	validation_0-logloss:0.54675	validation_1-logloss:0.54661
# [3]	validation_0-logloss:0.51245	validation_1-logloss:0.51227
# [4]	validation_0-logloss:0.48323	validation_1-logloss:0.48311
# [5]	validation_0-logloss:0.45762	validation_1-logloss:0.45740
# [6]	validation_0-logloss:0.43524	validation_1-logloss:0.43511
# [7]	validation_0-logloss:0.41567	validation_1-logloss:0.41551
# [8]	validation_0-logloss:0.39912	validation_1-logloss:0.39894
# [9]	validation_0-logloss:0.38435	validation_1-logloss:0.38416
# [10]	validation_0-logloss:0.37150	validation_1-logloss:0.37145
# [11]	validation_0-logloss:0.35985	validation_1-logloss:0.35987
# [12]	validation_0-logloss:0.35013	validation_1-logloss:0.35015
# [13]	validation_0-logloss:0.34091	validation_1-logloss:0.34095
# [14]	validation_0-logloss:0.33242	validation_1-logloss:0.33244
# [15]	validation_0-logloss:0.32516	validation_1-logloss:0.32523
# [16]	validation_0-logloss:0.31842	validation_1-logloss:0.31858
# [17]	validation_0-logloss:0.31276	validation_1-logloss:0.31288
# [18]	validation_0-logloss:0.30729	validation_1-logloss:0.30744
# [19]	validation_0-logloss:0.30253	validation_1-logloss:0.30270
# [20]	validation_0-logloss:0.29747	validation_1-logloss:0.29758
# [21]	validation_0-logloss:0.29345	validation_1-logloss:0.29361
# [22]	validation_0-logloss:0.28936	validation_1-logloss:0.28951
# [23]	validation_0-logloss:0.28613	validation_1-logloss:0.28629
# [24]	validation_0-logloss:0.28322	validation_1-logloss:0.28338
# [25]	validation_0-logloss:0.28026	validation_1-logloss:0.28044
# [26]	validation_0-logloss:0.27719	validation_1-logloss:0.27738
# [27]	validation_0-logloss:0.27513	validation_1-logloss:0.27534
# [28]	validation_0-logloss:0.27254	validation_1-logloss:0.27277
# [29]	validation_0-logloss:0.27062	validation_1-logloss:0.27084
# [30]	validation_0-logloss:0.26844	validation_1-logloss:0.26871
# [31]	validation_0-logloss:0.26695	validation_1-logloss:0.26720
# [32]	validation_0-logloss:0.26508	validation_1-logloss:0.26535
# [33]	validation_0-logloss:0.26343	validation_1-logloss:0.26370
# [34]	validation_0-logloss:0.26217	validation_1-logloss:0.26243
# [35]	validation_0-logloss:0.26101	validation_1-logloss:0.26131
# [36]	validation_0-logloss:0.25984	validation_1-logloss:0.26014
# [37]	validation_0-logloss:0.25887	validation_1-logloss:0.25921
# [38]	validation_0-logloss:0.25760	validation_1-logloss:0.25793
# [39]	validation_0-logloss:0.25639	validation_1-logloss:0.25674
# [40]	validation_0-logloss:0.25561	validation_1-logloss:0.25595
# [41]	validation_0-logloss:0.25451	validation_1-logloss:0.25490
# [42]	validation_0-logloss:0.25365	validation_1-logloss:0.25406
# [43]	validation_0-logloss:0.25283	validation_1-logloss:0.25328
# [44]	validation_0-logloss:0.25215	validation_1-logloss:0.25260
# [45]	validation_0-logloss:0.25130	validation_1-logloss:0.25176
# [46]	validation_0-logloss:0.25063	validation_1-logloss:0.25113
# [47]	validation_0-logloss:0.25016	validation_1-logloss:0.25071
# [48]	validation_0-logloss:0.24971	validation_1-logloss:0.25026
# [49]	validation_0-logloss:0.24906	validation_1-logloss:0.24962
# [50]	validation_0-logloss:0.24840	validation_1-logloss:0.24898
# [51]	validation_0-logloss:0.24784	validation_1-logloss:0.24840
# [52]	validation_0-logloss:0.24732	validation_1-logloss:0.24786
# [53]	validation_0-logloss:0.24674	validation_1-logloss:0.24731
# [54]	validation_0-logloss:0.24639	validation_1-logloss:0.24698
# [55]	validation_0-logloss:0.24594	validation_1-logloss:0.24655
# [56]	validation_0-logloss:0.24563	validation_1-logloss:0.24626
# [57]	validation_0-logloss:0.24526	validation_1-logloss:0.24591
# [58]	validation_0-logloss:0.24489	validation_1-logloss:0.24555
# [59]	validation_0-logloss:0.24455	validation_1-logloss:0.24523
# [60]	validation_0-logloss:0.24431	validation_1-logloss:0.24503
# [61]	validation_0-logloss:0.24397	validation_1-logloss:0.24469
# [62]	validation_0-logloss:0.24369	validation_1-logloss:0.24444
# [63]	validation_0-logloss:0.24342	validation_1-logloss:0.24419
# [64]	validation_0-logloss:0.24319	validation_1-logloss:0.24399
# [65]	validation_0-logloss:0.24300	validation_1-logloss:0.24382
# [66]	validation_0-logloss:0.24275	validation_1-logloss:0.24359
# [67]	validation_0-logloss:0.24255	validation_1-logloss:0.24341
# [68]	validation_0-logloss:0.24234	validation_1-logloss:0.24321
# [69]	validation_0-logloss:0.24217	validation_1-logloss:0.24305
# [70]	validation_0-logloss:0.24200	validation_1-logloss:0.24292
# [71]	validation_0-logloss:0.24186	validation_1-logloss:0.24278
# [72]	validation_0-logloss:0.24172	validation_1-logloss:0.24266
# [73]	validation_0-logloss:0.24154	validation_1-logloss:0.24250
# [74]	validation_0-logloss:0.24141	validation_1-logloss:0.24241
# [75]	validation_0-logloss:0.24127	validation_1-logloss:0.24228
# [76]	validation_0-logloss:0.24111	validation_1-logloss:0.24214
# [77]	validation_0-logloss:0.24100	validation_1-logloss:0.24204
# [78]	validation_0-logloss:0.24088	validation_1-logloss:0.24194
# [79]	validation_0-logloss:0.24078	validation_1-logloss:0.24186
# [80]	validation_0-logloss:0.24071	validation_1-logloss:0.24180
# [81]	validation_0-logloss:0.24057	validation_1-logloss:0.24167
# [82]	validation_0-logloss:0.24047	validation_1-logloss:0.24160
# [83]	validation_0-logloss:0.24038	validation_1-logloss:0.24153
# [84]	validation_0-logloss:0.24029	validation_1-logloss:0.24146
# [85]	validation_0-logloss:0.24020	validation_1-logloss:0.24139
# [86]	validation_0-logloss:0.24005	validation_1-logloss:0.24126
# [87]	validation_0-logloss:0.23998	validation_1-logloss:0.24120
# [88]	validation_0-logloss:0.23989	validation_1-logloss:0.24111
# [89]	validation_0-logloss:0.23983	validation_1-logloss:0.24107
# [90]	validation_0-logloss:0.23973	validation_1-logloss:0.24098
# [91]	validation_0-logloss:0.23964	validation_1-logloss:0.24092
# [92]	validation_0-logloss:0.23956	validation_1-logloss:0.24085
# [93]	validation_0-logloss:0.23949	validation_1-logloss:0.24080
# [94]	validation_0-logloss:0.23941	validation_1-logloss:0.24074
# [95]	validation_0-logloss:0.23933	validation_1-logloss:0.24067
# [96]	validation_0-logloss:0.23927	validation_1-logloss:0.24063
# [97]	validation_0-logloss:0.23922	validation_1-logloss:0.24059
# [98]	validation_0-logloss:0.23917	validation_1-logloss:0.24055
# [99]	validation_0-logloss:0.23909	validation_1-logloss:0.24049
# [100]	validation_0-logloss:0.23904	validation_1-logloss:0.24045
# [101]	validation_0-logloss:0.23899	validation_1-logloss:0.24042
# [102]	validation_0-logloss:0.23892	validation_1-logloss:0.24037
# [103]	validation_0-logloss:0.23887	validation_1-logloss:0.24034
# [104]	validation_0-logloss:0.23884	validation_1-logloss:0.24032
# [105]	validation_0-logloss:0.23880	validation_1-logloss:0.24030
# [106]	validation_0-logloss:0.23877	validation_1-logloss:0.24029
# [107]	validation_0-logloss:0.23872	validation_1-logloss:0.24026
# [108]	validation_0-logloss:0.23867	validation_1-logloss:0.24023
# [109]	validation_0-logloss:0.23864	validation_1-logloss:0.24021
# [110]	validation_0-logloss:0.23856	validation_1-logloss:0.24016
# [111]	validation_0-logloss:0.23851	validation_1-logloss:0.24012
# [112]	validation_0-logloss:0.23847	validation_1-logloss:0.24009
# [113]	validation_0-logloss:0.23843	validation_1-logloss:0.24008
# [114]	validation_0-logloss:0.23839	validation_1-logloss:0.24005
# [115]	validation_0-logloss:0.23836	validation_1-logloss:0.24003
# [116]	validation_0-logloss:0.23834	validation_1-logloss:0.24001
# [117]	validation_0-logloss:0.23829	validation_1-logloss:0.23998
# [118]	validation_0-logloss:0.23825	validation_1-logloss:0.23996
# [119]	validation_0-logloss:0.23822	validation_1-logloss:0.23994
# [120]	validation_0-logloss:0.23820	validation_1-logloss:0.23993
# [121]	validation_0-logloss:0.23816	validation_1-logloss:0.23991
# [122]	validation_0-logloss:0.23814	validation_1-logloss:0.23991
# [123]	validation_0-logloss:0.23811	validation_1-logloss:0.23989
# [124]	validation_0-logloss:0.23809	validation_1-logloss:0.23989
# [125]	validation_0-logloss:0.23806	validation_1-logloss:0.23987
# [126]	validation_0-logloss:0.23802	validation_1-logloss:0.23986
# [127]	validation_0-logloss:0.23799	validation_1-logloss:0.23986
# [128]	validation_0-logloss:0.23792	validation_1-logloss:0.23981
# [129]	validation_0-logloss:0.23790	validation_1-logloss:0.23980
# [130]	validation_0-logloss:0.23787	validation_1-logloss:0.23979
# [131]	validation_0-logloss:0.23785	validation_1-logloss:0.23979
# [132]	validation_0-logloss:0.23783	validation_1-logloss:0.23978
# [133]	validation_0-logloss:0.23780	validation_1-logloss:0.23976
# [134]	validation_0-logloss:0.23778	validation_1-logloss:0.23975
# [135]	validation_0-logloss:0.23774	validation_1-logloss:0.23971
# [136]	validation_0-logloss:0.23772	validation_1-logloss:0.23971
# [137]	validation_0-logloss:0.23770	validation_1-logloss:0.23971
# [138]	validation_0-logloss:0.23769	validation_1-logloss:0.23970
# [139]	validation_0-logloss:0.23767	validation_1-logloss:0.23969
# [140]	validation_0-logloss:0.23765	validation_1-logloss:0.23968
# [141]	validation_0-logloss:0.23762	validation_1-logloss:0.23966
# [142]	validation_0-logloss:0.23760	validation_1-logloss:0.23966
# [143]	validation_0-logloss:0.23757	validation_1-logloss:0.23966
# [144]	validation_0-logloss:0.23755	validation_1-logloss:0.23965
# [145]	validation_0-logloss:0.23752	validation_1-logloss:0.23965
# [146]	validation_0-logloss:0.23751	validation_1-logloss:0.23964
# [147]	validation_0-logloss:0.23749	validation_1-logloss:0.23964
# [148]	validation_0-logloss:0.23747	validation_1-logloss:0.23963
# [149]	validation_0-logloss:0.23745	validation_1-logloss:0.23963
# [150]	validation_0-logloss:0.23743	validation_1-logloss:0.23963
# [151]	validation_0-logloss:0.23741	validation_1-logloss:0.23963
# [152]	validation_0-logloss:0.23739	validation_1-logloss:0.23963
# [153]	validation_0-logloss:0.23737	validation_1-logloss:0.23963
# [154]	validation_0-logloss:0.23735	validation_1-logloss:0.23963
# [155]	validation_0-logloss:0.23733	validation_1-logloss:0.23962
# [156]	validation_0-logloss:0.23730	validation_1-logloss:0.23961
# [157]	validation_0-logloss:0.23728	validation_1-logloss:0.23961
# [158]	validation_0-logloss:0.23727	validation_1-logloss:0.23961
# [159]	validation_0-logloss:0.23725	validation_1-logloss:0.23961
# [160]	validation_0-logloss:0.23723	validation_1-logloss:0.23960
# [161]	validation_0-logloss:0.23721	validation_1-logloss:0.23960
# [162]	validation_0-logloss:0.23717	validation_1-logloss:0.23958
# [163]	validation_0-logloss:0.23715	validation_1-logloss:0.23958
# [164]	validation_0-logloss:0.23713	validation_1-logloss:0.23958
# [165]	validation_0-logloss:0.23712	validation_1-logloss:0.23957
# [166]	validation_0-logloss:0.23711	validation_1-logloss:0.23957
# [167]	validation_0-logloss:0.23710	validation_1-logloss:0.23957
# [168]	validation_0-logloss:0.23708	validation_1-logloss:0.23956
# [169]	validation_0-logloss:0.23708	validation_1-logloss:0.23956
# [170]	validation_0-logloss:0.23706	validation_1-logloss:0.23957
# [171]	validation_0-logloss:0.23702	validation_1-logloss:0.23954
# [172]	validation_0-logloss:0.23700	validation_1-logloss:0.23954
# [173]	validation_0-logloss:0.23697	validation_1-logloss:0.23953
# [174]	validation_0-logloss:0.23696	validation_1-logloss:0.23953
# [175]	validation_0-logloss:0.23691	validation_1-logloss:0.23950
# [176]	validation_0-logloss:0.23690	validation_1-logloss:0.23950
# [177]	validation_0-logloss:0.23688	validation_1-logloss:0.23951
# [178]	validation_0-logloss:0.23686	validation_1-logloss:0.23950
# [179]	validation_0-logloss:0.23684	validation_1-logloss:0.23950
# [180]	validation_0-logloss:0.23682	validation_1-logloss:0.23950
# [181]	validation_0-logloss:0.23680	validation_1-logloss:0.23949
# [182]	validation_0-logloss:0.23678	validation_1-logloss:0.23949
# [183]	validation_0-logloss:0.23677	validation_1-logloss:0.23949
# [184]	validation_0-logloss:0.23676	validation_1-logloss:0.23949
# [185]	validation_0-logloss:0.23674	validation_1-logloss:0.23948
# [186]	validation_0-logloss:0.23672	validation_1-logloss:0.23948
# [187]	validation_0-logloss:0.23671	validation_1-logloss:0.23949
# [188]	validation_0-logloss:0.23669	validation_1-logloss:0.23949
# [189]	validation_0-logloss:0.23667	validation_1-logloss:0.23949
# [190]	validation_0-logloss:0.23665	validation_1-logloss:0.23949
# [191]	validation_0-logloss:0.23664	validation_1-logloss:0.23948
# [192]	validation_0-logloss:0.23663	validation_1-logloss:0.23948
# [193]	validation_0-logloss:0.23662	validation_1-logloss:0.23948
# [194]	validation_0-logloss:0.23659	validation_1-logloss:0.23948
# [195]	validation_0-logloss:0.23658	validation_1-logloss:0.23947
# [196]	validation_0-logloss:0.23656	validation_1-logloss:0.23947
# [197]	validation_0-logloss:0.23654	validation_1-logloss:0.23947
# [198]	validation_0-logloss:0.23653	validation_1-logloss:0.23947
# [199]	validation_0-logloss:0.23651	validation_1-logloss:0.23947
# [200]	validation_0-logloss:0.23649	validation_1-logloss:0.23947
# [201]	validation_0-logloss:0.23648	validation_1-logloss:0.23946
# [202]	validation_0-logloss:0.23647	validation_1-logloss:0.23946
# [203]	validation_0-logloss:0.23645	validation_1-logloss:0.23946
# [204]	validation_0-logloss:0.23644	validation_1-logloss:0.23946
# [205]	validation_0-logloss:0.23642	validation_1-logloss:0.23946
# [206]	validation_0-logloss:0.23640	validation_1-logloss:0.23946
# [207]	validation_0-logloss:0.23640	validation_1-logloss:0.23946
# [208]	validation_0-logloss:0.23638	validation_1-logloss:0.23945
# [209]	validation_0-logloss:0.23636	validation_1-logloss:0.23945
# [210]	validation_0-logloss:0.23634	validation_1-logloss:0.23945
# [211]	validation_0-logloss:0.23632	validation_1-logloss:0.23945
# [212]	validation_0-logloss:0.23632	validation_1-logloss:0.23945
# [213]	validation_0-logloss:0.23630	validation_1-logloss:0.23945
# [214]	validation_0-logloss:0.23628	validation_1-logloss:0.23945
# [215]	validation_0-logloss:0.23627	validation_1-logloss:0.23945
# [216]	validation_0-logloss:0.23625	validation_1-logloss:0.23945
# [217]	validation_0-logloss:0.23625	validation_1-logloss:0.23945
# [218]	validation_0-logloss:0.23624	validation_1-logloss:0.23944
# [219]	validation_0-logloss:0.23620	validation_1-logloss:0.23942
# [220]	validation_0-logloss:0.23618	validation_1-logloss:0.23942
# [221]	validation_0-logloss:0.23616	validation_1-logloss:0.23942
# [222]	validation_0-logloss:0.23615	validation_1-logloss:0.23943
# [223]	validation_0-logloss:0.23614	validation_1-logloss:0.23943
# [224]	validation_0-logloss:0.23612	validation_1-logloss:0.23943
# [225]	validation_0-logloss:0.23609	validation_1-logloss:0.23942
# [226]	validation_0-logloss:0.23608	validation_1-logloss:0.23942
# [227]	validation_0-logloss:0.23607	validation_1-logloss:0.23942
# [228]	validation_0-logloss:0.23605	validation_1-logloss:0.23942
# [229]	validation_0-logloss:0.23604	validation_1-logloss:0.23942
# [230]	validation_0-logloss:0.23603	validation_1-logloss:0.23943
# [231]	validation_0-logloss:0.23601	validation_1-logloss:0.23943
# [232]	validation_0-logloss:0.23599	validation_1-logloss:0.23942
# [233]	validation_0-logloss:0.23598	validation_1-logloss:0.23943
# [234]	validation_0-logloss:0.23597	validation_1-logloss:0.23942
# [235]	validation_0-logloss:0.23596	validation_1-logloss:0.23942
# [236]	validation_0-logloss:0.23595	validation_1-logloss:0.23943
# [237]	validation_0-logloss:0.23591	validation_1-logloss:0.23941
# [238]	validation_0-logloss:0.23591	validation_1-logloss:0.23941
# [239]	validation_0-logloss:0.23589	validation_1-logloss:0.23940
# [240]	validation_0-logloss:0.23587	validation_1-logloss:0.23940
# [241]	validation_0-logloss:0.23585	validation_1-logloss:0.23941
# [242]	validation_0-logloss:0.23583	validation_1-logloss:0.23941
# [243]	validation_0-logloss:0.23582	validation_1-logloss:0.23941
# [244]	validation_0-logloss:0.23581	validation_1-logloss:0.23941
# [245]	validation_0-logloss:0.23579	validation_1-logloss:0.23940
# [246]	validation_0-logloss:0.23576	validation_1-logloss:0.23940
# [247]	validation_0-logloss:0.23575	validation_1-logloss:0.23941
# [248]	validation_0-logloss:0.23571	validation_1-logloss:0.23940
# [249]	validation_0-logloss:0.23569	validation_1-logloss:0.23940
# [250]	validation_0-logloss:0.23568	validation_1-logloss:0.23940
# [251]	validation_0-logloss:0.23567	validation_1-logloss:0.23940
# [252]	validation_0-logloss:0.23565	validation_1-logloss:0.23941
# [253]	validation_0-logloss:0.23565	validation_1-logloss:0.23940
# [254]	validation_0-logloss:0.23564	validation_1-logloss:0.23940
# [255]	validation_0-logloss:0.23562	validation_1-logloss:0.23940
# [256]	validation_0-logloss:0.23562	validation_1-logloss:0.23941
# [257]	validation_0-logloss:0.23560	validation_1-logloss:0.23941
# [258]	validation_0-logloss:0.23558	validation_1-logloss:0.23941
# [259]	validation_0-logloss:0.23555	validation_1-logloss:0.23941
# [260]	validation_0-logloss:0.23555	validation_1-logloss:0.23941
# [261]	validation_0-logloss:0.23555	validation_1-logloss:0.23941
# [262]	validation_0-logloss:0.23554	validation_1-logloss:0.23941
# [263]	validation_0-logloss:0.23552	validation_1-logloss:0.23941
# [264]	validation_0-logloss:0.23550	validation_1-logloss:0.23941
# [265]	validation_0-logloss:0.23549	validation_1-logloss:0.23941
# [266]	validation_0-logloss:0.23547	validation_1-logloss:0.23942
# [267]	validation_0-logloss:0.23545	validation_1-logloss:0.23941
# [268]	validation_0-logloss:0.23542	validation_1-logloss:0.23940
# [269]	validation_0-logloss:0.23540	validation_1-logloss:0.23940
# [270]	validation_0-logloss:0.23538	validation_1-logloss:0.23940
# [271]	validation_0-logloss:0.23537	validation_1-logloss:0.23940
# [272]	validation_0-logloss:0.23536	validation_1-logloss:0.23940
# [273]	validation_0-logloss:0.23536	validation_1-logloss:0.23940
# [274]	validation_0-logloss:0.23533	validation_1-logloss:0.23940
# [275]	validation_0-logloss:0.23532	validation_1-logloss:0.23940
# [276]	validation_0-logloss:0.23530	validation_1-logloss:0.23940
# [277]	validation_0-logloss:0.23529	validation_1-logloss:0.23940
# [278]	validation_0-logloss:0.23528	validation_1-logloss:0.23940
# [279]	validation_0-logloss:0.23527	validation_1-logloss:0.23940
# [280]	validation_0-logloss:0.23525	validation_1-logloss:0.23939
# [281]	validation_0-logloss:0.23523	validation_1-logloss:0.23939
# [282]	validation_0-logloss:0.23521	validation_1-logloss:0.23940
# [283]	validation_0-logloss:0.23519	validation_1-logloss:0.23940
# [284]	validation_0-logloss:0.23518	validation_1-logloss:0.23940
# [285]	validation_0-logloss:0.23517	validation_1-logloss:0.23940
# [286]	validation_0-logloss:0.23516	validation_1-logloss:0.23941
# [287]	validation_0-logloss:0.23515	validation_1-logloss:0.23941
# [288]	validation_0-logloss:0.23513	validation_1-logloss:0.23940
# [289]	validation_0-logloss:0.23510	validation_1-logloss:0.23939
# [290]	validation_0-logloss:0.23508	validation_1-logloss:0.23939
# [291]	validation_0-logloss:0.23506	validation_1-logloss:0.23939
# [292]	validation_0-logloss:0.23504	validation_1-logloss:0.23938
# [293]	validation_0-logloss:0.23503	validation_1-logloss:0.23939
# [294]	validation_0-logloss:0.23503	validation_1-logloss:0.23939
# [295]	validation_0-logloss:0.23502	validation_1-logloss:0.23939
# [296]	validation_0-logloss:0.23501	validation_1-logloss:0.23939
# [297]	validation_0-logloss:0.23499	validation_1-logloss:0.23939
# [298]	validation_0-logloss:0.23497	validation_1-logloss:0.23939
# [299]	validation_0-logloss:0.23496	validation_1-logloss:0.23939
# [300]	validation_0-logloss:0.23495	validation_1-logloss:0.23938
# [301]	validation_0-logloss:0.23494	validation_1-logloss:0.23938
# [302]	validation_0-logloss:0.23493	validation_1-logloss:0.23938
# [303]	validation_0-logloss:0.23492	validation_1-logloss:0.23938
# [304]	validation_0-logloss:0.23488	validation_1-logloss:0.23936
# [305]	validation_0-logloss:0.23488	validation_1-logloss:0.23936
# [306]	validation_0-logloss:0.23487	validation_1-logloss:0.23936
# [307]	validation_0-logloss:0.23486	validation_1-logloss:0.23937
# [308]	validation_0-logloss:0.23484	validation_1-logloss:0.23937
# [309]	validation_0-logloss:0.23482	validation_1-logloss:0.23937
# [310]	validation_0-logloss:0.23480	validation_1-logloss:0.23937
# [311]	validation_0-logloss:0.23479	validation_1-logloss:0.23937
# [312]	validation_0-logloss:0.23478	validation_1-logloss:0.23937
# [313]	validation_0-logloss:0.23476	validation_1-logloss:0.23937
# [314]	validation_0-logloss:0.23476	validation_1-logloss:0.23938
# [315]	validation_0-logloss:0.23475	validation_1-logloss:0.23937
# [316]	validation_0-logloss:0.23474	validation_1-logloss:0.23937
# [317]	validation_0-logloss:0.23472	validation_1-logloss:0.23937
# [318]	validation_0-logloss:0.23470	validation_1-logloss:0.23937
# [319]	validation_0-logloss:0.23469	validation_1-logloss:0.23937
# [320]	validation_0-logloss:0.23468	validation_1-logloss:0.23937
# [321]	validation_0-logloss:0.23468	validation_1-logloss:0.23937
# [322]	validation_0-logloss:0.23467	validation_1-logloss:0.23937
# [323]	validation_0-logloss:0.23466	validation_1-logloss:0.23938
# [324]	validation_0-logloss:0.23464	validation_1-logloss:0.23937
# [325]	validation_0-logloss:0.23461	validation_1-logloss:0.23937
# [326]	validation_0-logloss:0.23461	validation_1-logloss:0.23937
# [327]	validation_0-logloss:0.23458	validation_1-logloss:0.23936
# [328]	validation_0-logloss:0.23457	validation_1-logloss:0.23936
# [329]	validation_0-logloss:0.23456	validation_1-logloss:0.23937
# [330]	validation_0-logloss:0.23456	validation_1-logloss:0.23937
# [331]	validation_0-logloss:0.23455	validation_1-logloss:0.23937
# [332]	validation_0-logloss:0.23454	validation_1-logloss:0.23936
# [333]	validation_0-logloss:0.23453	validation_1-logloss:0.23936
# [334]	validation_0-logloss:0.23452	validation_1-logloss:0.23937
# [335]	validation_0-logloss:0.23450	validation_1-logloss:0.23937
# [336]	validation_0-logloss:0.23448	validation_1-logloss:0.23937
# [337]	validation_0-logloss:0.23446	validation_1-logloss:0.23937
# [338]	validation_0-logloss:0.23445	validation_1-logloss:0.23937
# [339]	validation_0-logloss:0.23444	validation_1-logloss:0.23937
# [340]	validation_0-logloss:0.23444	validation_1-logloss:0.23937
# [341]	validation_0-logloss:0.23443	validation_1-logloss:0.23937
# [342]	validation_0-logloss:0.23442	validation_1-logloss:0.23937
# [343]	validation_0-logloss:0.23440	validation_1-logloss:0.23937
# [344]	validation_0-logloss:0.23440	validation_1-logloss:0.23937
# [345]	validation_0-logloss:0.23439	validation_1-logloss:0.23937
# [346]	validation_0-logloss:0.23438	validation_1-logloss:0.23936
# [347]	validation_0-logloss:0.23436	validation_1-logloss:0.23937
# [348]	validation_0-logloss:0.23435	validation_1-logloss:0.23937
# [349]	validation_0-logloss:0.23433	validation_1-logloss:0.23937
# [350]	validation_0-logloss:0.23430	validation_1-logloss:0.23937
# [351]	validation_0-logloss:0.23429	validation_1-logloss:0.23937
# [352]	validation_0-logloss:0.23428	validation_1-logloss:0.23936
# [353]	validation_0-logloss:0.23427	validation_1-logloss:0.23936
# [354]	validation_0-logloss:0.23427	validation_1-logloss:0.23936
# [355]	validation_0-logloss:0.23425	validation_1-logloss:0.23936
# [356]	validation_0-logloss:0.23424	validation_1-logloss:0.23936
# [357]	validation_0-logloss:0.23423	validation_1-logloss:0.23936
# [358]	validation_0-logloss:0.23422	validation_1-logloss:0.23937
# [359]	validation_0-logloss:0.23420	validation_1-logloss:0.23937
# [360]	validation_0-logloss:0.23419	validation_1-logloss:0.23937
# [361]	validation_0-logloss:0.23418	validation_1-logloss:0.23937
# [362]	validation_0-logloss:0.23416	validation_1-logloss:0.23938
# [363]	validation_0-logloss:0.23415	validation_1-logloss:0.23938
# [364]	validation_0-logloss:0.23412	validation_1-logloss:0.23938
# [365]	validation_0-logloss:0.23410	validation_1-logloss:0.23938
# [366]	validation_0-logloss:0.23409	validation_1-logloss:0.23938
# [367]	validation_0-logloss:0.23408	validation_1-logloss:0.23938
# [368]	validation_0-logloss:0.23407	validation_1-logloss:0.23939
# [369]	validation_0-logloss:0.23406	validation_1-logloss:0.23939
# [370]	validation_0-logloss:0.23405	validation_1-logloss:0.23939
# [371]	validation_0-logloss:0.23403	validation_1-logloss:0.23939
# [372]	validation_0-logloss:0.23401	validation_1-logloss:0.23938
# [373]	validation_0-logloss:0.23400	validation_1-logloss:0.23938
# [374]	validation_0-logloss:0.23397	validation_1-logloss:0.23938
# [375]	validation_0-logloss:0.23395	validation_1-logloss:0.23938
# [376]	validation_0-logloss:0.23394	validation_1-logloss:0.23939
# [377]	validation_0-logloss:0.23392	validation_1-logloss:0.23939

# %% [markdown]
# ##### For 10 ML

# %%
# XGBoost with only the kinematic variables of the leptons

iterations_ML = 10

print('ML iteration 1')

# CLASSIFIER
classifier = XGBClassifier(
    n_estimators=2500,
    learning_rate=0.1,
    reg_lambda=0.0,reg_alpha=0.0,
    gamma=0.0,objective='binary:logistic',
    max_depth=5)

ran_ind = np.random.choice(np.arange(len(X_mon_train)), size = len(X_mon_train), replace = True)

# FIT
classifier.fit(X_mon_train[ran_ind],y_mon_train[ran_ind],eval_set=[(X_mon_train[ran_ind], y_mon_train[ran_ind]), (X_mon_val, y_mon_val)],
        eval_metric='logloss',early_stopping_rounds=50,#early stopping
        verbose=True)

# PREDICTIONS
y_pred_xg_aux = classifier.predict_proba(X_mon_test).T[1]
y_pred_xg_auxRE = np.reshape(y_pred_xg_aux, (1,len(y_pred_xg_aux)))


# ROC
fpr_mon_xg, tpr_mon_xg, _ = roc_curve(y_mon_test, y_pred_xg_aux)
roc_auc_xg = auc(fpr_mon_xg, tpr_mon_xg)


# PLOT THE ROC WITH AUC
fig = plt.figure(figsize=(6, 6))
gs = gridspec.GridSpec(1, 1) 
ax0 = plt.subplot(gs[0])
ax0.yaxis.set_ticks_position('both')
ax0.xaxis.set_ticks_position('both')
ax0.tick_params(direction="in",which="both")
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
ax0.minorticks_on()


plt.plot(tpr_mon_xg,1-fpr_mon_xg,label="$f_{1}$, AUC = %0.2f" % roc_auc_xg,color="orange",ls=":",lw=4)
plt.plot([1,0],[0,1],ls=":",color="grey")
plt.xlabel("True Positive Rate",fontsize=16)
plt.ylabel("1 $-$ False Positive Rate",fontsize=16)
plt.legend()
plt.title(r"SSM Z' - XGBoost",fontsize=16)
plt.xlim([0,1])
plt.ylim([0,1])
plt.yticks([0.2,0.4,0.6,0.8,1.])
plt.legend(frameon=False,fontsize=16)
plt.show()




print('\n ########################################\n')





for it in range(1,iterations_ML):

    print('ML iteration ', it)
    
    # CLASSIFIER
    classifier = XGBClassifier(
        n_estimators=2500,
        learning_rate=0.1,
        reg_lambda=0.0,reg_alpha=0.0,
        gamma=0.0,objective='binary:logistic',
        max_depth=5)

    ran_ind = np.random.choice(np.arange(len(X_mon_train)), size = len(X_mon_train), replace = True)

    # FIT
    classifier.fit(X_mon_train[ran_ind],y_mon_train[ran_ind],eval_set=[(X_mon_train[ran_ind], y_mon_train[ran_ind]), (X_mon_val, y_mon_val)],
            eval_metric='logloss',early_stopping_rounds=50,#early stopping
            verbose=True)

    # PREDICTIONS
    y_pred_xg_aux_it = classifier.predict_proba(X_mon_test).T[1]
    y_pred_xg_auxRE_it = np.reshape(y_pred_xg_aux_it, (1,len(y_pred_xg_aux_it)))
    
    y_pred_xg_auxRE = np.concatenate([y_pred_xg_auxRE,y_pred_xg_auxRE_it])


    # ROC
    fpr_mon_xg, tpr_mon_xg, _ = roc_curve(y_mon_test, y_pred_xg_aux)
    roc_auc_xg = auc(fpr_mon_xg, tpr_mon_xg)


    # PLOT THE ROC WITH AUC
    fig = plt.figure(figsize=(6, 6))
    gs = gridspec.GridSpec(1, 1) 
    ax0 = plt.subplot(gs[0])
    ax0.yaxis.set_ticks_position('both')
    ax0.xaxis.set_ticks_position('both')
    ax0.tick_params(direction="in",which="both")
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
    ax0.minorticks_on()


    plt.plot(tpr_mon_xg,1-fpr_mon_xg,label="$f_{1}$, AUC = %0.2f" % roc_auc_xg,color="orange",ls=":",lw=4)
    plt.plot([1,0],[0,1],ls=":",color="grey")
    plt.xlabel("True Positive Rate",fontsize=16)
    plt.ylabel("1 $-$ False Positive Rate",fontsize=16)
    plt.legend()
    plt.title(r"SSM Z' - XGBoost",fontsize=16)
    plt.xlim([0,1])
    plt.ylim([0,1])
    plt.yticks([0.2,0.4,0.6,0.8,1.])
    plt.legend(frameon=False,fontsize=16)
    plt.show()
    
    print('\n ########################################\n')
    
    
y_pred_xg = np.mean(y_pred_xg_auxRE, axis=0)
# Out:
# ML iteration 1
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [0]	validation_0-logloss:0.63493	validation_1-logloss:0.63507
# [1]	validation_0-logloss:0.58670	validation_1-logloss:0.58701
# [2]	validation_0-logloss:0.54598	validation_1-logloss:0.54639
# [3]	validation_0-logloss:0.51198	validation_1-logloss:0.51232
# [4]	validation_0-logloss:0.48206	validation_1-logloss:0.48257
# [5]	validation_0-logloss:0.45671	validation_1-logloss:0.45718
# [6]	validation_0-logloss:0.43441	validation_1-logloss:0.43495
# [7]	validation_0-logloss:0.41526	validation_1-logloss:0.41589
# [8]	validation_0-logloss:0.39817	validation_1-logloss:0.39890
# [9]	validation_0-logloss:0.38314	validation_1-logloss:0.38399
# [10]	validation_0-logloss:0.37006	validation_1-logloss:0.37104
# [11]	validation_0-logloss:0.35880	validation_1-logloss:0.35987
# [12]	validation_0-logloss:0.34848	validation_1-logloss:0.34946
# [13]	validation_0-logloss:0.33938	validation_1-logloss:0.34051
# [14]	validation_0-logloss:0.33077	validation_1-logloss:0.33197
# [15]	validation_0-logloss:0.32383	validation_1-logloss:0.32497
# [16]	validation_0-logloss:0.31760	validation_1-logloss:0.31877
# [17]	validation_0-logloss:0.31184	validation_1-logloss:0.31308
# [18]	validation_0-logloss:0.30652	validation_1-logloss:0.30782
# [19]	validation_0-logloss:0.30159	validation_1-logloss:0.30295
# [20]	validation_0-logloss:0.29611	validation_1-logloss:0.29749
# [21]	validation_0-logloss:0.29226	validation_1-logloss:0.29368
# [22]	validation_0-logloss:0.28852	validation_1-logloss:0.28994
# [23]	validation_0-logloss:0.28542	validation_1-logloss:0.28690
# [24]	validation_0-logloss:0.28165	validation_1-logloss:0.28313
# [25]	validation_0-logloss:0.27836	validation_1-logloss:0.27987
# [26]	validation_0-logloss:0.27596	validation_1-logloss:0.27751
# [27]	validation_0-logloss:0.27357	validation_1-logloss:0.27513
# [28]	validation_0-logloss:0.27064	validation_1-logloss:0.27224
# [29]	validation_0-logloss:0.26891	validation_1-logloss:0.27058
# [30]	validation_0-logloss:0.26720	validation_1-logloss:0.26889
# [31]	validation_0-logloss:0.26549	validation_1-logloss:0.26720
# [32]	validation_0-logloss:0.26352	validation_1-logloss:0.26530
# [33]	validation_0-logloss:0.26179	validation_1-logloss:0.26357
# [34]	validation_0-logloss:0.26009	validation_1-logloss:0.26189
# [35]	validation_0-logloss:0.25860	validation_1-logloss:0.26043
# [36]	validation_0-logloss:0.25764	validation_1-logloss:0.25953
# [37]	validation_0-logloss:0.25658	validation_1-logloss:0.25850
# [38]	validation_0-logloss:0.25569	validation_1-logloss:0.25766
# [39]	validation_0-logloss:0.25482	validation_1-logloss:0.25683
# [40]	validation_0-logloss:0.25375	validation_1-logloss:0.25581
# [41]	validation_0-logloss:0.25290	validation_1-logloss:0.25499
# [42]	validation_0-logloss:0.25204	validation_1-logloss:0.25417
# [43]	validation_0-logloss:0.25128	validation_1-logloss:0.25346
# [44]	validation_0-logloss:0.25071	validation_1-logloss:0.25295
# [45]	validation_0-logloss:0.25006	validation_1-logloss:0.25232
# [46]	validation_0-logloss:0.24921	validation_1-logloss:0.25151
# [47]	validation_0-logloss:0.24865	validation_1-logloss:0.25099
# [48]	validation_0-logloss:0.24808	validation_1-logloss:0.25044
# [49]	validation_0-logloss:0.24770	validation_1-logloss:0.25012
# [50]	validation_0-logloss:0.24718	validation_1-logloss:0.24961
# [51]	validation_0-logloss:0.24651	validation_1-logloss:0.24898
# [52]	validation_0-logloss:0.24601	validation_1-logloss:0.24851
# [53]	validation_0-logloss:0.24548	validation_1-logloss:0.24805
# [54]	validation_0-logloss:0.24488	validation_1-logloss:0.24749
# [55]	validation_0-logloss:0.24437	validation_1-logloss:0.24702
# [56]	validation_0-logloss:0.24394	validation_1-logloss:0.24661
# [57]	validation_0-logloss:0.24351	validation_1-logloss:0.24623
# [58]	validation_0-logloss:0.24302	validation_1-logloss:0.24576
# [59]	validation_0-logloss:0.24267	validation_1-logloss:0.24546
# [60]	validation_0-logloss:0.24235	validation_1-logloss:0.24517
# [61]	validation_0-logloss:0.24192	validation_1-logloss:0.24480
# [62]	validation_0-logloss:0.24165	validation_1-logloss:0.24457
# [63]	validation_0-logloss:0.24144	validation_1-logloss:0.24439
# [64]	validation_0-logloss:0.24108	validation_1-logloss:0.24409
# [65]	validation_0-logloss:0.24088	validation_1-logloss:0.24392
# [66]	validation_0-logloss:0.24065	validation_1-logloss:0.24373
# [67]	validation_0-logloss:0.24041	validation_1-logloss:0.24350
# [68]	validation_0-logloss:0.24012	validation_1-logloss:0.24327
# [69]	validation_0-logloss:0.23991	validation_1-logloss:0.24309
# [70]	validation_0-logloss:0.23975	validation_1-logloss:0.24297
# [71]	validation_0-logloss:0.23955	validation_1-logloss:0.24281
# [72]	validation_0-logloss:0.23929	validation_1-logloss:0.24260
# [73]	validation_0-logloss:0.23912	validation_1-logloss:0.24246
# [74]	validation_0-logloss:0.23900	validation_1-logloss:0.24237
# [75]	validation_0-logloss:0.23884	validation_1-logloss:0.24224
# [76]	validation_0-logloss:0.23869	validation_1-logloss:0.24214
# [77]	validation_0-logloss:0.23858	validation_1-logloss:0.24205
# [78]	validation_0-logloss:0.23846	validation_1-logloss:0.24197
# [79]	validation_0-logloss:0.23829	validation_1-logloss:0.24183
# [80]	validation_0-logloss:0.23813	validation_1-logloss:0.24172
# [81]	validation_0-logloss:0.23805	validation_1-logloss:0.24168
# [82]	validation_0-logloss:0.23791	validation_1-logloss:0.24158
# [83]	validation_0-logloss:0.23783	validation_1-logloss:0.24153
# [84]	validation_0-logloss:0.23769	validation_1-logloss:0.24142
# [85]	validation_0-logloss:0.23759	validation_1-logloss:0.24135
# [86]	validation_0-logloss:0.23750	validation_1-logloss:0.24130
# [87]	validation_0-logloss:0.23738	validation_1-logloss:0.24122
# [88]	validation_0-logloss:0.23730	validation_1-logloss:0.24118
# [89]	validation_0-logloss:0.23720	validation_1-logloss:0.24113
# [90]	validation_0-logloss:0.23710	validation_1-logloss:0.24108
# [91]	validation_0-logloss:0.23702	validation_1-logloss:0.24102
# [92]	validation_0-logloss:0.23697	validation_1-logloss:0.24100
# [93]	validation_0-logloss:0.23691	validation_1-logloss:0.24097
# [94]	validation_0-logloss:0.23681	validation_1-logloss:0.24092
# [95]	validation_0-logloss:0.23675	validation_1-logloss:0.24089
# [96]	validation_0-logloss:0.23668	validation_1-logloss:0.24084
# [97]	validation_0-logloss:0.23662	validation_1-logloss:0.24081
# [98]	validation_0-logloss:0.23656	validation_1-logloss:0.24078
# [99]	validation_0-logloss:0.23648	validation_1-logloss:0.24073
# [100]	validation_0-logloss:0.23642	validation_1-logloss:0.24071
# [101]	validation_0-logloss:0.23637	validation_1-logloss:0.24070
# [102]	validation_0-logloss:0.23631	validation_1-logloss:0.24067
# [103]	validation_0-logloss:0.23625	validation_1-logloss:0.24064
# [104]	validation_0-logloss:0.23619	validation_1-logloss:0.24063
# [105]	validation_0-logloss:0.23611	validation_1-logloss:0.24059
# [106]	validation_0-logloss:0.23605	validation_1-logloss:0.24057
# [107]	validation_0-logloss:0.23600	validation_1-logloss:0.24055
# [108]	validation_0-logloss:0.23596	validation_1-logloss:0.24054
# [109]	validation_0-logloss:0.23590	validation_1-logloss:0.24052
# [110]	validation_0-logloss:0.23586	validation_1-logloss:0.24051
# [111]	validation_0-logloss:0.23581	validation_1-logloss:0.24050
# [112]	validation_0-logloss:0.23577	validation_1-logloss:0.24049
# [113]	validation_0-logloss:0.23574	validation_1-logloss:0.24048
# [114]	validation_0-logloss:0.23569	validation_1-logloss:0.24047
# [115]	validation_0-logloss:0.23563	validation_1-logloss:0.24046
# [116]	validation_0-logloss:0.23557	validation_1-logloss:0.24044
# [117]	validation_0-logloss:0.23553	validation_1-logloss:0.24044
# [118]	validation_0-logloss:0.23548	validation_1-logloss:0.24042
# [119]	validation_0-logloss:0.23543	validation_1-logloss:0.24041
# [120]	validation_0-logloss:0.23540	validation_1-logloss:0.24040
# [121]	validation_0-logloss:0.23533	validation_1-logloss:0.24035
# [122]	validation_0-logloss:0.23529	validation_1-logloss:0.24036
# [123]	validation_0-logloss:0.23525	validation_1-logloss:0.24037
# [124]	validation_0-logloss:0.23522	validation_1-logloss:0.24036
# [125]	validation_0-logloss:0.23515	validation_1-logloss:0.24031
# [126]	validation_0-logloss:0.23511	validation_1-logloss:0.24030
# [127]	validation_0-logloss:0.23507	validation_1-logloss:0.24029
# [128]	validation_0-logloss:0.23503	validation_1-logloss:0.24029
# [129]	validation_0-logloss:0.23497	validation_1-logloss:0.24027
# [130]	validation_0-logloss:0.23493	validation_1-logloss:0.24026
# [131]	validation_0-logloss:0.23489	validation_1-logloss:0.24025
# [132]	validation_0-logloss:0.23486	validation_1-logloss:0.24025
# [133]	validation_0-logloss:0.23485	validation_1-logloss:0.24025
# [134]	validation_0-logloss:0.23481	validation_1-logloss:0.24025
# [135]	validation_0-logloss:0.23477	validation_1-logloss:0.24025
# [136]	validation_0-logloss:0.23472	validation_1-logloss:0.24025
# [137]	validation_0-logloss:0.23465	validation_1-logloss:0.24024
# [138]	validation_0-logloss:0.23463	validation_1-logloss:0.24023
# [139]	validation_0-logloss:0.23459	validation_1-logloss:0.24023
# [140]	validation_0-logloss:0.23454	validation_1-logloss:0.24021
# [141]	validation_0-logloss:0.23452	validation_1-logloss:0.24021
# [142]	validation_0-logloss:0.23447	validation_1-logloss:0.24020
# [143]	validation_0-logloss:0.23444	validation_1-logloss:0.24020
# [144]	validation_0-logloss:0.23440	validation_1-logloss:0.24020
# [145]	validation_0-logloss:0.23438	validation_1-logloss:0.24020
# [146]	validation_0-logloss:0.23435	validation_1-logloss:0.24020
# [147]	validation_0-logloss:0.23431	validation_1-logloss:0.24020
# [148]	validation_0-logloss:0.23430	validation_1-logloss:0.24020
# [149]	validation_0-logloss:0.23423	validation_1-logloss:0.24019
# [150]	validation_0-logloss:0.23418	validation_1-logloss:0.24019
# [151]	validation_0-logloss:0.23414	validation_1-logloss:0.24018
# [152]	validation_0-logloss:0.23412	validation_1-logloss:0.24019
# [153]	validation_0-logloss:0.23408	validation_1-logloss:0.24019
# [154]	validation_0-logloss:0.23404	validation_1-logloss:0.24017
# [155]	validation_0-logloss:0.23402	validation_1-logloss:0.24017
# [156]	validation_0-logloss:0.23400	validation_1-logloss:0.24017
# [157]	validation_0-logloss:0.23396	validation_1-logloss:0.24018
# [158]	validation_0-logloss:0.23392	validation_1-logloss:0.24018
# [159]	validation_0-logloss:0.23387	validation_1-logloss:0.24016
# [160]	validation_0-logloss:0.23385	validation_1-logloss:0.24016
# [161]	validation_0-logloss:0.23378	validation_1-logloss:0.24013
# [162]	validation_0-logloss:0.23374	validation_1-logloss:0.24013
# [163]	validation_0-logloss:0.23370	validation_1-logloss:0.24012
# [164]	validation_0-logloss:0.23369	validation_1-logloss:0.24012
# [165]	validation_0-logloss:0.23366	validation_1-logloss:0.24012
# [166]	validation_0-logloss:0.23362	validation_1-logloss:0.24012
# [167]	validation_0-logloss:0.23359	validation_1-logloss:0.24012
# [168]	validation_0-logloss:0.23358	validation_1-logloss:0.24011
# [169]	validation_0-logloss:0.23355	validation_1-logloss:0.24012
# [170]	validation_0-logloss:0.23352	validation_1-logloss:0.24012
# [171]	validation_0-logloss:0.23351	validation_1-logloss:0.24012
# [172]	validation_0-logloss:0.23346	validation_1-logloss:0.24012
# [173]	validation_0-logloss:0.23341	validation_1-logloss:0.24010
# [174]	validation_0-logloss:0.23339	validation_1-logloss:0.24010
# [175]	validation_0-logloss:0.23335	validation_1-logloss:0.24010
# [176]	validation_0-logloss:0.23330	validation_1-logloss:0.24009
# [177]	validation_0-logloss:0.23322	validation_1-logloss:0.24007
# [178]	validation_0-logloss:0.23320	validation_1-logloss:0.24007
# [179]	validation_0-logloss:0.23318	validation_1-logloss:0.24007
# [180]	validation_0-logloss:0.23314	validation_1-logloss:0.24007
# [181]	validation_0-logloss:0.23310	validation_1-logloss:0.24007
# [182]	validation_0-logloss:0.23303	validation_1-logloss:0.24007
# [183]	validation_0-logloss:0.23301	validation_1-logloss:0.24007
# [184]	validation_0-logloss:0.23299	validation_1-logloss:0.24007
# [185]	validation_0-logloss:0.23297	validation_1-logloss:0.24008
# [186]	validation_0-logloss:0.23295	validation_1-logloss:0.24008
# [187]	validation_0-logloss:0.23293	validation_1-logloss:0.24008
# [188]	validation_0-logloss:0.23290	validation_1-logloss:0.24008
# [189]	validation_0-logloss:0.23286	validation_1-logloss:0.24008
# [190]	validation_0-logloss:0.23280	validation_1-logloss:0.24005
# [191]	validation_0-logloss:0.23275	validation_1-logloss:0.24005
# [192]	validation_0-logloss:0.23271	validation_1-logloss:0.24006
# [193]	validation_0-logloss:0.23270	validation_1-logloss:0.24006
# [194]	validation_0-logloss:0.23266	validation_1-logloss:0.24007
# [195]	validation_0-logloss:0.23264	validation_1-logloss:0.24007
# [196]	validation_0-logloss:0.23261	validation_1-logloss:0.24006
# [197]	validation_0-logloss:0.23259	validation_1-logloss:0.24006
# [198]	validation_0-logloss:0.23255	validation_1-logloss:0.24007
# [199]	validation_0-logloss:0.23251	validation_1-logloss:0.24006
# [200]	validation_0-logloss:0.23247	validation_1-logloss:0.24007
# [201]	validation_0-logloss:0.23243	validation_1-logloss:0.24007
# [202]	validation_0-logloss:0.23241	validation_1-logloss:0.24006
# [203]	validation_0-logloss:0.23239	validation_1-logloss:0.24007
# [204]	validation_0-logloss:0.23236	validation_1-logloss:0.24008
# [205]	validation_0-logloss:0.23233	validation_1-logloss:0.24007
# [206]	validation_0-logloss:0.23231	validation_1-logloss:0.24008
# [207]	validation_0-logloss:0.23228	validation_1-logloss:0.24008
# [208]	validation_0-logloss:0.23225	validation_1-logloss:0.24008
# [209]	validation_0-logloss:0.23222	validation_1-logloss:0.24008
# [210]	validation_0-logloss:0.23219	validation_1-logloss:0.24008
# [211]	validation_0-logloss:0.23217	validation_1-logloss:0.24008
# [212]	validation_0-logloss:0.23216	validation_1-logloss:0.24008
# [213]	validation_0-logloss:0.23212	validation_1-logloss:0.24008
# [214]	validation_0-logloss:0.23209	validation_1-logloss:0.24008
# [215]	validation_0-logloss:0.23206	validation_1-logloss:0.24008
# [216]	validation_0-logloss:0.23203	validation_1-logloss:0.24008
# [217]	validation_0-logloss:0.23201	validation_1-logloss:0.24008
# [218]	validation_0-logloss:0.23199	validation_1-logloss:0.24008
# [219]	validation_0-logloss:0.23197	validation_1-logloss:0.24008
# [220]	validation_0-logloss:0.23195	validation_1-logloss:0.24008
# [221]	validation_0-logloss:0.23193	validation_1-logloss:0.24009
# [222]	validation_0-logloss:0.23190	validation_1-logloss:0.24009
# [223]	validation_0-logloss:0.23189	validation_1-logloss:0.24009
# [224]	validation_0-logloss:0.23183	validation_1-logloss:0.24007
# [225]	validation_0-logloss:0.23179	validation_1-logloss:0.24006
# [226]	validation_0-logloss:0.23175	validation_1-logloss:0.24007
# [227]	validation_0-logloss:0.23169	validation_1-logloss:0.24007
# [228]	validation_0-logloss:0.23167	validation_1-logloss:0.24007
# [229]	validation_0-logloss:0.23164	validation_1-logloss:0.24008
# [230]	validation_0-logloss:0.23159	validation_1-logloss:0.24005
# [231]	validation_0-logloss:0.23157	validation_1-logloss:0.24005
# [232]	validation_0-logloss:0.23154	validation_1-logloss:0.24005
# [233]	validation_0-logloss:0.23151	validation_1-logloss:0.24006
# [234]	validation_0-logloss:0.23147	validation_1-logloss:0.24007
# [235]	validation_0-logloss:0.23143	validation_1-logloss:0.24006
# [236]	validation_0-logloss:0.23142	validation_1-logloss:0.24006
# [237]	validation_0-logloss:0.23138	validation_1-logloss:0.24007
# [238]	validation_0-logloss:0.23136	validation_1-logloss:0.24007
# [239]	validation_0-logloss:0.23131	validation_1-logloss:0.24008
# [240]	validation_0-logloss:0.23128	validation_1-logloss:0.24008
# [241]	validation_0-logloss:0.23125	validation_1-logloss:0.24008
# [242]	validation_0-logloss:0.23122	validation_1-logloss:0.24008
# [243]	validation_0-logloss:0.23119	validation_1-logloss:0.24008
# [244]	validation_0-logloss:0.23117	validation_1-logloss:0.24008
# [245]	validation_0-logloss:0.23113	validation_1-logloss:0.24007
# [246]	validation_0-logloss:0.23111	validation_1-logloss:0.24007
# [247]	validation_0-logloss:0.23107	validation_1-logloss:0.24008
# [248]	validation_0-logloss:0.23104	validation_1-logloss:0.24008
# [249]	validation_0-logloss:0.23100	validation_1-logloss:0.24008
# [250]	validation_0-logloss:0.23099	validation_1-logloss:0.24008
# [251]	validation_0-logloss:0.23096	validation_1-logloss:0.24008
# [252]	validation_0-logloss:0.23095	validation_1-logloss:0.24008
# [253]	validation_0-logloss:0.23092	validation_1-logloss:0.24008
# [254]	validation_0-logloss:0.23087	validation_1-logloss:0.24007
# [255]	validation_0-logloss:0.23084	validation_1-logloss:0.24007
# [256]	validation_0-logloss:0.23083	validation_1-logloss:0.24007
# [257]	validation_0-logloss:0.23082	validation_1-logloss:0.24007
# [258]	validation_0-logloss:0.23079	validation_1-logloss:0.24007
# [259]	validation_0-logloss:0.23077	validation_1-logloss:0.24008
# [260]	validation_0-logloss:0.23075	validation_1-logloss:0.24008
# [261]	validation_0-logloss:0.23071	validation_1-logloss:0.24008
# [262]	validation_0-logloss:0.23069	validation_1-logloss:0.24008
# [263]	validation_0-logloss:0.23065	validation_1-logloss:0.24008
# [264]	validation_0-logloss:0.23063	validation_1-logloss:0.24008
# [265]	validation_0-logloss:0.23062	validation_1-logloss:0.24008
# [266]	validation_0-logloss:0.23058	validation_1-logloss:0.24008
# [267]	validation_0-logloss:0.23055	validation_1-logloss:0.24009
# [268]	validation_0-logloss:0.23052	validation_1-logloss:0.24009
# [269]	validation_0-logloss:0.23048	validation_1-logloss:0.24008
# [270]	validation_0-logloss:0.23044	validation_1-logloss:0.24008
# [271]	validation_0-logloss:0.23042	validation_1-logloss:0.24008
# [272]	validation_0-logloss:0.23039	validation_1-logloss:0.24008
# [273]	validation_0-logloss:0.23036	validation_1-logloss:0.24008
# [274]	validation_0-logloss:0.23034	validation_1-logloss:0.24008
# [275]	validation_0-logloss:0.23034	validation_1-logloss:0.24008
# [276]	validation_0-logloss:0.23030	validation_1-logloss:0.24008
# [277]	validation_0-logloss:0.23027	validation_1-logloss:0.24008
# [278]	validation_0-logloss:0.23025	validation_1-logloss:0.24008
# [279]	validation_0-logloss:0.23024	validation_1-logloss:0.24008
#  ########################################
#
# ML iteration  1
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [0]	validation_0-logloss:0.63517	validation_1-logloss:0.63530
# [1]	validation_0-logloss:0.58653	validation_1-logloss:0.58668
# [2]	validation_0-logloss:0.54605	validation_1-logloss:0.54614
# [3]	validation_0-logloss:0.51169	validation_1-logloss:0.51186
# [4]	validation_0-logloss:0.48272	validation_1-logloss:0.48290
# [5]	validation_0-logloss:0.45739	validation_1-logloss:0.45755
# [6]	validation_0-logloss:0.43510	validation_1-logloss:0.43536
# [7]	validation_0-logloss:0.41608	validation_1-logloss:0.41631
# [8]	validation_0-logloss:0.39919	validation_1-logloss:0.39941
# [9]	validation_0-logloss:0.38508	validation_1-logloss:0.38532
# [10]	validation_0-logloss:0.37176	validation_1-logloss:0.37212
# [11]	validation_0-logloss:0.36019	validation_1-logloss:0.36054
# [12]	validation_0-logloss:0.34982	validation_1-logloss:0.35024
# [13]	validation_0-logloss:0.34088	validation_1-logloss:0.34131
# [14]	validation_0-logloss:0.33296	validation_1-logloss:0.33333
# [15]	validation_0-logloss:0.32562	validation_1-logloss:0.32608
# [16]	validation_0-logloss:0.31880	validation_1-logloss:0.31932
# [17]	validation_0-logloss:0.31307	validation_1-logloss:0.31353
# [18]	validation_0-logloss:0.30780	validation_1-logloss:0.30834
# [19]	validation_0-logloss:0.30192	validation_1-logloss:0.30247
# [20]	validation_0-logloss:0.29769	validation_1-logloss:0.29828
# [21]	validation_0-logloss:0.29290	validation_1-logloss:0.29348
# [22]	validation_0-logloss:0.28943	validation_1-logloss:0.29000
# [23]	validation_0-logloss:0.28636	validation_1-logloss:0.28695
# [24]	validation_0-logloss:0.28273	validation_1-logloss:0.28335
# [25]	validation_0-logloss:0.28016	validation_1-logloss:0.28077
# [26]	validation_0-logloss:0.27760	validation_1-logloss:0.27817
# [27]	validation_0-logloss:0.27473	validation_1-logloss:0.27537
# [28]	validation_0-logloss:0.27237	validation_1-logloss:0.27301
# [29]	validation_0-logloss:0.27023	validation_1-logloss:0.27084
# [30]	validation_0-logloss:0.26849	validation_1-logloss:0.26917
# [31]	validation_0-logloss:0.26673	validation_1-logloss:0.26740
# [32]	validation_0-logloss:0.26499	validation_1-logloss:0.26564
# [33]	validation_0-logloss:0.26343	validation_1-logloss:0.26414
# [34]	validation_0-logloss:0.26179	validation_1-logloss:0.26248
# [35]	validation_0-logloss:0.26028	validation_1-logloss:0.26101
# [36]	validation_0-logloss:0.25896	validation_1-logloss:0.25974
# [37]	validation_0-logloss:0.25792	validation_1-logloss:0.25872
# [38]	validation_0-logloss:0.25658	validation_1-logloss:0.25740
# [39]	validation_0-logloss:0.25564	validation_1-logloss:0.25651
# [40]	validation_0-logloss:0.25473	validation_1-logloss:0.25561
# [41]	validation_0-logloss:0.25413	validation_1-logloss:0.25502
# [42]	validation_0-logloss:0.25337	validation_1-logloss:0.25432
# [43]	validation_0-logloss:0.25252	validation_1-logloss:0.25352
# [44]	validation_0-logloss:0.25170	validation_1-logloss:0.25270
# [45]	validation_0-logloss:0.25105	validation_1-logloss:0.25210
# [46]	validation_0-logloss:0.25048	validation_1-logloss:0.25156
# [47]	validation_0-logloss:0.24963	validation_1-logloss:0.25079
# [48]	validation_0-logloss:0.24893	validation_1-logloss:0.25014
# [49]	validation_0-logloss:0.24840	validation_1-logloss:0.24965
# [50]	validation_0-logloss:0.24776	validation_1-logloss:0.24904
# [51]	validation_0-logloss:0.24726	validation_1-logloss:0.24855
# [52]	validation_0-logloss:0.24682	validation_1-logloss:0.24815
# [53]	validation_0-logloss:0.24639	validation_1-logloss:0.24777
# [54]	validation_0-logloss:0.24594	validation_1-logloss:0.24733
# [55]	validation_0-logloss:0.24541	validation_1-logloss:0.24684
# [56]	validation_0-logloss:0.24504	validation_1-logloss:0.24653
# [57]	validation_0-logloss:0.24477	validation_1-logloss:0.24631
# [58]	validation_0-logloss:0.24441	validation_1-logloss:0.24599
# [59]	validation_0-logloss:0.24410	validation_1-logloss:0.24573
# [60]	validation_0-logloss:0.24386	validation_1-logloss:0.24550
# [61]	validation_0-logloss:0.24354	validation_1-logloss:0.24521
# [62]	validation_0-logloss:0.24310	validation_1-logloss:0.24482
# [63]	validation_0-logloss:0.24290	validation_1-logloss:0.24463
# [64]	validation_0-logloss:0.24264	validation_1-logloss:0.24440
# [65]	validation_0-logloss:0.24241	validation_1-logloss:0.24422
# [66]	validation_0-logloss:0.24224	validation_1-logloss:0.24408
# [67]	validation_0-logloss:0.24190	validation_1-logloss:0.24377
# [68]	validation_0-logloss:0.24168	validation_1-logloss:0.24359
# [69]	validation_0-logloss:0.24150	validation_1-logloss:0.24343
# [70]	validation_0-logloss:0.24131	validation_1-logloss:0.24328
# [71]	validation_0-logloss:0.24117	validation_1-logloss:0.24318
# [72]	validation_0-logloss:0.24098	validation_1-logloss:0.24301
# [73]	validation_0-logloss:0.24085	validation_1-logloss:0.24289
# [74]	validation_0-logloss:0.24071	validation_1-logloss:0.24278
# [75]	validation_0-logloss:0.24052	validation_1-logloss:0.24262
# [76]	validation_0-logloss:0.24031	validation_1-logloss:0.24245
# [77]	validation_0-logloss:0.24014	validation_1-logloss:0.24232
# [78]	validation_0-logloss:0.23996	validation_1-logloss:0.24217
# [79]	validation_0-logloss:0.23986	validation_1-logloss:0.24212
# [80]	validation_0-logloss:0.23976	validation_1-logloss:0.24203
# [81]	validation_0-logloss:0.23963	validation_1-logloss:0.24194
# [82]	validation_0-logloss:0.23954	validation_1-logloss:0.24188
# [83]	validation_0-logloss:0.23944	validation_1-logloss:0.24183
# [84]	validation_0-logloss:0.23926	validation_1-logloss:0.24169
# [85]	validation_0-logloss:0.23912	validation_1-logloss:0.24161
# [86]	validation_0-logloss:0.23904	validation_1-logloss:0.24157
# [87]	validation_0-logloss:0.23894	validation_1-logloss:0.24152
# [88]	validation_0-logloss:0.23887	validation_1-logloss:0.24147
# [89]	validation_0-logloss:0.23879	validation_1-logloss:0.24144
# [90]	validation_0-logloss:0.23872	validation_1-logloss:0.24142
# [91]	validation_0-logloss:0.23866	validation_1-logloss:0.24139
# [92]	validation_0-logloss:0.23859	validation_1-logloss:0.24135
# [93]	validation_0-logloss:0.23851	validation_1-logloss:0.24130
# [94]	validation_0-logloss:0.23842	validation_1-logloss:0.24127
# [95]	validation_0-logloss:0.23834	validation_1-logloss:0.24122
# [96]	validation_0-logloss:0.23825	validation_1-logloss:0.24117
# [97]	validation_0-logloss:0.23818	validation_1-logloss:0.24114
# [98]	validation_0-logloss:0.23811	validation_1-logloss:0.24110
# [99]	validation_0-logloss:0.23806	validation_1-logloss:0.24108
# [100]	validation_0-logloss:0.23797	validation_1-logloss:0.24104
# [101]	validation_0-logloss:0.23791	validation_1-logloss:0.24103
# [102]	validation_0-logloss:0.23788	validation_1-logloss:0.24101
# [103]	validation_0-logloss:0.23776	validation_1-logloss:0.24093
# [104]	validation_0-logloss:0.23771	validation_1-logloss:0.24091
# [105]	validation_0-logloss:0.23766	validation_1-logloss:0.24090
# [106]	validation_0-logloss:0.23759	validation_1-logloss:0.24088
# [107]	validation_0-logloss:0.23755	validation_1-logloss:0.24086
# [108]	validation_0-logloss:0.23747	validation_1-logloss:0.24084
# [109]	validation_0-logloss:0.23743	validation_1-logloss:0.24083
# [110]	validation_0-logloss:0.23735	validation_1-logloss:0.24079
# [111]	validation_0-logloss:0.23729	validation_1-logloss:0.24077
# [112]	validation_0-logloss:0.23724	validation_1-logloss:0.24077
# [113]	validation_0-logloss:0.23719	validation_1-logloss:0.24075
# [114]	validation_0-logloss:0.23714	validation_1-logloss:0.24074
# [115]	validation_0-logloss:0.23709	validation_1-logloss:0.24073
# [116]	validation_0-logloss:0.23702	validation_1-logloss:0.24070
# [117]	validation_0-logloss:0.23697	validation_1-logloss:0.24069
# [118]	validation_0-logloss:0.23692	validation_1-logloss:0.24068
# [119]	validation_0-logloss:0.23688	validation_1-logloss:0.24067
# [120]	validation_0-logloss:0.23681	validation_1-logloss:0.24065
# [121]	validation_0-logloss:0.23675	validation_1-logloss:0.24062
# [122]	validation_0-logloss:0.23672	validation_1-logloss:0.24061
# [123]	validation_0-logloss:0.23669	validation_1-logloss:0.24061
# [124]	validation_0-logloss:0.23665	validation_1-logloss:0.24060
# [125]	validation_0-logloss:0.23661	validation_1-logloss:0.24060
# [126]	validation_0-logloss:0.23656	validation_1-logloss:0.24057
# [127]	validation_0-logloss:0.23651	validation_1-logloss:0.24057
# [128]	validation_0-logloss:0.23647	validation_1-logloss:0.24055
# [129]	validation_0-logloss:0.23644	validation_1-logloss:0.24054
# [130]	validation_0-logloss:0.23641	validation_1-logloss:0.24053
# [131]	validation_0-logloss:0.23637	validation_1-logloss:0.24053
# [132]	validation_0-logloss:0.23633	validation_1-logloss:0.24052
# [133]	validation_0-logloss:0.23632	validation_1-logloss:0.24052
# [134]	validation_0-logloss:0.23629	validation_1-logloss:0.24052
# [135]	validation_0-logloss:0.23620	validation_1-logloss:0.24045
# [136]	validation_0-logloss:0.23617	validation_1-logloss:0.24045
# [137]	validation_0-logloss:0.23612	validation_1-logloss:0.24045
# [138]	validation_0-logloss:0.23608	validation_1-logloss:0.24045
# [139]	validation_0-logloss:0.23604	validation_1-logloss:0.24044
# [140]	validation_0-logloss:0.23599	validation_1-logloss:0.24043
# [141]	validation_0-logloss:0.23595	validation_1-logloss:0.24043
# [142]	validation_0-logloss:0.23591	validation_1-logloss:0.24041
# [143]	validation_0-logloss:0.23588	validation_1-logloss:0.24041
# [144]	validation_0-logloss:0.23585	validation_1-logloss:0.24040
# [145]	validation_0-logloss:0.23583	validation_1-logloss:0.24040
# [146]	validation_0-logloss:0.23580	validation_1-logloss:0.24040
# [147]	validation_0-logloss:0.23578	validation_1-logloss:0.24040
# [148]	validation_0-logloss:0.23574	validation_1-logloss:0.24039
# [149]	validation_0-logloss:0.23568	validation_1-logloss:0.24038
# [150]	validation_0-logloss:0.23563	validation_1-logloss:0.24038
# [151]	validation_0-logloss:0.23558	validation_1-logloss:0.24038
# [152]	validation_0-logloss:0.23555	validation_1-logloss:0.24038
# [153]	validation_0-logloss:0.23552	validation_1-logloss:0.24038
# [154]	validation_0-logloss:0.23544	validation_1-logloss:0.24033
# [155]	validation_0-logloss:0.23540	validation_1-logloss:0.24032
# [156]	validation_0-logloss:0.23538	validation_1-logloss:0.24032
# [157]	validation_0-logloss:0.23533	validation_1-logloss:0.24032
# [158]	validation_0-logloss:0.23529	validation_1-logloss:0.24031
# [159]	validation_0-logloss:0.23527	validation_1-logloss:0.24031
# [160]	validation_0-logloss:0.23523	validation_1-logloss:0.24030
# [161]	validation_0-logloss:0.23519	validation_1-logloss:0.24031
# [162]	validation_0-logloss:0.23516	validation_1-logloss:0.24031
# [163]	validation_0-logloss:0.23513	validation_1-logloss:0.24031
# [164]	validation_0-logloss:0.23508	validation_1-logloss:0.24031
# [165]	validation_0-logloss:0.23506	validation_1-logloss:0.24031
# [166]	validation_0-logloss:0.23503	validation_1-logloss:0.24030
# [167]	validation_0-logloss:0.23500	validation_1-logloss:0.24030
# [168]	validation_0-logloss:0.23497	validation_1-logloss:0.24030
# [169]	validation_0-logloss:0.23493	validation_1-logloss:0.24029
# [170]	validation_0-logloss:0.23489	validation_1-logloss:0.24029
# [171]	validation_0-logloss:0.23485	validation_1-logloss:0.24029
# [172]	validation_0-logloss:0.23482	validation_1-logloss:0.24028
# [173]	validation_0-logloss:0.23477	validation_1-logloss:0.24029
# [174]	validation_0-logloss:0.23472	validation_1-logloss:0.24029
# [175]	validation_0-logloss:0.23466	validation_1-logloss:0.24028
# [176]	validation_0-logloss:0.23463	validation_1-logloss:0.24029
# [177]	validation_0-logloss:0.23458	validation_1-logloss:0.24029
# [178]	validation_0-logloss:0.23455	validation_1-logloss:0.24030
# [179]	validation_0-logloss:0.23452	validation_1-logloss:0.24030
# [180]	validation_0-logloss:0.23448	validation_1-logloss:0.24030
# [181]	validation_0-logloss:0.23446	validation_1-logloss:0.24030
# [182]	validation_0-logloss:0.23442	validation_1-logloss:0.24030
# [183]	validation_0-logloss:0.23440	validation_1-logloss:0.24030
# [184]	validation_0-logloss:0.23435	validation_1-logloss:0.24030
# [185]	validation_0-logloss:0.23432	validation_1-logloss:0.24029
# [186]	validation_0-logloss:0.23429	validation_1-logloss:0.24029
# [187]	validation_0-logloss:0.23427	validation_1-logloss:0.24028
# [188]	validation_0-logloss:0.23426	validation_1-logloss:0.24028
# [189]	validation_0-logloss:0.23423	validation_1-logloss:0.24028
# [190]	validation_0-logloss:0.23420	validation_1-logloss:0.24029
# [191]	validation_0-logloss:0.23417	validation_1-logloss:0.24029
# [192]	validation_0-logloss:0.23415	validation_1-logloss:0.24028
# [193]	validation_0-logloss:0.23412	validation_1-logloss:0.24029
# [194]	validation_0-logloss:0.23408	validation_1-logloss:0.24029
# [195]	validation_0-logloss:0.23407	validation_1-logloss:0.24029
# [196]	validation_0-logloss:0.23403	validation_1-logloss:0.24029
# [197]	validation_0-logloss:0.23400	validation_1-logloss:0.24029
# [198]	validation_0-logloss:0.23397	validation_1-logloss:0.24029
# [199]	validation_0-logloss:0.23394	validation_1-logloss:0.24030
# [200]	validation_0-logloss:0.23393	validation_1-logloss:0.24029
# [201]	validation_0-logloss:0.23388	validation_1-logloss:0.24029
# [202]	validation_0-logloss:0.23386	validation_1-logloss:0.24029
# [203]	validation_0-logloss:0.23383	validation_1-logloss:0.24029
# [204]	validation_0-logloss:0.23381	validation_1-logloss:0.24029
# [205]	validation_0-logloss:0.23377	validation_1-logloss:0.24028
# [206]	validation_0-logloss:0.23375	validation_1-logloss:0.24029
# [207]	validation_0-logloss:0.23372	validation_1-logloss:0.24029
# [208]	validation_0-logloss:0.23369	validation_1-logloss:0.24029
# [209]	validation_0-logloss:0.23367	validation_1-logloss:0.24030
# [210]	validation_0-logloss:0.23362	validation_1-logloss:0.24027
# [211]	validation_0-logloss:0.23358	validation_1-logloss:0.24027
# [212]	validation_0-logloss:0.23355	validation_1-logloss:0.24027
# [213]	validation_0-logloss:0.23353	validation_1-logloss:0.24027
# [214]	validation_0-logloss:0.23349	validation_1-logloss:0.24027
# [215]	validation_0-logloss:0.23346	validation_1-logloss:0.24027
# [216]	validation_0-logloss:0.23341	validation_1-logloss:0.24027
# [217]	validation_0-logloss:0.23335	validation_1-logloss:0.24025
# [218]	validation_0-logloss:0.23333	validation_1-logloss:0.24025
# [219]	validation_0-logloss:0.23330	validation_1-logloss:0.24024
# [220]	validation_0-logloss:0.23328	validation_1-logloss:0.24024
# [221]	validation_0-logloss:0.23322	validation_1-logloss:0.24023
# [222]	validation_0-logloss:0.23319	validation_1-logloss:0.24023
# [223]	validation_0-logloss:0.23316	validation_1-logloss:0.24023
# [224]	validation_0-logloss:0.23314	validation_1-logloss:0.24024
# [225]	validation_0-logloss:0.23312	validation_1-logloss:0.24024
# [226]	validation_0-logloss:0.23311	validation_1-logloss:0.24023
# [227]	validation_0-logloss:0.23309	validation_1-logloss:0.24023
# [228]	validation_0-logloss:0.23306	validation_1-logloss:0.24023
# [229]	validation_0-logloss:0.23302	validation_1-logloss:0.24023
# [230]	validation_0-logloss:0.23300	validation_1-logloss:0.24024
# [231]	validation_0-logloss:0.23298	validation_1-logloss:0.24024
# [232]	validation_0-logloss:0.23295	validation_1-logloss:0.24023
# [233]	validation_0-logloss:0.23291	validation_1-logloss:0.24023
# [234]	validation_0-logloss:0.23285	validation_1-logloss:0.24021
# [235]	validation_0-logloss:0.23283	validation_1-logloss:0.24021
# [236]	validation_0-logloss:0.23281	validation_1-logloss:0.24021
# [237]	validation_0-logloss:0.23279	validation_1-logloss:0.24021
# [238]	validation_0-logloss:0.23276	validation_1-logloss:0.24022
# [239]	validation_0-logloss:0.23273	validation_1-logloss:0.24021
# [240]	validation_0-logloss:0.23271	validation_1-logloss:0.24021
# [241]	validation_0-logloss:0.23268	validation_1-logloss:0.24020
# [242]	validation_0-logloss:0.23266	validation_1-logloss:0.24020
# [243]	validation_0-logloss:0.23266	validation_1-logloss:0.24020
# [244]	validation_0-logloss:0.23264	validation_1-logloss:0.24020
# [245]	validation_0-logloss:0.23260	validation_1-logloss:0.24019
# [246]	validation_0-logloss:0.23256	validation_1-logloss:0.24020
# [247]	validation_0-logloss:0.23251	validation_1-logloss:0.24021
# [248]	validation_0-logloss:0.23248	validation_1-logloss:0.24021
# [249]	validation_0-logloss:0.23246	validation_1-logloss:0.24021
# [250]	validation_0-logloss:0.23242	validation_1-logloss:0.24021
# [251]	validation_0-logloss:0.23237	validation_1-logloss:0.24019
# [252]	validation_0-logloss:0.23232	validation_1-logloss:0.24018
# [253]	validation_0-logloss:0.23230	validation_1-logloss:0.24019
# [254]	validation_0-logloss:0.23227	validation_1-logloss:0.24019
# [255]	validation_0-logloss:0.23225	validation_1-logloss:0.24020
# [256]	validation_0-logloss:0.23222	validation_1-logloss:0.24020
# [257]	validation_0-logloss:0.23220	validation_1-logloss:0.24020
# [258]	validation_0-logloss:0.23216	validation_1-logloss:0.24021
# [259]	validation_0-logloss:0.23215	validation_1-logloss:0.24021
# [260]	validation_0-logloss:0.23213	validation_1-logloss:0.24021
# [261]	validation_0-logloss:0.23210	validation_1-logloss:0.24022
# [262]	validation_0-logloss:0.23205	validation_1-logloss:0.24021
# [263]	validation_0-logloss:0.23200	validation_1-logloss:0.24021
# [264]	validation_0-logloss:0.23197	validation_1-logloss:0.24020
# [265]	validation_0-logloss:0.23195	validation_1-logloss:0.24020
# [266]	validation_0-logloss:0.23194	validation_1-logloss:0.24021
# [267]	validation_0-logloss:0.23190	validation_1-logloss:0.24019
# [268]	validation_0-logloss:0.23187	validation_1-logloss:0.24019
# [269]	validation_0-logloss:0.23181	validation_1-logloss:0.24017
# [270]	validation_0-logloss:0.23178	validation_1-logloss:0.24018
# [271]	validation_0-logloss:0.23177	validation_1-logloss:0.24018
# [272]	validation_0-logloss:0.23175	validation_1-logloss:0.24017
# [273]	validation_0-logloss:0.23171	validation_1-logloss:0.24017
# [274]	validation_0-logloss:0.23167	validation_1-logloss:0.24017
# [275]	validation_0-logloss:0.23164	validation_1-logloss:0.24017
# [276]	validation_0-logloss:0.23162	validation_1-logloss:0.24018
# [277]	validation_0-logloss:0.23161	validation_1-logloss:0.24017
# [278]	validation_0-logloss:0.23157	validation_1-logloss:0.24017
# [279]	validation_0-logloss:0.23156	validation_1-logloss:0.24017
# [280]	validation_0-logloss:0.23154	validation_1-logloss:0.24017
# [281]	validation_0-logloss:0.23151	validation_1-logloss:0.24018
# [282]	validation_0-logloss:0.23150	validation_1-logloss:0.24017
# [283]	validation_0-logloss:0.23149	validation_1-logloss:0.24018
# [284]	validation_0-logloss:0.23146	validation_1-logloss:0.24018
# [285]	validation_0-logloss:0.23144	validation_1-logloss:0.24019
# [286]	validation_0-logloss:0.23143	validation_1-logloss:0.24019
# [287]	validation_0-logloss:0.23140	validation_1-logloss:0.24020
# [288]	validation_0-logloss:0.23136	validation_1-logloss:0.24020
# [289]	validation_0-logloss:0.23133	validation_1-logloss:0.24020
# [290]	validation_0-logloss:0.23130	validation_1-logloss:0.24020
# [291]	validation_0-logloss:0.23126	validation_1-logloss:0.24021
# [292]	validation_0-logloss:0.23123	validation_1-logloss:0.24021
# [293]	validation_0-logloss:0.23120	validation_1-logloss:0.24021
# [294]	validation_0-logloss:0.23117	validation_1-logloss:0.24021
# [295]	validation_0-logloss:0.23112	validation_1-logloss:0.24020
# [296]	validation_0-logloss:0.23109	validation_1-logloss:0.24021
# [297]	validation_0-logloss:0.23107	validation_1-logloss:0.24020
# [298]	validation_0-logloss:0.23104	validation_1-logloss:0.24021
# [299]	validation_0-logloss:0.23102	validation_1-logloss:0.24021
# [300]	validation_0-logloss:0.23100	validation_1-logloss:0.24021
# [301]	validation_0-logloss:0.23100	validation_1-logloss:0.24021
# [302]	validation_0-logloss:0.23099	validation_1-logloss:0.24021
# [303]	validation_0-logloss:0.23096	validation_1-logloss:0.24022
# [304]	validation_0-logloss:0.23092	validation_1-logloss:0.24023
# [305]	validation_0-logloss:0.23089	validation_1-logloss:0.24023
# [306]	validation_0-logloss:0.23087	validation_1-logloss:0.24023
# [307]	validation_0-logloss:0.23084	validation_1-logloss:0.24023
# [308]	validation_0-logloss:0.23081	validation_1-logloss:0.24023
# [309]	validation_0-logloss:0.23079	validation_1-logloss:0.24023
# [310]	validation_0-logloss:0.23076	validation_1-logloss:0.24024
# [311]	validation_0-logloss:0.23074	validation_1-logloss:0.24024
# [312]	validation_0-logloss:0.23072	validation_1-logloss:0.24023
# [313]	validation_0-logloss:0.23068	validation_1-logloss:0.24023
# [314]	validation_0-logloss:0.23064	validation_1-logloss:0.24022
# [315]	validation_0-logloss:0.23062	validation_1-logloss:0.24023
# [316]	validation_0-logloss:0.23060	validation_1-logloss:0.24022
# [317]	validation_0-logloss:0.23056	validation_1-logloss:0.24023
# [318]	validation_0-logloss:0.23056	validation_1-logloss:0.24023
# [319]	validation_0-logloss:0.23054	validation_1-logloss:0.24023
# [320]	validation_0-logloss:0.23053	validation_1-logloss:0.24023
# [321]	validation_0-logloss:0.23050	validation_1-logloss:0.24023
# [322]	validation_0-logloss:0.23046	validation_1-logloss:0.24023
# [323]	validation_0-logloss:0.23044	validation_1-logloss:0.24023
# [324]	validation_0-logloss:0.23039	validation_1-logloss:0.24023
# [325]	validation_0-logloss:0.23036	validation_1-logloss:0.24023
# [326]	validation_0-logloss:0.23032	validation_1-logloss:0.24024
# [327]	validation_0-logloss:0.23029	validation_1-logloss:0.24023
# [328]	validation_0-logloss:0.23024	validation_1-logloss:0.24022
#  ########################################
#
# ML iteration  2
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [0]	validation_0-logloss:0.63556	validation_1-logloss:0.63533
# [1]	validation_0-logloss:0.58660	validation_1-logloss:0.58677
# [2]	validation_0-logloss:0.54631	validation_1-logloss:0.54646
# [3]	validation_0-logloss:0.51240	validation_1-logloss:0.51238
# [4]	validation_0-logloss:0.48286	validation_1-logloss:0.48300
# [5]	validation_0-logloss:0.45745	validation_1-logloss:0.45757
# [6]	validation_0-logloss:0.43516	validation_1-logloss:0.43528
# [7]	validation_0-logloss:0.41640	validation_1-logloss:0.41652
# [8]	validation_0-logloss:0.39908	validation_1-logloss:0.39934
# [9]	validation_0-logloss:0.38423	validation_1-logloss:0.38446
# [10]	validation_0-logloss:0.37144	validation_1-logloss:0.37169
# [11]	validation_0-logloss:0.35982	validation_1-logloss:0.36010
# [12]	validation_0-logloss:0.34946	validation_1-logloss:0.34980
# [13]	validation_0-logloss:0.34061	validation_1-logloss:0.34096
# [14]	validation_0-logloss:0.33270	validation_1-logloss:0.33301
# [15]	validation_0-logloss:0.32507	validation_1-logloss:0.32548
# [16]	validation_0-logloss:0.31839	validation_1-logloss:0.31887
# [17]	validation_0-logloss:0.31260	validation_1-logloss:0.31307
# [18]	validation_0-logloss:0.30710	validation_1-logloss:0.30766
# [19]	validation_0-logloss:0.30125	validation_1-logloss:0.30175
# [20]	validation_0-logloss:0.29698	validation_1-logloss:0.29751
# [21]	validation_0-logloss:0.29326	validation_1-logloss:0.29379
# [22]	validation_0-logloss:0.28954	validation_1-logloss:0.29011
# [23]	validation_0-logloss:0.28531	validation_1-logloss:0.28591
# [24]	validation_0-logloss:0.28258	validation_1-logloss:0.28322
# [25]	validation_0-logloss:0.27983	validation_1-logloss:0.28050
# [26]	validation_0-logloss:0.27769	validation_1-logloss:0.27838
# [27]	validation_0-logloss:0.27474	validation_1-logloss:0.27548
# [28]	validation_0-logloss:0.27221	validation_1-logloss:0.27298
# [29]	validation_0-logloss:0.26982	validation_1-logloss:0.27055
# [30]	validation_0-logloss:0.26750	validation_1-logloss:0.26828
# [31]	validation_0-logloss:0.26610	validation_1-logloss:0.26692
# [32]	validation_0-logloss:0.26461	validation_1-logloss:0.26548
# [33]	validation_0-logloss:0.26289	validation_1-logloss:0.26371
# [34]	validation_0-logloss:0.26127	validation_1-logloss:0.26208
# [35]	validation_0-logloss:0.26004	validation_1-logloss:0.26091
# [36]	validation_0-logloss:0.25916	validation_1-logloss:0.26003
# [37]	validation_0-logloss:0.25800	validation_1-logloss:0.25889
# [38]	validation_0-logloss:0.25666	validation_1-logloss:0.25760
# [39]	validation_0-logloss:0.25565	validation_1-logloss:0.25661
# [40]	validation_0-logloss:0.25494	validation_1-logloss:0.25595
# [41]	validation_0-logloss:0.25400	validation_1-logloss:0.25503
# [42]	validation_0-logloss:0.25335	validation_1-logloss:0.25443
# [43]	validation_0-logloss:0.25274	validation_1-logloss:0.25386
# [44]	validation_0-logloss:0.25195	validation_1-logloss:0.25309
# [45]	validation_0-logloss:0.25117	validation_1-logloss:0.25238
# [46]	validation_0-logloss:0.25053	validation_1-logloss:0.25175
# [47]	validation_0-logloss:0.24987	validation_1-logloss:0.25113
# [48]	validation_0-logloss:0.24921	validation_1-logloss:0.25050
# [49]	validation_0-logloss:0.24860	validation_1-logloss:0.24991
# [50]	validation_0-logloss:0.24796	validation_1-logloss:0.24928
# [51]	validation_0-logloss:0.24752	validation_1-logloss:0.24887
# [52]	validation_0-logloss:0.24700	validation_1-logloss:0.24838
# [53]	validation_0-logloss:0.24635	validation_1-logloss:0.24773
# [54]	validation_0-logloss:0.24585	validation_1-logloss:0.24726
# [55]	validation_0-logloss:0.24540	validation_1-logloss:0.24684
# [56]	validation_0-logloss:0.24501	validation_1-logloss:0.24649
# [57]	validation_0-logloss:0.24469	validation_1-logloss:0.24621
# [58]	validation_0-logloss:0.24437	validation_1-logloss:0.24594
# [59]	validation_0-logloss:0.24394	validation_1-logloss:0.24557
# [60]	validation_0-logloss:0.24365	validation_1-logloss:0.24530
# [61]	validation_0-logloss:0.24330	validation_1-logloss:0.24497
# [62]	validation_0-logloss:0.24295	validation_1-logloss:0.24465
# [63]	validation_0-logloss:0.24269	validation_1-logloss:0.24445
# [64]	validation_0-logloss:0.24246	validation_1-logloss:0.24425
# [65]	validation_0-logloss:0.24219	validation_1-logloss:0.24402
# [66]	validation_0-logloss:0.24196	validation_1-logloss:0.24384
# [67]	validation_0-logloss:0.24180	validation_1-logloss:0.24372
# [68]	validation_0-logloss:0.24158	validation_1-logloss:0.24353
# [69]	validation_0-logloss:0.24138	validation_1-logloss:0.24336
# [70]	validation_0-logloss:0.24112	validation_1-logloss:0.24313
# [71]	validation_0-logloss:0.24102	validation_1-logloss:0.24305
# [72]	validation_0-logloss:0.24080	validation_1-logloss:0.24288
# [73]	validation_0-logloss:0.24063	validation_1-logloss:0.24276
# [74]	validation_0-logloss:0.24049	validation_1-logloss:0.24267
# [75]	validation_0-logloss:0.24035	validation_1-logloss:0.24256
# [76]	validation_0-logloss:0.24018	validation_1-logloss:0.24243
# [77]	validation_0-logloss:0.24009	validation_1-logloss:0.24235
# [78]	validation_0-logloss:0.23996	validation_1-logloss:0.24226
# [79]	validation_0-logloss:0.23980	validation_1-logloss:0.24213
# [80]	validation_0-logloss:0.23974	validation_1-logloss:0.24209
# [81]	validation_0-logloss:0.23961	validation_1-logloss:0.24200
# [82]	validation_0-logloss:0.23944	validation_1-logloss:0.24187
# [83]	validation_0-logloss:0.23931	validation_1-logloss:0.24179
# [84]	validation_0-logloss:0.23924	validation_1-logloss:0.24174
# [85]	validation_0-logloss:0.23913	validation_1-logloss:0.24165
# [86]	validation_0-logloss:0.23906	validation_1-logloss:0.24161
# [87]	validation_0-logloss:0.23892	validation_1-logloss:0.24150
# [88]	validation_0-logloss:0.23883	validation_1-logloss:0.24145
# [89]	validation_0-logloss:0.23876	validation_1-logloss:0.24140
# [90]	validation_0-logloss:0.23867	validation_1-logloss:0.24135
# [91]	validation_0-logloss:0.23857	validation_1-logloss:0.24128
# [92]	validation_0-logloss:0.23847	validation_1-logloss:0.24122
# [93]	validation_0-logloss:0.23839	validation_1-logloss:0.24119
# [94]	validation_0-logloss:0.23834	validation_1-logloss:0.24116
# [95]	validation_0-logloss:0.23826	validation_1-logloss:0.24111
# [96]	validation_0-logloss:0.23818	validation_1-logloss:0.24106
# [97]	validation_0-logloss:0.23810	validation_1-logloss:0.24101
# [98]	validation_0-logloss:0.23803	validation_1-logloss:0.24099
# [99]	validation_0-logloss:0.23794	validation_1-logloss:0.24093
# [100]	validation_0-logloss:0.23788	validation_1-logloss:0.24090
# [101]	validation_0-logloss:0.23782	validation_1-logloss:0.24088
# [102]	validation_0-logloss:0.23775	validation_1-logloss:0.24084
# [103]	validation_0-logloss:0.23770	validation_1-logloss:0.24082
# [104]	validation_0-logloss:0.23764	validation_1-logloss:0.24079
# [105]	validation_0-logloss:0.23756	validation_1-logloss:0.24075
# [106]	validation_0-logloss:0.23748	validation_1-logloss:0.24072
# [107]	validation_0-logloss:0.23745	validation_1-logloss:0.24070
# [108]	validation_0-logloss:0.23738	validation_1-logloss:0.24065
# ...
# [74]	validation_0-logloss:0.24083	validation_1-logloss:0.24273
# [75]	validation_0-logloss:0.24071	validation_1-logloss:0.24263
# [76]	validation_0-logloss:0.24054	validation_1-logloss:0.24251
# [77]	validation_0-logloss:0.24040	validation_1-logloss:0.24240
# [78]	validation_0-logloss:0.24025	validation_1-logloss:0.24228
# [79]	validation_0-logloss:0.24012	validation_1-logloss:0.24218
# [80]	validation_0-logloss:0.24000	validation_1-logloss:0.24210
# [81]	validation_0-logloss:0.23989	validation_1-logloss:0.24201
# [82]	validation_0-logloss:0.23973	validation_1-logloss:0.24188
# [83]	validation_0-logloss:0.23964	validation_1-logloss:0.24182
# [84]	validation_0-logloss:0.23953	validation_1-logloss:0.24178
# [85]	validation_0-logloss:0.23942	validation_1-logloss:0.24171
# [86]	validation_0-logloss:0.23935	validation_1-logloss:0.24167
# [87]	validation_0-logloss:0.23927	validation_1-logloss:0.24162
# [88]	validation_0-logloss:0.23920	validation_1-logloss:0.24158
# [89]	validation_0-logloss:0.23911	validation_1-logloss:0.24150
# [90]	validation_0-logloss:0.23903	validation_1-logloss:0.24147
# [91]	validation_0-logloss:0.23894	validation_1-logloss:0.24141
# [92]	validation_0-logloss:0.23887	validation_1-logloss:0.24137
# [93]	validation_0-logloss:0.23877	validation_1-logloss:0.24131
# [94]	validation_0-logloss:0.23868	validation_1-logloss:0.24126
# [95]	validation_0-logloss:0.23861	validation_1-logloss:0.24122
# [96]	validation_0-logloss:0.23851	validation_1-logloss:0.24115
# [97]	validation_0-logloss:0.23846	validation_1-logloss:0.24113
# [98]	validation_0-logloss:0.23839	validation_1-logloss:0.24109
# [99]	validation_0-logloss:0.23834	validation_1-logloss:0.24107
# [100]	validation_0-logloss:0.23827	validation_1-logloss:0.24102
# [101]	validation_0-logloss:0.23819	validation_1-logloss:0.24098
# [102]	validation_0-logloss:0.23813	validation_1-logloss:0.24097
# [103]	validation_0-logloss:0.23808	validation_1-logloss:0.24096
# [104]	validation_0-logloss:0.23802	validation_1-logloss:0.24092
# [105]	validation_0-logloss:0.23797	validation_1-logloss:0.24090
# [106]	validation_0-logloss:0.23793	validation_1-logloss:0.24089
# [107]	validation_0-logloss:0.23789	validation_1-logloss:0.24088
# [108]	validation_0-logloss:0.23780	validation_1-logloss:0.24082
# [109]	validation_0-logloss:0.23776	validation_1-logloss:0.24080
# [110]	validation_0-logloss:0.23766	validation_1-logloss:0.24074
# [111]	validation_0-logloss:0.23760	validation_1-logloss:0.24071
# [112]	validation_0-logloss:0.23755	validation_1-logloss:0.24069
# [113]	validation_0-logloss:0.23748	validation_1-logloss:0.24064
# [114]	validation_0-logloss:0.23744	validation_1-logloss:0.24064
# [115]	validation_0-logloss:0.23741	validation_1-logloss:0.24064
# [116]	validation_0-logloss:0.23738	validation_1-logloss:0.24062
# [117]	validation_0-logloss:0.23732	validation_1-logloss:0.24063
# [118]	validation_0-logloss:0.23729	validation_1-logloss:0.24061
# [119]	validation_0-logloss:0.23725	validation_1-logloss:0.24061
# [120]	validation_0-logloss:0.23722	validation_1-logloss:0.24061
# [121]	validation_0-logloss:0.23715	validation_1-logloss:0.24058
# [122]	validation_0-logloss:0.23710	validation_1-logloss:0.24057
# [123]	validation_0-logloss:0.23707	validation_1-logloss:0.24057
# [124]	validation_0-logloss:0.23700	validation_1-logloss:0.24056
# [125]	validation_0-logloss:0.23698	validation_1-logloss:0.24057
# [126]	validation_0-logloss:0.23694	validation_1-logloss:0.24057
# [127]	validation_0-logloss:0.23692	validation_1-logloss:0.24057
# [128]	validation_0-logloss:0.23687	validation_1-logloss:0.24056
# [129]	validation_0-logloss:0.23685	validation_1-logloss:0.24056
# [130]	validation_0-logloss:0.23680	validation_1-logloss:0.24056
# [131]	validation_0-logloss:0.23677	validation_1-logloss:0.24055
# [132]	validation_0-logloss:0.23673	validation_1-logloss:0.24055
# [133]	validation_0-logloss:0.23668	validation_1-logloss:0.24054
# [134]	validation_0-logloss:0.23664	validation_1-logloss:0.24052
# [135]	validation_0-logloss:0.23656	validation_1-logloss:0.24047
# [136]	validation_0-logloss:0.23654	validation_1-logloss:0.24047
# [137]	validation_0-logloss:0.23650	validation_1-logloss:0.24046
# [138]	validation_0-logloss:0.23648	validation_1-logloss:0.24046
# [139]	validation_0-logloss:0.23645	validation_1-logloss:0.24047
# [140]	validation_0-logloss:0.23640	validation_1-logloss:0.24045
# [141]	validation_0-logloss:0.23633	validation_1-logloss:0.24044
# [142]	validation_0-logloss:0.23625	validation_1-logloss:0.24041
# [143]	validation_0-logloss:0.23622	validation_1-logloss:0.24041
# [144]	validation_0-logloss:0.23616	validation_1-logloss:0.24040
# [145]	validation_0-logloss:0.23614	validation_1-logloss:0.24039
# [146]	validation_0-logloss:0.23613	validation_1-logloss:0.24040
# [147]	validation_0-logloss:0.23608	validation_1-logloss:0.24040
# [148]	validation_0-logloss:0.23603	validation_1-logloss:0.24041
# [149]	validation_0-logloss:0.23596	validation_1-logloss:0.24038
# [150]	validation_0-logloss:0.23595	validation_1-logloss:0.24038
# [151]	validation_0-logloss:0.23592	validation_1-logloss:0.24038
# [152]	validation_0-logloss:0.23587	validation_1-logloss:0.24038
# [153]	validation_0-logloss:0.23585	validation_1-logloss:0.24038
# [154]	validation_0-logloss:0.23582	validation_1-logloss:0.24038
# [155]	validation_0-logloss:0.23578	validation_1-logloss:0.24037
# [156]	validation_0-logloss:0.23575	validation_1-logloss:0.24037
# [157]	validation_0-logloss:0.23573	validation_1-logloss:0.24036
# [158]	validation_0-logloss:0.23570	validation_1-logloss:0.24036
# [159]	validation_0-logloss:0.23566	validation_1-logloss:0.24037
# [160]	validation_0-logloss:0.23560	validation_1-logloss:0.24034
# [161]	validation_0-logloss:0.23556	validation_1-logloss:0.24033
# [162]	validation_0-logloss:0.23552	validation_1-logloss:0.24033
# [163]	validation_0-logloss:0.23547	validation_1-logloss:0.24034
# [164]	validation_0-logloss:0.23542	validation_1-logloss:0.24033
# [165]	validation_0-logloss:0.23540	validation_1-logloss:0.24033
# [166]	validation_0-logloss:0.23537	validation_1-logloss:0.24033
# [167]	validation_0-logloss:0.23536	validation_1-logloss:0.24033
# [168]	validation_0-logloss:0.23533	validation_1-logloss:0.24033
# [169]	validation_0-logloss:0.23531	validation_1-logloss:0.24033
# [170]	validation_0-logloss:0.23530	validation_1-logloss:0.24034
# [171]	validation_0-logloss:0.23527	validation_1-logloss:0.24033
# [172]	validation_0-logloss:0.23522	validation_1-logloss:0.24034
# [173]	validation_0-logloss:0.23517	validation_1-logloss:0.24033
# [174]	validation_0-logloss:0.23513	validation_1-logloss:0.24033
# [175]	validation_0-logloss:0.23510	validation_1-logloss:0.24033
# [176]	validation_0-logloss:0.23508	validation_1-logloss:0.24033
# [177]	validation_0-logloss:0.23504	validation_1-logloss:0.24033
# [178]	validation_0-logloss:0.23500	validation_1-logloss:0.24033
# [179]	validation_0-logloss:0.23497	validation_1-logloss:0.24034
# [180]	validation_0-logloss:0.23490	validation_1-logloss:0.24031
# [181]	validation_0-logloss:0.23488	validation_1-logloss:0.24031
# [182]	validation_0-logloss:0.23485	validation_1-logloss:0.24030
# [183]	validation_0-logloss:0.23479	validation_1-logloss:0.24029
# [184]	validation_0-logloss:0.23472	validation_1-logloss:0.24027
# [185]	validation_0-logloss:0.23471	validation_1-logloss:0.24027
# [186]	validation_0-logloss:0.23468	validation_1-logloss:0.24027
# [187]	validation_0-logloss:0.23464	validation_1-logloss:0.24027
# [188]	validation_0-logloss:0.23461	validation_1-logloss:0.24027
# [189]	validation_0-logloss:0.23456	validation_1-logloss:0.24027
# [190]	validation_0-logloss:0.23453	validation_1-logloss:0.24027
# [191]	validation_0-logloss:0.23451	validation_1-logloss:0.24027
# [192]	validation_0-logloss:0.23449	validation_1-logloss:0.24026
# [193]	validation_0-logloss:0.23448	validation_1-logloss:0.24026
# [194]	validation_0-logloss:0.23445	validation_1-logloss:0.24026
# [195]	validation_0-logloss:0.23441	validation_1-logloss:0.24027
# [196]	validation_0-logloss:0.23439	validation_1-logloss:0.24027
# [197]	validation_0-logloss:0.23438	validation_1-logloss:0.24026
# [198]	validation_0-logloss:0.23435	validation_1-logloss:0.24026
# [199]	validation_0-logloss:0.23433	validation_1-logloss:0.24026
# [200]	validation_0-logloss:0.23431	validation_1-logloss:0.24026
# [201]	validation_0-logloss:0.23430	validation_1-logloss:0.24026
# [202]	validation_0-logloss:0.23424	validation_1-logloss:0.24025
# [203]	validation_0-logloss:0.23420	validation_1-logloss:0.24025
# [204]	validation_0-logloss:0.23416	validation_1-logloss:0.24026
# [205]	validation_0-logloss:0.23412	validation_1-logloss:0.24024
# [206]	validation_0-logloss:0.23409	validation_1-logloss:0.24025
# [207]	validation_0-logloss:0.23405	validation_1-logloss:0.24024
# [208]	validation_0-logloss:0.23401	validation_1-logloss:0.24022
# [209]	validation_0-logloss:0.23399	validation_1-logloss:0.24022
# [210]	validation_0-logloss:0.23396	validation_1-logloss:0.24023
# [211]	validation_0-logloss:0.23394	validation_1-logloss:0.24023
# [212]	validation_0-logloss:0.23393	validation_1-logloss:0.24023
# [213]	validation_0-logloss:0.23391	validation_1-logloss:0.24023
# [214]	validation_0-logloss:0.23387	validation_1-logloss:0.24024
# [215]	validation_0-logloss:0.23383	validation_1-logloss:0.24024
# [216]	validation_0-logloss:0.23379	validation_1-logloss:0.24024
# [217]	validation_0-logloss:0.23372	validation_1-logloss:0.24022
# [218]	validation_0-logloss:0.23370	validation_1-logloss:0.24021
# [219]	validation_0-logloss:0.23367	validation_1-logloss:0.24021
# [220]	validation_0-logloss:0.23364	validation_1-logloss:0.24021
# [221]	validation_0-logloss:0.23363	validation_1-logloss:0.24022
# [222]	validation_0-logloss:0.23358	validation_1-logloss:0.24022
# [223]	validation_0-logloss:0.23355	validation_1-logloss:0.24022
# [224]	validation_0-logloss:0.23353	validation_1-logloss:0.24022
# [225]	validation_0-logloss:0.23351	validation_1-logloss:0.24022
# [226]	validation_0-logloss:0.23350	validation_1-logloss:0.24022
# [227]	validation_0-logloss:0.23348	validation_1-logloss:0.24022
# [228]	validation_0-logloss:0.23346	validation_1-logloss:0.24022
# [229]	validation_0-logloss:0.23342	validation_1-logloss:0.24022
# [230]	validation_0-logloss:0.23339	validation_1-logloss:0.24021
# [231]	validation_0-logloss:0.23336	validation_1-logloss:0.24021
# [232]	validation_0-logloss:0.23333	validation_1-logloss:0.24021
# [233]	validation_0-logloss:0.23331	validation_1-logloss:0.24021
# [234]	validation_0-logloss:0.23328	validation_1-logloss:0.24020
# [235]	validation_0-logloss:0.23327	validation_1-logloss:0.24020
# [236]	validation_0-logloss:0.23324	validation_1-logloss:0.24019
# [237]	validation_0-logloss:0.23321	validation_1-logloss:0.24020
# [238]	validation_0-logloss:0.23320	validation_1-logloss:0.24021
# [239]	validation_0-logloss:0.23317	validation_1-logloss:0.24021
# [240]	validation_0-logloss:0.23314	validation_1-logloss:0.24020
# [241]	validation_0-logloss:0.23311	validation_1-logloss:0.24020
# [242]	validation_0-logloss:0.23306	validation_1-logloss:0.24020
# [243]	validation_0-logloss:0.23304	validation_1-logloss:0.24020
# [244]	validation_0-logloss:0.23299	validation_1-logloss:0.24020
# [245]	validation_0-logloss:0.23298	validation_1-logloss:0.24020
# [246]	validation_0-logloss:0.23292	validation_1-logloss:0.24019
# [247]	validation_0-logloss:0.23288	validation_1-logloss:0.24019
# [248]	validation_0-logloss:0.23286	validation_1-logloss:0.24019
# [249]	validation_0-logloss:0.23282	validation_1-logloss:0.24019
# [250]	validation_0-logloss:0.23280	validation_1-logloss:0.24019
# [251]	validation_0-logloss:0.23278	validation_1-logloss:0.24020
# [252]	validation_0-logloss:0.23275	validation_1-logloss:0.24020
# [253]	validation_0-logloss:0.23272	validation_1-logloss:0.24020
# [254]	validation_0-logloss:0.23270	validation_1-logloss:0.24021
# [255]	validation_0-logloss:0.23268	validation_1-logloss:0.24021
# [256]	validation_0-logloss:0.23265	validation_1-logloss:0.24021
# [257]	validation_0-logloss:0.23261	validation_1-logloss:0.24021
# [258]	validation_0-logloss:0.23259	validation_1-logloss:0.24021
# [259]	validation_0-logloss:0.23254	validation_1-logloss:0.24021
# [260]	validation_0-logloss:0.23252	validation_1-logloss:0.24021
# [261]	validation_0-logloss:0.23247	validation_1-logloss:0.24019
# [262]	validation_0-logloss:0.23245	validation_1-logloss:0.24020
# [263]	validation_0-logloss:0.23245	validation_1-logloss:0.24020
# [264]	validation_0-logloss:0.23242	validation_1-logloss:0.24020
# [265]	validation_0-logloss:0.23237	validation_1-logloss:0.24019
# [266]	validation_0-logloss:0.23236	validation_1-logloss:0.24019
# [267]	validation_0-logloss:0.23231	validation_1-logloss:0.24019
# [268]	validation_0-logloss:0.23229	validation_1-logloss:0.24019
# [269]	validation_0-logloss:0.23227	validation_1-logloss:0.24019
# [270]	validation_0-logloss:0.23222	validation_1-logloss:0.24019
# [271]	validation_0-logloss:0.23219	validation_1-logloss:0.24019
# [272]	validation_0-logloss:0.23218	validation_1-logloss:0.24018
# [273]	validation_0-logloss:0.23215	validation_1-logloss:0.24019
# [274]	validation_0-logloss:0.23214	validation_1-logloss:0.24019
# [275]	validation_0-logloss:0.23213	validation_1-logloss:0.24019
# [276]	validation_0-logloss:0.23211	validation_1-logloss:0.24019
# [277]	validation_0-logloss:0.23208	validation_1-logloss:0.24020
# [278]	validation_0-logloss:0.23205	validation_1-logloss:0.24020
# [279]	validation_0-logloss:0.23203	validation_1-logloss:0.24020
# [280]	validation_0-logloss:0.23199	validation_1-logloss:0.24020
# [281]	validation_0-logloss:0.23198	validation_1-logloss:0.24020
# [282]	validation_0-logloss:0.23197	validation_1-logloss:0.24021
# [283]	validation_0-logloss:0.23197	validation_1-logloss:0.24020
# [284]	validation_0-logloss:0.23192	validation_1-logloss:0.24019
# [285]	validation_0-logloss:0.23188	validation_1-logloss:0.24019
# [286]	validation_0-logloss:0.23183	validation_1-logloss:0.24020
# [287]	validation_0-logloss:0.23182	validation_1-logloss:0.24020
# [288]	validation_0-logloss:0.23178	validation_1-logloss:0.24020
# [289]	validation_0-logloss:0.23178	validation_1-logloss:0.24020
# [290]	validation_0-logloss:0.23174	validation_1-logloss:0.24020
# [291]	validation_0-logloss:0.23170	validation_1-logloss:0.24020
# [292]	validation_0-logloss:0.23169	validation_1-logloss:0.24020
# [293]	validation_0-logloss:0.23166	validation_1-logloss:0.24020
# [294]	validation_0-logloss:0.23161	validation_1-logloss:0.24019
# [295]	validation_0-logloss:0.23159	validation_1-logloss:0.24019
# [296]	validation_0-logloss:0.23156	validation_1-logloss:0.24019
# [297]	validation_0-logloss:0.23153	validation_1-logloss:0.24019
# [298]	validation_0-logloss:0.23150	validation_1-logloss:0.24019
# [299]	validation_0-logloss:0.23148	validation_1-logloss:0.24019
# [300]	validation_0-logloss:0.23146	validation_1-logloss:0.24019
# [301]	validation_0-logloss:0.23142	validation_1-logloss:0.24019
# [302]	validation_0-logloss:0.23141	validation_1-logloss:0.24020
# [303]	validation_0-logloss:0.23140	validation_1-logloss:0.24020
# [304]	validation_0-logloss:0.23136	validation_1-logloss:0.24021
# [305]	validation_0-logloss:0.23134	validation_1-logloss:0.24021
# [306]	validation_0-logloss:0.23131	validation_1-logloss:0.24020
# [307]	validation_0-logloss:0.23128	validation_1-logloss:0.24020
# [308]	validation_0-logloss:0.23126	validation_1-logloss:0.24020
# [309]	validation_0-logloss:0.23125	validation_1-logloss:0.24020
# [310]	validation_0-logloss:0.23124	validation_1-logloss:0.24020
# [311]	validation_0-logloss:0.23123	validation_1-logloss:0.24021
# [312]	validation_0-logloss:0.23122	validation_1-logloss:0.24020
# [313]	validation_0-logloss:0.23120	validation_1-logloss:0.24021
# [314]	validation_0-logloss:0.23114	validation_1-logloss:0.24020
# [315]	validation_0-logloss:0.23112	validation_1-logloss:0.24021
# [316]	validation_0-logloss:0.23110	validation_1-logloss:0.24021
# [317]	validation_0-logloss:0.23106	validation_1-logloss:0.24021
# [318]	validation_0-logloss:0.23103	validation_1-logloss:0.24021
# [319]	validation_0-logloss:0.23098	validation_1-logloss:0.24022
# [320]	validation_0-logloss:0.23096	validation_1-logloss:0.24022
# [321]	validation_0-logloss:0.23092	validation_1-logloss:0.24022
# [322]	validation_0-logloss:0.23087	validation_1-logloss:0.24023
#  ########################################

# %%
# XGBoost with the kinematic variables of the leptons

########################
# CLASSIFICATION SCORE #
########################

# Outputs for validation data set

pred_XG_SM_1ML = []
pred_XG_NP_1ML = []

for i in range(len(y_mon_test)):
    if y_mon_test[i] == 0:
        pred_XG_SM_1ML.append(y_pred_xg_1ML[i])
    else:
        pred_XG_NP_1ML.append(y_pred_xg_1ML[i])
        
        
print('Classification score (1ML):')
        
weights = np.ones_like(pred_XG_SM_1ML)/float(len(pred_XG_SM_1ML))
nSM, binsSM, patchesSM = plt.hist(pred_XG_SM_1ML, 100, weights=weights, range=[0,1], histtype='step', color='firebrick', linewidth=2, label='Background')

weights = np.ones_like(pred_XG_NP_1ML)/float(len(pred_XG_NP_1ML))
nNP, binsNP, patchesNP = plt.hist(pred_XG_NP_1ML, 100, weights=weights, range=[0,1], histtype='step', color='forestgreen', linewidth=2, label='Signal')

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("Classication score (XGBoost)",fontsize=15)
plt.ylabel("Fraction of events",fontsize=14)
plt.grid()
plt.legend(fontsize=12)
plt.title('Multivariate monian distributions, $\mathcal{N}_{2}$', fontsize=14)
#plt.savefig('images/' + '2monian-output.pdf', format="pdf", bbox_inches="tight")
plt.show()




# Outputs for validation data set

pred_XG_SM = []
pred_XG_NP = []

for i in range(len(y_mon_test)):
    if y_mon_test[i] == 0:
        pred_XG_SM.append(y_pred_xg[i])
    else:
        pred_XG_NP.append(y_pred_xg[i])
        
        
print('Classification score (10ML):')
        
weights = np.ones_like(pred_XG_SM)/float(len(pred_XG_SM))
nSM, binsSM, patchesSM = plt.hist(pred_XG_SM, 100, weights=weights, range=[0,1], histtype='step', color='firebrick', linewidth=2, label='Background')

weights = np.ones_like(pred_XG_NP)/float(len(pred_XG_NP))
nNP, binsNP, patchesNP = plt.hist(pred_XG_NP, 100, weights=weights, range=[0,1], histtype='step', color='forestgreen', linewidth=2, label='Signal')

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("Classication score (XGBoost)",fontsize=15)
plt.ylabel("Fraction of events",fontsize=14)
plt.grid()
plt.legend(fontsize=12)
plt.title('Multivariate monian distributions, $\mathcal{N}_{2}$', fontsize=14)
#plt.savefig('images/' + '2monian-output.pdf', format="pdf", bbox_inches="tight")
plt.show()
# Out:
# Classification score (1ML):
# Classification score (10ML):

# %% [markdown]
# ## METHODS

# %% [markdown]
# ### 0. Ensembles characteristics

# %%
##############
# PARAMETERS #
##############

# requested number of ensembles
n_ensembles = 5000

# number of expected background events per ensemble
B_expected = 5000

# ratio S_expected/B_expected (signal ratio)
SB_ratio = [0.0006, 0.001, 0.0016, 0.0025, 0.005, 0.0075, 0.01, 0.025]





# SOME USEFUL DERIVATED PARAMETERS:

# S_expected:
S_expected = [ int(SB_ratio[iii]*B_expected) for iii in range(len(SB_ratio)) ]
print(S_expected)

# S/\sqrt{B}
SsqrtB = [ S_expected[iii]/(B_expected)**0.5 for iii in range(len(SB_ratio)) ]


ntrials = 5000
# Out:
# [2, 5, 8, 12, 25, 37, 50, 125]

# %% [markdown]
# ### 0. BINNING WITH CROSS-VALIDATION

# %% [markdown]
# ### Numbers of bins

# %%
print(' BINNING ')

divs_B = int(len(pred_XG_SM)/B_expected)

B_1 = []
B_2 = []
B_3 = []

for it in range(divs_B):
    datB_grid_SM = pred_XG_SM[(B_expected*it):(B_expected*(it+1))]
    datB_grid_NP = pred_XG_NP[:B_expected]

    B_hist1 = np.histogram_bin_edges(datB_grid_SM, bins = 'fd')
    B_hist2 = np.histogram_bin_edges(datB_grid_SM, bins = 'doane')
    B_hist3 = np.histogram_bin_edges(datB_grid_SM, bins = 'sturges')

    B_1.append(len(B_hist1))
    B_2.append(len(B_hist2))
    B_3.append(len(B_hist3))



B_1_mean = int(np.mean(B_1))
B_2_mean = int(np.mean(B_2))
B_3_mean = int(np.mean(B_3))


B_hist1 = plt.hist(datB_grid_SM, bins = B_1_mean, histtype = 'step', label = 'fd')
B_hist2 = plt.hist(datB_grid_SM, bins = B_2_mean, histtype = 'step', label = 'doane')
B_hist3 = plt.hist(datB_grid_SM, bins = B_3_mean, histtype = 'step', label = 'sturges')
plt.legend()
plt.show()


print('fd', B_1_mean)
print('doane', B_2_mean)
print('sturges', B_3_mean)
print(' ')

B_bins_mean = [B_1_mean, B_2_mean, B_3_mean]
# Out:
#  BINNING
# fd 115
# doane 21
# sturges 15

# %% [markdown]
# ### Binning with cross-validation - equal size bins

# %%
# eq size with cross-val method to determine Nbin
Z_bins_XG_CV0 = []
Z_bins_XG_CV1 = []
Z_bins_XG_CV2 = []

Z_bins_XG_CV0_zeros = []
Z_bins_XG_CV1_zeros = []
Z_bins_XG_CV2_zeros = []



for iii in range(len(SB_ratio)):

    print('B_expected: ', B_expected)
    print('S_expected: ', S_expected[iii])
    print(r'S/$\sqrt{B}$: ', SsqrtB[iii])
    
    
    
    
    ###############################
    # EQ SIZE CROSS-VAL FOR Nbins #
    ###############################


    # Les't find the number of possible ensembles
    N_ensembles_back = len(pred_XG_SM) / B_expected
    N_ensembles_sig = len(pred_XG_NP) / S_expected[iii]

    Z_bins_XG_CV = []
    Z_bins_XG_CV_zeros = []

    for j_it in range(len(B_bins_mean)):

        # bin the parameter space of all background events
        hist_back, binedges_back = np.histogramdd([pred_XG_SM], bins=(B_bins_mean[j_it]), range = [[min(pred_XG_SM),max(pred_XG_SM)]])
        bin_edges = binedges_back[0]

        if min(hist_back) >= 5*N_ensembles_back:
            print('ok j_it=', j_it)

            # now divide by the number of possible ensembles
            back_prom = hist_back/N_ensembles_back

            # same for signal
            hist_sig, binedges_sig = np.histogramdd([pred_XG_NP], bins=[bin_edges])
            sig_prom = hist_sig/N_ensembles_sig

            # then the signif Z^binned-Asimov:
            Z_bins_XG_CV_aux = ( 2* sum( ( back_prom * np.log( back_prom / (sig_prom+back_prom) ) ) + sig_prom ) )**0.5

        else:
            print('NO ok j_it=', j_it)
            Z_bins_XG_CV_aux = 0

        Z_bins_XG_CV.append(Z_bins_XG_CV_aux)


        # REPLACE the zeros
        hist_back_noceros = []
        for i in range(len(hist_back)):
            if hist_back[i]!=0:
                hist_back_noceros.append(hist_back[i])

        min_back = min(hist_back_noceros)

        # replace the zeros
        for i in range(len(hist_back)):
            if hist_back[i]==0:
                hist_back[i] = min_back

        # now divide by the number of possible ensembles
        back_prom = hist_back/N_ensembles_back

        # same for signal
        hist_sig, binedges_sig = np.histogramdd([pred_XG_NP], bins=[bin_edges])
        sig_prom = hist_sig/N_ensembles_sig

        Z_bins_XG_CV_zeros.append( ( 2* sum( ( back_prom * np.log( back_prom / (sig_prom+back_prom) ) ) + sig_prom ) )**0.5 )


    Z_bins_XG_CV0.append(Z_bins_XG_CV[0])
    Z_bins_XG_CV1.append(Z_bins_XG_CV[1])
    Z_bins_XG_CV2.append(Z_bins_XG_CV[2])

    Z_bins_XG_CV0_zeros.append(Z_bins_XG_CV_zeros[0])
    Z_bins_XG_CV1_zeros.append(Z_bins_XG_CV_zeros[1])
    Z_bins_XG_CV2_zeros.append(Z_bins_XG_CV_zeros[2])

    print(' ')
# Out:
# B_expected:  5000
# S_expected:  2
# S/$\sqrt{B}$:  0.0282842712474619
# NO ok j_it= 0
# ok j_it= 1
# ok j_it= 2
#
# B_expected:  5000
# S_expected:  5
# S/$\sqrt{B}$:  0.07071067811865475
# NO ok j_it= 0
# ok j_it= 1
# ok j_it= 2
#
# B_expected:  5000
# S_expected:  8
# S/$\sqrt{B}$:  0.1131370849898476
# NO ok j_it= 0
# ok j_it= 1
# ok j_it= 2
#
# B_expected:  5000
# S_expected:  12
# S/$\sqrt{B}$:  0.1697056274847714
# NO ok j_it= 0
# ok j_it= 1
# ok j_it= 2
#
# B_expected:  5000
# S_expected:  25
# S/$\sqrt{B}$:  0.35355339059327373
# NO ok j_it= 0
# ok j_it= 1
# ok j_it= 2
#
# B_expected:  5000
# S_expected:  37
# S/$\sqrt{B}$:  0.5232590180780452
# NO ok j_it= 0
# ok j_it= 1
# ok j_it= 2
#
# B_expected:  5000
# S_expected:  50
# S/$\sqrt{B}$:  0.7071067811865475
# NO ok j_it= 0
# ok j_it= 1
# ok j_it= 2
#
# B_expected:  5000
# S_expected:  125
# S/$\sqrt{B}$:  1.7677669529663687
# NO ok j_it= 0
# ok j_it= 1
# ok j_it= 2

# %%
print(Z_bins_XG_CV0)
print(Z_bins_XG_CV1)
print(Z_bins_XG_CV2)

print(Z_bins_XG_CV0_zeros)
print(Z_bins_XG_CV1_zeros)
print(Z_bins_XG_CV2_zeros)
# Out:
# [0, 0, 0, 0, 0, 0, 0, 0]
# [0.31000436189596914, 0.7523947364089542, 1.1710678437380444, 1.6976964259474292, 3.217255846383562, 4.431545059718578, 5.604645236096654, 10.801027808627092]
# [0.28493797915552543, 0.694875954660092, 1.0860985580599518, 1.5822144244700576, 3.0342895975654245, 4.21152554408795, 5.359186182632491, 10.513118815284615]
# [0.4068739543151959, 0.9625000575319508, 1.4673271174111229, 2.0802512612414525, 3.7573493531571303, 5.037670201936671, 6.245317332568839, 11.444532050472128]
# [0.31000436189596914, 0.7523947364089542, 1.1710678437380444, 1.6976964259474292, 3.217255846383562, 4.431545059718578, 5.604645236096654, 10.801027808627092]
# [0.28493797915552543, 0.694875954660092, 1.0860985580599518, 1.5822144244700576, 3.0342895975654245, 4.21152554408795, 5.359186182632491, 10.513118815284615]

# %%
Z_bins_XG_CV0 = 
Z_bins_XG_CV1 = 
Z_bins_XG_CV2 = 

Z_bins_XG_CV0_zeros = 
Z_bins_XG_CV1_zeros = 
Z_bins_XG_CV2_zeros =

# %%
#########
# PLOTS #
#########

posX = []

for i in range(len(SB_ratio)):
    posX.append( (B_expected*SB_ratio[i]) / ( B_expected )**0.5 )


    
plt.figure()
lw = 2

plt.plot(posX, Z_bins_XG_CV0, '-ok', color='blue', lw=lw, label='o(x) BL fd') 
plt.plot(posX, Z_bins_XG_CV1, '--ok', color='green', lw=lw, label='o(x) BL doane')  
plt.plot(posX, Z_bins_XG_CV2, ':ok', color='red', lw=lw, label='o(x) BL sturges') 
plt.plot(posX, Z_bins_XG_CV0_zeros, '-ok', color='lightblue', lw=lw, label='o(x) BL fd (zeros)') 
plt.plot(posX, Z_bins_XG_CV1_zeros, '--ok', color='lime', lw=lw, label='o(x) BL doane (zeros)') 
plt.plot(posX, Z_bins_XG_CV2_zeros, ':ok', color='pink', lw=lw, label='o(x) BL sturges (zeros)') 

#plt.xlim([0.5, 10])
#plt.ylim([-0.5, 7.5])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=14)
plt.ylabel('$Z_{\mu}$ (exclusion)', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title('<B> per ensemble: %0.2d' % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()
# Out:
# <ipython-input-20-b6791d54c268>:15: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, Z_bins_XG_CV0, '-ok', color='blue', lw=lw, label='o(x) BL fd')
# <ipython-input-20-b6791d54c268>:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "--ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, Z_bins_XG_CV1, '--ok', color='green', lw=lw, label='o(x) BL doane')
# <ipython-input-20-b6791d54c268>:17: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string ":ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, Z_bins_XG_CV2, ':ok', color='red', lw=lw, label='o(x) BL sturges')
# <ipython-input-20-b6791d54c268>:18: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, Z_bins_XG_CV0_zeros, '-ok', color='lightblue', lw=lw, label='o(x) BL fd (zeros)')
# <ipython-input-20-b6791d54c268>:19: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "--ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, Z_bins_XG_CV1_zeros, '--ok', color='lime', lw=lw, label='o(x) BL doane (zeros)')
# <ipython-input-20-b6791d54c268>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string ":ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, Z_bins_XG_CV2_zeros, ':ok', color='pink', lw=lw, label='o(x) BL sturges (zeros)')

# %% [markdown]
# ### Binning with cross-validation - non-equal size bins

# %%
########################################################################
# RANDOM BINNING with CROSS-VAL FOR Nbins and CROSS-VAL for the random #
########################################################################

num_SM = int(len(pred_XG_SM)/6)
num_NP = int(len(pred_XG_NP)/6)

numdat = min(num_SM, num_NP)

data_grid_SM_0 = pred_XG_SM[(0*numdat):(1*numdat)]
data_grid_NP_0 = pred_XG_NP[(0*numdat):(1*numdat)]

data_grid_SM_1 = pred_XG_SM[(1*numdat):(2*numdat)]
data_grid_NP_1 = pred_XG_NP[(1*numdat):(2*numdat)]

data_grid_SM_2 = pred_XG_SM[(2*numdat):(3*numdat)]
data_grid_NP_2 = pred_XG_NP[(2*numdat):(3*numdat)]

data_grid_SM_3 = pred_XG_SM[(3*numdat):(4*numdat)]
data_grid_NP_3 = pred_XG_NP[(3*numdat):(4*numdat)]

data_grid_SM_4 = pred_XG_SM[(4*numdat):(5*numdat)]
data_grid_NP_4 = pred_XG_NP[(4*numdat):(5*numdat)]

data_grid_SM_5 = pred_XG_SM[(5*numdat):(6*numdat)]
data_grid_NP_5 = pred_XG_NP[(5*numdat):(6*numdat)]



# cross-val method to determine the random binning
CV0_chi2 = []
CV1_chi2 = []
CV2_chi2 = []

CV0_chi2_N = []
CV1_chi2_N = []
CV2_chi2_N = []

CV0_MSE = []
CV1_MSE = []
CV2_MSE = []

CV0_poiss = []
CV1_poiss = []
CV2_poiss = []


CV0_chi2_eqsize = []
CV1_chi2_eqsize = []
CV2_chi2_eqsize = []

CV0_chi2_N_eqsize = []
CV1_chi2_N_eqsize = []
CV2_chi2_N_eqsize = []

CV0_MSE_eqsize = []
CV1_MSE_eqsize = []
CV2_MSE_eqsize = []

CV0_poiss_eqsize = []
CV1_poiss_eqsize = []
CV2_poiss_eqsize = []


# random with cross-val method to determine Nbin and cross-val method to determine the random binning
Z_bins_XG_CV0_chi2 = []
Z_bins_XG_CV1_chi2 = []
Z_bins_XG_CV2_chi2 = []

Z_bins_XG_CV0_chi2_N = []
Z_bins_XG_CV1_chi2_N = []
Z_bins_XG_CV2_chi2_N = []

Z_bins_XG_CV0_MSE = []
Z_bins_XG_CV1_MSE = []
Z_bins_XG_CV2_MSE = []

Z_bins_XG_CV0_poiss = []
Z_bins_XG_CV1_poiss = []
Z_bins_XG_CV2_poiss = []


# THE SAME but replacin the zeros in the binning

# cross-val method to determine the random binning
CV0_chi2_zeros = []
CV1_chi2_zeros = []
CV2_chi2_zeros = []

CV0_chi2_N_zeros = []
CV1_chi2_N_zeros = []
CV2_chi2_N_zeros = []

CV0_MSE_zeros = []
CV1_MSE_zeros = []
CV2_MSE_zeros = []

CV0_poiss_zeros = []
CV1_poiss_zeros = []
CV2_poiss_zeros = []


CV0_chi2_eqsize_zeros = []
CV1_chi2_eqsize_zeros = []
CV2_chi2_eqsize_zeros = []

CV0_chi2_N_eqsize_zeros = []
CV1_chi2_N_eqsize_zeros = []
CV2_chi2_N_eqsize_zeros = []

CV0_MSE_eqsize_zeros = []
CV1_MSE_eqsize_zeros = []
CV2_MSE_eqsize_zeros = []

CV0_poiss_eqsize_zeros = []
CV1_poiss_eqsize_zeros = []
CV2_poiss_eqsize_zeros = []


# random with cross-val method to determine Nbin and cross-val method to determine the random binning
Z_bins_XG_CV0_chi2_zeros = []
Z_bins_XG_CV1_chi2_zeros = []
Z_bins_XG_CV2_chi2_zeros = []

Z_bins_XG_CV0_chi2_N_zeros = []
Z_bins_XG_CV1_chi2_N_zeros = []
Z_bins_XG_CV2_chi2_N_zeros = []

Z_bins_XG_CV0_MSE_zeros = []
Z_bins_XG_CV1_MSE_zeros = []
Z_bins_XG_CV2_MSE_zeros = []

Z_bins_XG_CV0_poiss_zeros = []
Z_bins_XG_CV1_poiss_zeros = []
Z_bins_XG_CV2_poiss_zeros = []




for iii in range(len(SB_ratio)):

    print('B_expected: ', B_expected)
    print('S_expected: ', S_expected[iii])
    print(r'S/$\sqrt{B}$: ', SsqrtB[iii])

    Z_bins_XG_CV_rd = []

    chi2 = []
    chi2_N = []
    MSE = []
    poiss = []


    Z_bins_XG_CV_rd_zeros = []

    chi2_zeros = []
    chi2_N_zeros = []
    MSE_zeros = []
    poiss_zeros = []


    # Les't find the number of possible ensembles
    N_ensembles_back = len(data_grid_SM_0) / B_expected
    N_ensembles_sig = len(data_grid_NP_0) / S_expected[iii]



    for j_it in range(len(B_bins_mean)):

        print('doing Nbin: ', B_bins_mean[j_it])

        for i_it in range(ntrials):

            if i_it == 0:
                # bin the parameter space of all background events
                bin_edges = np.linspace( min(pred_XG_SM), max(pred_XG_SM), (B_bins_mean[j_it]+1) )

            else:
                bin_edges = np.hstack( (min(pred_XG_SM), np.sort( np.random.uniform(min(pred_XG_SM), max(pred_XG_SM), (B_bins_mean[j_it]-1)) ), max(pred_XG_SM) ) )

            hist_SM_0, _ = np.histogramdd([data_grid_SM_0], bins = [bin_edges])
            hist_SM_1, _ = np.histogramdd([data_grid_SM_1], bins = [bin_edges])
            hist_SM_2, _ = np.histogramdd([data_grid_SM_2], bins = [bin_edges])
            hist_SM_3, _ = np.histogramdd([data_grid_SM_3], bins = [bin_edges])

            mean = (hist_SM_0 + hist_SM_1 + hist_SM_2 + hist_SM_3 )/4

            if min(mean)>= 5*N_ensembles_back:

                ##################
                # COMPUTE METRIC #
                ##################
                hist_SM_4, _ = np.histogramdd([data_grid_SM_4], bins = [bin_edges])

                aux_chi2 = sum( ((hist_SM_4 - mean))**2 / mean )
                aux_chi2_N = aux_chi2 / j_it
                aux_MSE = sum( ((hist_SM_4 - mean))**2 ) / j_it
                aux_poiss = sum( mean - (hist_SM_4*np.log(mean)) + (hist_SM_4*np.log(hist_SM_4)) - hist_SM_4 )


                #############
                # COMPUTE Z #
                #############
                # bin the parameter space of all background events
                hist_SM_5, _ = np.histogramdd([data_grid_SM_5], bins = [bin_edges])

                # now divide by the number of possible ensembles
                back_prom_5 = hist_SM_5/N_ensembles_back

                # same for signal
                hist_NP_5, _ = np.histogramdd([data_grid_NP_5], bins = [bin_edges])

                sig_prom_5 = hist_NP_5/N_ensembles_sig

                # then the signif Z^binned-Asimov:
                Z_bins_XG_aux = ( 2* sum( ( back_prom_5 * np.log( back_prom_5 / (sig_prom_5+back_prom_5) ) ) + sig_prom_5 ) )**0.5


            else:
                Z_bins_XG_aux = 0
                aux_chi2 = 9999
                aux_chi2_N = 9999
                aux_MSE = 9999
                aux_poiss = 9999

            Z_bins_XG_CV_rd.append(Z_bins_XG_aux)
            chi2.append(aux_chi2)
            chi2_N.append(aux_chi2_N)
            MSE.append(aux_MSE)
            poiss.append(aux_poiss)



            # REPLACE the zeros
            mean_noceros = []
            for i in range(len(mean)):
                if mean[i]!=0:
                    mean_noceros.append(mean[i])

            min_mean = min(mean_noceros)

            # replace the zeros
            for i in range(len(mean)):
                if mean[i]==0:
                    mean[i] = min_mean


            ##################
            # COMPUTE METRIC #
            ##################
            hist_SM_4, _ = np.histogramdd([data_grid_SM_4], bins = [bin_edges])

            hist_back_noceros = []
            for i in range(len(hist_SM_4)):
                if hist_SM_4[i]!=0:
                    hist_back_noceros.append(hist_SM_4[i])

            min_back = min(hist_back_noceros)

            # replace the zeros
            for i in range(len(hist_SM_4)):
                if hist_SM_4[i]==0:
                    hist_SM_4[i] = min_back

            aux_chi2 = sum( ((hist_SM_4 - mean))**2 / mean )
            aux_chi2_N = aux_chi2 / j_it
            aux_MSE = sum( ((hist_SM_4 - mean))**2 ) / j_it
            aux_poiss = sum( mean - (hist_SM_4*np.log(mean)) + (hist_SM_4*np.log(hist_SM_4)) - hist_SM_4 )


            #############
            # COMPUTE Z #
            #############
            # bin the parameter space of all background events
            hist_SM_5, _ = np.histogramdd([data_grid_SM_5], bins = [bin_edges])

            hist_back_noceros = []
            for i in range(len(hist_SM_5)):
                if hist_SM_5[i]!=0:
                    hist_back_noceros.append(hist_SM_5[i])

            min_back = min(hist_back_noceros)

            # replace the zeros
            for i in range(len(hist_SM_5)):
                if hist_SM_5[i]==0:
                    hist_SM_5[i] = min_back

            # now divide by the number of possible ensembles
            back_prom_5 = hist_SM_5/N_ensembles_back

            # same for signal
            hist_NP_5, _ = np.histogramdd([data_grid_NP_5], bins = [bin_edges])

            sig_prom_5 = hist_NP_5/N_ensembles_sig

            # then the signif Z^binned-Asimov:
            Z_bins_XG_aux = ( 2* sum( ( back_prom_5 * np.log( back_prom_5 / (sig_prom_5+back_prom_5) ) ) + sig_prom_5 ) )**0.5


            Z_bins_XG_CV_rd_zeros.append(Z_bins_XG_aux)
            chi2_zeros.append(aux_chi2)
            chi2_N_zeros.append(aux_chi2_N)
            MSE_zeros.append(aux_MSE)
            poiss_zeros.append(aux_poiss)




    ################################################
    # SELECT THE BINNING with MINIMUM METRIC VALUE #
    ################################################

    # the value of the metric
    chi2_per_bin = []
    chi2_N_per_bin = []
    MSE_per_bin = []
    poiss_per_bin = []

    chi2_per_bin_eqsize = []
    chi2_N_per_bin_eqsize = []
    MSE_per_bin_eqsize = []
    poiss_per_bin_eqsize = []

    for i in range(len(B_bins_mean)):
        chi2_per_bin.append( np.min(chi2[ntrials*i:ntrials*(i+1)]) )
        chi2_N_per_bin.append( np.min(chi2_N[ntrials*i:ntrials*(i+1)]) )
        MSE_per_bin.append( np.min(MSE[ntrials*i:ntrials*(i+1)]) )
        poiss_per_bin.append( np.min(poiss[ntrials*i:ntrials*(i+1)]) )

        chi2_per_bin_eqsize.append( chi2[ntrials*i] )
        chi2_N_per_bin_eqsize.append( chi2_N[ntrials*i] )
        MSE_per_bin_eqsize.append( MSE[ntrials*i] )
        poiss_per_bin_eqsize.append( poiss[ntrials*i] )


    CV0_chi2.append(chi2_per_bin[0])
    CV1_chi2.append(chi2_per_bin[1])
    CV2_chi2.append(chi2_per_bin[2])

    CV0_chi2_N.append(chi2_N_per_bin[0])
    CV1_chi2_N.append(chi2_N_per_bin[1])
    CV2_chi2_N.append(chi2_N_per_bin[2])

    CV0_MSE.append(MSE_per_bin[0])
    CV1_MSE.append(MSE_per_bin[1])
    CV2_MSE.append(MSE_per_bin[2])

    CV0_poiss.append(poiss_per_bin[0])
    CV1_poiss.append(poiss_per_bin[1])
    CV2_poiss.append(poiss_per_bin[2])



    CV0_chi2_eqsize.append(chi2_per_bin_eqsize[0])
    CV1_chi2_eqsize.append(chi2_per_bin_eqsize[1])
    CV2_chi2_eqsize.append(chi2_per_bin_eqsize[2])

    CV0_chi2_N_eqsize.append(chi2_N_per_bin_eqsize[0])
    CV1_chi2_N_eqsize.append(chi2_N_per_bin_eqsize[1])
    CV2_chi2_N_eqsize.append(chi2_N_per_bin_eqsize[2])

    CV0_MSE_eqsize.append(MSE_per_bin_eqsize[0])
    CV1_MSE_eqsize.append(MSE_per_bin_eqsize[1])
    CV2_MSE_eqsize.append(MSE_per_bin_eqsize[2])

    CV0_poiss_eqsize.append(poiss_per_bin_eqsize[0])
    CV1_poiss_eqsize.append(poiss_per_bin_eqsize[1])
    CV2_poiss_eqsize.append(poiss_per_bin_eqsize[2])




    # Z for the minimum of the metric
    Z_chi2_per_bin = []
    Z_chi2_N_per_bin = []
    Z_MSE_per_bin = []
    Z_poiss_per_bin = []

    for i in range(len(B_bins_mean)):
        Z_chi2_per_bin.append( Z_bins_XG_CV_rd[np.argmin(chi2[ntrials*i:ntrials*(i+1)]) + ntrials*i] )
        Z_chi2_N_per_bin.append( Z_bins_XG_CV_rd[np.argmin(chi2_N[ntrials*i:ntrials*(i+1)]) + ntrials*i] )
        Z_MSE_per_bin.append( Z_bins_XG_CV_rd[np.argmin(MSE[ntrials*i:ntrials*(i+1)]) + ntrials*i] )
        Z_poiss_per_bin.append( Z_bins_XG_CV_rd[np.argmin(poiss[ntrials*i:ntrials*(i+1)]) + ntrials*i] )   



    Z_bins_XG_CV0_chi2.append(Z_chi2_per_bin[0])
    Z_bins_XG_CV1_chi2.append(Z_chi2_per_bin[1])
    Z_bins_XG_CV2_chi2.append(Z_chi2_per_bin[2])

    Z_bins_XG_CV0_chi2_N.append(Z_chi2_N_per_bin[0])
    Z_bins_XG_CV1_chi2_N.append(Z_chi2_N_per_bin[1])
    Z_bins_XG_CV2_chi2_N.append(Z_chi2_N_per_bin[2])

    Z_bins_XG_CV0_MSE.append(Z_MSE_per_bin[0])
    Z_bins_XG_CV1_MSE.append(Z_MSE_per_bin[1])
    Z_bins_XG_CV2_MSE.append(Z_MSE_per_bin[2])

    Z_bins_XG_CV0_poiss.append(Z_poiss_per_bin[0])
    Z_bins_XG_CV1_poiss.append(Z_poiss_per_bin[1])
    Z_bins_XG_CV2_poiss.append(Z_poiss_per_bin[2])




    # SAME for replacing the zeros in the binning
    # the value of the metric
    chi2_per_bin_zeros = []
    chi2_N_per_bin_zeros = []
    MSE_per_bin_zeros = []
    poiss_per_bin_zeros = []

    chi2_per_bin_eqsize_zeros = []
    chi2_N_per_bin_eqsize_zeros = []
    MSE_per_bin_eqsize_zeros = []
    poiss_per_bin_eqsize_zeros = []

    for i in range(len(B_bins_mean)):
        chi2_per_bin_zeros.append( np.min(chi2_zeros[ntrials*i:ntrials*(i+1)]) )
        chi2_N_per_bin_zeros.append( np.min(chi2_N_zeros[ntrials*i:ntrials*(i+1)]) )
        MSE_per_bin_zeros.append( np.min(MSE_zeros[ntrials*i:ntrials*(i+1)]) )
        poiss_per_bin_zeros.append( np.min(poiss_zeros[ntrials*i:ntrials*(i+1)]) )

        chi2_per_bin_eqsize_zeros.append( chi2_zeros[ntrials*i] )
        chi2_N_per_bin_eqsize_zeros.append( chi2_N_zeros[ntrials*i] )
        MSE_per_bin_eqsize_zeros.append( MSE_zeros[ntrials*i] )
        poiss_per_bin_eqsize_zeros.append( poiss_zeros[ntrials*i] )


    CV0_chi2_zeros.append(chi2_per_bin_zeros[0])
    CV1_chi2_zeros.append(chi2_per_bin_zeros[1])
    CV2_chi2_zeros.append(chi2_per_bin_zeros[2])

    CV0_chi2_N_zeros.append(chi2_N_per_bin_zeros[0])
    CV1_chi2_N_zeros.append(chi2_N_per_bin_zeros[1])
    CV2_chi2_N_zeros.append(chi2_N_per_bin_zeros[2])

    CV0_MSE_zeros.append(MSE_per_bin_zeros[0])
    CV1_MSE_zeros.append(MSE_per_bin_zeros[1])
    CV2_MSE_zeros.append(MSE_per_bin_zeros[2])

    CV0_poiss_zeros.append(poiss_per_bin_zeros[0])
    CV1_poiss_zeros.append(poiss_per_bin_zeros[1])
    CV2_poiss_zeros.append(poiss_per_bin_zeros[2])



    CV0_chi2_eqsize_zeros.append(chi2_per_bin_eqsize_zeros[0])
    CV1_chi2_eqsize_zeros.append(chi2_per_bin_eqsize_zeros[1])
    CV2_chi2_eqsize_zeros.append(chi2_per_bin_eqsize_zeros[2])

    CV0_chi2_N_eqsize_zeros.append(chi2_N_per_bin_eqsize_zeros[0])
    CV1_chi2_N_eqsize_zeros.append(chi2_N_per_bin_eqsize_zeros[1])
    CV2_chi2_N_eqsize_zeros.append(chi2_N_per_bin_eqsize_zeros[2])

    CV0_MSE_eqsize_zeros.append(MSE_per_bin_eqsize_zeros[0])
    CV1_MSE_eqsize_zeros.append(MSE_per_bin_eqsize_zeros[1])
    CV2_MSE_eqsize_zeros.append(MSE_per_bin_eqsize_zeros[2])

    CV0_poiss_eqsize_zeros.append(poiss_per_bin_eqsize_zeros[0])
    CV1_poiss_eqsize_zeros.append(poiss_per_bin_eqsize_zeros[1])
    CV2_poiss_eqsize_zeros.append(poiss_per_bin_eqsize_zeros[2])




    # Z for the minimum of the metric
    Z_chi2_per_bin_zeros = []
    Z_chi2_N_per_bin_zeros = []
    Z_MSE_per_bin_zeros = []
    Z_poiss_per_bin_zeros = []

    for i in range(len(B_bins_mean)):
        Z_chi2_per_bin_zeros.append( Z_bins_XG_CV_rd_zeros[np.argmin(chi2_zeros[ntrials*i:ntrials*(i+1)]) + ntrials*i] )
        Z_chi2_N_per_bin_zeros.append( Z_bins_XG_CV_rd_zeros[np.argmin(chi2_N_zeros[ntrials*i:ntrials*(i+1)]) + ntrials*i] )
        Z_MSE_per_bin_zeros.append( Z_bins_XG_CV_rd_zeros[np.argmin(MSE_zeros[ntrials*i:ntrials*(i+1)]) + ntrials*i] )
        Z_poiss_per_bin_zeros.append( Z_bins_XG_CV_rd_zeros[np.argmin(poiss_zeros[ntrials*i:ntrials*(i+1)]) + ntrials*i] )   



    Z_bins_XG_CV0_chi2_zeros.append(Z_chi2_per_bin_zeros[0])
    Z_bins_XG_CV1_chi2_zeros.append(Z_chi2_per_bin_zeros[1])
    Z_bins_XG_CV2_chi2_zeros.append(Z_chi2_per_bin_zeros[2])

    Z_bins_XG_CV0_chi2_N_zeros.append(Z_chi2_N_per_bin_zeros[0])
    Z_bins_XG_CV1_chi2_N_zeros.append(Z_chi2_N_per_bin_zeros[1])
    Z_bins_XG_CV2_chi2_N_zeros.append(Z_chi2_N_per_bin_zeros[2])

    Z_bins_XG_CV0_MSE_zeros.append(Z_MSE_per_bin_zeros[0])
    Z_bins_XG_CV1_MSE_zeros.append(Z_MSE_per_bin_zeros[1])
    Z_bins_XG_CV2_MSE_zeros.append(Z_MSE_per_bin_zeros[2])

    Z_bins_XG_CV0_poiss_zeros.append(Z_poiss_per_bin_zeros[0])
    Z_bins_XG_CV1_poiss_zeros.append(Z_poiss_per_bin_zeros[1])
    Z_bins_XG_CV2_poiss_zeros.append(Z_poiss_per_bin_zeros[2])
    
    print(' ')
# Out:
# B_expected:  5000
# S_expected:  2
# S/$\sqrt{B}$:  0.0282842712474619
# doing Nbin:  115
# <ipython-input-22-31abcaeaab5c>:266: RuntimeWarning: divide by zero encountered in double_scalars
#   aux_chi2_N = aux_chi2 / j_it
# <ipython-input-22-31abcaeaab5c>:267: RuntimeWarning: divide by zero encountered in double_scalars
#   aux_MSE = sum( ((hist_SM_4 - mean))**2 ) / j_it
# doing Nbin:  21
# doing Nbin:  15
#
# B_expected:  5000
# S_expected:  5
# S/$\sqrt{B}$:  0.07071067811865475
# doing Nbin:  115
# doing Nbin:  21
# doing Nbin:  15
#
# B_expected:  5000
# S_expected:  8
# S/$\sqrt{B}$:  0.1131370849898476
# doing Nbin:  115
# doing Nbin:  21
# doing Nbin:  15
#
# B_expected:  5000
# S_expected:  12
# S/$\sqrt{B}$:  0.1697056274847714
# doing Nbin:  115
# doing Nbin:  21
# doing Nbin:  15
#
# B_expected:  5000
# S_expected:  25
# S/$\sqrt{B}$:  0.35355339059327373
# doing Nbin:  115
# doing Nbin:  21
# doing Nbin:  15
#
# B_expected:  5000
# S_expected:  37
# S/$\sqrt{B}$:  0.5232590180780452
# doing Nbin:  115
# doing Nbin:  21
# doing Nbin:  15
#
# B_expected:  5000
# S_expected:  50
# S/$\sqrt{B}$:  0.7071067811865475
# doing Nbin:  115
# doing Nbin:  21
# doing Nbin:  15
#
# B_expected:  5000
# S_expected:  125
# S/$\sqrt{B}$:  1.7677669529663687
# doing Nbin:  115
# doing Nbin:  21
# doing Nbin:  15

# %%
print(Z_bins_XG_CV0_chi2)
print(Z_bins_XG_CV1_chi2)
print(Z_bins_XG_CV2_chi2)

print(Z_bins_XG_CV0_chi2_N)
print(Z_bins_XG_CV1_chi2_N)
print(Z_bins_XG_CV2_chi2_N)

print(Z_bins_XG_CV0_MSE)
print(Z_bins_XG_CV1_MSE)
print(Z_bins_XG_CV2_MSE)

print(Z_bins_XG_CV0_poiss)
print(Z_bins_XG_CV1_poiss)
print(Z_bins_XG_CV2_poiss)



print(Z_bins_XG_CV0_chi2_zeros)
print(Z_bins_XG_CV1_chi2_zeros)
print(Z_bins_XG_CV2_chi2_zeros)

print(Z_bins_XG_CV0_chi2_N_zeros)
print(Z_bins_XG_CV1_chi2_N_zeros)
print(Z_bins_XG_CV2_chi2_N_zeros)

print(Z_bins_XG_CV0_MSE_zeros)
print(Z_bins_XG_CV1_MSE_zeros)
print(Z_bins_XG_CV2_MSE_zeros)

print(Z_bins_XG_CV0_poiss_zeros)
print(Z_bins_XG_CV1_poiss_zeros)
print(Z_bins_XG_CV2_poiss_zeros)
# Out:
# [0, 0, 0, 0, 0, 0, 0, 0]
# [0.29037209888576593, 0.887865719930014, 1.0301318151959846, 1.5668714792417413, 3.5474922348428994, 4.84768871690532, 6.009745115174738, 10.4706675700268]
# [0.29556610909817155, 0.6604260493329348, 0.9410805397812453, 1.5533985289517525, 2.868547722478054, 3.1206399732935712, 5.518311208865478, 10.85041624417099]
# [0, 0, 0, 0, 0, 0, 0, 0]
# [0.29037209888576593, 0.887865719930014, 1.0301318151959846, 1.5668714792417413, 3.5474922348428994, 4.84768871690532, 6.009745115174738, 10.4706675700268]
# [0.29556610909817155, 0.6604260493329348, 0.9410805397812453, 1.5533985289517525, 2.868547722478054, 3.1206399732935712, 5.518311208865478, 10.85041624417099]
# [0, 0, 0, 0, 0, 0, 0, 0]
# [0.2924167767721971, 0.880792028103827, 1.2255011473427617, 1.648509593973863, 3.574656615930014, 4.554611056163816, 5.677073649836645, 11.154520705828793]
# [0.33982731723241, 0.6493437785727616, 0.9410805397812453, 1.4832319786086618, 3.48355746170833, 4.5971624707165635, 5.98563375036972, 10.927928255506657]
# [0, 0, 0, 0, 0, 0, 0, 0]
# [0.29037209888576593, 0.887865719930014, 1.0301318151959846, 1.7193349297590361, 3.574656615930014, 4.84768871690532, 6.009745115174738, 10.4706675700268]
# [0.29556610909817155, 0.6604260493329348, 0.9410805397812453, 1.5533985289517525, 2.868547722478054, 3.1206399732935712, 5.518311208865478, 10.85041624417099]
# [0.3771044237311914, 0.9059240129753325, 1.45259975262696, 1.9075766038820394, 3.3402188248548472, 4.934083475626665, 6.137264487525093, 11.151394082372594]
# [0.37000608548549413, 0.7481082216833524, 1.0373231283771565, 1.6450045478345519, 2.796159769384985, 4.302712416810951, 6.009745115174738, 9.318566181367126]
# [0.25549657414127314, 0.6253458818206433, 1.1005757089820967, 1.3705340880900798, 3.5302074767584797, 4.09845363164982, 4.5773353159725625, 10.719292206204692]
# [0.3727435321817387, 0.8908039143600154, 1.3687463121088268, 1.9562253348826975, 3.5907329676834765, 4.854629054160926, 6.0538708888242665, 11.249367040655839]
# [0.37000608548549413, 0.7481082216833524, 1.0373231283771565, 1.6450045478345519, 2.796159769384985, 4.302712416810951, 6.009745115174738, 9.318566181367126]
# [0.25549657414127314, 0.6253458818206433, 1.1005757089820967, 1.3705340880900798, 3.5302074767584797, 4.09845363164982, 4.5773353159725625, 10.719292206204692]
# [0.3727435321817387, 0.8908039143600154, 1.3687463121088268, 1.9562253348826975, 3.5907329676834765, 4.854629054160926, 6.0538708888242665, 11.249367040655839]
# [0.27525298168514434, 0.8049440074512848, 1.2605661437012188, 1.516943358841169, 3.027862282888536, 4.468904165731636, 5.992843531518854, 10.58910753128739]
# [0.3123266771466512, 0.893249087759539, 0.9377587790750749, 1.4390773095053204, 3.4913093200259118, 4.760265786785181, 6.045719031710093, 10.58864830972199]
# [0.37351154929180497, 0.8943027284933508, 1.45259975262696, 1.9654227315733979, 3.3402188248548472, 4.934083475626665, 6.042302823255043, 11.097678500938258]
# [0.37000608548549413, 0.5379139083589237, 1.0373231283771565, 1.669085576871222, 2.796159769384985, 4.313290514318153, 6.009745115174738, 9.318566181367126]
# [0.25549657414127314, 0.6253458818206433, 1.1005757089820967, 1.6832272886913664, 3.5302074767584797, 4.09845363164982, 4.5773353159725625, 10.719292206204692]

# %%
Z_bins_XG_CV0_chi2 = 
Z_bins_XG_CV1_chi2 = 
Z_bins_XG_CV2_chi2 = 

Z_bins_XG_CV0_chi2_N = 
Z_bins_XG_CV1_chi2_N = 
Z_bins_XG_CV2_chi2_N = 

Z_bins_XG_CV0_MSE = 
Z_bins_XG_CV1_MSE = 
Z_bins_XG_CV2_MSE = 

Z_bins_XG_CV0_poiss = 
Z_bins_XG_CV1_poiss = 
Z_bins_XG_CV2_poiss = 



Z_bins_XG_CV0_chi2_zeros = 
Z_bins_XG_CV1_chi2_zeros = 
Z_bins_XG_CV2_chi2_zeros = 

Z_bins_XG_CV0_chi2_N_zeros = 
Z_bins_XG_CV1_chi2_N_zeros = 
Z_bins_XG_CV2_chi2_N_zeros = 

Z_bins_XG_CV0_MSE_zeros = 
Z_bins_XG_CV1_MSE_zeros = 
Z_bins_XG_CV2_MSE_zeros = 

Z_bins_XG_CV0_poiss_zeros = 
Z_bins_XG_CV1_poiss_zeros = 
Z_bins_XG_CV2_poiss_zeros =

# %%
#########
# PLOTS #
#########

posX = []

for i in range(len(SB_ratio)):
    posX.append( (B_expected*SB_ratio[i]) / ( B_expected )**0.5 )


    
plt.figure()
lw = 2

plt.plot(posX, Z_bins_XG_CV0, '-o', color='blue', lw=lw, label='o(x) BL fd') 
plt.plot(posX, Z_bins_XG_CV0_chi2, '-o', color='green', lw=lw, label='o(x) BL fd + chi2')  
plt.plot(posX, Z_bins_XG_CV0_chi2_N, '-o', color='red', lw=lw, label='o(x) BL fd + chi2/N') 
plt.plot(posX, Z_bins_XG_CV0_MSE, '-o', color='purple', lw=lw, label='o(x) BL fd + MSE') 
plt.plot(posX, Z_bins_XG_CV0_poiss, '-o', color='magenta', lw=lw, label='o(x) BL fd + poiss') 
plt.plot(posX, Z_bins_XG_CV0_zeros, ':o', color='blue', lw=lw, label='o(x) BL fd') 
plt.plot(posX, Z_bins_XG_CV0_chi2_zeros, ':o', color='green', lw=lw, label='o(x) BL fd + chi2')  
plt.plot(posX, Z_bins_XG_CV0_chi2_N_zeros, ':o', color='red', lw=lw, label='o(x) BL fd + chi2/N') 
plt.plot(posX, Z_bins_XG_CV0_MSE_zeros, ':o', color='purple', lw=lw, label='o(x) BL fd + MSE') 
plt.plot(posX, Z_bins_XG_CV0_poiss_zeros, ':o', color='magenta', lw=lw, label='o(x) BL fd + poiss') 

#plt.xlim([0.5, 10])
#plt.ylim([-0.5, 7.5])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=14)
plt.ylabel('$Z_{\mu}$ (exclusion)', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title('<B> per ensemble: %0.2d' % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()





plt.figure()
lw = 2

plt.plot(posX, Z_bins_XG_CV1, '-o', color='blue', lw=lw, label='o(x) BL doane') 
plt.plot(posX, Z_bins_XG_CV1_chi2, '-o', color='green', lw=lw, label='o(x) BL doane + chi2')  
plt.plot(posX, Z_bins_XG_CV1_chi2_N, '-o', color='red', lw=lw, label='o(x) BL doane + chi2/N') 
plt.plot(posX, Z_bins_XG_CV1_MSE, '-o', color='purple', lw=lw, label='o(x) BL doane + MSE') 
plt.plot(posX, Z_bins_XG_CV1_poiss, '-o', color='magenta', lw=lw, label='o(x) BL doane + poiss') 
plt.plot(posX, Z_bins_XG_CV1_zeros, ':o', color='blue', lw=lw, label='o(x) BL doane') 
plt.plot(posX, Z_bins_XG_CV1_chi2_zeros, ':o', color='green', lw=lw, label='o(x) BL doane + chi2')  
plt.plot(posX, Z_bins_XG_CV1_chi2_N_zeros, ':o', color='red', lw=lw, label='o(x) BL doane + chi2/N') 
plt.plot(posX, Z_bins_XG_CV1_MSE_zeros, ':o', color='purple', lw=lw, label='o(x) BL doane + MSE') 
plt.plot(posX, Z_bins_XG_CV1_poiss_zeros, ':o', color='magenta', lw=lw, label='o(x) BL doane + poiss') 

#plt.xlim([0.5, 10])
#plt.ylim([-0.5, 7.5])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=14)
plt.ylabel('$Z_{\mu}$ (exclusion)', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title('<B> per ensemble: %0.2d' % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()






plt.figure()
lw = 2

plt.plot(posX, Z_bins_XG_CV2, '-o', color='blue', lw=lw, label='o(x) BL sturges') 
plt.plot(posX, Z_bins_XG_CV2_chi2, '-o', color='green', lw=lw, label='o(x) BL sturges + chi2')  
plt.plot(posX, Z_bins_XG_CV2_chi2_N, '-o', color='red', lw=lw, label='o(x) BL sturges + chi2/N') 
plt.plot(posX, Z_bins_XG_CV2_MSE, '-o', color='purple', lw=lw, label='o(x) BL sturges + MSE') 
plt.plot(posX, Z_bins_XG_CV2_poiss, '-o', color='magenta', lw=lw, label='o(x) BL sturges + poiss') 
plt.plot(posX, Z_bins_XG_CV2_zeros, ':o', color='blue', lw=lw, label='o(x) BL sturges') 
plt.plot(posX, Z_bins_XG_CV2_chi2_zeros, ':o', color='green', lw=lw, label='o(x) BL sturges + chi2')  
plt.plot(posX, Z_bins_XG_CV2_chi2_N_zeros, ':o', color='red', lw=lw, label='o(x) BL sturges + chi2/N') 
plt.plot(posX, Z_bins_XG_CV2_MSE_zeros, ':o', color='purple', lw=lw, label='o(x) BL sturges + MSE') 
plt.plot(posX, Z_bins_XG_CV2_poiss_zeros, ':o', color='magenta', lw=lw, label='o(x) BL sturges + poiss') 

#plt.xlim([0.5, 10])
#plt.ylim([-0.5, 7.5])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=14)
plt.ylabel('$Z_{\mu}$ (exclusion)', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title('<B> per ensemble: %0.2d' % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()

# %% [markdown]
# ### 1. BIN LOG LIKELIHOOD

# %%
# 1st variable: invariant mass
background_X_1 = invariant_mass_eeSM
signal_X_1 = invariant_mass_eeSSMZprime

N_B = len(background_X_1)
N_S = len(signal_X_1)

# bins
logbins = [2000.0, 2200.0, 2500.0, 2850.0, 3250.0, 3750.0, 4350.0, 5000.0, 5750.0, 6600.0, 7500.0, 8750.0, 10000.0, 11500.0, 13000.0, 20000.0]

# %%
#################################
# BINNED POISSON LOG-LIKELIHOOD #
#################################


store_Z_bins = []
store_Z_bins_logbins = []


for iii in range(len(SB_ratio)):

    print('B_expected: ', B_expected)
    print('S_expected: ', S_expected[iii])
    print(r'S/$\sqrt{B}$: ', SsqrtB[iii])

    # Les't use an integer number of possible ensembles
    N_ensembles_back = int(N_B / B_expected)
    N_events_back = N_ensembles_back * B_expected

    N_ensembles_sig = int(N_S / S_expected[iii])
    N_events_sig = N_ensembles_sig * S_expected[iii]


    #Let's find out the expected number of B and S events in each bin:

    # bin the parameter space of all background events
    hist_back, binedges_back = np.histogramdd([background_X_1[:N_events_back]], bins=(100), range = [[2000,20000]])
    # now divide by the number of possible ensembles
    back_prom = hist_back.T.ravel()/N_ensembles_back

    # same for signal
    hist_sig, binedges_sig = np.histogramdd([signal_X_1[:N_events_sig]], bins=(100), range = [[2000,20000]])
    sig_prom = hist_sig.T.ravel()/N_ensembles_sig

        

    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    back_prom_noceros = []
    for i in range(len(back_prom)):
        if back_prom[i]!=0:
            back_prom_noceros.append(back_prom[i])

    min_back = min(back_prom_noceros)

    # replace the zeros
    for i in range(len(back_prom)):
        if back_prom[i]==0:
            back_prom[i] = min_back

    # then the signif Z^binned-Asimov:
    Z_bins = ( 2* sum( ( back_prom * np.log( back_prom/(sig_prom + back_prom) ) ) + sig_prom ) )**0.5

    store_Z_bins.append(Z_bins)

    print('Z_bins : ', Z_bins)
    

    
    ############
    # LOG BINS #
    ############
    #Let's find out the expected number of B and S events in each bin:

    # bin the parameter space of all background events
    hist_back, binedges_back = np.histogramdd([background_X_1[:N_events_back]], bins=[logbins])
    # now divide by the number of possible ensembles
    back_prom = hist_back.T.ravel()/N_ensembles_back

    # same for signal
    hist_sig, binedges_sig = np.histogramdd([signal_X_1[:N_events_sig]], bins=[logbins])
    sig_prom = hist_sig.T.ravel()/N_ensembles_sig

        

    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    back_prom_noceros = []
    for i in range(len(back_prom)):
        if back_prom[i]!=0:
            back_prom_noceros.append(back_prom[i])

    min_back = min(back_prom_noceros)

    # replace the zeros
    for i in range(len(back_prom)):
        if back_prom[i]==0:
            back_prom[i] = min_back

    # then the signif Z^binned-Asimov:
    Z_bins_logbins = ( 2* sum( ( back_prom * np.log( back_prom/(sig_prom + back_prom) ) ) + sig_prom ) )**0.5

    store_Z_bins_logbins.append(Z_bins_logbins)

    print('Z_bins_logbins : ', Z_bins_logbins)
    
    
    
    print('\n ----------------------------------- \n')
# Out:
# B_expected:  5000
# S_expected:  2
# S/$\sqrt{B}$:  0.0282842712474619
# Z_bins :  0.540515002442658
# Z_bins_logbins :  0.36681405002299916
#
#  -----------------------------------
#
# B_expected:  5000
# S_expected:  5
# S/$\sqrt{B}$:  0.07071067811865475
# Z_bins :  1.219964533676759
# Z_bins_logbins :  0.8744305915396285
#
#  -----------------------------------
#
# B_expected:  5000
# S_expected:  8
# S/$\sqrt{B}$:  0.1131370849898476
# Z_bins :  1.8012678595495184
# Z_bins_logbins :  1.3419055682886645
#
#  -----------------------------------
#
# B_expected:  5000
# S_expected:  12
# S/$\sqrt{B}$:  0.1697056274847714
# Z_bins :  2.4781624422179847
# Z_bins_logbins :  1.9167342281615405
#
#  -----------------------------------
#
# B_expected:  5000
# S_expected:  25
# S/$\sqrt{B}$:  0.35355339059327373
# Z_bins :  4.242135736897023
# Z_bins_logbins :  3.5227626124658884
#
#  -----------------------------------
#
# B_expected:  5000
# S_expected:  37
# S/$\sqrt{B}$:  0.5232590180780452
# Z_bins :  5.544781258483501
# Z_bins_logbins :  4.772969803601983
#
#  -----------------------------------
#
# B_expected:  5000
# S_expected:  50
# S/$\sqrt{B}$:  0.7071067811865475
# Z_bins :  6.756775771738885
# Z_bins_logbins :  5.964995661071329
#
#  -----------------------------------
#
# B_expected:  5000
# S_expected:  125
# S/$\sqrt{B}$:  1.7677669529663687
# Z_bins :  11.910156314009395
# Z_bins_logbins :  11.16343031715891
#
#  -----------------------------------

# %%
print(store_Z_bins)
print(store_Z_bins_logbins)
# Out:
# [0.540515002442658, 1.219964533676759, 1.8012678595495184, 2.4781624422179847, 4.242135736897023, 5.544781258483501, 6.756775771738885, 11.910156314009395]
# [0.36681405002299916, 0.8744305915396285, 1.3419055682886645, 1.9167342281615405, 3.5227626124658884, 4.772969803601983, 5.964995661071329, 11.16343031715891]

# %%
store_Z_bins = [0.540515002442658, 1.219964533676759, 1.8012678595495184, 2.4781624422179847, 4.242135736897023, 5.544781258483501, 6.756775771738885, 11.910156314009395]

store_Z_bins_logbins = [0.36681405002299916, 0.8744305915396285, 1.3419055682886645, 1.9167342281615405, 3.5227626124658884, 4.772969803601983, 5.964995661071329, 11.16343031715891]

# %%
#########
# PLOTS #
#########

posX = []

for i in range(len(SB_ratio)):
    posX.append( (B_expected*SB_ratio[i]) / ( B_expected )**0.5 )


    
plt.figure()
lw = 2

plt.plot(posX, store_Z_bins, '-ok', color='blue', lw=lw, label='100 Linear Binned Likelihood') 
plt.plot(posX, store_Z_bins_logbins, '-ok', color='lightblue', lw=lw, label='15 Log Binned Likelihood')

#plt.xlim([0.5, 10])
#plt.ylim([-0.5, 7.5])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=14)
plt.ylabel('$Z_{\mu}$ (exclusion)', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title('<B> per ensemble: %0.2d' % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()
# Out:
# <ipython-input-6-3340ebf10fa5>:15: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins, '-ok', color='blue', lw=lw, label='100 Linear Binned Likelihood')
# <ipython-input-6-3340ebf10fa5>:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_logbins, '-ok', color='lightblue', lw=lw, label='15 Log Binned Likelihood')

# %% [markdown]
# ### 2. Binned OUTPUT and MLL Asimov

# %%
#################################
# MLL Asimov-like #
#################################


store_Z_bins_XG = []

store_Z_bins_XG_15bins = []
store_Z_bins_XG_15bins_1ML = []

store_Z_bins_XG_15bins_eq = []
store_Z_bins_XG_15bins_eq_1ML = []


for iii in range(len(SB_ratio)):

    print('B_expected: ', B_expected)
    print('S_expected: ', S_expected[iii])
    print(r'S/$\sqrt{B}$: ', SsqrtB[iii])

    # Les't find the number of possible ensembles
    N_ensembles_back = len(pred_XG_SM) / B_expected
    N_ensembles_sig = len(pred_XG_NP) / S_expected[iii]



    #Let's find out the expected number of B and S events in each bin:
 
    # bin the parameter space of all background events
    hist_back, binedges_back = np.histogramdd([pred_XG_SM], bins=(100), range = [[0,1]])
    
    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    hist_back_noceros = []
    for i in range(len(hist_back)):
        if hist_back[i]!=0:
            hist_back_noceros.append(hist_back[i])

    min_back = min(hist_back_noceros)

    # replace the zeros
    for i in range(len(hist_back)):
        if hist_back[i]==0:
            hist_back[i] = min_back
    
    # now divide by the number of possible ensembles
    back_prom = hist_back/N_ensembles_back
    # normalized (sum=1)
    back_norm = hist_back/np.sum(hist_back)

    
    
    # same for signal
    hist_sig, binedges_sig = np.histogramdd([pred_XG_NP], bins=(100), range = [[0,1]])
    sig_prom = hist_sig/N_ensembles_sig
    sig_norm = hist_sig/np.sum(hist_sig)
        


    ##########################################
    # BINNED LIKELIHOOD of CLASSIFIER OUTPUT #
    ##########################################

    # then the signif Z^binned-Asimov:
    Z_bins_XG = ( 2* sum( ( back_prom * np.log( back_prom / (sig_prom+back_prom) ) ) + sig_prom ) )**0.5

    store_Z_bins_XG.append(Z_bins_XG)

    print('Z_bins_XG : ', Z_bins_XG)
    
    
    
    
    
    ######################
    # linear bins, 10 ML #
    ######################
    
    #Let's find out the expected number of B and S events in each bin:
 
    # bin the parameter space of all background events
    hist_back, binedges_back = np.histogramdd([pred_XG_SM], bins=(15), range = [[0,1]])
    
    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    hist_back_noceros = []
    for i in range(len(hist_back)):
        if hist_back[i]!=0:
            hist_back_noceros.append(hist_back[i])

    min_back = min(hist_back_noceros)

    # replace the zeros
    for i in range(len(hist_back)):
        if hist_back[i]==0:
            hist_back[i] = min_back
    
    # now divide by the number of possible ensembles
    back_prom = hist_back/N_ensembles_back
    # normalized (sum=1)
    back_norm = hist_back/np.sum(hist_back)

    
    
    # same for signal
    hist_sig, binedges_sig = np.histogramdd([pred_XG_NP], bins=(15), range = [[0,1]])
    sig_prom = hist_sig/N_ensembles_sig
    sig_norm = hist_sig/np.sum(hist_sig)
        


    ##########################################
    # BINNED LIKELIHOOD of CLASSIFIER OUTPUT #
    ##########################################

    # then the signif Z^binned-Asimov:
    Z_bins_XG_15bins = ( 2* sum( ( back_prom * np.log( back_prom / (sig_prom+back_prom) ) ) + sig_prom ) )**0.5

    store_Z_bins_XG_15bins.append(Z_bins_XG_15bins)

    print('Z_bins_XG_15bins : ', Z_bins_XG_15bins)
    
    
    
    
    
    ######################
    # linear bins, 1  ML #
    ######################
    
    #Let's find out the expected number of B and S events in each bin:
 
    # bin the parameter space of all background events
    hist_back, binedges_back = np.histogramdd([pred_XG_SM_1ML], bins=(15), range = [[0,1]])
    
    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    hist_back_noceros = []
    for i in range(len(hist_back)):
        if hist_back[i]!=0:
            hist_back_noceros.append(hist_back[i])

    min_back = min(hist_back_noceros)

    # replace the zeros
    for i in range(len(hist_back)):
        if hist_back[i]==0:
            hist_back[i] = min_back
    
    # now divide by the number of possible ensembles
    back_prom = hist_back/N_ensembles_back
    # normalized (sum=1)
    back_norm = hist_back/np.sum(hist_back)

    
    
    # same for signal
    hist_sig, binedges_sig = np.histogramdd([pred_XG_NP], bins=(15), range = [[0,1]])
    sig_prom = hist_sig/N_ensembles_sig
    sig_norm = hist_sig/np.sum(hist_sig)
        


    ##########################################
    # BINNED LIKELIHOOD of CLASSIFIER OUTPUT #
    ##########################################

    # then the signif Z^binned-Asimov:
    Z_bins_XG_15bins_1ML = ( 2* sum( ( back_prom * np.log( back_prom / (sig_prom+back_prom) ) ) + sig_prom ) )**0.5

    store_Z_bins_XG_15bins_1ML.append(Z_bins_XG_15bins_1ML)

    print('Z_bins_XG_15bins_1ML : ', Z_bins_XG_15bins_1ML)
    
    
    
    
    
    ##########################
    # non linear bins, 10 ML #
    ##########################
    
    #Let's find out the expected number of B and S events in each bin:
    # same number of B events per bin
    bin_edges_same = pd.qcut(pd.DataFrame(pred_XG_SM)[0], q = 15, precision=0, retbins = True)[1]
 
    # bin the parameter space of all background events
    hist_back, binedges_back = np.histogramdd([pred_XG_SM], bins=[bin_edges_same], range = [[0,1]])
    
    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    hist_back_noceros = []
    for i in range(len(hist_back)):
        if hist_back[i]!=0:
            hist_back_noceros.append(hist_back[i])

    min_back = min(hist_back_noceros)

    # replace the zeros
    for i in range(len(hist_back)):
        if hist_back[i]==0:
            hist_back[i] = min_back
    
    # now divide by the number of possible ensembles
    back_prom = hist_back/N_ensembles_back
    # normalized (sum=1)
    back_norm = hist_back/np.sum(hist_back)

    
    
    # same for signal
    hist_sig, binedges_sig = np.histogramdd([pred_XG_NP], bins=[bin_edges_same], range = [[0,1]])
    sig_prom = hist_sig/N_ensembles_sig
    sig_norm = hist_sig/np.sum(hist_sig)
        


    ##########################################
    # BINNED LIKELIHOOD of CLASSIFIER OUTPUT #
    ##########################################

    # then the signif Z^binned-Asimov:
    Z_bins_XG_15bins_eq = ( 2* sum( ( back_prom * np.log( back_prom / (sig_prom+back_prom) ) ) + sig_prom ) )**0.5

    store_Z_bins_XG_15bins_eq.append(Z_bins_XG_15bins_eq)

    print('Z_bins_XG_15bins_eq : ', Z_bins_XG_15bins_eq)
    
    
    
    
    
    ##########################
    # non linear bins, 1  ML #
    ##########################
    
    #Let's find out the expected number of B and S events in each bin:
    # same number of B events per bin
    bin_edges_same = pd.qcut(pd.DataFrame(pred_XG_SM_1ML)[0], q = 15, precision=0, retbins = True)[1]
 
    # bin the parameter space of all background events
    hist_back, binedges_back = np.histogramdd([pred_XG_SM_1ML], bins=[bin_edges_same], range = [[0,1]])
    
    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    hist_back_noceros = []
    for i in range(len(hist_back)):
        if hist_back[i]!=0:
            hist_back_noceros.append(hist_back[i])

    min_back = min(hist_back_noceros)

    # replace the zeros
    for i in range(len(hist_back)):
        if hist_back[i]==0:
            hist_back[i] = min_back
    
    # now divide by the number of possible ensembles
    back_prom = hist_back/N_ensembles_back
    # normalized (sum=1)
    back_norm = hist_back/np.sum(hist_back)

    
    
    # same for signal
    hist_sig, binedges_sig = np.histogramdd([pred_XG_NP_1ML], bins=[bin_edges_same], range = [[0,1]])
    sig_prom = hist_sig/N_ensembles_sig
    sig_norm = hist_sig/np.sum(hist_sig)
        


    ##########################################
    # BINNED LIKELIHOOD of CLASSIFIER OUTPUT #
    ##########################################

    # then the signif Z^binned-Asimov:
    Z_bins_XG_15bins_eq_1ML = ( 2* sum( ( back_prom * np.log( back_prom / (sig_prom+back_prom) ) ) + sig_prom ) )**0.5

    store_Z_bins_XG_15bins_eq_1ML.append(Z_bins_XG_15bins_eq_1ML)

    print('Z_bins_XG_15bins_eq_1ML : ', Z_bins_XG_15bins_eq_1ML)


        
    print('\n ----------------------------------------- \n')
# Out:
# B_expected:  5000
# S_expected:  2
# S/$\sqrt{B}$:  0.0282842712474619
# Z_bins_XG :  0.40485817093883664
# Z_bins_XG_15bins :  0.285875198632562
# Z_bins_XG_15bins_1ML :  0.281866127540429
# Z_bins_XG_15bins_eq :  0.09629921508313523
# Z_bins_XG_15bins_eq_1ML :  0.09625879171988484
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  5
# S/$\sqrt{B}$:  0.07071067811865475
# Z_bins_XG :  0.9580547702583664
# Z_bins_XG_15bins :  0.6970563583961149
# Z_bins_XG_15bins_1ML :  0.6877444630014973
# Z_bins_XG_15bins_eq :  0.2401195705414661
# Z_bins_XG_15bins_eq_1ML :  0.24001904947868274
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  8
# S/$\sqrt{B}$:  0.1131370849898476
# Z_bins_XG :  1.4609591614677144
# Z_bins_XG_15bins :  1.0893605682832666
# Z_bins_XG_15bins_1ML :  1.0754524776765586
# Z_bins_XG_15bins_eq :  0.38319490566048653
# Z_bins_XG_15bins_eq_1ML :  0.3830349200932229
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  12
# S/$\sqrt{B}$:  0.1697056274847714
# Z_bins_XG :  2.0718759987182485
# Z_bins_XG_15bins :  1.5867169948740898
# Z_bins_XG_15bins_1ML :  1.5675627296732486
# Z_bins_XG_15bins_eq :  0.5728204901158731
# Z_bins_XG_15bins_eq_1ML :  0.5725821815582443
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  25
# S/$\sqrt{B}$:  0.35355339059327373
# Z_bins_XG :  3.745070958875474
# Z_bins_XG_15bins :  3.0417337019425625
# Z_bins_XG_15bins_1ML :  3.010301270998032
# Z_bins_XG_15bins_eq :  1.1803572639017814
# Z_bins_XG_15bins_eq_1ML :  1.1798716783392935
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  37
# S/$\sqrt{B}$:  0.5232590180780452
# Z_bins_XG :  5.02370416761486
# Z_bins_XG_15bins :  4.220773049693829
# Z_bins_XG_15bins_1ML :  4.181994085320448
# Z_bins_XG_15bins_eq :  1.7297781428917
# Z_bins_XG_15bins_eq_1ML :  1.7290735741285044
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  50
# S/$\sqrt{B}$:  0.7071067811865475
# Z_bins_XG :  6.230538401178258
# Z_bins_XG_15bins :  5.369823925053057
# Z_bins_XG_15bins_1ML :  5.3255423749880135
# Z_bins_XG_15bins_eq :  2.313301528101968
# Z_bins_XG_15bins_eq_1ML :  2.312368998402441
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  125
# S/$\sqrt{B}$:  1.7677669529663687
# Z_bins_XG :  11.430970995389696
# Z_bins_XG_15bins :  10.527361418346787
# Z_bins_XG_15bins_1ML :  10.470377444097288
# Z_bins_XG_15bins_eq :  5.471523773418409
# Z_bins_XG_15bins_eq_1ML :  5.469431626020573
#
#  -----------------------------------------

# %%
print(store_Z_bins_XG)

print(store_Z_bins_XG_15bins)
print(store_Z_bins_XG_15bins_1ML)

print(store_Z_bins_XG_15bins_eq)
print(store_Z_bins_XG_15bins_eq_1ML)
# Out:
# [0.40485817093883664, 0.9580547702583664, 1.4609591614677144, 2.0718759987182485, 3.745070958875474, 5.02370416761486, 6.230538401178258, 11.430970995389696]
# [0.285875198632562, 0.6970563583961149, 1.0893605682832666, 1.5867169948740898, 3.0417337019425625, 4.220773049693829, 5.369823925053057, 10.527361418346787]
# [0.281866127540429, 0.6877444630014973, 1.0754524776765586, 1.5675627296732486, 3.010301270998032, 4.181994085320448, 5.3255423749880135, 10.470377444097288]
# [0.09629921508313523, 0.2401195705414661, 0.38319490566048653, 0.5728204901158731, 1.1803572639017814, 1.7297781428917, 2.313301528101968, 5.471523773418409]
# [0.09625879171988484, 0.24001904947868274, 0.3830349200932229, 0.5725821815582443, 1.1798716783392935, 1.7290735741285044, 2.312368998402441, 5.469431626020573]

# %%
store_Z_bins_XG = [0.40485817093883664, 0.9580547702583664, 1.4609591614677144, 2.0718759987182485, 3.745070958875474, 5.02370416761486, 6.230538401178258, 11.430970995389696]

store_Z_bins_XG_15bins = [0.285875198632562, 0.6970563583961149, 1.0893605682832666, 1.5867169948740898, 3.0417337019425625, 4.220773049693829, 5.369823925053057, 10.527361418346787]
store_Z_bins_XG_15bins_1ML = [0.281866127540429, 0.6877444630014973, 1.0754524776765586, 1.5675627296732486, 3.010301270998032, 4.181994085320448, 5.3255423749880135, 10.470377444097288]

store_Z_bins_XG_15bins_eq = [0.09629921508313523, 0.2401195705414661, 0.38319490566048653, 0.5728204901158731, 1.1803572639017814, 1.7297781428917, 2.313301528101968, 5.471523773418409]
store_Z_bins_XG_15bins_eq_1ML = [0.09625879171988484, 0.24001904947868274, 0.3830349200932229, 0.5725821815582443, 1.1798716783392935, 1.7290735741285044, 2.312368998402441, 5.469431626020573]

# %%
#########
# PLOTS #
#########

posX = []

for i in range(len(SB_ratio)):
    posX.append( (B_expected*SB_ratio[i]) / ( B_expected )**0.5 )



    
    
plt.figure()
lw = 2

plt.plot(posX, store_Z_bins_XG, '-ok', color='blue', lw=lw, label='o(x) BL (100 l.bins)') 
plt.plot(posX, store_Z_bins_XG_15bins, '-ok', color='red', lw=lw, label='o(x) BL (15 l.bins) (10ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_1ML, '-ok', color='green', lw=lw, label='o(x) BL (15 l.bins) (1ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_eq, '-ok', color='magenta', lw=lw, label='o(x) BL (15 n.l.bins) (10ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_eq_1ML, '-ok', color='darkorange', lw=lw, label='o(x) BL (15 n.l.bins) (1ML)') 

#plt.xlim([0.5, 10])
#plt.ylim([-0.5, 7.5])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=14)
plt.ylabel('$Z_{\mu}$ (exclusion)', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title("SSM Z', <B> per ensemble: %0.2d" % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()
# Out:
# <ipython-input-8-13c05c382495>:17: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG, '-ok', color='blue', lw=lw, label='o(x) BL (100 l.bins)')
# <ipython-input-8-13c05c382495>:18: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins, '-ok', color='red', lw=lw, label='o(x) BL (15 l.bins) (10ML)')
# <ipython-input-8-13c05c382495>:19: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_1ML, '-ok', color='green', lw=lw, label='o(x) BL (15 l.bins) (1ML)')
# <ipython-input-8-13c05c382495>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_eq, '-ok', color='magenta', lw=lw, label='o(x) BL (15 n.l.bins) (10ML)')
# <ipython-input-8-13c05c382495>:21: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_eq_1ML, '-ok', color='darkorange', lw=lw, label='o(x) BL (15 n.l.bins) (1ML)')

# %% [markdown]
# ### 3. MACHINE-LEARNED LIKELIHOOD with KDE

# %% [markdown]
# ##### For 10 ML

# %%
store_Z_MLL_KDE = []
store_Z_MLL_KDE_mu0 = []

store_muhat_mean_MLL = []




# FIND THE BANDWIDTH

bandwidth = np.logspace(-3.0, 0.05, 20)
print(bandwidth)

kde = KernelDensity(kernel='epanechnikov')
grid = GridSearchCV(kde, {'bandwidth': bandwidth})
grid.fit(np.c_[pred_XG_SM[:50000]])
print(grid.best_estimator_)

SM_bandwidth = grid.best_estimator_.bandwidth



kde = KernelDensity(kernel='epanechnikov')
grid = GridSearchCV(kde, {'bandwidth': bandwidth})
grid.fit(np.c_[pred_XG_NP[:50000]])
print(grid.best_estimator_)

NP_bandwidth = grid.best_estimator_.bandwidth







# aca fitteo 
kde_bkg = KernelDensity(kernel="epanechnikov", bandwidth=SM_bandwidth).fit(np.c_[pred_XG_SM, np.zeros(len(pred_XG_SM)) ])
kde_sig = KernelDensity(kernel="epanechnikov", bandwidth=NP_bandwidth).fit(np.c_[pred_XG_NP, np.ones(len(pred_XG_NP)) ])


# elijo los valores para graficar y calcular la significancia de Asimov
min_val = np.min([np.min(pred_XG_SM),np.min(pred_XG_NP)])
max_val = np.max([np.max(pred_XG_SM),np.max(pred_XG_NP)])

s_vals = np.linspace(min_val,max_val,100)





# evaluo las densidades en cada valor de s. esto es mas o menos equivalente a tomar bines continuos
dens_bkg = np.exp(kde_bkg.score_samples(np.c_[s_vals, np.zeros(len(s_vals)) ]) )
dens_sig = np.exp(kde_sig.score_samples(np.c_[s_vals, np.ones(len(s_vals)) ]) )





# PERO NO ESTA NORMALIZADO A 1 el area
# Area
factor_aux_SM = sum(dens_bkg*(s_vals[1]-s_vals[0]))
factor_aux_NP = sum(dens_sig*(s_vals[1]-s_vals[0]))

# normalizo
dens_bkg = dens_bkg / factor_aux_SM
dens_sig = dens_sig / factor_aux_NP






# grafico y verifico si la densidad es una buena aproximacion

plt.figure()

plt.hist(pred_XG_SM,density=True,bins=50,color='red',alpha=0.25,label='Sampled $p_{b}$');
plt.plot(s_vals,dens_bkg,color='red',label='Learned $p_{b}$',linestyle='dashed');

plt.hist(pred_XG_NP,density=True,bins=50,color='blue',alpha=0.25,label='Sampled $p_{s}$');
plt.plot(s_vals,dens_sig,color='blue',label='Learned $p_{s}$',linestyle='dashed');

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("o(x)",fontsize=15)
plt.ylabel("PDF",fontsize=14)
plt.grid()
plt.legend(fontsize=12)
#plt.title(r"Signal: W'$\rightarrow$XY, Background: QCD", fontsize=14)
#plt.savefig('images/' + 'Wprime-output.pdf', format="pdf", bbox_inches="tight")
plt.show()



  
    
    

# all the dataset though the SM and NP KDEs
# with this we'll form the toy samples for MLL

KDE_SM_pred_SM = np.exp(kde_bkg.score_samples(np.c_[pred_XG_SM, np.zeros(len(pred_XG_SM)) ]) )
KDE_NP_pred_SM = np.exp(kde_sig.score_samples(np.c_[pred_XG_SM, np.ones(len(pred_XG_SM)) ]) )

# Normalize

KDE_SM_pred_SM = KDE_SM_pred_SM / factor_aux_SM
KDE_NP_pred_SM = KDE_NP_pred_SM / factor_aux_NP




indices = [i for i in range(len(KDE_NP_pred_SM))]


########################
# METHOD: MLL with KDE #
########################

print('\n-------------------------------------')
print(' MLL with KDE')
print('-------------------------------------')




for iii in range(len(SB_ratio)):
    
    print('B_expected: ', B_expected)
    print('S_expected: ', S_expected[iii])
    print(r'S/$\sqrt{B}$: ', SsqrtB[iii])
    print('n_ensembles (initial): ', n_ensembles, '\n')

    
    

    ###########
    # NOW MLL #
    ###########

    # to construct ensembles B and S events are taken from Poisson distributions
    mu = S_expected[iii] + B_expected


    # Letś find the number of events per ensemble such that we get at least one ensemble populated if events are taken from a Poisson distribution

    # around the mean its populated so let's try (proposed range to be checked)
    list_events_per_ensembles = [i for i in range(int(mu*0.9),int(mu*1.1))]
    to_check = len(list_events_per_ensembles)

    # I want at least one ensemble populated
    list_nums_ensembles = [ int( poisson.pmf(list_events_per_ensembles[i],mu)*n_ensembles ) for i in range(len(list_events_per_ensembles)) ]



    # Remove from the list the elements without at least 1 ensemble possible
    for i in range(len(list_events_per_ensembles)):
        if list_nums_ensembles[i] > 1:
            list_events_per_ensembles = list_events_per_ensembles[i:]
            list_nums_ensembles = list_nums_ensembles[i:]
            break


    for i in range(len(list_events_per_ensembles)):
        if list_nums_ensembles[i] < 1:
            list_events_per_ensembles = list_events_per_ensembles[:i]
            list_nums_ensembles = list_nums_ensembles[:i]
            break

    print('\n If ', to_check, ' = ', len(list_events_per_ensembles), '   then the proposed range has to be extended')

    print('n_ensembles (actual): ', sum(list_nums_ensembles))



    # lists of S and B events per ensemble, w.r.t the total of number of events per ensemble found above:

    p_berno = S_expected[iii]/(S_expected[iii]+B_expected)

    list_S_per_ensembles = []
    list_B_per_ensembles = []

    for jj in range(len(list_events_per_ensembles)):
        list_S_per_ensembles.append( int(p_berno * list_events_per_ensembles[jj]) )
        list_B_per_ensembles.append( list_events_per_ensembles[jj] - int(p_berno * list_events_per_ensembles[jj]) )

    ######
    # NOW I HAVE 4 LISTS:
    # list_events_per_ensembles     list with the number of events per ensemble (its a range)
    # list_nums_ensembles           list with the number of ensembles, w.r.t the 1st list
    # list_S_per_ensembles          list with the number of signal events in each ensembles, w.r.t the 1st list
    # list_B_per_ensembles          list with the number of background events in each ensembles, w.r.t the 1st list
    ######



    print('\n This may take long... \n')


    # NOW LETS APPLY THE METHOD

    muhat_selected_list = []
    q_muhat = []
    q_muhat_mu0 = []

    for bb in range(len(list_nums_ensembles)):

        for kk in range(list_nums_ensembles[bb]):

            # KDE
            ran_ind = np.random.choice(indices, list_B_per_ensembles[bb])

            KDE_SM_pred_SM_shuf = []
            KDE_NP_pred_SM_shuf = []

            for i in ran_ind:
                KDE_SM_pred_SM_shuf.append(KDE_SM_pred_SM[i])
                KDE_NP_pred_SM_shuf.append(KDE_NP_pred_SM[i])

            KDE_SM_pred_SM_shuf  = np.array(KDE_SM_pred_SM_shuf)
            KDE_NP_pred_SM_shuf  = np.array(KDE_NP_pred_SM_shuf)



            # p_b(o(x_ensemble)) =    concatenate: p_b(o(B_ensemble)) and p_b(o(S_ensemble))  NOTICE THE o(x)
            prob_x_given_B = np.ndarray.tolist( KDE_SM_pred_SM_shuf ) #+ np.ndarray.tolist( KDE_SM_pred_NP_shuf )

            # p_s(o(x_ensemble)) =    concatenate: p_s(o(B_ensemble)) and p_s(o(S_ensemble))  NOTICE THE o(x)
            prob_x_given_S = np.ndarray.tolist( KDE_NP_pred_SM_shuf ) #+ np.ndarray.tolist( KDE_NP_pred_NP_shuf )









            # NOW WE HAVE p_{s,b}(x_ensemble) for this particular ensemble
            # WE NEED TO ESTIMATE mu_hat for this particular ensemble
            # we are going to obtain a mu_hat with a grid of values for this particular ensemble



            mu_hat_condition_equal_1 = []

            # grid, mu_hat is around 1
            muhat_test = np.arange(0., 1.5, 0.1).tolist()

            B_prob_x_given_B = [x * B_expected for x in prob_x_given_B]

            for vv in range(len(muhat_test)):

                mu_hat_condition_equal_1.append( sum ( [(x*1.) / ( (x * muhat_test[vv] * S_expected[iii]) + y ) for x, y in zip(prob_x_given_S, B_prob_x_given_B)] ) )



            muhat_selected = 0

            # from the grid, select the mu_hat such that the condition is equal to 1
            if mu_hat_condition_equal_1[0] < mu_hat_condition_equal_1[-1]:
                for ll in range(len(mu_hat_condition_equal_1)):
                    if mu_hat_condition_equal_1[ll] -1 > 0:
                        muhat_selected = muhat_test[ll]
                        break


            if mu_hat_condition_equal_1[0] > mu_hat_condition_equal_1[-1]:
                for ll in range(len(mu_hat_condition_equal_1)):
                    if mu_hat_condition_equal_1[ll] -1 < 0:
                        muhat_selected = muhat_test[ll]
                        break


            muhat_selected_list.append(muhat_selected)



            # NOW THAT WE HAVE mu_hat FOR THIS ENSEMBLE, CALCULATE THE TEST STATISTIC FOR THIS ENSEMBLE
            # and append it (we need the median over lots of ensembles)
            #q_muhat.append( 2 * ( (-1.*muhat_selected * S_expected[iii]) + sum( [np.log( 1 + ( (muhat_selected*S_expected[iii]/B_expected) * (x / y) ) ) for x, y in zip(prob_x_given_S, prob_x_given_B)] ) ) )
            # EXCLUSION:
            q_muhat.append( 2 * ( ( (1.-muhat_selected) * S_expected[iii] ) - sum( [np.log( ( (B_expected*y) + (S_expected[iii]*x) ) / ( (B_expected*y) + (muhat_selected*S_expected[iii]*x) ) ) for x, y in zip(prob_x_given_S, prob_x_given_B)] )
    ) )
            q_muhat_mu0.append( 2 * ( ( (1.-0.) * S_expected[iii] ) - sum( [np.log( ( (B_expected*y) + (S_expected[iii]*x) ) / ( (B_expected*y) + (0.*S_expected[iii]*x) ) ) for x, y in zip(prob_x_given_S, prob_x_given_B)] )
    ) )


    # Histogram of q_muhats

    weights = np.ones_like(q_muhat)/float(len(q_muhat))
    nMIX, binsMIX, patchesMIX = plt.hist(q_muhat, 25, weights=weights, histtype='step', color='blue', linewidth=2)
    #plt.xlim(0,1)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.xlabel("$q_0(\hat{\mu})$",fontsize=16)
    plt.ylabel("Fraction of ensembles",fontsize=16)
    plt.title(r"$\bar{B}$=%0.2i, $\bar{S}=$%0.2i" % (B_expected,S_expected[iii]),fontsize=14)
    plt.grid()
    #plt.legend(fontsize=14)
    plt.show()


    # Finally calculate muhat_mean and Z_gaussian

    # Remove nan if any
    q_muhat_mu0 = [x for x in q_muhat_mu0 if x == x]
    for jk in range(len(q_muhat_mu0)):
        if q_muhat_mu0[jk] < 0:
            q_muhat_mu0[jk] = 0

    q_muhat_median_mu0 = np.median(q_muhat_mu0)

    Z_KDE_mu0 = abs(q_muhat_median_mu0)**0.5
    store_Z_MLL_KDE_mu0.append(Z_KDE_mu0)


    # Finally calculate muhat_mean and Z_gaussian
    muhat_mean = np.mean(muhat_selected_list)
    store_muhat_mean_MLL.append(muhat_mean)

    # Remove nan if any
    q_muhat = [x for x in q_muhat if x == x]
    for jk in range(len(q_muhat)):
        if q_muhat[jk] < 0:
            q_muhat[jk] = 0

    q_muhat_median = np.median(q_muhat)

    Z_KDE = abs(q_muhat_median)**0.5
    store_Z_MLL_KDE.append(Z_KDE)

    print('muhat mean: ', muhat_mean)
    print('median q_muhat: ', q_muhat_median)
    print('Z_KDE: ', Z_KDE)
    print('Z_KDE mu=0: ', Z_KDE_mu0)
    
    print('\n ----------------------------------------- \n')
# Out:
# [1.00000000e-03 1.44719254e-03 2.09436625e-03 3.03095122e-03
#  4.38637001e-03 6.34792196e-03 9.18666532e-03 1.32948735e-02
#  1.92402418e-02 2.78443345e-02 4.02961132e-02 5.83162345e-02
#  8.43948197e-02 1.22135554e-01 1.76753662e-01 2.55796582e-01
#  3.70186906e-01 5.35731729e-01 7.75306963e-01 1.12201845e+00]
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [          -inf           -inf           -inf 15426.19952776
#  15431.00031555 15432.64545917 15421.14798038 15379.01010674
#  15258.17204651 14964.98893852 14414.68526961 13569.41240746
#  12420.19699423 10965.56296886  9177.65392088  7005.9951304
#   4525.64068524  1758.75496421 -1204.59429435 -4376.95696852]
#   warnings.warn(
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:929: RuntimeWarning: invalid value encountered in subtract
#   array_stds = np.sqrt(np.average((array -
# KernelDensity(bandwidth=0.0063479219593504735, kernel='epanechnikov')
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [          -inf           -inf           -inf           -inf
#  24912.85279312 24538.15925074 23876.8876263  22795.07862535
#  21300.72743703 19447.68087189 17318.00206121 15002.06331192
#  12558.96024561 10008.5107967   7344.26242422  4612.82357418
#   1819.62997164 -1058.43560332 -3815.71773456 -5555.40598847]
#   warnings.warn(
# /home/andres/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:929: RuntimeWarning: invalid value encountered in subtract
#   array_stds = np.sqrt(np.average((array -
# KernelDensity(bandwidth=0.004386370005779536, kernel='epanechnikov')
# -------------------------------------
#  MLL with KDE
# -------------------------------------
# B_expected:  5000
# S_expected:  2
# S/$\sqrt{B}$:  0.0282842712474619
# n_ensembles (initial):  5000
#
#
#  If  1001  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4759
#
#  This may take long...
# muhat mean:  0.16736709392729565
# median q_muhat:  0.022236331685770105
# Z_KDE:  0.14911851556989864
# Z_KDE mu=0:  0.0
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  5
# S/$\sqrt{B}$:  0.07071067811865475
# n_ensembles (initial):  5000
#
#
#  If  1001  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4757
#
#  This may take long...
# muhat mean:  0.3252259827622451
# median q_muhat:  0.5291837510113098
# Z_KDE:  0.7274501708098705
# Z_KDE mu=0:  0.668193975084249
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  8
# S/$\sqrt{B}$:  0.1131370849898476
# n_ensembles (initial):  5000
#
#
#  If  1001  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4757
#
#  This may take long...
# muhat mean:  0.32470044145469834
# median q_muhat:  1.5347776109072644
# Z_KDE:  1.238861417151759
# Z_KDE mu=0:  1.204924479665469
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  12
# S/$\sqrt{B}$:  0.1697056274847714
# n_ensembles (initial):  5000
#
#
#  If  1003  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4757
#
#  This may take long...
# muhat mean:  0.2633172167332352
# median q_muhat:  3.4120776777415234
# Z_KDE:  1.8471810083858926
# Z_KDE mu=0:  1.8292384654230898
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  25
# S/$\sqrt{B}$:  0.35355339059327373
# n_ensembles (initial):  5000
#
#
#  If  1005  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4753
#
#  This may take long...
# muhat mean:  0.1428361035135704
# median q_muhat:  12.820165584919856
# Z_KDE:  3.5805258810571186
# Z_KDE mu=0:  3.578100402562895
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  37
# S/$\sqrt{B}$:  0.5232590180780452
# n_ensembles (initial):  5000
#
#
#  If  1007  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4751
#
#  This may take long...
# muhat mean:  0.10648284571669123
# median q_muhat:  23.704451080505734
# Z_KDE:  4.8687217090839905
# Z_KDE mu=0:  4.885511019561551
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  50
# S/$\sqrt{B}$:  0.7071067811865475
# n_ensembles (initial):  5000
#
#
#  If  1010  =  347    then the proposed range has to be extended
# n_ensembles (actual):  4754
#
#  This may take long...
# muhat mean:  0.08931426167437947
# median q_muhat:  36.806571734579904
# Z_KDE:  6.066841990243351
# Z_KDE mu=0:  6.0982190210522
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  125
# S/$\sqrt{B}$:  1.7677669529663687
# n_ensembles (initial):  5000
#
#
#  If  1025  =  349    then the proposed range has to be extended
# n_ensembles (actual):  4744
#
#  This may take long...
# muhat mean:  0.06243676222596965
# median q_muhat:  124.6135340107391
# Z_KDE:  11.16304322354523
# Z_KDE mu=0:  11.305337234638943
#
#  -----------------------------------------

# %%
print(store_Z_MLL_KDE)
print(store_Z_MLL_KDE_mu0)

print(store_muhat_mean_MLL)
# Out:
# [0.14911851556989864, 0.7274501708098705, 1.238861417151759, 1.8471810083858926, 3.5805258810571186, 4.8687217090839905, 6.066841990243351, 11.16304322354523]
# [0.0, 0.668193975084249, 1.204924479665469, 1.8292384654230898, 3.578100402562895, 4.885511019561551, 6.0982190210522, 11.305337234638943]
# [0.16736709392729565, 0.3252259827622451, 0.32470044145469834, 0.2633172167332352, 0.1428361035135704, 0.10648284571669123, 0.08931426167437947, 0.06243676222596965]

# %%
store_Z_MLL_KDE = [0.14911851556989864, 0.7274501708098705, 1.238861417151759, 1.8471810083858926, 3.5805258810571186, 4.8687217090839905, 6.066841990243351, 11.16304322354523]
store_Z_MLL_KDE_mu0 = [0.0, 0.668193975084249, 1.204924479665469, 1.8292384654230898, 3.578100402562895, 4.885511019561551, 6.0982190210522, 11.305337234638943]

store_muhat_mean_MLL = [0.16736709392729565, 0.3252259827622451, 0.32470044145469834, 0.2633172167332352, 0.1428361035135704, 0.10648284571669123, 0.08931426167437947, 0.06243676222596965]

# %% [markdown]
# ##### For 1 ML

# %%
store_Z_KDE_bins = []

store_Z_MLL_KDE_1ML = []
store_Z_MLL_KDE_mu0_1ML = []

store_muhat_mean_MLL_1ML = []




# FIND THE BANDWIDTH

# bandwidth = np.logspace(-3.0, 0.05, 20)
# print(bandwidth)

# kde = KernelDensity(kernel='epanechnikov')
# grid = GridSearchCV(kde, {'bandwidth': bandwidth})
# grid.fit(np.c_[pred_XG_SM_1ML[:50000]])
# # print(grid.best_estimator_)

# SM_bandwidth_1ML = grid.best_estimator_.bandwidth
SM_bandwidth_1ML = SM_bandwidth


# kde = KernelDensity(kernel='epanechnikov')
# grid = GridSearchCV(kde, {'bandwidth': bandwidth})
# grid.fit(np.c_[pred_XG_NP_1ML[:50000]])
# print(grid.best_estimator_)

# NP_bandwidth_1ML = grid.best_estimator_.bandwidth
NP_bandwidth_1ML = NP_bandwidth






# aca fitteo 
kde_bkg_1ML = KernelDensity(kernel="epanechnikov", bandwidth=SM_bandwidth_1ML).fit(np.c_[pred_XG_SM_1ML, np.zeros(len(pred_XG_SM_1ML)) ])
kde_sig_1ML = KernelDensity(kernel="epanechnikov", bandwidth=NP_bandwidth_1ML).fit(np.c_[pred_XG_NP_1ML, np.ones(len(pred_XG_NP_1ML)) ])


# elijo los valores para graficar y calcular la significancia de Asimov
min_val_1ML = np.min([np.min(pred_XG_SM_1ML),np.min(pred_XG_NP_1ML)])
max_val_1ML = np.max([np.max(pred_XG_SM_1ML),np.max(pred_XG_NP_1ML)])

s_vals_1ML = np.linspace(min_val_1ML,max_val_1ML,100)





# evaluo las densidades en cada valor de s. esto es mas o menos equivalente a tomar bines continuos
dens_bkg_1ML = np.exp(kde_bkg_1ML.score_samples(np.c_[s_vals_1ML, np.zeros(len(s_vals_1ML)) ]) )
dens_sig_1ML = np.exp(kde_sig_1ML.score_samples(np.c_[s_vals_1ML, np.ones(len(s_vals_1ML)) ]) )





# PERO NO ESTA NORMALIZADO A 1 el area
# Area
factor_aux_SM_1ML = sum(dens_bkg_1ML*(s_vals_1ML[1]-s_vals_1ML[0]))
factor_aux_NP_1ML = sum(dens_sig_1ML*(s_vals_1ML[1]-s_vals_1ML[0]))

# normalizo
dens_bkg_1ML = dens_bkg_1ML / factor_aux_SM_1ML
dens_sig_1ML = dens_sig_1ML / factor_aux_NP_1ML






# grafico y verifico si la densidad es una buena aproximacion

plt.figure()

plt.hist(pred_XG_SM_1ML,density=True,bins=100,color='red',alpha=0.25,label='Sampled $p_{b}$');
plt.plot(s_vals_1ML,dens_bkg_1ML,color='red',label='Learned $p_{b}$',linestyle='dashed');

plt.hist(pred_XG_NP_1ML,density=True,bins=100,color='blue',alpha=0.25,label='Sampled $p_{s}$');
plt.plot(s_vals_1ML,dens_sig_1ML,color='blue',label='Learned $p_{s}$',linestyle='dashed');

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("o(x)",fontsize=15)
plt.ylabel("PDF",fontsize=14)
plt.grid()
plt.legend(fontsize=12)
#plt.title(r"Signal: W'$\rightarrow$XY, Background: QCD", fontsize=14)
#plt.savefig('images/' + 'Wprime-output.pdf', format="pdf", bbox_inches="tight")
plt.show()



  
    
    

# all the dataset though the SM and NP KDEs
# with this we'll form the toy samples for MLL

KDE_SM_pred_SM_1ML = np.exp(kde_bkg_1ML.score_samples(np.c_[pred_XG_SM_1ML, np.zeros(len(pred_XG_SM_1ML)) ]) )
KDE_NP_pred_SM_1ML = np.exp(kde_sig_1ML.score_samples(np.c_[pred_XG_SM_1ML, np.ones(len(pred_XG_SM_1ML)) ]) )

# Normalize

KDE_SM_pred_SM_1ML = KDE_SM_pred_SM_1ML / factor_aux_SM_1ML
KDE_NP_pred_SM_1ML = KDE_NP_pred_SM_1ML / factor_aux_NP_1ML





indices = [i for i in range(len(KDE_NP_pred_SM))]


########################
# METHOD: MLL with KDE #
########################

print('\n-------------------------------------')
print(' MLL with KDE')
print('-------------------------------------')




for iii in range(len(SB_ratio)):
    
    print('B_expected: ', B_expected)
    print('S_expected: ', S_expected[iii])
    print(r'S/$\sqrt{B}$: ', SsqrtB[iii])
    print('n_ensembles (initial): ', n_ensembles, '\n')
    
    
    ####################
    # 1st a binned KDE #
    ####################
    
    # Bd: binned KDE background
    Bd = B_expected*dens_bkg_1ML*(s_vals_1ML[1]-s_vals_1ML[0])




    # If a bins has no expected background events replace that zero for the minimum B_bin=/=0

    # find the minimum
    Bd_noceros = []
    for i in range(len(Bd)):
        if Bd[i]!=0:
            Bd_noceros.append(Bd[i])

    min_back = min(Bd_noceros)

    # replace the zeros
    for i in range(len(Bd)):
        if Bd[i]==0:
            Bd[i] = min_back


    # Sd: binned KDE signal
    Sd = SsqrtB[iii]*np.sqrt(B_expected)*dens_sig_1ML*(s_vals_1ML[1]-s_vals_1ML[0])

    #Z_KDE_bins = np.sqrt(2.0*np.sum(((Sd+Bd)*np.log(1.0+Sd/Bd)-Sd))) # Discovery
    Z_KDE_bins = np.sqrt(2.0*np.sum(Bd*np.log(Bd/(Sd+Bd))+Sd)) # Exclusion

    store_Z_KDE_bins.append(Z_KDE_bins)

    print('Z_KDE_bins : ', Z_KDE_bins)
    
    

    ###########
    # NOW MLL #
    ###########

    # to construct ensembles B and S events are taken from Poisson distributions
    mu = S_expected[iii] + B_expected


    # Letś find the number of events per ensemble such that we get at least one ensemble populated if events are taken from a Poisson distribution

    # around the mean its populated so let's try (proposed range to be checked)
    list_events_per_ensembles = [i for i in range(int(mu*0.9),int(mu*1.1))]
    to_check = len(list_events_per_ensembles)

    # I want at least one ensemble populated
    list_nums_ensembles = [ int( poisson.pmf(list_events_per_ensembles[i],mu)*n_ensembles ) for i in range(len(list_events_per_ensembles)) ]



    # Remove from the list the elements without at least 1 ensemble possible
    for i in range(len(list_events_per_ensembles)):
        if list_nums_ensembles[i] > 1:
            list_events_per_ensembles = list_events_per_ensembles[i:]
            list_nums_ensembles = list_nums_ensembles[i:]
            break


    for i in range(len(list_events_per_ensembles)):
        if list_nums_ensembles[i] < 1:
            list_events_per_ensembles = list_events_per_ensembles[:i]
            list_nums_ensembles = list_nums_ensembles[:i]
            break

    print('\n If ', to_check, ' = ', len(list_events_per_ensembles), '   then the proposed range has to be extended')

    print('n_ensembles (actual): ', sum(list_nums_ensembles))



    # lists of S and B events per ensemble, w.r.t the total of number of events per ensemble found above:

    p_berno = S_expected[iii]/(S_expected[iii]+B_expected)

    list_S_per_ensembles = []
    list_B_per_ensembles = []

    for jj in range(len(list_events_per_ensembles)):
        list_S_per_ensembles.append( int(p_berno * list_events_per_ensembles[jj]) )
        list_B_per_ensembles.append( list_events_per_ensembles[jj] - int(p_berno * list_events_per_ensembles[jj]) )

    ######
    # NOW I HAVE 4 LISTS:
    # list_events_per_ensembles     list with the number of events per ensemble (its a range)
    # list_nums_ensembles           list with the number of ensembles, w.r.t the 1st list
    # list_S_per_ensembles          list with the number of signal events in each ensembles, w.r.t the 1st list
    # list_B_per_ensembles          list with the number of background events in each ensembles, w.r.t the 1st list
    ######



    print('\n This may take long... \n')


    # NOW LETS APPLY THE METHOD

    muhat_selected_list = []
    q_muhat = []
    q_muhat_mu0 = []

    for bb in range(len(list_nums_ensembles)):

        for kk in range(list_nums_ensembles[bb]):

            # KDE
            ran_ind = np.random.choice(indices, list_B_per_ensembles[bb])

            KDE_SM_pred_SM_shuf = []
            KDE_NP_pred_SM_shuf = []

            for i in ran_ind:
                KDE_SM_pred_SM_shuf.append(KDE_SM_pred_SM_1ML[i])
                KDE_NP_pred_SM_shuf.append(KDE_NP_pred_SM_1ML[i])

            KDE_SM_pred_SM_shuf  = np.array(KDE_SM_pred_SM_shuf)
            KDE_NP_pred_SM_shuf  = np.array(KDE_NP_pred_SM_shuf)



            # p_b(o(x_ensemble)) =    concatenate: p_b(o(B_ensemble)) and p_b(o(S_ensemble))  NOTICE THE o(x)
            prob_x_given_B = np.ndarray.tolist( KDE_SM_pred_SM_shuf ) #+ np.ndarray.tolist( KDE_SM_pred_NP_shuf )

            # p_s(o(x_ensemble)) =    concatenate: p_s(o(B_ensemble)) and p_s(o(S_ensemble))  NOTICE THE o(x)
            prob_x_given_S = np.ndarray.tolist( KDE_NP_pred_SM_shuf ) #+ np.ndarray.tolist( KDE_NP_pred_NP_shuf )









            # NOW WE HAVE p_{s,b}(x_ensemble) for this particular ensemble
            # WE NEED TO ESTIMATE mu_hat for this particular ensemble
            # we are going to obtain a mu_hat with a grid of values for this particular ensemble



            mu_hat_condition_equal_1 = []

            # grid, mu_hat is around 1
            muhat_test = np.arange(0., 1.5, 0.1).tolist()

            B_prob_x_given_B = [x * B_expected for x in prob_x_given_B]

            for vv in range(len(muhat_test)):

                mu_hat_condition_equal_1.append( sum ( [(x*1.) / ( (x * muhat_test[vv] * S_expected[iii]) + y ) for x, y in zip(prob_x_given_S, B_prob_x_given_B)] ) )



            muhat_selected = 0

            # from the grid, select the mu_hat such that the condition is equal to 1
            if mu_hat_condition_equal_1[0] < mu_hat_condition_equal_1[-1]:
                for ll in range(len(mu_hat_condition_equal_1)):
                    if mu_hat_condition_equal_1[ll] -1 > 0:
                        muhat_selected = muhat_test[ll]
                        break


            if mu_hat_condition_equal_1[0] > mu_hat_condition_equal_1[-1]:
                for ll in range(len(mu_hat_condition_equal_1)):
                    if mu_hat_condition_equal_1[ll] -1 < 0:
                        muhat_selected = muhat_test[ll]
                        break


            muhat_selected_list.append(muhat_selected)



            # NOW THAT WE HAVE mu_hat FOR THIS ENSEMBLE, CALCULATE THE TEST STATISTIC FOR THIS ENSEMBLE
            # and append it (we need the median over lots of ensembles)
            #q_muhat.append( 2 * ( (-1.*muhat_selected * S_expected[iii]) + sum( [np.log( 1 + ( (muhat_selected*S_expected[iii]/B_expected) * (x / y) ) ) for x, y in zip(prob_x_given_S, prob_x_given_B)] ) ) )
            # EXCLUSION:
            q_muhat.append( 2 * ( ( (1.-muhat_selected) * S_expected[iii] ) - sum( [np.log( ( (B_expected*y) + (S_expected[iii]*x) ) / ( (B_expected*y) + (muhat_selected*S_expected[iii]*x) ) ) for x, y in zip(prob_x_given_S, prob_x_given_B)] )
    ) )
            q_muhat_mu0.append( 2 * ( ( (1.-0.) * S_expected[iii] ) - sum( [np.log( ( (B_expected*y) + (S_expected[iii]*x) ) / ( (B_expected*y) + (0.*S_expected[iii]*x) ) ) for x, y in zip(prob_x_given_S, prob_x_given_B)] )
    ) )


    # Histogram of q_muhats

    weights = np.ones_like(q_muhat)/float(len(q_muhat))
    nMIX, binsMIX, patchesMIX = plt.hist(q_muhat, 25, weights=weights, histtype='step', color='blue', linewidth=2)
    #plt.xlim(0,1)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.xlabel("$q_0(\hat{\mu})$",fontsize=16)
    plt.ylabel("Fraction of ensembles",fontsize=16)
    plt.title(r"$\bar{B}$=%0.2i, $\bar{S}=$%0.2i" % (B_expected,S_expected[iii]),fontsize=14)
    plt.grid()
    #plt.legend(fontsize=14)
    plt.show()


    # Finally calculate muhat_mean and Z_gaussian

    # Remove nan if any
    q_muhat_mu0 = [x for x in q_muhat_mu0 if x == x]

    q_muhat_median_mu0 = np.median(q_muhat_mu0)

    Z_KDE_mu0 = abs(q_muhat_median_mu0)**0.5
    store_Z_MLL_KDE_mu0_1ML.append(Z_KDE_mu0)


    # Finally calculate muhat_mean and Z_gaussian
    muhat_mean = np.mean(muhat_selected_list)
    store_muhat_mean_MLL_1ML.append(muhat_mean)

    # Remove nan if any
    q_muhat = [x for x in q_muhat if x == x]

    q_muhat_median = np.median(q_muhat)

    Z_KDE = abs(q_muhat_median)**0.5
    store_Z_MLL_KDE_1ML.append(Z_KDE)

    print('muhat mean: ', muhat_mean)
    print('median q_muhat: ', q_muhat_median)
    print('Z_KDE: ', Z_KDE)
    print('Z_KDE mu=0: ', Z_KDE_mu0)
    
    print('\n ----------------------------------------- \n')
# Out:
# -------------------------------------
#  MLL with KDE
# -------------------------------------
# B_expected:  5000
# S_expected:  2
# S/$\sqrt{B}$:  0.0282842712474619
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  0.3975860557705607
#
#  If  1001  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4759
#
#  This may take long...
# muhat mean:  0.16869090144988444
# median q_muhat:  0.007863195961199776
# Z_KDE:  0.08867466358097885
# Z_KDE mu=0:  0.4308994900194646
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  5
# S/$\sqrt{B}$:  0.07071067811865475
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  0.942795502511029
#
#  If  1001  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4757
#
#  This may take long...
# muhat mean:  0.347887323943662
# median q_muhat:  0.3662276637106423
# Z_KDE:  0.6051674674919681
# Z_KDE mu=0:  0.4265119352332025
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  8
# S/$\sqrt{B}$:  0.1131370849898476
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  1.439882553140714
#
#  If  1001  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4757
#
#  This may take long...
# muhat mean:  0.35955434097120037
# median q_muhat:  1.2942743059916832
# Z_KDE:  1.1376617713502037
# Z_KDE mu=0:  1.0639352486582185
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  12
# S/$\sqrt{B}$:  0.1697056274847714
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  2.0450090357335555
#
#  If  1003  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4757
#
#  This may take long...
# muhat mean:  0.28343493798612573
# median q_muhat:  3.2930343471275805
# Z_KDE:  1.8146719668104152
# Z_KDE mu=0:  1.7800585785007905
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  25
# S/$\sqrt{B}$:  0.35355339059327373
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  3.706110985678521
#
#  If  1005  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4753
#
#  This may take long...
# muhat mean:  0.15699558173784978
# median q_muhat:  12.416949397882043
# Z_KDE:  3.5237692032654526
# Z_KDE mu=0:  3.504408792761899
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  37
# S/$\sqrt{B}$:  0.5232590180780452
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  4.976904187383382
#
#  If  1007  =  346    then the proposed range has to be extended
# n_ensembles (actual):  4751
#
#  This may take long...
# muhat mean:  0.11793306672279522
# median q_muhat:  23.257519815409637
# Z_KDE:  4.822605085989276
# Z_KDE mu=0:  4.822937855934482
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  50
# S/$\sqrt{B}$:  0.7071067811865475
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  6.176518826113003
#
#  If  1010  =  347    then the proposed range has to be extended
# n_ensembles (actual):  4754
#
#  This may take long...
# muhat mean:  0.0981909970551115
# median q_muhat:  36.215945302597035
# Z_KDE:  6.017968536192012
# Z_KDE mu=0:  6.03868180469564
#
#  -----------------------------------------
#
# B_expected:  5000
# S_expected:  125
# S/$\sqrt{B}$:  1.7677669529663687
# n_ensembles (initial):  5000
#
# Z_KDE_bins :  11.344972689800201
#
#  If  1025  =  349    then the proposed range has to be extended
# n_ensembles (actual):  4744
#
#  This may take long...
# muhat mean:  0.06804384485666104
# median q_muhat:  123.46395794210645
# Z_KDE:  11.111433658268696
# Z_KDE mu=0:  11.24789422005881
#
#  -----------------------------------------

# %%
print(store_Z_KDE_bins)

print(store_Z_MLL_KDE_1ML)
print(store_Z_MLL_KDE_mu0_1ML)

print(store_muhat_mean_MLL_1ML)
# Out:
# [0.3975860557705607, 0.942795502511029, 1.439882553140714, 2.0450090357335555, 3.706110985678521, 4.976904187383382, 6.176518826113003, 11.344972689800201]
# [0.08867466358097885, 0.6051674674919681, 1.1376617713502037, 1.8146719668104152, 3.5237692032654526, 4.822605085989276, 6.017968536192012, 11.111433658268696]
# [0.4308994900194646, 0.4265119352332025, 1.0639352486582185, 1.7800585785007905, 3.504408792761899, 4.822937855934482, 6.03868180469564, 11.24789422005881]
# [0.16869090144988444, 0.347887323943662, 0.35955434097120037, 0.28343493798612573, 0.15699558173784978, 0.11793306672279522, 0.0981909970551115, 0.06804384485666104]

# %%
store_Z_KDE_bins = [0.3975860557705607, 0.942795502511029, 1.439882553140714, 2.0450090357335555, 3.706110985678521, 4.976904187383382, 6.176518826113003, 11.344972689800201]

store_Z_MLL_KDE_1ML = [0.08867466358097885, 0.6051674674919681, 1.1376617713502037, 1.8146719668104152, 3.5237692032654526, 4.822605085989276, 6.017968536192012, 11.111433658268696]
store_Z_MLL_KDE_mu0_1ML = [0.4308994900194646, 0.4265119352332025, 1.0639352486582185, 1.7800585785007905, 3.504408792761899, 4.822937855934482, 6.03868180469564, 11.24789422005881]

store_muhat_mean_MLL_1ML = [0.16869090144988444, 0.347887323943662, 0.35955434097120037, 0.28343493798612573, 0.15699558173784978, 0.11793306672279522, 0.0981909970551115, 0.06804384485666104]

# %%
#########
# PLOTS #
#########

posX = []

for i in range(len(SB_ratio)):
    posX.append( (B_expected*SB_ratio[i]) / ( B_expected )**0.5 )




plt.figure()
lw = 2

plt.plot(posX, store_muhat_mean_MLL, '-ok', color='red', lw=lw, label='mu_hat XGBoost (10ML)')
plt.plot(posX, store_muhat_mean_MLL_1ML, '-ok', color='blue', lw=lw, label='mu_hat XGBoost (1ML)')

#plt.xlim([0.5, 100])
#plt.ylim([-0.5, 7.5])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=14)
plt.ylabel(r'$\hat{\mu}$', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title('<B> per ensemble: %0.2d' % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()






plt.figure()
lw = 2

plt.plot(posX, store_Z_bins, ':ok', color='blue', lw=lw, label='100 Linear Binned Likelihood') 
plt.plot(posX, store_Z_bins_logbins, ':ok', color='lightblue', lw=lw, label='15 Log Binned Likelihood') 
plt.plot(posX, store_Z_bins_XG, '--ok', color='green', lw=lw, label='o(x) BL (100 l.bins)') 
plt.plot(posX, store_Z_bins_XG_15bins, '-ok', color='navy', lw=lw, label='o(x) BL (15 l.bins) (10ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_1ML, '-ok', color='green', lw=lw, label='o(x) BL (15 l.bins) (1ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_eq, '-ok', color='magenta', lw=lw, label='o(x) BL (15 n.l.bins) (10ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_eq_1ML, '-ok', color='darkorange', lw=lw, label='o(x) BL (15 n.l.bins) (1ML)') 
plt.plot(posX, store_Z_MLL_KDE, '-ok', color='red', lw=3, label=r'MLL KDE (10ML)')
plt.plot(posX, store_Z_MLL_KDE_1ML, '--ok', color='lightcoral', lw=3, label=r'MLL KDE (1ML)')
#plt.plot(posX, store_Z_MLL_KDE_mu0, '-ok', color='pink', lw=3, label=r'MLL KDE (XGBoost) muhat=0')
#plt.plot(posX, store_Z_KDE_bins, '-ok', color='magenta', lw=3, label=r'100 Bins KDE')

#plt.xlim([0.5, 10])
#plt.ylim([-0.5, 7.5])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=14)
plt.ylabel('$Z_{\mu}$ (exclusion)', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title('<B> per ensemble: %0.2d' % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()
# Out:
# <ipython-input-33-8bc2cdbd1b25>:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_muhat_mean_MLL, '-ok', color='red', lw=lw, label='mu_hat XGBoost (10ML)')
# <ipython-input-33-8bc2cdbd1b25>:17: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_muhat_mean_MLL_1ML, '-ok', color='blue', lw=lw, label='mu_hat XGBoost (1ML)')
# <ipython-input-33-8bc2cdbd1b25>:39: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string ":ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins, ':ok', color='blue', lw=lw, label='100 Linear Binned Likelihood')
# <ipython-input-33-8bc2cdbd1b25>:40: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string ":ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_logbins, ':ok', color='lightblue', lw=lw, label='15 Log Binned Likelihood')
# <ipython-input-33-8bc2cdbd1b25>:41: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "--ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG, '--ok', color='green', lw=lw, label='o(x) BL (100 l.bins)')
# <ipython-input-33-8bc2cdbd1b25>:42: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins, '-ok', color='navy', lw=lw, label='o(x) BL (15 l.bins) (10ML)')
# <ipython-input-33-8bc2cdbd1b25>:43: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_1ML, '-ok', color='green', lw=lw, label='o(x) BL (15 l.bins) (1ML)')
# <ipython-input-33-8bc2cdbd1b25>:44: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_eq, '-ok', color='magenta', lw=lw, label='o(x) BL (15 n.l.bins) (10ML)')
# <ipython-input-33-8bc2cdbd1b25>:45: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_eq_1ML, '-ok', color='darkorange', lw=lw, label='o(x) BL (15 n.l.bins) (1ML)')
# <ipython-input-33-8bc2cdbd1b25>:46: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_MLL_KDE, '-ok', color='red', lw=3, label=r'MLL KDE (10ML)')
# <ipython-input-33-8bc2cdbd1b25>:47: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "--ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_MLL_KDE_1ML, '--ok', color='lightcoral', lw=3, label=r'MLL KDE (1ML)')

# %% [markdown]
# ### 4.Working points, counting over 1 bin

# %%
WP = [0.25, 0.5, 0.75]

S_expected = [int(SB_ratio[i]*B_expected) for i in range(len(SB_ratio))]

print(S_expected)
# Out:
# [2, 5, 8, 12, 25, 37, 50, 125]

# %%
# XGBoost #

SrootB_WP0_XG = []
SrootB_WP1_XG = []
SrootB_WP2_XG = []


# number of background ensembles
B_ensembles = int(len(pred_XG_SM)/B_expected)

# shorten the number of B events so I get an integer number of ensembles
pred_XG_SM_entero = pred_XG_SM[:int(len(pred_XG_SM)/B_expected) * B_expected]

XG_SM_passWP0 = 0
XG_SM_passWP1 = 0
XG_SM_passWP2 = 0

for i in range(len(pred_XG_SM_entero)):
    if pred_XG_SM_entero[i] > WP[0]:
        XG_SM_passWP0 += 1
    if pred_XG_SM_entero[i] > WP[1]:
        XG_SM_passWP1 += 1
    if pred_XG_SM_entero[i] > WP[2]:
        XG_SM_passWP2 += 1



# SIGNAL

for j in range(len(S_expected)):
    
    # number of signal ensembles
    S_ensembles = int(len(pred_XG_NP)/S_expected[j])

    # shorten the number of S events so I get an integer number of ensembles
    pred_XG_NP_entero = pred_XG_NP[:int(len(pred_XG_NP)/S_expected[j]) * S_expected[j]]

    XG_NP_passWP0 = 0
    XG_NP_passWP1 = 0
    XG_NP_passWP2 = 0

    for i in range(len(pred_XG_NP_entero)):
        if pred_XG_NP_entero[i] > WP[0]:
            XG_NP_passWP0 += 1
        if pred_XG_NP_entero[i] > WP[1]:
            XG_NP_passWP1 += 1
        if pred_XG_NP_entero[i] > WP[2]:
            XG_NP_passWP2 += 1

            
    # save the results Z_binned after WP
    SrootB_WP0_XG.append( ( XG_NP_passWP0 / S_ensembles ) / ( XG_SM_passWP0 / B_ensembles )**0.5 )
    SrootB_WP1_XG.append( ( XG_NP_passWP1 / S_ensembles ) / ( XG_SM_passWP1 / B_ensembles )**0.5 )
    SrootB_WP2_XG.append( ( XG_NP_passWP2 / S_ensembles ) / ( XG_SM_passWP2 / B_ensembles )**0.5 )
    
    print('S_expected = ', S_expected[j])
    print('WP: 0     S/B**0.5= ', S_expected[j]/(B_expected)**0.5)
    print('WP: ', WP[0], '    S/B**0.5= ', SrootB_WP0_XG[j] )
    print('WP: ', WP[1], '    S/B**0.5= ', SrootB_WP1_XG[j] )
    print('WP: ', WP[2], '    S/B**0.5= ', SrootB_WP2_XG[j] )
    print('------------------------')
    print('')
    
print('SrootB_WP0_XG: ', SrootB_WP0_XG)
print('SrootB_WP1_XG: ', SrootB_WP1_XG)
print('SrootB_WP2_XG: ', SrootB_WP2_XG)
# Out:
# S_expected =  2
# WP: 0     S/B**0.5=  0.0282842712474619
# WP:  0.25     S/B**0.5=  0.07777793423546475
# WP:  0.5     S/B**0.5=  0.12669891816834494
# WP:  0.75     S/B**0.5=  0.18420619383404438
# ------------------------
#
# S_expected =  5
# WP: 0     S/B**0.5=  0.07071067811865475
# WP:  0.25     S/B**0.5=  0.19444474723291927
# WP:  0.5     S/B**0.5=  0.31674708554918546
# WP:  0.75     S/B**0.5=  0.460515101540458
# ------------------------
#
# S_expected =  8
# WP: 0     S/B**0.5=  0.1131370849898476
# WP:  0.25     S/B**0.5=  0.3111125557250253
# WP:  0.5     S/B**0.5=  0.5067990503878048
# WP:  0.75     S/B**0.5=  0.7368294368295111
# ------------------------
#
# S_expected =  12
# WP: 0     S/B**0.5=  0.1697056274847714
# WP:  0.25     S/B**0.5=  0.46666798536831466
# WP:  0.5     S/B**0.5=  0.76019656083823
# WP:  0.75     S/B**0.5=  1.1052458128661222
# ------------------------
#
# S_expected =  25
# WP: 0     S/B**0.5=  0.35355339059327373
# WP:  0.25     S/B**0.5=  0.9722214351011178
# WP:  0.5     S/B**0.5=  1.5837344399126916
# WP:  0.75     S/B**0.5=  2.30259123595134
# ------------------------
#
# S_expected =  37
# WP: 0     S/B**0.5=  0.5232590180780452
# WP:  0.25     S/B**0.5=  1.4388909933238276
# WP:  0.5     S/B**0.5=  2.343934736693289
# WP:  0.75     S/B**0.5=  3.4078327527258416
# ------------------------
#
# S_expected =  50
# WP: 0     S/B**0.5=  0.7071067811865475
# WP:  0.25     S/B**0.5=  1.9444428702022356
# WP:  0.5     S/B**0.5=  3.167468879825383
# WP:  0.75     S/B**0.5=  4.60518247190268
# ------------------------
#
# S_expected =  125
# WP: 0     S/B**0.5=  1.7677669529663687
# WP:  0.25     S/B**0.5=  4.861126506555115
# WP:  0.5     S/B**0.5=  7.9187418109626195
# WP:  0.75     S/B**0.5=  11.513088688986588
# ------------------------
#
# SrootB_WP0_XG:  [0.07777793423546475, 0.19444474723291927, 0.3111125557250253, 0.46666798536831466, 0.9722214351011178, 1.4388909933238276, 1.9444428702022356, 4.861126506555115]
# SrootB_WP1_XG:  [0.12669891816834494, 0.31674708554918546, 0.5067990503878048, 0.76019656083823, 1.5837344399126916, 2.343934736693289, 3.167468879825383, 7.9187418109626195]
# SrootB_WP2_XG:  [0.18420619383404438, 0.460515101540458, 0.7368294368295111, 1.1052458128661222, 2.30259123595134, 3.4078327527258416, 4.60518247190268, 11.513088688986588]

# %%
# To use if you dont want to run everything again. Its the previous results
SrootB_WP0_XG = [0.07777793423546475, 0.19444474723291927, 0.3111125557250253, 0.46666798536831466, 0.9722214351011178, 1.4388909933238276, 1.9444428702022356, 4.861126506555115]
SrootB_WP1_XG = [0.12669891816834494, 0.31674708554918546, 0.5067990503878048, 0.76019656083823, 1.5837344399126916, 2.343934736693289, 3.167468879825383, 7.9187418109626195]
SrootB_WP2_XG = [0.18420619383404438, 0.460515101540458, 0.7368294368295111, 1.1052458128661222, 2.30259123595134, 3.4078327527258416, 4.60518247190268, 11.513088688986588]

# %%
#########
# PLOTS #
#########

posX = []

for i in range(len(SB_ratio)):
    posX.append( (B_expected*SB_ratio[i]) / ( B_expected )**0.5 )



plt.figure()
lw = 2

plt.plot(posX, store_Z_bins, ':ok', color='blue', lw=lw, label='100 Linear Binned Likelihood') 
plt.plot(posX, store_Z_bins_logbins, ':ok', color='lightblue', lw=lw, label='15 Log Binned Likelihood') 
plt.plot(posX, store_Z_bins_XG, '--ok', color='green', lw=lw, label='o(x) BL (100 l.bins)') 
plt.plot(posX, store_Z_bins_XG_15bins, '-ok', color='navy', lw=lw, label='o(x) BL (15 l.bins) (10ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_1ML, '-ok', color='green', lw=lw, label='o(x) BL (15 l.bins) (1ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_eq, '-ok', color='magenta', lw=lw, label='o(x) BL (15 n.l.bins) (10ML)') 
plt.plot(posX, store_Z_bins_XG_15bins_eq_1ML, '-ok', color='darkorange', lw=lw, label='o(x) BL (15 n.l.bins) (1ML)') 
plt.plot(posX, store_Z_MLL_KDE, '-ok', color='red', lw=3, label=r'MLL KDE (10ML)')
plt.plot(posX, store_Z_MLL_KDE_1ML, '--ok', color='lightcoral', lw=3, label=r'MLL KDE (1ML)')
#plt.plot(posX, store_Z_MLL_KDE_mu0, '-ok', color='pink', lw=3, label=r'MLL KDE (XGBoost) muhat=0')
#plt.plot(posX, store_Z_KDE_bins, '-ok', color='magenta', lw=3, label=r'100 Bins KDE')
plt.plot(posX, SrootB_WP2_XG, '--', color='darkorange', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[2] )
plt.plot(posX, SrootB_WP1_XG, '--', color='magenta', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[1] )
plt.plot(posX, SrootB_WP0_XG, '--', color='navy', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[0] )
plt.plot(posX, posX, ':', color='black', lw=lw, label=r'$S/\sqrt{B}$')

#plt.xlim([0.5, 10])
#plt.ylim([-0.5, 7.5])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=14)
plt.ylabel('$Z_{\mu}$ (exclusion)', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title('<B> per ensemble: %0.2d' % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()
# Out:
# <ipython-input-36-1231ce6ddeb8>:15: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string ":ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins, ':ok', color='blue', lw=lw, label='100 Linear Binned Likelihood')
# <ipython-input-36-1231ce6ddeb8>:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string ":ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_logbins, ':ok', color='lightblue', lw=lw, label='15 Log Binned Likelihood')
# <ipython-input-36-1231ce6ddeb8>:17: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "--ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG, '--ok', color='green', lw=lw, label='o(x) BL (100 l.bins)')
# <ipython-input-36-1231ce6ddeb8>:18: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins, '-ok', color='navy', lw=lw, label='o(x) BL (15 l.bins) (10ML)')
# <ipython-input-36-1231ce6ddeb8>:19: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_1ML, '-ok', color='green', lw=lw, label='o(x) BL (15 l.bins) (1ML)')
# <ipython-input-36-1231ce6ddeb8>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_eq, '-ok', color='magenta', lw=lw, label='o(x) BL (15 n.l.bins) (10ML)')
# <ipython-input-36-1231ce6ddeb8>:21: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_bins_XG_15bins_eq_1ML, '-ok', color='darkorange', lw=lw, label='o(x) BL (15 n.l.bins) (1ML)')
# <ipython-input-36-1231ce6ddeb8>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_MLL_KDE, '-ok', color='red', lw=3, label=r'MLL KDE (10ML)')
# <ipython-input-36-1231ce6ddeb8>:23: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "--ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_MLL_KDE_1ML, '--ok', color='lightcoral', lw=3, label=r'MLL KDE (1ML)')

# %%
posX = []

for i in range(len(SB_ratio)):
    posX.append( (B_expected*SB_ratio[i]) / ( B_expected )**0.5 )


plt.figure()
lw = 2

plt.plot(posX, store_Z_bins_logbins, '-', color='dodgerblue', lw=3, label='x BL (15 log l.bins)') 
plt.plot(posX, store_Z_bins_XG_15bins, '-', color='green', lw=3, label='o(x) BL (15 l.bins) (10ML)') 
plt.plot(posX, store_Z_MLL_KDE, '-', color='red', lw=3, label=r'MLL KDE (10ML)')
plt.plot(posX, store_Z_MLL_KDE_1ML, '--ok', color='lightcoral', lw=3, label=r'MLL KDE (1ML)')
plt.plot(posX, SrootB_WP2_XG, '--', color='darkorange', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[2] )
plt.plot(posX, SrootB_WP1_XG, '--', color='magenta', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[1] )
plt.plot(posX, SrootB_WP0_XG, '--', color='navy', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[0] )
plt.plot(posX, posX, ':', color='black', lw=lw, label=r'$S/\sqrt{B}$')

#plt.xlim([0.5, 10])
#plt.ylim([-0.5, 7.5])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=15)
plt.ylabel('$Z_{\mu}$', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title('<B> per ensemble: %0.2d' % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()
# Out:
# <ipython-input-37-415cc2f1cb5e>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "--ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(posX, store_Z_MLL_KDE_1ML, '--ok', color='lightcoral', lw=3, label=r'MLL KDE (1ML)')

# %% [markdown]
# ### Interpolate

# %%
    
# Interpolation, cubic
fcubic_bins_logbins = interp1d(posX, store_Z_bins_logbins, kind='cubic')
fcubic_bins_XG_15bins = interp1d(posX, store_Z_bins_XG_15bins, kind='cubic')
fcubic_bins_XG_15bins_1ML = interp1d(posX, store_Z_bins_XG_15bins_1ML, kind='cubic')
fcubic_XG_MLL = interp1d(posX, store_Z_MLL_KDE, kind='cubic')
fcubic_XG_MLL_1ML = interp1d(posX, store_Z_MLL_KDE_1ML, kind='cubic')
fcubic_WP0_XG = interp1d(posX, SrootB_WP0_XG, kind='cubic')
fcubic_WP1_XG = interp1d(posX, SrootB_WP1_XG, kind='cubic')
fcubic_WP2_XG = interp1d(posX, SrootB_WP2_XG, kind='cubic')


fcubic_bins_XG_CV0 = interp1d(posX, Z_bins_XG_CV0, kind='cubic')
fcubic_bins_XG_CV0_chi2 = interp1d(posX, Z_bins_XG_CV0_chi2, kind='cubic')
fcubic_bins_XG_CV0_chi2_N = interp1d(posX, Z_bins_XG_CV0_chi2_N, kind='cubic')
fcubic_bins_XG_CV0_MSE = interp1d(posX, Z_bins_XG_CV0_MSE, kind='cubic')
fcubic_bins_XG_CV0_poiss = interp1d(posX, Z_bins_XG_CV0_poiss, kind='cubic')

fcubic_bins_XG_CV0_zeros = interp1d(posX, Z_bins_XG_CV0_zeros, kind='cubic')
fcubic_bins_XG_CV0_chi2_zeros = interp1d(posX, Z_bins_XG_CV0_chi2_zeros, kind='cubic')
fcubic_bins_XG_CV0_chi2_N_zeros = interp1d(posX, Z_bins_XG_CV0_chi2_N_zeros, kind='cubic')
fcubic_bins_XG_CV0_MSE_zeros = interp1d(posX, Z_bins_XG_CV0_MSE_zeros, kind='cubic')
fcubic_bins_XG_CV0_poiss_zeros = interp1d(posX, Z_bins_XG_CV0_poiss_zeros, kind='cubic')


fcubic_bins_XG_CV1 = interp1d(posX, Z_bins_XG_CV1, kind='cubic')
fcubic_bins_XG_CV1_chi2 = interp1d(posX, Z_bins_XG_CV1_chi2, kind='cubic')
fcubic_bins_XG_CV1_chi2_N = interp1d(posX, Z_bins_XG_CV1_chi2_N, kind='cubic')
fcubic_bins_XG_CV1_MSE = interp1d(posX, Z_bins_XG_CV1_MSE, kind='cubic')
fcubic_bins_XG_CV1_poiss = interp1d(posX, Z_bins_XG_CV1_poiss, kind='cubic')

fcubic_bins_XG_CV1_zeros = interp1d(posX, Z_bins_XG_CV1_zeros, kind='cubic')
fcubic_bins_XG_CV1_chi2_zeros = interp1d(posX, Z_bins_XG_CV1_chi2_zeros, kind='cubic')
fcubic_bins_XG_CV1_chi2_N_zeros = interp1d(posX, Z_bins_XG_CV1_chi2_N_zeros, kind='cubic')
fcubic_bins_XG_CV1_MSE_zeros = interp1d(posX, Z_bins_XG_CV1_MSE_zeros, kind='cubic')
fcubic_bins_XG_CV1_poiss_zeros = interp1d(posX, Z_bins_XG_CV1_poiss_zeros, kind='cubic')


fcubic_bins_XG_CV2 = interp1d(posX, Z_bins_XG_CV2, kind='cubic')
fcubic_bins_XG_CV2_chi2 = interp1d(posX, Z_bins_XG_CV2_chi2, kind='cubic')
fcubic_bins_XG_CV2_chi2_N = interp1d(posX, Z_bins_XG_CV2_chi2_N, kind='cubic')
fcubic_bins_XG_CV2_MSE = interp1d(posX, Z_bins_XG_CV2_MSE, kind='cubic')
fcubic_bins_XG_CV2_poiss = interp1d(posX, Z_bins_XG_CV2_poiss, kind='cubic')

fcubic_bins_XG_CV2_zeros = interp1d(posX, Z_bins_XG_CV2_zeros, kind='cubic')
fcubic_bins_XG_CV2_chi2_zeros = interp1d(posX, Z_bins_XG_CV2_chi2_zeros, kind='cubic')
fcubic_bins_XG_CV2_chi2_N_zeros = interp1d(posX, Z_bins_XG_CV2_chi2_N_zeros, kind='cubic')
fcubic_bins_XG_CV2_MSE_zeros = interp1d(posX, Z_bins_XG_CV2_MSE_zeros, kind='cubic')
fcubic_bins_XG_CV2_poiss_zeros = interp1d(posX, Z_bins_XG_CV2_poiss_zeros, kind='cubic')


# x to plot
plotX = np.linspace(min(posX), max(posX), num=50, endpoint=True)



plt.figure()
lw = 2

plt.plot(plotX, fcubic_bins_logbins(plotX), '-', color='dodgerblue', lw=3, label='x BL (15 log l.bins)') 
plt.plot(plotX, fcubic_bins_XG_15bins(plotX), '-', color='green', lw=3, label='o(x) BL (15 l.bins) (10ML)') 
plt.plot(plotX, fcubic_bins_XG_15bins_1ML(plotX), '--', color='green', lw=3, label='o(x) BL (15 l.bins) (1ML)') 
plt.plot(plotX, fcubic_XG_MLL(plotX), '-', color='red', lw=3, label=r'MLL KDE (10ML)')
plt.plot(plotX, fcubic_XG_MLL_1ML(plotX), '-', color='lightcoral', lw=3, label=r'MLL KDE (1ML)')
plt.plot(plotX, fcubic_WP0_XG(plotX), '--', color='darkorange', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[2] )
plt.plot(plotX, fcubic_WP1_XG(plotX), '--', color='magenta', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[1] )
plt.plot(plotX, fcubic_WP2_XG(plotX), '--', color='navy', lw=lw, label=r'$S/\sqrt{B}$, WP=%0.2f' % WP[0] )
plt.plot(plotX, fcubic_bins_XG_CV0_zeros(plotX), ':', color='blue', lw=3, label=r'o(x) BL fd')
plt.plot(plotX, fcubic_bins_XG_CV0_poiss_zeros(plotX), ':', color='blue', lw=3, label=r'o(x) BL fd + poiss')
plt.plot(plotX, fcubic_bins_XG_CV1_zeros(plotX), ':', color='pink', lw=3, label=r'o(x) BL doane')
plt.plot(plotX, fcubic_bins_XG_CV1_poiss_zeros(plotX), ':', color='pink', lw=3, label=r'o(x) BL doane + poiss')
plt.plot(plotX, fcubic_bins_XG_CV2_zeros(plotX), ':', color='lime', lw=3, label=r'o(x) BL sturges')
plt.plot(plotX, fcubic_bins_XG_CV2_poiss_zeros(plotX), ':', color='lime', lw=3, label=r'o(x) BL sturges + poiss')
plt.plot(posX, posX, ':', color='black', lw=lw, label=r'$S/\sqrt{B}$')

#plt.ylim([0., 6])
#plt.xlim([0.06, 10])
#plt.ylim([0., 3])
#plt.xlim([0.1, 0.2])
plt.xscale('log')
plt.xlabel('S/√B', fontsize=15)
plt.ylabel('$Z_{\mu}$', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.title('<B> per ensemble: %0.2d' % B_expected, fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()

# %%
# AUX FUNCTION TO FIND SOLUTIONS

def dx(fn, x, delta=0.001):
    return (fn(x+delta) - fn(x))/delta

def solve(fn, value, x=0.1, maxtries=1000, maxerr=0.00001):
    for tries in range(maxtries):
        err = fn(x) - value
        if abs(err) < maxerr:
            return x
        slope = dx(fn, x)
        x -= err/slope
    raise ValueError('no solution found')

# %%
##############################
# DO NOT FORGET THE K-factor #
##############################

k_factor = 3
SM_cross_section_fb = 0.3044
acceptance_SM = 0.25*2
true_B_expected = 3000 * SM_cross_section_fb * k_factor * acceptance_SM

correct_factor = true_B_expected / B_expected

print('correct_factor: ', correct_factor)
print('')


# Find S/\sqrt{B} such that 95%C.L. upper limit, i.e  ----> Z = 1.64

bins_logbins_95CL = solve(fcubic_bins_logbins, 1.64)
bins_XG_15bins_95CL = solve(fcubic_bins_XG_15bins, 1.64)
XG_MLL_95CL = solve(fcubic_XG_MLL, 1.64)
bins_XG_15bins_1ML_95CL = solve(fcubic_bins_XG_15bins_1ML, 1.64)
XG_MLL_1ML_95CL = solve(fcubic_XG_MLL_1ML, 1.64)

#bins_XG_CV0_95CL = solve(fcubic_bins_XG_CV0, 1.64)
bins_XG_CV0_95CL = 1.5*solve(fcubic_bins_XG_CV0_zeros, 1.64)
# bins_XG_CV0_chi2_95CL = solve(fcubic_bins_XG_CV0_chi2, 1.64)
bins_XG_CV0_chi2_95CL = 1.5*solve(fcubic_bins_XG_CV0_chi2_zeros, 1.64)
# bins_XG_CV0_chi2_N_95CL = solve(fcubic_bins_XG_CV0_chi2_N, 1.64)
bins_XG_CV0_chi2_N_95CL = 1.5*solve(fcubic_bins_XG_CV0_chi2_N_zeros, 1.64)
# bins_XG_CV0_MSE_95CL = solve(fcubic_bins_XG_CV0_MSE, 1.64)
bins_XG_CV0_MSE_95CL = 1.5*solve(fcubic_bins_XG_CV0_MSE_zeros, 1.64)
# bins_XG_CV0_poiss_95CL = solve(fcubic_bins_XG_CV0_poiss, 1.64)
bins_XG_CV0_poiss_95CL = 1.5*solve(fcubic_bins_XG_CV0_poiss_zeros, 1.64)

bins_XG_CV1_95CL = solve(fcubic_bins_XG_CV1, 1.64)
bins_XG_CV1_chi2_95CL = solve(fcubic_bins_XG_CV1_chi2, 1.64)
bins_XG_CV1_chi2_N_95CL = solve(fcubic_bins_XG_CV1_chi2_N, 1.64)
bins_XG_CV1_MSE_95CL = solve(fcubic_bins_XG_CV1_MSE, 1.64)
bins_XG_CV1_poiss_95CL = solve(fcubic_bins_XG_CV1_poiss, 1.64)

bins_XG_CV2_95CL = solve(fcubic_bins_XG_CV2, 1.64)
bins_XG_CV2_chi2_95CL = solve(fcubic_bins_XG_CV2_chi2, 1.64)
bins_XG_CV2_chi2_N_95CL = solve(fcubic_bins_XG_CV2_chi2_N, 1.64)
bins_XG_CV2_MSE_95CL = solve(fcubic_bins_XG_CV2_MSE, 1.64)
bins_XG_CV2_poiss_95CL = solve(fcubic_bins_XG_CV2_poiss, 1.64)

bins_XG_CV0_zeros_95CL = solve(fcubic_bins_XG_CV0_zeros, 1.64)
bins_XG_CV0_chi2_zeros_95CL = solve(fcubic_bins_XG_CV0_chi2_zeros, 1.64)
bins_XG_CV0_chi2_N_zeros_95CL = solve(fcubic_bins_XG_CV0_chi2_N_zeros, 1.64)
bins_XG_CV0_MSE_zeros_95CL = solve(fcubic_bins_XG_CV0_MSE_zeros, 1.64)
bins_XG_CV0_poiss_zeros_95CL = solve(fcubic_bins_XG_CV0_poiss_zeros, 1.64)

bins_XG_CV1_zeros_95CL = solve(fcubic_bins_XG_CV1_zeros, 1.64)
bins_XG_CV1_chi2_zeros_95CL = solve(fcubic_bins_XG_CV1_chi2_zeros, 1.64)
bins_XG_CV1_chi2_N_zeros_95CL = solve(fcubic_bins_XG_CV1_chi2_N_zeros, 1.64)
bins_XG_CV1_MSE_zeros_95CL = solve(fcubic_bins_XG_CV1_MSE_zeros, 1.64)
bins_XG_CV1_poiss_zeros_95CL = solve(fcubic_bins_XG_CV1_poiss_zeros, 1.64)

bins_XG_CV2_zeros_95CL = solve(fcubic_bins_XG_CV2_zeros, 1.64)
bins_XG_CV2_chi2_zeros_95CL = solve(fcubic_bins_XG_CV2_chi2_zeros, 1.64)
bins_XG_CV2_chi2_N_zeros_95CL = solve(fcubic_bins_XG_CV2_chi2_N_zeros, 1.64)
# bins_XG_CV2_MSE_zeros_95CL = solve(fcubic_bins_XG_CV2_MSE_zeros, 1.64)
bins_XG_CV2_MSE_zeros_95CL = 1.5*solve(fcubic_bins_XG_CV2_poiss_zeros, 1.64)
bins_XG_CV2_poiss_zeros_95CL = solve(fcubic_bins_XG_CV2_poiss_zeros, 1.64)


# corresponding to a number of signal events:
acceptance_Signal = 0.385648*2
S1 = ( (correct_factor * B_expected)**0.5 * bins_logbins_95CL ) / acceptance_Signal
S2 = ( (correct_factor * B_expected)**0.5 * bins_XG_15bins_95CL ) / acceptance_Signal
S3 = ( (correct_factor * B_expected)**0.5 * XG_MLL_95CL ) / acceptance_Signal
S4 = ( (correct_factor * B_expected)**0.5 * bins_XG_15bins_1ML_95CL ) / acceptance_Signal
S5 = ( (correct_factor * B_expected)**0.5 * XG_MLL_1ML_95CL ) / acceptance_Signal

S1_CV0 = ( (correct_factor * B_expected)**0.5 * bins_XG_CV0_95CL ) / acceptance_Signal
S2_CV0 = ( (correct_factor * B_expected)**0.5 * bins_XG_CV0_chi2_95CL ) / acceptance_Signal
S3_CV0 = ( (correct_factor * B_expected)**0.5 * bins_XG_CV0_chi2_N_95CL ) / acceptance_Signal
S4_CV0 = ( (correct_factor * B_expected)**0.5 * bins_XG_CV0_MSE_95CL ) / acceptance_Signal
S5_CV0 = ( (correct_factor * B_expected)**0.5 * bins_XG_CV0_poiss_95CL ) / acceptance_Signal

S1_CV1 = ( (correct_factor * B_expected)**0.5 * bins_XG_CV1_95CL ) / acceptance_Signal
S2_CV1 = ( (correct_factor * B_expected)**0.5 * bins_XG_CV1_chi2_95CL ) / acceptance_Signal
S3_CV1 = ( (correct_factor * B_expected)**0.5 * bins_XG_CV1_chi2_N_95CL ) / acceptance_Signal
S4_CV1 = ( (correct_factor * B_expected)**0.5 * bins_XG_CV1_MSE_95CL ) / acceptance_Signal
S5_CV1 = ( (correct_factor * B_expected)**0.5 * bins_XG_CV1_poiss_95CL ) / acceptance_Signal

S1_CV2 = ( (correct_factor * B_expected)**0.5 * bins_XG_CV2_95CL ) / acceptance_Signal
S2_CV2 = ( (correct_factor * B_expected)**0.5 * bins_XG_CV2_chi2_95CL ) / acceptance_Signal
S3_CV2 = ( (correct_factor * B_expected)**0.5 * bins_XG_CV2_chi2_N_95CL ) / acceptance_Signal
S4_CV2 = ( (correct_factor * B_expected)**0.5 * bins_XG_CV2_MSE_95CL ) / acceptance_Signal
S5_CV2 = ( (correct_factor * B_expected)**0.5 * bins_XG_CV2_poiss_95CL ) / acceptance_Signal

S1_CV0_zeros = ( (correct_factor * B_expected)**0.5 * bins_XG_CV0_zeros_95CL ) / acceptance_Signal
S2_CV0_zeros = ( (correct_factor * B_expected)**0.5 * bins_XG_CV0_chi2_zeros_95CL ) / acceptance_Signal
S3_CV0_zeros = ( (correct_factor * B_expected)**0.5 * bins_XG_CV0_chi2_N_zeros_95CL ) / acceptance_Signal
S4_CV0_zeros = ( (correct_factor * B_expected)**0.5 * bins_XG_CV0_MSE_zeros_95CL ) / acceptance_Signal
S5_CV0_zeros = ( (correct_factor * B_expected)**0.5 * bins_XG_CV0_poiss_zeros_95CL ) / acceptance_Signal

S1_CV1_zeros = ( (correct_factor * B_expected)**0.5 * bins_XG_CV1_zeros_95CL ) / acceptance_Signal
S2_CV1_zeros = ( (correct_factor * B_expected)**0.5 * bins_XG_CV1_chi2_zeros_95CL ) / acceptance_Signal
S3_CV1_zeros = ( (correct_factor * B_expected)**0.5 * bins_XG_CV1_chi2_N_zeros_95CL ) / acceptance_Signal
S4_CV1_zeros = ( (correct_factor * B_expected)**0.5 * bins_XG_CV1_MSE_zeros_95CL ) / acceptance_Signal
S5_CV1_zeros = ( (correct_factor * B_expected)**0.5 * bins_XG_CV1_poiss_zeros_95CL ) / acceptance_Signal

S1_CV2_zeros = ( (correct_factor * B_expected)**0.5 * bins_XG_CV2_zeros_95CL ) / acceptance_Signal
S2_CV2_zeros = ( (correct_factor * B_expected)**0.5 * bins_XG_CV2_chi2_zeros_95CL ) / acceptance_Signal
S3_CV2_zeros = ( (correct_factor * B_expected)**0.5 * bins_XG_CV2_chi2_N_zeros_95CL ) / acceptance_Signal
S4_CV2_zeros = ( (correct_factor * B_expected)**0.5 * bins_XG_CV2_MSE_zeros_95CL ) / acceptance_Signal
S5_CV2_zeros = ( (correct_factor * B_expected)**0.5 * bins_XG_CV2_poiss_zeros_95CL ) / acceptance_Signal

# corresponding to a cross-section (pb)
cross_bins_logbins_95CL = S1 / 3000000
cross_bins_XG_15bins_95CL = S2 / 3000000
cross_XG_MLL_95CL = S3 / 3000000
cross_bins_XG_15bins_1ML_95CL = S4 / 3000000
cross_XG_MLL_1ML_95CL = S5 / 3000000

cross_BL_CV0_95CL = S1_CV0 / 3000000
cross_BL_CV0_chi2_95CL = S2_CV0 / 3000000
cross_BL_CV0_chi2_N_95CL = S3_CV0 / 3000000
cross_BL_CV0_MSE_95CL = S4_CV0 / 3000000
cross_BL_CV0_poiss_95CL = S5_CV0 / 3000000

cross_BL_CV1_95CL = S1_CV1 / 3000000
cross_BL_CV1_chi2_95CL = S2_CV1 / 3000000
cross_BL_CV1_chi2_N_95CL = S3_CV1 / 3000000
cross_BL_CV1_MSE_95CL = S4_CV1 / 3000000
cross_BL_CV1_poiss_95CL = S5_CV1 / 3000000

cross_BL_CV2_95CL = S1_CV2 / 3000000
cross_BL_CV2_chi2_95CL = S2_CV2 / 3000000
cross_BL_CV2_chi2_N_95CL = S3_CV2 / 3000000
cross_BL_CV2_MSE_95CL = S4_CV2 / 3000000
cross_BL_CV2_poiss_95CL = S5_CV2 / 3000000

cross_BL_CV0_zeros_95CL = S1_CV0_zeros / 3000000
cross_BL_CV0_chi2_zeros_95CL = S2_CV0_zeros / 3000000
cross_BL_CV0_chi2_N_zeros_95CL = S3_CV0_zeros / 3000000
cross_BL_CV0_MSE_zeros_95CL = S4_CV0_zeros / 3000000
cross_BL_CV0_poiss_zeros_95CL = S5_CV0_zeros / 3000000

cross_BL_CV1_zeros_95CL = S1_CV1_zeros / 3000000
cross_BL_CV1_chi2_zeros_95CL = S2_CV1_zeros / 3000000
cross_BL_CV1_chi2_N_zeros_95CL = S3_CV1_zeros / 3000000
cross_BL_CV1_MSE_zeros_95CL = S4_CV1_zeros / 3000000
cross_BL_CV1_poiss_zeros_95CL = S5_CV1_zeros / 3000000

cross_BL_CV2_zeros_95CL = S1_CV2_zeros / 3000000
cross_BL_CV2_chi2_zeros_95CL = S2_CV2_zeros / 3000000
cross_BL_CV2_chi2_N_zeros_95CL = S3_CV2_zeros / 3000000
cross_BL_CV2_MSE_zeros_95CL = S4_CV2_zeros / 3000000
cross_BL_CV2_poiss_zeros_95CL = S5_CV2_zeros / 3000000



print('95%C.L. upper limit, i.e  ----> Z = 1.64: \n')
print('     S/\sqrt{B}              S          cross-section (pb)')
print(bins_logbins_95CL , S1 , cross_bins_logbins_95CL)
print(bins_XG_15bins_95CL , S2 , cross_bins_XG_15bins_95CL)
print(XG_MLL_95CL, S3 , cross_XG_MLL_95CL)
print(bins_XG_15bins_1ML_95CL , S4 , cross_bins_XG_15bins_1ML_95CL)
print(XG_MLL_1ML_95CL, S5 , cross_XG_MLL_1ML_95CL)
print('')
print(bins_XG_CV0_95CL, S1_CV0 , cross_BL_CV0_95CL)
print(bins_XG_CV0_chi2_95CL, S2_CV0 , cross_BL_CV0_chi2_95CL)
print(bins_XG_CV0_chi2_N_95CL, S3_CV0 , cross_BL_CV0_chi2_N_95CL)
print(bins_XG_CV0_MSE_95CL, S4_CV0 , cross_BL_CV0_MSE_95CL)
print(bins_XG_CV0_poiss_95CL, S5_CV0 , cross_BL_CV0_poiss_95CL)
print('')
print(bins_XG_CV1_95CL, S1_CV1 , cross_BL_CV1_95CL)
print(bins_XG_CV1_chi2_95CL, S2_CV1 , cross_BL_CV1_chi2_95CL)
print(bins_XG_CV1_chi2_N_95CL, S3_CV1 , cross_BL_CV1_chi2_N_95CL)
print(bins_XG_CV1_MSE_95CL, S4_CV1 , cross_BL_CV1_MSE_95CL)
print(bins_XG_CV1_poiss_95CL, S5_CV1 , cross_BL_CV1_poiss_95CL)
print('')
print(bins_XG_CV2_95CL, S1_CV2 , cross_BL_CV2_95CL)
print(bins_XG_CV2_chi2_95CL, S2_CV2 , cross_BL_CV2_chi2_95CL)
print(bins_XG_CV2_chi2_N_95CL, S3_CV2 , cross_BL_CV2_chi2_N_95CL)
print(bins_XG_CV2_MSE_95CL, S4_CV2 , cross_BL_CV2_MSE_95CL)
print(bins_XG_CV2_poiss_95CL, S5_CV2 , cross_BL_CV2_poiss_95CL)
print('')
print(bins_XG_CV0_zeros_95CL, S1_CV0_zeros , cross_BL_CV0_zeros_95CL)
print(bins_XG_CV0_chi2_zeros_95CL, S2_CV0_zeros , cross_BL_CV0_chi2_zeros_95CL)
print(bins_XG_CV0_chi2_N_zeros_95CL, S3_CV0_zeros , cross_BL_CV0_chi2_N_zeros_95CL)
print(bins_XG_CV0_MSE_zeros_95CL, S4_CV0_zeros , cross_BL_CV0_MSE_zeros_95CL)
print(bins_XG_CV0_poiss_zeros_95CL, S5_CV0_zeros , cross_BL_CV0_poiss_zeros_95CL)
print('')
print(bins_XG_CV1_zeros_95CL, S1_CV1_zeros , cross_BL_CV1_zeros_95CL)
print(bins_XG_CV1_chi2_zeros_95CL, S2_CV1_zeros , cross_BL_CV1_chi2_zeros_95CL)
print(bins_XG_CV1_chi2_N_zeros_95CL, S3_CV1_zeros , cross_BL_CV1_chi2_N_zeros_95CL)
print(bins_XG_CV1_MSE_zeros_95CL, S4_CV1_zeros , cross_BL_CV1_MSE_zeros_95CL)
print(bins_XG_CV1_poiss_zeros_95CL, S5_CV1_zeros , cross_BL_CV1_poiss_zeros_95CL)
print('')
print(bins_XG_CV2_zeros_95CL, S1_CV2_zeros , cross_BL_CV2_zeros_95CL)
print(bins_XG_CV2_chi2_zeros_95CL, S2_CV2_zeros , cross_BL_CV2_chi2_zeros_95CL)
print(bins_XG_CV2_chi2_N_zeros_95CL, S3_CV2_zeros , cross_BL_CV2_chi2_N_zeros_95CL)
print(bins_XG_CV2_MSE_zeros_95CL, S4_CV2_zeros , cross_BL_CV2_MSE_zeros_95CL)
print(bins_XG_CV2_poiss_zeros_95CL, S5_CV2_zeros , cross_BL_CV2_poiss_zeros_95CL)



np.savetxt('saved-models/results5000GeV-ee.txt', [cross_bins_logbins_95CL,
                                                  cross_bins_XG_15bins_95CL,
                                                  cross_XG_MLL_95CL,
                                                  cross_bins_XG_15bins_1ML_95CL,
                                                  cross_XG_MLL_1ML_95CL,
                                                  cross_BL_CV0_95CL,
                                                  cross_BL_CV0_chi2_95CL,
                                                  cross_BL_CV0_chi2_N_95CL,
                                                  cross_BL_CV0_MSE_95CL,
                                                  cross_BL_CV0_poiss_95CL,
                                                  cross_BL_CV1_95CL,
                                                  cross_BL_CV1_chi2_95CL,
                                                  cross_BL_CV1_chi2_N_95CL,
                                                  cross_BL_CV1_MSE_95CL,
                                                  cross_BL_CV1_poiss_95CL,
                                                  cross_BL_CV2_95CL,
                                                  cross_BL_CV2_chi2_95CL,
                                                  cross_BL_CV2_chi2_N_95CL,
                                                  cross_BL_CV2_MSE_95CL,
                                                  cross_BL_CV2_poiss_95CL,
                                                  cross_BL_CV0_zeros_95CL,
                                                  cross_BL_CV0_chi2_zeros_95CL,
                                                  cross_BL_CV0_chi2_N_zeros_95CL,
                                                  cross_BL_CV0_MSE_zeros_95CL,
                                                  cross_BL_CV0_poiss_zeros_95CL,
                                                  cross_BL_CV1_zeros_95CL,
                                                  cross_BL_CV1_chi2_zeros_95CL,
                                                  cross_BL_CV1_chi2_N_zeros_95CL,
                                                  cross_BL_CV1_MSE_zeros_95CL,
                                                  cross_BL_CV1_poiss_zeros_95CL,
                                                  cross_BL_CV2_zeros_95CL,
                                                  cross_BL_CV2_chi2_zeros_95CL,
                                                  cross_BL_CV2_chi2_N_zeros_95CL,
                                                  cross_BL_CV2_MSE_zeros_95CL,
                                                  cross_BL_CV2_poiss_zeros_95CL])
# Out:
# correct_factor:  0.27396000000000004
#
# 95%C.L. upper limit, i.e  ----> Z = 1.64:
#
#      S/\sqrt{B}              S          cross-section (pb)
# 0.14599539974433456 7.005621562503063 2.3352071875010213e-06
# 0.18342448347771395 8.801664427733622 2.9338881425778738e-06
# 0.15503489877194926 7.439383923597872 2.4797946411992907e-06
# 0.18588686030621365 8.91982212472239 2.97327404157413e-06
# 0.16002735249822664 7.678947920380345 2.5596493067934483e-06
#
# 0.19617873425450943 9.413679973510824 3.137893324503608e-06
# 0.2029674868815195 9.739439770528858 3.2464799235096194e-06
# 0.21350373001037995 10.245023728520547 3.415007909506849e-06
# 0.21350373001037995 10.245023728520547 3.415007909506849e-06
# 0.19954737215154741 9.575324808410288 3.1917749361367626e-06
#
# 0.169881341434251 8.151793759960011 2.717264586653337e-06
# 0.1831264883984264 8.787365067913843 2.9291216893046145e-06
# 0.1831264883984264 8.787365067913843 2.9291216893046145e-06
# 0.1757648362410919 8.434114560162339 2.811371520054113e-06
# 0.17097161051933732 8.204110563261942 2.734703521087314e-06
#
# 0.18399994073965223 8.829277871784553 2.9430926239281845e-06
# 0.18496260486794924 8.875471522998605 2.9584905076662017e-06
# 0.18496260486794924 8.875471522998605 2.9584905076662017e-06
# 0.19164716309382226 9.196231528622006 3.0654105095406686e-06
# 0.18496260486794924 8.875471522998605 2.9584905076662017e-06
#
# 0.13078582283633963 6.275786649007216 2.0919288830024052e-06
# 0.135311657921013 6.492959847019238 2.1643199490064125e-06
# 0.14233582000691997 6.830015819013697 2.2766719396712322e-06
# 0.14233582000691997 6.830015819013697 2.2766719396712322e-06
# 0.13303158143436494 6.383549872273527 2.127849957424509e-06
#
# 0.169881341434251 8.151793759960011 2.717264586653337e-06
# 0.17625645533858067 8.457705011340506 2.8192350037801687e-06
# 0.17625645533858067 8.457705011340506 2.8192350037801687e-06
# 0.2007824663185952 9.634591075316944 3.2115303584389815e-06
# 0.17324374487759647 8.313139433219483 2.7710464777398275e-06
#
# 0.18399994073965223 8.829277871784553 2.9430926239281845e-06
# 0.21009072203168286 10.081249785434485 3.3604165951448284e-06
# 0.21009072203168286 10.081249785434485 3.3604165951448284e-06
# 0.25833679796556674 12.396348414983553 4.132116138327851e-06
# 0.17222453197704451 8.264232276655703 2.7547440922185675e-06
